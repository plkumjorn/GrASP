# %%
import pickle
from sklearn.model_selection import train_test_split
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
import nltk
from nltk.corpus import wordnet as wn
from nltk.wsd import lesk
from typing import Iterable, List, Set, Callable, Optional, Union, Sequence
from grasp import GrASP, CustomAttribute

# %% [markdown]
# ## Load the data
# - Download and unzip the spam dataset **if you have not done this before**

# %%
import urllib.request
url = 'http://www.dt.fee.unicamp.br/~tiago/smsspamcollection/smsspamcollection.zip'
filename = './data/smsspamcollection.zip'
urllib.request.urlretrieve(url, filename)

# %%
# !unzip ./data/smsspamcollection.zip -d ./data

# %% [markdown]
# - Load the data

# %%
def get_data():
    f = open('data/SMSSpamCollection.txt', 'r')
    texts, labels = [], []
    for line in f:
        line = line.strip()
        tab_idx = line.index('\t')
        label = line[:tab_idx]
        text = line[tab_idx+1:]
        if label == 'ham':
            label = 0
        elif label == 'spam':
            label = 1
        else:
            raise Exception(f"Invalid label - {label}")
        texts.append(text)
        labels.append(label)
    return texts, labels

# %%
texts, labels = get_data()
X_train, X_test, y_train, y_test = train_test_split(texts, labels, test_size=0.2, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1)
len(texts), sum(labels), len(X_test), sum(y_test)
# Out:
# (5574, 747, 1115, 138)

# %%
positive = [t for idx, t in enumerate(X_train) if y_train[idx]]
negative = [t for idx, t in enumerate(X_train) if not y_train[idx]]

# %% [markdown]
# ## Example 1

# %%
# Create the GrASP engine
grasp_model = GrASP(gaps_allowed = 0, num_patterns = 100)

# %%
# Fit GrASP to the dataset
the_patterns = grasp_model.fit_transform(positive, negative)
# Out:
#   0%|          | 0/488 [00:00<?, ?it/s]
# Step 1: Create augmented texts
# 100%|██████████| 488/488 [00:35<00:00, 13.56it/s]
# 100%|██████████| 3079/3079 [02:26<00:00, 20.99it/s]
# Step 2: Find frequent attributes
#   0%|          | 4/1336 [00:00<00:39, 33.70it/s]
# Total number of candidate alphabet = 1336, such as ['SPACY:DEP-ROOT', 'SPACY:POS-VERB', 'SPACY:POS-NOUN', 'SPACY:DEP-punct', 'SPACY:POS-PUNCT']
# Step 3: Find alphabet set
# 100%|██████████| 1336/1336 [00:52<00:00, 25.49it/s]
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
# Finding top k: 100 / 100
#   0%|          | 0/100 [00:00<?, ?it/s]
# Total number of alphabet = 100
# ['SPACY:POS-NUM', 'SPACY:DEP-compound', 'SPACY:NER-ORG', 'SPACY:POS-PROPN', 'SPACY:NER-DATE', 'TEXT:call', 'HYPERNYM:communication.n.02', 'SPACY:DEP-amod', 'TEXT:i', 'SPACY:POS-SYM', 'TEXT:free', 'TEXT:txt', 'TEXT:claim', 'TEXT:!', 'HYPERNYM:message.n.02', 'TEXT:mobile', 'SPACY:DEP-pobj', 'HYPERNYM:transferred_property.n.01', 'HYPERNYM:abstraction.n.06', 'TEXT:to', 'TEXT:prize', 'HYPERNYM:relation.n.01', 'HYPERNYM:win.v.01', 'SPACY:DEP-appos', 'SENTIMENT:pos', 'HYPERNYM:act.n.02', 'HYPERNYM:object.n.01', 'SPACY:NER-PERSON', 'TEXT:your', 'SPACY:POS-ADJ', 'TEXT:or', 'HYPERNYM:symbol.n.01', 'TEXT:text', 'HYPERNYM:entity.n.01', 'HYPERNYM:statement.n.01', 'TEXT:stop', 'SPACY:DEP-nmod', 'HYPERNYM:converse.v.01', 'HYPERNYM:book.n.01', 'TEXT:-', 'TEXT:150p', 'TEXT:guaranteed', 'TEXT:urgent', 'TEXT:win', 'HYPERNYM:written_communication.n.01', 'TEXT:+', 'SPACY:POS-PRON', 'TEXT:16', 'HYPERNYM:cash.n.02', 'HYPERNYM:artifact.n.01', 'HYPERNYM:creation.n.02', 'TEXT:from', 'HYPERNYM:assertion.n.01', 'TEXT:reply', 'SPACY:NER-GPE', 'TEXT:now', 'SPACY:DEP-dobj', 'HYPERNYM:award.n.02', 'TEXT:.', 'TEXT:tone', 'TEXT:18', 'HYPERNYM:acquisition.n.02', 'SPACY:POS-DET', 'HYPERNYM:measure.n.02', 'TEXT:nokia', 'TEXT:a', 'SPACY:DEP-conj', 'TEXT:our', 'HYPERNYM:mobile.n.02', 'HYPERNYM:minute.n.01', 'HYPERNYM:user.n.01', 'HYPERNYM:claim.v.03', 'TEXT:service', 'TEXT:contact', 'TEXT:for', 'TEXT:...', 'HYPERNYM:organism.n.01', 'HYPERNYM:offer.n.02', 'TEXT:awarded', 'TEXT:â£1000', 'TEXT:150ppm', 'HYPERNYM:document.n.01', 'TEXT:4', 'HYPERNYM:request.n.01', 'TEXT:per', 'HYPERNYM:call.v.28', 'HYPERNYM:television_equipment.n.01', 'SPACY:DEP-acl', 'HYPERNYM:land_line.n.01', 'TEXT:ur', 'TEXT:camera', 'HYPERNYM:phone.n.02', 'TEXT:rate', 'TEXT:my', 'HYPERNYM:plastic_art.n.01', 'TEXT:latest', 'HYPERNYM:text.n.04', 'TEXT:box', 'TEXT:draw', 'TEXT::']
# Example of patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 1
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Examples ~ Class Negative:
# [MATCH]: What i mean was i left too early to check , cos i 'm working a 9:['SPACY:POS-NUM'] - 6 .
# -------------------------
# [MATCH]: " I;m reaching in another 2:['SPACY:POS-NUM'] stops . "
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: important information 4:['SPACY:POS-NUM'] orange user 0789xxxxxxx . today is your lucky day!2find out why log onto http://www.urawinner.com THERE 'S A FANTASTIC SURPRISE AWAITING YOU !
# -------------------------
# [MATCH]: We tried to contact you re your reply to our offer of a Video Phone 750:['SPACY:POS-NUM'] anytime any network mins Half Price Line Rental Camcorder Reply or call 08000930705
# -------------------------
# ==================================================
# Pattern: [['SPACY:DEP-compound']]
# Window size: 1
# Class: Negative
# Precision: 0.680
# Match: 1379 (38.7%)
# Gain = 0.134
# Examples ~ Class Negative:
# [MATCH]: So when do you wanna gym:['SPACY:DEP-compound'] harri
# -------------------------
# [MATCH]: Desires- u going to doctor 4 liver . And get a bit stylish . Get ur:['SPACY:DEP-compound'] hair managed . That s it .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Hi 07734396839 IBH:['SPACY:DEP-compound'] Customer Loyalty Offer : The NEW NOKIA6600 Mobile from ONLY Â£10 at TXTAUCTION!Txt word : START to No:81151 & get Yours Now!4 T &
# -------------------------
# [MATCH]: < Forwarded from 21870000>Hi - this is your Mailbox:['SPACY:DEP-compound'] Messaging SMS alert . You have 40 matches . Please call back on 09056242159 to retrieve your messages and matches cc100p / min
# -------------------------
# ==================================================
# Pattern: [['SPACY:NER-ORG']]
# Window size: 1
# Class: Negative
# Precision: 0.527
# Match: 676 (19.0%)
# Gain = 0.127
# Examples ~ Class Negative:
# [MATCH]: Just hopeing that wasnâ€˜t:['SPACY:NER-ORG'] too pissed up to remember and has gone off to his sisters or something !
# -------------------------
# [MATCH]: Jolly good ! By the way ,  :['SPACY:NER-ORG'] will give u tickets for sat eve 7.30 . Speak before then x
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: YES ! The only place in town to meet exciting adult singles is now in the UK . Txt CHAT to 86688 now ! 150p:['SPACY:NER-ORG'] / Msg .
# -------------------------
# [MATCH]: Tone Club : Your subs has now expired 2 re - sub reply MONOC 4 monos or POLYC:['SPACY:NER-ORG'] 4 polys 1 weekly @ 150p per week Txt STOP 2 stop This msg free Stream 0871212025016
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN']]
# Window size: 1
# Class: Negative
# Precision: 0.690
# Match: 1347 (37.8%)
# Gain = 0.112
# Examples ~ Class Negative:
# [MATCH]: HAPPY:['SPACY:POS-PROPN'] NEW YEAR MY NO.1 MAN
# -------------------------
# [MATCH]: Can you plz tell me the ans . BSLVYL:['SPACY:POS-PROPN'] sent via fullonsms.com
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: You 've won tkts to the EURO2004:['SPACY:POS-PROPN'] CUP FINAL or Â£800 CASH , to collect CALL 09058099801 b4190604 , POBOX 7876150ppm
# -------------------------
# [MATCH]: I do n't know u and u do n't know me . Send CHAT:['SPACY:POS-PROPN'] to 86688 now and let 's find each other ! Only 150p / Msg rcvd . HG / Suite342/2Lands / Row / W1J6HL LDN . 18 years or over .
# -------------------------
# ==================================================
# Pattern: [['SPACY:NER-DATE']]
# Window size: 1
# Class: Negative
# Precision: 0.548
# Match: 651 (18.3%)
# Gain = 0.106
# Examples ~ Class Negative:
# [MATCH]: Happy birthday ... May:['SPACY:NER-DATE'] u find ur prince charming soon n dun work too hard ...
# -------------------------
# [MATCH]: Do you know what Mallika Sherawat did yesterday:['SPACY:NER-DATE'] ? Find out now @   & lt;URL&gt ;
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: U have a secret admirer who is looking 2 make contact with U - find out who they R*reveal who thinks UR so special - call on 09058094594:['SPACY:NER-DATE']
# -------------------------
# [MATCH]: Monthly:['SPACY:NER-DATE'] password for wap . mobsi.com is 391784 . Use your wap phone not PC .
# -------------------------
# ==================================================
# Step 4: Grow patterns
# 100%|██████████| 100/100 [02:18<00:00,  1.38s/it]
# Length 2 / 5; New candidates = 14950
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 1
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Examples ~ Class Negative:
# [MATCH]: Do whatever you want . You know what the rules are . We had a talk earlier this week about what had to start happening , you showing responsibility . Yet , every week it 's can i bend the rule this way ? What about that way ? Do whatever . I 'm tired of having thia same argument with you every week . And a   & lt;#&gt ;   movie DOESNT inlude the previews . You 're still getting in after 1:['SPACY:POS-NUM'] .
# -------------------------
# [MATCH]: I not free today i haf 2:['SPACY:POS-NUM'] pick my parents up tonite ...
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Had your mobile 11:['SPACY:POS-NUM'] months or more ? U R entitled to Update to the latest colour mobiles with camera for Free ! Call The Mobile Update Co FREE on 08002986030
# -------------------------
# [MATCH]: Eerie Nokia tones 4u:['SPACY:POS-NUM'] , rply TONE TITLE to 8007 eg TONE DRACULA to 8007 Titles : GHOST , ADDAMSFA , MUNSTERS , EXORCIST , TWILIGHT www.getzed.co.uk POBox36504W45WQ 150p
# -------------------------
# ==================================================
# Pattern: [['SPACY:NER-DATE', 'SPACY:POS-NUM']]
# Window size: 1
# Class: Positive
# Precision: 0.861
# Match: 280 (7.8%)
# Gain = 0.175
# Examples ~ Class Positive:
# [MATCH]: Please call our customer service representative on FREEPHONE 0808 145:['SPACY:POS-NUM', 'SPACY:NER-DATE'] 4742 between 9am-11pm as you have WON a guaranteed Â£1000 cash or Â£5000 prize !
# -------------------------
# [MATCH]: Your free ringtone is waiting to be collected . Simply text the password " MIX " to 85069:['SPACY:POS-NUM', 'SPACY:NER-DATE'] to verify . Get Usher and Britney . FML , PO Box 5249 , MK17 92H. 450Ppw 16
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Nothing lor ... A bit bored too ... Then y dun u go home early 2:['SPACY:POS-NUM', 'SPACY:NER-DATE'] sleep today ...
# -------------------------
# [MATCH]: Let me know how it changes in the next 6hrs:['SPACY:POS-NUM', 'SPACY:NER-DATE'] . It can even be appendix but you are out of that age range . However its not impossible . So just chill and let me know in 6hrs
# -------------------------
# ==================================================
# Pattern: [['SPACY:DEP-compound'], ['SPACY:POS-PROPN']]
# Window size: 2
# Class: Positive
# Precision: 0.641
# Match: 451 (12.6%)
# Gain = 0.157
# Examples ~ Class Positive:
# [MATCH]: Santa calling ! Would your little ones like a call from Santa:['SPACY:DEP-compound'] Xmas:['SPACY:POS-PROPN'] Eve ? Call 09077818151 to book you time . Calls1.50ppm last 3mins 30s T&C www.santacalling.com
# -------------------------
# [MATCH]: Goal ! Arsenal 4 ( Henry , 7 v Liverpool 2:['SPACY:DEP-compound'] Henry:['SPACY:POS-PROPN'] scores with a simple shot from 6 yards from a pass by Bergkamp to give Arsenal a 2 goal margin after 78 mins .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I AM AT A PARTY WITH ALEX:['SPACY:DEP-compound'] NICHOLS:['SPACY:POS-PROPN']
# -------------------------
# [MATCH]: FR'NDSHIP is like a needle of a clock . Though V r in d same clock , V r nt able 2 met . Evn if V meet , itz only 4few seconds . Bt:['SPACY:DEP-compound'] V:['SPACY:POS-PROPN'] alwys stay conected . Gud 9t;- )
# -------------------------
# ==================================================
# Pattern: [['SPACY:DEP-compound', 'SPACY:POS-PROPN']]
# Window size: 1
# Class: Positive
# Precision: 0.542
# Match: 583 (16.3%)
# Gain = 0.147
# Examples ~ Class Positive:
# [MATCH]: Urgent ! Please call 09061213237 from landline . Â£5000 cash or a luxury 4 * Canary:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] Islands Holiday await collection . T&Cs SAE PO Box 177 . M227XY . 150ppm . 16 +
# -------------------------
# [MATCH]: Auction round 4 . The highest bid is now Â£54 . Next maximum bid is Â£71 . To bid , send BIDS:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] e. g. 10 ( to bid Â£10 ) to 83383 . Good luck .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: 1.20 that call cost . Which i guess is nt bad . Miss:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] ya , need ya , want ya , love ya
# -------------------------
# [MATCH]: Thanks da:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] thangam , i feel very very happy dear . I also miss you da .
# -------------------------
# ==================================================
# Pattern: [['SPACY:DEP-compound']]
# Window size: 1
# Class: Negative
# Precision: 0.680
# Match: 1379 (38.7%)
# Gain = 0.134
# Examples ~ Class Negative:
# [MATCH]: No shoot me . I 'm in the docs waiting:['SPACY:DEP-compound'] room . :/
# -------------------------
# [MATCH]: Host - based IDPS for linux:['SPACY:DEP-compound'] systems .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: 449050000301 You have won a Â£2,000:['SPACY:DEP-compound'] price ! To claim , call 09050000301 .
# -------------------------
# [MATCH]: PRIVATE ! Your 2003 Account:['SPACY:DEP-compound'] Statement for 07815296484 shows 800 un - redeemed S.I.M. points . Call 08718738001 Identifier Code 41782 Expires 18/11/04
# -------------------------
# ==================================================
# 100%|██████████| 73/73 [01:41<00:00,  1.39s/it]
# Length 3 / 5; New candidates = 14337
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 1
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Examples ~ Class Negative:
# [MATCH]: I luv u soo much u donÂ’t understand how special u r 2:['SPACY:POS-NUM'] me ring u 2morrow luv u xxx
# -------------------------
# [MATCH]: Derp . Which is worse , a dude who always wants to party or a dude who files a complaint about the three:['SPACY:POS-NUM'] drug abusers he lives with
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: You have been selected to stay in 1:['SPACY:POS-NUM'] of 250 top British hotels - FOR NOTHING ! Holiday Worth Â£350 ! To Claim , Call London 02072069400 . Bx 526 , SW73SS
# -------------------------
# [MATCH]: Final Chance ! Claim ur Â£150 worth of discount vouchers today ! Text YES to 85023:['SPACY:POS-NUM'] now ! SavaMob , member offers mobile ! T Cs SavaMob POBOX84 , M263UZ . Â£3.00 Subs 16
# -------------------------
# ==================================================
# Pattern: [['SPACY:NER-DATE', 'SPACY:POS-NUM']]
# Window size: 1
# Class: Positive
# Precision: 0.861
# Match: 280 (7.8%)
# Gain = 0.175
# Examples ~ Class Positive:
# [MATCH]: Dear Dave this is your final notice to collect your 4 * Tenerife Holiday or # 5000 CASH award ! Call 09061743806:['SPACY:POS-NUM', 'SPACY:NER-DATE'] from landline . TCs SAE Box326 CW25WX 150ppm
# -------------------------
# [MATCH]: Today 's Offer ! Claim ur Â£150 worth of discount vouchers ! Text YES to 85023 now ! SavaMob , member offers mobile ! T Cs 08717898035:['SPACY:POS-NUM', 'SPACY:NER-DATE'] . Â£3.00 Sub . 16 . Unsub reply X
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: This is ur face test ( 1:['SPACY:POS-NUM', 'SPACY:NER-DATE'] 2 3 4 5 6 7 8 9   & lt;#&gt ;   ) select any number i will tell ur face astrology .... am waiting . quick reply ...
# -------------------------
# [MATCH]: From someone not to smoke when every time I 've smoked in the last two:['SPACY:POS-NUM', 'SPACY:NER-DATE'] weeks is because of you calling or texting me that you wanted to smoke
# -------------------------
# ==================================================
# Pattern: [['SPACY:DEP-compound'], ['SPACY:POS-PROPN']]
# Window size: 2
# Class: Positive
# Precision: 0.641
# Match: 451 (12.6%)
# Gain = 0.157
# Examples ~ Class Positive:
# [MATCH]: Thanks for your ringtone order , reference number:['SPACY:DEP-compound'] X29:['SPACY:POS-PROPN'] . Your mobile will be charged 4.50 . Should your tone not arrive please call customer services 09065989180
# -------------------------
# [MATCH]: URGENT ! We are trying to contact you . Last weekends draw shows that you have won a Â£900 prize:['SPACY:DEP-compound'] GUARANTEED:['SPACY:POS-PROPN'] . Call 09061701851 . Claim code K61 . Valid 12hours only
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: " CHEERS FOR CALLIN BABE.SOZI CULDNT TALKBUT I WANNATELL U DETAILS LATER WENWECAN:['SPACY:DEP-compound'] CHAT:['SPACY:POS-PROPN'] PROPERLY X "
# -------------------------
# [MATCH]: Smile in Pleasure Smile in Pain Smile when trouble pours like Rain Smile when sum1:['SPACY:DEP-compound'] Hurts:['SPACY:POS-PROPN'] U Smile becoz SOMEONE still Loves to see u Smiling ! !
# -------------------------
# ==================================================
# Pattern: [['SPACY:DEP-compound', 'SPACY:POS-PROPN']]
# Window size: 1
# Class: Positive
# Precision: 0.542
# Match: 583 (16.3%)
# Gain = 0.147
# Examples ~ Class Positive:
# [MATCH]: IMPORTANT INFORMATION 4 ORANGE:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] USER 0796XXXXXX . TODAY IS UR LUCKY DAY!2 FIND OUT WHY LOG ONTO http://www.urawinner.com THERE 'S A FANTASTIC PRIZEAWAITING YOU !
# -------------------------
# [MATCH]: Join the UK 's horniest Dogging service and u can have sex 2nite!. Just sign up and follow the instructions . Txt:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] ENTRY to 69888 now ! Nyt . EC2A.3LP.msg@150p
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Y so late but i need to go n get da:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] laptop ...
# -------------------------
# [MATCH]: " CHEERS U:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] TEX MECAUSE U WEREBORED ! YEAH OKDEN HUNNY R UIN WK SAT?SOUNDÂ ’S LIKEYOUR HAVIN GR8FUN J ! KEEP UPDAT COUNTINLOTS OF LOVEME XXXXX . "
# -------------------------
# ==================================================
# Pattern: [['SPACY:DEP-compound']]
# Window size: 1
# Class: Negative
# Precision: 0.680
# Match: 1379 (38.7%)
# Gain = 0.134
# Examples ~ Class Negative:
# [MATCH]: Yo:['SPACY:DEP-compound'] sorry was in the shower sup
# -------------------------
# [MATCH]: Shhhhh:['SPACY:DEP-compound'] nobody is supposed to know !
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Mila , age23 , blonde , new in UK . I look sex with UK:['SPACY:DEP-compound'] guys . if u like fun with me . Text MTALK to 69866.18 . 30pp / txt 1st 5free . Â£1.50 increments . Help08718728876
# -------------------------
# [MATCH]: To review and KEEP the fantastic Nokia:['SPACY:DEP-compound'] N - Gage game deck with Club Nokia , go 2 www.cnupdates.com/newsletter . unsubscribe from alerts reply with the word OUT
# -------------------------
# ==================================================
# 100%|██████████| 22/22 [00:26<00:00,  1.20s/it]
# Length 4 / 5; New candidates = 4357
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
# 0it [00:00, ?it/s]
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 1
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Examples ~ Class Negative:
# [MATCH]: is your hamster dead ? Hey so tmr i meet you at 1:['SPACY:POS-NUM'] pm orchard mrt ?
# -------------------------
# [MATCH]: I thk 50:['SPACY:POS-NUM'] shd be ok he said plus minus 10 .. Did Ã¼ leave a line in between paragraphs ?
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Not heard from U4 a while . Call 4:['SPACY:POS-NUM'] rude chat private line 01223585334 to cum . Wan 2C pics of me gettin shagged then text PIX to 8552 . 2End send STOP 8552 SAM xxx
# -------------------------
# [MATCH]: 449050000301:['SPACY:POS-NUM'] You have won a Â£2,000 price ! To claim , call 09050000301 .
# -------------------------
# ==================================================
# Pattern: [['SPACY:NER-DATE', 'SPACY:POS-NUM']]
# Window size: 1
# Class: Positive
# Precision: 0.861
# Match: 280 (7.8%)
# Gain = 0.175
# Examples ~ Class Positive:
# [MATCH]: Here is your discount code RP176781 . To stop further messages reply stop . www.regalportfolio.co.uk . Customer Services 08717205546:['SPACY:POS-NUM', 'SPACY:NER-DATE']
# -------------------------
# [MATCH]: URGENT ! Your Mobile No 07808726822:['SPACY:POS-NUM', 'SPACY:NER-DATE'] was awarded a Â£2,000 Bonus Caller Prize on 02/09/03 ! This is our 2nd attempt to contact YOU ! Call 0871 - 872 - 9758 BOX95QU
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: U studying in sch or going home ? Anyway i 'll b going 2:['SPACY:POS-NUM', 'SPACY:NER-DATE'] sch later .
# -------------------------
# [MATCH]: Hey next sun 1030:['SPACY:POS-NUM', 'SPACY:NER-DATE'] there 's a basic yoga course ... at bugis ... We can go for that ... Pilates intro next sat .... Tell me what time you r free
# -------------------------
# ==================================================
# Pattern: [['SPACY:DEP-compound'], ['SPACY:POS-PROPN']]
# Window size: 2
# Class: Positive
# Precision: 0.641
# Match: 451 (12.6%)
# Gain = 0.157
# Examples ~ Class Positive:
# [MATCH]: Bears:['SPACY:DEP-compound'] Pic:['SPACY:POS-PROPN'] Nick , and Tom , Pete and ... Dick . In fact , all types try gay chat with photo upload call 08718730666 ( 10p / min ) . 2 stop texts call 08712460324
# -------------------------
# [MATCH]: Your free ringtone is waiting to be collected . Simply text the password " MIX " to 85069 to verify . Get Usher and Britney . FML , PO:['SPACY:DEP-compound'] Box:['SPACY:POS-PROPN'] 5249 , MK17 92H. 450Ppw 16
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Ãœ:['SPACY:DEP-compound'] neva:['SPACY:POS-PROPN'] tell me how i noe ... I 'm not at home in da aft wat ...
# -------------------------
# [MATCH]: Evry:['SPACY:DEP-compound'] Emotion:['SPACY:POS-PROPN'] dsn't hav Words . Evry Wish dsn't hav Prayrs .. If u Smile , D World is wit u . Othrwise even d Drop of Tear dsn't lik 2 Stay wit u . So b happy .. Good morning , keep smiling:- )
# -------------------------
# ==================================================
# Pattern: [['SPACY:DEP-compound', 'SPACY:POS-PROPN']]
# Window size: 1
# Class: Positive
# Precision: 0.542
# Match: 583 (16.3%)
# Gain = 0.147
# Examples ~ Class Positive:
# [MATCH]: Free video camera phones with Half:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] Price line rental for 12 mths and 500 cross ntwk mins 100 txts . Call MobileUpd8 08001950382 or Call2OptOut/674
# -------------------------
# [MATCH]: FREE GAME . Get Rayman:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] Golf 4 FREE from the O2 Games Arcade . 1st get UR games settings . Reply POST , then save & activ8 . Press 0 key for Arcade . Termsapply
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: HI:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] DARLIN I FINISH AT 3 DO U 1 2 PICK ME UP OR MEET ME ? TEXT BACK ON THIS NUMBER LUV KATE XXX
# -------------------------
# [MATCH]: Esplanade:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] lor . Where else ...
# -------------------------
# ==================================================
# Pattern: [['SPACY:DEP-compound']]
# Window size: 1
# Class: Negative
# Precision: 0.680
# Match: 1379 (38.7%)
# Gain = 0.134
# Examples ~ Class Negative:
# [MATCH]: Purity of friendship between two is not about smiling after reading the forwarded message .. Its about smiling just by seeing the name . Gud:['SPACY:DEP-compound'] evng musthu
# -------------------------
# [MATCH]: I AM AT A PARTY WITH ALEX:['SPACY:DEP-compound'] NICHOLS
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Had your mobile 10 mths ? Update to latest Orange:['SPACY:DEP-compound'] camera / video phones for FREE . Save Â£s with Free texts / weekend calls . Text YES for a callback orno to opt out
# -------------------------
# [MATCH]: Ur ringtone:['SPACY:DEP-compound'] service has changed ! 25 Free credits ! Go to club4mobiles.com to choose content now ! Stop ? txt CLUB STOP to 87070 . 150p / wk Club4 PO Box1146 MK45 2WT
# -------------------------
# ==================================================
# Length 5 / 5; New candidates = 0

# %%
# Print the patterns
for idx, p in enumerate(the_patterns):
    print(f'Rank {idx}')
    print(p)
# Out:
# Rank 0
# Pattern: [['SPACY:POS-NUM']]
# Window size: 1
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Examples ~ Class Negative:
# [MATCH]: One:['SPACY:POS-NUM'] of best dialogue in cute reltnship .. ! ! " Wen i Die , Do nt Come Near My Body .. ! ! Bcoz My Hands May Not Come 2 Wipe Ur Tears Off That Time .. !Gud ni8
# -------------------------
# [MATCH]: Hi i m having the most relaxing time ever ! we have to get up at 7:['SPACY:POS-NUM'] am every day ! was the party good the other night ? I get home tomorrow at 5ish .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: 83039:['SPACY:POS-NUM'] 62735=Â£450 UK Break AccommodationVouchers terms & conditions apply . 2 claim you mustprovide your claim number which is 15541
# -------------------------
# [MATCH]: WINNER ! As a valued network customer you hvae been selected to receive a Â£900 reward ! To collect call 09061701444:['SPACY:POS-NUM'] . Valid 24 hours only . ACL03530150PM
# -------------------------
# ==================================================
# Rank 1
# Pattern: [['SPACY:NER-DATE', 'SPACY:POS-NUM']]
# Window size: 1
# Class: Positive
# Precision: 0.861
# Match: 280 (7.8%)
# Gain = 0.175
# Examples ~ Class Positive:
# [MATCH]: Panasonic & BluetoothHdset FREE . Nokia FREE . Motorola FREE & DoubleMins & DoubleTxt on Orange contract . Call MobileUpd8 on 08000839402:['SPACY:POS-NUM', 'SPACY:NER-DATE'] or call 2optout
# -------------------------
# [MATCH]: Uâ€ ™ ve Bin Awarded Â£50 to Play 4 Instant Cash . Call 08715203028 To Claim . EVERY 9th Player Wins Min Â£50-Â£500 . OptOut 08718727870:['SPACY:POS-NUM', 'SPACY:NER-DATE']
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Not planned yet : ) going to join company on jan 5:['SPACY:POS-NUM', 'SPACY:NER-DATE'] only.don know what will happen after that .
# -------------------------
# [MATCH]: From someone not to smoke when every time I 've smoked in the last two:['SPACY:POS-NUM', 'SPACY:NER-DATE'] weeks is because of you calling or texting me that you wanted to smoke
# -------------------------
# ==================================================
# Rank 2
# Pattern: [['SPACY:DEP-compound'], ['SPACY:POS-PROPN']]
# Window size: 2
# Class: Positive
# Precision: 0.641
# Match: 451 (12.6%)
# Gain = 0.157
# Examples ~ Class Positive:
# [MATCH]: GENT ! We are trying to contact you . Last weekends draw shows that you won a Â£1000 prize:['SPACY:DEP-compound'] GUARANTEED:['SPACY:POS-PROPN'] . Call 09064012160 . Claim Code K52 . Valid 12hrs only . 150ppm
# -------------------------
# [MATCH]: Sunshine:['SPACY:DEP-compound'] Quiz:['SPACY:POS-PROPN'] Wkly Q ! Win a top Sony DVD player if u know which country the Algarve is in ? Txt ansr to 82277 . Â£1.50 SP : Tyrone
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Brainless:['SPACY:DEP-compound'] Baby:['SPACY:POS-PROPN'] Doll .. :-D;- ) , vehicle sariyag drive madoke barolla ..
# -------------------------
# [MATCH]: TODAY is Sorry day . ! If ever i was angry with you , if ever i misbehaved or hurt you ? plz plz JUST SLAP:['SPACY:DEP-compound'] URSELF:['SPACY:POS-PROPN'] Bcoz , Its ur fault , I 'm basically GOOD
# -------------------------
# ==================================================
# Rank 3
# Pattern: [['SPACY:DEP-compound', 'SPACY:POS-PROPN']]
# Window size: 1
# Class: Positive
# Precision: 0.542
# Match: 583 (16.3%)
# Gain = 0.147
# Examples ~ Class Positive:
# [MATCH]: Had your contract mobile 11 Mnths ? Latest Motorola , Nokia etc . all FREE ! Double Mins & Text on Orange:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] tariffs . TEXT YES for callback , no to remove from records .
# -------------------------
# [MATCH]: Double Mins & Double Txt & 1/2 price Linerental on Latest:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] Orange Bluetooth mobiles . Call MobileUpd8 for the very latest offers . 08000839402 or call2optout / LF56
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Nokia:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] phone is lovly ..
# -------------------------
# [MATCH]: PLEASSSSSSSEEEEEE:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] TEL ME V AVENT DONE SPORTSx
# -------------------------
# ==================================================
# Rank 4
# Pattern: [['SPACY:DEP-compound']]
# Window size: 1
# Class: Negative
# Precision: 0.680
# Match: 1379 (38.7%)
# Gain = 0.134
# Examples ~ Class Negative:
# [MATCH]: I sent my scores to sophas and i had to do secondary application for a few schools . I think if you are thinking of applying , do a research on cost also . Contact:['SPACY:DEP-compound'] joke ogunrinde , her school is one me the less expensive ones
# -------------------------
# [MATCH]: Does cinema plus drink appeal tomo ? * Is a fr:['SPACY:DEP-compound'] thriller by director i like on at mac at 8.30 .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Wanna have a laugh ? Try CHIT:['SPACY:DEP-compound'] - CHAT on your mobile now ! Logon by txting the word : CHAT and send it to No : 8883 CM PO Box 4217 London W1A 6ZF 16 + 118p / msg rcvd
# -------------------------
# [MATCH]: I want some cock ! My hubby 's away , I need a real man 2 satisfy me . Txt:['SPACY:DEP-compound'] WIFE to 89938 for no strings action . ( Txt STOP 2 end , txt rec Â£1.50ea . OTBox 731 LA1 7WS . )
# -------------------------
# ==================================================
# Rank 5
# Pattern: [['SPACY:DEP-compound'], ['HYPERNYM:abstraction.n.06']]
# Window size: 2
# Class: Negative
# Precision: 0.559
# Match: 777 (21.8%)
# Gain = 0.130
# Examples ~ Class Negative:
# [MATCH]: Sorry vikky , i 'm Watching olave:['SPACY:DEP-compound'] mandara:['HYPERNYM:abstraction.n.06'] movie kano in trishul theatre wit my frnds ..
# -------------------------
# [MATCH]: Where are you ? What do you do ? How can you stand to be away from me ? Does n't your heart:['SPACY:DEP-compound'] ache:['HYPERNYM:abstraction.n.06'] without me ? Do n't you wonder of me ? Do n't you crave me ?
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Urgent ! call 09066612661 from landline . Your complementary 4 * Tenerife:['SPACY:DEP-compound'] Holiday:['HYPERNYM:abstraction.n.06'] or Â£10,000 cash await collection SAE T&Cs PO Box 3 WA14 2PX 150ppm 18 + Sender : Hol Offer
# -------------------------
# [MATCH]: Sunshine Hols . To claim ur med holiday send a stamped self:['SPACY:DEP-compound'] address:['HYPERNYM:abstraction.n.06'] envelope to Drinks on Us UK , PO Box 113 , Bray , Wicklow , Eire . Quiz Starts Saturday ! Unsub Stop
# -------------------------
# ==================================================
# Rank 6
# Pattern: [['SPACY:NER-ORG']]
# Window size: 1
# Class: Negative
# Precision: 0.527
# Match: 676 (19.0%)
# Gain = 0.127
# Examples ~ Class Negative:
# [MATCH]: ZOE IT JUST HIT ME 2 IM FUCKING SHITIN MYSELF IL DEFO TRY MY HARDEST 2 CUM:['SPACY:NER-ORG'] 2MOROW LUV U MILLIONS LEKDOG
# -------------------------
# [MATCH]: Plz note : if anyone calling from a mobile Co.:['SPACY:NER-ORG'] & amp ; asks u to type # & lt;#&gt ;   or # & lt;#&gt ; . Do not do so . Disconnect the call , coz it iz an attempt of ' terrorist ' to make use of the sim card no . Itz confirmd by nokia n motorola n has been verified by CNN IBN .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: For your chance to WIN a FREE Bluetooth Headset then simply reply back with " ADP:['SPACY:NER-ORG'] "
# -------------------------
# [MATCH]: Thank you , winner notified by sms . Good Luck ! No future marketing reply STOP:['SPACY:NER-ORG'] to 84122 customer services 08450542832
# -------------------------
# ==================================================
# Rank 7
# Pattern: [['HYPERNYM:abstraction.n.06'], ['SPACY:POS-PROPN']]
# Window size: 2
# Class: Positive
# Precision: 0.708
# Match: 305 (8.6%)
# Gain = 0.123
# Examples ~ Class Positive:
# [MATCH]: < Forwarded from 21870000>Hi - this is your Mailbox Messaging:['HYPERNYM:abstraction.n.06'] SMS:['SPACY:POS-PROPN'] alert . You have 40 matches . Please call back on 09056242159 to retrieve your messages and matches cc100p / min
# -------------------------
# [MATCH]: SMS . ac JSco : Energy is high , but u may not know where 2channel it . 2day ur leadership skills r strong . Psychic ? Reply:['HYPERNYM:abstraction.n.06'] ANS:['SPACY:POS-PROPN'] w / question . End ? Reply END JSCO
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Thanks:['HYPERNYM:abstraction.n.06'] da:['SPACY:POS-PROPN'] thangam , i feel very very happy dear . I also miss you da .
# -------------------------
# [MATCH]: I ( Career:['HYPERNYM:abstraction.n.06'] Tel:['SPACY:POS-PROPN'] ) have added u as a contact on INDYAROCKS.COM to send FREE SMS . To remove from phonebook - sms NO to   & lt;#&gt ;
# -------------------------
# ==================================================
# Rank 8
# Pattern: [['SPACY:DEP-compound', 'SPACY:POS-PROPN'], ['HYPERNYM:abstraction.n.06']]
# Window size: 2
# Class: Positive
# Precision: 0.694
# Match: 310 (8.7%)
# Gain = 0.119
# Examples ~ Class Positive:
# [MATCH]: URGENT ! We are trying to contact U:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] Todays:['HYPERNYM:abstraction.n.06'] draw shows that you have won a Â£800 prize GUARANTEED . Call 09050000460 from land line . Claim J89 . po box245c2150pm
# -------------------------
# [MATCH]: URGENT ! We are trying to contact you . Last weekends draw shows that you have won a Â£900:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] prize:['HYPERNYM:abstraction.n.06'] GUARANTEED . Call 09061701939 . Claim code S89 . Valid 12hrs only
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Wylie:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] update:['HYPERNYM:abstraction.n.06'] : my weed dealer carlos went to freedom and had a class with lunsford
# -------------------------
# [MATCH]: " AH:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] POOR:['HYPERNYM:abstraction.n.06'] BABY!HOPE URFEELING BETTERSN LUV ! PROBTHAT OVERDOSE OF WORK HEY GO CAREFUL SPK 2 U SN LOTS OF LOVEJEN XXX . "
# -------------------------
# ==================================================
# Rank 9
# Pattern: [['HYPERNYM:abstraction.n.06', 'SPACY:POS-PROPN']]
# Window size: 1
# Class: Positive
# Precision: 0.508
# Match: 555 (15.6%)
# Gain = 0.116
# Examples ~ Class Positive:
# [MATCH]: PRIVATE ! Your 2003 Account:['SPACY:POS-PROPN', 'HYPERNYM:abstraction.n.06'] Statement for 07753741225 shows 800 un - redeemed S. I. M. points . Call 08715203677 Identifier Code : 42478 Expires 24/10/04
# -------------------------
# [MATCH]: URGENT ! Your Mobile No was awarded a Â£2,000 Bonus:['SPACY:POS-PROPN', 'HYPERNYM:abstraction.n.06'] Caller Prize on 1/08/03 ! This is our 2nd attempt to contact YOU ! Call 0871 - 4719 - 523 BOX95QU BT National Rate
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: So there 's a ring that comes with the guys costumes . It 's there so they can gift their future yowifes . Hint:['SPACY:POS-PROPN', 'HYPERNYM:abstraction.n.06'] hint
# -------------------------
# [MATCH]: Evry Emotion:['SPACY:POS-PROPN', 'HYPERNYM:abstraction.n.06'] dsn't hav Words . Evry Wish dsn't hav Prayrs .. If u Smile , D World is wit u . Othrwise even d Drop of Tear dsn't lik 2 Stay wit u . So b happy .. Good morning , keep smiling:- )
# -------------------------
# ==================================================
# Rank 10
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 2
# Class: Positive
# Precision: 1.000
# Match: 135 (3.8%)
# Gain = 0.116
# Examples ~ Class Positive:
# [MATCH]: You are a winner you have been specially selected to receive Â£1000 cash or a Â£2000 award . Speak to a live operator to claim call:['TEXT:call'] 087123002209am-7pm:['SPACY:POS-NUM'] . Cost 10p
# -------------------------
# [MATCH]: Please CALL:['TEXT:call'] 08712402902:['SPACY:POS-NUM'] immediately as there is an urgent message waiting for you .
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Rank 11
# Pattern: [['SPACY:POS-PROPN']]
# Window size: 1
# Class: Negative
# Precision: 0.690
# Match: 1347 (37.8%)
# Gain = 0.112
# Examples ~ Class Negative:
# [MATCH]: Wat:['SPACY:POS-PROPN'] makes u thk i 'll fall down . But actually i thk i 'm quite prone 2 falls . Lucky my dad at home i ask him come n fetch me already .
# -------------------------
# [MATCH]: Nope but i 'll b going 2 sch on fri quite early lor cos mys sis got paper in da:['SPACY:POS-PROPN'] morn :-)
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: You are awarded a SiPix:['SPACY:POS-PROPN'] Digital Camera ! call 09061221061 from landline . Delivery within 28days . T Cs Box177 . M221BP . 2yr warranty . 150ppm . 16 . p pÂ£3.99
# -------------------------
# [MATCH]: Urgent ! Please call 09061743810 from landline . Your ABTA:['SPACY:POS-PROPN'] complimentary 4 * Tenerife Holiday or # 5000 cash await collection SAE T&Cs Box 326 CW25WX 150 ppm
# -------------------------
# ==================================================
# Rank 12
# Pattern: [['SPACY:DEP-pobj', 'SPACY:POS-NUM']]
# Window size: 1
# Class: Positive
# Precision: 0.743
# Match: 253 (7.1%)
# Gain = 0.110
# Examples ~ Class Positive:
# [MATCH]: Your free ringtone is waiting to be collected . Simply text the password " MIX " to 85069:['SPACY:POS-NUM', 'SPACY:DEP-pobj'] to verify . Get Usher and Britney . FML , PO Box 5249 , MK17 92H. 450Ppw 16
# -------------------------
# [MATCH]: FROM 88066:['SPACY:POS-NUM', 'SPACY:DEP-pobj'] LOST Â£12 HELP
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Your opinion about me ? 1 . Over 2:['SPACY:POS-NUM', 'SPACY:DEP-pobj'] . Jada 3 . Kusruthi 4 . Lovable 5 . Silent 6 . Spl character 7 . Not matured 8 . Stylish 9 . Simple Pls reply ..
# -------------------------
# [MATCH]: Glad it went well :) come over at 11:['SPACY:POS-NUM', 'SPACY:DEP-pobj'] then we 'll have plenty of time before claire goes to work .
# -------------------------
# ==================================================
# Rank 13
# Pattern: [['SPACY:NER-DATE']]
# Window size: 1
# Class: Negative
# Precision: 0.548
# Match: 651 (18.3%)
# Gain = 0.106
# Examples ~ Class Negative:
# [MATCH]: Lol yep did that yesterday:['SPACY:NER-DATE'] . Already got my fireplace . Now its just another icon sitting there for me .
# -------------------------
# [MATCH]: Sad story of a:['SPACY:NER-DATE'] Man - Last week was my b'day . My Wife did'nt wish me . My Parents forgot n so did my Kids . I went to work . Even my Colleagues did not wish . As I entered my cabin my PA said , '' Happy B'day Boss ! ! '' . I felt special . She askd me 4 lunch . After lunch she invited me to her apartment . We went there . She said , '' do u mind if I go into the bedroom for a minute ? '' ' ' OK '' , I sed in a sexy mood . She came out 5 minuts latr wid a cake ... n My Wife , My Parents , My Kidz , My Friends n My Colleagues . All screaming .. SURPRISE ! ! and I was waiting on the sofa .. ... ..... ' NAKED ... !
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: U 447801259231:['SPACY:NER-DATE'] have a secret admirer who is looking 2 make contact with U - find out who they R*reveal who thinks UR so special - call on 09058094597
# -------------------------
# [MATCH]: Thanks for your Ringtone Order , Reference T91 . You will be charged GBP 4:['SPACY:NER-DATE'] per week . You can unsubscribe at anytime by calling customer services on 09057039994
# -------------------------
# ==================================================
# Rank 14
# Pattern: [['SPACY:DEP-compound'], ['SPACY:DEP-compound']]
# Window size: 2
# Class: Positive
# Precision: 0.562
# Match: 420 (11.8%)
# Gain = 0.104
# Examples ~ Class Positive:
# [MATCH]: Not heard from U4 a while . Call 4 rude chat private line 01223585334 to cum . Wan:['SPACY:DEP-compound'] 2C:['SPACY:DEP-compound'] pics of me gettin shagged then text PIX to 8552 . 2End send STOP 8552 SAM xxx
# -------------------------
# [MATCH]: Congrats 2 mobile 3 G:['SPACY:DEP-compound'] Videophones:['SPACY:DEP-compound'] R yours . call 09063458130 now ! videochat wid ur mates , play java games , Dload polypH music , noline rentl . bx420 . ip4 . 5we . 150p
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Kate:['SPACY:DEP-compound'] jackson:['SPACY:DEP-compound'] rec center before 7ish , right ?
# -------------------------
# [MATCH]: Thank You for calling . Forgot to say Happy Onam to you Sirji . I am fine here and remembered you when i met an insurance person . Meet You in Qatar:['SPACY:DEP-compound'] Insha:['SPACY:DEP-compound'] Allah . Rakhesh , ex Tata AIG who joined TISSCO , Tayseer .
# -------------------------
# ==================================================
# Rank 15
# Pattern: [['TEXT:call']]
# Window size: 1
# Class: Positive
# Precision: 0.618
# Match: 348 (9.8%)
# Gain = 0.104
# Examples ~ Class Positive:
# [MATCH]: Bears Pic Nick , and Tom , Pete and ... Dick . In fact , all types try gay chat with photo upload call:['TEXT:call'] 08718730666 ( 10p / min ) . 2 stop texts call 08712460324
# -------------------------
# [MATCH]: Hack Chat . Get backdoor entry into 121 chat rooms at a fraction of the cost . Reply NEO69 or call:['TEXT:call'] 09050280520 , to subscribe 25p pm . DPS , Bcm box 8027 Ldn , wc1n3xx
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Even if he my friend he is a priest call:['TEXT:call'] him now
# -------------------------
# [MATCH]: Call:['TEXT:call'] me when u finish then i come n pick u.
# -------------------------
# ==================================================
# Rank 16
# Pattern: [['TEXT:to'], ['SPACY:POS-NUM']]
# Window size: 2
# Class: Positive
# Precision: 0.931
# Match: 144 (4.0%)
# Gain = 0.101
# Examples ~ Class Positive:
# [MATCH]: You have won a Nokia 7250i . This is what you get when you win our FREE auction . To take part send Nokia to:['TEXT:to'] 86021:['SPACY:POS-NUM'] now . HG / Suite342/2Lands Row / W1JHL 16 +
# -------------------------
# [MATCH]: Urgent UR awarded a complimentary trip to EuroDisinc Trav , Aco&Entry41 Or Â£1000 . To claim txt DIS to:['TEXT:to'] 87121:['SPACY:POS-NUM'] 18 + 6*Â£1.50(moreFrmMob . ShrAcomOrSglSuplt)10 , LS1 3AJ
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Ugh . Got ta drive back to:['TEXT:to'] sd:['SPACY:POS-NUM'] from la . My butt is sore .
# -------------------------
# [MATCH]: Aight , I should be there by 8 at the latest , probably closer to:['TEXT:to'] 7:['SPACY:POS-NUM'] . Are jay and tyler down or should we just do two trips ?
# -------------------------
# ==================================================
# Rank 17
# Pattern: [['HYPERNYM:abstraction.n.06', 'SPACY:DEP-compound']]
# Window size: 1
# Class: Negative
# Precision: 0.563
# Match: 668 (18.7%)
# Gain = 0.101
# Examples ~ Class Negative:
# [MATCH]: Goodnight , sleep well da please take care:['SPACY:DEP-compound', 'HYPERNYM:abstraction.n.06'] pa . Please .
# -------------------------
# [MATCH]: My darling sister . How are you doing . When 's school resuming . Is there a minimum wait:['SPACY:DEP-compound', 'HYPERNYM:abstraction.n.06'] period before you reapply ? Do take care
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Double Mins & Double Txt & 1/2 price:['SPACY:DEP-compound', 'HYPERNYM:abstraction.n.06'] Linerental on Latest Orange Bluetooth mobiles . Call MobileUpd8 for the very latest offers . 08000839402 or call2optout / LF56
# -------------------------
# [MATCH]: URGENT ! Your mobile number * * * * * * * * * * * * * * * WON a Â£2000 Bonus:['SPACY:DEP-compound', 'HYPERNYM:abstraction.n.06'] Caller prize on 10/06/03 ! This is the 2nd attempt to reach you ! Call 09066368753 ASAP ! Box 97N7QP , 150ppm
# -------------------------
# ==================================================
# Rank 18
# Pattern: [['HYPERNYM:entity.n.01'], ['SPACY:POS-NUM']]
# Window size: 2
# Class: Positive
# Precision: 0.710
# Match: 255 (7.1%)
# Gain = 0.100
# Examples ~ Class Positive:
# [MATCH]: FreeMsg : Txt : CALL to No : 86888 & claim your reward of 3 hours talk time to use from your phone now ! Subscribe6GBP / mnth inc:['HYPERNYM:entity.n.01'] 3hrs:['SPACY:POS-NUM'] 16 stop?txtStop
# -------------------------
# [MATCH]: Congratulations ur awarded either Â£500 of CD gift vouchers & Free entry:['HYPERNYM:entity.n.01'] 2:['SPACY:POS-NUM'] our Â£100 weekly draw txt MUSIC to 87066 TnCs www . Ldew.com1win150ppmx3age16
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Ok i found dis pierre cardin one which looks normal costs:['HYPERNYM:entity.n.01'] 20:['SPACY:POS-NUM'] its on sale .
# -------------------------
# [MATCH]: Hi mate its RV did u hav a nice hol just a message:['HYPERNYM:entity.n.01'] 3:['SPACY:POS-NUM'] say hello coz havenÂ’t sent u 1 in ages started driving so stay off roads!RVx
# -------------------------
# ==================================================
# Rank 19
# Pattern: [['SPACY:DEP-compound'], ['SPACY:NER-ORG']]
# Window size: 2
# Class: Positive
# Precision: 0.769
# Match: 216 (6.1%)
# Gain = 0.100
# Examples ~ Class Positive:
# [MATCH]: This is the 2nd time we have tried to contact u.:['SPACY:DEP-compound'] U:['SPACY:NER-ORG'] have won the Â£400 prize . 2 claim is easy , just call 087104711148 NOW ! Only 10p per minute . BT - national - rate
# -------------------------
# [MATCH]: URGENT ! We are trying to contact you . Last weekends draw shows that you have won a Â£900 prize:['SPACY:DEP-compound'] GUARANTEED:['SPACY:NER-ORG'] . Call 09061701939 . Claim code S89 . Valid 12hrs only
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Indians r poor but India is not a poor country . Says one of the swiss bank directors . He says that " & lt;#&gt ;   lac crore " of Indian money is deposited in swiss banks which can be used for ' taxless ' budget for   & lt;#&gt ;   yrs . Can give   & lt;#&gt ;   crore jobs to all Indians . From any village to Delhi 4 lane roads . Forever free power suply to more than   & lt;#&gt ;   social projects . Every citizen can get monthly   & lt;#&gt ; /- for   & lt;#&gt ;   yrs . No need of World:['SPACY:DEP-compound'] Bank:['SPACY:NER-ORG'] & amp ; IMF loan . Think how our money is blocked by rich politicians . We have full rights against corrupt politicians . Itna forward karo ki pura INDIA padhe.g.m . "
# -------------------------
# [MATCH]: WHAT TIME:['SPACY:DEP-compound'] U:['SPACY:NER-ORG'] WRKIN ?
# -------------------------
# ==================================================
# Rank 20
# Pattern: [['HYPERNYM:abstraction.n.06', 'SPACY:DEP-compound', 'SPACY:POS-PROPN']]
# Window size: 1
# Class: Positive
# Precision: 0.698
# Match: 255 (7.1%)
# Gain = 0.096
# Examples ~ Class Positive:
# [MATCH]: Do you want a new Video handset ? 750 any time any network mins ? UNLIMITED TEXT ? Camcorder ? Reply or Call now 08000930705 for del Sat:['SPACY:POS-PROPN', 'HYPERNYM:abstraction.n.06', 'SPACY:DEP-compound'] AM
# -------------------------
# [MATCH]: -PLS STOP bootydelious ( 32/F ) is inviting you to be her friend . Reply:['SPACY:POS-PROPN', 'HYPERNYM:abstraction.n.06', 'SPACY:DEP-compound'] YES-434 or NO-434 See her : www . SMS.ac / u / bootydelious STOP ? Send STOP FRND to 62468
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Smile in Pleasure:['SPACY:POS-PROPN', 'HYPERNYM:abstraction.n.06', 'SPACY:DEP-compound'] Smile in Pain Smile when trouble pours like Rain Smile when sum1 Hurts U Smile becoz SOMEONE still Loves to see u Smiling ! !
# -------------------------
# [MATCH]: WE REGRET TO INFORM U THAT THE NHS HAS MADE A MISTAKE.U WERE NEVER ACTUALLY BORN.PLEASE REPORT 2 YOR LOCAL HOSPITAL:['SPACY:POS-PROPN', 'HYPERNYM:abstraction.n.06', 'SPACY:DEP-compound'] 2B TERMINATED.WE R SORRY 4 THE INCONVENIENCE
# -------------------------
# ==================================================
# Rank 21
# Pattern: [['SPACY:DEP-pobj', 'SPACY:NER-DATE', 'SPACY:POS-NUM']]
# Window size: 1
# Class: Positive
# Precision: 0.975
# Match: 121 (3.4%)
# Gain = 0.095
# Examples ~ Class Positive:
# [MATCH]: 87077 : Kick off a new season with 2wks FREE goals & news to ur mobile ! Txt ur club name to 87077:['SPACY:POS-NUM', 'SPACY:DEP-pobj', 'SPACY:NER-DATE'] eg VILLA to 87077
# -------------------------
# [MATCH]: You have won a Nokia 7250i . This is what you get when you win our FREE auction . To take part send Nokia to 86021:['SPACY:POS-NUM', 'SPACY:DEP-pobj', 'SPACY:NER-DATE'] now . HG / Suite342/2Lands Row / W1JHL 16 +
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I shall book chez jules for half eight:['SPACY:POS-NUM', 'SPACY:DEP-pobj', 'SPACY:NER-DATE'] , if that 's ok with you ?
# -------------------------
# [MATCH]: K I 'm leaving soon , be there a little after 9:['SPACY:POS-NUM', 'SPACY:DEP-pobj', 'SPACY:NER-DATE']
# -------------------------
# ==================================================
# Rank 22
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:DEP-compound']]
# Window size: 2
# Class: Positive
# Precision: 0.652
# Match: 287 (8.0%)
# Gain = 0.094
# Examples ~ Class Positive:
# [MATCH]: U can WIN Â£100 of Music:['SPACY:POS-PROPN'] Gift:['SPACY:DEP-compound'] Vouchers every week starting NOW Txt the word DRAW to 87066 TsCs www . Idew.com SkillGame , 1Winaweek , age16 . 150ppermessSubscription
# -------------------------
# [MATCH]: GENT ! We are trying to contact you . Last weekends draw shows that you won a Â£1000:['SPACY:POS-PROPN'] prize:['SPACY:DEP-compound'] GUARANTEED . Call 09064012160 . Claim Code K52 . Valid 12hrs only . 150ppm
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: IM:['SPACY:POS-PROPN'] FINE:['SPACY:DEP-compound'] BABES AINT BEEN UP 2 MUCH THO ! SAW SCARY MOVIE YEST ITS QUITE FUNNY ! WANT 2MRW AFTERNOON ? AT TOWN OR MALL OR SUMTHIN?xx
# -------------------------
# [MATCH]: Let Ur Heart Be Ur:['SPACY:POS-PROPN'] Compass:['SPACY:DEP-compound'] Ur Mind Ur Map Ur Soul Ur Guide And U Will Never loose in world .... gnun - Sent via WAY2SMS.COM
# -------------------------
# ==================================================
# Rank 23
# Pattern: [['HYPERNYM:entity.n.01', 'SPACY:NER-ORG']]
# Window size: 1
# Class: Positive
# Precision: 0.637
# Match: 292 (8.2%)
# Gain = 0.091
# Examples ~ Class Positive:
# [MATCH]: This is the 2nd time we have tried 2 contact u. U:['HYPERNYM:entity.n.01', 'SPACY:NER-ORG'] have won the 750 Pound prize . 2 claim is easy , call 08712101358 NOW ! Only 10p per min . BT - national - rate
# -------------------------
# [MATCH]: Want a new Video:['HYPERNYM:entity.n.01', 'SPACY:NER-ORG'] Phone ? 750 anytime any network mins ? Half price line rental free text for 3 months ? Reply or call 08000930705 for free delivery
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Imagine Life:['HYPERNYM:entity.n.01', 'SPACY:NER-ORG'] WITHOUT ME ... see .. How fast u are searching me?Don't worry .. l'm always there To disturb U .. Goodnoon .. : )
# -------------------------
# [MATCH]: Yeah if we do have to get a random dude we need to change our info sheets to PARTY:['HYPERNYM:entity.n.01', 'SPACY:NER-ORG']   & lt;#&gt ; /7 NEVER STUDY just to be safe
# -------------------------
# ==================================================
# Rank 24
# Pattern: [['HYPERNYM:entity.n.01'], ['HYPERNYM:abstraction.n.06']]
# Window size: 2
# Class: Negative
# Precision: 0.591
# Match: 675 (18.9%)
# Gain = 0.085
# Examples ~ Class Negative:
# [MATCH]: Ca n't . I feel nauseous . I 'm so pissed . I did n't eat any sweets all week:['HYPERNYM:entity.n.01'] cause:['HYPERNYM:abstraction.n.06'] today I was planning to pig out . I was dieting all week . And now I 'm not hungry :/
# -------------------------
# [MATCH]: Sorry man my account 's dry or I would , if you want we could trade back half or I could buy some shit with my credit:['HYPERNYM:entity.n.01'] card:['HYPERNYM:abstraction.n.06']
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: No 1 POLYPHONIC tone 4 ur mob every week ! Just txt PT2 to 87575 . 1st Tone FREE ! so get txtin now and tell ur friends . 150p / tone . 16 reply:['HYPERNYM:entity.n.01'] HL:['HYPERNYM:abstraction.n.06'] 4info
# -------------------------
# [MATCH]: Free entry in 2 a wkly comp to win FA:['HYPERNYM:entity.n.01'] Cup:['HYPERNYM:abstraction.n.06'] final tkts 21st May 2005 . Text FA to 87121 to receive entry question(std txt rate)T&C 's apply 08452810075over18 's
# -------------------------
# ==================================================
# Rank 25
# Pattern: [['SPACY:NER-ORG'], ['HYPERNYM:entity.n.01']]
# Window size: 2
# Class: Positive
# Precision: 0.695
# Match: 226 (6.3%)
# Gain = 0.083
# Examples ~ Class Positive:
# [MATCH]: * * FREE MESSAGE**Thanks for using the:['SPACY:NER-ORG'] Auction:['HYPERNYM:entity.n.01'] Subscription Service . 18 . 150p / MSGRCVD 2 Skip an Auction txt OUT . 2 Unsubscribe txt STOP CustomerCare 08718726270
# -------------------------
# [MATCH]: Ringtone:['SPACY:NER-ORG'] Club:['HYPERNYM:entity.n.01'] : Gr8 new polys direct to your mobile every week !
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Hello . How u doing?What u been up 2?When:['SPACY:NER-ORG'] will:['HYPERNYM:entity.n.01'] u b moving out of the flat , cos I will need to arrange to pick up the lamp , etc . Take care . Hello caroline !
# -------------------------
# [MATCH]: Solve d Case : A Man Was Found Murdered On   & lt;DECIMAL&gt ; . & lt;#&gt ;   AfterNoon . 1,His wife called Police . 2,Police questioned everyone . 3,Wife : Sir , I was sleeping , when the murder took place . 4.Cook : I was cooking . 5.Gardener : I was picking vegetables . 6.House - Maid : I went 2 d post office . 7.Children : We went 2 play . 8.Neighbour : We went 2 a marriage . Police arrested d murderer Immediately . Who 's It ? Reply With Reason , If U:['SPACY:NER-ORG'] r:['HYPERNYM:entity.n.01'] Brilliant .
# -------------------------
# ==================================================
# Rank 26
# Pattern: [['HYPERNYM:entity.n.01'], ['HYPERNYM:abstraction.n.06', 'SPACY:POS-PROPN']]
# Window size: 2
# Class: Positive
# Precision: 0.766
# Match: 175 (4.9%)
# Gain = 0.078
# Examples ~ Class Positive:
# [MATCH]: Valentines:['HYPERNYM:entity.n.01'] Day:['SPACY:POS-PROPN', 'HYPERNYM:abstraction.n.06'] Special ! Win over Â£1000 in our quiz and take your partner on the trip of a lifetime ! Send GO to 83600 now . 150p / msg rcvd . CustCare:08718720201
# -------------------------
# [MATCH]: Fantasy:['HYPERNYM:entity.n.01'] Football:['SPACY:POS-PROPN', 'HYPERNYM:abstraction.n.06'] is back on your TV . Go to Sky Gamestar on Sky Active and play Â£250k Dream Team . Scoring starts on Saturday , so register now!SKY OPT OUT to 88088
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: HIYA STU WOT U UP 2.IM IN SO MUCH TRUBLE AT HOME AT MOMENT EVONE HATES ME EVEN U ! WOT THE HELL AV I DONE NOW ? Y:['HYPERNYM:entity.n.01'] WONT:['SPACY:POS-PROPN', 'HYPERNYM:abstraction.n.06'] U JUST TELL ME TEXT BCK PLEASE LUV DAN
# -------------------------
# [MATCH]: WE REGRET TO INFORM U THAT THE NHS HAS MADE A MISTAKE.U WERE NEVER ACTUALLY BORN.PLEASE REPORT 2 YOR LOCAL:['HYPERNYM:entity.n.01'] HOSPITAL:['SPACY:POS-PROPN', 'HYPERNYM:abstraction.n.06'] 2B TERMINATED.WE R SORRY 4 THE INCONVENIENCE
# -------------------------
# ==================================================
# Rank 27
# Pattern: [['HYPERNYM:communication.n.02']]
# Window size: 1
# Class: Negative
# Precision: 0.648
# Match: 870 (24.4%)
# Gain = 0.078
# Examples ~ Class Negative:
# [MATCH]: Is that seriously how you spell his name:['HYPERNYM:communication.n.02'] ?
# -------------------------
# [MATCH]: I wanted to wish you a Happy New Year and I wanted to talk to you about some legal advice:['HYPERNYM:communication.n.02'] to do with when Gary and I split but in person . I 'll make a trip to Ptbo for that . I hope everything is good with you babe and I love ya :)
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: 07732584351 - Rodger Burns - MSG = We tried to call you re your reply:['HYPERNYM:communication.n.02'] to our sms for a free nokia mobile + free camcorder . Please call now 08000930705 for delivery tomorrow
# -------------------------
# [MATCH]: This is the 2nd time we have tried 2 contact u. U have won the 750 Pound prize:['HYPERNYM:communication.n.02'] . 2 claim is easy , call 08712101358 NOW ! Only 10p per min . BT - national - rate
# -------------------------
# ==================================================
# Rank 28
# Pattern: [['HYPERNYM:abstraction.n.06'], ['HYPERNYM:entity.n.01']]
# Window size: 2
# Class: Negative
# Precision: 0.593
# Match: 637 (17.9%)
# Gain = 0.077
# Examples ~ Class Negative:
# [MATCH]: Yeah if we do have to get a random dude we need to change our info:['HYPERNYM:abstraction.n.06'] sheets:['HYPERNYM:entity.n.01'] to PARTY   & lt;#&gt ; /7 NEVER STUDY just to be safe
# -------------------------
# [MATCH]: Playin space:['HYPERNYM:abstraction.n.06'] poker:['HYPERNYM:entity.n.01'] , u ?
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Had your mobile 11 months or more ? U:['HYPERNYM:abstraction.n.06'] R:['HYPERNYM:entity.n.01'] entitled to Update to the latest colour mobiles with camera for Free ! Call The Mobile Update Co FREE on 08002986030
# -------------------------
# [MATCH]: Ur cash - balance is currently 500 pounds - to maximize ur cash - in now send COLLECT to 83600 only 150p / msg . CC : 08718720201 PO:['HYPERNYM:abstraction.n.06'] BOX:['HYPERNYM:entity.n.01'] 114/14 TCR / W1
# -------------------------
# ==================================================
# Rank 29
# Pattern: [['HYPERNYM:entity.n.01'], ['SPACY:DEP-compound']]
# Window size: 2
# Class: Positive
# Precision: 0.562
# Match: 320 (9.0%)
# Gain = 0.075
# Examples ~ Class Positive:
# [MATCH]: SMS:['HYPERNYM:entity.n.01'] AUCTION:['SPACY:DEP-compound'] - A BRAND NEW Nokia 7250 is up 4 auction today ! Auction is FREE 2 join & take part ! Txt NOKIA to 86021 now !
# -------------------------
# [MATCH]: Congrats ! 2 mobile 3 G:['HYPERNYM:entity.n.01'] Videophones:['SPACY:DEP-compound'] R yours . call 09063458130 now ! videochat wid your mates , play java games , Dload polyPH music , noline rentl .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Wat 's da:['HYPERNYM:entity.n.01'] model:['SPACY:DEP-compound'] num of ur phone ?
# -------------------------
# [MATCH]: Today is ACCEPT DAY .. U Accept me as ? Brother:['HYPERNYM:entity.n.01'] Sister:['SPACY:DEP-compound'] Lover Dear1 Best1 Clos1 Lvblefrnd Jstfrnd Cutefrnd Lifpartnr Belovd Swtheart Bstfrnd No rply means enemy
# -------------------------
# ==================================================
# Rank 30
# Pattern: [['SPACY:DEP-compound', 'SPACY:NER-ORG', 'SPACY:POS-PROPN']]
# Window size: 1
# Class: Positive
# Precision: 0.719
# Match: 192 (5.4%)
# Gain = 0.075
# Examples ~ Class Positive:
# [MATCH]: Eerie:['SPACY:POS-PROPN', 'SPACY:NER-ORG', 'SPACY:DEP-compound'] Nokia tones 4u , rply TONE TITLE to 8007 eg TONE DRACULA to 8007 Titles : GHOST , ADDAMSFA , MUNSTERS , EXORCIST , TWILIGHT www.getzed.co.uk POBox36504W45WQ 150p
# -------------------------
# [MATCH]: Sunshine Quiz Wkly Q ! Win a top Sony:['SPACY:POS-PROPN', 'SPACY:NER-ORG', 'SPACY:DEP-compound'] DVD player if u know which country Liverpool played in mid week ? Txt ansr to 82277 . Â£1.50 SP : Tyrone
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Helloooo ... Wake up .. ! " Sweet " " morning " " welcomes " " You " " Enjoy " " This Day " " with full of joy " .. " GUD:['SPACY:POS-PROPN', 'SPACY:NER-ORG', 'SPACY:DEP-compound'] MRNG " .
# -------------------------
# [MATCH]: Honeybee Said : * I 'm d Sweetest in d World * God Laughed & amp ; Said : * Wait , U:['SPACY:POS-PROPN', 'SPACY:NER-ORG', 'SPACY:DEP-compound'] Havnt Met d Person Reading This Msg * MORAL : Even GOD Can Crack Jokes ! GM+GN+GE+GN : )
# -------------------------
# ==================================================
# Rank 31
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:NER-ORG']]
# Window size: 2
# Class: Positive
# Precision: 0.696
# Match: 204 (5.7%)
# Gain = 0.074
# Examples ~ Class Positive:
# [MATCH]: Want 2 get laid tonight ? Want real Dogging locations sent direct 2 ur mob ? Join the UK 's largest Dogging:['SPACY:POS-PROPN'] Network:['SPACY:NER-ORG'] bt Txting GRAVEL to 69888 ! Nt . ec2a . 31p.msg@150p
# -------------------------
# [MATCH]: Free 1st week entry 2 TEXTPOD 4 a chance 2 win 40 GB:['SPACY:POS-PROPN'] iPod:['SPACY:NER-ORG'] or Â£250 cash every wk . Txt POD to 84128 Ts&Cs www.textpod.net custcare 08712405020 .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Honeybee Said : * I 'm d Sweetest in d World * God:['SPACY:POS-PROPN'] Laughed:['SPACY:NER-ORG'] & amp ; Said : * Wait , U Havnt Met d Person Reading This Msg * MORAL : Even GOD Can Crack Jokes ! GM+GN+GE+GN : )
# -------------------------
# [MATCH]: Evry Emotion dsn't hav Words . Evry Wish dsn't hav Prayrs .. If u Smile , D:['SPACY:POS-PROPN'] World:['SPACY:NER-ORG'] is wit u . Othrwise even d Drop of Tear dsn't lik 2 Stay wit u . So b happy .. Good morning , keep smiling:- )
# -------------------------
# ==================================================
# Rank 32
# Pattern: [['SPACY:DEP-compound'], ['SPACY:POS-PROPN'], ['HYPERNYM:entity.n.01']]
# Window size: 3
# Class: Positive
# Precision: 0.773
# Match: 163 (4.6%)
# Gain = 0.074
# Examples ~ Class Positive:
# [MATCH]: SPJanuary:['SPACY:DEP-compound'] Male:['SPACY:POS-PROPN'] Sale:['HYPERNYM:entity.n.01'] ! Hot Gay chat now cheaper , call 08709222922 . National rate from 1.5p / min cheap to 7.8p / min peak ! To stop texts call 08712460324 ( 10p / min )
# -------------------------
# [MATCH]: You can donate Â£2.50 to UNICEF 's Asian:['SPACY:DEP-compound'] Tsunami:['SPACY:POS-PROPN'] disaster:['HYPERNYM:entity.n.01'] support fund by texting DONATE to 864233 . Â£2.50 will be added to your next bill
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Mmmmmm ... I love you , so much , Ahmad ... I ca n't wait for this year to begin as every second takes me closer to being at your side . Happy:['SPACY:DEP-compound'] New:['SPACY:POS-PROPN'] Year:['HYPERNYM:entity.n.01'] , my love ! !
# -------------------------
# [MATCH]: Today is ACCEPT DAY .. U Accept me as ? Brother:['SPACY:DEP-compound'] Sister:['SPACY:POS-PROPN'] Lover:['HYPERNYM:entity.n.01'] Dear1 Best1 Clos1 Lvblefrnd Jstfrnd Cutefrnd Lifpartnr Belovd Swtheart Bstfrnd No rply means enemy
# -------------------------
# ==================================================
# Rank 33
# Pattern: [['SPACY:DEP-compound'], ['HYPERNYM:communication.n.02']]
# Window size: 2
# Class: Positive
# Precision: 0.618
# Match: 254 (7.1%)
# Gain = 0.072
# Examples ~ Class Positive:
# [MATCH]: Todays Vodafone:['SPACY:DEP-compound'] numbers:['HYPERNYM:communication.n.02'] ending with 4882 are selected to a receive a Â£350 award . If your number matches call 09064019014 to receive your Â£350 award .
# -------------------------
# [MATCH]: * FREE * POLYPHONIC RINGTONE:['SPACY:DEP-compound'] Text:['HYPERNYM:communication.n.02'] SUPER to 87131 to get your FREE POLY TONE of the week now ! 16 SN PoBox202 NR31 7ZS subscription 450pw
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Did u got that persons:['SPACY:DEP-compound'] story:['HYPERNYM:communication.n.02']
# -------------------------
# [MATCH]: Howz that persons:['SPACY:DEP-compound'] story:['HYPERNYM:communication.n.02']
# -------------------------
# ==================================================
# Rank 34
# Pattern: [['SPACY:DEP-compound'], ['SPACY:DEP-compound'], ['SPACY:POS-PROPN']]
# Window size: 3
# Class: Positive
# Precision: 0.726
# Match: 179 (5.0%)
# Gain = 0.071
# Examples ~ Class Positive:
# [MATCH]: Bears:['SPACY:DEP-compound'] Pic:['SPACY:DEP-compound'] Nick:['SPACY:POS-PROPN'] , and Tom , Pete and ... Dick . In fact , all types try gay chat with photo upload call 08718730666 ( 10p / min ) . 2 stop texts call 08712460324
# -------------------------
# [MATCH]: Urgent Urgent ! We have 800 FREE flights to Europe to give away , call B4:['SPACY:DEP-compound'] 10th:['SPACY:DEP-compound'] Sept:['SPACY:POS-PROPN'] & take a friend 4 FREE . Call now to claim on 09050000555 . BA128NNFWFLY150ppm
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Y?WHERE U AT DOGBREATH ? ITS JUST SOUNDING LIKE:['SPACY:DEP-compound'] JAN:['SPACY:DEP-compound'] C:['SPACY:POS-PROPN'] THATÂ ’S AL ! ! ! ! ! ! ! ! !
# -------------------------
# [MATCH]: HIYA COMIN 2 BRISTOL 1 ST WEEK IN APRIL . LES:['SPACY:DEP-compound'] GOT:['SPACY:DEP-compound'] OFF:['SPACY:POS-PROPN'] + RUDI ON NEW YRS EVE BUT I WAS SNORING.THEY WERE DRUNK ! U BAK AT COLLEGE YET ? MY WORK SENDS INK 2 BATH .
# -------------------------
# ==================================================
# Rank 35
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
# Window size: 2
# Class: Positive
# Precision: 0.861
# Match: 122 (3.4%)
# Gain = 0.070
# Examples ~ Class Positive:
# [MATCH]: Uâ€ ™ ve Bin Awarded Â£50 to Play 4:['SPACY:POS-NUM'] Instant:['SPACY:POS-PROPN'] Cash . Call 08715203028 To Claim . EVERY 9th Player Wins Min Â£50-Â£500 . OptOut 08718727870
# -------------------------
# [MATCH]: You have won a guaranteed Â£200 award or even Â£1000 cashto claim UR award call free on 08000407165 ( 18 + ) 2 stop getstop on 88222:['SPACY:POS-NUM'] PHP:['SPACY:POS-PROPN']
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Hi here . have birth at on the   to   at 8:['SPACY:POS-NUM'] lb:['SPACY:POS-PROPN'] 7 oz . Mother and baby doing brilliantly .
# -------------------------
# [MATCH]: HEY THERE BABE , HOW U DOIN ? WOT U UP 2 2NITE:['SPACY:POS-NUM'] LOVE:['SPACY:POS-PROPN'] ANNIE X.
# -------------------------
# ==================================================
# Rank 36
# Pattern: [['HYPERNYM:entity.n.01'], ['SPACY:DEP-compound', 'SPACY:POS-PROPN']]
# Window size: 2
# Class: Positive
# Precision: 0.793
# Match: 145 (4.1%)
# Gain = 0.069
# Examples ~ Class Positive:
# [MATCH]: Ur ringtone service has changed ! 25 Free credits ! Go to club4mobiles.com to choose content now ! Stop ? txt CLUB STOP to 87070 . 150p / wk Club4 PO:['HYPERNYM:entity.n.01'] Box1146:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] MK45 2WT
# -------------------------
# [MATCH]: You 'll not rcv any more msgs from the chat svc . For FREE:['HYPERNYM:entity.n.01'] Hardcore:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] services text GO to : 69988 If u get nothing u must Age Verify with yr network & try again
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Hello beautiful r u ok ? I 've kinda ad a row wiv and he walked out the pub ? ? I wanted a night wiv u:['HYPERNYM:entity.n.01'] Miss:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] u
# -------------------------
# [MATCH]: 1Apple / Day = No Doctor . 1Tulsi Leaf / Day = No Cancer . 1Lemon / Day = No Fat . 1Cup Milk / day = No Bone Problms 3 Litres Watr / Day = No Diseases:['HYPERNYM:entity.n.01'] Snd:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] ths 2 Whom U Care .. :- )
# -------------------------
# ==================================================
# Rank 37
# Pattern: [['SPACY:DEP-amod']]
# Window size: 1
# Class: Negative
# Precision: 0.735
# Match: 1440 (40.4%)
# Gain = 0.068
# Examples ~ Class Negative:
# [MATCH]: I might come to kerala for 2 days.so you can be prepared to take a leave once i finalise .dont plan any travel during my visit.need to finish urgent:['SPACY:DEP-amod'] works .
# -------------------------
# [MATCH]: Lil:['SPACY:DEP-amod'] fever : ) now fine : )
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: For ur chance to win Â£250:['SPACY:DEP-amod'] cash every wk TXT : PLAY to 83370 . T's&C 's www.music-trivia.net custcare 08715705022 , 1x150p / wk .
# -------------------------
# [MATCH]: Final Chance ! Claim ur Â£150 worth:['SPACY:DEP-amod'] of discount vouchers today ! Text YES to 85023 now ! SavaMob , member offers mobile ! T Cs SavaMob POBOX84 , M263UZ . Â£3.00 Subs 16
# -------------------------
# ==================================================
# Rank 38
# Pattern: [['TEXT:i']]
# Window size: 1
# Class: Negative
# Precision: 0.983
# Match: 1327 (37.2%)
# Gain = 0.067
# Examples ~ Class Negative:
# [MATCH]: I:['TEXT:i'] 'm done oredi ...
# -------------------------
# [MATCH]: Sorry my roommates took forever , it ok if I:['TEXT:i'] come by now ?
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Babe : U want me do nt u baby ! I:['TEXT:i'] m nasty and have a thing 4 filthyguys . Fancy a rude time with a sexy bitch . How about we go slo n hard ! Txt XXX SLO(4msgs )
# -------------------------
# [MATCH]: FreeMsg Hey U , i:['TEXT:i'] just got 1 of these video / pic fones , reply WILD to this txt & ill send U my pics , hurry up I m so bored at work xxx ( 18 150p / rcvd STOP2stop )
# -------------------------
# ==================================================
# Rank 39
# Pattern: [['SPACY:POS-SYM']]
# Window size: 1
# Class: Positive
# Precision: 0.756
# Match: 156 (4.4%)
# Gain = 0.067
# Examples ~ Class Positive:
# [MATCH]: Urgent ! call 09066612661 from landline . Your complementary 4 * Tenerife Holiday or Â£10,000 cash await collection SAE T&Cs PO Box 3 WA14 2PX 150ppm 18 +:['SPACY:POS-SYM'] Sender : Hol Offer
# -------------------------
# [MATCH]: 1st wk FREE ! Gr8 tones str8 2 u each wk . Txt NOKIA ON to 8007 for Classic Nokia tones or HIT ON to 8007 for Polys . Nokia/150p Poly/200p 16 +:['SPACY:POS-SYM']
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: If anyone calls for a treadmill say you 'll buy it . Make sure its working . I found an ad on Craigslist selling for $:['SPACY:POS-SYM'] & lt;#&gt ; .
# -------------------------
# [MATCH]: Please protect yourself from e - threats . SIB never asks for sensitive information like Passwords , ATM /:['SPACY:POS-SYM'] SMS PIN thru email . Never share your password with anybody .
# -------------------------
# ==================================================
# Rank 40
# Pattern: [['TEXT:free']]
# Window size: 1
# Class: Positive
# Precision: 0.748
# Match: 159 (4.5%)
# Gain = 0.067
# Examples ~ Class Positive:
# [MATCH]: You have won a guaranteed Â£200 award or even Â£1000 cashto claim UR award call free:['TEXT:free'] on 08000407165 ( 18 + ) 2 stop getstop on 88222 PHP . RG21 4JX
# -------------------------
# [MATCH]: Had your mobile 10 mths ? Update to latest Orange camera / video phones for FREE:['TEXT:free'] . Save Â£s with Free texts / weekend calls . Text YES for a callback orno to opt out
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I ( Career Tel ) have added u as a contact on INDYAROCKS.COM to send FREE:['TEXT:free'] SMS . To remove from phonebook - sms NO to   & lt;#&gt ;
# -------------------------
# [MATCH]: K .. then come wenever u lik to come and also tel vikky to come by getting free:['TEXT:free'] time .. :- )
# -------------------------
# ==================================================
# Rank 41
# Pattern: [['HYPERNYM:entity.n.01'], ['SPACY:NER-ORG']]
# Window size: 2
# Class: Positive
# Precision: 0.686
# Match: 191 (5.4%)
# Gain = 0.067
# Examples ~ Class Positive:
# [MATCH]: URGENT ! Your Mobile No was awarded a Â£2,000 Bonus Caller Prize on 1/08/03 ! This is our 2nd attempt to contact YOU ! Call 0871 - 4719 - 523 BOX95QU BT National:['HYPERNYM:entity.n.01'] Rate:['SPACY:NER-ORG']
# -------------------------
# [MATCH]: You will be receiving this week 's Triple:['HYPERNYM:entity.n.01'] Echo:['SPACY:NER-ORG'] ringtone shortly . Enjoy it !
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Today is ACCEPT DAY .. U:['HYPERNYM:entity.n.01'] Accept:['SPACY:NER-ORG'] me as ? Brother Sister Lover Dear1 Best1 Clos1 Lvblefrnd Jstfrnd Cutefrnd Lifpartnr Belovd Swtheart Bstfrnd No rply means enemy
# -------------------------
# [MATCH]: ALRITE SAM ITS NIC JUST CHECKIN THAT THIS IS UR NUMBER:['HYPERNYM:entity.n.01'] -:['SPACY:NER-ORG'] SO IS IT?T.B *
# -------------------------
# ==================================================
# Rank 42
# Pattern: [['TEXT:txt']]
# Window size: 1
# Class: Positive
# Precision: 0.938
# Match: 96 (2.7%)
# Gain = 0.067
# Examples ~ Class Positive:
# [MATCH]: You are guaranteed the latest Nokia Phone , a 40 GB iPod MP3 player or a Â£500 prize ! Txt:['TEXT:txt'] word : COLLECT to No : 83355 ! IBHltd LdnW15H 150p / Mtmsgrcvd18 +
# -------------------------
# [MATCH]: FREE for 1st week ! No1 Nokia tone 4 ur mobile every week just txt:['TEXT:txt'] NOKIA to 8077 Get txting and tell ur mates . www.getzed.co.uk POBox 36504 W45WQ 16 + norm150p / tone
# -------------------------
# Counterexamples ~ Not class Positive:
# ...
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Dear where you .:['TEXT:.'] Call:['TEXT:call'] me
# -------------------------
# [MATCH]: You call him and tell now infront of them .:['TEXT:.'] Call:['TEXT:call'] him now .
# -------------------------
# ==================================================
# Rank 87
# Pattern: [['SPACY:POS-ADJ'], ['SPACY:DEP-compound']]
# Window size: 2
# Class: Negative
# Precision: 0.548
# Match: 321 (9.0%)
# Gain = 0.044
# Examples ~ Class Negative:
# [MATCH]: Good:['SPACY:POS-ADJ'] afternoon:['SPACY:DEP-compound'] starshine ! How 's my boytoy ? Does he crave me yet ? Ache to fuck me ? * sips cappuccino * I miss you babe * teasing kiss *
# -------------------------
# [MATCH]: Wow so healthy . Old:['SPACY:POS-ADJ'] airport:['SPACY:DEP-compound'] rd lor . Ca nt thk of anything else . But i 'll b bathing my dog later .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Congrats ! Nokia 3650 video camera phone is your:['SPACY:POS-ADJ'] Call:['SPACY:DEP-compound'] 09066382422 Calls cost 150ppm Ave call 3mins vary from mobiles 16 + Close 300603 post BCM4284 Ldn WC1N3XX
# -------------------------
# [MATCH]: For your chance to WIN a FREE:['SPACY:POS-ADJ'] Bluetooth:['SPACY:DEP-compound'] Headset then simply reply back with " ADP "
# -------------------------
# ==================================================
# Rank 88
# Pattern: [['HYPERNYM:entity.n.01', 'SPACY:DEP-compound', 'SPACY:NER-ORG']]
# Window size: 1
# Class: Positive
# Precision: 0.699
# Match: 123 (3.4%)
# Gain = 0.043
# Examples ~ Class Positive:
# [MATCH]: HOT LIVE FANTASIES call now 08707509020 Just 20p per min NTT Ltd , PO:['SPACY:DEP-compound', 'HYPERNYM:entity.n.01', 'SPACY:NER-ORG'] Box 1327 Croydon CR9 5WB 0870 is a national rate call
# -------------------------
# [MATCH]: Not heard from U4 a while . Call 4 rude chat private line 01223585334 to cum . Wan 2C pics of me gettin shagged then text PIX to 8552 . 2End send STOP 8552 SAM:['SPACY:DEP-compound', 'HYPERNYM:entity.n.01', 'SPACY:NER-ORG'] xxx
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Honeybee Said : * I 'm d Sweetest in d World * God Laughed & amp ; Said : * Wait , U:['SPACY:DEP-compound', 'HYPERNYM:entity.n.01', 'SPACY:NER-ORG'] Havnt Met d Person Reading This Msg * MORAL : Even GOD Can Crack Jokes ! GM+GN+GE+GN : )
# -------------------------
# [MATCH]: Height of Confidence : All the Aeronautics:['SPACY:DEP-compound', 'HYPERNYM:entity.n.01', 'SPACY:NER-ORG'] professors wer calld & amp ; they wer askd 2 sit in an aeroplane . Aftr they sat they wer told dat the plane ws made by their students . Dey all hurried out of d plane .. Bt only 1 did nt move ... He said:"if it is made by my students , this wo nt even start ........ Datz confidence ..
# -------------------------
# ==================================================
# Rank 89
# Pattern: [['SPACY:DEP-appos']]
# Window size: 1
# Class: Negative
# Precision: 0.543
# Match: 311 (8.7%)
# Gain = 0.043
# Examples ~ Class Negative:
# [MATCH]: And you ! Will expect you whenever you text ! Hope all:['SPACY:DEP-appos'] goes well tomo
# -------------------------
# [MATCH]: Ee msg na poortiyagi odalebeku : Hanumanji 7 name 1-Hanuman 2-Bajarangabali 3-Maruti 4-Pavanaputra 5-Sankatmochan 6-Ramaduth 7-Mahaveer:['SPACY:DEP-appos'] ee 7 name   & lt;#&gt ;   janarige ivatte kalisidare next saturday olage ondu good news keluviri ... ! Maretare inde 1 dodda problum nalli siguviri idu matra   & lt;#&gt ; % true .. Do n't neglet .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: U've been selected to stay in 1 of 250 top British hotels - FOR NOTHING ! Holiday valued at Â£350 ! Dial 08712300220 to claim - National Rate Call . Bx526 , SW73SS:['SPACY:DEP-appos']
# -------------------------
# [MATCH]: Win the newest â€œHarry Potter and the Order of the Phoenix ( Book:['SPACY:DEP-appos'] 5 ) reply HARRY , answer 5 questions - chance to be the first among readers !
# -------------------------
# ==================================================
# Rank 90
# Pattern: [['SPACY:DEP-compound'], ['SPACY:DEP-dobj', 'SPACY:POS-PROPN']]
# Window size: 2
# Class: Positive
# Precision: 0.745
# Match: 106 (3.0%)
# Gain = 0.043
# Examples ~ Class Positive:
# [MATCH]: URGENT ! We are trying to contact you . Last weekends draw shows that you have won a Â£900 prize:['SPACY:DEP-compound'] GUARANTEED:['SPACY:POS-PROPN', 'SPACY:DEP-dobj'] . Call 09061701851 . Claim code K61 . Valid 12hours only
# -------------------------
# [MATCH]: U've been selected to stay in 1 of 250 top British hotels - FOR NOTHING ! Holiday valued at Â£350 ! Dial 08712300220 to claim - National Rate:['SPACY:DEP-compound'] Call:['SPACY:POS-PROPN', 'SPACY:DEP-dobj'] . Bx526 , SW73SS
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: THATÂ ’S ALRITE:['SPACY:DEP-compound'] GIRL:['SPACY:POS-PROPN', 'SPACY:DEP-dobj'] , U KNOW GAIL IS NEVA WRONG!!TAKE CARE SWEET AND DONÂ’T WORRY.C U L8TR HUN!LOVE Yaxxx
# -------------------------
# [MATCH]: IM FINE BABES AINT BEEN UP 2 MUCH THO ! SAW SCARY MOVIE YEST ITS QUITE FUNNY ! WANT 2MRW:['SPACY:DEP-compound'] AFTERNOON:['SPACY:POS-PROPN', 'SPACY:DEP-dobj'] ? AT TOWN OR MALL OR SUMTHIN?xx
# -------------------------
# ==================================================
# Rank 91
# Pattern: [['HYPERNYM:communication.n.02'], ['SPACY:POS-NUM']]
# Window size: 2
# Class: Positive
# Precision: 0.923
# Match: 65 (1.8%)
# Gain = 0.043
# Examples ~ Class Positive:
# [MATCH]: Congratulations ur awarded either Â£500 of CD gift vouchers & Free entry:['HYPERNYM:communication.n.02'] 2:['SPACY:POS-NUM'] our Â£100 weekly draw txt MUSIC to 87066 TnCs www . Ldew.com1win150ppmx3age16
# -------------------------
# [MATCH]: Congratulations ur awarded either Â£500 of CD gift vouchers & Free entry:['HYPERNYM:communication.n.02'] 2:['SPACY:POS-NUM'] our Â£100 weekly draw txt MUSIC to 87066 TnCs www . Ldew.com 1 win150ppmx3age16
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: " Getting tickets:['HYPERNYM:communication.n.02'] 4:['SPACY:POS-NUM'] walsall tue 6 th march . My mate is getting me them on sat . ill pay my treat . Want 2 go . Txt bak .Terry "
# -------------------------
# [MATCH]: Hi mate its RV did u hav a nice hol just a message:['HYPERNYM:communication.n.02'] 3:['SPACY:POS-NUM'] say hello coz havenÂ’t sent u 1 in ages started driving so stay off roads!RVx
# -------------------------
# ==================================================
# Rank 92
# Pattern: [['SPACY:DEP-compound'], ['HYPERNYM:relation.n.01']]
# Window size: 2
# Class: Positive
# Precision: 0.584
# Match: 178 (5.0%)
# Gain = 0.043
# Examples ~ Class Positive:
# [MATCH]: You have won a guaranteed Â£200:['SPACY:DEP-compound'] award:['HYPERNYM:relation.n.01'] or even Â£1000 cashto claim UR award call free on 08000407165 ( 18 + ) 2 stop getstop on 88222 PHP . RG21 4JX
# -------------------------
# [MATCH]: SMS SERVICES . for your inclusive text:['SPACY:DEP-compound'] credits:['HYPERNYM:relation.n.01'] , pls goto www.comuk.net login= 3qxj9 unsubscribe with STOP , no extra charge . help 08702840625.COMUK . 220-CM2 9AE
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: " CHEERS:['SPACY:DEP-compound'] U:['HYPERNYM:relation.n.01'] TEX MECAUSE U WEREBORED ! YEAH OKDEN HUNNY R UIN WK SAT?SOUNDÂ ’S LIKEYOUR HAVIN GR8FUN J ! KEEP UPDAT COUNTINLOTS OF LOVEME XXXXX . "
# -------------------------
# [MATCH]: Evry Emotion dsn't hav Words . Evry Wish dsn't hav Prayrs .. If u Smile , D World is wit u . Othrwise even d Drop of Tear dsn't lik 2 Stay wit:['SPACY:DEP-compound'] u:['HYPERNYM:relation.n.01'] . So b happy .. Good morning , keep smiling:- )
# -------------------------
# ==================================================
# Rank 93
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:DEP-compound'], ['HYPERNYM:abstraction.n.06']]
# Window size: 3
# Class: Positive
# Precision: 0.703
# Match: 118 (3.3%)
# Gain = 0.042
# Examples ~ Class Positive:
# [MATCH]: Ur:['SPACY:POS-PROPN'] HMV:['SPACY:DEP-compound'] Quiz:['HYPERNYM:abstraction.n.06'] cash - balance is currently Â£500 - to maximize ur cash - in now send HMV1 to 86688 only 150p / msg
# -------------------------
# [MATCH]: Do you want a new Video handset ? 750 any time any network mins ? UNLIMITED TEXT ? Camcorder ? Reply or Call now 08000930705 for del:['SPACY:POS-PROPN'] Sat:['SPACY:DEP-compound'] AM:['HYPERNYM:abstraction.n.06']
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: She is our sister .. She belongs 2 our family .. She is d hope of tomorrow .. Pray 4 her , who was fated 4 d Shoranur:['SPACY:POS-PROPN'] train:['SPACY:DEP-compound'] incident:['HYPERNYM:abstraction.n.06'] . Lets hold our hands together & amp ; fuelled by love & amp ; concern prior 2 her grief & amp ; pain . Pls join in dis chain & amp ; pass it . STOP VIOLENCE AGAINST WOMEN .
# -------------------------
# [MATCH]: HIYA COMIN 2 BRISTOL 1 ST WEEK IN APRIL . LES GOT OFF + RUDI ON NEW:['SPACY:POS-PROPN'] YRS:['SPACY:DEP-compound'] EVE:['HYPERNYM:abstraction.n.06'] BUT I WAS SNORING.THEY WERE DRUNK ! U BAK AT COLLEGE YET ? MY WORK SENDS INK 2 BATH .
# -------------------------
# ==================================================
# Rank 94
# Pattern: [['TEXT:call'], ['SPACY:DEP-dobj']]
# Window size: 2
# Class: Positive
# Precision: 0.614
# Match: 158 (4.4%)
# Gain = 0.042
# Examples ~ Class Positive:
# [MATCH]: Call:['TEXT:call'] Germany:['SPACY:DEP-dobj'] for only 1 pence per minute ! Call from a fixed line via access number 0844 861 85 85 . No prepayment . Direct access ! www.telediscount.co.uk
# -------------------------
# [MATCH]: Want a new Video Phone ? 750 anytime any network mins ? Half price line rental free text for 3 months ? Reply or call:['TEXT:call'] 08000930705:['SPACY:DEP-dobj'] for free delivery
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Hey now am free you can call:['TEXT:call'] me:['SPACY:DEP-dobj'] .
# -------------------------
# [MATCH]: My life Means a lot to me , Not because I love my life , But because I love the people in my life , The world calls them friends , I call:['TEXT:call'] them:['SPACY:DEP-dobj'] my World:- ) .. Ge:- ) ..
# -------------------------
# ==================================================
# Rank 95
# Pattern: [['SENTIMENT:pos']]
# Window size: 1
# Class: Negative
# Precision: 0.761
# Match: 1425 (39.9%)
# Gain = 0.042
# Examples ~ Class Negative:
# [MATCH]: One of the joys in lifeis waking up each daywith thoughts that somewhereSomeone cares enough:['SENTIMENT:pos'] tosend a warm morning greeting .. -
# -------------------------
# [MATCH]: That 's fine:['SENTIMENT:pos'] , I 'll bitch at you about it later then
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: UR awarded:['SENTIMENT:pos'] a City Break and could WIN a Â£200 Summer Shopping spree every WK . Txt STORE to 88039 . SkilGme . TsCs087147403231Winawk!Age16 Â£1.50perWKsub
# -------------------------
# [MATCH]: Santa calling ! Would your little ones like:['SENTIMENT:pos'] a call from Santa Xmas Eve ? Call 09077818151 to book you time . Calls1.50ppm last 3mins 30s T&C www.santacalling.com
# -------------------------
# ==================================================
# Rank 96
# Pattern: [['HYPERNYM:abstraction.n.06'], ['SPACY:NER-ORG', 'SPACY:POS-PROPN']]
# Window size: 2
# Class: Positive
# Precision: 0.805
# Match: 87 (2.4%)
# Gain = 0.042
# Examples ~ Class Positive:
# [MATCH]: okmail : Dear Dave this is your final notice to collect your 4 * Tenerife Holiday or # 5000 CASH award ! Call 09061743806 from landline . TCs:['HYPERNYM:abstraction.n.06'] SAE:['SPACY:POS-PROPN', 'SPACY:NER-ORG'] Box326 CW25WX 150ppm
# -------------------------
# [MATCH]: Your free ringtone is waiting to be collected . Simply text the password " MIX " to 85069 to verify . Get Usher and Britney . FML , PO:['HYPERNYM:abstraction.n.06'] Box:['SPACY:POS-PROPN', 'SPACY:NER-ORG'] 5249 , MK17 92H. 450Ppw 16
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Solve d Case : A Man Was Found Murdered On   & lt;DECIMAL&gt ; . & lt;#&gt ;   AfterNoon . 1,His wife called Police . 2,Police questioned everyone . 3,Wife : Sir , I was sleeping , when the murder took place . 4.Cook : I was cooking . 5.Gardener : I was picking vegetables . 6.House - Maid : I went 2 d post office . 7.Children : We went 2 play . 8.Neighbour : We went 2 a marriage . Police arrested d murderer Immediately . Who 's It ? Reply With Reason , If U r:['HYPERNYM:abstraction.n.06'] Brilliant:['SPACY:POS-PROPN', 'SPACY:NER-ORG'] .
# -------------------------
# [MATCH]: WHAT TIME U:['HYPERNYM:abstraction.n.06'] WRKIN:['SPACY:POS-PROPN', 'SPACY:NER-ORG'] ?
# -------------------------
# ==================================================
# Rank 97
# Pattern: [['HYPERNYM:act.n.02']]
# Window size: 1
# Class: Negative
# Precision: 0.686
# Match: 726 (20.4%)
# Gain = 0.041
# Examples ~ Class Negative:
# [MATCH]: I 've been searching for the right words to thank you for this breather . I promise i wo nt take your help for granted and will fulfil my promise:['HYPERNYM:act.n.02'] . You have been wonderful and a blessing at all times .
# -------------------------
# [MATCH]: Oh you got many responsibilities:['HYPERNYM:act.n.02'] .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Camera - You are awarded a SiPix Digital Camera ! call 09061221066 fromm landline . Delivery:['HYPERNYM:act.n.02'] within 28 days .
# -------------------------
# [MATCH]: Customer service announcement . We recently tried to make a delivery:['HYPERNYM:act.n.02'] to you but were unable to do so , please call 07099833605 to re - schedule . Ref:9280114
# -------------------------
# ==================================================
# Rank 98
# Pattern: [['HYPERNYM:communication.n.02', 'SPACY:DEP-compound']]
# Window size: 1
# Class: Positive
# Precision: 0.588
# Match: 170 (4.8%)
# Gain = 0.041
# Examples ~ Class Positive:
# [MATCH]: URGENT ! We are trying to contact U. Todays draw shows that you have won a Â£2000 prize:['HYPERNYM:communication.n.02', 'SPACY:DEP-compound'] GUARANTEED . Call 09066358361 from land line . Claim Y87 . Valid 12hrs only
# -------------------------
# [MATCH]: URGENT ! Your Mobile number has been awarded a < UKP>2000 prize:['HYPERNYM:communication.n.02', 'SPACY:DEP-compound'] GUARANTEED . Call 09061790125 from landline . Claim 3030 . Valid 12hrs only 150ppm
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: U R THE MOST BEAUTIFUL GIRL IVE EVER SEEN . U R MY BABY COME AND C:['HYPERNYM:communication.n.02', 'SPACY:DEP-compound'] ME IN THE COMMON ROOM
# -------------------------
# [MATCH]: Those cocksuckers . If it makes you feel better ipads are worthless garbage:['HYPERNYM:communication.n.02', 'SPACY:DEP-compound'] novelty items and you should feel bad for even wanting one
# -------------------------
# ==================================================
# Rank 99
# Pattern: [['SPACY:NER-ORG'], ['SPACY:POS-NUM']]
# Window size: 2
# Class: Positive
# Precision: 0.863
# Match: 73 (2.0%)
# Gain = 0.041
# Examples ~ Class Positive:
# [MATCH]: Please call our customer service representative on FREEPHONE:['SPACY:NER-ORG'] 0808:['SPACY:POS-NUM'] 145 4742 between 9am-11pm as you have WON a guaranteed Â£1000 cash or Â£5000 prize !
# -------------------------
# [MATCH]: Urgent ! call 09066350750 from your landline . Your complimentary 4 * Ibiza Holiday or 10,000 cash await collection SAE T&Cs PO BOX:['SPACY:NER-ORG'] 434:['SPACY:POS-NUM'] SK3 8WP 150 ppm 18 +
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: How have your little darlings been so far this week ? Need a coffee run tomo?Can't believe it 's that time of week already â€:['SPACY:NER-ORG'] ¦:['SPACY:POS-NUM']
# -------------------------
# [MATCH]: Boy ; I love u Grl : Hogolo Boy : gold chain kodstini Grl : Agalla Boy : necklace madstini Grl : agalla Boy : Hogli:['SPACY:NER-ORG'] 1:['SPACY:POS-NUM'] mutai eerulli kodthini ! Grl : I love U kano;- )
# -------------------------
# ==================================================

# %%
for idx, p in enumerate(the_patterns):
    print(f'{idx:>3} {p.support_class}   {round(p.coverage*100, 1):>4}   {p.precision:.3f}   {p.get_pattern_id()}')
# Out:
#   0 Negative   26.2   0.526   [['SPACY:POS-NUM']]
#   1 Positive    7.8   0.861   [['SPACY:NER-DATE', 'SPACY:POS-NUM']]
#   2 Positive   12.6   0.641   [['SPACY:DEP-compound'], ['SPACY:POS-PROPN']]
#   3 Positive   16.3   0.542   [['SPACY:DEP-compound', 'SPACY:POS-PROPN']]
#   4 Negative   38.7   0.680   [['SPACY:DEP-compound']]
#   5 Negative   21.8   0.559   [['SPACY:DEP-compound'], ['HYPERNYM:abstraction.n.06']]
#   6 Negative   19.0   0.527   [['SPACY:NER-ORG']]
#   7 Positive    8.6   0.708   [['HYPERNYM:abstraction.n.06'], ['SPACY:POS-PROPN']]
#   8 Positive    8.7   0.694   [['SPACY:DEP-compound', 'SPACY:POS-PROPN'], ['HYPERNYM:abstraction.n.06']]
#   9 Positive   15.6   0.508   [['HYPERNYM:abstraction.n.06', 'SPACY:POS-PROPN']]
#  10 Positive    3.8   1.000   [['TEXT:call'], ['SPACY:POS-NUM']]
#  11 Negative   37.8   0.690   [['SPACY:POS-PROPN']]
#  12 Positive    7.1   0.743   [['SPACY:DEP-pobj', 'SPACY:POS-NUM']]
#  13 Negative   18.3   0.548   [['SPACY:NER-DATE']]
#  14 Positive   11.8   0.562   [['SPACY:DEP-compound'], ['SPACY:DEP-compound']]
#  15 Positive    9.8   0.618   [['TEXT:call']]
#  16 Positive    4.0   0.931   [['TEXT:to'], ['SPACY:POS-NUM']]
#  17 Negative   18.7   0.563   [['HYPERNYM:abstraction.n.06', 'SPACY:DEP-compound']]
#  18 Positive    7.1   0.710   [['HYPERNYM:entity.n.01'], ['SPACY:POS-NUM']]
#  19 Positive    6.1   0.769   [['SPACY:DEP-compound'], ['SPACY:NER-ORG']]
#  20 Positive    7.1   0.698   [['HYPERNYM:abstraction.n.06', 'SPACY:DEP-compound', 'SPACY:POS-PROPN']]
#  21 Positive    3.4   0.975   [['SPACY:DEP-pobj', 'SPACY:NER-DATE', 'SPACY:POS-NUM']]
#  22 Positive    8.0   0.652   [['SPACY:POS-PROPN'], ['SPACY:DEP-compound']]
#  23 Positive    8.2   0.637   [['HYPERNYM:entity.n.01', 'SPACY:NER-ORG']]
#  24 Negative   18.9   0.591   [['HYPERNYM:entity.n.01'], ['HYPERNYM:abstraction.n.06']]
#  25 Positive    6.3   0.695   [['SPACY:NER-ORG'], ['HYPERNYM:entity.n.01']]
#  26 Positive    4.9   0.766   [['HYPERNYM:entity.n.01'], ['HYPERNYM:abstraction.n.06', 'SPACY:POS-PROPN']]
#  27 Negative   24.4   0.648   [['HYPERNYM:communication.n.02']]
#  28 Negative   17.9   0.593   [['HYPERNYM:abstraction.n.06'], ['HYPERNYM:entity.n.01']]
#  29 Positive    9.0   0.562   [['HYPERNYM:entity.n.01'], ['SPACY:DEP-compound']]
#  30 Positive    5.4   0.719   [['SPACY:DEP-compound', 'SPACY:NER-ORG', 'SPACY:POS-PROPN']]
#  31 Positive    5.7   0.696   [['SPACY:POS-PROPN'], ['SPACY:NER-ORG']]
#  32 Positive    4.6   0.773   [['SPACY:DEP-compound'], ['SPACY:POS-PROPN'], ['HYPERNYM:entity.n.01']]
#  33 Positive    7.1   0.618   [['SPACY:DEP-compound'], ['HYPERNYM:communication.n.02']]
#  34 Positive    5.0   0.726   [['SPACY:DEP-compound'], ['SPACY:DEP-compound'], ['SPACY:POS-PROPN']]
#  35 Positive    3.4   0.861   [['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
#  36 Positive    4.1   0.793   [['HYPERNYM:entity.n.01'], ['SPACY:DEP-compound', 'SPACY:POS-PROPN']]
#  37 Negative   40.4   0.735   [['SPACY:DEP-amod']]
#  38 Negative   37.2   0.983   [['TEXT:i']]
#  39 Positive    4.4   0.756   [['SPACY:POS-SYM']]
#  40 Positive    4.5   0.748   [['TEXT:free']]
#  41 Positive    5.4   0.686   [['HYPERNYM:entity.n.01'], ['SPACY:NER-ORG']]
#  42 Positive    2.7   0.938   [['TEXT:txt']]
#  43 Positive    5.8   0.655   [['SPACY:DEP-compound'], ['HYPERNYM:abstraction.n.06', 'SPACY:DEP-compound']]
#  44 Positive    9.8   0.507   [['HYPERNYM:abstraction.n.06', 'SPACY:DEP-compound'], ['HYPERNYM:abstraction.n.06']]
#  45 Positive    2.2   1.000   [['TEXT:claim']]
#  46 Negative   16.1   0.602   [['TEXT:!']]
#  47 Negative   13.5   0.568   [['SPACY:DEP-compound'], ['SPACY:DEP-dobj']]
#  48 Negative   13.4   0.572   [['HYPERNYM:message.n.02']]
#  49 Positive    2.4   0.942   [['TEXT:mobile']]
#  50 Positive    5.6   0.640   [['SPACY:DEP-compound'], ['SPACY:DEP-compound'], ['HYPERNYM:abstraction.n.06']]
#  51 Positive    4.6   0.701   [['SPACY:DEP-compound', 'SPACY:NER-PERSON']]
#  52 Positive    3.6   0.787   [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  53 Negative   55.0   0.780   [['SPACY:DEP-pobj']]
#  54 Positive    5.2   0.658   [['SPACY:POS-NUM'], ['SPACY:DEP-compound']]
#  55 Positive    4.3   0.714   [['SPACY:DEP-dobj', 'SPACY:POS-NUM']]
#  56 Positive    4.6   0.691   [['HYPERNYM:abstraction.n.06', 'SPACY:POS-PROPN'], ['HYPERNYM:abstraction.n.06']]
#  57 Positive    3.7   0.758   [['SPACY:POS-NUM'], ['TEXT:.']]
#  58 Positive    2.9   0.838   [['HYPERNYM:transferred_property.n.01']]
#  59 Positive    6.2   0.588   [['SPACY:DEP-dobj', 'SPACY:POS-PROPN']]
#  60 Positive    4.4   0.692   [['HYPERNYM:abstraction.n.06'], ['HYPERNYM:communication.n.02']]
#  61 Negative   10.5   0.539   [['SPACY:POS-NUM'], ['HYPERNYM:entity.n.01']]
#  62 Positive    3.2   0.791   [['SPACY:DEP-dobj', 'SPACY:NER-ORG']]
#  63 Positive    2.6   0.862   [['HYPERNYM:communication.n.02'], ['SPACY:POS-PROPN']]
#  64 Positive    3.2   0.789   [['SPACY:POS-PROPN'], ['HYPERNYM:communication.n.02']]
#  65 Positive    4.1   0.701   [['HYPERNYM:entity.n.01'], ['SPACY:DEP-compound'], ['HYPERNYM:abstraction.n.06']]
#  66 Positive    4.4   0.677   [['SPACY:POS-PROPN'], ['SPACY:DEP-dobj']]
#  67 Positive    5.3   0.622   [['SPACY:POS-PROPN'], ['HYPERNYM:object.n.01']]
#  68 Negative   72.7   0.816   [['HYPERNYM:abstraction.n.06']]
#  69 Positive    2.7   0.835   [['SPACY:POS-PROPN'], ['HYPERNYM:abstraction.n.06', 'SPACY:NER-ORG']]
#  70 Positive    2.2   0.922   [['HYPERNYM:win.v.01', 'SENTIMENT:pos']]
#  71 Positive    3.3   0.756   [['SPACY:POS-PROPN'], ['HYPERNYM:abstraction.n.06', 'SPACY:DEP-compound']]
#  72 Positive    2.9   0.798   [['SPACY:DEP-compound'], ['HYPERNYM:abstraction.n.06'], ['SPACY:POS-PROPN']]
#  73 Negative    9.4   0.539   [['SPACY:NER-ORG'], ['SPACY:NER-ORG']]
#  74 Positive    4.5   0.648   [['SPACY:DEP-compound'], ['HYPERNYM:abstraction.n.06'], ['HYPERNYM:entity.n.01']]
#  75 Positive    7.0   0.524   [['SPACY:DEP-amod'], ['SPACY:DEP-compound']]
#  76 Negative   30.8   0.725   [['TEXT:to']]
#  77 Positive    5.2   0.603   [['SPACY:DEP-compound'], ['HYPERNYM:act.n.02']]
#  78 Positive    3.2   0.746   [['SPACY:NER-ORG'], ['SPACY:DEP-compound']]
#  79 Positive    1.9   0.940   [['SPACY:NER-ORG'], ['TEXT:to']]
#  80 Positive    1.6   1.000   [['TEXT:prize']]
#  81 Negative    8.7   0.531   [['TEXT:to'], ['SPACY:DEP-pobj']]
#  82 Negative   21.7   0.686   [['HYPERNYM:relation.n.01']]
#  83 Positive    2.0   0.903   [['SPACY:POS-NUM'], ['SPACY:POS-SYM']]
#  84 Negative    8.7   0.535   [['HYPERNYM:entity.n.01'], ['TEXT:to']]
#  85 Positive    2.4   0.835   [['HYPERNYM:abstraction.n.06'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  86 Positive    1.8   0.938   [['TEXT:.'], ['TEXT:call']]
#  87 Negative    9.0   0.548   [['SPACY:POS-ADJ'], ['SPACY:DEP-compound']]
#  88 Positive    3.4   0.699   [['HYPERNYM:entity.n.01', 'SPACY:DEP-compound', 'SPACY:NER-ORG']]
#  89 Negative    8.7   0.543   [['SPACY:DEP-appos']]
#  90 Positive    3.0   0.745   [['SPACY:DEP-compound'], ['SPACY:DEP-dobj', 'SPACY:POS-PROPN']]
#  91 Positive    1.8   0.923   [['HYPERNYM:communication.n.02'], ['SPACY:POS-NUM']]
#  92 Positive    5.0   0.584   [['SPACY:DEP-compound'], ['HYPERNYM:relation.n.01']]
#  93 Positive    3.3   0.703   [['SPACY:POS-PROPN'], ['SPACY:DEP-compound'], ['HYPERNYM:abstraction.n.06']]
#  94 Positive    4.4   0.614   [['TEXT:call'], ['SPACY:DEP-dobj']]
#  95 Negative   39.9   0.761   [['SENTIMENT:pos']]
#  96 Positive    2.4   0.805   [['HYPERNYM:abstraction.n.06'], ['SPACY:NER-ORG', 'SPACY:POS-PROPN']]
#  97 Negative   20.4   0.686   [['HYPERNYM:act.n.02']]
#  98 Positive    4.8   0.588   [['HYPERNYM:communication.n.02', 'SPACY:DEP-compound']]
#  99 Positive    2.0   0.863   [['SPACY:NER-ORG'], ['SPACY:POS-NUM']]

# %% [markdown]
# ## Example 2

# %% [markdown]
# - Create a custom attribute - Hypernym3 (using only hypernyms which are at most three levels above the current synset)

# %%
HYPERNYM_DICT = dict()

def _get_anvr_pos(penn_tag: str): # Return Literal['a', 'n', 'v', 'r', None]
    if penn_tag.startswith('JJ'): # Adjective
        return 'a'
    elif penn_tag.startswith('NN'): # Noun
        return 'n'
    elif penn_tag.startswith('VB'): # Verb
        return 'v'
    elif penn_tag.startswith('RB'): # Adverb
        return 'r'
    else: # Invalid wordnet type
        return None 
    
def _get_all_hypernyms(synset: nltk.corpus.reader.wordnet.Synset, above: int) -> Set[nltk.corpus.reader.wordnet.Synset]:
    if above == 0:
        return set()
    
    if (str(synset), above) not in HYPERNYM_DICT:
        ans = set()
        direct_hypernyms = synset.hypernyms() # type: List[nltk.corpus.reader.wordnet.Synset]
        for ss in direct_hypernyms:
            ans.update(_get_all_hypernyms(ss, above-1))
            ans.update(set([ss]))
        HYPERNYM_DICT[(str(synset), above)] = ans
    return HYPERNYM_DICT[(str(synset), above)]
    
def _hypernym_extraction_3(text: str, tokens: List[str]) -> List[Set[str]]:
    ans = []
    for t in nlp(text):
        pos = _get_anvr_pos(t.tag_)
        if pos is not None:
            synset = lesk(tokens, t.text, pos)
            if synset is not None:
                all_hypernyms = set([synset]) # This version of hypernym extraction includes synset of the word itself
                all_hypernyms.update(_get_all_hypernyms(synset, 3))
                ans.append(set([str(ss)[8:-2] for ss in all_hypernyms]))
            else:
                ans.append(set([]))
        else:
            ans.append(set([]))
    return ans

Hypernym3Attribute = CustomAttribute(name = 'HYPERNYM3', extraction_function = _hypernym_extraction_3)

# %%
grasp_model_2 = GrASP(gaps_allowed = 2, num_patterns = 100, include_standard = ['TEXT', 'POS', 'SENTIMENT'],
                    include_custom = [Hypernym3Attribute],
                    correlation_threshold = 0.5, alphabet_size = 100)

# %%
the_patterns_2 = grasp_model_2.fit_transform(positive, negative)
# Out:
#   1%|          | 3/488 [00:00<00:19, 25.27it/s]
# Step 1: Create augmented texts
# 100%|██████████| 488/488 [00:17<00:00, 27.74it/s]
# 100%|██████████| 3079/3079 [01:27<00:00, 35.10it/s]
# Step 2: Find frequent attributes
#   1%|          | 8/1215 [00:00<00:17, 68.54it/s]
# Total number of candidate alphabet = 1215, such as ['SPACY:POS-VERB', 'SPACY:POS-NOUN', 'SPACY:POS-PUNCT', 'SPACY:POS-PRON', 'SPACY:POS-ADV']
# Step 3: Find alphabet set
# 100%|██████████| 1215/1215 [00:29<00:00, 41.46it/s]
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finding top k: 100 / 100
# Total number of alphabet = 100
# ['SPACY:POS-NUM', 'SPACY:POS-PROPN', 'TEXT:call', 'TEXT:i', 'SPACY:POS-SYM', 'TEXT:free', 'TEXT:txt', 'TEXT:claim', 'TEXT:!', 'TEXT:mobile', 'HYPERNYM3:cost.n.01', 'SPACY:POS-ADP', 'HYPERNYM3:message.n.02', 'TEXT:to', 'TEXT:prize', 'HYPERNYM3:communication.n.02', 'HYPERNYM3:win.v.01', 'SENTIMENT:pos', 'HYPERNYM3:symbol.n.01', 'HYPERNYM3:statement.n.01', 'TEXT:your', 'SPACY:POS-ADJ', 'TEXT:or', 'TEXT:text', 'TEXT:stop', 'TEXT:-', 'TEXT:150p', 'TEXT:guaranteed', 'TEXT:urgent', 'HYPERNYM3:textbook.n.01', 'HYPERNYM3:act.n.02', 'TEXT:win', 'HYPERNYM3:oppose.v.01', 'TEXT:+', 'HYPERNYM3:written_communication.n.01', 'SPACY:POS-PRON', 'TEXT:16', 'TEXT:cash', 'HYPERNYM3:abstraction.n.06', 'TEXT:from', 'HYPERNYM3:assertion.n.01', 'TEXT:reply', 'TEXT:now', 'TEXT:.', 'TEXT:tone', 'TEXT:18', 'HYPERNYM3:acquisition.n.02', 'SPACY:POS-DET', 'TEXT:nokia', 'TEXT:a', 'HYPERNYM3:user.n.01', 'TEXT:our', 'HYPERNYM3:mobile.n.02', 'HYPERNYM3:minute.n.01', 'HYPERNYM3:person.n.01', 'HYPERNYM3:claim.v.03', 'TEXT:service', 'TEXT:contact', 'HYPERNYM3:writing.n.02', 'TEXT:for', 'TEXT:...', 'HYPERNYM3:offer.n.02', 'TEXT:awarded', 'TEXT:â£1000', 'TEXT:150ppm', 'TEXT:4', 'HYPERNYM3:request.n.01', 'TEXT:per', 'HYPERNYM3:call.v.28', 'HYPERNYM3:convey.v.03', 'HYPERNYM3:television_equipment.n.01', 'HYPERNYM3:land_line.n.01', 'TEXT:ur', 'HYPERNYM3:state.v.01', 'TEXT:camera', 'HYPERNYM3:phone.n.02', 'TEXT:rate', 'TEXT:my', 'HYPERNYM3:plastic_art.n.01', 'TEXT:latest', 'HYPERNYM3:text.n.04', 'HYPERNYM3:coding_system.n.01', 'TEXT:box', 'TEXT:draw', 'TEXT::', 'HYPERNYM3:event.n.01', 'TEXT:line', 'HYPERNYM3:free.a.01', 'TEXT:shows', 'HYPERNYM3:now.r.03', 'HYPERNYM3:declare.v.01', 'TEXT:10p', 'TEXT:collection', 'TEXT:2', 'SPACY:POS-NOUN', 'HYPERNYM3:memory_device.n.01', 'HYPERNYM3:document.n.01', 'HYPERNYM3:service.n.11', 'HYPERNYM3:equipment.n.01', 'HYPERNYM3:part.n.01']
# Example of patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Metric (global) = 0.223
# Examples ~ Class Negative:
# [MATCH]: Sorry . You never hear unless you book it . One:['SPACY:POS-NUM'] was kinda a joke -- thet were really looking for skinny white girls . The other was one line -- you can only do so much on camera with that . Something like that they 're casting on the look .
# -------------------------
# [MATCH]: Derp . Which is worse , a dude who always wants to party or a dude who files a complaint about the three:['SPACY:POS-NUM'] drug abusers he lives with
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: UR awarded a City Break and could WIN a Â£200 Summer Shopping spree every WK . Txt STORE to 88039.SkilGme:['SPACY:POS-NUM'] . TsCs087147403231Winawk!Age16+Â£1.50perWKsub
# -------------------------
# [MATCH]: You have won a Nokia 7250i:['SPACY:POS-NUM'] . This is what you get when you win our FREE auction . To take part send Nokia to 86021 now . HG / Suite342/2Lands Row / W1JHL 16 +
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN']]
# Window size: 3
# Class: Negative
# Precision: 0.690
# Match: 1347 (37.8%)
# Gain = 0.112
# Metric (global) = 0.112
# Examples ~ Class Negative:
# [MATCH]: Now press conference da:['SPACY:POS-PROPN'] : )
# -------------------------
# [MATCH]: Wat:['SPACY:POS-PROPN'] makes some people dearer is not just de happiness dat u feel when u meet them but de pain u feel when u miss dem ! ! !
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: U have won a nokia 6230 plus a free digital camera . This is what u get when u win our FREE auction . To take part send NOKIA to 83383 now . POBOX114/14TCR:['SPACY:POS-PROPN'] / W1 16
# -------------------------
# [MATCH]: Santa:['SPACY:POS-PROPN'] calling ! Would your little ones like a call from Santa Xmas Eve ? Call 09077818151 to book you time . Calls1.50ppm last 3mins 30s T&C www.santacalling.com
# -------------------------
# ==================================================
# Pattern: [['TEXT:call']]
# Window size: 3
# Class: Positive
# Precision: 0.618
# Match: 348 (9.8%)
# Gain = 0.104
# Metric (global) = 0.104
# Examples ~ Class Positive:
# [MATCH]: We currently have a message awaiting your collection . To collect your message just call:['TEXT:call'] 08718723815 .
# -------------------------
# [MATCH]: This is the 2nd attempt to contract U , you have won this weeks top prize of either Â£1000 cash or Â£200 prize . Just call:['TEXT:call'] 09066361921
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I am in tirupur .   call:['TEXT:call'] you da .
# -------------------------
# [MATCH]: 1.20 that call:['TEXT:call'] cost . Which i guess is nt bad . Miss ya , need ya , want ya , love ya
# -------------------------
# ==================================================
# Pattern: [['TEXT:i']]
# Window size: 3
# Class: Negative
# Precision: 0.983
# Match: 1327 (37.2%)
# Gain = 0.067
# Metric (global) = 0.067
# Examples ~ Class Negative:
# [MATCH]: Ok i:['TEXT:i'] also wan 2 watch e 9 pm show ...
# -------------------------
# [MATCH]: Me also da , i:['TEXT:i'] feel yesterday night   wait til 2day night dear .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Babe : U want me do nt u baby ! I:['TEXT:i'] m nasty and have a thing 4 filthyguys . Fancy a rude time with a sexy bitch . How about we go slo n hard ! Txt XXX SLO(4msgs )
# -------------------------
# [MATCH]: cmon babe , make me horny , * turn * me on ! Txt me your fantasy now babe - ) I:['TEXT:i'] m hot , sticky and need you now . All replies cost Â£1.50 . 2 cancel send STOP
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-SYM']]
# Window size: 3
# Class: Positive
# Precision: 0.756
# Match: 156 (4.4%)
# Gain = 0.067
# Metric (global) = 0.067
# Examples ~ Class Positive:
# [MATCH]: YES ! The only place in town to meet exciting adult singles is now in the UK . Txt CHAT to 86688 now ! 150p /:['SPACY:POS-SYM'] Msg .
# -------------------------
# [MATCH]: Warner Village 83118 C Colin Farrell in SWAT this wkend @Warner Village & get 1 free med . Popcorn!Just show msg+ticket@kiosk . Valid 4 -:['SPACY:POS-SYM'] 7/12 . C t&c @kiosk . Reply SONY 4 mre film offers
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Okay name ur price as long as its legal ! Wen can I pick them up ? Y u ave x:['SPACY:POS-SYM'] ams xx
# -------------------------
# [MATCH]: I 'll text you when I drop x:['SPACY:POS-SYM'] off
# -------------------------
# ==================================================
# Step 4: Grow patterns
# 100%|██████████| 100/100 [00:57<00:00,  1.73it/s]
# Length 2 / 5; New candidates = 14950
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Metric (global) = 0.223
# Examples ~ Class Negative:
# [MATCH]: Hey . What happened ? U switch off ur cell d:['SPACY:POS-NUM'] whole day . This is nt good . Now if u do care , give me a call tomorrow .
# -------------------------
# [MATCH]: Ok no problem ... Yup i 'm going to sch at 4:['SPACY:POS-NUM'] if i rem correctly ...
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: URGENT ! : Your Mobile No . was awarded a Â£2,000 Bonus Caller Prize on 02/09/03 ! This is our 2nd attempt to contact YOU ! Call 0871:['SPACY:POS-NUM'] - 872 - 9755 BOX95QU
# -------------------------
# [MATCH]: Congrats ! 1:['SPACY:POS-NUM'] year special cinema pass for 2 is yours . call 09061209465 now ! C Suprman V , Matrix3 , StarWars3 , etc all 4 FREE ! bx420-ip4 - 5we . 150pm . Do nt miss out !
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.806
# Match: 319 (8.9%)
# Gain = 0.175
# Metric (global) = 0.175
# Examples ~ Class Positive:
# [MATCH]: Thanks for your Ringtone Order , Reference T91 . You will be charged GBP:['SPACY:POS-PROPN'] 4:['SPACY:POS-NUM'] per week . You can unsubscribe at anytime by calling customer services on 09057039994
# -------------------------
# [MATCH]: Wan2 win a Meet+Greet with Westlife:['SPACY:POS-PROPN'] 4:['SPACY:POS-NUM'] U or a m8 ? They are currently on what tour ? 1)Unbreakable , 2)Untamed , 3)Unkempt . Text 1,2 or 3 to 83049 . Cost 50p + std text
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Yun:['SPACY:POS-PROPN'] ah.the ubi one:['SPACY:POS-NUM'] say if Ã¼ wan call by tomorrow.call 67441233 look for irene.ere only got bus8,22,65,61,66,382 . Ubi cres , ubi tech park.6ph for 1st 5wkg days . Ã¨n
# -------------------------
# [MATCH]: Ee msg na poortiyagi odalebeku : Hanumanji:['SPACY:POS-PROPN'] 7:['SPACY:POS-NUM'] name 1-Hanuman 2-Bajarangabali 3-Maruti 4-Pavanaputra 5-Sankatmochan 6-Ramaduth 7-Mahaveer ee 7 name   & lt;#&gt ;   janarige ivatte kalisidare next saturday olage ondu good news keluviri ... ! Maretare inde 1 dodda problum nalli siguviri idu matra   & lt;#&gt ; % true .. Do n't neglet .
# -------------------------
# ==================================================
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.984
# Match: 183 (5.1%)
# Gain = 0.152
# Metric (global) = 0.152
# Examples ~ Class Positive:
# [MATCH]: Great News ! Call:['TEXT:call'] FREEFONE 08006344447:['SPACY:POS-NUM'] to claim your guaranteed Â£1000 CASH or Â£2000 gift . Speak to a live operator NOW !
# -------------------------
# [MATCH]: Congrats ! 1 year special cinema pass for 2 is yours . call:['TEXT:call'] 09061209465:['SPACY:POS-NUM'] now ! C Suprman V , Matrix3 , StarWars3 , etc all 4 FREE ! bx420-ip4 - 5we . 150pm . Do nt miss out !
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Ummma.will call:['TEXT:call'] after check in.our:['SPACY:POS-NUM'] life will begin from qatar so pls pray very hard .
# -------------------------
# [MATCH]: I 'm in a movie . Call:['TEXT:call'] me 4:['SPACY:POS-NUM'] wat ?
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.579
# Match: 518 (14.5%)
# Gain = 0.148
# Metric (global) = 0.148
# Examples ~ Class Positive:
# [MATCH]: INTERFLORA:['SPACY:POS-PROPN'] - Â“It:['SPACY:POS-PROPN'] 's not too late to order Interflora flowers for christmas call 0800 505060 to place your order before Midnight tomorrow .
# -------------------------
# [MATCH]: Double Mins:['SPACY:POS-PROPN'] & Double Txt:['SPACY:POS-PROPN'] & 1/2 price Linerental on Latest Orange Bluetooth mobiles . Call MobileUpd8 for the very latest offers . 08000839402 or call2optout / LF56
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Sad story of a Man - Last week was my b'day . My Wife did'nt wish me . My Parents forgot n so did my Kids . I went to work . Even my Colleagues did not wish . As I entered my cabin my PA said , '' Happy B'day:['SPACY:POS-PROPN'] Boss:['SPACY:POS-PROPN'] ! ! '' . I felt special . She askd me 4 lunch . After lunch she invited me to her apartment . We went there . She said , '' do u mind if I go into the bedroom for a minute ? '' ' ' OK '' , I sed in a sexy mood . She came out 5 minuts latr wid a cake ... n My Wife , My Parents , My Kidz , My Friends n My Colleagues . All screaming .. SURPRISE ! ! and I was waiting on the sofa .. ... ..... ' NAKED ... !
# -------------------------
# [MATCH]: MY NEW:['SPACY:POS-PROPN'] YEARS:['SPACY:POS-PROPN'] EVE WAS OK . I WENT TO A PARTY WITH MY BOYFRIEND . WHO IS THIS SI THEN HEY
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.613
# Match: 421 (11.8%)
# Gain = 0.129
# Metric (global) = 0.129
# Examples ~ Class Positive:
# [MATCH]: Dear Voucher Holder , 2 claim this weeks offer , at your PC go to http://www.e-tlp.co.uk/expressoffer Ts&Cs apply.2 stop texts txt STOP to:['SPACY:POS-ADP'] 80062:['SPACY:POS-NUM'] .
# -------------------------
# [MATCH]: You have won a guaranteed Â£200 award or even Â£1000 cashto claim UR award call free on:['SPACY:POS-ADP'] 08000407165:['SPACY:POS-NUM'] ( 18 + ) 2 stop getstop on 88222 PHP . RG21 4JX
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Your opinion about:['SPACY:POS-ADP'] me ? 1:['SPACY:POS-NUM'] . Over 2 . Jada 3 . Kusruthi 4 . Lovable 5 . Silent 6 . Spl character 7 . Not matured 8 . Stylish 9 . Simple Pls reply ..
# -------------------------
# [MATCH]: Do whatever you want . You know what the rules are . We had a talk earlier this week about what had to start happening , you showing responsibility . Yet , every week it 's can i bend the rule this way ? What about that way ? Do whatever . I 'm tired of having thia same argument with you every week . And a   & lt;#&gt ;   movie DOESNT inlude the previews . You 're still getting in after:['SPACY:POS-ADP'] 1:['SPACY:POS-NUM'] .
# -------------------------
# ==================================================
# 100%|██████████| 68/68 [01:02<00:00,  1.10it/s]
# Length 3 / 5; New candidates = 13344
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
#   0%|          | 0/36 [00:00<?, ?it/s]
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Metric (global) = 0.223
# Examples ~ Class Negative:
# [MATCH]: THANX4 TODAY CER IT WAS NICE 2:['SPACY:POS-NUM'] CATCH UP BUT WE AVE 2 FIND MORE TIME MORE OFTEN OH WELL TAKE CARE C U SOON.C
# -------------------------
# [MATCH]: Hi i wo n't b ard 4:['SPACY:POS-NUM'] christmas . But do enjoy n merry x'mas .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Message Important information for O2 user . Today is your lucky day ! 2:['SPACY:POS-NUM'] find out why log onto http://www.urawinner.com there is a fantastic surprise awaiting you
# -------------------------
# [MATCH]: Your 2004:['SPACY:POS-NUM'] account for 07XXXXXXXXX shows 786 unredeemed points . To claim call 08719181259 Identifier code : XXXXX Expires 26.03.05
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.806
# Match: 319 (8.9%)
# Gain = 0.175
# Metric (global) = 0.175
# Examples ~ Class Positive:
# [MATCH]: LORD OF THE RINGS : RETURN OF THE KING in store NOW!REPLY:['SPACY:POS-PROPN'] LOTR by 2:['SPACY:POS-NUM'] June 4 Chance 2 WIN LOTR soundtrack CDs StdTxtRate . Reply STOP to end txts
# -------------------------
# [MATCH]: Hello from Orange:['SPACY:POS-PROPN'] . For 1:['SPACY:POS-NUM'] month 's free access to games , news and sport , plus 10 free texts and 20 photo messages , reply YES . Terms apply : www.orange.co.uk/ow
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Ard:['SPACY:POS-PROPN'] 6:['SPACY:POS-NUM'] like dat lor .
# -------------------------
# [MATCH]: HEY THERE BABE , HOW U DOIN ? WOT:['SPACY:POS-PROPN'] U UP 2:['SPACY:POS-NUM'] 2NITE LOVE ANNIE X.
# -------------------------
# ==================================================
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.984
# Match: 183 (5.1%)
# Gain = 0.152
# Metric (global) = 0.152
# Examples ~ Class Positive:
# [MATCH]: Congratulations ! Thanks to a good friend U have WON the Â£2,000 Xmas prize . 2 claim is easy , just call:['TEXT:call'] 08718726971:['SPACY:POS-NUM'] NOW ! Only 10p per minute . BT - national - rate .
# -------------------------
# [MATCH]: Please CALL:['TEXT:call'] 08712402902:['SPACY:POS-NUM'] immediately as there is an urgent message waiting for you .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Yun ah.the ubi one say if Ã¼ wan call:['TEXT:call'] by tomorrow.call 67441233:['SPACY:POS-NUM'] look for irene.ere only got bus8,22,65,61,66,382 . Ubi cres , ubi tech park.6ph for 1st 5wkg days . Ã¨n
# -------------------------
# [MATCH]: I 'm in a movie . Call:['TEXT:call'] me 4:['SPACY:POS-NUM'] wat ?
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.579
# Match: 518 (14.5%)
# Gain = 0.148
# Metric (global) = 0.148
# Examples ~ Class Positive:
# [MATCH]: Married local women looking for discreet action now ! 5 real matches instantly to your phone . Text:['SPACY:POS-PROPN'] MATCH:['SPACY:POS-PROPN'] to 69969 Msg cost 150p 2 stop txt stop BCMSFWC1N3XX
# -------------------------
# [MATCH]: 8007 25p 4 Alfie:['SPACY:POS-PROPN'] Moon:['SPACY:POS-PROPN'] 's Children in Need song on ur mob . Tell ur m8s . Txt TONE CHARITY to 8007 for nokias or POLY CHARITY for polys : zed 08701417012 profit 2 charity
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: MY NEW:['SPACY:POS-PROPN'] YEARS:['SPACY:POS-PROPN'] EVE WAS OK . I WENT TO A PARTY WITH MY BOYFRIEND . WHO IS THIS SI THEN HEY
# -------------------------
# [MATCH]: Haha:['SPACY:POS-PROPN'] ... Yup:['SPACY:POS-PROPN'] hopefully   we will lose a few kg by mon . after hip hop can go orchard and weigh again
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.613
# Match: 421 (11.8%)
# Gain = 0.129
# Metric (global) = 0.129
# Examples ~ Class Positive:
# [MATCH]: Got what it takes 2 take part in the WRC Rally in Oz ? U can with Lucozade Energy ! Text RALLY LE to:['SPACY:POS-ADP'] 61200:['SPACY:POS-NUM'] ( 25p ) , see packs or lucozade.co.uk/wrc & itcould be u !
# -------------------------
# [MATCH]: Dear Voucher Holder , To claim this weeks offer , at you PC please go to http://www.e-tlp.co.uk/expressoffer Ts&Cs apply . To stop texts , txt STOP to:['SPACY:POS-ADP'] 80062:['SPACY:POS-NUM']
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: From someone not to smoke when every time I 've smoked in:['SPACY:POS-ADP'] the last two:['SPACY:POS-NUM'] weeks is because of you calling or texting me that you wanted to smoke
# -------------------------
# [MATCH]: Do whatever you want . You know what the rules are . We had a talk earlier this week about what had to start happening , you showing responsibility . Yet , every week it 's can i bend the rule this way ? What about that way ? Do whatever . I 'm tired of having thia same argument with you every week . And a   & lt;#&gt ;   movie DOESNT inlude the previews . You 're still getting in after:['SPACY:POS-ADP'] 1:['SPACY:POS-NUM'] .
# -------------------------
# ==================================================
# 100%|██████████| 36/36 [00:31<00:00,  1.13it/s]
# Length 4 / 5; New candidates = 7137
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
#   0%|          | 0/5 [00:00<?, ?it/s]
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Metric (global) = 0.223
# Examples ~ Class Negative:
# [MATCH]: All boys made fun of me today . Ok i have no problem . I just sent one:['SPACY:POS-NUM'] message just for fun
# -------------------------
# [MATCH]: Me also da , i feel yesterday night   wait til 2day:['SPACY:POS-NUM'] night dear .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: FREE entry into our Â£250 weekly comp just send the word ENTER to 84128:['SPACY:POS-NUM'] NOW . 18 T&C www.textcomp.com cust care 08712405020 .
# -------------------------
# [MATCH]: Urgent ! Please call 09061743810:['SPACY:POS-NUM'] from landline . Your ABTA complimentary 4 * Tenerife Holiday or # 5000 cash await collection SAE T&Cs Box 326 CW25WX 150 ppm
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.806
# Match: 319 (8.9%)
# Gain = 0.175
# Metric (global) = 0.175
# Examples ~ Class Positive:
# [MATCH]: Married local women looking for discreet action now ! 5 real matches instantly to your phone . Text:['SPACY:POS-PROPN'] MATCH to 69969:['SPACY:POS-NUM'] Msg cost 150p 2 stop txt stop BCMSFWC1N3XX
# -------------------------
# [MATCH]: FREE for 1st week ! No1:['SPACY:POS-PROPN'] Nokia tone 4:['SPACY:POS-NUM'] ur mob every week just txt NOKIA to 8007 Get txting and tell ur mates www.getzed.co.uk POBox 36504 W45WQ norm150p / tone 16 +
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: C movie is juz last minute decision mah . Juz:['SPACY:POS-PROPN'] watch 2:['SPACY:POS-NUM'] lar but i tot Ã¼ not interested .
# -------------------------
# [MATCH]: Quite late lar ... Ard:['SPACY:POS-PROPN'] 12:['SPACY:POS-NUM'] anyway i wun b drivin ...
# -------------------------
# ==================================================
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.984
# Match: 183 (5.1%)
# Gain = 0.152
# Metric (global) = 0.152
# Examples ~ Class Positive:
# [MATCH]: This is the 2nd time we have tried to contact u. U have won the Â£1450 prize to claim just call:['TEXT:call'] 09053750005:['SPACY:POS-NUM'] b4 310303 . T&Cs / stop SMS 08718725756 . 140ppm
# -------------------------
# [MATCH]: U 447801259231 have a secret admirer who is looking 2 make contact with U - find out who they R*reveal who thinks UR so special - call:['TEXT:call'] on 09058094597:['SPACY:POS-NUM']
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Yun ah.the ubi one say if Ã¼ wan call:['TEXT:call'] by tomorrow.call 67441233:['SPACY:POS-NUM'] look for irene.ere only got bus8,22,65,61,66,382 . Ubi cres , ubi tech park.6ph for 1st 5wkg days . Ã¨n
# -------------------------
# [MATCH]: Ummma.will call:['TEXT:call'] after check in.our:['SPACY:POS-NUM'] life will begin from qatar so pls pray very hard .
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.579
# Match: 518 (14.5%)
# Gain = 0.148
# Metric (global) = 0.148
# Examples ~ Class Positive:
# [MATCH]: XMAS:['SPACY:POS-PROPN'] Prize:['SPACY:POS-PROPN'] draws ! We are trying to contact U. Todays draw shows that you have won a Â£2000 prize GUARANTEED . Call 09058094565 from land line . Valid 12hrs only
# -------------------------
# [MATCH]: < Forwarded from 21870000>Hi - this is your Mailbox:['SPACY:POS-PROPN'] Messaging:['SPACY:POS-PROPN'] SMS alert . You have 40 matches . Please call back on 09056242159 to retrieve your messages and matches cc100p / min
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: " CHEERS U:['SPACY:POS-PROPN'] TEX:['SPACY:POS-PROPN'] MECAUSE U WEREBORED ! YEAH OKDEN HUNNY R UIN WK SAT?SOUNDÂ ’S LIKEYOUR HAVIN GR8FUN J ! KEEP UPDAT COUNTINLOTS OF LOVEME XXXXX . "
# -------------------------
# [MATCH]: Haf:['SPACY:POS-PROPN'] u:['SPACY:POS-PROPN'] found him ? I feel so stupid da v cam was working .
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.613
# Match: 421 (11.8%)
# Gain = 0.129
# Metric (global) = 0.129
# Examples ~ Class Positive:
# [MATCH]: You are being ripped off ! Get your mobile content from:['SPACY:POS-ADP'] www.clubmoby.com call 08717509990:['SPACY:POS-NUM'] poly / true / Pix / Ringtones / Games six downloads for only 3
# -------------------------
# [MATCH]: ( Bank of Granite issues Strong - Buy ) EXPLOSIVE PICK FOR OUR MEMBERS * * * * * UP OVER:['SPACY:POS-ADP'] 300:['SPACY:POS-NUM'] % * * * * * * * * * * * Nasdaq Symbol CDGT That is a $ 5.00 per ..
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: And that is the problem . You walk around in " julianaland " oblivious to what is going on around you . I say the same things constantly and they go in:['SPACY:POS-ADP'] one:['SPACY:POS-NUM'] ear and out the other while you go off doing whatever you want to do . It 's not that you do n't know why I 'm upset -- it 's that you do n't listen when i tell you WHAT is going to upset me . Then you want to be surprised when I 'm mad .
# -------------------------
# [MATCH]: Your opinion about:['SPACY:POS-ADP'] me ? 1:['SPACY:POS-NUM'] . Over 2 . Jada 3 . Kusruthi 4 . Lovable 5 . Silent 6 . Spl character 7 . Not matured 8 . Stylish 9 . Simple Pls reply ..
# -------------------------
# ==================================================
# 100%|██████████| 5/5 [00:03<00:00,  1.28it/s]
# Length 5 / 5; New candidates = 994
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Metric (global) = 0.223
# Examples ~ Class Negative:
# [MATCH]: The guy ( kadeem ) has n't been selling since the break , I know one:['SPACY:POS-NUM'] other guy but he 's paranoid as fuck and does n't like selling without me there and I ca n't be up there til late tonight
# -------------------------
# [MATCH]: If u dun drive then how i go 2:['SPACY:POS-NUM'] sch .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: URGENT This is our 2nd attempt to contact U. Your Â£900 prize from YESTERDAY is still awaiting collection . To claim CALL NOW 09061702893:['SPACY:POS-NUM'] . ACL03530150PM
# -------------------------
# [MATCH]: Fantasy Football is back on your TV . Go to Sky Gamestar on Sky Active and play Â£250k Dream Team . Scoring starts on Saturday , so register now!SKY OPT OUT to 88088:['SPACY:POS-NUM']
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.806
# Match: 319 (8.9%)
# Gain = 0.175
# Metric (global) = 0.175
# Examples ~ Class Positive:
# [MATCH]: SMS AUCTION - A BRAND NEW Nokia:['SPACY:POS-PROPN'] 7250:['SPACY:POS-NUM'] is up 4 auction today ! Auction is FREE 2 join & take part ! Txt NOKIA to 86021 now !
# -------------------------
# [MATCH]: Hack Chat . Get backdoor entry into 121 chat rooms at a fraction of the cost . Reply NEO69:['SPACY:POS-PROPN'] or call 09050280520:['SPACY:POS-NUM'] , to subscribe 25p pm . DPS , Bcm box 8027 Ldn , wc1n3xx
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Just got part Nottingham:['SPACY:POS-PROPN'] - 3:['SPACY:POS-NUM'] hrs 63miles . Good thing i love my man so much , but only doing 40 mph . Hey ho
# -------------------------
# [MATCH]: WHEN THE FIRST STRIKE IS A RED:['SPACY:POS-PROPN'] ONE:['SPACY:POS-NUM'] . THE BIRD + ANTELOPE BEGIN TOPLAY IN THE FIELDOF SELFINDEPENDENCE BELIEVE THIS + THE FLOWER OF CONTENTION WILL GROW.RANDOM !
# -------------------------
# ==================================================
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.984
# Match: 183 (5.1%)
# Gain = 0.152
# Metric (global) = 0.152
# Examples ~ Class Positive:
# [MATCH]: PRIVATE ! Your 2003 Account Statement for 07815296484 shows 800 un - redeemed S.I.M. points . Call:['TEXT:call'] 08718738001:['SPACY:POS-NUM'] Identifier Code 41782 Expires 18/11/04
# -------------------------
# [MATCH]: We tried to call you re your reply to our sms for a video mobile 750 mins UNLIMITED TEXT free camcorder Reply or call:['TEXT:call'] now 08000930705:['SPACY:POS-NUM'] Del Thurs
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Yun ah.the ubi one say if Ã¼ wan call:['TEXT:call'] by tomorrow.call 67441233:['SPACY:POS-NUM'] look for irene.ere only got bus8,22,65,61,66,382 . Ubi cres , ubi tech park.6ph for 1st 5wkg days . Ã¨n
# -------------------------
# [MATCH]: I 'm in a movie . Call:['TEXT:call'] me 4:['SPACY:POS-NUM'] wat ?
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.579
# Match: 518 (14.5%)
# Gain = 0.148
# Metric (global) = 0.148
# Examples ~ Class Positive:
# [MATCH]: You have won a Nokia 7250i . This is what you get when you win our FREE auction . To take part send Nokia to 86021 now . HG:['SPACY:POS-PROPN'] / Suite342/2Lands:['SPACY:POS-PROPN'] Row / W1JHL 16 +
# -------------------------
# [MATCH]: Latest:['SPACY:POS-PROPN'] News:['SPACY:POS-PROPN'] ! Police station toilet stolen , cops have nothing to go on !
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: K:['SPACY:POS-PROPN'] , wat:['SPACY:POS-PROPN'] s tht incident ?
# -------------------------
# [MATCH]: Nothing , smsing u n xy lor . Sorry lor da:['SPACY:POS-PROPN'] guys neva:['SPACY:POS-PROPN'] c u in person but they sort of know u lor . So u wan 2 meet them xy ask me 2 bring u along 4 our next meeting .
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.613
# Match: 421 (11.8%)
# Gain = 0.129
# Metric (global) = 0.129
# Examples ~ Class Positive:
# [MATCH]: Last Chance ! Claim ur Â£150 worth of discount vouchers today ! Text SHOP to:['SPACY:POS-ADP'] 85023:['SPACY:POS-NUM'] now ! SavaMob , offers mobile ! T Cs SavaMob POBOX84 , M263UZ . Â£3.00 Sub . 16
# -------------------------
# [MATCH]: BIG BROTHER ALERT ! The computer has selected u for:['SPACY:POS-ADP'] 10k:['SPACY:POS-NUM'] cash or # 150 voucher . Call 09064018838 . NTT PO Box CRO1327 18 + BT Landline Cost 150ppm mobiles vary
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Those cocksuckers . If it makes you feel better ipads are worthless garbage novelty items and you should feel bad for:['SPACY:POS-ADP'] even wanting one:['SPACY:POS-NUM']
# -------------------------
# [MATCH]: U wake up already ? Wat u doing ? U picking us up later rite ? I 'm taking sq825 , reaching ard:['SPACY:POS-ADP'] 7:['SPACY:POS-NUM'] smth 8 like dat . U can check e arrival time . C ya soon ...
# -------------------------
# ==================================================

# %%
for idx, p in enumerate(the_patterns_2):
    print(f'Rank {idx}')
    print(p)
# Out:
# Rank 0
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Metric (global) = 0.223
# Examples ~ Class Negative:
# [MATCH]: Ãœ come lt 25:['SPACY:POS-NUM'] n pass to me lar
# -------------------------
# [MATCH]: Ill be at yours in about 3:['SPACY:POS-NUM'] mins but look out for me
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: URGENT ! We are trying to contact you . Last weekends draw shows that you have won a Â£900 prize GUARANTEED . Call 09061701851:['SPACY:POS-NUM'] . Claim code K61 . Valid 12hours only
# -------------------------
# [MATCH]: Phony Â£350 award - Todays Voda numbers ending XXXX are selected to receive a Â£350 award . If you have a match please call 08712300220:['SPACY:POS-NUM'] quoting claim code 3100 standard rates app
# -------------------------
# ==================================================
# Rank 1
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.806
# Match: 319 (8.9%)
# Gain = 0.175
# Metric (global) = 0.175
# Examples ~ Class Positive:
# [MATCH]: No 1 POLYPHONIC:['SPACY:POS-PROPN'] tone 4:['SPACY:POS-NUM'] ur mob every week ! Just txt PT2 to 87575 . 1st Tone FREE ! so get txtin now and tell ur friends . 150p / tone . 16 reply HL 4info
# -------------------------
# [MATCH]: You are being ripped off ! Get your mobile content from www.clubmoby.com call 08717509990 poly / true / Pix / Ringtones:['SPACY:POS-PROPN'] / Games six:['SPACY:POS-NUM'] downloads for only 3
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Solve d Case : A Man Was Found Murdered On   & lt;DECIMAL&gt ; . & lt;#&gt ;   AfterNoon:['SPACY:POS-PROPN'] . 1,His:['SPACY:POS-NUM'] wife called Police . 2,Police questioned everyone . 3,Wife : Sir , I was sleeping , when the murder took place . 4.Cook : I was cooking . 5.Gardener : I was picking vegetables . 6.House - Maid : I went 2 d post office . 7.Children : We went 2 play . 8.Neighbour : We went 2 a marriage . Police arrested d murderer Immediately . Who 's It ? Reply With Reason , If U r Brilliant .
# -------------------------
# [MATCH]: WE REGRET TO INFORM U THAT THE NHS HAS MADE A MISTAKE.U WERE NEVER ACTUALLY BORN.PLEASE:['SPACY:POS-PROPN'] REPORT 2:['SPACY:POS-NUM'] YOR LOCAL HOSPITAL 2B TERMINATED.WE R SORRY 4 THE INCONVENIENCE
# -------------------------
# ==================================================
# Rank 2
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.984
# Match: 183 (5.1%)
# Gain = 0.152
# Metric (global) = 0.152
# Examples ~ Class Positive:
# [MATCH]: URGENT ! We are trying to contact you . Last weekends draw shows that you have won a Â£900 prize GUARANTEED . Call:['TEXT:call'] 09061701939:['SPACY:POS-NUM'] . Claim code S89 . Valid 12hrs only
# -------------------------
# [MATCH]: Congratulations - Thanks to a good friend U have WON the Â£2,000 Xmas prize . 2 claim is easy , just call:['TEXT:call'] 08712103738:['SPACY:POS-NUM'] NOW ! Only 10p per minute . BT - national - rate
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I 'm in a movie . Call:['TEXT:call'] me 4:['SPACY:POS-NUM'] wat ?
# -------------------------
# [MATCH]: Yun ah.the ubi one say if Ã¼ wan call:['TEXT:call'] by tomorrow.call 67441233:['SPACY:POS-NUM'] look for irene.ere only got bus8,22,65,61,66,382 . Ubi cres , ubi tech park.6ph for 1st 5wkg days . Ã¨n
# -------------------------
# ==================================================
# Rank 3
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.579
# Match: 518 (14.5%)
# Gain = 0.148
# Metric (global) = 0.148
# Examples ~ Class Positive:
# [MATCH]: Urgent:['SPACY:POS-PROPN'] Urgent:['SPACY:POS-PROPN'] ! We have 800 FREE flights to Europe to give away , call B4 10th Sept & take a friend 4 FREE . Call now to claim on 09050000555 . BA128NNFWFLY150ppm
# -------------------------
# [MATCH]: Marvel:['SPACY:POS-PROPN'] Mobile:['SPACY:POS-PROPN'] Play the official Ultimate Spider - man game ( Â£4.50 ) on ur mobile right now . Text SPIDER to 83338 for the game & we ll send u a FREE 8Ball wallpaper
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Solve d Case : A Man Was Found Murdered On   & lt;DECIMAL&gt ; . & lt;#&gt ;   AfterNoon . 1,His wife called Police . 2,Police questioned everyone . 3,Wife : Sir , I was sleeping , when the murder took place . 4.Cook : I was cooking . 5.Gardener : I was picking vegetables . 6.House - Maid : I went 2 d post office . 7.Children : We went 2 play . 8.Neighbour : We went 2 a marriage . Police arrested d murderer Immediately . Who 's It ? Reply With Reason:['SPACY:POS-PROPN'] , If U:['SPACY:POS-PROPN'] r Brilliant .
# -------------------------
# [MATCH]: Meeting:['SPACY:POS-PROPN'] u:['SPACY:POS-PROPN'] is my work . . . Tel me when shall i do my work tomorrow
# -------------------------
# ==================================================
# Rank 4
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.613
# Match: 421 (11.8%)
# Gain = 0.129
# Metric (global) = 0.129
# Examples ~ Class Positive:
# [MATCH]: Eerie Nokia tones 4u , rply TONE TITLE to:['SPACY:POS-ADP'] 8007:['SPACY:POS-NUM'] eg TONE DRACULA to 8007 Titles : GHOST , ADDAMSFA , MUNSTERS , EXORCIST , TWILIGHT www.getzed.co.uk POBox36504W45WQ 150p
# -------------------------
# [MATCH]: FREE for 1st week ! No1 Nokia tone 4 ur mobile every week just txt NOKIA to:['SPACY:POS-ADP'] 8077:['SPACY:POS-NUM'] Get txting and tell ur mates . www.getzed.co.uk POBox 36504 W45WQ 16 + norm150p / tone
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: The battery is for:['SPACY:POS-ADP'] mr:['SPACY:POS-NUM'] adewale my uncle . Aka Egbon
# -------------------------
# [MATCH]: What is your record for:['SPACY:POS-ADP'] one:['SPACY:POS-NUM'] night ? :)
# -------------------------
# ==================================================
# Rank 5
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.811
# Match: 243 (6.8%)
# Gain = 0.129
# Metric (global) = 0.129
# Examples ~ Class Positive:
# [MATCH]: Ur cash - balance is currently 500 pounds - to maximize ur cash - in now send COLLECT to 83600 only 150p / msg . CC : 08718720201:['SPACY:POS-NUM'] PO:['SPACY:POS-PROPN'] BOX 114/14 TCR / W1
# -------------------------
# [MATCH]: Ur ringtone service has changed ! 25 Free credits ! Go to club4mobiles.com to choose content now ! Stop ? txt CLUB STOP to 87070 . 150p:['SPACY:POS-NUM'] / wk Club4:['SPACY:POS-PROPN'] PO Box1146 MK45 2WT
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Solve d Case : A Man Was Found Murdered On   & lt;DECIMAL&gt ; . & lt;#&gt ;   AfterNoon . 1,His:['SPACY:POS-NUM'] wife called Police:['SPACY:POS-PROPN'] . 2,Police questioned everyone . 3,Wife : Sir , I was sleeping , when the murder took place . 4.Cook : I was cooking . 5.Gardener : I was picking vegetables . 6.House - Maid : I went 2 d post office . 7.Children : We went 2 play . 8.Neighbour : We went 2 a marriage . Police arrested d murderer Immediately . Who 's It ? Reply With Reason , If U r Brilliant .
# -------------------------
# [MATCH]: Your opinion about me ? 1 . Over 2:['SPACY:POS-NUM'] . Jada:['SPACY:POS-PROPN'] 3 . Kusruthi 4 . Lovable 5 . Silent 6 . Spl character 7 . Not matured 8 . Stylish 9 . Simple Pls reply ..
# -------------------------
# ==================================================
# Rank 6
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Negative
# Precision: 0.526
# Match: 644 (18.1%)
# Gain = 0.119
# Metric (global) = 0.119
# Examples ~ Class Negative:
# [MATCH]: Yun ah.the ubi one say if Ã¼ wan call by tomorrow.call 67441233 look for irene.ere only got bus8,22,65,61,66,382:['SPACY:POS-NOUN'] . Ubi:['SPACY:POS-PROPN'] cres , ubi tech park.6ph for 1st 5wkg days . Ã¨n
# -------------------------
# [MATCH]: So many people seems to be special at first sight , But only very few will remain special to you till your last sight .. Maintain them till life ends .. take cr:['SPACY:POS-NOUN'] da:['SPACY:POS-PROPN']
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: ( Bank of Granite issues:['SPACY:POS-NOUN'] Strong:['SPACY:POS-PROPN'] - Buy ) EXPLOSIVE PICK FOR OUR MEMBERS * * * * * UP OVER 300 % * * * * * * * * * * * Nasdaq Symbol CDGT That is a $ 5.00 per ..
# -------------------------
# [MATCH]: Had your mobile 10 mths ? Update:['SPACY:POS-NOUN'] to latest Orange:['SPACY:POS-PROPN'] camera / video phones for FREE . Save Â£s with Free texts / weekend calls . Text YES for a callback orno to opt out
# -------------------------
# ==================================================
# Rank 7
# Pattern: [['TEXT:to'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.856
# Match: 194 (5.4%)
# Gain = 0.114
# Metric (global) = 0.114
# Examples ~ Class Positive:
# [MATCH]: Valentines Day Special ! Win over Â£1000 in our quiz and take your partner on the trip of a lifetime ! Send GO to:['TEXT:to'] 83600:['SPACY:POS-NUM'] now . 150p / msg rcvd . CustCare:08718720201 .
# -------------------------
# [MATCH]: 8007 FREE for 1st week ! No1 Nokia tone 4 ur mob every week just txt NOKIA to:['TEXT:to'] 8007:['SPACY:POS-NUM'] Get txting and tell ur mates www.getzed.co.uk POBox 36504 W4 5WQ norm 150p / tone 16 +
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Ugh . Got ta drive back to:['TEXT:to'] sd:['SPACY:POS-NUM'] from la . My butt is sore .
# -------------------------
# [MATCH]: Sorry about earlier . Putting out fires . Are you around to:['TEXT:to'] talk after 9:['SPACY:POS-NUM'] ? Or do you actually have a life , lol !
# -------------------------
# ==================================================
# Rank 8
# Pattern: [['SPACY:POS-PROPN']]
# Window size: 3
# Class: Negative
# Precision: 0.690
# Match: 1347 (37.8%)
# Gain = 0.112
# Metric (global) = 0.112
# Examples ~ Class Negative:
# [MATCH]: I wanted to wish you a Happy:['SPACY:POS-PROPN'] New Year and I wanted to talk to you about some legal advice to do with when Gary and I split but in person . I 'll make a trip to Ptbo for that . I hope everything is good with you babe and I love ya :)
# -------------------------
# [MATCH]: Beautiful Truth:['SPACY:POS-PROPN'] against Gravity .. Read carefully : " Our heart feels light when someone is in it .. But it feels very heavy when someone leaves it .. " GOOD NIGHT
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: URGENT:['SPACY:POS-PROPN'] ! Your Mobile No . was awarded Â£2000 Bonus Caller Prize on 5/9/03 This is our final try to contact U ! Call from Landline 09064019788 BOX42WR29C , 150PPM
# -------------------------
# [MATCH]: Dear U've been invited to XCHAT:['SPACY:POS-PROPN'] . This is our final attempt to contact u ! Txt CHAT to 86688 150p / MsgrcvdHG / Suite342/2Lands / Row / W1J6HL LDN 18 yrs
# -------------------------
# ==================================================
# Rank 9
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.702
# Match: 272 (7.6%)
# Gain = 0.105
# Metric (global) = 0.105
# Examples ~ Class Positive:
# [MATCH]: FREE2DAY sexy St George 's Day pic of Jordan!Txt PIC to 89080 do nt miss out , then every wk a saucy celeb!4 more pics:['SPACY:POS-NOUN'] c PocketBabe.co.uk:['SPACY:POS-NOUN'] 0870241182716:['SPACY:POS-NUM'] Â£3/wk
# -------------------------
# [MATCH]: Phony Â£350 award - Todays Voda numbers ending XXXX are selected to receive a Â£350 award . If you have a match please call 08712300220 quoting claim:['SPACY:POS-NOUN'] code:['SPACY:POS-NOUN'] 3100:['SPACY:POS-NUM'] standard rates app
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Your opinion about me ? 1 . Over 2 . Jada 3 . Kusruthi 4 . Lovable 5 . Silent 6 . Spl:['SPACY:POS-NOUN'] character:['SPACY:POS-NOUN'] 7:['SPACY:POS-NUM'] . Not matured 8 . Stylish 9 . Simple Pls reply ..
# -------------------------
# [MATCH]: I REALLY NEED 2 KISS U I MISS U MY BABY:['SPACY:POS-NOUN'] FROM UR BABY:['SPACY:POS-NOUN'] 4EVA:['SPACY:POS-NUM']
# -------------------------
# ==================================================
# Rank 10
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 5
# Class: Positive
# Precision: 0.722
# Match: 255 (7.1%)
# Gain = 0.104
# Metric (global) = 0.104
# Examples ~ Class Positive:
# [MATCH]: 1000 's flirting NOW ! Txt:['SPACY:POS-PROPN'] GIRL:['SPACY:POS-PROPN'] or BLOKE:['SPACY:POS-PROPN'] & ur NAME & AGE , eg GIRL ZOE 18 to 8007 to join and get chatting !
# -------------------------
# [MATCH]: Urgent ! Please call 09061743810 from landline . Your ABTA complimentary 4 * Tenerife Holiday or # 5000 cash await collection SAE:['SPACY:POS-PROPN'] T&Cs:['SPACY:POS-PROPN'] Box:['SPACY:POS-PROPN'] 326 CW25WX 150 ppm
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: HAPPY:['SPACY:POS-PROPN'] NEW YEAR MY:['SPACY:POS-PROPN'] NO.1:['SPACY:POS-PROPN'] MAN
# -------------------------
# [MATCH]: U havenÂ’t lost me ill always b here 4u.i didnÂ’t intend 2 hurt u but I never knew how u felt about me when Iwas+marine&thatÂ:['SPACY:POS-PROPN'] ’s:['SPACY:POS-PROPN'] what itried2tell urmom.i:['SPACY:POS-PROPN'] careabout u
# -------------------------
# ==================================================
# Rank 11
# Pattern: [['TEXT:.'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.797
# Match: 202 (5.7%)
# Gain = 0.101
# Metric (global) = 0.101
# Examples ~ Class Positive:
# [MATCH]: Congrats ! 1 year special cinema pass for 2 is yours .:['TEXT:.'] call 09061209465:['SPACY:POS-NUM'] now ! C Suprman V , Matrix3 , StarWars3 , etc all 4 FREE ! bx420-ip4 - 5we . 150pm . Do nt miss out !
# -------------------------
# [MATCH]: You have an important customer service announcement .:['TEXT:.'] Call FREEPHONE 0800:['SPACY:POS-NUM'] 542 0825 now !
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Hello hun how ru ? Its here by the way . I m good .:['TEXT:.'] Been on 2:['SPACY:POS-NUM'] dates with that guy i met in walkabout so far . We have to meet up soon . How s everyone else ?
# -------------------------
# [MATCH]: Yeah he got in at 2 and was v apologetic . n had fallen out and she was actin like spoilt child and he got caught up in that .:['TEXT:.'] Till 2:['SPACY:POS-NUM'] ! But we wo n't go there ! Not doing too badly cheers . You ?
# -------------------------
# ==================================================
# Rank 12
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.735
# Match: 238 (6.7%)
# Gain = 0.100
# Metric (global) = 0.100
# Examples ~ Class Positive:
# [MATCH]: Hi if ur lookin 4 saucy daytime fun wiv busty married woman Am free all next week Chat now 2:['SPACY:POS-NUM'] sort time 09099726429:['SPACY:POS-NUM'] JANINExx CallsÂ£1/minMobsmoreLKPOBOX177HP51FL
# -------------------------
# [MATCH]: You are a winner U have been specially selected 2:['SPACY:POS-NUM'] receive Â£1000:['SPACY:POS-NUM'] cash or a 4 * holiday ( flights inc ) speak to a live operator 2 claim 0871277810810
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: No dice , art class 6:['SPACY:POS-NUM'] thru 9:['SPACY:POS-NUM'] :( thanks though . Any idea what time I should come tomorrow ?
# -------------------------
# [MATCH]: U wake up already ? Thanx 4:['SPACY:POS-NUM'] e tau:['SPACY:POS-NUM'] sar piah it 's quite nice .
# -------------------------
# ==================================================
# Rank 13
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
# Window size: 4
# Class: Negative
# Precision: 0.585
# Match: 714 (20.0%)
# Gain = 0.095
# Metric (global) = 0.095
# Examples ~ Class Negative:
# [MATCH]: I wo nt . So wat:['SPACY:POS-PROPN'] 's wit:['SPACY:POS-NOUN'] the guys
# -------------------------
# [MATCH]: Missed your call cause I was yelling at scrappy . Miss:['SPACY:POS-PROPN'] u.:['SPACY:POS-NOUN'] Ca n't wait for u to come home . I 'm so lonely today .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Urgent ! Please call 0906346330 . Your ABTA complimentary 4 * Spanish Holiday:['SPACY:POS-PROPN'] or Â£10,000 cash:['SPACY:POS-NOUN'] await collection SAE T&Cs BOX 47 PO19 2EZ 150ppm 18 +
# -------------------------
# [MATCH]: 8007 25p 4 Alfie:['SPACY:POS-PROPN'] Moon 's Children:['SPACY:POS-NOUN'] in Need song on ur mob . Tell ur m8s . Txt TONE CHARITY to 8007 for nokias or POLY CHARITY for polys : zed 08701417012 profit 2 charity
# -------------------------
# ==================================================
# Rank 14
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
# Window size: 4
# Class: Positive
# Precision: 0.597
# Match: 313 (8.8%)
# Gain = 0.085
# Metric (global) = 0.085
# Examples ~ Class Positive:
# [MATCH]: Double Mins & Double Txt & 1/2:['SPACY:POS-NUM'] price Linerental on:['SPACY:POS-ADP'] Latest Orange Bluetooth mobiles . Call MobileUpd8 for the very latest offers . 08000839402 or call2optout / LF56
# -------------------------
# [MATCH]: Free entry in 2 a weekly comp for a chance to win an ipod . Txt POD to 80182 to get entry ( std txt rate ) T&C 's apply 08452810073:['SPACY:POS-NUM'] for:['SPACY:POS-ADP'] details 18 +
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Single line with a big meaning : : : : : " Miss anything 4:['SPACY:POS-NUM'] ur:['SPACY:POS-ADP'] " Best Life " but , do n't miss ur best life for anything ... Gud nyt ...
# -------------------------
# [MATCH]: From someone not to smoke when every time I 've smoked in the last two:['SPACY:POS-NUM'] weeks is because:['SPACY:POS-ADP'] of you calling or texting me that you wanted to smoke
# -------------------------
# ==================================================
# Rank 15
# Pattern: [['SPACY:POS-ADJ'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.655
# Match: 258 (7.2%)
# Gain = 0.084
# Metric (global) = 0.084
# Examples ~ Class Positive:
# [MATCH]: PRIVATE:['SPACY:POS-ADJ'] ! Your 2003:['SPACY:POS-NUM'] Account Statement for shows 800 un - redeemed S. I. M. points . Call 08718738002 Identifier Code : 48922 Expires 21/11/04
# -------------------------
# [MATCH]: Dear:['SPACY:POS-ADJ'] 0776xxxxxxx:['SPACY:POS-NUM'] U've been invited to XCHAT . This is our final attempt to contact u ! Txt CHAT to 86688 150p / MsgrcvdHG / Suite342/2Lands / Row / W1J6HL LDN 18yrs
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Hi there . We have now moved in2 our pub . Would be great:['SPACY:POS-ADJ'] 2:['SPACY:POS-NUM'] c u if u cud come up .
# -------------------------
# [MATCH]: IÂ’m cool ta luv but v.tired:['SPACY:POS-ADJ'] 2:['SPACY:POS-NUM'] cause i have been doin loads of planning all wk , we have got our social services inspection at the nursery ! Take care & spk sn x.
# -------------------------
# ==================================================
# Rank 16
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
# Window size: 5
# Class: Positive
# Precision: 0.649
# Match: 259 (7.3%)
# Gain = 0.083
# Metric (global) = 0.083
# Examples ~ Class Positive:
# [MATCH]: Hi . Customer Loyalty Offer : The NEW Nokia6650:['SPACY:POS-PROPN'] Mobile:['SPACY:POS-PROPN'] from ONLY Â£10:['SPACY:POS-NOUN'] at TXTAUCTION ! Txt word : START to No : 81151 & get yours Now ! 4T&Ctxt TC 150p / MTmsg
# -------------------------
# [MATCH]: Last Chance ! Claim ur Â£150 worth of discount vouchers today ! Text SHOP to 85023 now ! SavaMob , offers mobile ! T:['SPACY:POS-PROPN'] Cs:['SPACY:POS-PROPN'] SavaMob POBOX84:['SPACY:POS-NOUN'] , M263UZ . Â£3.00 Sub . 16
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Ryder:['SPACY:POS-PROPN'] unsold.now:['SPACY:POS-PROPN'] gibbs:['SPACY:POS-NOUN'] .
# -------------------------
# [MATCH]: THANX4:['SPACY:POS-PROPN'] TODAY:['SPACY:POS-PROPN'] CER IT:['SPACY:POS-NOUN'] WAS NICE 2 CATCH UP BUT WE AVE 2 FIND MORE TIME MORE OFTEN OH WELL TAKE CARE C U SOON.C
# -------------------------
# ==================================================
# Rank 17
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.926
# Match: 121 (3.4%)
# Gain = 0.082
# Metric (global) = 0.082
# Examples ~ Class Positive:
# [MATCH]: No . 1 Nokia Tone 4 ur mob every week ! Just txt NOK:['SPACY:POS-PROPN'] to:['SPACY:POS-ADP'] 87021:['SPACY:POS-NUM'] . 1st Tone FREE ! so get txtin now and tell ur friends . 150p / tone . 16 reply HL 4info
# -------------------------
# [MATCH]: XCLUSIVE@CLUBSAISAI 2MOROW 28/5 SOIREE SPECIALE ZOUK WITH NICHOLS:['SPACY:POS-PROPN'] FROM:['SPACY:POS-ADP'] PARIS.FREE ROSES 2:['SPACY:POS-NUM'] ALL LADIES ! ! ! info : 07946746291/07880867867
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Omg:['SPACY:POS-PROPN'] if:['SPACY:POS-ADP'] its not one:['SPACY:POS-NUM'] thing its another . My cat has worms :/ when does this bad day end ?
# -------------------------
# [MATCH]: We made it ! Eta:['SPACY:POS-PROPN'] at:['SPACY:POS-ADP'] taunton is 12:30:['SPACY:POS-NUM'] as planned , hope thatâ€˜s still okday ? ! Good to see you ! : -xx
# -------------------------
# ==================================================
# Rank 18
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]
# Window size: 4
# Class: Positive
# Precision: 0.504
# Match: 421 (11.8%)
# Gain = 0.080
# Metric (global) = 0.080
# Examples ~ Class Positive:
# [MATCH]: U were outbid by simonwatson5120:['SPACY:POS-PROPN'] on:['SPACY:POS-ADP'] the Shinco DVD Plyr . 2 bid again , visit sms . ac / smsrewards 2 end bid notifications , reply END OUT
# -------------------------
# [MATCH]: URGENT ! We are trying to contact U. Todays:['SPACY:POS-PROPN'] draw shows that:['SPACY:POS-ADP'] you have won a Â£800 prize GUARANTEED . Call 09050001808 from land line . Claim M95 . Valid12hrs only
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Bull . Your plan was to go floating off to IKEA:['SPACY:POS-PROPN'] with:['SPACY:POS-ADP'] me without a care in the world . So i have to live with your mess another day .
# -------------------------
# [MATCH]: Why you Dint:['SPACY:POS-PROPN'] come with:['SPACY:POS-ADP'] us .
# -------------------------
# ==================================================
# Rank 19
# Pattern: [['SPACY:POS-NUM'], ['TEXT:.']]
# Window size: 4
# Class: Positive
# Precision: 0.591
# Match: 286 (8.0%)
# Gain = 0.074
# Metric (global) = 0.074
# Examples ~ Class Positive:
# [MATCH]: u r subscribed 2 TEXTCOMP 250:['SPACY:POS-NUM'] wkly comp .:['TEXT:.'] 1st wk?s free question follows , subsequent wks charged@150p / msg.2 unsubscribe txt STOP 2 84128,custcare 08712405020
# -------------------------
# [MATCH]: You can donate Â£2.50 to UNICEF 's Asian Tsunami disaster support fund by texting DONATE to 864233:['SPACY:POS-NUM'] .:['TEXT:.'] Â£2.50 will be added to your next bill
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Probably money worries . Things are coming due and i have several outstanding invoices for work i did two and three:['SPACY:POS-NUM'] months ago .:['TEXT:.']
# -------------------------
# [MATCH]: Open rebtel with firefox . When it loads just put plus sign in the user name place , and it will show you two:['SPACY:POS-NUM'] numbers .:['TEXT:.'] The lower number is my number . Once you pick that number the pin will display okay !
# -------------------------
# ==================================================
# Rank 20
# Pattern: [['SPACY:POS-NOUN'], ['TEXT:call']]
# Window size: 4
# Class: Positive
# Precision: 0.791
# Match: 153 (4.3%)
# Gain = 0.073
# Metric (global) = 0.073
# Examples ~ Class Positive:
# [MATCH]: Shop till u Drop , IS IT YOU , either 10 K , 5 K , Â£500 Cash or Â£100 Travel voucher:['SPACY:POS-NOUN'] , Call:['TEXT:call'] now , 09064011000 . NTT PO Box CR01327BT fixedline Cost 150ppm mobile vary
# -------------------------
# [MATCH]: URGENT ! We are trying to contact U. Todays draw shows that you have won a Â£800 prize:['SPACY:POS-NOUN'] GUARANTEED . Call:['TEXT:call'] 09050001808 from land line . Claim M95 . Valid12hrs only
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I 'm at home:['SPACY:POS-NOUN'] . Please call:['TEXT:call']
# -------------------------
# [MATCH]: Even if he my friend he is a priest:['SPACY:POS-NOUN'] call:['TEXT:call'] him now
# -------------------------
# ==================================================
# Rank 21
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.843
# Match: 127 (3.6%)
# Gain = 0.069
# Metric (global) = 0.069
# Examples ~ Class Positive:
# [MATCH]: FREE GAME . Get Rayman:['SPACY:POS-PROPN'] Golf:['SPACY:POS-NOUN'] 4:['SPACY:POS-NUM'] FREE from the O2 Games Arcade . 1st get UR games settings . Reply POST , then save & activ8 . Press 0 key for Arcade . Termsapply
# -------------------------
# [MATCH]: Ur ringtone service has changed ! 25 Free credits ! Go to club4mobiles.com to choose content now ! Stop ? txt CLUB:['SPACY:POS-PROPN'] STOP:['SPACY:POS-NOUN'] to 87070:['SPACY:POS-NUM'] . 150p / wk Club4 PO Box1146 MK45 2WT
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Ee msg na poortiyagi odalebeku : Hanumanji:['SPACY:POS-PROPN'] 7 name:['SPACY:POS-NOUN'] 1-Hanuman:['SPACY:POS-NUM'] 2-Bajarangabali 3-Maruti 4-Pavanaputra 5-Sankatmochan 6-Ramaduth 7-Mahaveer ee 7 name   & lt;#&gt ;   janarige ivatte kalisidare next saturday olage ondu good news keluviri ... ! Maretare inde 1 dodda problum nalli siguviri idu matra   & lt;#&gt ; % true .. Do n't neglet .
# -------------------------
# [MATCH]: Once a fishrman woke early in d mrng . It was very dark . He waited a while & amp ; found a sack ful of stones . He strtd throwin thm in2 d sea 2 pass time . Atlast:['SPACY:POS-PROPN'] he had jus:['SPACY:POS-NOUN'] 1stone:['SPACY:POS-NUM'] , sun rose up & amp ; he found out tht those r nt stones , those were diamonds . Moral:"Dont wake up early in d mrng '' GOOD night
# -------------------------
# ==================================================
# Rank 22
# Pattern: [['TEXT:i']]
# Window size: 3
# Class: Negative
# Precision: 0.983
# Match: 1327 (37.2%)
# Gain = 0.067
# Metric (global) = 0.067
# Examples ~ Class Negative:
# [MATCH]: Your gon na be the death if me . I:['TEXT:i'] 'm gon na leave a note that says its all robs fault . Avenge me .
# -------------------------
# [MATCH]: Hello ! How r u ? I:['TEXT:i'] m bored . Inever thought i d get bored with the tv but I am . Tell me something exciting has happened there ? Anything ! =/
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: I:['TEXT:i'] want some cock ! My hubby 's away , I need a real man 2 satisfy me . Txt WIFE to 89938 for no strings action . ( Txt STOP 2 end , txt rec Â£1.50ea . OTBox 731 LA1 7WS . )
# -------------------------
# [MATCH]: Hey I:['TEXT:i'] am really horny want to chat or see me naked text hot to 69698 text charged at 150pm to unsubscribe text stop 69698
# -------------------------
# ==================================================
# Rank 23
# Pattern: [['SPACY:POS-SYM']]
# Window size: 3
# Class: Positive
# Precision: 0.756
# Match: 156 (4.4%)
# Gain = 0.067
# Metric (global) = 0.067
# Examples ~ Class Positive:
# [MATCH]: You have won a guaranteed 32000 award or maybe even Â£1000 cash to claim ur award call free on 0800 ..... ( 18 +:['SPACY:POS-SYM'] ) . Its a legitimat efreefone number wat do u think ? ? ?
# -------------------------
# [MATCH]: Do you want a New Nokia 3510i Colour Phone Delivered Tomorrow ? With 200 FREE minutes to any mobile +:['SPACY:POS-SYM'] 100 FREE text + FREE camcorder Reply or Call 08000930705
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: What i mean was i left too early to check , cos i 'm working a 9 -:['SPACY:POS-SYM'] 6 .
# -------------------------
# [MATCH]: Er yeah , i will b there at 15:26 , sorry ! Just tell me which pub /:['SPACY:POS-SYM'] cafe to sit in and come wen u can
# -------------------------
# ==================================================
# Rank 24
# Pattern: [['TEXT:free']]
# Window size: 3
# Class: Positive
# Precision: 0.748
# Match: 159 (4.5%)
# Gain = 0.067
# Metric (global) = 0.067
# Examples ~ Class Positive:
# [MATCH]: Had your contract mobile 11 Mnths ? Latest Motorola , Nokia etc . all FREE:['TEXT:free'] ! Double Mins & Text on Orange tariffs . TEXT YES for callback , no to remove from records .
# -------------------------
# [MATCH]: Get ur 1st RINGTONE FREE:['TEXT:free'] NOW ! Reply to this msg with TONE . Gr8 TOP 20 tones to your phone every week just Â£1.50 per wk 2 opt out send STOP 08452810071 16
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Ok . There may be a free:['TEXT:free'] gym about .
# -------------------------
# [MATCH]: Forgot you were working today ! Wanna chat , but things are ok so drop me a text when you 're free:['TEXT:free'] / bored etc and i 'll ring . Hope all is well , nose essay and all xx
# -------------------------
# ==================================================
# Rank 25
# Pattern: [['TEXT:txt']]
# Window size: 3
# Class: Positive
# Precision: 0.938
# Match: 96 (2.7%)
# Gain = 0.067
# Metric (global) = 0.067
# Examples ~ Class Positive:
# [MATCH]: No 1 POLYPHONIC tone 4 ur mob every week ! Just txt:['TEXT:txt'] PT2 to 87575 . 1st Tone FREE ! so get txtin now and tell ur friends . 150p / tone . 16 reply HL 4info
# -------------------------
# [MATCH]: Download as many ringtones as u like no restrictions , 1000s 2 choose . U can even send 2 yr buddys . Txt:['TEXT:txt'] Sir to 80082 Â£3
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: On the road so ca nt txt:['TEXT:txt']
# -------------------------
# [MATCH]: I love u 2 babe ! R u sure everything is alrite . Is he being an idiot ? Txt:['TEXT:txt'] bak girlie
# -------------------------
# ==================================================
# Rank 26
# Pattern: [['SPACY:POS-NOUN'], ['TEXT:to']]
# Window size: 4
# Class: Negative
# Precision: 0.591
# Match: 552 (15.5%)
# Gain = 0.065
# Metric (global) = 0.065
# Examples ~ Class Negative:
# [MATCH]: We have sent JD for Customer Service cum:['SPACY:POS-NOUN'] Accounts Executive to:['TEXT:to'] ur mail i d , For details contact us
# -------------------------
# [MATCH]: U gd lor go shopping i got stuff:['SPACY:POS-NOUN'] to:['TEXT:to'] do . U wan 2 watch infernal affairs a not ? Come lar ...
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: You have won ? 1,000 cash or a ? 2,000 prize:['SPACY:POS-NOUN'] ! To:['TEXT:to'] claim , call09050000327 . T&C : RSTM , SW7 3SS . 150ppm
# -------------------------
# [MATCH]: -PLS STOP bootydelious ( 32/F ) is inviting you to be her friend . Reply YES-434 or NO-434 See her : www . SMS.ac / u / bootydelious STOP ? Send STOP:['SPACY:POS-NOUN'] FRND to:['TEXT:to'] 62468
# -------------------------
# ==================================================
# Rank 27
# Pattern: [['TEXT:claim']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 77 (2.2%)
# Gain = 0.064
# Metric (global) = 0.064
# Examples ~ Class Positive:
# [MATCH]: You have won a guaranteed 32000 award or maybe even Â£1000 cash to claim:['TEXT:claim'] ur award call free on 0800 ..... ( 18 + ) . Its a legitimat efreefone number wat do u think ? ? ?
# -------------------------
# [MATCH]: UR GOING 2 BAHAMAS ! CallFREEFONE 08081560665 and speak to a live operator to claim:['TEXT:claim'] either Bahamas cruise ofÂ£2000 CASH 18+only . To opt out txt X to 07786200117
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Rank 28
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-ADP', 'TEXT:to']]
# Window size: 4
# Class: Positive
# Precision: 0.592
# Match: 250 (7.0%)
# Gain = 0.064
# Metric (global) = 0.064
# Examples ~ Class Positive:
# [MATCH]: we tried to contact you re your response:['SPACY:POS-NOUN'] to:['TEXT:to', 'SPACY:POS-ADP'] our offer of a new nokia fone and camcorder hit reply or call 08000930705 for delivery
# -------------------------
# [MATCH]: Hey I am really horny want to chat or see me naked text:['SPACY:POS-NOUN'] hot to:['TEXT:to', 'SPACY:POS-ADP'] 69698 text charged at 150pm to unsubscribe text stop 69698
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I only work from mon:['SPACY:POS-NOUN'] to:['TEXT:to', 'SPACY:POS-ADP'] thurs but Sat i ca nt leh ... Booked liao ... Which other day u free ?
# -------------------------
# [MATCH]: Kindly send some one:['SPACY:POS-NOUN'] to:['TEXT:to', 'SPACY:POS-ADP'] our flat before   & lt;DECIMAL&gt ;   today .
# -------------------------
# ==================================================
# Rank 29
# Pattern: [['TEXT:!']]
# Window size: 3
# Class: Negative
# Precision: 0.602
# Match: 575 (16.1%)
# Gain = 0.063
# Metric (global) = 0.063
# Examples ~ Class Negative:
# [MATCH]: Me too baby !:['TEXT:!'] I promise to treat you well ! I bet you will take good care of me ...
# -------------------------
# [MATCH]: Aww that 's the first time u said u missed me without asking if I missed u first . You DO love me !:['TEXT:!'] :)
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Your next amazing xxx PICSFREE1 video will be sent to you enjoy !:['TEXT:!'] If one vid is not enough for 2day text back the keyword PICSFREE1 to get the next video .
# -------------------------
# [MATCH]: SMS AUCTION - A BRAND NEW Nokia 7250 is up 4 auction today !:['TEXT:!'] Auction is FREE 2 join & take part ! Txt NOKIA to 86021 now !
# -------------------------
# ==================================================
# Rank 30
# Pattern: [['TEXT:.'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.539
# Match: 297 (8.3%)
# Gain = 0.062
# Metric (global) = 0.062
# Examples ~ Class Positive:
# [MATCH]: WINNER ! ! As a valued network customer you have been selected to receivea Â£900 prize reward ! To claim call 09061701461 .:['TEXT:.'] Claim code KL341:['SPACY:POS-PROPN'] . Valid 12 hours only .
# -------------------------
# [MATCH]: Sunshine Quiz Wkly Q ! Win a top Sony DVD player if u know which country Liverpool played in mid week ? Txt ansr to 82277 .:['TEXT:.'] Â£1.50 SP:['SPACY:POS-PROPN'] : Tyrone
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Yar i wanted 2 scold u yest but late already ... I where got zhong se qing you ? If u ask me b4 he ask me then i 'll go out w u all lor .:['TEXT:.'] N:['SPACY:POS-PROPN'] u still can act so real .
# -------------------------
# [MATCH]: Macha do nt feel upset.i can assume your mindset.believe me one evening with me and i have some wonderful plans for both of us .:['TEXT:.'] LET LIFE:['SPACY:POS-PROPN'] BEGIN AGAIN.call me anytime
# -------------------------
# ==================================================
# Rank 31
# Pattern: [['SPACY:POS-PROPN'], ['TEXT:.']]
# Window size: 4
# Class: Positive
# Precision: 0.522
# Match: 312 (8.7%)
# Gain = 0.061
# Metric (global) = 0.061
# Examples ~ Class Positive:
# [MATCH]: I do n't know u and u do n't know me . Send CHAT to 86688 now and let 's find each other ! Only 150p / Msg:['SPACY:POS-PROPN'] rcvd .:['TEXT:.'] HG / Suite342/2Lands / Row / W1J6HL LDN . 18 years or over .
# -------------------------
# [MATCH]: Hack Chat:['SPACY:POS-PROPN'] .:['TEXT:.'] Get backdoor entry into 121 chat rooms at a fraction of the cost . Reply NEO69 or call 09050280520 , to subscribe 25p pm . DPS , Bcm box 8027 Ldn , wc1n3xx
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: As per your request ' Melle Melle ( Oru Minnaminunginte Nurungu Vettam ) ' has been set as your callertune for all Callers:['SPACY:POS-PROPN'] .:['TEXT:.'] Press * 9 to copy your friends Callertune
# -------------------------
# [MATCH]: Oh ya ya . I remember da:['SPACY:POS-PROPN'] .:['TEXT:.'] .
# -------------------------
# ==================================================
# Rank 32
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 5
# Class: Positive
# Precision: 0.624
# Match: 213 (6.0%)
# Gain = 0.061
# Metric (global) = 0.061
# Examples ~ Class Positive:
# [MATCH]: Ur balance is now Â£600 . Next question : Complete the landmark , Big , A.:['SPACY:POS-NOUN'] Bob:['SPACY:POS-PROPN'] , B.:['SPACY:POS-PROPN'] Barry or C. Ben ? . Text A , B or C to 83738 . Good luck !
# -------------------------
# [MATCH]: Got what it takes 2 take part:['SPACY:POS-NOUN'] in the WRC:['SPACY:POS-PROPN'] Rally:['SPACY:POS-PROPN'] in Oz ? U can with Lucozade Energy ! Text RALLY LE to 61200 ( 25p ) , see packs or lucozade.co.uk/wrc & itcould be u !
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: THATÂ:['SPACY:POS-NOUN'] ’S ALRITE:['SPACY:POS-PROPN'] GIRL:['SPACY:POS-PROPN'] , U KNOW GAIL IS NEVA WRONG!!TAKE CARE SWEET AND DONÂ’T WORRY.C U L8TR HUN!LOVE Yaxxx
# -------------------------
# [MATCH]: HIYA COMIN 2 BRISTOL 1 ST WEEK:['SPACY:POS-NOUN'] IN APRIL:['SPACY:POS-PROPN'] . LES:['SPACY:POS-PROPN'] GOT OFF + RUDI ON NEW YRS EVE BUT I WAS SNORING.THEY WERE DRUNK ! U BAK AT COLLEGE YET ? MY WORK SENDS INK 2 BATH .
# -------------------------
# ==================================================
# Rank 33
# Pattern: [['TEXT:mobile']]
# Window size: 3
# Class: Positive
# Precision: 0.942
# Match: 86 (2.4%)
# Gain = 0.060
# Metric (global) = 0.060
# Examples ~ Class Positive:
# [MATCH]: FREE MSG : We billed your mobile:['TEXT:mobile'] number by mistake from shortcode 83332.Please call 08081263000 to have charges refunded . This call will be free from a BT landline
# -------------------------
# [MATCH]: Sex up ur mobile:['TEXT:mobile'] with a FREE sexy pic of Jordan ! Just text BABE to 88600 . Then every wk get a sexy celeb ! PocketBabe.co.uk 4 more pics . 16 Â£3/wk 087016248
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Plz note : if anyone calling from a mobile:['TEXT:mobile'] Co. & amp ; asks u to type # & lt;#&gt ;   or # & lt;#&gt ; . Do not do so . Disconnect the call , coz it iz an attempt of ' terrorist ' to make use of the sim card no . Itz confirmd by nokia n motorola n has been verified by CNN IBN .
# -------------------------
# [MATCH]: Hi , Mobile:['TEXT:mobile'] no .   & lt;#&gt ;   has added you in their contact list on www.fullonsms.com It s a great place to send free sms to people For more visit fullonsms.com
# -------------------------
# ==================================================
# Rank 34
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
# Window size: 5
# Class: Positive
# Precision: 0.591
# Match: 235 (6.6%)
# Gain = 0.060
# Metric (global) = 0.060
# Examples ~ Class Positive:
# [MATCH]: Sunshine Hols . To claim ur med holiday send a stamped self:['SPACY:POS-NOUN'] address:['SPACY:POS-NOUN'] envelope to Drinks:['SPACY:POS-PROPN'] on Us UK , PO Box 113 , Bray , Wicklow , Eire . Quiz Starts Saturday ! Unsub Stop
# -------------------------
# [MATCH]: PRIVATE ! Your 2003 Account Statement for 07973788240 shows 800 un - redeemed S. I. M. points:['SPACY:POS-NOUN'] . Call:['SPACY:POS-NOUN'] 08715203649 Identifier:['SPACY:POS-PROPN'] Code : 40533 Expires 31/10/04
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Do u konw waht is rael FRIENDSHIP I m gving yuo an exmpel : Jsut ese tihs msg .. Evrey splleing of tihs msg is wrnog .. Bt sitll yuo can raed it wihtuot:['SPACY:POS-NOUN'] ayn:['SPACY:POS-NOUN'] mitsake .. GOODNIGHT:['SPACY:POS-PROPN'] & amp ; HAVE A NICE SLEEP .. SWEET DREAMS ..
# -------------------------
# [MATCH]: Am going to take bath ill place:['SPACY:POS-NOUN'] the key:['SPACY:POS-NOUN'] in window:-:['SPACY:POS-PROPN'] )
# -------------------------
# ==================================================
# Rank 35
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]
# Window size: 5
# Class: Positive
# Precision: 0.739
# Match: 142 (4.0%)
# Gain = 0.058
# Metric (global) = 0.058
# Examples ~ Class Positive:
# [MATCH]: 25p 4 alfie Moon 's Children in need song on ur mob . Tell ur m8s . Txt:['SPACY:POS-PROPN'] Tone:['SPACY:POS-PROPN'] charity to:['SPACY:POS-ADP'] 8007 for Nokias or Poly charity for polys : zed 08701417012 profit 2 charity .
# -------------------------
# [MATCH]: Fantasy:['SPACY:POS-PROPN'] Football:['SPACY:POS-PROPN'] is back on:['SPACY:POS-ADP'] your TV . Go to Sky Gamestar on Sky Active and play Â£250k Dream Team . Scoring starts on Saturday , so register now!SKY OPT OUT to 88088
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: TODAY is Sorry day . ! If ever i was angry with you , if ever i misbehaved or hurt you ? plz plz JUST SLAP URSELF:['SPACY:POS-PROPN'] Bcoz:['SPACY:POS-PROPN'] , Its ur:['SPACY:POS-ADP'] fault , I 'm basically GOOD
# -------------------------
# [MATCH]: Kaiez:['SPACY:POS-PROPN'] ... Enjoy:['SPACY:POS-PROPN'] ur:['SPACY:POS-ADP'] tuition ... Gee ... Thk e second option sounds beta ... I 'll go yan jiu den msg u ...
# -------------------------
# ==================================================
# Rank 36
# Pattern: [['SPACY:POS-ADJ'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Negative
# Precision: 0.530
# Match: 368 (10.3%)
# Gain = 0.057
# Metric (global) = 0.057
# Examples ~ Class Negative:
# [MATCH]: I will take care of financial:['SPACY:POS-ADJ'] problem.i:['SPACY:POS-PROPN'] will help : )
# -------------------------
# [MATCH]: NOT MUCH:['SPACY:POS-ADJ'] NO FIGHTS:['SPACY:POS-PROPN'] . IT WAS A GOOD NITE ! !
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: XCLUSIVE@CLUBSAISAI 2MOROW 28/5 SOIREE SPECIALE ZOUK:['SPACY:POS-ADJ'] WITH NICHOLS:['SPACY:POS-PROPN'] FROM PARIS.FREE ROSES 2 ALL LADIES ! ! ! info : 07946746291/07880867867
# -------------------------
# [MATCH]: Good:['SPACY:POS-ADJ'] Luck:['SPACY:POS-PROPN'] ! Draw takes place 28th Feb 06 . Good Luck ! For removal send STOP to 87239 customer services 08708034412
# -------------------------
# ==================================================
# Rank 37
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-ADJ']]
# Window size: 4
# Class: Positive
# Precision: 0.559
# Match: 245 (6.9%)
# Gain = 0.055
# Metric (global) = 0.055
# Examples ~ Class Positive:
# [MATCH]: Had your contract mobile 11:['SPACY:POS-NUM'] Mnths ? Latest:['SPACY:POS-ADJ'] Motorola , Nokia etc . all FREE ! Double Mins & Text on Orange tariffs . TEXT YES for callback , no to remove from records .
# -------------------------
# [MATCH]: Todays Voda numbers ending 5226 are selected to receive a ? 350 award . If you hava a match please call 08712300220 quoting claim code 1131:['SPACY:POS-NUM'] standard:['SPACY:POS-ADJ'] rates app
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Your opinion about me ? 1 . Over 2 . Jada 3 . Kusruthi 4:['SPACY:POS-NUM'] . Lovable:['SPACY:POS-ADJ'] 5 . Silent 6 . Spl character 7 . Not matured 8 . Stylish 9 . Simple Pls reply ..
# -------------------------
# [MATCH]: U gd lor go shopping i got stuff to do . U wan 2:['SPACY:POS-NUM'] watch infernal:['SPACY:POS-ADJ'] affairs a not ? Come lar ...
# -------------------------
# ==================================================
# Rank 38
# Pattern: [['SENTIMENT:pos'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.542
# Match: 260 (7.3%)
# Gain = 0.054
# Metric (global) = 0.054
# Examples ~ Class Positive:
# [MATCH]: URGENT ! Your mobile number * * * * * * * * * * * * * * * WON:['SENTIMENT:pos'] a Â£2000 Bonus:['SPACY:POS-PROPN'] Caller prize on 10/06/03 ! This is the 2nd attempt to reach you ! Call 09066368753 ASAP ! Box 97N7QP , 150ppm
# -------------------------
# [MATCH]: Urgent UR awarded a complimentary:['SENTIMENT:pos'] trip to EuroDisinc:['SPACY:POS-PROPN'] Trav , Aco&Entry41 Or Â£1000 . To claim txt DIS to 87121 18 + 6*Â£1.50(moreFrmMob . ShrAcomOrSglSuplt)10 , LS1 3AJ
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Your opinion about me ? 1 . Over 2 . Jada 3 . Kusruthi 4 . Lovable:['SENTIMENT:pos'] 5 . Silent:['SPACY:POS-PROPN'] 6 . Spl character 7 . Not matured 8 . Stylish 9 . Simple Pls reply ..
# -------------------------
# [MATCH]: Do u konw waht is rael FRIENDSHIP I m gving yuo an exmpel : Jsut ese tihs msg .. Evrey splleing of tihs msg is wrnog .. Bt sitll yuo can raed it wihtuot ayn mitsake .. GOODNIGHT & amp ; HAVE A NICE:['SENTIMENT:pos'] SLEEP .. SWEET:['SPACY:POS-PROPN'] DREAMS ..
# -------------------------
# ==================================================
# Rank 39
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.802
# Match: 111 (3.1%)
# Gain = 0.053
# Metric (global) = 0.053
# Examples ~ Class Positive:
# [MATCH]: FREE for 1st week ! No1 Nokia tone 4 ur mobile every week just txt NOKIA to 8077 Get txting and tell ur mates . www.getzed.co.uk POBox:['SPACY:POS-NOUN'] 36504 W45WQ:['SPACY:POS-PROPN'] 16:['SPACY:POS-NUM'] + norm150p / tone
# -------------------------
# [MATCH]: Your 2004 account for 07XXXXXXXXX shows 786 unredeemed points . To claim call 08719181259 Identifier code:['SPACY:POS-NOUN'] : XXXXX:['SPACY:POS-PROPN'] Expires 26.03.05:['SPACY:POS-NUM']
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: " BOO BABE ! U ENJOYIN YOURJOB:['SPACY:POS-NOUN'] ? U:['SPACY:POS-PROPN'] SEEMED 2:['SPACY:POS-NUM'] B GETTIN ON WELL HUNNY!HOPE URE OK?TAKE CARE & IÂ’LLSPEAK 2U SOONLOTS OF LOVEME XXXX . "
# -------------------------
# [MATCH]: After my work:['SPACY:POS-NOUN'] ah ... Den:['SPACY:POS-PROPN'] 6:['SPACY:POS-NUM'] plus lor ... U workin oso rite ... Den go orchard lor , no other place to go liao ...
# -------------------------
# ==================================================
# Rank 40
# Pattern: [['TEXT:.'], ['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.985
# Match: 67 (1.9%)
# Gain = 0.053
# Metric (global) = 0.053
# Examples ~ Class Positive:
# [MATCH]: PRIVATE ! Your 2003 Account Statement for shows 800 un - redeemed S.I.M. points .:['TEXT:.'] Call:['TEXT:call'] 08715203685:['SPACY:POS-NUM'] Identifier Code:4xx26 Expires 13/10/04
# -------------------------
# [MATCH]: I 'd like to tell you my deepest darkest fantasies .:['TEXT:.'] Call:['TEXT:call'] me 09094646631:['SPACY:POS-NUM'] just 60p / min . To stop texts call 08712460324 ( nat rate )
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I 'm in a movie .:['TEXT:.'] Call:['TEXT:call'] me 4:['SPACY:POS-NUM'] wat ?
# -------------------------
# ==================================================
# Rank 41
# Pattern: [['HYPERNYM3:communication.n.02'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.923
# Match: 78 (2.2%)
# Gain = 0.052
# Metric (global) = 0.052
# Examples ~ Class Positive:
# [MATCH]: Do you want a New Nokia 3510i Colour Phone Delivered Tomorrow ? With 200 FREE minutes to any mobile + 100 FREE text + FREE camcorder Reply:['HYPERNYM3:communication.n.02'] or Call 08000930705:['SPACY:POS-NUM']
# -------------------------
# [MATCH]: Auction round 4 . The highest bid is now Â£54 . Next maximum bid is Â£71 . To bid , send BIDS:['HYPERNYM3:communication.n.02'] e. g. 10:['SPACY:POS-NUM'] ( to bid Â£10 ) to 83383 . Good luck .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Oh god i am happy to see your message:['HYPERNYM3:communication.n.02'] after 3:['SPACY:POS-NUM'] days
# -------------------------
# [MATCH]: Hi mate its RV did u hav a nice hol just a message:['HYPERNYM3:communication.n.02'] 3:['SPACY:POS-NUM'] say hello coz havenÂ’t sent u 1 in ages started driving so stay off roads!RVx
# -------------------------
# ==================================================
# Rank 42
# Pattern: [['HYPERNYM3:win.v.01', 'SENTIMENT:pos']]
# Window size: 3
# Class: Positive
# Precision: 0.922
# Match: 77 (2.2%)
# Gain = 0.051
# Metric (global) = 0.051
# Examples ~ Class Positive:
# [MATCH]: You have won:['HYPERNYM3:win.v.01', 'SENTIMENT:pos'] ? 1,000 cash or a ? 2,000 prize ! To claim , call09050000327 . T&C : RSTM , SW7 3SS . 150ppm
# -------------------------
# [MATCH]: This is the 2nd time we have tried to contact u. U have won:['HYPERNYM3:win.v.01', 'SENTIMENT:pos'] the Â£400 prize . 2 claim is easy , just call 087104711148 NOW ! Only 10p per minute . BT - national - rate
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: New Theory : Argument wins:['HYPERNYM3:win.v.01', 'SENTIMENT:pos'] d SITUATION , but loses the PERSON . So do nt argue with ur friends just .. . . . kick them & amp ; say , I 'm always correct . !
# -------------------------
# ...
# -------------------------
# ==================================================
# Rank 86
# Pattern: [['SENTIMENT:pos'], ['TEXT:call']]
# Window size: 4
# Class: Positive
# Precision: 0.838
# Match: 74 (2.1%)
# Gain = 0.039
# Metric (global) = 0.039
# Examples ~ Class Positive:
# [MATCH]: Had your mobile 11 months or more ? U R entitled to Update to the latest colour mobiles with camera for Free:['SENTIMENT:pos'] ! Call:['TEXT:call'] The Mobile Update Co FREE on 08002986030
# -------------------------
# [MATCH]: HOT:['SENTIMENT:pos'] LIVE FANTASIES call:['TEXT:call'] now 08707509020 Just 20p per min NTT Ltd , PO Box 1327 Croydon CR9 5WB 0870 is a national rate call
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I 'm at work:['SENTIMENT:pos'] . Please call:['TEXT:call']
# -------------------------
# [MATCH]: Hey now am free:['SENTIMENT:pos'] you can call:['TEXT:call'] me .
# -------------------------
# ==================================================
# Rank 87
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.868
# Match: 68 (1.9%)
# Gain = 0.038
# Metric (global) = 0.038
# Examples ~ Class Positive:
# [MATCH]: For taking part in our mobile survey yesterday ! You can now have 500 texts 2 use however you wish . 2 get txts just send TXT to 80160:['SPACY:POS-NUM'] T&C:['SPACY:POS-PROPN'] www.txt43.com 1.50p:['SPACY:POS-NUM']
# -------------------------
# [MATCH]: 500:['SPACY:POS-NUM'] New:['SPACY:POS-PROPN'] Mobiles from 2004:['SPACY:POS-NUM'] , MUST GO ! Txt : NOKIA to No : 89545 & collect yours today!From ONLY Â£1 www.4-tc.biz 2optout 087187262701.50gbp / mtmsg18
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: HOW ARE U ? I HAVE MISSED U ! I HAVENT BEEN UP 2 MUCH A BIT BORED WITH THE HOLIDAY WANT 2:['SPACY:POS-NUM'] GO:['SPACY:POS-PROPN'] BAK 2:['SPACY:POS-NUM'] COLLEGE ! SAD ISNT IT?xx
# -------------------------
# [MATCH]: Your opinion about me ? 1 . Over 2:['SPACY:POS-NUM'] . Jada:['SPACY:POS-PROPN'] 3:['SPACY:POS-NUM'] . Kusruthi 4 . Lovable 5 . Silent 6 . Spl character 7 . Not matured 8 . Stylish 9 . Simple Pls reply ..
# -------------------------
# ==================================================
# Rank 88
# Pattern: [['HYPERNYM3:symbol.n.01']]
# Window size: 3
# Class: Positive
# Precision: 0.764
# Match: 89 (2.5%)
# Gain = 0.038
# Metric (global) = 0.038
# Examples ~ Class Positive:
# [MATCH]: Moby Pub Quiz . Win a Â£100 High Street prize:['HYPERNYM3:symbol.n.01'] if u know who the new Duchess of Cornwall will be ? Txt her first name to 82277.unsub STOP Â£1.50 008704050406 SP Arrow
# -------------------------
# [MATCH]: URGENT ! Your Mobile number has been awarded with a Â£2000 prize:['HYPERNYM3:symbol.n.01'] GUARANTEED . Call 09061790121 from land line . Claim 3030 . Valid 12hrs only 150ppm
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Lol ! Nah was n't too bad thanks . Its good to b home but its been quite a reality check:['HYPERNYM3:symbol.n.01'] . How s ur day been ? Did u do anything with website ?
# -------------------------
# [MATCH]: Genius what 's up . How your brother . Pls send his number:['HYPERNYM3:symbol.n.01'] to my skype .
# -------------------------
# ==================================================
# Rank 89
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
# Window size: 5
# Class: Positive
# Precision: 0.543
# Match: 184 (5.2%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: U can WIN Â£100 of Music Gift Vouchers every week starting NOW Txt the word DRAW to:['SPACY:POS-ADP'] 87066:['SPACY:POS-NUM'] TsCs www:['SPACY:POS-NOUN'] . Idew.com SkillGame , 1Winaweek , age16 . 150ppermessSubscription
# -------------------------
# [MATCH]: FREE for 1st week ! No1 Nokia tone 4 ur mobile every week just txt NOKIA to:['SPACY:POS-ADP'] 8077:['SPACY:POS-NUM'] Get txting:['SPACY:POS-NOUN'] and tell ur mates . www.getzed.co.uk POBox 36504 W45WQ 16 + norm150p / tone
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Eat jap done oso aft ur lect wat ... Ãœ got lect at:['SPACY:POS-ADP'] 12:['SPACY:POS-NUM'] rite:['SPACY:POS-NOUN'] ...
# -------------------------
# [MATCH]: Is xy:['SPACY:POS-ADP'] going 4:['SPACY:POS-NUM'] e:['SPACY:POS-NOUN'] lunch ?
# -------------------------
# ==================================================
# Rank 90
# Pattern: [['TEXT:!'], ['SPACY:POS-ADJ']]
# Window size: 4
# Class: Positive
# Precision: 0.648
# Match: 125 (3.5%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: You are guaranteed the latest Nokia Phone , a 40 GB iPod MP3 player or a Â£500 prize !:['TEXT:!'] Txt:['SPACY:POS-ADJ'] word : COLLECT to No : 83355 ! IBHltd LdnW15H 150p / Mtmsgrcvd18 +
# -------------------------
# [MATCH]: PRIVATE !:['TEXT:!'] Your:['SPACY:POS-ADJ'] 2003 Account Statement for shows 800 un - redeemed S.I.M. points . Call 08715203685 Identifier Code:4xx26 Expires 13/10/04
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Hiya . How was last night ? I 've been naughty and bought myself clothes and very little ... Ready for more shopping tho !:['TEXT:!'] What:['SPACY:POS-ADJ'] kind of time do you wanna meet ?
# -------------------------
# [MATCH]: Mmmm ... Fuck ... Not fair !:['TEXT:!'] You know my:['SPACY:POS-ADJ'] weaknesses ! * grins * * pushes you to your knee 's * * exposes my belly and pulls your head to it * Do n't forget ... I know yours too * wicked smile *
# -------------------------
# ==================================================
# Rank 91
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
# Window size: 6
# Class: Positive
# Precision: 0.914
# Match: 58 (1.6%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: Buy Space:['SPACY:POS-PROPN'] Invaders:['SPACY:POS-PROPN'] 4 a chance:['SPACY:POS-NOUN'] 2:['SPACY:POS-NUM'] win orig Arcade Game console . Press 0 for Games Arcade ( std WAP charge ) See o2.co.uk/games 4 Terms + settings . No purchase
# -------------------------
# [MATCH]: URGENT ! We are trying to contact you . Last weekends draw shows that you have won a Â£900:['SPACY:POS-PROPN'] prize GUARANTEED:['SPACY:POS-PROPN'] . Call:['SPACY:POS-NOUN'] 09061701851:['SPACY:POS-NUM'] . Claim code K61 . Valid 12hours only
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: 1Apple / Day = No Doctor . 1Tulsi Leaf / Day = No Cancer . 1Lemon / Day = No Fat . 1Cup Milk / day = No Bone Problms 3 Litres Watr / Day = No Diseases:['SPACY:POS-PROPN'] Snd:['SPACY:POS-PROPN'] ths:['SPACY:POS-NOUN'] 2:['SPACY:POS-NUM'] Whom U Care .. :- )
# -------------------------
# [MATCH]: HIYA:['SPACY:POS-PROPN'] STU:['SPACY:POS-PROPN'] WOT:['SPACY:POS-NOUN'] U UP 2.IM:['SPACY:POS-NUM'] IN SO MUCH TRUBLE AT HOME AT MOMENT EVONE HATES ME EVEN U ! WOT THE HELL AV I DONE NOW ? Y WONT U JUST TELL ME TEXT BCK PLEASE LUV DAN
# -------------------------
# ==================================================
# Rank 92
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-DET']]
# Window size: 4
# Class: Positive
# Precision: 0.634
# Match: 131 (3.7%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: You have won a Nokia 7250i:['SPACY:POS-NUM'] . This:['SPACY:POS-DET'] is what you get when you win our FREE auction . To take part send Nokia to 86021 now . HG / Suite342/2Lands Row / W1JHL 16 +
# -------------------------
# [MATCH]: Ur TONEXS subscription has been renewed and you have been charged Â£4.50 . You can choose 10:['SPACY:POS-NUM'] more polys this:['SPACY:POS-DET'] month . www.clubzed.co.uk * BILLING MSG *
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Aight , I should be there by 8:['SPACY:POS-NUM'] at the:['SPACY:POS-DET'] latest , probably closer to 7 . Are jay and tyler down or should we just do two trips ?
# -------------------------
# [MATCH]: I shall book chez jules for half eight:['SPACY:POS-NUM'] , if that:['SPACY:POS-DET'] 's ok with you ?
# -------------------------
# ==================================================
# Rank 93
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['TEXT:to']]
# Window size: 5
# Class: Positive
# Precision: 0.565
# Match: 168 (4.7%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: FREE for 1st week ! No1 Nokia tone 4 ur mob every week:['SPACY:POS-NOUN'] just txt NOKIA:['SPACY:POS-NOUN'] to:['TEXT:to'] 8007 Get txting and tell ur mates www.getzed.co.uk POBox 36504 W45WQ norm150p / tone 16 +
# -------------------------
# [MATCH]: FREE MSG : We billed your mobile number by mistake from shortcode:['SPACY:POS-NOUN'] 83332.Please call:['SPACY:POS-NOUN'] 08081263000 to:['TEXT:to'] have charges refunded . This call will be free from a BT landline
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Happy new year to u and ur family ... may this new year bring happiness , stability:['SPACY:POS-NOUN'] and tranquility:['SPACY:POS-NOUN'] to:['TEXT:to'] ur vibrant colourful life : ) : )
# -------------------------
# [MATCH]: Ya , i 'm referin to mei 's ex wat ... No ah , waitin:['SPACY:POS-NOUN'] 4 u:['SPACY:POS-NOUN'] to:['TEXT:to'] treat , somebody shld b rich liao ... So gd , den u dun have to work frm tmr onwards ...
# -------------------------
# ==================================================
# Rank 94
# Pattern: [['SENTIMENT:pos'], ['SPACY:POS-DET'], ['SPACY:POS-PROPN']]
# Window size: 5
# Class: Positive
# Precision: 0.797
# Match: 79 (2.2%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: December only ! Had your mobile 11mths+ ? You are entitled to update to the latest colour camera mobile for Free:['SENTIMENT:pos'] ! Call The:['SPACY:POS-DET'] Mobile:['SPACY:POS-PROPN'] Update Co FREE on 08002986906
# -------------------------
# [MATCH]: URGENT ! We are trying to contact U. Todays draw shows that you have won:['SENTIMENT:pos'] a:['SPACY:POS-DET'] Â£800:['SPACY:POS-PROPN'] prize GUARANTEED . Call 09050003091 from land line . Claim C52 . Valid 12hrs only
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Smile in Pleasure Smile in Pain Smile when trouble pours like Rain Smile:['SENTIMENT:pos'] when sum1:['SPACY:POS-DET'] Hurts:['SPACY:POS-PROPN'] U Smile becoz SOMEONE still Loves to see u Smiling ! !
# -------------------------
# [MATCH]: Sounds like:['SENTIMENT:pos'] a:['SPACY:POS-DET'] plan ! Cardiff:['SPACY:POS-PROPN'] is still here and still cold ! I 'm sitting on the radiator !
# -------------------------
# ==================================================
# Rank 95
# Pattern: [['TEXT:.'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.875
# Match: 64 (1.8%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: Urgent ! Please call 09061743810 from landline .:['TEXT:.'] Your ABTA:['SPACY:POS-PROPN'] complimentary 4:['SPACY:POS-NUM'] * Tenerife Holiday or # 5000 cash await collection SAE T&Cs Box 326 CW25WX 150 ppm
# -------------------------
# [MATCH]: Urgent ! Please call 09061743811 from landline .:['TEXT:.'] Your ABTA:['SPACY:POS-PROPN'] complimentary 4:['SPACY:POS-NUM'] * Tenerife Holiday or Â£5000 cash await collection SAE T&Cs Box 326 CW25WX 150ppm
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: MY NO .:['TEXT:.'] IN LUTON:['SPACY:POS-PROPN'] 0125698789:['SPACY:POS-NUM'] RING ME IF UR AROUND ! H *
# -------------------------
# [MATCH]: We not watching movie already .:['TEXT:.'] Xy:['SPACY:POS-PROPN'] wants 2:['SPACY:POS-NUM'] shop so i 'm shopping w her now .
# -------------------------
# ==================================================
# Rank 96
# Pattern: [['HYPERNYM3:statement.n.01']]
# Window size: 3
# Class: Positive
# Precision: 0.692
# Match: 107 (3.0%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: FREEMSG : Our records indicate you may be entitled to 3750 pounds for the Accident you had . To claim for free reply:['HYPERNYM3:statement.n.01'] with YES to this msg . To opt out text STOP
# -------------------------
# [MATCH]: FREE > Ringtone ! Reply:['HYPERNYM3:statement.n.01'] REAL or POLY eg REAL1 1 . PushButton 2 . DontCha 3 . BabyGoodbye 4 . GoldDigger 5 . WeBeBurnin 1st tone FREE and 6 more when u join for Â£3/wk
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Well at this right I 'm gon na have to get up and check today 's steam sales:['HYPERNYM3:statement.n.01'] / pee so text me when you want me to come get you
# -------------------------
# [MATCH]: No drama Pls.i have had enough from you and family while i am struggling in the hot sun in a strange place . No reason:['HYPERNYM3:statement.n.01'] why there should be an ego of not going ' IF NOT INVITED ' when actually its necessity to go.wait for very serious reppurcussions .
# -------------------------
# ==================================================
# Rank 97
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
# Window size: 5
# Class: Positive
# Precision: 0.520
# Match: 198 (5.6%)
# Gain = 0.036
# Metric (global) = 0.036
# Examples ~ Class Positive:
# [MATCH]: This is the 2nd attempt to contract U , you have won this weeks top prize of either Â£1000 cash:['SPACY:POS-NOUN'] or Â£200:['SPACY:POS-PROPN'] prize:['SPACY:POS-NOUN'] . Just call 09066361921
# -------------------------
# [MATCH]: 5p 4 alfie:['SPACY:POS-NOUN'] Moon:['SPACY:POS-PROPN'] 's Children:['SPACY:POS-NOUN'] in need song on ur mob . Tell ur m8s . Txt Tone charity to 8007 for Nokias or Poly charity for polys : zed 08701417012 profit 2 charity .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Purity of friendship between two is not about smiling after reading the forwarded message .. Its about smiling just by seeing the name:['SPACY:POS-NOUN'] . Gud:['SPACY:POS-PROPN'] evng:['SPACY:POS-NOUN']
# -------------------------
# [MATCH]: Thts:['SPACY:POS-NOUN'] god:['SPACY:POS-PROPN'] 's gift:['SPACY:POS-NOUN'] for birds as humans hav some natural gift frm god ..
# -------------------------
# ==================================================
# Rank 98
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
# Window size: 5
# Class: Positive
# Precision: 1.000
# Match: 44 (1.2%)
# Gain = 0.036
# Metric (global) = 0.036
# Examples ~ Class Positive:
# [MATCH]: URGENT ! We are trying to contact U. Todays draw shows that you have won a Â£800 prize GUARANTEED . Call:['TEXT:call'] 09050001808:['SPACY:POS-NUM'] from:['SPACY:POS-ADP'] land line . Claim M95 . Valid12hrs only
# -------------------------
# [MATCH]: XMAS Prize draws ! We are trying to contact U. Todays draw shows that you have won a Â£2000 prize GUARANTEED . Call:['TEXT:call'] 09058094565:['SPACY:POS-NUM'] from:['SPACY:POS-ADP'] land line . Valid 12hrs only
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Rank 99
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['TEXT:.'], ['SPACY:POS-NUM']]
# Window size: 6
# Class: Positive
# Precision: 1.000
# Match: 44 (1.2%)
# Gain = 0.036
# Metric (global) = 0.036
# Examples ~ Class Positive:
# [MATCH]: 5 Free Top Polyphonic Tones call 087018728737 , National Rate . Get a toppoly tune sent every week , just text SUBPOLY to 81618 , Â£3:['SPACY:POS-PROPN'] per pole:['SPACY:POS-NOUN'] .:['TEXT:.'] UnSub 08718727870:['SPACY:POS-NUM'] .
# -------------------------
# [MATCH]: PRIVATE ! Your 2003 Account Statement for shows 800 un - redeemed S.I.M.:['SPACY:POS-PROPN'] points:['SPACY:POS-NOUN'] .:['TEXT:.'] Call 08715203685:['SPACY:POS-NUM'] Identifier Code:4xx26 Expires 13/10/04
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================

# %% [markdown]
# - Sort the patterns by their information gain

# %%
for idx, p in enumerate(the_patterns_2):
    print(f'{idx+1:>3} {p.support_class}   {round(p.coverage*100, 1):>4}   {p.precision:.3f}   {p.get_pattern_id()}')
# Out:
#   1 Negative   26.2   0.526   [['SPACY:POS-NUM']]
#   2 Positive    8.9   0.806   [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#   3 Positive    5.1   0.984   [['TEXT:call'], ['SPACY:POS-NUM']]
#   4 Positive   14.5   0.579   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#   5 Positive   11.8   0.613   [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
#   6 Positive    6.8   0.811   [['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
#   7 Negative   18.1   0.526   [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
#   8 Positive    5.4   0.856   [['TEXT:to'], ['SPACY:POS-NUM']]
#   9 Negative   37.8   0.690   [['SPACY:POS-PROPN']]
#  10 Positive    7.6   0.702   [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  11 Positive    7.1   0.722   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  12 Positive    5.7   0.797   [['TEXT:.'], ['SPACY:POS-NUM']]
#  13 Positive    6.7   0.735   [['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
#  14 Negative   20.0   0.585   [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  15 Positive    8.8   0.597   [['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
#  16 Positive    7.2   0.655   [['SPACY:POS-ADJ'], ['SPACY:POS-NUM']]
#  17 Positive    7.3   0.649   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  18 Positive    3.4   0.926   [['SPACY:POS-PROPN'], ['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
#  19 Positive   11.8   0.504   [['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]
#  20 Positive    8.0   0.591   [['SPACY:POS-NUM'], ['TEXT:.']]
#  21 Positive    4.3   0.791   [['SPACY:POS-NOUN'], ['TEXT:call']]
#  22 Positive    3.6   0.843   [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  23 Negative   37.2   0.983   [['TEXT:i']]
#  24 Positive    4.4   0.756   [['SPACY:POS-SYM']]
#  25 Positive    4.5   0.748   [['TEXT:free']]
#  26 Positive    2.7   0.938   [['TEXT:txt']]
#  27 Negative   15.5   0.591   [['SPACY:POS-NOUN'], ['TEXT:to']]
#  28 Positive    2.2   1.000   [['TEXT:claim']]
#  29 Positive    7.0   0.592   [['SPACY:POS-NOUN'], ['SPACY:POS-ADP', 'TEXT:to']]
#  30 Negative   16.1   0.602   [['TEXT:!']]
#  31 Positive    8.3   0.539   [['TEXT:.'], ['SPACY:POS-PROPN']]
#  32 Positive    8.7   0.522   [['SPACY:POS-PROPN'], ['TEXT:.']]
#  33 Positive    6.0   0.624   [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  34 Positive    2.4   0.942   [['TEXT:mobile']]
#  35 Positive    6.6   0.591   [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
#  36 Positive    4.0   0.739   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]
#  37 Negative   10.3   0.530   [['SPACY:POS-ADJ'], ['SPACY:POS-PROPN']]
#  38 Positive    6.9   0.559   [['SPACY:POS-NUM'], ['SPACY:POS-ADJ']]
#  39 Positive    7.3   0.542   [['SENTIMENT:pos'], ['SPACY:POS-PROPN']]
#  40 Positive    3.1   0.802   [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  41 Positive    1.9   0.985   [['TEXT:.'], ['TEXT:call'], ['SPACY:POS-NUM']]
#  42 Positive    2.2   0.923   [['HYPERNYM3:communication.n.02'], ['SPACY:POS-NUM']]
#  43 Positive    2.2   0.922   [['HYPERNYM3:win.v.01', 'SENTIMENT:pos']]
#  44 Negative   13.6   0.601   [['SPACY:POS-ADP', 'TEXT:to']]
#  45 Positive    2.0   0.957   [['TEXT:call'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
#  46 Positive    3.1   0.784   [['TEXT:.'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  47 Positive    7.5   0.521   [['SPACY:POS-DET'], ['SPACY:POS-PROPN']]
#  48 Positive    3.8   0.716   [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
#  49 Negative   10.6   0.559   [['SPACY:POS-ADP'], ['SPACY:POS-PROPN']]
#  50 Positive    4.0   0.690   [['SPACY:POS-PROPN'], ['TEXT:to']]
#  51 Positive    2.2   0.909   [['HYPERNYM3:cost.n.01']]
#  52 Negative   65.0   0.804   [['SPACY:POS-ADP']]
#  53 Positive    2.2   0.899   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  54 Negative   54.1   0.785   [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN']]
#  55 Negative   12.1   0.586   [['HYPERNYM3:message.n.02']]
#  56 Positive    5.1   0.613   [['SPACY:POS-NOUN'], ['HYPERNYM3:message.n.02']]
#  57 Negative   30.8   0.725   [['TEXT:to']]
#  58 Positive    2.5   0.843   [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  59 Positive    2.4   0.851   [['TEXT:!'], ['SPACY:POS-NUM']]
#  60 Positive    1.6   1.000   [['TEXT:prize']]
#  61 Positive    2.2   0.873   [['HYPERNYM3:message.n.02'], ['SPACY:POS-NUM']]
#  62 Negative    8.6   0.533   [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NOUN']]
#  63 Negative   10.8   0.580   [['HYPERNYM3:communication.n.02']]
#  64 Positive    1.6   0.982   [['HYPERNYM3:call.v.28'], ['SPACY:POS-NUM']]
#  65 Positive    2.0   0.890   [['SPACY:POS-PROPN'], ['TEXT:call']]
#  66 Positive    2.9   0.765   [['TEXT:call'], ['SPACY:POS-ADP']]
#  67 Positive    2.4   0.816   [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
#  68 Negative   15.9   0.649   [['TEXT:.'], ['SPACY:POS-NOUN']]
#  69 Negative   39.6   0.759   [['SPACY:POS-NOUN'], ['SPACY:POS-ADP']]
#  70 Positive    1.5   0.982   [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['TEXT:to'], ['SPACY:POS-NUM']]
#  71 Positive    4.8   0.594   [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-ADP']]
#  72 Negative   39.9   0.761   [['SENTIMENT:pos']]
#  73 Positive    2.2   0.838   [['SPACY:POS-ADP'], ['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
#  74 Positive    1.9   0.909   [['TEXT:to'], ['SPACY:POS-NUM'], ['TEXT:.']]
#  75 Positive    4.0   0.639   [['SPACY:POS-ADJ'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  76 Positive    1.7   0.934   [['SPACY:POS-NUM'], ['TEXT:now']]
#  77 Positive    2.5   0.789   [['TEXT:.'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  78 Positive    3.5   0.675   [['SENTIMENT:pos'], ['SPACY:POS-NUM']]
#  79 Positive    3.6   0.667   [['TEXT:!'], ['SPACY:POS-PROPN']]
#  80 Positive    1.9   0.884   [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
#  81 Positive    2.2   0.833   [['SPACY:POS-PROPN'], ['TEXT:.'], ['SPACY:POS-NUM']]
#  82 Positive    5.1   0.563   [['TEXT:!'], ['SPACY:POS-NOUN']]
#  83 Positive    3.1   0.709   [['SPACY:POS-DET'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  84 Positive    3.4   0.678   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['TEXT:.']]
#  85 Positive    3.0   0.713   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  86 Positive    4.1   0.621   [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['TEXT:.']]
#  87 Positive    2.1   0.838   [['SENTIMENT:pos'], ['TEXT:call']]
#  88 Positive    1.9   0.868   [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  89 Positive    2.5   0.764   [['HYPERNYM3:symbol.n.01']]
#  90 Positive    5.2   0.543   [['SPACY:POS-ADP'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
#  91 Positive    3.5   0.648   [['TEXT:!'], ['SPACY:POS-ADJ']]
#  92 Positive    1.6   0.914   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  93 Positive    3.7   0.634   [['SPACY:POS-NUM'], ['SPACY:POS-DET']]
#  94 Positive    4.7   0.565   [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['TEXT:to']]
#  95 Positive    2.2   0.797   [['SENTIMENT:pos'], ['SPACY:POS-DET'], ['SPACY:POS-PROPN']]
#  96 Positive    1.8   0.875   [['TEXT:.'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  97 Positive    3.0   0.692   [['HYPERNYM3:statement.n.01']]
#  98 Positive    5.6   0.520   [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  99 Positive    1.2   1.000   [['TEXT:call'], ['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
# 100 Positive    1.2   1.000   [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['TEXT:.'], ['SPACY:POS-NUM']]

# %%
print(f'  #    class Cov(%)    Prec   Gain     Pattern')
for idx, p in enumerate(sorted(the_patterns_2, key = lambda x: x.metric, reverse = True)):
    print(f'{idx+1:>3} {p.support_class}   {round(p.coverage*100, 1):>4}   {p.precision:.3f}   {p.metric:.3f}    {p.get_pattern_id()}')
# Out:
#   #    class Cov(%)    Prec   Gain     Pattern
#   1 Negative   26.2   0.526   0.223    [['SPACY:POS-NUM']]
#   2 Positive    8.9   0.806   0.175    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#   3 Positive    5.1   0.984   0.152    [['TEXT:call'], ['SPACY:POS-NUM']]
#   4 Positive   14.5   0.579   0.148    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#   5 Positive   11.8   0.613   0.129    [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
#   6 Positive    6.8   0.811   0.129    [['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
#   7 Negative   18.1   0.526   0.119    [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
#   8 Positive    5.4   0.856   0.114    [['TEXT:to'], ['SPACY:POS-NUM']]
#   9 Negative   37.8   0.690   0.112    [['SPACY:POS-PROPN']]
#  10 Positive    7.6   0.702   0.105    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  11 Positive    7.1   0.722   0.104    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  12 Positive    5.7   0.797   0.101    [['TEXT:.'], ['SPACY:POS-NUM']]
#  13 Positive    6.7   0.735   0.100    [['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
#  14 Negative   20.0   0.585   0.095    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  15 Positive    8.8   0.597   0.085    [['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
#  16 Positive    7.2   0.655   0.084    [['SPACY:POS-ADJ'], ['SPACY:POS-NUM']]
#  17 Positive    7.3   0.649   0.083    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  18 Positive    3.4   0.926   0.082    [['SPACY:POS-PROPN'], ['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
#  19 Positive   11.8   0.504   0.080    [['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]
#  20 Positive    8.0   0.591   0.074    [['SPACY:POS-NUM'], ['TEXT:.']]
#  21 Positive    4.3   0.791   0.073    [['SPACY:POS-NOUN'], ['TEXT:call']]
#  22 Positive    3.6   0.843   0.069    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  23 Negative   37.2   0.983   0.067    [['TEXT:i']]
#  24 Positive    4.4   0.756   0.067    [['SPACY:POS-SYM']]
#  25 Positive    4.5   0.748   0.067    [['TEXT:free']]
#  26 Positive    2.7   0.938   0.067    [['TEXT:txt']]
#  27 Negative   15.5   0.591   0.065    [['SPACY:POS-NOUN'], ['TEXT:to']]
#  28 Positive    2.2   1.000   0.064    [['TEXT:claim']]
#  29 Positive    7.0   0.592   0.064    [['SPACY:POS-NOUN'], ['SPACY:POS-ADP', 'TEXT:to']]
#  30 Negative   16.1   0.602   0.063    [['TEXT:!']]
#  31 Positive    8.3   0.539   0.062    [['TEXT:.'], ['SPACY:POS-PROPN']]
#  32 Positive    8.7   0.522   0.061    [['SPACY:POS-PROPN'], ['TEXT:.']]
#  33 Positive    6.0   0.624   0.061    [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  34 Positive    2.4   0.942   0.060    [['TEXT:mobile']]
#  35 Positive    6.6   0.591   0.060    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
#  36 Positive    4.0   0.739   0.058    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]
#  37 Negative   10.3   0.530   0.057    [['SPACY:POS-ADJ'], ['SPACY:POS-PROPN']]
#  38 Positive    6.9   0.559   0.055    [['SPACY:POS-NUM'], ['SPACY:POS-ADJ']]
#  39 Positive    7.3   0.542   0.054    [['SENTIMENT:pos'], ['SPACY:POS-PROPN']]
#  40 Positive    3.1   0.802   0.053    [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  41 Positive    1.9   0.985   0.053    [['TEXT:.'], ['TEXT:call'], ['SPACY:POS-NUM']]
#  42 Positive    2.2   0.923   0.052    [['HYPERNYM3:communication.n.02'], ['SPACY:POS-NUM']]
#  43 Positive    2.2   0.922   0.051    [['HYPERNYM3:win.v.01', 'SENTIMENT:pos']]
#  44 Negative   13.6   0.601   0.051    [['SPACY:POS-ADP', 'TEXT:to']]
#  45 Positive    2.0   0.957   0.051    [['TEXT:call'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
#  46 Positive    3.1   0.784   0.051    [['TEXT:.'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  47 Positive    7.5   0.521   0.051    [['SPACY:POS-DET'], ['SPACY:POS-PROPN']]
#  48 Positive    3.8   0.716   0.050    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
#  49 Negative   10.6   0.559   0.050    [['SPACY:POS-ADP'], ['SPACY:POS-PROPN']]
#  50 Positive    4.0   0.690   0.049    [['SPACY:POS-PROPN'], ['TEXT:to']]
#  51 Positive    2.2   0.909   0.049    [['HYPERNYM3:cost.n.01']]
#  52 Negative   65.0   0.804   0.049    [['SPACY:POS-ADP']]
#  53 Positive    2.2   0.899   0.049    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  54 Negative   54.1   0.785   0.049    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN']]
#  55 Negative   12.1   0.586   0.049    [['HYPERNYM3:message.n.02']]
#  56 Positive    5.1   0.613   0.049    [['SPACY:POS-NOUN'], ['HYPERNYM3:message.n.02']]
#  57 Negative   30.8   0.725   0.048    [['TEXT:to']]
#  58 Positive    2.5   0.843   0.048    [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  59 Positive    2.4   0.851   0.047    [['TEXT:!'], ['SPACY:POS-NUM']]
#  60 Positive    1.6   1.000   0.046    [['TEXT:prize']]
#  61 Positive    2.2   0.873   0.046    [['HYPERNYM3:message.n.02'], ['SPACY:POS-NUM']]
#  62 Negative    8.6   0.533   0.045    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NOUN']]
#  63 Negative   10.8   0.580   0.044    [['HYPERNYM3:communication.n.02']]
#  64 Positive    1.6   0.982   0.044    [['HYPERNYM3:call.v.28'], ['SPACY:POS-NUM']]
#  65 Positive    2.0   0.890   0.044    [['SPACY:POS-PROPN'], ['TEXT:call']]
#  66 Positive    2.9   0.765   0.044    [['TEXT:call'], ['SPACY:POS-ADP']]
#  67 Positive    2.4   0.816   0.043    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
#  68 Negative   15.9   0.649   0.043    [['TEXT:.'], ['SPACY:POS-NOUN']]
#  69 Negative   39.6   0.759   0.043    [['SPACY:POS-NOUN'], ['SPACY:POS-ADP']]
#  70 Positive    1.5   0.982   0.043    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['TEXT:to'], ['SPACY:POS-NUM']]
#  71 Positive    4.8   0.594   0.042    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-ADP']]
#  72 Negative   39.9   0.761   0.042    [['SENTIMENT:pos']]
#  73 Positive    2.2   0.838   0.042    [['SPACY:POS-ADP'], ['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
#  74 Positive    1.9   0.909   0.042    [['TEXT:to'], ['SPACY:POS-NUM'], ['TEXT:.']]
#  75 Positive    4.0   0.639   0.042    [['SPACY:POS-ADJ'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  76 Positive    1.7   0.934   0.041    [['SPACY:POS-NUM'], ['TEXT:now']]
#  77 Positive    2.5   0.789   0.041    [['TEXT:.'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  78 Positive    3.5   0.675   0.041    [['SENTIMENT:pos'], ['SPACY:POS-NUM']]
#  79 Positive    3.6   0.667   0.041    [['TEXT:!'], ['SPACY:POS-PROPN']]
#  80 Positive    1.9   0.884   0.041    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
#  81 Positive    2.2   0.833   0.040    [['SPACY:POS-PROPN'], ['TEXT:.'], ['SPACY:POS-NUM']]
#  82 Positive    5.1   0.563   0.040    [['TEXT:!'], ['SPACY:POS-NOUN']]
#  83 Positive    3.1   0.709   0.040    [['SPACY:POS-DET'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  84 Positive    3.4   0.678   0.040    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['TEXT:.']]
#  85 Positive    3.0   0.713   0.040    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  86 Positive    4.1   0.621   0.039    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['TEXT:.']]
#  87 Positive    2.1   0.838   0.039    [['SENTIMENT:pos'], ['TEXT:call']]
#  88 Positive    1.9   0.868   0.038    [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  89 Positive    2.5   0.764   0.038    [['HYPERNYM3:symbol.n.01']]
#  90 Positive    5.2   0.543   0.037    [['SPACY:POS-ADP'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
#  91 Positive    3.5   0.648   0.037    [['TEXT:!'], ['SPACY:POS-ADJ']]
#  92 Positive    1.6   0.914   0.037    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  93 Positive    3.7   0.634   0.037    [['SPACY:POS-NUM'], ['SPACY:POS-DET']]
#  94 Positive    4.7   0.565   0.037    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['TEXT:to']]
#  95 Positive    2.2   0.797   0.037    [['SENTIMENT:pos'], ['SPACY:POS-DET'], ['SPACY:POS-PROPN']]
#  96 Positive    1.8   0.875   0.037    [['TEXT:.'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  97 Positive    3.0   0.692   0.037    [['HYPERNYM3:statement.n.01']]
#  98 Positive    5.6   0.520   0.036    [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  99 Positive    1.2   1.000   0.036    [['TEXT:call'], ['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
# 100 Positive    1.2   1.000   0.036    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['TEXT:.'], ['SPACY:POS-NUM']]

# %% [markdown]
# - Sort the patterns by their precision

# %%
for idx, p in enumerate(sorted(the_patterns_2, key = lambda x: -x.precision)):
    print(f'{idx+1:>3} {p.support_class}   {round(p.coverage*100, 1):>4}   {p.precision:.3f}   {p.get_pattern_id()}')
# Out:
#   1 Positive    2.2   1.000   [['TEXT:claim']]
#   2 Positive    1.6   1.000   [['TEXT:prize']]
#   3 Positive    1.2   1.000   [['TEXT:call'], ['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
#   4 Positive    1.2   1.000   [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['TEXT:.'], ['SPACY:POS-NUM']]
#   5 Positive    1.9   0.985   [['TEXT:.'], ['TEXT:call'], ['SPACY:POS-NUM']]
#   6 Positive    5.1   0.984   [['TEXT:call'], ['SPACY:POS-NUM']]
#   7 Negative   37.2   0.983   [['TEXT:i']]
#   8 Positive    1.6   0.982   [['HYPERNYM3:call.v.28'], ['SPACY:POS-NUM']]
#   9 Positive    1.5   0.982   [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['TEXT:to'], ['SPACY:POS-NUM']]
#  10 Positive    2.0   0.957   [['TEXT:call'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
#  11 Positive    2.4   0.942   [['TEXT:mobile']]
#  12 Positive    2.7   0.938   [['TEXT:txt']]
#  13 Positive    1.7   0.934   [['SPACY:POS-NUM'], ['TEXT:now']]
#  14 Positive    3.4   0.926   [['SPACY:POS-PROPN'], ['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
#  15 Positive    2.2   0.923   [['HYPERNYM3:communication.n.02'], ['SPACY:POS-NUM']]
#  16 Positive    2.2   0.922   [['HYPERNYM3:win.v.01', 'SENTIMENT:pos']]
#  17 Positive    1.6   0.914   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  18 Positive    2.2   0.909   [['HYPERNYM3:cost.n.01']]
#  19 Positive    1.9   0.909   [['TEXT:to'], ['SPACY:POS-NUM'], ['TEXT:.']]
#  20 Positive    2.2   0.899   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  21 Positive    2.0   0.890   [['SPACY:POS-PROPN'], ['TEXT:call']]
#  22 Positive    1.9   0.884   [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
#  23 Positive    1.8   0.875   [['TEXT:.'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  24 Positive    2.2   0.873   [['HYPERNYM3:message.n.02'], ['SPACY:POS-NUM']]
#  25 Positive    1.9   0.868   [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  26 Positive    5.4   0.856   [['TEXT:to'], ['SPACY:POS-NUM']]
#  27 Positive    2.4   0.851   [['TEXT:!'], ['SPACY:POS-NUM']]
#  28 Positive    2.5   0.843   [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  29 Positive    3.6   0.843   [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  30 Positive    2.1   0.838   [['SENTIMENT:pos'], ['TEXT:call']]
#  31 Positive    2.2   0.838   [['SPACY:POS-ADP'], ['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
#  32 Positive    2.2   0.833   [['SPACY:POS-PROPN'], ['TEXT:.'], ['SPACY:POS-NUM']]
#  33 Positive    2.4   0.816   [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
#  34 Positive    6.8   0.811   [['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
#  35 Positive    8.9   0.806   [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  36 Negative   65.0   0.804   [['SPACY:POS-ADP']]
#  37 Positive    3.1   0.802   [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  38 Positive    2.2   0.797   [['SENTIMENT:pos'], ['SPACY:POS-DET'], ['SPACY:POS-PROPN']]
#  39 Positive    5.7   0.797   [['TEXT:.'], ['SPACY:POS-NUM']]
#  40 Positive    4.3   0.791   [['SPACY:POS-NOUN'], ['TEXT:call']]
#  41 Positive    2.5   0.789   [['TEXT:.'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  42 Negative   54.1   0.785   [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN']]
#  43 Positive    3.1   0.784   [['TEXT:.'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  44 Positive    2.9   0.765   [['TEXT:call'], ['SPACY:POS-ADP']]
#  45 Positive    2.5   0.764   [['HYPERNYM3:symbol.n.01']]
#  46 Negative   39.9   0.761   [['SENTIMENT:pos']]
#  47 Negative   39.6   0.759   [['SPACY:POS-NOUN'], ['SPACY:POS-ADP']]
#  48 Positive    4.4   0.756   [['SPACY:POS-SYM']]
#  49 Positive    4.5   0.748   [['TEXT:free']]
#  50 Positive    4.0   0.739   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]
#  51 Positive    6.7   0.735   [['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
#  52 Negative   30.8   0.725   [['TEXT:to']]
#  53 Positive    7.1   0.722   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  54 Positive    3.8   0.716   [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
#  55 Positive    3.0   0.713   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  56 Positive    3.1   0.709   [['SPACY:POS-DET'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  57 Positive    7.6   0.702   [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  58 Positive    3.0   0.692   [['HYPERNYM3:statement.n.01']]
#  59 Negative   37.8   0.690   [['SPACY:POS-PROPN']]
#  60 Positive    4.0   0.690   [['SPACY:POS-PROPN'], ['TEXT:to']]
#  61 Positive    3.4   0.678   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['TEXT:.']]
#  62 Positive    3.5   0.675   [['SENTIMENT:pos'], ['SPACY:POS-NUM']]
#  63 Positive    3.6   0.667   [['TEXT:!'], ['SPACY:POS-PROPN']]
#  64 Positive    7.2   0.655   [['SPACY:POS-ADJ'], ['SPACY:POS-NUM']]
#  65 Negative   15.9   0.649   [['TEXT:.'], ['SPACY:POS-NOUN']]
#  66 Positive    7.3   0.649   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  67 Positive    3.5   0.648   [['TEXT:!'], ['SPACY:POS-ADJ']]
#  68 Positive    4.0   0.639   [['SPACY:POS-ADJ'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  69 Positive    3.7   0.634   [['SPACY:POS-NUM'], ['SPACY:POS-DET']]
#  70 Positive    6.0   0.624   [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  71 Positive    4.1   0.621   [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['TEXT:.']]
#  72 Positive    5.1   0.613   [['SPACY:POS-NOUN'], ['HYPERNYM3:message.n.02']]
#  73 Positive   11.8   0.613   [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
#  74 Negative   16.1   0.602   [['TEXT:!']]
#  75 Negative   13.6   0.601   [['SPACY:POS-ADP', 'TEXT:to']]
#  76 Positive    8.8   0.597   [['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
#  77 Positive    4.8   0.594   [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-ADP']]
#  78 Positive    7.0   0.592   [['SPACY:POS-NOUN'], ['SPACY:POS-ADP', 'TEXT:to']]
#  79 Positive    6.6   0.591   [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
#  80 Positive    8.0   0.591   [['SPACY:POS-NUM'], ['TEXT:.']]
#  81 Negative   15.5   0.591   [['SPACY:POS-NOUN'], ['TEXT:to']]
#  82 Negative   12.1   0.586   [['HYPERNYM3:message.n.02']]
#  83 Negative   20.0   0.585   [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  84 Negative   10.8   0.580   [['HYPERNYM3:communication.n.02']]
#  85 Positive   14.5   0.579   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  86 Positive    4.7   0.565   [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['TEXT:to']]
#  87 Positive    5.1   0.563   [['TEXT:!'], ['SPACY:POS-NOUN']]
#  88 Negative   10.6   0.559   [['SPACY:POS-ADP'], ['SPACY:POS-PROPN']]
#  89 Positive    6.9   0.559   [['SPACY:POS-NUM'], ['SPACY:POS-ADJ']]
#  90 Positive    5.2   0.543   [['SPACY:POS-ADP'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
#  91 Positive    7.3   0.542   [['SENTIMENT:pos'], ['SPACY:POS-PROPN']]
#  92 Positive    8.3   0.539   [['TEXT:.'], ['SPACY:POS-PROPN']]
#  93 Negative    8.6   0.533   [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NOUN']]
#  94 Negative   10.3   0.530   [['SPACY:POS-ADJ'], ['SPACY:POS-PROPN']]
#  95 Negative   18.1   0.526   [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
#  96 Negative   26.2   0.526   [['SPACY:POS-NUM']]
#  97 Positive    8.7   0.522   [['SPACY:POS-PROPN'], ['TEXT:.']]
#  98 Positive    7.5   0.521   [['SPACY:POS-DET'], ['SPACY:POS-PROPN']]
#  99 Positive    5.6   0.520   [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
# 100 Positive   11.8   0.504   [['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]

# %%
print(f'  #    class Cov(%)    Prec    Gain    Pattern')
for idx, p in enumerate(sorted(the_patterns_2, key = lambda x: x.precision, reverse = True)):
    print(f'{idx+1:>3} {p.support_class}   {round(p.coverage*100, 1):>4}   {p.precision:.3f}   {p.metric:.3f}    {p.get_pattern_id()}')
# Out:
#   #    class Cov(%)    Prec    Gain    Pattern
#   1 Positive    2.2   1.000   0.064    [['TEXT:claim']]
#   2 Positive    1.6   1.000   0.046    [['TEXT:prize']]
#   3 Positive    1.2   1.000   0.036    [['TEXT:call'], ['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
#   4 Positive    1.2   1.000   0.036    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['TEXT:.'], ['SPACY:POS-NUM']]
#   5 Positive    1.9   0.985   0.053    [['TEXT:.'], ['TEXT:call'], ['SPACY:POS-NUM']]
#   6 Positive    5.1   0.984   0.152    [['TEXT:call'], ['SPACY:POS-NUM']]
#   7 Negative   37.2   0.983   0.067    [['TEXT:i']]
#   8 Positive    1.6   0.982   0.044    [['HYPERNYM3:call.v.28'], ['SPACY:POS-NUM']]
#   9 Positive    1.5   0.982   0.043    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['TEXT:to'], ['SPACY:POS-NUM']]
#  10 Positive    2.0   0.957   0.051    [['TEXT:call'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
#  11 Positive    2.4   0.942   0.060    [['TEXT:mobile']]
#  12 Positive    2.7   0.938   0.067    [['TEXT:txt']]
#  13 Positive    1.7   0.934   0.041    [['SPACY:POS-NUM'], ['TEXT:now']]
#  14 Positive    3.4   0.926   0.082    [['SPACY:POS-PROPN'], ['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
#  15 Positive    2.2   0.923   0.052    [['HYPERNYM3:communication.n.02'], ['SPACY:POS-NUM']]
#  16 Positive    2.2   0.922   0.051    [['HYPERNYM3:win.v.01', 'SENTIMENT:pos']]
#  17 Positive    1.6   0.914   0.037    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  18 Positive    2.2   0.909   0.049    [['HYPERNYM3:cost.n.01']]
#  19 Positive    1.9   0.909   0.042    [['TEXT:to'], ['SPACY:POS-NUM'], ['TEXT:.']]
#  20 Positive    2.2   0.899   0.049    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  21 Positive    2.0   0.890   0.044    [['SPACY:POS-PROPN'], ['TEXT:call']]
#  22 Positive    1.9   0.884   0.041    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
#  23 Positive    1.8   0.875   0.037    [['TEXT:.'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  24 Positive    2.2   0.873   0.046    [['HYPERNYM3:message.n.02'], ['SPACY:POS-NUM']]
#  25 Positive    1.9   0.868   0.038    [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  26 Positive    5.4   0.856   0.114    [['TEXT:to'], ['SPACY:POS-NUM']]
#  27 Positive    2.4   0.851   0.047    [['TEXT:!'], ['SPACY:POS-NUM']]
#  28 Positive    2.5   0.843   0.048    [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  29 Positive    3.6   0.843   0.069    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  30 Positive    2.1   0.838   0.039    [['SENTIMENT:pos'], ['TEXT:call']]
#  31 Positive    2.2   0.838   0.042    [['SPACY:POS-ADP'], ['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
#  32 Positive    2.2   0.833   0.040    [['SPACY:POS-PROPN'], ['TEXT:.'], ['SPACY:POS-NUM']]
#  33 Positive    2.4   0.816   0.043    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
#  34 Positive    6.8   0.811   0.129    [['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
#  35 Positive    8.9   0.806   0.175    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  36 Negative   65.0   0.804   0.049    [['SPACY:POS-ADP']]
#  37 Positive    3.1   0.802   0.053    [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  38 Positive    2.2   0.797   0.037    [['SENTIMENT:pos'], ['SPACY:POS-DET'], ['SPACY:POS-PROPN']]
#  39 Positive    5.7   0.797   0.101    [['TEXT:.'], ['SPACY:POS-NUM']]
#  40 Positive    4.3   0.791   0.073    [['SPACY:POS-NOUN'], ['TEXT:call']]
#  41 Positive    2.5   0.789   0.041    [['TEXT:.'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  42 Negative   54.1   0.785   0.049    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN']]
#  43 Positive    3.1   0.784   0.051    [['TEXT:.'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  44 Positive    2.9   0.765   0.044    [['TEXT:call'], ['SPACY:POS-ADP']]
#  45 Positive    2.5   0.764   0.038    [['HYPERNYM3:symbol.n.01']]
#  46 Negative   39.9   0.761   0.042    [['SENTIMENT:pos']]
#  47 Negative   39.6   0.759   0.043    [['SPACY:POS-NOUN'], ['SPACY:POS-ADP']]
#  48 Positive    4.4   0.756   0.067    [['SPACY:POS-SYM']]
#  49 Positive    4.5   0.748   0.067    [['TEXT:free']]
#  50 Positive    4.0   0.739   0.058    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]
#  51 Positive    6.7   0.735   0.100    [['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
#  52 Negative   30.8   0.725   0.048    [['TEXT:to']]
#  53 Positive    7.1   0.722   0.104    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  54 Positive    3.8   0.716   0.050    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
#  55 Positive    3.0   0.713   0.040    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  56 Positive    3.1   0.709   0.040    [['SPACY:POS-DET'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  57 Positive    7.6   0.702   0.105    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  58 Positive    3.0   0.692   0.037    [['HYPERNYM3:statement.n.01']]
#  59 Negative   37.8   0.690   0.112    [['SPACY:POS-PROPN']]
#  60 Positive    4.0   0.690   0.049    [['SPACY:POS-PROPN'], ['TEXT:to']]
#  61 Positive    3.4   0.678   0.040    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['TEXT:.']]
#  62 Positive    3.5   0.675   0.041    [['SENTIMENT:pos'], ['SPACY:POS-NUM']]
#  63 Positive    3.6   0.667   0.041    [['TEXT:!'], ['SPACY:POS-PROPN']]
#  64 Positive    7.2   0.655   0.084    [['SPACY:POS-ADJ'], ['SPACY:POS-NUM']]
#  65 Negative   15.9   0.649   0.043    [['TEXT:.'], ['SPACY:POS-NOUN']]
#  66 Positive    7.3   0.649   0.083    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  67 Positive    3.5   0.648   0.037    [['TEXT:!'], ['SPACY:POS-ADJ']]
#  68 Positive    4.0   0.639   0.042    [['SPACY:POS-ADJ'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  69 Positive    3.7   0.634   0.037    [['SPACY:POS-NUM'], ['SPACY:POS-DET']]
#  70 Positive    6.0   0.624   0.061    [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  71 Positive    4.1   0.621   0.039    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['TEXT:.']]
#  72 Positive    5.1   0.613   0.049    [['SPACY:POS-NOUN'], ['HYPERNYM3:message.n.02']]
#  73 Positive   11.8   0.613   0.129    [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
#  74 Negative   16.1   0.602   0.063    [['TEXT:!']]
#  75 Negative   13.6   0.601   0.051    [['SPACY:POS-ADP', 'TEXT:to']]
#  76 Positive    8.8   0.597   0.085    [['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
#  77 Positive    4.8   0.594   0.042    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-ADP']]
#  78 Positive    7.0   0.592   0.064    [['SPACY:POS-NOUN'], ['SPACY:POS-ADP', 'TEXT:to']]
#  79 Positive    6.6   0.591   0.060    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
#  80 Positive    8.0   0.591   0.074    [['SPACY:POS-NUM'], ['TEXT:.']]
#  81 Negative   15.5   0.591   0.065    [['SPACY:POS-NOUN'], ['TEXT:to']]
#  82 Negative   12.1   0.586   0.049    [['HYPERNYM3:message.n.02']]
#  83 Negative   20.0   0.585   0.095    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  84 Negative   10.8   0.580   0.044    [['HYPERNYM3:communication.n.02']]
#  85 Positive   14.5   0.579   0.148    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  86 Positive    4.7   0.565   0.037    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['TEXT:to']]
#  87 Positive    5.1   0.563   0.040    [['TEXT:!'], ['SPACY:POS-NOUN']]
#  88 Negative   10.6   0.559   0.050    [['SPACY:POS-ADP'], ['SPACY:POS-PROPN']]
#  89 Positive    6.9   0.559   0.055    [['SPACY:POS-NUM'], ['SPACY:POS-ADJ']]
#  90 Positive    5.2   0.543   0.037    [['SPACY:POS-ADP'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
#  91 Positive    7.3   0.542   0.054    [['SENTIMENT:pos'], ['SPACY:POS-PROPN']]
#  92 Positive    8.3   0.539   0.062    [['TEXT:.'], ['SPACY:POS-PROPN']]
#  93 Negative    8.6   0.533   0.045    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NOUN']]
#  94 Negative   10.3   0.530   0.057    [['SPACY:POS-ADJ'], ['SPACY:POS-PROPN']]
#  95 Negative   18.1   0.526   0.119    [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
#  96 Negative   26.2   0.526   0.223    [['SPACY:POS-NUM']]
#  97 Positive    8.7   0.522   0.061    [['SPACY:POS-PROPN'], ['TEXT:.']]
#  98 Positive    7.5   0.521   0.051    [['SPACY:POS-DET'], ['SPACY:POS-PROPN']]
#  99 Positive    5.6   0.520   0.036    [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
# 100 Positive   11.8   0.504   0.080    [['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]

# %% [markdown]
# ## Example 3
# Using F_0.05 as a metric to select patterns.

# %%
grasp_model_3 = GrASP(gaps_allowed = 2, num_patterns = 100, include_standard = ['TEXT', 'POS', 'SENTIMENT'],
                    include_custom = [Hypernym3Attribute],
                    correlation_threshold = 0.5, alphabet_size = 100,
                    gain_criteria = 'F_0.05')

# %%
the_patterns_3 = grasp_model_3.fit_transform(positive, negative)
# Out:
#   0%|          | 0/488 [00:00<?, ?it/s]
# Step 1: Create augmented texts
# 100%|██████████| 488/488 [00:20<00:00, 23.58it/s]
# 100%|██████████| 3079/3079 [01:27<00:00, 35.30it/s]
# Step 2: Find frequent attributes
#   1%|          | 7/1215 [00:00<00:19, 62.64it/s]
# Total number of candidate alphabet = 1215, such as ['SPACY:POS-VERB', 'SPACY:POS-NOUN', 'SPACY:POS-PUNCT', 'SPACY:POS-PRON', 'SPACY:POS-ADV']
# Step 3: Find alphabet set
# 100%|██████████| 1215/1215 [00:36<00:00, 33.39it/s]
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finding top k: 100 / 100
# Total number of alphabet = 100
# ['TEXT:claim', 'TEXT:prize', 'TEXT:i', 'TEXT:won', 'TEXT:...', 'TEXT:150p', 'TEXT:guaranteed', 'TEXT:my', 'HYPERNYM3:assertion.n.01', 'TEXT:;', 'TEXT:tone', 'TEXT:18', 'HYPERNYM3:prize.n.01', 'TEXT:..', 'TEXT:but', 'HYPERNYM3:claim.v.03', 'SPACY:POS-SPACE', 'TEXT:awarded', 'TEXT:â£1000', 'TEXT:150ppm', "TEXT:'m", 'HYPERNYM3:outgo.n.01', 'HYPERNYM3:television_equipment.n.01', 'HYPERNYM3:match.v.01', 'TEXT:urgent', 'TEXT:16', 'TEXT:ok', 'HYPERNYM3:corner.n.08', 'TEXT:it', 'TEXT:come', 'TEXT:me', 'TEXT:that', 'TEXT:10p', 'TEXT:collection', 'TEXT:how', 'TEXT:he', "TEXT:'ll", 'TEXT:got', 'TEXT:service', 'TEXT:mobile', "TEXT:n't", 'TEXT:did', 'TEXT:txt', 'TEXT:going', 'HYPERNYM3:make.v.03', 'HYPERNYM3:then.r.03', 'TEXT:home', 'TEXT:nt', 'HYPERNYM3:not.r.01', 'TEXT:later', 'TEXT:lor', 'HYPERNYM3:cause.v.01', 'TEXT:da', 'TEXT:do', 'TEXT:rate', 'HYPERNYM3:mobile.n.03', 'SPACY:POS-INTJ', 'SPACY:POS-PRON', 'HYPERNYM3:search.v.04', 'TEXT:in', 'TEXT:at', 'HYPERNYM3:mobile.n.02', 'TEXT:good', 'TEXT:when', 'TEXT:she', 'HYPERNYM3:travel.v.01', 'TEXT:am', 'TEXT:sorry', 'TEXT:love', 'TEXT:like', 'TEXT:so', 'TEXT:code', 'TEXT:think', 'HYPERNYM3:happen.v.01', 'TEXT:its', 'TEXT:much', 'TEXT:was', 'HYPERNYM3:service.n.11', 'TEXT:what', 'TEXT:ã¼', 'TEXT:too', 'TEXT:win', 'TEXT:if', 'HYPERNYM3:category.n.02', 'TEXT:?', 'HYPERNYM3:land_line.n.01', 'TEXT:nokia', 'TEXT:one', 'HYPERNYM3:speculate.v.02', 'HYPERNYM3:know.v.01', 'TEXT:doing', 'TEXT:camera', 'HYPERNYM3:substance.n.07', 'TEXT:about', 'TEXT:well', 'TEXT:already', 'TEXT:ca', 'HYPERNYM3:exist.v.01', 'TEXT:where', 'TEXT:latest']
# Example of patterns
# Pattern: [['TEXT:claim']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 77 (2.2%)
# Gain = 0.064
# Metric (F_0.05) = 0.987
# Examples ~ Class Positive:
# [MATCH]: You have won a guaranteed Â£200 award or even Â£1000 cashto claim:['TEXT:claim'] UR award call free on 08000407165 ( 18 + ) 2 stop getstop on 88222 PHP
# -------------------------
# [MATCH]: Sunshine Hols . To claim:['TEXT:claim'] ur med holiday send a stamped self address envelope to Drinks on Us UK , PO Box 113 , Bray , Wicklow , Eire . Quiz Starts Saturday ! Unsub Stop
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Pattern: [['TEXT:prize']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 56 (1.6%)
# Gain = 0.046
# Metric (F_0.05) = 0.981
# Examples ~ Class Positive:
# [MATCH]: URGENT This is our 2nd attempt to contact U. Your Â£900 prize:['TEXT:prize'] from YESTERDAY is still awaiting collection . To claim CALL NOW 09061702893
# -------------------------
# [MATCH]: URGENT ! We are trying to contact U. Todays draw shows that you have won a Â£800 prize:['TEXT:prize'] GUARANTEED . Call 09050001808 from land line . Claim M95 . Valid12hrs only
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Pattern: [['TEXT:i']]
# Window size: 3
# Class: Negative
# Precision: 0.983
# Match: 1327 (37.2%)
# Gain = 0.067
# Metric (F_0.05) = 0.980
# Examples ~ Class Negative:
# [MATCH]: That s cool . I:['TEXT:i'] want to please you ...
# -------------------------
# [MATCH]: You know my old Dom I:['TEXT:i'] told you about yesterday ? His name is Roger ? He got in touch with me last night and wants me to meet him today at 2 pm
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: I:['TEXT:i'] 'd like to tell you my deepest darkest fantasies . Call me 09094646631 just 60p / min . To stop texts call 08712460324 ( nat rate )
# -------------------------
# [MATCH]: Can U get 2 phone NOW ? I:['TEXT:i'] wanna chat 2 set up meet Call me NOW on 09096102316 U can cum here 2moro Luv JANE xx CallsÂ£1/minmoremobsEMSPOBox45PO139WA
# -------------------------
# ==================================================
# Pattern: [['TEXT:won']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 48 (1.3%)
# Gain = 0.039
# Metric (F_0.05) = 0.978
# Examples ~ Class Positive:
# [MATCH]: You have won:['TEXT:won'] a Nokia 7250i . This is what you get when you win our FREE auction . To take part send Nokia to 86021 now . HG / Suite342/2Lands Row / W1JHL 16 +
# -------------------------
# [MATCH]: You have won:['TEXT:won'] a guaranteed Â£200 award or even Â£1000 cashto claim UR award call free on 08000407165 ( 18 + ) 2 stop getstop on 88222 PHP . RG21 4JX
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Pattern: [['TEXT:...']]
# Window size: 3
# Class: Negative
# Precision: 0.989
# Match: 449 (12.6%)
# Gain = 0.021
# Metric (F_0.05) = 0.975
# Examples ~ Class Negative:
# [MATCH]: Ãœ eatin later but i 'm eatin wif my frens now lei ...:['TEXT:...'] Ãœ going home first ?
# -------------------------
# [MATCH]: Geeeee ...:['TEXT:...'] Your internet is really bad today , eh ?
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: TheMob > Yo yo yo - Here comes a new selection of hot downloads for our members to get for FREE ! Just click & open the next link sent to ur fone ...:['TEXT:...']
# -------------------------
# [MATCH]: Hi , this is Mandy Sullivan calling from HOTMIX FM ...:['TEXT:...'] you are chosen to receive Â£5000.00 in our Easter Prize draw ..... Please telephone 09041940223 to claim before 29/03/05 or your prize will be transferred to someone else ....
# -------------------------
# ==================================================
# Step 4: Grow patterns
# 100%|██████████| 100/100 [00:33<00:00,  2.97it/s]
# Length 2 / 5; New candidates = 14950
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['TEXT:claim']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 77 (2.2%)
# Gain = 0.064
# Metric (F_0.05) = 0.987
# Examples ~ Class Positive:
# [MATCH]: URGENT ! We are trying to contact you . Last weekends draw shows that you have won a Â£900 prize GUARANTEED . Call 09061701851 . Claim:['TEXT:claim'] code K61 . Valid 12hours only
# -------------------------
# [MATCH]: You have won a guaranteed Â£200 award or even Â£1000 cashto claim:['TEXT:claim'] UR award call free on 08000407165 ( 18 + ) 2 stop getstop on 88222 PHP . RG21 4JX
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Pattern: [['TEXT:prize']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 56 (1.6%)
# Gain = 0.046
# Metric (F_0.05) = 0.981
# Examples ~ Class Positive:
# [MATCH]: This is the 2nd time we have tried to contact u. U have won the Â£1450 prize:['TEXT:prize'] to claim just call 09053750005 b4 310303 . T&Cs / stop SMS 08718725756 . 140ppm
# -------------------------
# [MATCH]: This is the 2nd attempt to contract U , you have won this weeks top prize:['TEXT:prize'] of either Â£1000 cash or Â£200 prize . Just call 09066361921
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Pattern: [['TEXT:i']]
# Window size: 3
# Class: Negative
# Precision: 0.983
# Match: 1327 (37.2%)
# Gain = 0.067
# Metric (F_0.05) = 0.980
# Examples ~ Class Negative:
# [MATCH]: Lol now I:['TEXT:i'] 'm after that hot air balloon !
# -------------------------
# [MATCH]: Good evening Sir , hope you are having a nice day . I:['TEXT:i'] wanted to bring it to your notice that I have been late in paying rent for the past few months and have had to pay a $ & lt;#&gt ;   charge . I felt it would be inconsiderate of me to nag about something you give at great cost to yourself and that 's why i did nt speak up . I however am in a recession and wo nt be able to pay the charge this month hence my askin well ahead of month 's end . Can you please help . Thank you for everything .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Guess who am I?This is the first time I:['TEXT:i'] created a web page WWW.ASJESUS.COM read all I wrote . I 'm waiting for your opinions . I want to be your friend 1/1
# -------------------------
# [MATCH]: Babe : U want me do nt u baby ! I:['TEXT:i'] m nasty and have a thing 4 filthyguys . Fancy a rude time with a sexy bitch . How about we go slo n hard ! Txt XXX SLO(4msgs )
# -------------------------
# ==================================================
# Pattern: [['TEXT:won']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 48 (1.3%)
# Gain = 0.039
# Metric (F_0.05) = 0.978
# Examples ~ Class Positive:
# [MATCH]: You have WON:['TEXT:won'] a guaranteed Â£1000 cash or a Â£2000 prize . To claim yr prize call our customer service representative on 08714712412 between 10am-7pm Cost 10p
# -------------------------
# [MATCH]: 449050000301 You have won:['TEXT:won'] a Â£2,000 price ! To claim , call 09050000301 .
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Pattern: [['TEXT:...']]
# Window size: 3
# Class: Negative
# Precision: 0.989
# Match: 449 (12.6%)
# Gain = 0.021
# Metric (F_0.05) = 0.975
# Examples ~ Class Negative:
# [MATCH]: I was at bugis juz now wat ...:['TEXT:...'] But now i 'm walking home oredi ... Ãœ so late then reply ... I oso saw a top dat i like but din buy ... Where r Ã¼ now ?
# -------------------------
# [MATCH]: As in missionary hook up , doggy hook up , standing ...:['TEXT:...'] |
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Hi this is Amy , we will be sending you a free phone number in a couple of days , which will give you an access to all the adult parties ...:['TEXT:...']
# -------------------------
# [MATCH]: Hi , this is Mandy Sullivan calling from HOTMIX FM ...:['TEXT:...'] you are chosen to receive Â£5000.00 in our Easter Prize draw ..... Please telephone 09041940223 to claim before 29/03/05 or your prize will be transferred to someone else ....
# -------------------------
# ==================================================
# 100%|██████████| 30/30 [00:18<00:00,  1.64it/s]
# Length 3 / 5; New candidates = 5872
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
#   0%|          | 0/1 [00:00<?, ?it/s]
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['TEXT:claim']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 77 (2.2%)
# Gain = 0.064
# Metric (F_0.05) = 0.987
# Examples ~ Class Positive:
# [MATCH]: URGENT ! We are trying to contact U Todays draw shows that you have won a Â£800 prize GUARANTEED . Call 09050000460 from land line . Claim:['TEXT:claim'] J89 . po box245c2150pm
# -------------------------
# [MATCH]: + 123 Congratulations - in this week 's competition draw u have won the Â£1450 prize to claim:['TEXT:claim'] just call 09050002311 b4280703 . T&Cs / stop SMS 08718727868 . Over 18 only 150ppm
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Pattern: [['TEXT:prize']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 56 (1.6%)
# Gain = 0.046
# Metric (F_0.05) = 0.981
# Examples ~ Class Positive:
# [MATCH]: Please call our customer service representative on FREEPHONE 0808 145 4742 between 9am-11pm as you have WON a guaranteed Â£1000 cash or Â£5000 prize:['TEXT:prize'] !
# -------------------------
# [MATCH]: URGENT ! We are trying to contact U. Todays draw shows that you have won a Â£2000 prize:['TEXT:prize'] GUARANTEED . Call 09066358361 from land line . Claim Y87 . Valid 12hrs only
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Pattern: [['TEXT:i']]
# Window size: 3
# Class: Negative
# Precision: 0.983
# Match: 1327 (37.2%)
# Gain = 0.067
# Metric (F_0.05) = 0.980
# Examples ~ Class Negative:
# [MATCH]: I:['TEXT:i'] 'm doing da intro covers energy trends n pros n cons ... Brief description of nuclear fusion n oso brief history of iter n jet got abt 7 n half pages ..
# -------------------------
# [MATCH]: Actually , my mobile is full of msg . And i:['TEXT:i'] m doing a work online , where i need to send them   & lt;#&gt ;   sent msg i wil explain u later .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Mila , age23 , blonde , new in UK . I:['TEXT:i'] look sex with UK guys . if u like fun with me . Text MTALK to 69866.18 . 30pp / txt 1st 5free . Â£1.50 increments . Help08718728876
# -------------------------
# [MATCH]: I:['TEXT:i'] do n't know u and u do n't know me . Send CHAT to 86688 now and let 's find each other ! Only 150p / Msg rcvd . HG / Suite342/2Lands / Row / W1J6HL LDN . 18 years or over .
# -------------------------
# ==================================================
# Pattern: [['TEXT:won']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 48 (1.3%)
# Gain = 0.039
# Metric (F_0.05) = 0.978
# Examples ~ Class Positive:
# [MATCH]: You have won:['TEXT:won'] a Nokia 7250i . This is what you get when you win our FREE auction . To take part send Nokia to 86021 now . HG / Suite342/2Lands Row / W1JHL 16 +
# -------------------------
# [MATCH]: Please call our customer service representative on 0800 169 6031 between 10am-9pm as you have WON:['TEXT:won'] a guaranteed Â£1000 cash or Â£5000 prize !
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Pattern: [['TEXT:...']]
# Window size: 3
# Class: Negative
# Precision: 0.989
# Match: 449 (12.6%)
# Gain = 0.021
# Metric (F_0.05) = 0.975
# Examples ~ Class Negative:
# [MATCH]: Nice line said by a broken heart- Plz do n't cum 1 more times infront of me ...:['TEXT:...'] Other wise once again I ll trust U ... Good 9 t : )
# -------------------------
# [MATCH]: Say this slowly . ? GOD , I LOVE YOU & amp ; I NEED YOU , CLEAN MY HEART WITH YOUR BLOOD.Send this to Ten special people & amp ; u c miracle tomorrow , do it , pls , pls do it ...:['TEXT:...']
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Do n't b floppy ...:['TEXT:...'] b snappy & happy ! Only gay chat service with photo upload call 08718730666 ( 10p / min ) . 2 stop our texts call 08712460324
# -------------------------
# [MATCH]: Hi , this is Mandy Sullivan calling from HOTMIX FM ...:['TEXT:...'] you are chosen to receive Â£5000.00 in our Easter Prize draw ..... Please telephone 09041940223 to claim before 29/03/05 or your prize will be transferred to someone else ....
# -------------------------
# ==================================================
# 100%|██████████| 1/1 [00:00<00:00,  3.40it/s]
# Length 4 / 5; New candidates = 199
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
# 0it [00:00, ?it/s]
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['TEXT:claim']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 77 (2.2%)
# Gain = 0.064
# Metric (F_0.05) = 0.987
# Examples ~ Class Positive:
# [MATCH]: URGENT ! We are trying to contact U. Todays draw shows that you have won a Â£800 prize GUARANTEED . Call 09050001808 from land line . Claim:['TEXT:claim'] M95 . Valid12hrs only
# -------------------------
# [MATCH]: Congratulations - Thanks to a good friend U have WON the Â£2,000 Xmas prize . 2 claim:['TEXT:claim'] is easy , just call 08712103738 NOW ! Only 10p per minute . BT - national - rate
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Pattern: [['TEXT:prize']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 56 (1.6%)
# Gain = 0.046
# Metric (F_0.05) = 0.981
# Examples ~ Class Positive:
# [MATCH]: URGENT ! Your Mobile number has been awarded with a Â£2000 prize:['TEXT:prize'] GUARANTEED . Call 09061790126 from land line . Claim 3030 . Valid 12hrs only 150ppm
# -------------------------
# [MATCH]: Please call our customer service representative on FREEPHONE 0808 145 4742 between 9am-11pm as you have WON a guaranteed Â£1000 cash or Â£5000 prize:['TEXT:prize'] !
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Pattern: [['TEXT:i']]
# Window size: 3
# Class: Negative
# Precision: 0.983
# Match: 1327 (37.2%)
# Gain = 0.067
# Metric (F_0.05) = 0.980
# Examples ~ Class Negative:
# [MATCH]: As if i:['TEXT:i'] was n't having enough trouble sleeping .
# -------------------------
# [MATCH]: I:['TEXT:i'] do n't think I can get away for a trek that long with family in town , sorry
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: I:['TEXT:i'] 'd like to tell you my deepest darkest fantasies . Call me 09094646631 just 60p / min . To stop texts call 08712460324 ( nat rate )
# -------------------------
# [MATCH]: I:['TEXT:i'] do n't know u and u do n't know me . Send CHAT to 86688 now and let 's find each other ! Only 150p / Msg rcvd . HG / Suite342/2Lands / Row / W1J6HL LDN . 18 years or over .
# -------------------------
# ==================================================
# Pattern: [['TEXT:won']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 48 (1.3%)
# Gain = 0.039
# Metric (F_0.05) = 0.978
# Examples ~ Class Positive:
# [MATCH]: 449050000301 You have won:['TEXT:won'] a Â£2,000 price ! To claim , call 09050000301 .
# -------------------------
# [MATCH]: URGENT ! Your mobile No 077xxx WON:['TEXT:won'] a Â£2,000 Bonus Caller Prize on 02/06/03 ! This is the 2nd attempt to reach YOU ! Call 09066362206 ASAP ! BOX97N7QP , 150ppm
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Pattern: [['TEXT:...']]
# Window size: 3
# Class: Negative
# Precision: 0.989
# Match: 449 (12.6%)
# Gain = 0.021
# Metric (F_0.05) = 0.975
# Examples ~ Class Negative:
# [MATCH]: I not free today i haf 2 pick my parents up tonite ...:['TEXT:...']
# -------------------------
# [MATCH]: If e timing can , then i go w u lor ...:['TEXT:...']
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Hi , this is Mandy Sullivan calling from HOTMIX FM ...:['TEXT:...'] you are chosen to receive Â£5000.00 in our Easter Prize draw ..... Please telephone 09041940223 to claim before 29/03/05 or your prize will be transferred to someone else ....
# -------------------------
# [MATCH]: TheMob > Yo yo yo - Here comes a new selection of hot downloads for our members to get for FREE ! Just click & open the next link sent to ur fone ...:['TEXT:...']
# -------------------------
# ==================================================
# Length 5 / 5; New candidates = 0

# %%
for idx, p in enumerate(the_patterns_3):
    print(f'Rank {idx}')
    print(p)
# Out:
# Rank 0
# Pattern: [['TEXT:claim']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 77 (2.2%)
# Gain = 0.064
# Metric (F_0.05) = 0.987
# Examples ~ Class Positive:
# [MATCH]: Final Chance ! Claim:['TEXT:claim'] ur Â£150 worth of discount vouchers today ! Text YES to 85023 now ! SavaMob , member offers mobile ! T Cs SavaMob POBOX84 , M263UZ . Â£3.00 Subs 16
# -------------------------
# [MATCH]: Uâ€ ™ ve Bin Awarded Â£50 to Play 4 Instant Cash . Call 08715203028 To Claim:['TEXT:claim'] . EVERY 9th Player Wins Min Â£50-Â£500 . OptOut 08718727870
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Rank 1
# Pattern: [['TEXT:prize']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 56 (1.6%)
# Gain = 0.046
# Metric (F_0.05) = 0.981
# Examples ~ Class Positive:
# [MATCH]: URGENT ! Your mobile No 077xxx WON a Â£2,000 Bonus Caller Prize:['TEXT:prize'] on 02/06/03 ! This is the 2nd attempt to reach YOU ! Call 09066362206 ASAP ! BOX97N7QP , 150ppm
# -------------------------
# [MATCH]: This is the 2nd time we have tried 2 contact u. U have won the 750 Pound prize:['TEXT:prize'] . 2 claim is easy , call 08718726970 NOW ! Only 10p per min . BT - national - rate
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Rank 2
# Pattern: [['TEXT:i']]
# Window size: 3
# Class: Negative
# Precision: 0.983
# Match: 1327 (37.2%)
# Gain = 0.067
# Metric (F_0.05) = 0.980
# Examples ~ Class Negative:
# [MATCH]: Sorry , I:['TEXT:i'] 'll call later
# -------------------------
# [MATCH]: Ok i:['TEXT:i'] also wan 2 watch e 9 pm show ...
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Guess who am I?This is the first time I:['TEXT:i'] created a web page WWW.ASJESUS.COM read all I wrote . I 'm waiting for your opinions . I want to be your friend 1/1
# -------------------------
# [MATCH]: Hi babe its Jordan , how r u ? I:['TEXT:i'] m home from abroad and lonely , text me back if u wanna chat xxSP visionsms.com Text stop to stopCost 150p 08712400603
# -------------------------
# ==================================================
# Rank 3
# Pattern: [['TEXT:won']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 48 (1.3%)
# Gain = 0.039
# Metric (F_0.05) = 0.978
# Examples ~ Class Positive:
# [MATCH]: Please call our customer service representative on FREEPHONE 0808 145 4742 between 9am-11pm as you have WON:['TEXT:won'] a guaranteed Â£1000 cash or Â£5000 prize !
# -------------------------
# [MATCH]: URGENT ! We are trying to contact U. Todays draw shows that you have won:['TEXT:won'] a Â£800 prize GUARANTEED . Call 09050003091 from land line . Claim C52 . Valid 12hrs only
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Rank 4
# Pattern: [['TEXT:...']]
# Window size: 3
# Class: Negative
# Precision: 0.989
# Match: 449 (12.6%)
# Gain = 0.021
# Metric (F_0.05) = 0.975
# Examples ~ Class Negative:
# [MATCH]: Hey i will be really pretty late ...:['TEXT:...'] You want to go for the lesson first ? I will join you . I 'm only reaching tp mrt
# -------------------------
# [MATCH]: After my work ah ...:['TEXT:...'] Den 6 plus lor ... U workin oso rite ... Den go orchard lor , no other place to go liao ...
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Bears Pic Nick , and Tom , Pete and ...:['TEXT:...'] Dick . In fact , all types try gay chat with photo upload call 08718730666 ( 10p / min ) . 2 stop texts call 08712460324
# -------------------------
# [MATCH]: Do n't b floppy ...:['TEXT:...'] b snappy & happy ! Only gay chat service with photo upload call 08718730666 ( 10p / min ) . 2 stop our texts call 08712460324
# -------------------------
# ==================================================
# Rank 5
# Pattern: [['TEXT:i'], ['SPACY:POS-PRON']]
# Window size: 4
# Class: Negative
# Precision: 0.997
# Match: 292 (8.2%)
# Gain = 0.016
# Metric (F_0.05) = 0.973
# Examples ~ Class Negative:
# [MATCH]: Wish i:['TEXT:i'] were with you:['SPACY:POS-PRON'] now !
# -------------------------
# [MATCH]: " CHEERS FOR CALLIN BABE.SOZI CULDNT TALKBUT I:['TEXT:i'] WANNATELL U:['SPACY:POS-PRON'] DETAILS LATER WENWECAN CHAT PROPERLY X "
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Guess who am I?This is the first time I created a web page WWW.ASJESUS.COM read all I:['TEXT:i'] wrote . I:['SPACY:POS-PRON'] 'm waiting for your opinions . I want to be your friend 1/1
# -------------------------
# ==================================================
# Rank 6
# Pattern: [['TEXT:150p']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 38 (1.1%)
# Gain = 0.031
# Metric (F_0.05) = 0.971
# Examples ~ Class Positive:
# [MATCH]: Tone Club : Your subs has now expired 2 re - sub reply MONOC 4 monos or POLYC 4 polys 1 weekly @ 150p:['TEXT:150p'] per week Txt STOP 2 stop This msg free Stream 0871212025016
# -------------------------
# [MATCH]: Married local women looking for discreet action now ! 5 real matches instantly to your phone . Text MATCH to 69969 Msg cost 150p:['TEXT:150p'] 2 stop txt stop BCMSFWC1N3XX
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Rank 7
# Pattern: [['TEXT:guaranteed']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 38 (1.1%)
# Gain = 0.031
# Metric (F_0.05) = 0.971
# Examples ~ Class Positive:
# [MATCH]: Congratulations U can claim 2 VIP row A Tickets 2 C Blu in concert in November or Blu gift guaranteed:['TEXT:guaranteed'] Call 09061104276 to claim TS&Cs www.smsco.net costÂ£3.75max
# -------------------------
# [MATCH]: You have WON a guaranteed:['TEXT:guaranteed'] Â£1000 cash or a Â£2000 prize . To claim yr prize call our customer service representative on 08714712394 between 10am-7pm
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Rank 8
# Pattern: [['TEXT:my']]
# Window size: 3
# Class: Negative
# Precision: 0.987
# Match: 383 (10.7%)
# Gain = 0.017
# Metric (F_0.05) = 0.970
# Examples ~ Class Negative:
# [MATCH]: MOON has come to color your dreams , STARS to make them musical and my:['TEXT:my'] SMS to give you warm and Peaceful Sleep . Good Night
# -------------------------
# [MATCH]: I was n't well babe , i have swollen glands at my:['TEXT:my'] throat ... What did you end up doing ?
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: I 'd like to tell you my:['TEXT:my'] deepest darkest fantasies . Call me 09094646631 just 60p / min . To stop texts call 08712460324 ( nat rate )
# -------------------------
# [MATCH]: FreeMsg Hey U , i just got 1 of these video / pic fones , reply WILD to this txt & ill send U my:['TEXT:my'] pics , hurry up I m so bored at work xxx ( 18 150p / rcvd STOP2stop )
# -------------------------
# ==================================================
# Rank 9
# Pattern: [['SPACY:POS-PRON'], ['SPACY:POS-PRON']]
# Window size: 4
# Class: Negative
# Precision: 0.977
# Match: 641 (18.0%)
# Gain = 0.023
# Metric (F_0.05) = 0.967
# Examples ~ Class Negative:
# [MATCH]: I want to tell you:['SPACY:POS-PRON'] how bad I:['SPACY:POS-PRON'] feel that basically the only times I text you lately are when I need drugs
# -------------------------
# [MATCH]: Say this slowly . ? GOD , I:['SPACY:POS-PRON'] LOVE YOU:['SPACY:POS-PRON'] & amp ; I NEED YOU , CLEAN MY HEART WITH YOUR BLOOD.Send this to Ten special people & amp ; u c miracle tomorrow , do it , pls , pls do it ...
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Hi ya babe x u 4goten bout me ? ' scammers getting smart .. Though this is a regular vodafone no , if you:['SPACY:POS-PRON'] respond you:['SPACY:POS-PRON'] get further prem rate msg / subscription . Other nos used also . Beware !
# -------------------------
# [MATCH]: Marvel Mobile Play the official Ultimate Spider - man game ( Â£4.50 ) on ur mobile right now . Text SPIDER to 83338 for the game & we:['SPACY:POS-PRON'] ll send u:['SPACY:POS-PRON'] a FREE 8Ball wallpaper
# -------------------------
# ==================================================
# Rank 10
# Pattern: [['SPACY:POS-INTJ'], ['SPACY:POS-PRON']]
# Window size: 4
# Class: Negative
# Precision: 0.983
# Match: 406 (11.4%)
# Gain = 0.016
# Metric (F_0.05) = 0.967
# Examples ~ Class Negative:
# [MATCH]: Pls:['SPACY:POS-INTJ'] i:['SPACY:POS-PRON'] wo nt belive god.not only jesus .
# -------------------------
# [MATCH]: Sorry:['SPACY:POS-INTJ'] . You:['SPACY:POS-PRON'] never hear unless you book it . One was kinda a joke -- thet were really looking for skinny white girls . The other was one line -- you can only do so much on camera with that . Something like that they 're casting on the look .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Mila , age23 , blonde , new in UK . I look sex with UK guys . if u like:['SPACY:POS-INTJ'] fun with me:['SPACY:POS-PRON'] . Text MTALK to 69866.18 . 30pp / txt 1st 5free . Â£1.50 increments . Help08718728876
# -------------------------
# [MATCH]: Oh my:['SPACY:POS-INTJ'] god ! I:['SPACY:POS-PRON'] 've found your number again ! I 'm so glad , text me back xafter this msgs cst std ntwk chg Â£1.50
# -------------------------
# ==================================================
# Rank 11
# Pattern: [['HYPERNYM3:assertion.n.01']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 32 (0.9%)
# Gain = 0.026
# Metric (F_0.05) = 0.966
# Examples ~ Class Positive:
# [MATCH]: Today 's Offer ! Claim:['HYPERNYM3:assertion.n.01'] ur Â£150 worth of discount vouchers ! Text YES to 85023 now ! SavaMob , member offers mobile ! T Cs 08717898035 . Â£3.00 Sub . 16 . Unsub reply X
# -------------------------
# [MATCH]: URGENT ! We are trying to contact you . Last weekends draw shows that you have won a Â£900 prize GUARANTEED . Call 09061701851 . Claim:['HYPERNYM3:assertion.n.01'] code K61 . Valid 12hours only
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Rank 12
# Pattern: [['TEXT:;']]
# Window size: 3
# Class: Negative
# Precision: 1.000
# Match: 193 (5.4%)
# Gain = 0.012
# Metric (F_0.05) = 0.964
# Examples ~ Class Negative:
# [MATCH]: ;:['TEXT:;'] - ( oh well , c u later
# -------------------------
# [MATCH]: House - Maid is the murderer , coz the man was murdered on   & lt;#&gt ;:['TEXT:;'] th January .. As public holiday all govt.instituitions are closed , including post office .. understand ?
# -------------------------
# Counterexamples ~ Not class Negative:
#
# ==================================================
# Rank 13
# Pattern: [['TEXT:tone']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 30 (0.8%)
# Gain = 0.024
# Metric (F_0.05) = 0.963
# Examples ~ Class Positive:
# [MATCH]: 25p 4 alfie Moon 's Children in need song on ur mob . Tell ur m8s . Txt Tone:['TEXT:tone'] charity to 8007 for Nokias or Poly charity for polys : zed 08701417012 profit 2 charity .
# -------------------------
# [MATCH]: FREE for 1st week ! No1 Nokia tone:['TEXT:tone'] 4 ur mobile every week just txt NOKIA to 8077 Get txting and tell ur mates . www.getzed.co.uk POBox 36504 W45WQ 16 + norm150p / tone
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Rank 14
# Pattern: [['TEXT:18']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 30 (0.8%)
# Gain = 0.024
# Metric (F_0.05) = 0.963
# Examples ~ Class Positive:
# [MATCH]: FREE entry into our Â£250 weekly comp just send the word ENTER to 84128 NOW . 18:['TEXT:18'] T&C www.textcomp.com cust care 08712405020 .
# -------------------------
# [MATCH]: Urgent UR awarded a complimentary trip to EuroDisinc Trav , Aco&Entry41 Or Â£1000 . To claim txt DIS to 87121 18:['TEXT:18'] + 6*Â£1.50(moreFrmMob . ShrAcomOrSglSuplt)10 , LS1 3AJ
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Rank 15
# Pattern: [['HYPERNYM3:prize.n.01']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 29 (0.8%)
# Gain = 0.024
# Metric (F_0.05) = 0.962
# Examples ~ Class Positive:
# [MATCH]: You have won a guaranteed 32000 award:['HYPERNYM3:prize.n.01'] or maybe even Â£1000 cash to claim ur award call free on 0800 ..... ( 18 + ) . Its a legitimat efreefone number wat do u think ? ? ?
# -------------------------
# [MATCH]: + 123 Congratulations - in this week 's competition draw u have won the Â£1450 prize:['HYPERNYM3:prize.n.01'] to claim just call 09050002311 b4280703 . T&Cs / stop SMS 08718727868 . Over 18 only 150ppm
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Rank 16
# Pattern: [['TEXT:..']]
# Window size: 3
# Class: Negative
# Precision: 0.986
# Match: 281 (7.9%)
# Gain = 0.012
# Metric (F_0.05) = 0.962
# Examples ~ Class Negative:
# [MATCH]: Can Ã¼ all decide faster cos my sis going home liao ..:['TEXT:..']
# -------------------------
# [MATCH]: For me the love should start with attraction.i should feel that I need her every time around me.she should be the first thing which comes in my thoughts . I would start the day and end it with her.she should be there every time I dream.love will be then when my every breath has her name.my life should happen around her.my life will be named to her . I would cry for her.will give all my happiness and take all her sorrows . I will be ready to fight with anyone for her . I will be in love when I will be doing the craziest things for her.love will be when I do n't have to proove anyone that my girl is the most beautiful lady on the whole planet . I will always be singing praises for her.love will be when I start up making chicken curry and end up makiing sambar.life will be the most beautiful then.will get every morning and thank god for the day because she is with me . I would like to say a lot ..:['TEXT:..'] will tell later ..
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: thesmszone.com lets you send free anonymous and masked messages ..:['TEXT:..'] im sending this message from there .. do you see the potential for abuse ? ? ?
# -------------------------
# [MATCH]: HOT LIVE FANTASIES call now 08707509020 Just 20p per min NTT Ltd , PO Box 1327 Croydon CR9 5WB 0870 ..:['TEXT:..'] k
# -------------------------
# ==================================================
# Rank 17
# Pattern: [['TEXT:but']]
# Window size: 3
# Class: Negative
# Precision: 0.988
# Match: 243 (6.8%)
# Gain = 0.011
# Metric (F_0.05) = 0.960
# Examples ~ Class Negative:
# [MATCH]: I told her I had a Dr appt next week . She thinks I 'm gon na die . I told her its just a check . Nothing to be worried about . But:['TEXT:but'] she did n't listen .
# -------------------------
# [MATCH]: But:['TEXT:but'] you dint in touch with me .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: For sale - arsenal dartboard . Good condition but:['TEXT:but'] no doubles or trebles !
# -------------------------
# [MATCH]: SMS . ac JSco : Energy is high , but:['TEXT:but'] u may not know where 2channel it . 2day ur leadership skills r strong . Psychic ? Reply ANS w / question . End ? Reply END JSCO
# -------------------------
# ==================================================
# Rank 18
# Pattern: [['HYPERNYM3:claim.v.03']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 27 (0.8%)
# Gain = 0.022
# Metric (F_0.05) = 0.959
# Examples ~ Class Positive:
# [MATCH]: Congratulations U can claim:['HYPERNYM3:claim.v.03'] 2 VIP row A Tickets 2 C Blu in concert in November or Blu gift guaranteed Call 09061104276 to claim TS&Cs www.smsco.net costÂ£3.75max
# -------------------------
# [MATCH]: You have won a guaranteed 32000 award or maybe even Â£1000 cash to claim:['HYPERNYM3:claim.v.03'] ur award call free on 0800 ..... ( 18 + ) . Its a legitimat efreefone number wat do u think ? ? ?
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Rank 19
# Pattern: [['SPACY:POS-SPACE']]
# Window size: 3
# Class: Negative
# Precision: 1.000
# Match: 161 (4.5%)
# Gain = 0.010
# Metric (F_0.05) = 0.957
# Examples ~ Class Negative:
# [MATCH]: Do you know what Mallika Sherawat did yesterday ? Find out now @  :['SPACY:POS-SPACE'] & lt;URL&gt ;
# -------------------------
# [MATCH]: I wnt to buy a BMW car urgently .. its vry urgent.but hv a shortage of  :['SPACY:POS-SPACE'] & lt;#&gt ; Lacs.there is no source to arng dis amt . & lt;#&gt ; lacs .. thats my prob
# -------------------------
# Counterexamples ~ Not class Negative:
#
# ==================================================
# Rank 20
# Pattern: [['TEXT:awarded']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 25 (0.7%)
# Gain = 0.020
# Metric (F_0.05) = 0.956
# Examples ~ Class Positive:
# [MATCH]: WIN URGENT ! Your mobile number has been awarded:['TEXT:awarded'] with a Â£2000 prize GUARANTEED call 09061790121 from land line . claim 3030 valid 12hrs only 150ppm
# -------------------------
# [MATCH]: UR awarded:['TEXT:awarded'] a City Break and could WIN a Â£200 Summer Shopping spree every WK . Txt STORE to 88039 . SkilGme . TsCs087147403231Winawk!Age16 Â£1.50perWKsub
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Rank 21
# Pattern: [['TEXT:â£1000']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 25 (0.7%)
# Gain = 0.020
# Metric (F_0.05) = 0.956
# Examples ~ Class Positive:
# [MATCH]: Great News ! Call FREEFONE 08006344447 to claim your guaranteed Â£1000:['TEXT:â£1000'] CASH or Â£2000 gift . Speak to a live operator NOW !
# -------------------------
# [MATCH]: Please call our customer service representative on FREEPHONE 0808 145 4742 between 9am-11pm as you have WON a guaranteed Â£1000:['TEXT:â£1000'] cash or Â£5000 prize !
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Rank 22
# Pattern: [['TEXT:150ppm']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 25 (0.7%)
# Gain = 0.020
# Metric (F_0.05) = 0.956
# Examples ~ Class Positive:
# [MATCH]: Congrats ! Nokia 3650 video camera phone is your Call 09066382422 Calls cost 150ppm:['TEXT:150ppm'] Ave call 3mins vary from mobiles 16 + Close 300603 post BCM4284 Ldn WC1N3XX
# -------------------------
# [MATCH]: You are awarded a SiPix Digital Camera ! call 09061221061 from landline . Delivery within 28days . T Cs Box177 . M221BP . 2yr warranty . 150ppm:['TEXT:150ppm'] . 16 . p pÂ£3.99
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Rank 23
# Pattern: [["TEXT:'m"]]
# Window size: 3
# Class: Negative
# Precision: 0.983
# Match: 241 (6.8%)
# Gain = 0.010
# Metric (F_0.05) = 0.955
# Examples ~ Class Negative:
# [MATCH]: Yes , i 'm:["TEXT:'m"] small kid .. And boost is the secret of my energy ..
# -------------------------
# [MATCH]: Just trying to figure out when I 'm:["TEXT:'m"] suppose to see a couple different people this week . We said we 'd get together but I did n't set dates
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Guess who am I?This is the first time I created a web page WWW.ASJESUS.COM read all I wrote . I 'm:["TEXT:'m"] waiting for your opinions . I want to be your friend 1/1
# -------------------------
# [MATCH]: Oh my god ! I 've found your number again ! I 'm:["TEXT:'m"] so glad , text me back xafter this msgs cst std ntwk chg Â£1.50
# -------------------------
# ==================================================
# Rank 24
# Pattern: [['HYPERNYM3:outgo.n.01']]
# Window size: 3
# Class: Positive
# Precision: 0.969
# Match: 64 (1.8%)
# Gain = 0.048
# Metric (F_0.05) = 0.953
# Examples ~ Class Positive:
# [MATCH]: You have WON a guaranteed Â£1000 cash:['HYPERNYM3:outgo.n.01'] or a Â£2000 prize . To claim yr prize call our customer service representative on
# -------------------------
# [MATCH]: U've been selected to stay in 1 of 250 top British hotels - FOR NOTHING ! Holiday valued at Â£350 ! Dial 08712300220 to claim - National Rate:['HYPERNYM3:outgo.n.01'] Call . Bx526 , SW73SS
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Nah it 's straight , if you can just bring bud or drinks or something that 's actually a little more useful than straight cash:['HYPERNYM3:outgo.n.01']
# -------------------------
# [MATCH]: Remember all those whom i hurt during days of satanic imposter in me.need to pay a price:['HYPERNYM3:outgo.n.01'] , so be it.may destiny keep me going and as u said pray that i get the mind to get over the same .
# -------------------------
# ==================================================
# Rank 25
# Pattern: [['HYPERNYM3:television_equipment.n.01']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 23 (0.6%)
# Gain = 0.019
# Metric (F_0.05) = 0.952
# Examples ~ Class Positive:
# [MATCH]: We tried to contact you re your reply to our offer of a Video Phone 750 anytime any network mins Half Price Line Rental Camcorder:['HYPERNYM3:television_equipment.n.01'] Reply or call 08000930705
# -------------------------
# [MATCH]: Had your mobile 11mths ? Update for FREE to Oranges latest colour camera:['HYPERNYM3:television_equipment.n.01'] mobiles & unlimited weekend calls . Call Mobile Upd8 on freefone 08000839402 or 2StopTxt
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Rank 26
# Pattern: [['SPACY:POS-PRON'], ['TEXT:i']]
# Window size: 4
# Class: Negative
# Precision: 0.985
# Match: 202 (5.7%)
# Gain = 0.008
# Metric (F_0.05) = 0.951
# Examples ~ Class Negative:
# [MATCH]: No need to say anything to me:['SPACY:POS-PRON'] . I:['TEXT:i'] know i am an outsider
# -------------------------
# [MATCH]: Call me:['SPACY:POS-PRON'] , i:['TEXT:i'] am senthil from hsbc .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Hello darling how are you:['SPACY:POS-PRON'] today ? I:['TEXT:i'] would love to have a chat , why do nt you tell me what you look like and what you are in to sexy ?
# -------------------------
# [MATCH]: sexy sexy cum and text me:['SPACY:POS-PRON'] i:['TEXT:i'] m wet and warm and ready for some porn ! u up for some fun ? THIS MSG IS FREE RECD MSGS 150P INC VAT 2 CANCEL TEXT STOP
# -------------------------
# ==================================================
# Rank 27
# Pattern: [['HYPERNYM3:match.v.01']]
# Window size: 3
# Class: Negative
# Precision: 0.985
# Match: 199 (5.6%)
# Gain = 0.008
# Metric (F_0.05) = 0.951
# Examples ~ Class Negative:
# [MATCH]: What you did:['HYPERNYM3:match.v.01'] in   leave .
# -------------------------
# [MATCH]: I 'm okay . Chasing the dream . What 's good . What are you doing:['HYPERNYM3:match.v.01'] next .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: WELL DONE:['HYPERNYM3:match.v.01'] ! Your 4 * Costa Del Sol Holiday or Â£5000 await collection . Call 09050090044 Now toClaim . SAE , TCs , POBox334 , Stockport , SK38xh , CostÂ£1.50/pm , Max10mins
# -------------------------
# [MATCH]: Do:['HYPERNYM3:match.v.01'] n't b floppy ... b snappy & happy ! Only gay chat service with photo upload call 08718730666 ( 10p / min ) . 2 stop our texts call 08712460324
# -------------------------
# ==================================================
# Rank 28
# Pattern: [['TEXT:urgent']]
# Window size: 3
# Class: Positive
# Precision: 0.976
# Match: 41 (1.1%)
# Gain = 0.031
# Metric (F_0.05) = 0.950
# Examples ~ Class Positive:
# [MATCH]: Please CALL 08712402779 immediately as there is an urgent:['TEXT:urgent'] message waiting for you
# -------------------------
# [MATCH]: Urgent:['TEXT:urgent'] ! Please call 09061743811 from landline . Your ABTA complimentary 4 * Tenerife Holiday or Â£5000 cash await collection SAE T&Cs Box 326 CW25WX 150ppm
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I might come to kerala for 2 days.so you can be prepared to take a leave once i finalise .dont plan any travel during my visit.need to finish urgent:['TEXT:urgent'] works .
# -------------------------
# ==================================================
# Rank 29
# Pattern: [['SPACY:POS-PRON', 'TEXT:it']]
# Window size: 3
# Class: Negative
# Precision: 0.963
# Match: 379 (10.6%)
# Gain = 0.010
# Metric (F_0.05) = 0.946
# Examples ~ Class Negative:
# [MATCH]: I do n't run away frm u ... I walk slowly & amp ; it:['TEXT:it', 'SPACY:POS-PRON'] kills me that u do n't care enough to stop me ...
# -------------------------
# [MATCH]: What are you doing in langport ? Sorry , but I 'll probably be in bed by 9 pm . It:['TEXT:it', 'SPACY:POS-PRON'] sucks being ill at xmas ! When do you and go2sri lanka ?
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Got what it:['TEXT:it', 'SPACY:POS-PRON'] takes 2 take part in the WRC Rally in Oz ? U can with Lucozade Energy ! Text RALLY LE to 61200 ( 25p ) , see packs or lucozade.co.uk/wrc & itcould be u !
# -------------------------
# [MATCH]: Hungry gay guys feeling hungry and up 4 it:['TEXT:it', 'SPACY:POS-PRON'] , now . Call 08718730555 just 10p / min . To stop texts call 08712460324 ( 10p / min )
# -------------------------
# ==================================================
# Rank 30
# Pattern: [['SPACY:POS-PRON'], ['TEXT:in']]
# Window size: 4
# Class: Negative
# Precision: 0.988
# Match: 164 (4.6%)
# Gain = 0.007
# Metric (F_0.05) = 0.946
# Examples ~ Class Negative:
# [MATCH]: How many times i:['SPACY:POS-PRON'] told in:['TEXT:in'] the stage all use to laugh . You not listen aha .
# -------------------------
# [MATCH]: " SYMPTOMS " when U:['SPACY:POS-PRON'] are in:['TEXT:in'] love : " 1.U like listening songs 2.U get stopped where u see the name of your beloved 3.U wo n't get angry when your
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Do you:['SPACY:POS-PRON'] realize that in:['TEXT:in'] about 40 years , we 'll have thousands of old ladies running around with tattoos ?
# -------------------------
# [MATCH]: Hello darling how are you today ? I would love to have a chat , why do nt you tell me what you look like and what you:['SPACY:POS-PRON'] are in:['TEXT:in'] to sexy ?
# -------------------------
# ==================================================
# Rank 31
# Pattern: [['TEXT:16']]
# Window size: 3
# Class: Positive
# Precision: 0.974
# Match: 38 (1.1%)
# Gain = 0.028
# Metric (F_0.05) = 0.946
# Examples ~ Class Positive:
# [MATCH]: FREE for 1st week ! No1 Nokia tone 4 ur mobile every week just txt NOKIA to 8077 Get txting and tell ur mates . www.getzed.co.uk POBox 36504 W45WQ 16:['TEXT:16'] + norm150p / tone
# -------------------------
# [MATCH]: Urgent ! Please call 09061213237 from landline . Â£5000 cash or a luxury 4 * Canary Islands Holiday await collection . T&Cs SAE PO Box 177 . M227XY . 150ppm . 16:['TEXT:16'] +
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Hey ... Great deal ... Farm tour 9 am to 5 pm $ 95/pax , $ 50 deposit by 16:['TEXT:16'] May
# -------------------------
# ==================================================
# Rank 32
# Pattern: [['TEXT:...'], ['SPACY:POS-PRON']]
# Window size: 4
# Class: Negative
# Precision: 0.993
# Match: 144 (4.0%)
# Gain = 0.007
# Metric (F_0.05) = 0.945
# Examples ~ Class Negative:
# [MATCH]: I dun thk i 'll quit yet ... Hmmm , can go jazz ? Yogasana oso can ...:['TEXT:...'] We:['SPACY:POS-PRON'] can go meet em after our lessons den ...
# -------------------------
# [MATCH]: Good morning , my Love ...:['TEXT:...'] I:['SPACY:POS-PRON'] go to sleep now and wish you a great day full of feeling better and opportunity ... You are my last thought babe , I LOVE YOU * kiss *
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Hi , this is Mandy Sullivan calling from HOTMIX FM ...:['TEXT:...'] you:['SPACY:POS-PRON'] are chosen to receive Â£5000.00 in our Easter Prize draw ..... Please telephone 09041940223 to claim before 29/03/05 or your prize will be transferred to someone else ....
# -------------------------
# ==================================================
# Rank 33
# Pattern: [['TEXT:ok']]
# Window size: 3
# Class: Negative
# Precision: 0.988
# Match: 161 (4.5%)
# Gain = 0.007
# Metric (F_0.05) = 0.945
# Examples ~ Class Negative:
# [MATCH]: Its ok:['TEXT:ok'] .. come to my home it vl nice to meet and v can chat ..
# -------------------------
# [MATCH]: Ok:['TEXT:ok'] lor ... Sony ericsson salesman ... I ask shuhui then she say quite gd 2 use so i considering ...
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: FreeMsg : Claim ur 250 SMS messages - Text OK:['TEXT:ok'] to 84025 now!Use web2mobile 2 ur mates etc . Join Txt250.com for 1.50p / wk . T&C BOX139 , LA32WU . 16 . Remove txtX or stop
# -------------------------
# [MATCH]: accordingly . I repeat , just text the word ok:['TEXT:ok'] on your mobile phone and send
# -------------------------
# ==================================================
# Rank 34
# Pattern: [['HYPERNYM3:corner.n.08']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 20 (0.6%)
# Gain = 0.016
# Metric (F_0.05) = 0.945
# Examples ~ Class Positive:
# [MATCH]: Shop till u Drop , IS IT YOU , either 10 K , 5 K , Â£500 Cash or Â£100 Travel voucher , Call now , 09064011000 . NTT PO Box:['HYPERNYM3:corner.n.08'] CR01327BT fixedline Cost 150ppm mobile vary
# -------------------------
# [MATCH]: Urgent ! call 09066350750 from your landline . Your complimentary 4 * Ibiza Holiday or 10,000 cash await collection SAE T&Cs PO BOX:['HYPERNYM3:corner.n.08'] 434 SK3 8WP 150 ppm 18 +
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Rank 35
# Pattern: [['TEXT:come']]
# Window size: 3
# Class: Negative
# Precision: 0.993
# Match: 140 (3.9%)
# Gain = 0.007
# Metric (F_0.05) = 0.943
# Examples ~ Class Negative:
# [MATCH]: Eh ur laptop got no stock lei ... He say mon muz come:['TEXT:come'] again to take a look c got a not ...
# -------------------------
# [MATCH]: Call me when u finish then i come:['TEXT:come'] n pick u.
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: How come:['TEXT:come'] it takes so little time for a child who is afraid of the dark to become a teenager who wants to stay out all night ?
# -------------------------
# ==================================================
# Rank 36
# Pattern: [['TEXT:me']]
# Window size: 3
# Class: Negative
# Precision: 0.956
# Match: 451 (12.6%)
# Gain = 0.010
# Metric (F_0.05) = 0.942
# Examples ~ Class Negative:
# [MATCH]: On ma way to school . Can you pls send me:['TEXT:me'] ashley 's number
# -------------------------
# [MATCH]: No shit , but I was n't that surprised , so I went and spent the evening with that french guy I met in town here and we fooled around a bit but I did n't let him fuck me:['TEXT:me']
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Hi babe its Jordan , how r u ? I m home from abroad and lonely , text me:['TEXT:me'] back if u wanna chat xxSP visionsms.com Text stop to stopCost 150p 08712400603
# -------------------------
# [MATCH]: I do n't know u and u do n't know me:['TEXT:me'] . Send CHAT to 86688 now and let 's find each other ! Only 150p / Msg rcvd . HG / Suite342/2Lands / Row / W1J6HL LDN . 18 years or over .
# -------------------------
# ==================================================
# Rank 37
# Pattern: [['SPACY:POS-PRON'], ['TEXT:...']]
# Window size: 4
# Class: Negative
# Precision: 1.000
# Match: 118 (3.3%)
# Gain = 0.007
# Metric (F_0.05) = 0.941
# Examples ~ Class Negative:
# [MATCH]: Leave it wif me:['SPACY:POS-PRON'] lar ...:['TEXT:...'] Ãœ wan to carry meh so heavy ... Is da num 98321561 familiar to Ã¼ ?
# -------------------------
# [MATCH]: Lmao you know me:['SPACY:POS-PRON'] so well ...:['TEXT:...']
# -------------------------
# Counterexamples ~ Not class Negative:
#
# ==================================================
# Rank 38
# Pattern: [['TEXT:that']]
# Window size: 3
# Class: Negative
# Precision: 0.959
# Match: 338 (9.5%)
# Gain = 0.008
# Metric (F_0.05) = 0.940
# Examples ~ Class Negative:
# [MATCH]: You 're gon na have to be way more specific than that:['TEXT:that']
# -------------------------
# [MATCH]: Sorry . You never hear unless you book it . One was kinda a joke -- thet were really looking for skinny white girls . The other was one line -- you can only do so much on camera with that:['TEXT:that'] . Something like that they 're casting on the look .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: URGENT ! We are trying to contact U. Todays draw shows that:['TEXT:that'] you have won a Â£800 prize GUARANTEED . Call 09050003091 from land line . Claim C52 . Valid12hrs only
# -------------------------
# [MATCH]: URGENT ! We are trying to contact U. Todays draw shows that:['TEXT:that'] you have won a Â£2000 prize GUARANTEED . Call 09066358361 from land line . Claim Y87 . Valid 12hrs only
# -------------------------
# ==================================================
# Rank 39
# Pattern: [['TEXT:10p']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 18 (0.5%)
# Gain = 0.015
# Metric (F_0.05) = 0.939
# Examples ~ Class Positive:
# [MATCH]: This is the 2nd time we have tried 2 contact u. U have won the 750 Pound prize . 2 claim is easy , call 08718726970 NOW ! Only 10p:['TEXT:10p'] per min . BT - national - rate
# -------------------------
# [MATCH]: This is the 2nd time we have tried 2 contact u. U have won the 750 Pound prize . 2 claim is easy , call 08712101358 NOW ! Only 10p:['TEXT:10p'] per min . BT - national - rate
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Rank 40
# Pattern: [['TEXT:collection']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 18 (0.5%)
# Gain = 0.015
# Metric (F_0.05) = 0.939
# Examples ~ Class Positive:
# [MATCH]: Urgent ! Please call 09061213237 from landline . Â£5000 cash or a luxury 4 * Canary Islands Holiday await collection:['TEXT:collection'] . T&Cs SAE PO Box 177 . M227XY . 150ppm . 16 +
# -------------------------
# [MATCH]: Urgent ! Please call 09061743810 from landline . Your ABTA complimentary 4 * Tenerife Holiday or # 5000 cash await collection:['TEXT:collection'] SAE T&Cs Box 326 CW25WX 150 ppm
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Rank 41
# Pattern: [['TEXT:i'], ["TEXT:'ll"]]
# Window size: 4
# Class: Negative
# Precision: 1.000
# Match: 113 (3.2%)
# Gain = 0.007
# Metric (F_0.05) = 0.939
# Examples ~ Class Negative:
# [MATCH]: Sorry , I:['TEXT:i'] 'll:["TEXT:'ll"] call later
# -------------------------
# [MATCH]: Thought we could go out for dinner . I:['TEXT:i'] 'll:["TEXT:'ll"] treat you ! Seem ok ?
# -------------------------
# Counterexamples ~ Not class Negative:
#
# ==================================================
# Rank 42
# Pattern: [['TEXT:how']]
# Window size: 3
# Class: Negative
# Precision: 0.974
# Match: 189 (5.3%)
# Gain = 0.006
# Metric (F_0.05) = 0.938
# Examples ~ Class Negative:
# [MATCH]: Arms fine , how:['TEXT:how'] 's Cardiff and uni ?
# -------------------------
# [MATCH]: Hiya do u like the hlday pics looked horrible in them so took mo out ! How:['TEXT:how'] s the camp Amrca thing ? Speak soon Serena : )
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Babe : U want me do nt u baby ! I m nasty and have a thing 4 filthyguys . Fancy a rude time with a sexy bitch . How:['TEXT:how'] about we go slo n hard ! Txt XXX SLO(4msgs )
# -------------------------
# [MATCH]: Hello darling how:['TEXT:how'] are you today ? I would love to have a chat , why do nt you tell me what you look like and what you are in to sexy ?
# -------------------------
# ==================================================
# Rank 43
# Pattern: [['TEXT:he']]
# Window size: 3
# Class: Negative
# Precision: 1.000
# Match: 108 (3.0%)
# Gain = 0.007
# Metric (F_0.05) = 0.936
# Examples ~ Class Negative:
# [MATCH]: He:['TEXT:he'] is there . You call and meet him
# -------------------------
# [MATCH]: Derp . Which is worse , a dude who always wants to party or a dude who files a complaint about the three drug abusers he:['TEXT:he'] lives with
# -------------------------
# Counterexamples ~ Not class Negative:
#
# ==================================================
# Rank 44
# Pattern: [['SPACY:POS-PRON'], ['TEXT:it']]
# Window size: 4
# Class: Negative
# Precision: 1.000
# Match: 101 (2.8%)
# Gain = 0.006
# Metric (F_0.05) = 0.932
# Examples ~ Class Negative:
# [MATCH]: Let me:['SPACY:POS-PRON'] know how it:['TEXT:it'] changes in the next 6hrs . It can even be appendix but you are out of that age range . However its not impossible . So just chill and let me know in 6hrs
# -------------------------
# [MATCH]: What time you think you:['SPACY:POS-PRON'] 'll have it:['TEXT:it'] ? Need to know when I should be near campus
# -------------------------
# Counterexamples ~ Not class Negative:
#
# ==================================================
# Rank 45
# Pattern: [['TEXT:got']]
# Window size: 3
# Class: Negative
# Precision: 0.979
# Match: 143 (4.0%)
# Gain = 0.005
# Metric (F_0.05) = 0.931
# Examples ~ Class Negative:
# [MATCH]: I got:['TEXT:got'] to video tape pple type in message lor . U so free wan 2 help me ? Hee ... Cos i noe u wan 2 watch infernal affairs so ask u along . Asking shuhui oso .
# -------------------------
# [MATCH]: I got:['TEXT:got'] like $ & lt;#&gt ; , I can get some more later though . Get whatever you feel like
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Got:['TEXT:got'] what it takes 2 take part in the WRC Rally in Oz ? U can with Lucozade Energy ! Text RALLY LE to 61200 ( 25p ) , see packs or lucozade.co.uk/wrc & itcould be u !
# -------------------------
# [MATCH]: FreeMsg Hey U , i just got:['TEXT:got'] 1 of these video / pic fones , reply WILD to this txt & ill send U my pics , hurry up I m so bored at work xxx ( 18 150p / rcvd STOP2stop )
# -------------------------
# ==================================================
# Rank 46
# Pattern: [['TEXT:service']]
# Window size: 3
# Class: Positive
# Precision: 0.967
# Match: 30 (0.8%)
# Gain = 0.022
# Metric (F_0.05) = 0.931
# Examples ~ Class Positive:
# [MATCH]: You have WON a guaranteed Â£1000 cash or a Â£2000 prize . To claim yr prize call our customer service:['TEXT:service'] representative on
# -------------------------
# [MATCH]: Please call our customer service:['TEXT:service'] representative on 0800 169 6031 between 10am-9pm as you have WON a guaranteed Â£1000 cash or Â£5000 prize !
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: We have sent JD for Customer Service:['TEXT:service'] cum Accounts Executive to ur mail i d , For details contact us
# -------------------------
# ==================================================
# Rank 47
# Pattern: [['TEXT:mobile']]
# Window size: 3
# Class: Positive
# Precision: 0.942
# Match: 86 (2.4%)
# Gain = 0.060
# Metric (F_0.05) = 0.931
# Examples ~ Class Positive:
# [MATCH]: Do you want a New Nokia 3510i colour phone DeliveredTomorrow ? With 300 free minutes to any mobile:['TEXT:mobile'] + 100 free texts + Free Camcorder reply or call 08000930705
# -------------------------
# [MATCH]: URGENT ! : Your Mobile:['TEXT:mobile'] No . was awarded a Â£2,000 Bonus Caller Prize on 02/09/03 ! This is our 2nd attempt to contact YOU ! Call 0871 - 872 - 9755 BOX95QU
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Plz note : if anyone calling from a mobile:['TEXT:mobile'] Co. & amp ; asks u to type # & lt;#&gt ;   or # & lt;#&gt ; . Do not do so . Disconnect the call , coz it iz an attempt of ' terrorist ' to make use of the sim card no . Itz confirmd by nokia n motorola n has been verified by CNN IBN .
# -------------------------
# [MATCH]: Actually , my mobile:['TEXT:mobile'] is full of msg . And i m doing a work online , where i need to send them   & lt;#&gt ;   sent msg i wil explain u later .
# -------------------------
# ==================================================
# Rank 48
# Pattern: [["TEXT:n't"]]
# Window size: 3
# Class: Negative
# Precision: 0.967
# Match: 182 (5.1%)
# Gain = 0.005
# Metric (F_0.05) = 0.930
# Examples ~ Class Negative:
# [MATCH]: Hope ur head does n't:["TEXT:n't"] hurt 2 much ! Am ploughing my way through a pile of ironing ! Staying in with a chinky tonight come round if you like .
# -------------------------
# [MATCH]: I call you later , do n't:["TEXT:n't"] have network . If urgnt , sms me .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: I do n't:["TEXT:n't"] know u and u do n't know me . Send CHAT to 86688 now and let 's find each other ! Only 150p / Msg rcvd . HG / Suite342/2Lands / Row / W1J6HL LDN . 18 years or over .
# -------------------------
# [MATCH]: I do n't:["TEXT:n't"] know u and u do n't know me . Send CHAT to 86688 now and let 's find each other ! Only 150p / Msg rcvd . HG / Suite342/2Lands / Row / W1J6HL LDN . 18 years or over .
# -------------------------
# ==================================================
# Rank 49
# Pattern: [['TEXT:did']]
# Window size: 3
# Class: Negative
# Precision: 0.991
# Match: 111 (3.1%)
# Gain = 0.005
# Metric (F_0.05) = 0.929
# Examples ~ Class Negative:
# [MATCH]: I thk 50 shd be ok he said plus minus 10 .. Did:['TEXT:did'] Ã¼ leave a line in between paragraphs ?
# -------------------------
# [MATCH]: Re your call ; You did:['TEXT:did'] n't see my facebook huh ?
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Did:['TEXT:did'] you hear about the new " Divorce Barbie " ? It comes with all of Ken 's stuff !
# -------------------------
# ==================================================
# Rank 50
# Pattern: [['TEXT:txt']]
# Window size: 3
# Class: Positive
# Precision: 0.938
# Match: 96 (2.7%)
# Gain = 0.067
# Metric (F_0.05) = 0.928
# Examples ~ Class Positive:
# [MATCH]: 1000 's flirting NOW ! Txt:['TEXT:txt'] GIRL or BLOKE & ur NAME & AGE , eg GIRL ZOE 18 to 8007 to join and get chatting !
# -------------------------
# [MATCH]: No 1 POLYPHONIC tone 4 ur mob every week ! Just txt:['TEXT:txt'] PT2 to 87575 . 1st Tone FREE ! so get txtin now and tell ur friends . 150p / tone . 16 reply HL 4info
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: On the road so ca nt txt:['TEXT:txt']
# -------------------------
# [MATCH]: Oh yes I can speak txt:['TEXT:txt'] 2 u no ! Hmm . Did u get   email ?
# -------------------------
# ==================================================
# Rank 51
# Pattern: [['TEXT:going']]
# Window size: 3
# Class: Negative
# Precision: 0.984
# Match: 122 (3.4%)
# Gain = 0.005
# Metric (F_0.05) = 0.928
# Examples ~ Class Negative:
# [MATCH]: S .... s ... india going:['TEXT:going'] to draw the series after many years in south african soil ..
# -------------------------
# [MATCH]: Oh that s late ! Well have a good night and i will give u a call tomorrow . Iam now going:['TEXT:going'] to go to sleep night night
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: UR GOING:['TEXT:going'] 2 BAHAMAS ! CallFREEFONE 08081560665 and speak to a live operator to claim either Bahamas cruise ofÂ£2000 CASH 18+only . To opt out txt X to 07786200117
# -------------------------
# [MATCH]: Do you ever notice that when you 're driving , anyone going:['TEXT:going'] slower than you is an idiot and everyone driving faster than you is a maniac ?
# -------------------------
# ==================================================
# Rank 52
# Pattern: [['HYPERNYM3:make.v.03']]
# Window size: 3
# Class: Negative
# Precision: 0.952
# Match: 248 (7.0%)
# Gain = 0.005
# Metric (F_0.05) = 0.925
# Examples ~ Class Negative:
# [MATCH]: Dear relieved of westonzoyland , all going to plan:['HYPERNYM3:make.v.03'] this end too !
# -------------------------
# [MATCH]: I just made some payments so do:['HYPERNYM3:make.v.03'] nt have that much . Sorry . Would you want it fedex or the other way .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: -PLS STOP bootydelious ( 32/F ) is inviting:['HYPERNYM3:make.v.03'] you to be her friend . Reply YES-434 or NO-434 See her : www . SMS.ac / u / bootydelious STOP ? Send STOP FRND to 62468
# -------------------------
# [MATCH]: Dear 0776xxxxxxx U've been invited:['HYPERNYM3:make.v.03'] to XCHAT . This is our final attempt to contact u ! Txt CHAT to 86688 150p / MsgrcvdHG / Suite342/2Lands / Row / W1J6HL LDN 18yrs
# -------------------------
# ==================================================
# Rank 53
# Pattern: [['SPACY:POS-PRON'], ['TEXT:?']]
# Window size: 4
# Class: Negative
# Precision: 0.959
# Match: 195 (5.5%)
# Gain = 0.004
# Metric (F_0.05) = 0.925
# Examples ~ Class Negative:
# [MATCH]: Today is ACCEPT DAY .. U Accept me:['SPACY:POS-PRON'] as ?:['TEXT:?'] Brother Sister Lover Dear1 Best1 Clos1 Lvblefrnd Jstfrnd Cutefrnd Lifpartnr Belovd Swtheart Bstfrnd No rply means enemy
# -------------------------
# [MATCH]: Do u still have plumbers tape and a wrench we:['SPACY:POS-PRON'] could borrow ?:['TEXT:?']
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: EASTENDERS TV Quiz . What FLOWER does DOT compare herself:['SPACY:POS-PRON'] to ?:['TEXT:?'] D= VIOLET E= TULIP F= LILY txt D E or F to 84025 NOW 4 chance 2 WIN Â£100 Cash WKENT/150P16 +
# -------------------------
# [MATCH]: Guess what ! Somebody you know secretly fancies you ! Wanna find out who it:['SPACY:POS-PRON'] is ?:['TEXT:?'] Give us a call on 09065394514 From Landline DATEBox1282EssexCM61XN 150p / min 18
# -------------------------
# ==================================================
# Rank 54
# Pattern: [['HYPERNYM3:then.r.03']]
# Window size: 3
# Class: Negative
# Precision: 0.983
# Match: 116 (3.3%)
# Gain = 0.004
# Metric (F_0.05) = 0.924
# Examples ~ Class Negative:
# [MATCH]: Evening * v good if somewhat event laden . Will fill you in , do n't you worry â€ ¦ Head * ok but throat * wrecked . See you at six then:['HYPERNYM3:then.r.03'] !
# -------------------------
# [MATCH]: Aiyo cos i sms Ã¼ then:['HYPERNYM3:then.r.03'] Ã¼ neva reply so i wait 4 Ã¼ to reply lar . I tot Ã¼ have nt finish ur lab wat .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: FREE GAME . Get Rayman Golf 4 FREE from the O2 Games Arcade . 1st get UR games settings . Reply POST , then:['HYPERNYM3:then.r.03'] save & activ8 . Press 0 key for Arcade . Termsapply
# -------------------------
# [MATCH]: Hey Boys . Want hot XXX pics sent direct 2 ur phone ? Txt PORN to 69855 , 24Hrs free and then:['HYPERNYM3:then.r.03'] just 50p per day . To stop text STOPBCM SF WC1N3XX
# -------------------------
# ==================================================
# Rank 55
# Pattern: [['TEXT:home']]
# Window size: 3
# Class: Negative
# Precision: 0.990
# Match: 103 (2.9%)
# Gain = 0.005
# Metric (F_0.05) = 0.924
# Examples ~ Class Negative:
# [MATCH]: I just got home:['TEXT:home'] babe , are you still awake ?
# -------------------------
# [MATCH]: I 'm hungry buy smth home:['TEXT:home'] ...
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Hi babe its Jordan , how r u ? I m home:['TEXT:home'] from abroad and lonely , text me back if u wanna chat xxSP visionsms.com Text stop to stopCost 150p 08712400603
# -------------------------
# ==================================================
# Rank 56
# Pattern: [['SPACY:POS-PRON'], ['HYPERNYM3:exist.v.01']]
# Window size: 4
# Class: Negative
# Precision: 0.983
# Match: 115 (3.2%)
# Gain = 0.004
# Metric (F_0.05) = 0.923
# Examples ~ Class Negative:
# [MATCH]: I guess you:['SPACY:POS-PRON'] could be:['HYPERNYM3:exist.v.01'] as good an excuse as any , lol .
# -------------------------
# [MATCH]: Have you:['SPACY:POS-PRON'] always been:['HYPERNYM3:exist.v.01'] saying welp ?
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Ur TONEXS subscription has been renewed and you:['SPACY:POS-PRON'] have been:['HYPERNYM3:exist.v.01'] charged Â£4.50 . You can choose 10 more polys this month . www.clubzed.co.uk * BILLING MSG *
# -------------------------
# [MATCH]: You:['SPACY:POS-PRON'] will be:['HYPERNYM3:exist.v.01'] receiving this week 's Triple Echo ringtone shortly . Enjoy it !
# -------------------------
# ==================================================
# Rank 57
# Pattern: [['TEXT:nt']]
# Window size: 3
# Class: Negative
# Precision: 0.958
# Match: 189 (5.3%)
# Gain = 0.004
# Metric (F_0.05) = 0.922
# Examples ~ Class Negative:
# [MATCH]: Then its most likely called Mittelschmertz . Google it . If you do nt:['TEXT:nt'] have paracetamol do nt worry it will go .
# -------------------------
# [MATCH]: 1.20 that call cost . Which i guess is nt:['TEXT:nt'] bad . Miss ya , need ya , want ya , love ya
# -------------------------
# Counterexamples ~ Not class Negative:
# ...
# [MATCH]: Ur TONEXS subscription has been renewed and you:['SPACY:POS-PRON'] have been charged Â£4.50 . You can choose 10 more polys this month . www.clubzed.co.uk * BILLING MSG *
# -------------------------
# [MATCH]: 449050000301 You:['SPACY:POS-PRON'] have won a Â£2,000 price ! To claim , call 09050000301 .
# -------------------------
# ==================================================
# Rank 83
# Pattern: [['SPACY:POS-PRON'], ['HYPERNYM3:make.v.03']]
# Window size: 4
# Class: Negative
# Precision: 0.966
# Match: 118 (3.3%)
# Gain = 0.003
# Metric (F_0.05) = 0.909
# Examples ~ Class Negative:
# [MATCH]: U need my presnts always bcz U ca nt mis love . " jeevithathile irulinae neekunna prakasamanu sneham " prakasam ennal prabha ' That mns prabha is'LOVE ' Got it:['SPACY:POS-PRON'] . Do:['HYPERNYM3:make.v.03'] nt mis me ....
# -------------------------
# [MATCH]: I:['SPACY:POS-PRON'] can make:['HYPERNYM3:make.v.03'] it up there , squeezed   & lt;#&gt ;   bucks out of my dad
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Free msg . Sorry , a service you ordered from 81303 could not be delivered as you:['SPACY:POS-PRON'] do:['HYPERNYM3:make.v.03'] not have sufficient credit . Please top up to receive the service .
# -------------------------
# [MATCH]: accordingly . I:['SPACY:POS-PRON'] repeat:['HYPERNYM3:make.v.03'] , just text the word ok on your mobile phone and send
# -------------------------
# ==================================================
# Rank 84
# Pattern: [['HYPERNYM3:search.v.04']]
# Window size: 3
# Class: Negative
# Precision: 1.000
# Match: 75 (2.1%)
# Gain = 0.005
# Metric (F_0.05) = 0.909
# Examples ~ Class Negative:
# [MATCH]: Were gon na go:['HYPERNYM3:search.v.04'] get some tacos
# -------------------------
# [MATCH]: No way I 'm going:['HYPERNYM3:search.v.04'] back there !
# -------------------------
# Counterexamples ~ Not class Negative:
#
# ==================================================
# Rank 85
# Pattern: [['TEXT:in']]
# Window size: 3
# Class: Negative
# Precision: 0.920
# Match: 514 (14.4%)
# Gain = 0.004
# Metric (F_0.05) = 0.909
# Examples ~ Class Negative:
# [MATCH]: Sorry , was in:['TEXT:in'] the bathroom , sup
# -------------------------
# [MATCH]: FR'NDSHIP is like a needle of a clock . Though V r in:['TEXT:in'] d same clock , V r nt able 2 met . Evn if V meet , itz only 4few seconds . Bt V alwys stay conected . Gud 9t;- )
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Free msg : Single ? Find a partner in:['TEXT:in'] your area ! 1000s of real people are waiting to chat now!Send CHAT to 62220Cncl send STOPCS 08717890890Â£1.50 per msg
# -------------------------
# [MATCH]: FreeMsg Today 's the day if you are ready ! I 'm horny & live in:['TEXT:in'] your town . I love sex fun & games ! Netcollex Ltd 08700621170150p per msg reply Stop to end
# -------------------------
# ==================================================
# Rank 86
# Pattern: [['TEXT:at']]
# Window size: 3
# Class: Negative
# Precision: 0.936
# Match: 234 (6.6%)
# Gain = 0.003
# Metric (F_0.05) = 0.908
# Examples ~ Class Negative:
# [MATCH]: I 'm not driving ... Raining ! Then i 'll get caught at:['TEXT:at'] e mrt station lor .
# -------------------------
# [MATCH]: Night has ended for another day , morning has come in a special way . May you smile like the sunny rays and leaves your worries at:['TEXT:at'] the blue blue bay .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Hi its LUCY Hubby at:['TEXT:at'] meetins all day Fri & I will B alone at hotel U fancy cumin over ? Pls leave msg 2day 09099726395 Lucy x CallsÂ£1/minMobsmoreLKPOBOX177HP51FL
# -------------------------
# [MATCH]: Hi 07734396839 IBH Customer Loyalty Offer : The NEW NOKIA6600 Mobile from ONLY Â£10 at:['TEXT:at'] TXTAUCTION!Txt word : START to No:81151 & get Yours Now!4 T &
# -------------------------
# ==================================================
# Rank 87
# Pattern: [['HYPERNYM3:mobile.n.02']]
# Window size: 3
# Class: Positive
# Precision: 0.939
# Match: 33 (0.9%)
# Gain = 0.022
# Metric (F_0.05) = 0.908
# Examples ~ Class Positive:
# [MATCH]: Latest Nokia Mobile:['HYPERNYM3:mobile.n.02'] or iPOD MP3 Player + Â£400 proze GUARANTEED ! Reply with : WIN to 83355 now ! Norcorp Ltd . Â£1,50/Mtmsgrcvd18 +
# -------------------------
# [MATCH]: Get the official ENGLAND poly ringtone or colour flag on yer mobile:['HYPERNYM3:mobile.n.02'] for tonights game ! Text TONE or FLAG to 84199 . Optout txt ENG STOP Box39822 W111WX Â£1.50
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Hi , Mobile:['HYPERNYM3:mobile.n.02'] no .   & lt;#&gt ;   has added you in their contact list on www.fullonsms.com It s a great place to send free sms to people For more visit fullonsms.com
# -------------------------
# [MATCH]: Actually , my mobile:['HYPERNYM3:mobile.n.02'] is full of msg . And i m doing a work online , where i need to send them   & lt;#&gt ;   sent msg i wil explain u later .
# -------------------------
# ==================================================
# Rank 88
# Pattern: [['TEXT:good']]
# Window size: 3
# Class: Negative
# Precision: 0.949
# Match: 158 (4.4%)
# Gain = 0.003
# Metric (F_0.05) = 0.908
# Examples ~ Class Negative:
# [MATCH]: Short But Cute : " Be a good:['TEXT:good'] person , but do nt try to prove " ..... Gud mrng ...
# -------------------------
# [MATCH]: She 's good:['TEXT:good'] . How are you . Where r u working now
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Thank you , winner notified by sms . Good:['TEXT:good'] Luck ! No future marketing reply STOP to 84122 customer services 08450542832
# -------------------------
# [MATCH]: Ur balance is now Â£600 . Next question : Complete the landmark , Big , A. Bob , B. Barry or C. Ben ? . Text A , B or C to 83738 . Good:['TEXT:good'] luck !
# -------------------------
# ==================================================
# Rank 89
# Pattern: [['HYPERNYM3:match.v.01'], ['SPACY:POS-PRON']]
# Window size: 4
# Class: Negative
# Precision: 0.988
# Match: 84 (2.4%)
# Gain = 0.004
# Metric (F_0.05) = 0.907
# Examples ~ Class Negative:
# [MATCH]: Fine . Do:['HYPERNYM3:match.v.01'] you:['SPACY:POS-PRON'] remember me .
# -------------------------
# [MATCH]: Are your freezing ? Are you home yet ? Will you remember to kiss your mom in the morning ? Do:['HYPERNYM3:match.v.01'] you:['SPACY:POS-PRON'] love me ? Do you think of me ? Are you missing me yet ?
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Do:['HYPERNYM3:match.v.01'] you:['SPACY:POS-PRON'] realize that in about 40 years , we 'll have thousands of old ladies running around with tattoos ?
# -------------------------
# ==================================================
# Rank 90
# Pattern: [['TEXT:when']]
# Window size: 3
# Class: Negative
# Precision: 0.944
# Match: 178 (5.0%)
# Gain = 0.003
# Metric (F_0.05) = 0.907
# Examples ~ Class Negative:
# [MATCH]: Beautiful Truth against Gravity .. Read carefully : " Our heart feels light when:['TEXT:when'] someone is in it .. But it feels very heavy when someone leaves it .. " GOOD NIGHT
# -------------------------
# [MATCH]: Cool , text me when:['TEXT:when'] you head out
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: You have won a Nokia 7250i . This is what you get when:['TEXT:when'] you win our FREE auction . To take part send Nokia to 86021 now . HG / Suite342/2Lands Row / W1JHL 16 +
# -------------------------
# [MATCH]: U have won a nokia 6230 plus a free digital camera . This is what u get when:['TEXT:when'] u win our FREE auction . To take part send NOKIA to 83383 now . POBOX114/14TCR / W1 16
# -------------------------
# ==================================================
# Rank 91
# Pattern: [['TEXT:she']]
# Window size: 3
# Class: Negative
# Precision: 1.000
# Match: 73 (2.0%)
# Gain = 0.004
# Metric (F_0.05) = 0.907
# Examples ~ Class Negative:
# [MATCH]: Sad story of a Man - Last week was my b'day . My Wife did'nt wish me . My Parents forgot n so did my Kids . I went to work . Even my Colleagues did not wish . As I entered my cabin my PA said , '' Happy B'day Boss ! ! '' . I felt special . She:['TEXT:she'] askd me 4 lunch . After lunch she invited me to her apartment . We went there . She said , '' do u mind if I go into the bedroom for a minute ? '' ' ' OK '' , I sed in a sexy mood . She came out 5 minuts latr wid a cake ... n My Wife , My Parents , My Kidz , My Friends n My Colleagues . All screaming .. SURPRISE ! ! and I was waiting on the sofa .. ... ..... ' NAKED ... !
# -------------------------
# [MATCH]: I got it before the new year cos yetunde said she:['TEXT:she'] wanted to surprise you with it but when i did nt see money i returned it mid january before the   & lt;#&gt ; day return period ended .
# -------------------------
# Counterexamples ~ Not class Negative:
#
# ==================================================
# Rank 92
# Pattern: [['HYPERNYM3:travel.v.01']]
# Window size: 3
# Class: Negative
# Precision: 0.960
# Match: 125 (3.5%)
# Gain = 0.003
# Metric (F_0.05) = 0.907
# Examples ~ Class Negative:
# [MATCH]: Do n't forget though that I love you .... And I walk:['HYPERNYM3:travel.v.01'] beside you . Watching over you and keeping your heart warm .
# -------------------------
# [MATCH]: Nope wif my sis lor ... Aft bathing my dog then i can bathe ... Looks like it 's going:['HYPERNYM3:travel.v.01'] 2 rain soon .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Ur ringtone service has changed:['HYPERNYM3:travel.v.01'] ! 25 Free credits ! Go to club4mobiles.com to choose content now ! Stop ? txt CLUB STOP to 87070 . 150p / wk Club4 PO Box1146 MK45 2WT
# -------------------------
# [MATCH]: Dear Voucher Holder 2 claim your 1st class airport lounge passes:['HYPERNYM3:travel.v.01'] when using Your holiday voucher call 08704439680 . When booking quote 1st class x 2
# -------------------------
# ==================================================
# Rank 93
# Pattern: [['TEXT:sorry']]
# Window size: 3
# Class: Negative
# Precision: 0.971
# Match: 103 (2.9%)
# Gain = 0.003
# Metric (F_0.05) = 0.906
# Examples ~ Class Negative:
# [MATCH]: Sorry:['TEXT:sorry'] , I 'll call later
# -------------------------
# [MATCH]: Sorry:['TEXT:sorry'] , I 'll call later
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Sorry:['TEXT:sorry'] I missed your call let 's talk when you have the time . I 'm on 07090201529
# -------------------------
# [MATCH]: Sorry:['TEXT:sorry'] ! U can not unsubscribe yet . THE MOB offer package has a min term of 54 weeks > pls resubmit request after expiry . Reply THEMOB HELP 4 more info
# -------------------------
# ==================================================
# Rank 94
# Pattern: [['TEXT:love']]
# Window size: 3
# Class: Negative
# Precision: 0.970
# Match: 101 (2.8%)
# Gain = 0.003
# Metric (F_0.05) = 0.904
# Examples ~ Class Negative:
# [MATCH]: Just got part Nottingham - 3 hrs 63miles . Good thing i love:['TEXT:love'] my man so much , but only doing 40 mph . Hey ho
# -------------------------
# [MATCH]: I wonder how you got online , my love:['TEXT:love'] ? Had you gone to the net cafe ? Did you get your phone recharged ? Were you on a friends net ? I think of you , boytoy
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: FreeMsg Today 's the day if you are ready ! I 'm horny & live in your town . I love:['TEXT:love'] sex fun & games ! Netcollex Ltd 08700621170150p per msg reply Stop to end
# -------------------------
# [MATCH]: Hello darling how are you today ? I would love:['TEXT:love'] to have a chat , why do nt you tell me what you look like and what you are in to sexy ?
# -------------------------
# ==================================================
# Rank 95
# Pattern: [['TEXT:like']]
# Window size: 3
# Class: Negative
# Precision: 0.947
# Match: 150 (4.2%)
# Gain = 0.002
# Metric (F_0.05) = 0.903
# Examples ~ Class Negative:
# [MATCH]: A gram usually runs like:['TEXT:like']   & lt;#&gt ; , a half eighth is smarter though and gets you almost a whole second gram for   & lt;#&gt ;
# -------------------------
# [MATCH]: Same as u ... Dun wan ... Y u dun like:['TEXT:like'] me already ah ... Wat u doing now ? Still eating ?
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Bored of speed dating ? Try SPEEDCHAT , txt SPEEDCHAT to 80155 , if you do n't like:['TEXT:like'] em txt SWAP and get a new chatter ! Chat80155 POBox36504W45WQ 150p / msg rcd 16
# -------------------------
# [MATCH]: Download as many ringtones as u like:['TEXT:like'] no restrictions , 1000s 2 choose . U can even send 2 yr buddys . Txt Sir to 80082 Â£3
# -------------------------
# ==================================================
# Rank 96
# Pattern: [['TEXT:so']]
# Window size: 3
# Class: Negative
# Precision: 0.925
# Match: 280 (7.8%)
# Gain = 0.002
# Metric (F_0.05) = 0.903
# Examples ~ Class Negative:
# [MATCH]: I 'm in town now so:['TEXT:so'] i 'll jus take mrt down later .
# -------------------------
# [MATCH]: Nope ... Think i will go for it on monday ... Sorry i replied so:['TEXT:so'] late
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: WIN : We have a winner ! Mr. T. Foley won an iPod ! More exciting prizes soon , so:['TEXT:so'] keep an eye on ur mobile or visit www.win-82050.co.uk
# -------------------------
# [MATCH]: Oh my god ! I 've found your number again ! I 'm so:['TEXT:so'] glad , text me back xafter this msgs cst std ntwk chg Â£1.50
# -------------------------
# ==================================================
# Rank 97
# Pattern: [['TEXT:code']]
# Window size: 3
# Class: Positive
# Precision: 0.952
# Match: 21 (0.6%)
# Gain = 0.015
# Metric (F_0.05) = 0.902
# Examples ~ Class Positive:
# [MATCH]: PRIVATE ! Your 2003 Account Statement for shows 800 un - redeemed S. I. M. points . Call 08715203694 Identifier Code:['TEXT:code'] : 40533 Expires 31/10/04
# -------------------------
# [MATCH]: URGENT ! We are trying to contact you . Last weekends draw shows that you have won a Â£900 prize GUARANTEED . Call 09061701851 . Claim code:['TEXT:code'] K61 . Valid 12hours only
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: My sort code:['TEXT:code'] is   and acc no is . The bank is natwest . Can you reply to confirm i 've sent this to the right person !
# -------------------------
# ==================================================
# Rank 98
# Pattern: [['SPACY:POS-PRON'], ['TEXT:that']]
# Window size: 4
# Class: Negative
# Precision: 0.978
# Match: 89 (2.5%)
# Gain = 0.003
# Metric (F_0.05) = 0.902
# Examples ~ Class Negative:
# [MATCH]: So are you:['SPACY:POS-PRON'] guys asking that:['TEXT:that'] i get that slippers again or its gone with last year
# -------------------------
# [MATCH]: I don wake since . I:['SPACY:POS-PRON'] checked that:['TEXT:that'] stuff and saw that its true no available spaces . Pls call the embassy or send a mail to them .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Do you:['SPACY:POS-PRON'] ever notice that:['TEXT:that'] when you 're driving , anyone going slower than you is an idiot and everyone driving faster than you is a maniac ?
# -------------------------
# [MATCH]: Do you:['SPACY:POS-PRON'] realize that:['TEXT:that'] in about 40 years , we 'll have thousands of old ladies running around with tattoos ?
# -------------------------
# ==================================================
# Rank 99
# Pattern: [['TEXT:think']]
# Window size: 3
# Class: Negative
# Precision: 0.987
# Match: 79 (2.2%)
# Gain = 0.003
# Metric (F_0.05) = 0.902
# Examples ~ Class Negative:
# [MATCH]: You are always putting your business out there . You put pictures of your ass on facebook . You are one of the most open people i 've ever met . Why would i think:['TEXT:think'] a picture of your room would hurt you , make you feel violated .
# -------------------------
# [MATCH]: I think:['TEXT:think'] chennai well settled ?
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: You have won a guaranteed 32000 award or maybe even Â£1000 cash to claim ur award call free on 0800 ..... ( 18 + ) . Its a legitimat efreefone number wat do u think:['TEXT:think'] ? ? ?
# -------------------------
# ==================================================

# %%
print(f'  #    class Cov(%)    Prec  {grasp_model_3.gain_criteria}    Pattern')
for idx, p in enumerate(sorted(the_patterns_3, key = lambda x: x.metric, reverse = True)):
    print(f'{idx+1:>3} {p.support_class}   {round(p.coverage*100, 1):>4}   {p.precision:.3f}   {p.metric:.3f}    {p.get_pattern_id()}')
# Out:
#   #    class Cov(%)    Prec  F_0.05    Pattern
#   1 Positive    2.2   1.000   0.987    [['TEXT:claim']]
#   2 Positive    1.6   1.000   0.981    [['TEXT:prize']]
#   3 Negative   37.2   0.983   0.980    [['TEXT:i']]
#   4 Positive    1.3   1.000   0.978    [['TEXT:won']]
#   5 Negative   12.6   0.989   0.975    [['TEXT:...']]
#   6 Negative    8.2   0.997   0.973    [['TEXT:i'], ['SPACY:POS-PRON']]
#   7 Positive    1.1   1.000   0.971    [['TEXT:150p']]
#   8 Positive    1.1   1.000   0.971    [['TEXT:guaranteed']]
#   9 Negative   10.7   0.987   0.970    [['TEXT:my']]
#  10 Negative   18.0   0.977   0.967    [['SPACY:POS-PRON'], ['SPACY:POS-PRON']]
#  11 Negative   11.4   0.983   0.967    [['SPACY:POS-INTJ'], ['SPACY:POS-PRON']]
#  12 Positive    0.9   1.000   0.966    [['HYPERNYM3:assertion.n.01']]
#  13 Negative    5.4   1.000   0.964    [['TEXT:;']]
#  14 Positive    0.8   1.000   0.963    [['TEXT:tone']]
#  15 Positive    0.8   1.000   0.963    [['TEXT:18']]
#  16 Positive    0.8   1.000   0.962    [['HYPERNYM3:prize.n.01']]
#  17 Negative    7.9   0.986   0.962    [['TEXT:..']]
#  18 Negative    6.8   0.988   0.960    [['TEXT:but']]
#  19 Positive    0.8   1.000   0.959    [['HYPERNYM3:claim.v.03']]
#  20 Negative    4.5   1.000   0.957    [['SPACY:POS-SPACE']]
#  21 Positive    0.7   1.000   0.956    [['TEXT:awarded']]
#  22 Positive    0.7   1.000   0.956    [['TEXT:â£1000']]
#  23 Positive    0.7   1.000   0.956    [['TEXT:150ppm']]
#  24 Negative    6.8   0.983   0.955    [["TEXT:'m"]]
#  25 Positive    1.8   0.969   0.953    [['HYPERNYM3:outgo.n.01']]
#  26 Positive    0.6   1.000   0.952    [['HYPERNYM3:television_equipment.n.01']]
#  27 Negative    5.7   0.985   0.951    [['SPACY:POS-PRON'], ['TEXT:i']]
#  28 Negative    5.6   0.985   0.951    [['HYPERNYM3:match.v.01']]
#  29 Positive    1.1   0.976   0.950    [['TEXT:urgent']]
#  30 Negative   10.6   0.963   0.946    [['SPACY:POS-PRON', 'TEXT:it']]
#  31 Negative    4.6   0.988   0.946    [['SPACY:POS-PRON'], ['TEXT:in']]
#  32 Positive    1.1   0.974   0.946    [['TEXT:16']]
#  33 Negative    4.0   0.993   0.945    [['TEXT:...'], ['SPACY:POS-PRON']]
#  34 Negative    4.5   0.988   0.945    [['TEXT:ok']]
#  35 Positive    0.6   1.000   0.945    [['HYPERNYM3:corner.n.08']]
#  36 Negative    3.9   0.993   0.943    [['TEXT:come']]
#  37 Negative   12.6   0.956   0.942    [['TEXT:me']]
#  38 Negative    3.3   1.000   0.941    [['SPACY:POS-PRON'], ['TEXT:...']]
#  39 Negative    9.5   0.959   0.940    [['TEXT:that']]
#  40 Positive    0.5   1.000   0.939    [['TEXT:10p']]
#  41 Positive    0.5   1.000   0.939    [['TEXT:collection']]
#  42 Negative    3.2   1.000   0.939    [['TEXT:i'], ["TEXT:'ll"]]
#  43 Negative    5.3   0.974   0.938    [['TEXT:how']]
#  44 Negative    3.0   1.000   0.936    [['TEXT:he']]
#  45 Negative    2.8   1.000   0.932    [['SPACY:POS-PRON'], ['TEXT:it']]
#  46 Negative    4.0   0.979   0.931    [['TEXT:got']]
#  47 Positive    0.8   0.967   0.931    [['TEXT:service']]
#  48 Positive    2.4   0.942   0.931    [['TEXT:mobile']]
#  49 Negative    5.1   0.967   0.930    [["TEXT:n't"]]
#  50 Negative    3.1   0.991   0.929    [['TEXT:did']]
#  51 Positive    2.7   0.938   0.928    [['TEXT:txt']]
#  52 Negative    3.4   0.984   0.928    [['TEXT:going']]
#  53 Negative    7.0   0.952   0.925    [['HYPERNYM3:make.v.03']]
#  54 Negative    5.5   0.959   0.925    [['SPACY:POS-PRON'], ['TEXT:?']]
#  55 Negative    3.3   0.983   0.924    [['HYPERNYM3:then.r.03']]
#  56 Negative    2.9   0.990   0.924    [['TEXT:home']]
#  57 Negative    3.2   0.983   0.923    [['SPACY:POS-PRON'], ['HYPERNYM3:exist.v.01']]
#  58 Negative    5.3   0.958   0.922    [['TEXT:nt']]
#  59 Positive    0.4   1.000   0.922    [['TEXT:prize'], ['TEXT:claim']]
#  60 Positive    0.4   1.000   0.922    [['TEXT:won'], ['TEXT:prize']]
#  61 Negative    7.0   0.948   0.921    [['HYPERNYM3:not.r.01']]
#  62 Negative    2.4   1.000   0.921    [['TEXT:later']]
#  63 Negative    2.4   1.000   0.920    [['SPACY:POS-INTJ'], ['TEXT:...']]
#  64 Negative    2.7   0.990   0.920    [['SPACY:POS-PRON'], ['TEXT:my']]
#  65 Negative    2.4   1.000   0.919    [['TEXT:lor']]
#  66 Negative    3.4   0.975   0.919    [['HYPERNYM3:cause.v.01']]
#  67 Negative    2.4   1.000   0.918    [['TEXT:da']]
#  68 Negative    2.3   1.000   0.917    [['SPACY:POS-PRON'], ['HYPERNYM3:match.v.01']]
#  69 Negative    3.3   0.974   0.916    [['TEXT:so'], ['SPACY:POS-PRON']]
#  70 Negative    2.6   0.989   0.916    [['TEXT:i'], ['TEXT:am']]
#  71 Negative   10.3   0.932   0.915    [['TEXT:do']]
#  72 Negative    3.2   0.974   0.914    [['SPACY:POS-INTJ'], ['SPACY:POS-INTJ']]
#  73 Negative    3.2   0.974   0.914    [['SPACY:POS-PRON'], ['TEXT:me']]
#  74 Positive    0.7   0.958   0.914    [['TEXT:rate']]
#  75 Negative    2.2   1.000   0.913    [['SPACY:POS-PRON', 'TEXT:it'], ['SPACY:POS-PRON']]
#  76 Negative    4.1   0.959   0.913    [['SPACY:POS-PRON'], ['TEXT:do']]
#  77 Positive    0.6   0.957   0.911    [['HYPERNYM3:mobile.n.03']]
#  78 Negative    2.4   0.989   0.910    [['SPACY:POS-PRON'], ['TEXT:at']]
#  79 Positive    0.3   1.000   0.910    [['HYPERNYM3:outgo.n.01'], ['TEXT:prize']]
#  80 Positive    0.3   1.000   0.910    [['TEXT:urgent'], ['TEXT:mobile']]
#  81 Negative   26.7   0.915   0.910    [['SPACY:POS-INTJ']]
#  82 Negative    3.0   0.972   0.910    [['TEXT:me'], ['SPACY:POS-PRON']]
#  83 Negative   70.3   0.910   0.910    [['SPACY:POS-PRON']]
#  84 Negative    3.3   0.966   0.909    [['SPACY:POS-PRON'], ['HYPERNYM3:make.v.03']]
#  85 Negative    2.1   1.000   0.909    [['HYPERNYM3:search.v.04']]
#  86 Negative   14.4   0.920   0.909    [['TEXT:in']]
#  87 Negative    6.6   0.936   0.908    [['TEXT:at']]
#  88 Positive    0.9   0.939   0.908    [['HYPERNYM3:mobile.n.02']]
#  89 Negative    4.4   0.949   0.908    [['TEXT:good']]
#  90 Negative    2.4   0.988   0.907    [['HYPERNYM3:match.v.01'], ['SPACY:POS-PRON']]
#  91 Negative    5.0   0.944   0.907    [['TEXT:when']]
#  92 Negative    2.0   1.000   0.907    [['TEXT:she']]
#  93 Negative    3.5   0.960   0.907    [['HYPERNYM3:travel.v.01']]
#  94 Negative    2.9   0.971   0.906    [['TEXT:sorry']]
#  95 Negative    2.8   0.970   0.904    [['TEXT:love']]
#  96 Negative    4.2   0.947   0.903    [['TEXT:like']]
#  97 Negative    7.8   0.925   0.903    [['TEXT:so']]
#  98 Positive    0.6   0.952   0.902    [['TEXT:code']]
#  99 Negative    2.5   0.978   0.902    [['SPACY:POS-PRON'], ['TEXT:that']]
# 100 Negative    2.2   0.987   0.902    [['TEXT:think']]
