# %%
import pickle
from sklearn.model_selection import train_test_split
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
import nltk
from nltk.corpus import wordnet as wn
from nltk.wsd import lesk
from typing import Iterable, List, Set, Callable, Optional, Union, Sequence
from grasp import GrASP, CustomAttribute

# %% [markdown]
# ## Load the data
# - Download and unzip the spam dataset **if you have not done this before**

# %%
import urllib.request
url = 'http://www.dt.fee.unicamp.br/~tiago/smsspamcollection/smsspamcollection.zip'
filename = './data/smsspamcollection.zip'
urllib.request.urlretrieve(url, filename)

# %%
# !unzip ./data/smsspamcollection.zip -d ./data

# %% [markdown]
# - Load the data

# %%
def get_data():
    f = open('data/SMSSpamCollection.txt', 'r')
    texts, labels = [], []
    for line in f:
        line = line.strip()
        tab_idx = line.index('\t')
        label = line[:tab_idx]
        text = line[tab_idx+1:]
        if label == 'ham':
            label = 0
        elif label == 'spam':
            label = 1
        else:
            raise Exception(f"Invalid label - {label}")
        texts.append(text)
        labels.append(label)
    return texts, labels

# %%
texts, labels = get_data()
X_train, X_test, y_train, y_test = train_test_split(texts, labels, test_size=0.2, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1)
len(texts), sum(labels), len(X_test), sum(y_test)
# Out:
# (5574, 747, 1115, 138)

# %%
positive = [t for idx, t in enumerate(X_train) if y_train[idx]]
negative = [t for idx, t in enumerate(X_train) if not y_train[idx]]

# %% [markdown]
# ## Example 1

# %%
# Create the GrASP engine
grasp_model = GrASP(gaps_allowed = 0, num_patterns = 100)

# %%
# Fit GrASP to the dataset
the_patterns = grasp_model.fit_transform(positive, negative)
# Out:
#   0%|          | 0/488 [00:00<?, ?it/s]
# Step 1: Create augmented texts
# 100%|██████████| 488/488 [00:35<00:00, 13.56it/s]
# 100%|██████████| 3079/3079 [02:26<00:00, 20.99it/s]
# Step 2: Find frequent attributes
#   0%|          | 4/1336 [00:00<00:39, 33.70it/s]
# Total number of candidate alphabet = 1336, such as ['SPACY:DEP-ROOT', 'SPACY:POS-VERB', 'SPACY:POS-NOUN', 'SPACY:DEP-punct', 'SPACY:POS-PUNCT']
# Step 3: Find alphabet set
# 100%|██████████| 1336/1336 [00:52<00:00, 25.49it/s]
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
# Finding top k: 100 / 100
#   0%|          | 0/100 [00:00<?, ?it/s]
# Total number of alphabet = 100
# ['SPACY:POS-NUM', 'SPACY:DEP-compound', 'SPACY:NER-ORG', 'SPACY:POS-PROPN', 'SPACY:NER-DATE', 'TEXT:call', 'HYPERNYM:communication.n.02', 'SPACY:DEP-amod', 'TEXT:i', 'SPACY:POS-SYM', 'TEXT:free', 'TEXT:txt', 'TEXT:claim', 'TEXT:!', 'HYPERNYM:message.n.02', 'TEXT:mobile', 'SPACY:DEP-pobj', 'HYPERNYM:transferred_property.n.01', 'HYPERNYM:abstraction.n.06', 'TEXT:to', 'TEXT:prize', 'HYPERNYM:relation.n.01', 'HYPERNYM:win.v.01', 'SPACY:DEP-appos', 'SENTIMENT:pos', 'HYPERNYM:act.n.02', 'HYPERNYM:object.n.01', 'SPACY:NER-PERSON', 'TEXT:your', 'SPACY:POS-ADJ', 'TEXT:or', 'HYPERNYM:symbol.n.01', 'TEXT:text', 'HYPERNYM:entity.n.01', 'HYPERNYM:statement.n.01', 'TEXT:stop', 'SPACY:DEP-nmod', 'HYPERNYM:converse.v.01', 'HYPERNYM:book.n.01', 'TEXT:-', 'TEXT:150p', 'TEXT:guaranteed', 'TEXT:urgent', 'TEXT:win', 'HYPERNYM:written_communication.n.01', 'TEXT:+', 'SPACY:POS-PRON', 'TEXT:16', 'HYPERNYM:cash.n.02', 'HYPERNYM:artifact.n.01', 'HYPERNYM:creation.n.02', 'TEXT:from', 'HYPERNYM:assertion.n.01', 'TEXT:reply', 'SPACY:NER-GPE', 'TEXT:now', 'SPACY:DEP-dobj', 'HYPERNYM:award.n.02', 'TEXT:.', 'TEXT:tone', 'TEXT:18', 'HYPERNYM:acquisition.n.02', 'SPACY:POS-DET', 'HYPERNYM:measure.n.02', 'TEXT:nokia', 'TEXT:a', 'SPACY:DEP-conj', 'TEXT:our', 'HYPERNYM:mobile.n.02', 'HYPERNYM:minute.n.01', 'HYPERNYM:user.n.01', 'HYPERNYM:claim.v.03', 'TEXT:service', 'TEXT:contact', 'TEXT:for', 'TEXT:...', 'HYPERNYM:organism.n.01', 'HYPERNYM:offer.n.02', 'TEXT:awarded', 'TEXT:â£1000', 'TEXT:150ppm', 'HYPERNYM:document.n.01', 'TEXT:4', 'HYPERNYM:request.n.01', 'TEXT:per', 'HYPERNYM:call.v.28', 'HYPERNYM:television_equipment.n.01', 'SPACY:DEP-acl', 'HYPERNYM:land_line.n.01', 'TEXT:ur', 'TEXT:camera', 'HYPERNYM:phone.n.02', 'TEXT:rate', 'TEXT:my', 'HYPERNYM:plastic_art.n.01', 'TEXT:latest', 'HYPERNYM:text.n.04', 'TEXT:box', 'TEXT:draw', 'TEXT::']
# Example of patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 1
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Examples ~ Class Negative:
# [MATCH]: What i mean was i left too early to check , cos i 'm working a 9:['SPACY:POS-NUM'] - 6 .
# -------------------------
# [MATCH]: " I;m reaching in another 2:['SPACY:POS-NUM'] stops . "
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: important information 4:['SPACY:POS-NUM'] orange user 0789xxxxxxx . today is your lucky day!2find out why log onto http://www.urawinner.com THERE 'S A FANTASTIC SURPRISE AWAITING YOU !
# -------------------------
# [MATCH]: We tried to contact you re your reply to our offer of a Video Phone 750:['SPACY:POS-NUM'] anytime any network mins Half Price Line Rental Camcorder Reply or call 08000930705
# -------------------------
# ==================================================
# Pattern: [['SPACY:DEP-compound']]
# Window size: 1
# Class: Negative
# Precision: 0.680
# Match: 1379 (38.7%)
# Gain = 0.134
# Examples ~ Class Negative:
# [MATCH]: So when do you wanna gym:['SPACY:DEP-compound'] harri
# -------------------------
# [MATCH]: Desires- u going to doctor 4 liver . And get a bit stylish . Get ur:['SPACY:DEP-compound'] hair managed . That s it .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Hi 07734396839 IBH:['SPACY:DEP-compound'] Customer Loyalty Offer : The NEW NOKIA6600 Mobile from ONLY Â£10 at TXTAUCTION!Txt word : START to No:81151 & get Yours Now!4 T &
# -------------------------
# [MATCH]: < Forwarded from 21870000>Hi - this is your Mailbox:['SPACY:DEP-compound'] Messaging SMS alert . You have 40 matches . Please call back on 09056242159 to retrieve your messages and matches cc100p / min
# -------------------------
# ==================================================
# Pattern: [['SPACY:NER-ORG']]
# Window size: 1
# Class: Negative
# Precision: 0.527
# Match: 676 (19.0%)
# Gain = 0.127
# Examples ~ Class Negative:
# [MATCH]: Just hopeing that wasnâ€˜t:['SPACY:NER-ORG'] too pissed up to remember and has gone off to his sisters or something !
# -------------------------
# [MATCH]: Jolly good ! By the way ,  :['SPACY:NER-ORG'] will give u tickets for sat eve 7.30 . Speak before then x
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: YES ! The only place in town to meet exciting adult singles is now in the UK . Txt CHAT to 86688 now ! 150p:['SPACY:NER-ORG'] / Msg .
# -------------------------
# [MATCH]: Tone Club : Your subs has now expired 2 re - sub reply MONOC 4 monos or POLYC:['SPACY:NER-ORG'] 4 polys 1 weekly @ 150p per week Txt STOP 2 stop This msg free Stream 0871212025016
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN']]
# Window size: 1
# Class: Negative
# Precision: 0.690
# Match: 1347 (37.8%)
# Gain = 0.112
# Examples ~ Class Negative:
# [MATCH]: HAPPY:['SPACY:POS-PROPN'] NEW YEAR MY NO.1 MAN
# -------------------------
# [MATCH]: Can you plz tell me the ans . BSLVYL:['SPACY:POS-PROPN'] sent via fullonsms.com
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: You 've won tkts to the EURO2004:['SPACY:POS-PROPN'] CUP FINAL or Â£800 CASH , to collect CALL 09058099801 b4190604 , POBOX 7876150ppm
# -------------------------
# [MATCH]: I do n't know u and u do n't know me . Send CHAT:['SPACY:POS-PROPN'] to 86688 now and let 's find each other ! Only 150p / Msg rcvd . HG / Suite342/2Lands / Row / W1J6HL LDN . 18 years or over .
# -------------------------
# ==================================================
# Pattern: [['SPACY:NER-DATE']]
# Window size: 1
# Class: Negative
# Precision: 0.548
# Match: 651 (18.3%)
# Gain = 0.106
# Examples ~ Class Negative:
# [MATCH]: Happy birthday ... May:['SPACY:NER-DATE'] u find ur prince charming soon n dun work too hard ...
# -------------------------
# [MATCH]: Do you know what Mallika Sherawat did yesterday:['SPACY:NER-DATE'] ? Find out now @   & lt;URL&gt ;
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: U have a secret admirer who is looking 2 make contact with U - find out who they R*reveal who thinks UR so special - call on 09058094594:['SPACY:NER-DATE']
# -------------------------
# [MATCH]: Monthly:['SPACY:NER-DATE'] password for wap . mobsi.com is 391784 . Use your wap phone not PC .
# -------------------------
# ==================================================
# Step 4: Grow patterns
# 100%|██████████| 100/100 [02:18<00:00,  1.38s/it]
# Length 2 / 5; New candidates = 14950
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 1
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Examples ~ Class Negative:
# [MATCH]: Do whatever you want . You know what the rules are . We had a talk earlier this week about what had to start happening , you showing responsibility . Yet , every week it 's can i bend the rule this way ? What about that way ? Do whatever . I 'm tired of having thia same argument with you every week . And a   & lt;#&gt ;   movie DOESNT inlude the previews . You 're still getting in after 1:['SPACY:POS-NUM'] .
# -------------------------
# [MATCH]: I not free today i haf 2:['SPACY:POS-NUM'] pick my parents up tonite ...
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Had your mobile 11:['SPACY:POS-NUM'] months or more ? U R entitled to Update to the latest colour mobiles with camera for Free ! Call The Mobile Update Co FREE on 08002986030
# -------------------------
# [MATCH]: Eerie Nokia tones 4u:['SPACY:POS-NUM'] , rply TONE TITLE to 8007 eg TONE DRACULA to 8007 Titles : GHOST , ADDAMSFA , MUNSTERS , EXORCIST , TWILIGHT www.getzed.co.uk POBox36504W45WQ 150p
# -------------------------
# ==================================================
# Pattern: [['SPACY:NER-DATE', 'SPACY:POS-NUM']]
# Window size: 1
# Class: Positive
# Precision: 0.861
# Match: 280 (7.8%)
# Gain = 0.175
# Examples ~ Class Positive:
# [MATCH]: Please call our customer service representative on FREEPHONE 0808 145:['SPACY:POS-NUM', 'SPACY:NER-DATE'] 4742 between 9am-11pm as you have WON a guaranteed Â£1000 cash or Â£5000 prize !
# -------------------------
# [MATCH]: Your free ringtone is waiting to be collected . Simply text the password " MIX " to 85069:['SPACY:POS-NUM', 'SPACY:NER-DATE'] to verify . Get Usher and Britney . FML , PO Box 5249 , MK17 92H. 450Ppw 16
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Nothing lor ... A bit bored too ... Then y dun u go home early 2:['SPACY:POS-NUM', 'SPACY:NER-DATE'] sleep today ...
# -------------------------
# [MATCH]: Let me know how it changes in the next 6hrs:['SPACY:POS-NUM', 'SPACY:NER-DATE'] . It can even be appendix but you are out of that age range . However its not impossible . So just chill and let me know in 6hrs
# -------------------------
# ==================================================
# Pattern: [['SPACY:DEP-compound'], ['SPACY:POS-PROPN']]
# Window size: 2
# Class: Positive
# Precision: 0.641
# Match: 451 (12.6%)
# Gain = 0.157
# Examples ~ Class Positive:
# [MATCH]: Santa calling ! Would your little ones like a call from Santa:['SPACY:DEP-compound'] Xmas:['SPACY:POS-PROPN'] Eve ? Call 09077818151 to book you time . Calls1.50ppm last 3mins 30s T&C www.santacalling.com
# -------------------------
# [MATCH]: Goal ! Arsenal 4 ( Henry , 7 v Liverpool 2:['SPACY:DEP-compound'] Henry:['SPACY:POS-PROPN'] scores with a simple shot from 6 yards from a pass by Bergkamp to give Arsenal a 2 goal margin after 78 mins .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I AM AT A PARTY WITH ALEX:['SPACY:DEP-compound'] NICHOLS:['SPACY:POS-PROPN']
# -------------------------
# [MATCH]: FR'NDSHIP is like a needle of a clock . Though V r in d same clock , V r nt able 2 met . Evn if V meet , itz only 4few seconds . Bt:['SPACY:DEP-compound'] V:['SPACY:POS-PROPN'] alwys stay conected . Gud 9t;- )
# -------------------------
# ==================================================
# Pattern: [['SPACY:DEP-compound', 'SPACY:POS-PROPN']]
# Window size: 1
# Class: Positive
# Precision: 0.542
# Match: 583 (16.3%)
# Gain = 0.147
# Examples ~ Class Positive:
# [MATCH]: Urgent ! Please call 09061213237 from landline . Â£5000 cash or a luxury 4 * Canary:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] Islands Holiday await collection . T&Cs SAE PO Box 177 . M227XY . 150ppm . 16 +
# -------------------------
# [MATCH]: Auction round 4 . The highest bid is now Â£54 . Next maximum bid is Â£71 . To bid , send BIDS:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] e. g. 10 ( to bid Â£10 ) to 83383 . Good luck .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: 1.20 that call cost . Which i guess is nt bad . Miss:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] ya , need ya , want ya , love ya
# -------------------------
# [MATCH]: Thanks da:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] thangam , i feel very very happy dear . I also miss you da .
# -------------------------
# ==================================================
# Pattern: [['SPACY:DEP-compound']]
# Window size: 1
# Class: Negative
# Precision: 0.680
# Match: 1379 (38.7%)
# Gain = 0.134
# Examples ~ Class Negative:
# [MATCH]: No shoot me . I 'm in the docs waiting:['SPACY:DEP-compound'] room . :/
# -------------------------
# [MATCH]: Host - based IDPS for linux:['SPACY:DEP-compound'] systems .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: 449050000301 You have won a Â£2,000:['SPACY:DEP-compound'] price ! To claim , call 09050000301 .
# -------------------------
# [MATCH]: PRIVATE ! Your 2003 Account:['SPACY:DEP-compound'] Statement for 07815296484 shows 800 un - redeemed S.I.M. points . Call 08718738001 Identifier Code 41782 Expires 18/11/04
# -------------------------
# ==================================================
# 100%|██████████| 73/73 [01:41<00:00,  1.39s/it]
# Length 3 / 5; New candidates = 14337
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 1
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Examples ~ Class Negative:
# [MATCH]: I luv u soo much u donÂ’t understand how special u r 2:['SPACY:POS-NUM'] me ring u 2morrow luv u xxx
# -------------------------
# [MATCH]: Derp . Which is worse , a dude who always wants to party or a dude who files a complaint about the three:['SPACY:POS-NUM'] drug abusers he lives with
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: You have been selected to stay in 1:['SPACY:POS-NUM'] of 250 top British hotels - FOR NOTHING ! Holiday Worth Â£350 ! To Claim , Call London 02072069400 . Bx 526 , SW73SS
# -------------------------
# [MATCH]: Final Chance ! Claim ur Â£150 worth of discount vouchers today ! Text YES to 85023:['SPACY:POS-NUM'] now ! SavaMob , member offers mobile ! T Cs SavaMob POBOX84 , M263UZ . Â£3.00 Subs 16
# -------------------------
# ==================================================
# Pattern: [['SPACY:NER-DATE', 'SPACY:POS-NUM']]
# Window size: 1
# Class: Positive
# Precision: 0.861
# Match: 280 (7.8%)
# Gain = 0.175
# Examples ~ Class Positive:
# [MATCH]: Dear Dave this is your final notice to collect your 4 * Tenerife Holiday or # 5000 CASH award ! Call 09061743806:['SPACY:POS-NUM', 'SPACY:NER-DATE'] from landline . TCs SAE Box326 CW25WX 150ppm
# -------------------------
# [MATCH]: Today 's Offer ! Claim ur Â£150 worth of discount vouchers ! Text YES to 85023 now ! SavaMob , member offers mobile ! T Cs 08717898035:['SPACY:POS-NUM', 'SPACY:NER-DATE'] . Â£3.00 Sub . 16 . Unsub reply X
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: This is ur face test ( 1:['SPACY:POS-NUM', 'SPACY:NER-DATE'] 2 3 4 5 6 7 8 9   & lt;#&gt ;   ) select any number i will tell ur face astrology .... am waiting . quick reply ...
# -------------------------
# [MATCH]: From someone not to smoke when every time I 've smoked in the last two:['SPACY:POS-NUM', 'SPACY:NER-DATE'] weeks is because of you calling or texting me that you wanted to smoke
# -------------------------
# ==================================================
# Pattern: [['SPACY:DEP-compound'], ['SPACY:POS-PROPN']]
# Window size: 2
# Class: Positive
# Precision: 0.641
# Match: 451 (12.6%)
# Gain = 0.157
# Examples ~ Class Positive:
# [MATCH]: Thanks for your ringtone order , reference number:['SPACY:DEP-compound'] X29:['SPACY:POS-PROPN'] . Your mobile will be charged 4.50 . Should your tone not arrive please call customer services 09065989180
# -------------------------
# [MATCH]: URGENT ! We are trying to contact you . Last weekends draw shows that you have won a Â£900 prize:['SPACY:DEP-compound'] GUARANTEED:['SPACY:POS-PROPN'] . Call 09061701851 . Claim code K61 . Valid 12hours only
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: " CHEERS FOR CALLIN BABE.SOZI CULDNT TALKBUT I WANNATELL U DETAILS LATER WENWECAN:['SPACY:DEP-compound'] CHAT:['SPACY:POS-PROPN'] PROPERLY X "
# -------------------------
# [MATCH]: Smile in Pleasure Smile in Pain Smile when trouble pours like Rain Smile when sum1:['SPACY:DEP-compound'] Hurts:['SPACY:POS-PROPN'] U Smile becoz SOMEONE still Loves to see u Smiling ! !
# -------------------------
# ==================================================
# Pattern: [['SPACY:DEP-compound', 'SPACY:POS-PROPN']]
# Window size: 1
# Class: Positive
# Precision: 0.542
# Match: 583 (16.3%)
# Gain = 0.147
# Examples ~ Class Positive:
# [MATCH]: IMPORTANT INFORMATION 4 ORANGE:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] USER 0796XXXXXX . TODAY IS UR LUCKY DAY!2 FIND OUT WHY LOG ONTO http://www.urawinner.com THERE 'S A FANTASTIC PRIZEAWAITING YOU !
# -------------------------
# [MATCH]: Join the UK 's horniest Dogging service and u can have sex 2nite!. Just sign up and follow the instructions . Txt:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] ENTRY to 69888 now ! Nyt . EC2A.3LP.msg@150p
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Y so late but i need to go n get da:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] laptop ...
# -------------------------
# [MATCH]: " CHEERS U:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] TEX MECAUSE U WEREBORED ! YEAH OKDEN HUNNY R UIN WK SAT?SOUNDÂ ’S LIKEYOUR HAVIN GR8FUN J ! KEEP UPDAT COUNTINLOTS OF LOVEME XXXXX . "
# -------------------------
# ==================================================
# Pattern: [['SPACY:DEP-compound']]
# Window size: 1
# Class: Negative
# Precision: 0.680
# Match: 1379 (38.7%)
# Gain = 0.134
# Examples ~ Class Negative:
# [MATCH]: Yo:['SPACY:DEP-compound'] sorry was in the shower sup
# -------------------------
# [MATCH]: Shhhhh:['SPACY:DEP-compound'] nobody is supposed to know !
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Mila , age23 , blonde , new in UK . I look sex with UK:['SPACY:DEP-compound'] guys . if u like fun with me . Text MTALK to 69866.18 . 30pp / txt 1st 5free . Â£1.50 increments . Help08718728876
# -------------------------
# [MATCH]: To review and KEEP the fantastic Nokia:['SPACY:DEP-compound'] N - Gage game deck with Club Nokia , go 2 www.cnupdates.com/newsletter . unsubscribe from alerts reply with the word OUT
# -------------------------
# ==================================================
# 100%|██████████| 22/22 [00:26<00:00,  1.20s/it]
# Length 4 / 5; New candidates = 4357
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
# 0it [00:00, ?it/s]
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 1
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Examples ~ Class Negative:
# [MATCH]: is your hamster dead ? Hey so tmr i meet you at 1:['SPACY:POS-NUM'] pm orchard mrt ?
# -------------------------
# [MATCH]: I thk 50:['SPACY:POS-NUM'] shd be ok he said plus minus 10 .. Did Ã¼ leave a line in between paragraphs ?
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Not heard from U4 a while . Call 4:['SPACY:POS-NUM'] rude chat private line 01223585334 to cum . Wan 2C pics of me gettin shagged then text PIX to 8552 . 2End send STOP 8552 SAM xxx
# -------------------------
# [MATCH]: 449050000301:['SPACY:POS-NUM'] You have won a Â£2,000 price ! To claim , call 09050000301 .
# -------------------------
# ==================================================
# Pattern: [['SPACY:NER-DATE', 'SPACY:POS-NUM']]
# Window size: 1
# Class: Positive
# Precision: 0.861
# Match: 280 (7.8%)
# Gain = 0.175
# Examples ~ Class Positive:
# [MATCH]: Here is your discount code RP176781 . To stop further messages reply stop . www.regalportfolio.co.uk . Customer Services 08717205546:['SPACY:POS-NUM', 'SPACY:NER-DATE']
# -------------------------
# [MATCH]: URGENT ! Your Mobile No 07808726822:['SPACY:POS-NUM', 'SPACY:NER-DATE'] was awarded a Â£2,000 Bonus Caller Prize on 02/09/03 ! This is our 2nd attempt to contact YOU ! Call 0871 - 872 - 9758 BOX95QU
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: U studying in sch or going home ? Anyway i 'll b going 2:['SPACY:POS-NUM', 'SPACY:NER-DATE'] sch later .
# -------------------------
# [MATCH]: Hey next sun 1030:['SPACY:POS-NUM', 'SPACY:NER-DATE'] there 's a basic yoga course ... at bugis ... We can go for that ... Pilates intro next sat .... Tell me what time you r free
# -------------------------
# ==================================================
# Pattern: [['SPACY:DEP-compound'], ['SPACY:POS-PROPN']]
# Window size: 2
# Class: Positive
# Precision: 0.641
# Match: 451 (12.6%)
# Gain = 0.157
# Examples ~ Class Positive:
# [MATCH]: Bears:['SPACY:DEP-compound'] Pic:['SPACY:POS-PROPN'] Nick , and Tom , Pete and ... Dick . In fact , all types try gay chat with photo upload call 08718730666 ( 10p / min ) . 2 stop texts call 08712460324
# -------------------------
# [MATCH]: Your free ringtone is waiting to be collected . Simply text the password " MIX " to 85069 to verify . Get Usher and Britney . FML , PO:['SPACY:DEP-compound'] Box:['SPACY:POS-PROPN'] 5249 , MK17 92H. 450Ppw 16
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Ãœ:['SPACY:DEP-compound'] neva:['SPACY:POS-PROPN'] tell me how i noe ... I 'm not at home in da aft wat ...
# -------------------------
# [MATCH]: Evry:['SPACY:DEP-compound'] Emotion:['SPACY:POS-PROPN'] dsn't hav Words . Evry Wish dsn't hav Prayrs .. If u Smile , D World is wit u . Othrwise even d Drop of Tear dsn't lik 2 Stay wit u . So b happy .. Good morning , keep smiling:- )
# -------------------------
# ==================================================
# Pattern: [['SPACY:DEP-compound', 'SPACY:POS-PROPN']]
# Window size: 1
# Class: Positive
# Precision: 0.542
# Match: 583 (16.3%)
# Gain = 0.147
# Examples ~ Class Positive:
# [MATCH]: Free video camera phones with Half:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] Price line rental for 12 mths and 500 cross ntwk mins 100 txts . Call MobileUpd8 08001950382 or Call2OptOut/674
# -------------------------
# [MATCH]: FREE GAME . Get Rayman:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] Golf 4 FREE from the O2 Games Arcade . 1st get UR games settings . Reply POST , then save & activ8 . Press 0 key for Arcade . Termsapply
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: HI:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] DARLIN I FINISH AT 3 DO U 1 2 PICK ME UP OR MEET ME ? TEXT BACK ON THIS NUMBER LUV KATE XXX
# -------------------------
# [MATCH]: Esplanade:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] lor . Where else ...
# -------------------------
# ==================================================
# Pattern: [['SPACY:DEP-compound']]
# Window size: 1
# Class: Negative
# Precision: 0.680
# Match: 1379 (38.7%)
# Gain = 0.134
# Examples ~ Class Negative:
# [MATCH]: Purity of friendship between two is not about smiling after reading the forwarded message .. Its about smiling just by seeing the name . Gud:['SPACY:DEP-compound'] evng musthu
# -------------------------
# [MATCH]: I AM AT A PARTY WITH ALEX:['SPACY:DEP-compound'] NICHOLS
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Had your mobile 10 mths ? Update to latest Orange:['SPACY:DEP-compound'] camera / video phones for FREE . Save Â£s with Free texts / weekend calls . Text YES for a callback orno to opt out
# -------------------------
# [MATCH]: Ur ringtone:['SPACY:DEP-compound'] service has changed ! 25 Free credits ! Go to club4mobiles.com to choose content now ! Stop ? txt CLUB STOP to 87070 . 150p / wk Club4 PO Box1146 MK45 2WT
# -------------------------
# ==================================================
# Length 5 / 5; New candidates = 0

# %%
# Print the patterns
for idx, p in enumerate(the_patterns):
    print(f'Rank {idx}')
    print(p)
# Out:
# Rank 0
# Pattern: [['SPACY:POS-NUM']]
# Window size: 1
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Examples ~ Class Negative:
# [MATCH]: One:['SPACY:POS-NUM'] of best dialogue in cute reltnship .. ! ! " Wen i Die , Do nt Come Near My Body .. ! ! Bcoz My Hands May Not Come 2 Wipe Ur Tears Off That Time .. !Gud ni8
# -------------------------
# [MATCH]: Hi i m having the most relaxing time ever ! we have to get up at 7:['SPACY:POS-NUM'] am every day ! was the party good the other night ? I get home tomorrow at 5ish .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: 83039:['SPACY:POS-NUM'] 62735=Â£450 UK Break AccommodationVouchers terms & conditions apply . 2 claim you mustprovide your claim number which is 15541
# -------------------------
# [MATCH]: WINNER ! As a valued network customer you hvae been selected to receive a Â£900 reward ! To collect call 09061701444:['SPACY:POS-NUM'] . Valid 24 hours only . ACL03530150PM
# -------------------------
# ==================================================
# Rank 1
# Pattern: [['SPACY:NER-DATE', 'SPACY:POS-NUM']]
# Window size: 1
# Class: Positive
# Precision: 0.861
# Match: 280 (7.8%)
# Gain = 0.175
# Examples ~ Class Positive:
# [MATCH]: Panasonic & BluetoothHdset FREE . Nokia FREE . Motorola FREE & DoubleMins & DoubleTxt on Orange contract . Call MobileUpd8 on 08000839402:['SPACY:POS-NUM', 'SPACY:NER-DATE'] or call 2optout
# -------------------------
# [MATCH]: Uâ€ ™ ve Bin Awarded Â£50 to Play 4 Instant Cash . Call 08715203028 To Claim . EVERY 9th Player Wins Min Â£50-Â£500 . OptOut 08718727870:['SPACY:POS-NUM', 'SPACY:NER-DATE']
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Not planned yet : ) going to join company on jan 5:['SPACY:POS-NUM', 'SPACY:NER-DATE'] only.don know what will happen after that .
# -------------------------
# [MATCH]: From someone not to smoke when every time I 've smoked in the last two:['SPACY:POS-NUM', 'SPACY:NER-DATE'] weeks is because of you calling or texting me that you wanted to smoke
# -------------------------
# ==================================================
# Rank 2
# Pattern: [['SPACY:DEP-compound'], ['SPACY:POS-PROPN']]
# Window size: 2
# Class: Positive
# Precision: 0.641
# Match: 451 (12.6%)
# Gain = 0.157
# Examples ~ Class Positive:
# [MATCH]: GENT ! We are trying to contact you . Last weekends draw shows that you won a Â£1000 prize:['SPACY:DEP-compound'] GUARANTEED:['SPACY:POS-PROPN'] . Call 09064012160 . Claim Code K52 . Valid 12hrs only . 150ppm
# -------------------------
# [MATCH]: Sunshine:['SPACY:DEP-compound'] Quiz:['SPACY:POS-PROPN'] Wkly Q ! Win a top Sony DVD player if u know which country the Algarve is in ? Txt ansr to 82277 . Â£1.50 SP : Tyrone
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Brainless:['SPACY:DEP-compound'] Baby:['SPACY:POS-PROPN'] Doll .. :-D;- ) , vehicle sariyag drive madoke barolla ..
# -------------------------
# [MATCH]: TODAY is Sorry day . ! If ever i was angry with you , if ever i misbehaved or hurt you ? plz plz JUST SLAP:['SPACY:DEP-compound'] URSELF:['SPACY:POS-PROPN'] Bcoz , Its ur fault , I 'm basically GOOD
# -------------------------
# ==================================================
# Rank 3
# Pattern: [['SPACY:DEP-compound', 'SPACY:POS-PROPN']]
# Window size: 1
# Class: Positive
# Precision: 0.542
# Match: 583 (16.3%)
# Gain = 0.147
# Examples ~ Class Positive:
# [MATCH]: Had your contract mobile 11 Mnths ? Latest Motorola , Nokia etc . all FREE ! Double Mins & Text on Orange:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] tariffs . TEXT YES for callback , no to remove from records .
# -------------------------
# [MATCH]: Double Mins & Double Txt & 1/2 price Linerental on Latest:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] Orange Bluetooth mobiles . Call MobileUpd8 for the very latest offers . 08000839402 or call2optout / LF56
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Nokia:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] phone is lovly ..
# -------------------------
# [MATCH]: PLEASSSSSSSEEEEEE:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] TEL ME V AVENT DONE SPORTSx
# -------------------------
# ==================================================
# Rank 4
# Pattern: [['SPACY:DEP-compound']]
# Window size: 1
# Class: Negative
# Precision: 0.680
# Match: 1379 (38.7%)
# Gain = 0.134
# Examples ~ Class Negative:
# [MATCH]: I sent my scores to sophas and i had to do secondary application for a few schools . I think if you are thinking of applying , do a research on cost also . Contact:['SPACY:DEP-compound'] joke ogunrinde , her school is one me the less expensive ones
# -------------------------
# [MATCH]: Does cinema plus drink appeal tomo ? * Is a fr:['SPACY:DEP-compound'] thriller by director i like on at mac at 8.30 .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Wanna have a laugh ? Try CHIT:['SPACY:DEP-compound'] - CHAT on your mobile now ! Logon by txting the word : CHAT and send it to No : 8883 CM PO Box 4217 London W1A 6ZF 16 + 118p / msg rcvd
# -------------------------
# [MATCH]: I want some cock ! My hubby 's away , I need a real man 2 satisfy me . Txt:['SPACY:DEP-compound'] WIFE to 89938 for no strings action . ( Txt STOP 2 end , txt rec Â£1.50ea . OTBox 731 LA1 7WS . )
# -------------------------
# ==================================================
# Rank 5
# Pattern: [['SPACY:DEP-compound'], ['HYPERNYM:abstraction.n.06']]
# Window size: 2
# Class: Negative
# Precision: 0.559
# Match: 777 (21.8%)
# Gain = 0.130
# Examples ~ Class Negative:
# [MATCH]: Sorry vikky , i 'm Watching olave:['SPACY:DEP-compound'] mandara:['HYPERNYM:abstraction.n.06'] movie kano in trishul theatre wit my frnds ..
# -------------------------
# [MATCH]: Where are you ? What do you do ? How can you stand to be away from me ? Does n't your heart:['SPACY:DEP-compound'] ache:['HYPERNYM:abstraction.n.06'] without me ? Do n't you wonder of me ? Do n't you crave me ?
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Urgent ! call 09066612661 from landline . Your complementary 4 * Tenerife:['SPACY:DEP-compound'] Holiday:['HYPERNYM:abstraction.n.06'] or Â£10,000 cash await collection SAE T&Cs PO Box 3 WA14 2PX 150ppm 18 + Sender : Hol Offer
# -------------------------
# [MATCH]: Sunshine Hols . To claim ur med holiday send a stamped self:['SPACY:DEP-compound'] address:['HYPERNYM:abstraction.n.06'] envelope to Drinks on Us UK , PO Box 113 , Bray , Wicklow , Eire . Quiz Starts Saturday ! Unsub Stop
# -------------------------
# ==================================================
# Rank 6
# Pattern: [['SPACY:NER-ORG']]
# Window size: 1
# Class: Negative
# Precision: 0.527
# Match: 676 (19.0%)
# Gain = 0.127
# Examples ~ Class Negative:
# [MATCH]: ZOE IT JUST HIT ME 2 IM FUCKING SHITIN MYSELF IL DEFO TRY MY HARDEST 2 CUM:['SPACY:NER-ORG'] 2MOROW LUV U MILLIONS LEKDOG
# -------------------------
# [MATCH]: Plz note : if anyone calling from a mobile Co.:['SPACY:NER-ORG'] & amp ; asks u to type # & lt;#&gt ;   or # & lt;#&gt ; . Do not do so . Disconnect the call , coz it iz an attempt of ' terrorist ' to make use of the sim card no . Itz confirmd by nokia n motorola n has been verified by CNN IBN .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: For your chance to WIN a FREE Bluetooth Headset then simply reply back with " ADP:['SPACY:NER-ORG'] "
# -------------------------
# [MATCH]: Thank you , winner notified by sms . Good Luck ! No future marketing reply STOP:['SPACY:NER-ORG'] to 84122 customer services 08450542832
# -------------------------
# ==================================================
# Rank 7
# Pattern: [['HYPERNYM:abstraction.n.06'], ['SPACY:POS-PROPN']]
# Window size: 2
# Class: Positive
# Precision: 0.708
# Match: 305 (8.6%)
# Gain = 0.123
# Examples ~ Class Positive:
# [MATCH]: < Forwarded from 21870000>Hi - this is your Mailbox Messaging:['HYPERNYM:abstraction.n.06'] SMS:['SPACY:POS-PROPN'] alert . You have 40 matches . Please call back on 09056242159 to retrieve your messages and matches cc100p / min
# -------------------------
# [MATCH]: SMS . ac JSco : Energy is high , but u may not know where 2channel it . 2day ur leadership skills r strong . Psychic ? Reply:['HYPERNYM:abstraction.n.06'] ANS:['SPACY:POS-PROPN'] w / question . End ? Reply END JSCO
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Thanks:['HYPERNYM:abstraction.n.06'] da:['SPACY:POS-PROPN'] thangam , i feel very very happy dear . I also miss you da .
# -------------------------
# [MATCH]: I ( Career:['HYPERNYM:abstraction.n.06'] Tel:['SPACY:POS-PROPN'] ) have added u as a contact on INDYAROCKS.COM to send FREE SMS . To remove from phonebook - sms NO to   & lt;#&gt ;
# -------------------------
# ==================================================
# Rank 8
# Pattern: [['SPACY:DEP-compound', 'SPACY:POS-PROPN'], ['HYPERNYM:abstraction.n.06']]
# Window size: 2
# Class: Positive
# Precision: 0.694
# Match: 310 (8.7%)
# Gain = 0.119
# Examples ~ Class Positive:
# [MATCH]: URGENT ! We are trying to contact U:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] Todays:['HYPERNYM:abstraction.n.06'] draw shows that you have won a Â£800 prize GUARANTEED . Call 09050000460 from land line . Claim J89 . po box245c2150pm
# -------------------------
# [MATCH]: URGENT ! We are trying to contact you . Last weekends draw shows that you have won a Â£900:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] prize:['HYPERNYM:abstraction.n.06'] GUARANTEED . Call 09061701939 . Claim code S89 . Valid 12hrs only
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Wylie:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] update:['HYPERNYM:abstraction.n.06'] : my weed dealer carlos went to freedom and had a class with lunsford
# -------------------------
# [MATCH]: " AH:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] POOR:['HYPERNYM:abstraction.n.06'] BABY!HOPE URFEELING BETTERSN LUV ! PROBTHAT OVERDOSE OF WORK HEY GO CAREFUL SPK 2 U SN LOTS OF LOVEJEN XXX . "
# -------------------------
# ==================================================
# Rank 9
# Pattern: [['HYPERNYM:abstraction.n.06', 'SPACY:POS-PROPN']]
# Window size: 1
# Class: Positive
# Precision: 0.508
# Match: 555 (15.6%)
# Gain = 0.116
# Examples ~ Class Positive:
# [MATCH]: PRIVATE ! Your 2003 Account:['SPACY:POS-PROPN', 'HYPERNYM:abstraction.n.06'] Statement for 07753741225 shows 800 un - redeemed S. I. M. points . Call 08715203677 Identifier Code : 42478 Expires 24/10/04
# -------------------------
# [MATCH]: URGENT ! Your Mobile No was awarded a Â£2,000 Bonus:['SPACY:POS-PROPN', 'HYPERNYM:abstraction.n.06'] Caller Prize on 1/08/03 ! This is our 2nd attempt to contact YOU ! Call 0871 - 4719 - 523 BOX95QU BT National Rate
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: So there 's a ring that comes with the guys costumes . It 's there so they can gift their future yowifes . Hint:['SPACY:POS-PROPN', 'HYPERNYM:abstraction.n.06'] hint
# -------------------------
# [MATCH]: Evry Emotion:['SPACY:POS-PROPN', 'HYPERNYM:abstraction.n.06'] dsn't hav Words . Evry Wish dsn't hav Prayrs .. If u Smile , D World is wit u . Othrwise even d Drop of Tear dsn't lik 2 Stay wit u . So b happy .. Good morning , keep smiling:- )
# -------------------------
# ==================================================
# Rank 10
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 2
# Class: Positive
# Precision: 1.000
# Match: 135 (3.8%)
# Gain = 0.116
# Examples ~ Class Positive:
# [MATCH]: You are a winner you have been specially selected to receive Â£1000 cash or a Â£2000 award . Speak to a live operator to claim call:['TEXT:call'] 087123002209am-7pm:['SPACY:POS-NUM'] . Cost 10p
# -------------------------
# [MATCH]: Please CALL:['TEXT:call'] 08712402902:['SPACY:POS-NUM'] immediately as there is an urgent message waiting for you .
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Rank 11
# Pattern: [['SPACY:POS-PROPN']]
# Window size: 1
# Class: Negative
# Precision: 0.690
# Match: 1347 (37.8%)
# Gain = 0.112
# Examples ~ Class Negative:
# [MATCH]: Wat:['SPACY:POS-PROPN'] makes u thk i 'll fall down . But actually i thk i 'm quite prone 2 falls . Lucky my dad at home i ask him come n fetch me already .
# -------------------------
# [MATCH]: Nope but i 'll b going 2 sch on fri quite early lor cos mys sis got paper in da:['SPACY:POS-PROPN'] morn :-)
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: You are awarded a SiPix:['SPACY:POS-PROPN'] Digital Camera ! call 09061221061 from landline . Delivery within 28days . T Cs Box177 . M221BP . 2yr warranty . 150ppm . 16 . p pÂ£3.99
# -------------------------
# [MATCH]: Urgent ! Please call 09061743810 from landline . Your ABTA:['SPACY:POS-PROPN'] complimentary 4 * Tenerife Holiday or # 5000 cash await collection SAE T&Cs Box 326 CW25WX 150 ppm
# -------------------------
# ==================================================
# Rank 12
# Pattern: [['SPACY:DEP-pobj', 'SPACY:POS-NUM']]
# Window size: 1
# Class: Positive
# Precision: 0.743
# Match: 253 (7.1%)
# Gain = 0.110
# Examples ~ Class Positive:
# [MATCH]: Your free ringtone is waiting to be collected . Simply text the password " MIX " to 85069:['SPACY:POS-NUM', 'SPACY:DEP-pobj'] to verify . Get Usher and Britney . FML , PO Box 5249 , MK17 92H. 450Ppw 16
# -------------------------
# [MATCH]: FROM 88066:['SPACY:POS-NUM', 'SPACY:DEP-pobj'] LOST Â£12 HELP
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Your opinion about me ? 1 . Over 2:['SPACY:POS-NUM', 'SPACY:DEP-pobj'] . Jada 3 . Kusruthi 4 . Lovable 5 . Silent 6 . Spl character 7 . Not matured 8 . Stylish 9 . Simple Pls reply ..
# -------------------------
# [MATCH]: Glad it went well :) come over at 11:['SPACY:POS-NUM', 'SPACY:DEP-pobj'] then we 'll have plenty of time before claire goes to work .
# -------------------------
# ==================================================
# Rank 13
# Pattern: [['SPACY:NER-DATE']]
# Window size: 1
# Class: Negative
# Precision: 0.548
# Match: 651 (18.3%)
# Gain = 0.106
# Examples ~ Class Negative:
# [MATCH]: Lol yep did that yesterday:['SPACY:NER-DATE'] . Already got my fireplace . Now its just another icon sitting there for me .
# -------------------------
# [MATCH]: Sad story of a:['SPACY:NER-DATE'] Man - Last week was my b'day . My Wife did'nt wish me . My Parents forgot n so did my Kids . I went to work . Even my Colleagues did not wish . As I entered my cabin my PA said , '' Happy B'day Boss ! ! '' . I felt special . She askd me 4 lunch . After lunch she invited me to her apartment . We went there . She said , '' do u mind if I go into the bedroom for a minute ? '' ' ' OK '' , I sed in a sexy mood . She came out 5 minuts latr wid a cake ... n My Wife , My Parents , My Kidz , My Friends n My Colleagues . All screaming .. SURPRISE ! ! and I was waiting on the sofa .. ... ..... ' NAKED ... !
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: U 447801259231:['SPACY:NER-DATE'] have a secret admirer who is looking 2 make contact with U - find out who they R*reveal who thinks UR so special - call on 09058094597
# -------------------------
# [MATCH]: Thanks for your Ringtone Order , Reference T91 . You will be charged GBP 4:['SPACY:NER-DATE'] per week . You can unsubscribe at anytime by calling customer services on 09057039994
# -------------------------
# ==================================================
# Rank 14
# Pattern: [['SPACY:DEP-compound'], ['SPACY:DEP-compound']]
# Window size: 2
# Class: Positive
# Precision: 0.562
# Match: 420 (11.8%)
# Gain = 0.104
# Examples ~ Class Positive:
# [MATCH]: Not heard from U4 a while . Call 4 rude chat private line 01223585334 to cum . Wan:['SPACY:DEP-compound'] 2C:['SPACY:DEP-compound'] pics of me gettin shagged then text PIX to 8552 . 2End send STOP 8552 SAM xxx
# -------------------------
# [MATCH]: Congrats 2 mobile 3 G:['SPACY:DEP-compound'] Videophones:['SPACY:DEP-compound'] R yours . call 09063458130 now ! videochat wid ur mates , play java games , Dload polypH music , noline rentl . bx420 . ip4 . 5we . 150p
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Kate:['SPACY:DEP-compound'] jackson:['SPACY:DEP-compound'] rec center before 7ish , right ?
# -------------------------
# [MATCH]: Thank You for calling . Forgot to say Happy Onam to you Sirji . I am fine here and remembered you when i met an insurance person . Meet You in Qatar:['SPACY:DEP-compound'] Insha:['SPACY:DEP-compound'] Allah . Rakhesh , ex Tata AIG who joined TISSCO , Tayseer .
# -------------------------
# ==================================================
# Rank 15
# Pattern: [['TEXT:call']]
# Window size: 1
# Class: Positive
# Precision: 0.618
# Match: 348 (9.8%)
# Gain = 0.104
# Examples ~ Class Positive:
# [MATCH]: Bears Pic Nick , and Tom , Pete and ... Dick . In fact , all types try gay chat with photo upload call:['TEXT:call'] 08718730666 ( 10p / min ) . 2 stop texts call 08712460324
# -------------------------
# [MATCH]: Hack Chat . Get backdoor entry into 121 chat rooms at a fraction of the cost . Reply NEO69 or call:['TEXT:call'] 09050280520 , to subscribe 25p pm . DPS , Bcm box 8027 Ldn , wc1n3xx
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Even if he my friend he is a priest call:['TEXT:call'] him now
# -------------------------
# [MATCH]: Call:['TEXT:call'] me when u finish then i come n pick u.
# -------------------------
# ==================================================
# Rank 16
# Pattern: [['TEXT:to'], ['SPACY:POS-NUM']]
# Window size: 2
# Class: Positive
# Precision: 0.931
# Match: 144 (4.0%)
# Gain = 0.101
# Examples ~ Class Positive:
# [MATCH]: You have won a Nokia 7250i . This is what you get when you win our FREE auction . To take part send Nokia to:['TEXT:to'] 86021:['SPACY:POS-NUM'] now . HG / Suite342/2Lands Row / W1JHL 16 +
# -------------------------
# [MATCH]: Urgent UR awarded a complimentary trip to EuroDisinc Trav , Aco&Entry41 Or Â£1000 . To claim txt DIS to:['TEXT:to'] 87121:['SPACY:POS-NUM'] 18 + 6*Â£1.50(moreFrmMob . ShrAcomOrSglSuplt)10 , LS1 3AJ
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Ugh . Got ta drive back to:['TEXT:to'] sd:['SPACY:POS-NUM'] from la . My butt is sore .
# -------------------------
# [MATCH]: Aight , I should be there by 8 at the latest , probably closer to:['TEXT:to'] 7:['SPACY:POS-NUM'] . Are jay and tyler down or should we just do two trips ?
# -------------------------
# ==================================================
# Rank 17
# Pattern: [['HYPERNYM:abstraction.n.06', 'SPACY:DEP-compound']]
# Window size: 1
# Class: Negative
# Precision: 0.563
# Match: 668 (18.7%)
# Gain = 0.101
# Examples ~ Class Negative:
# [MATCH]: Goodnight , sleep well da please take care:['SPACY:DEP-compound', 'HYPERNYM:abstraction.n.06'] pa . Please .
# -------------------------
# [MATCH]: My darling sister . How are you doing . When 's school resuming . Is there a minimum wait:['SPACY:DEP-compound', 'HYPERNYM:abstraction.n.06'] period before you reapply ? Do take care
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Double Mins & Double Txt & 1/2 price:['SPACY:DEP-compound', 'HYPERNYM:abstraction.n.06'] Linerental on Latest Orange Bluetooth mobiles . Call MobileUpd8 for the very latest offers . 08000839402 or call2optout / LF56
# -------------------------
# [MATCH]: URGENT ! Your mobile number * * * * * * * * * * * * * * * WON a Â£2000 Bonus:['SPACY:DEP-compound', 'HYPERNYM:abstraction.n.06'] Caller prize on 10/06/03 ! This is the 2nd attempt to reach you ! Call 09066368753 ASAP ! Box 97N7QP , 150ppm
# -------------------------
# ==================================================
# Rank 18
# Pattern: [['HYPERNYM:entity.n.01'], ['SPACY:POS-NUM']]
# Window size: 2
# Class: Positive
# Precision: 0.710
# Match: 255 (7.1%)
# Gain = 0.100
# Examples ~ Class Positive:
# [MATCH]: FreeMsg : Txt : CALL to No : 86888 & claim your reward of 3 hours talk time to use from your phone now ! Subscribe6GBP / mnth inc:['HYPERNYM:entity.n.01'] 3hrs:['SPACY:POS-NUM'] 16 stop?txtStop
# -------------------------
# [MATCH]: Congratulations ur awarded either Â£500 of CD gift vouchers & Free entry:['HYPERNYM:entity.n.01'] 2:['SPACY:POS-NUM'] our Â£100 weekly draw txt MUSIC to 87066 TnCs www . Ldew.com1win150ppmx3age16
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Ok i found dis pierre cardin one which looks normal costs:['HYPERNYM:entity.n.01'] 20:['SPACY:POS-NUM'] its on sale .
# -------------------------
# [MATCH]: Hi mate its RV did u hav a nice hol just a message:['HYPERNYM:entity.n.01'] 3:['SPACY:POS-NUM'] say hello coz havenÂ’t sent u 1 in ages started driving so stay off roads!RVx
# -------------------------
# ==================================================
# Rank 19
# Pattern: [['SPACY:DEP-compound'], ['SPACY:NER-ORG']]
# Window size: 2
# Class: Positive
# Precision: 0.769
# Match: 216 (6.1%)
# Gain = 0.100
# Examples ~ Class Positive:
# [MATCH]: This is the 2nd time we have tried to contact u.:['SPACY:DEP-compound'] U:['SPACY:NER-ORG'] have won the Â£400 prize . 2 claim is easy , just call 087104711148 NOW ! Only 10p per minute . BT - national - rate
# -------------------------
# [MATCH]: URGENT ! We are trying to contact you . Last weekends draw shows that you have won a Â£900 prize:['SPACY:DEP-compound'] GUARANTEED:['SPACY:NER-ORG'] . Call 09061701939 . Claim code S89 . Valid 12hrs only
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Indians r poor but India is not a poor country . Says one of the swiss bank directors . He says that " & lt;#&gt ;   lac crore " of Indian money is deposited in swiss banks which can be used for ' taxless ' budget for   & lt;#&gt ;   yrs . Can give   & lt;#&gt ;   crore jobs to all Indians . From any village to Delhi 4 lane roads . Forever free power suply to more than   & lt;#&gt ;   social projects . Every citizen can get monthly   & lt;#&gt ; /- for   & lt;#&gt ;   yrs . No need of World:['SPACY:DEP-compound'] Bank:['SPACY:NER-ORG'] & amp ; IMF loan . Think how our money is blocked by rich politicians . We have full rights against corrupt politicians . Itna forward karo ki pura INDIA padhe.g.m . "
# -------------------------
# [MATCH]: WHAT TIME:['SPACY:DEP-compound'] U:['SPACY:NER-ORG'] WRKIN ?
# -------------------------
# ==================================================
# Rank 20
# Pattern: [['HYPERNYM:abstraction.n.06', 'SPACY:DEP-compound', 'SPACY:POS-PROPN']]
# Window size: 1
# Class: Positive
# Precision: 0.698
# Match: 255 (7.1%)
# Gain = 0.096
# Examples ~ Class Positive:
# [MATCH]: Do you want a new Video handset ? 750 any time any network mins ? UNLIMITED TEXT ? Camcorder ? Reply or Call now 08000930705 for del Sat:['SPACY:POS-PROPN', 'HYPERNYM:abstraction.n.06', 'SPACY:DEP-compound'] AM
# -------------------------
# [MATCH]: -PLS STOP bootydelious ( 32/F ) is inviting you to be her friend . Reply:['SPACY:POS-PROPN', 'HYPERNYM:abstraction.n.06', 'SPACY:DEP-compound'] YES-434 or NO-434 See her : www . SMS.ac / u / bootydelious STOP ? Send STOP FRND to 62468
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Smile in Pleasure:['SPACY:POS-PROPN', 'HYPERNYM:abstraction.n.06', 'SPACY:DEP-compound'] Smile in Pain Smile when trouble pours like Rain Smile when sum1 Hurts U Smile becoz SOMEONE still Loves to see u Smiling ! !
# -------------------------
# [MATCH]: WE REGRET TO INFORM U THAT THE NHS HAS MADE A MISTAKE.U WERE NEVER ACTUALLY BORN.PLEASE REPORT 2 YOR LOCAL HOSPITAL:['SPACY:POS-PROPN', 'HYPERNYM:abstraction.n.06', 'SPACY:DEP-compound'] 2B TERMINATED.WE R SORRY 4 THE INCONVENIENCE
# -------------------------
# ==================================================
# Rank 21
# Pattern: [['SPACY:DEP-pobj', 'SPACY:NER-DATE', 'SPACY:POS-NUM']]
# Window size: 1
# Class: Positive
# Precision: 0.975
# Match: 121 (3.4%)
# Gain = 0.095
# Examples ~ Class Positive:
# [MATCH]: 87077 : Kick off a new season with 2wks FREE goals & news to ur mobile ! Txt ur club name to 87077:['SPACY:POS-NUM', 'SPACY:DEP-pobj', 'SPACY:NER-DATE'] eg VILLA to 87077
# -------------------------
# [MATCH]: You have won a Nokia 7250i . This is what you get when you win our FREE auction . To take part send Nokia to 86021:['SPACY:POS-NUM', 'SPACY:DEP-pobj', 'SPACY:NER-DATE'] now . HG / Suite342/2Lands Row / W1JHL 16 +
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I shall book chez jules for half eight:['SPACY:POS-NUM', 'SPACY:DEP-pobj', 'SPACY:NER-DATE'] , if that 's ok with you ?
# -------------------------
# [MATCH]: K I 'm leaving soon , be there a little after 9:['SPACY:POS-NUM', 'SPACY:DEP-pobj', 'SPACY:NER-DATE']
# -------------------------
# ==================================================
# Rank 22
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:DEP-compound']]
# Window size: 2
# Class: Positive
# Precision: 0.652
# Match: 287 (8.0%)
# Gain = 0.094
# Examples ~ Class Positive:
# [MATCH]: U can WIN Â£100 of Music:['SPACY:POS-PROPN'] Gift:['SPACY:DEP-compound'] Vouchers every week starting NOW Txt the word DRAW to 87066 TsCs www . Idew.com SkillGame , 1Winaweek , age16 . 150ppermessSubscription
# -------------------------
# [MATCH]: GENT ! We are trying to contact you . Last weekends draw shows that you won a Â£1000:['SPACY:POS-PROPN'] prize:['SPACY:DEP-compound'] GUARANTEED . Call 09064012160 . Claim Code K52 . Valid 12hrs only . 150ppm
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: IM:['SPACY:POS-PROPN'] FINE:['SPACY:DEP-compound'] BABES AINT BEEN UP 2 MUCH THO ! SAW SCARY MOVIE YEST ITS QUITE FUNNY ! WANT 2MRW AFTERNOON ? AT TOWN OR MALL OR SUMTHIN?xx
# -------------------------
# [MATCH]: Let Ur Heart Be Ur:['SPACY:POS-PROPN'] Compass:['SPACY:DEP-compound'] Ur Mind Ur Map Ur Soul Ur Guide And U Will Never loose in world .... gnun - Sent via WAY2SMS.COM
# -------------------------
# ==================================================
# Rank 23
# Pattern: [['HYPERNYM:entity.n.01', 'SPACY:NER-ORG']]
# Window size: 1
# Class: Positive
# Precision: 0.637
# Match: 292 (8.2%)
# Gain = 0.091
# Examples ~ Class Positive:
# [MATCH]: This is the 2nd time we have tried 2 contact u. U:['HYPERNYM:entity.n.01', 'SPACY:NER-ORG'] have won the 750 Pound prize . 2 claim is easy , call 08712101358 NOW ! Only 10p per min . BT - national - rate
# -------------------------
# [MATCH]: Want a new Video:['HYPERNYM:entity.n.01', 'SPACY:NER-ORG'] Phone ? 750 anytime any network mins ? Half price line rental free text for 3 months ? Reply or call 08000930705 for free delivery
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Imagine Life:['HYPERNYM:entity.n.01', 'SPACY:NER-ORG'] WITHOUT ME ... see .. How fast u are searching me?Don't worry .. l'm always there To disturb U .. Goodnoon .. : )
# -------------------------
# [MATCH]: Yeah if we do have to get a random dude we need to change our info sheets to PARTY:['HYPERNYM:entity.n.01', 'SPACY:NER-ORG']   & lt;#&gt ; /7 NEVER STUDY just to be safe
# -------------------------
# ==================================================
# Rank 24
# Pattern: [['HYPERNYM:entity.n.01'], ['HYPERNYM:abstraction.n.06']]
# Window size: 2
# Class: Negative
# Precision: 0.591
# Match: 675 (18.9%)
# Gain = 0.085
# Examples ~ Class Negative:
# [MATCH]: Ca n't . I feel nauseous . I 'm so pissed . I did n't eat any sweets all week:['HYPERNYM:entity.n.01'] cause:['HYPERNYM:abstraction.n.06'] today I was planning to pig out . I was dieting all week . And now I 'm not hungry :/
# -------------------------
# [MATCH]: Sorry man my account 's dry or I would , if you want we could trade back half or I could buy some shit with my credit:['HYPERNYM:entity.n.01'] card:['HYPERNYM:abstraction.n.06']
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: No 1 POLYPHONIC tone 4 ur mob every week ! Just txt PT2 to 87575 . 1st Tone FREE ! so get txtin now and tell ur friends . 150p / tone . 16 reply:['HYPERNYM:entity.n.01'] HL:['HYPERNYM:abstraction.n.06'] 4info
# -------------------------
# [MATCH]: Free entry in 2 a wkly comp to win FA:['HYPERNYM:entity.n.01'] Cup:['HYPERNYM:abstraction.n.06'] final tkts 21st May 2005 . Text FA to 87121 to receive entry question(std txt rate)T&C 's apply 08452810075over18 's
# -------------------------
# ==================================================
# Rank 25
# Pattern: [['SPACY:NER-ORG'], ['HYPERNYM:entity.n.01']]
# Window size: 2
# Class: Positive
# Precision: 0.695
# Match: 226 (6.3%)
# Gain = 0.083
# Examples ~ Class Positive:
# [MATCH]: * * FREE MESSAGE**Thanks for using the:['SPACY:NER-ORG'] Auction:['HYPERNYM:entity.n.01'] Subscription Service . 18 . 150p / MSGRCVD 2 Skip an Auction txt OUT . 2 Unsubscribe txt STOP CustomerCare 08718726270
# -------------------------
# [MATCH]: Ringtone:['SPACY:NER-ORG'] Club:['HYPERNYM:entity.n.01'] : Gr8 new polys direct to your mobile every week !
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Hello . How u doing?What u been up 2?When:['SPACY:NER-ORG'] will:['HYPERNYM:entity.n.01'] u b moving out of the flat , cos I will need to arrange to pick up the lamp , etc . Take care . Hello caroline !
# -------------------------
# [MATCH]: Solve d Case : A Man Was Found Murdered On   & lt;DECIMAL&gt ; . & lt;#&gt ;   AfterNoon . 1,His wife called Police . 2,Police questioned everyone . 3,Wife : Sir , I was sleeping , when the murder took place . 4.Cook : I was cooking . 5.Gardener : I was picking vegetables . 6.House - Maid : I went 2 d post office . 7.Children : We went 2 play . 8.Neighbour : We went 2 a marriage . Police arrested d murderer Immediately . Who 's It ? Reply With Reason , If U:['SPACY:NER-ORG'] r:['HYPERNYM:entity.n.01'] Brilliant .
# -------------------------
# ==================================================
# Rank 26
# Pattern: [['HYPERNYM:entity.n.01'], ['HYPERNYM:abstraction.n.06', 'SPACY:POS-PROPN']]
# Window size: 2
# Class: Positive
# Precision: 0.766
# Match: 175 (4.9%)
# Gain = 0.078
# Examples ~ Class Positive:
# [MATCH]: Valentines:['HYPERNYM:entity.n.01'] Day:['SPACY:POS-PROPN', 'HYPERNYM:abstraction.n.06'] Special ! Win over Â£1000 in our quiz and take your partner on the trip of a lifetime ! Send GO to 83600 now . 150p / msg rcvd . CustCare:08718720201
# -------------------------
# [MATCH]: Fantasy:['HYPERNYM:entity.n.01'] Football:['SPACY:POS-PROPN', 'HYPERNYM:abstraction.n.06'] is back on your TV . Go to Sky Gamestar on Sky Active and play Â£250k Dream Team . Scoring starts on Saturday , so register now!SKY OPT OUT to 88088
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: HIYA STU WOT U UP 2.IM IN SO MUCH TRUBLE AT HOME AT MOMENT EVONE HATES ME EVEN U ! WOT THE HELL AV I DONE NOW ? Y:['HYPERNYM:entity.n.01'] WONT:['SPACY:POS-PROPN', 'HYPERNYM:abstraction.n.06'] U JUST TELL ME TEXT BCK PLEASE LUV DAN
# -------------------------
# [MATCH]: WE REGRET TO INFORM U THAT THE NHS HAS MADE A MISTAKE.U WERE NEVER ACTUALLY BORN.PLEASE REPORT 2 YOR LOCAL:['HYPERNYM:entity.n.01'] HOSPITAL:['SPACY:POS-PROPN', 'HYPERNYM:abstraction.n.06'] 2B TERMINATED.WE R SORRY 4 THE INCONVENIENCE
# -------------------------
# ==================================================
# Rank 27
# Pattern: [['HYPERNYM:communication.n.02']]
# Window size: 1
# Class: Negative
# Precision: 0.648
# Match: 870 (24.4%)
# Gain = 0.078
# Examples ~ Class Negative:
# [MATCH]: Is that seriously how you spell his name:['HYPERNYM:communication.n.02'] ?
# -------------------------
# [MATCH]: I wanted to wish you a Happy New Year and I wanted to talk to you about some legal advice:['HYPERNYM:communication.n.02'] to do with when Gary and I split but in person . I 'll make a trip to Ptbo for that . I hope everything is good with you babe and I love ya :)
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: 07732584351 - Rodger Burns - MSG = We tried to call you re your reply:['HYPERNYM:communication.n.02'] to our sms for a free nokia mobile + free camcorder . Please call now 08000930705 for delivery tomorrow
# -------------------------
# [MATCH]: This is the 2nd time we have tried 2 contact u. U have won the 750 Pound prize:['HYPERNYM:communication.n.02'] . 2 claim is easy , call 08712101358 NOW ! Only 10p per min . BT - national - rate
# -------------------------
# ==================================================
# Rank 28
# Pattern: [['HYPERNYM:abstraction.n.06'], ['HYPERNYM:entity.n.01']]
# Window size: 2
# Class: Negative
# Precision: 0.593
# Match: 637 (17.9%)
# Gain = 0.077
# Examples ~ Class Negative:
# [MATCH]: Yeah if we do have to get a random dude we need to change our info:['HYPERNYM:abstraction.n.06'] sheets:['HYPERNYM:entity.n.01'] to PARTY   & lt;#&gt ; /7 NEVER STUDY just to be safe
# -------------------------
# [MATCH]: Playin space:['HYPERNYM:abstraction.n.06'] poker:['HYPERNYM:entity.n.01'] , u ?
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Had your mobile 11 months or more ? U:['HYPERNYM:abstraction.n.06'] R:['HYPERNYM:entity.n.01'] entitled to Update to the latest colour mobiles with camera for Free ! Call The Mobile Update Co FREE on 08002986030
# -------------------------
# [MATCH]: Ur cash - balance is currently 500 pounds - to maximize ur cash - in now send COLLECT to 83600 only 150p / msg . CC : 08718720201 PO:['HYPERNYM:abstraction.n.06'] BOX:['HYPERNYM:entity.n.01'] 114/14 TCR / W1
# -------------------------
# ==================================================
# Rank 29
# Pattern: [['HYPERNYM:entity.n.01'], ['SPACY:DEP-compound']]
# Window size: 2
# Class: Positive
# Precision: 0.562
# Match: 320 (9.0%)
# Gain = 0.075
# Examples ~ Class Positive:
# [MATCH]: SMS:['HYPERNYM:entity.n.01'] AUCTION:['SPACY:DEP-compound'] - A BRAND NEW Nokia 7250 is up 4 auction today ! Auction is FREE 2 join & take part ! Txt NOKIA to 86021 now !
# -------------------------
# [MATCH]: Congrats ! 2 mobile 3 G:['HYPERNYM:entity.n.01'] Videophones:['SPACY:DEP-compound'] R yours . call 09063458130 now ! videochat wid your mates , play java games , Dload polyPH music , noline rentl .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Wat 's da:['HYPERNYM:entity.n.01'] model:['SPACY:DEP-compound'] num of ur phone ?
# -------------------------
# [MATCH]: Today is ACCEPT DAY .. U Accept me as ? Brother:['HYPERNYM:entity.n.01'] Sister:['SPACY:DEP-compound'] Lover Dear1 Best1 Clos1 Lvblefrnd Jstfrnd Cutefrnd Lifpartnr Belovd Swtheart Bstfrnd No rply means enemy
# -------------------------
# ==================================================
# Rank 30
# Pattern: [['SPACY:DEP-compound', 'SPACY:NER-ORG', 'SPACY:POS-PROPN']]
# Window size: 1
# Class: Positive
# Precision: 0.719
# Match: 192 (5.4%)
# Gain = 0.075
# Examples ~ Class Positive:
# [MATCH]: Eerie:['SPACY:POS-PROPN', 'SPACY:NER-ORG', 'SPACY:DEP-compound'] Nokia tones 4u , rply TONE TITLE to 8007 eg TONE DRACULA to 8007 Titles : GHOST , ADDAMSFA , MUNSTERS , EXORCIST , TWILIGHT www.getzed.co.uk POBox36504W45WQ 150p
# -------------------------
# [MATCH]: Sunshine Quiz Wkly Q ! Win a top Sony:['SPACY:POS-PROPN', 'SPACY:NER-ORG', 'SPACY:DEP-compound'] DVD player if u know which country Liverpool played in mid week ? Txt ansr to 82277 . Â£1.50 SP : Tyrone
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Helloooo ... Wake up .. ! " Sweet " " morning " " welcomes " " You " " Enjoy " " This Day " " with full of joy " .. " GUD:['SPACY:POS-PROPN', 'SPACY:NER-ORG', 'SPACY:DEP-compound'] MRNG " .
# -------------------------
# [MATCH]: Honeybee Said : * I 'm d Sweetest in d World * God Laughed & amp ; Said : * Wait , U:['SPACY:POS-PROPN', 'SPACY:NER-ORG', 'SPACY:DEP-compound'] Havnt Met d Person Reading This Msg * MORAL : Even GOD Can Crack Jokes ! GM+GN+GE+GN : )
# -------------------------
# ==================================================
# Rank 31
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:NER-ORG']]
# Window size: 2
# Class: Positive
# Precision: 0.696
# Match: 204 (5.7%)
# Gain = 0.074
# Examples ~ Class Positive:
# [MATCH]: Want 2 get laid tonight ? Want real Dogging locations sent direct 2 ur mob ? Join the UK 's largest Dogging:['SPACY:POS-PROPN'] Network:['SPACY:NER-ORG'] bt Txting GRAVEL to 69888 ! Nt . ec2a . 31p.msg@150p
# -------------------------
# [MATCH]: Free 1st week entry 2 TEXTPOD 4 a chance 2 win 40 GB:['SPACY:POS-PROPN'] iPod:['SPACY:NER-ORG'] or Â£250 cash every wk . Txt POD to 84128 Ts&Cs www.textpod.net custcare 08712405020 .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Honeybee Said : * I 'm d Sweetest in d World * God:['SPACY:POS-PROPN'] Laughed:['SPACY:NER-ORG'] & amp ; Said : * Wait , U Havnt Met d Person Reading This Msg * MORAL : Even GOD Can Crack Jokes ! GM+GN+GE+GN : )
# -------------------------
# [MATCH]: Evry Emotion dsn't hav Words . Evry Wish dsn't hav Prayrs .. If u Smile , D:['SPACY:POS-PROPN'] World:['SPACY:NER-ORG'] is wit u . Othrwise even d Drop of Tear dsn't lik 2 Stay wit u . So b happy .. Good morning , keep smiling:- )
# -------------------------
# ==================================================
# Rank 32
# Pattern: [['SPACY:DEP-compound'], ['SPACY:POS-PROPN'], ['HYPERNYM:entity.n.01']]
# Window size: 3
# Class: Positive
# Precision: 0.773
# Match: 163 (4.6%)
# Gain = 0.074
# Examples ~ Class Positive:
# [MATCH]: SPJanuary:['SPACY:DEP-compound'] Male:['SPACY:POS-PROPN'] Sale:['HYPERNYM:entity.n.01'] ! Hot Gay chat now cheaper , call 08709222922 . National rate from 1.5p / min cheap to 7.8p / min peak ! To stop texts call 08712460324 ( 10p / min )
# -------------------------
# [MATCH]: You can donate Â£2.50 to UNICEF 's Asian:['SPACY:DEP-compound'] Tsunami:['SPACY:POS-PROPN'] disaster:['HYPERNYM:entity.n.01'] support fund by texting DONATE to 864233 . Â£2.50 will be added to your next bill
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Mmmmmm ... I love you , so much , Ahmad ... I ca n't wait for this year to begin as every second takes me closer to being at your side . Happy:['SPACY:DEP-compound'] New:['SPACY:POS-PROPN'] Year:['HYPERNYM:entity.n.01'] , my love ! !
# -------------------------
# [MATCH]: Today is ACCEPT DAY .. U Accept me as ? Brother:['SPACY:DEP-compound'] Sister:['SPACY:POS-PROPN'] Lover:['HYPERNYM:entity.n.01'] Dear1 Best1 Clos1 Lvblefrnd Jstfrnd Cutefrnd Lifpartnr Belovd Swtheart Bstfrnd No rply means enemy
# -------------------------
# ==================================================
# Rank 33
# Pattern: [['SPACY:DEP-compound'], ['HYPERNYM:communication.n.02']]
# Window size: 2
# Class: Positive
# Precision: 0.618
# Match: 254 (7.1%)
# Gain = 0.072
# Examples ~ Class Positive:
# [MATCH]: Todays Vodafone:['SPACY:DEP-compound'] numbers:['HYPERNYM:communication.n.02'] ending with 4882 are selected to a receive a Â£350 award . If your number matches call 09064019014 to receive your Â£350 award .
# -------------------------
# [MATCH]: * FREE * POLYPHONIC RINGTONE:['SPACY:DEP-compound'] Text:['HYPERNYM:communication.n.02'] SUPER to 87131 to get your FREE POLY TONE of the week now ! 16 SN PoBox202 NR31 7ZS subscription 450pw
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Did u got that persons:['SPACY:DEP-compound'] story:['HYPERNYM:communication.n.02']
# -------------------------
# [MATCH]: Howz that persons:['SPACY:DEP-compound'] story:['HYPERNYM:communication.n.02']
# -------------------------
# ==================================================
# Rank 34
# Pattern: [['SPACY:DEP-compound'], ['SPACY:DEP-compound'], ['SPACY:POS-PROPN']]
# Window size: 3
# Class: Positive
# Precision: 0.726
# Match: 179 (5.0%)
# Gain = 0.071
# Examples ~ Class Positive:
# [MATCH]: Bears:['SPACY:DEP-compound'] Pic:['SPACY:DEP-compound'] Nick:['SPACY:POS-PROPN'] , and Tom , Pete and ... Dick . In fact , all types try gay chat with photo upload call 08718730666 ( 10p / min ) . 2 stop texts call 08712460324
# -------------------------
# [MATCH]: Urgent Urgent ! We have 800 FREE flights to Europe to give away , call B4:['SPACY:DEP-compound'] 10th:['SPACY:DEP-compound'] Sept:['SPACY:POS-PROPN'] & take a friend 4 FREE . Call now to claim on 09050000555 . BA128NNFWFLY150ppm
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Y?WHERE U AT DOGBREATH ? ITS JUST SOUNDING LIKE:['SPACY:DEP-compound'] JAN:['SPACY:DEP-compound'] C:['SPACY:POS-PROPN'] THATÂ ’S AL ! ! ! ! ! ! ! ! !
# -------------------------
# [MATCH]: HIYA COMIN 2 BRISTOL 1 ST WEEK IN APRIL . LES:['SPACY:DEP-compound'] GOT:['SPACY:DEP-compound'] OFF:['SPACY:POS-PROPN'] + RUDI ON NEW YRS EVE BUT I WAS SNORING.THEY WERE DRUNK ! U BAK AT COLLEGE YET ? MY WORK SENDS INK 2 BATH .
# -------------------------
# ==================================================
# Rank 35
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
# Window size: 2
# Class: Positive
# Precision: 0.861
# Match: 122 (3.4%)
# Gain = 0.070
# Examples ~ Class Positive:
# [MATCH]: Uâ€ ™ ve Bin Awarded Â£50 to Play 4:['SPACY:POS-NUM'] Instant:['SPACY:POS-PROPN'] Cash . Call 08715203028 To Claim . EVERY 9th Player Wins Min Â£50-Â£500 . OptOut 08718727870
# -------------------------
# [MATCH]: You have won a guaranteed Â£200 award or even Â£1000 cashto claim UR award call free on 08000407165 ( 18 + ) 2 stop getstop on 88222:['SPACY:POS-NUM'] PHP:['SPACY:POS-PROPN']
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Hi here . have birth at on the   to   at 8:['SPACY:POS-NUM'] lb:['SPACY:POS-PROPN'] 7 oz . Mother and baby doing brilliantly .
# -------------------------
# [MATCH]: HEY THERE BABE , HOW U DOIN ? WOT U UP 2 2NITE:['SPACY:POS-NUM'] LOVE:['SPACY:POS-PROPN'] ANNIE X.
# -------------------------
# ==================================================
# Rank 36
# Pattern: [['HYPERNYM:entity.n.01'], ['SPACY:DEP-compound', 'SPACY:POS-PROPN']]
# Window size: 2
# Class: Positive
# Precision: 0.793
# Match: 145 (4.1%)
# Gain = 0.069
# Examples ~ Class Positive:
# [MATCH]: Ur ringtone service has changed ! 25 Free credits ! Go to club4mobiles.com to choose content now ! Stop ? txt CLUB STOP to 87070 . 150p / wk Club4 PO:['HYPERNYM:entity.n.01'] Box1146:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] MK45 2WT
# -------------------------
# [MATCH]: You 'll not rcv any more msgs from the chat svc . For FREE:['HYPERNYM:entity.n.01'] Hardcore:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] services text GO to : 69988 If u get nothing u must Age Verify with yr network & try again
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Hello beautiful r u ok ? I 've kinda ad a row wiv and he walked out the pub ? ? I wanted a night wiv u:['HYPERNYM:entity.n.01'] Miss:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] u
# -------------------------
# [MATCH]: 1Apple / Day = No Doctor . 1Tulsi Leaf / Day = No Cancer . 1Lemon / Day = No Fat . 1Cup Milk / day = No Bone Problms 3 Litres Watr / Day = No Diseases:['HYPERNYM:entity.n.01'] Snd:['SPACY:POS-PROPN', 'SPACY:DEP-compound'] ths 2 Whom U Care .. :- )
# -------------------------
# ==================================================
# Rank 37
# Pattern: [['SPACY:DEP-amod']]
# Window size: 1
# Class: Negative
# Precision: 0.735
# Match: 1440 (40.4%)
# Gain = 0.068
# Examples ~ Class Negative:
# [MATCH]: I might come to kerala for 2 days.so you can be prepared to take a leave once i finalise .dont plan any travel during my visit.need to finish urgent:['SPACY:DEP-amod'] works .
# -------------------------
# [MATCH]: Lil:['SPACY:DEP-amod'] fever : ) now fine : )
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: For ur chance to win Â£250:['SPACY:DEP-amod'] cash every wk TXT : PLAY to 83370 . T's&C 's www.music-trivia.net custcare 08715705022 , 1x150p / wk .
# -------------------------
# [MATCH]: Final Chance ! Claim ur Â£150 worth:['SPACY:DEP-amod'] of discount vouchers today ! Text YES to 85023 now ! SavaMob , member offers mobile ! T Cs SavaMob POBOX84 , M263UZ . Â£3.00 Subs 16
# -------------------------
# ==================================================
# Rank 38
# Pattern: [['TEXT:i']]
# Window size: 1
# Class: Negative
# Precision: 0.983
# Match: 1327 (37.2%)
# Gain = 0.067
# Examples ~ Class Negative:
# [MATCH]: I:['TEXT:i'] 'm done oredi ...
# -------------------------
# [MATCH]: Sorry my roommates took forever , it ok if I:['TEXT:i'] come by now ?
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Babe : U want me do nt u baby ! I:['TEXT:i'] m nasty and have a thing 4 filthyguys . Fancy a rude time with a sexy bitch . How about we go slo n hard ! Txt XXX SLO(4msgs )
# -------------------------
# [MATCH]: FreeMsg Hey U , i:['TEXT:i'] just got 1 of these video / pic fones , reply WILD to this txt & ill send U my pics , hurry up I m so bored at work xxx ( 18 150p / rcvd STOP2stop )
# -------------------------
# ==================================================
# Rank 39
# Pattern: [['SPACY:POS-SYM']]
# Window size: 1
# Class: Positive
# Precision: 0.756
# Match: 156 (4.4%)
# Gain = 0.067
# Examples ~ Class Positive:
# [MATCH]: Urgent ! call 09066612661 from landline . Your complementary 4 * Tenerife Holiday or Â£10,000 cash await collection SAE T&Cs PO Box 3 WA14 2PX 150ppm 18 +:['SPACY:POS-SYM'] Sender : Hol Offer
# -------------------------
# [MATCH]: 1st wk FREE ! Gr8 tones str8 2 u each wk . Txt NOKIA ON to 8007 for Classic Nokia tones or HIT ON to 8007 for Polys . Nokia/150p Poly/200p 16 +:['SPACY:POS-SYM']
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: If anyone calls for a treadmill say you 'll buy it . Make sure its working . I found an ad on Craigslist selling for $:['SPACY:POS-SYM'] & lt;#&gt ; .
# -------------------------
# [MATCH]: Please protect yourself from e - threats . SIB never asks for sensitive information like Passwords , ATM /:['SPACY:POS-SYM'] SMS PIN thru email . Never share your password with anybody .
# -------------------------
# ==================================================
# Rank 40
# Pattern: [['TEXT:free']]
# Window size: 1
# Class: Positive
# Precision: 0.748
# Match: 159 (4.5%)
# Gain = 0.067
# Examples ~ Class Positive:
# [MATCH]: You have won a guaranteed Â£200 award or even Â£1000 cashto claim UR award call free:['TEXT:free'] on 08000407165 ( 18 + ) 2 stop getstop on 88222 PHP . RG21 4JX
# -------------------------
# [MATCH]: Had your mobile 10 mths ? Update to latest Orange camera / video phones for FREE:['TEXT:free'] . Save Â£s with Free texts / weekend calls . Text YES for a callback orno to opt out
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I ( Career Tel ) have added u as a contact on INDYAROCKS.COM to send FREE:['TEXT:free'] SMS . To remove from phonebook - sms NO to   & lt;#&gt ;
# -------------------------
# [MATCH]: K .. then come wenever u lik to come and also tel vikky to come by getting free:['TEXT:free'] time .. :- )
# -------------------------
# ==================================================
# Rank 41
# Pattern: [['HYPERNYM:entity.n.01'], ['SPACY:NER-ORG']]
# Window size: 2
# Class: Positive
# Precision: 0.686
# Match: 191 (5.4%)
# Gain = 0.067
# Examples ~ Class Positive:
# [MATCH]: URGENT ! Your Mobile No was awarded a Â£2,000 Bonus Caller Prize on 1/08/03 ! This is our 2nd attempt to contact YOU ! Call 0871 - 4719 - 523 BOX95QU BT National:['HYPERNYM:entity.n.01'] Rate:['SPACY:NER-ORG']
# -------------------------
# [MATCH]: You will be receiving this week 's Triple:['HYPERNYM:entity.n.01'] Echo:['SPACY:NER-ORG'] ringtone shortly . Enjoy it !
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Today is ACCEPT DAY .. U:['HYPERNYM:entity.n.01'] Accept:['SPACY:NER-ORG'] me as ? Brother Sister Lover Dear1 Best1 Clos1 Lvblefrnd Jstfrnd Cutefrnd Lifpartnr Belovd Swtheart Bstfrnd No rply means enemy
# -------------------------
# [MATCH]: ALRITE SAM ITS NIC JUST CHECKIN THAT THIS IS UR NUMBER:['HYPERNYM:entity.n.01'] -:['SPACY:NER-ORG'] SO IS IT?T.B *
# -------------------------
# ==================================================
# Rank 42
# Pattern: [['TEXT:txt']]
# Window size: 1
# Class: Positive
# Precision: 0.938
# Match: 96 (2.7%)
# Gain = 0.067
# Examples ~ Class Positive:
# [MATCH]: You are guaranteed the latest Nokia Phone , a 40 GB iPod MP3 player or a Â£500 prize ! Txt:['TEXT:txt'] word : COLLECT to No : 83355 ! IBHltd LdnW15H 150p / Mtmsgrcvd18 +
# -------------------------
# [MATCH]: FREE for 1st week ! No1 Nokia tone 4 ur mobile every week just txt:['TEXT:txt'] NOKIA to 8077 Get txting and tell ur mates . www.getzed.co.uk POBox 36504 W45WQ 16 + norm150p / tone
# -------------------------
# Counterexamples ~ Not class Positive:
# ...
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Dear where you .:['TEXT:.'] Call:['TEXT:call'] me
# -------------------------
# [MATCH]: You call him and tell now infront of them .:['TEXT:.'] Call:['TEXT:call'] him now .
# -------------------------
# ==================================================
# Rank 87
# Pattern: [['SPACY:POS-ADJ'], ['SPACY:DEP-compound']]
# Window size: 2
# Class: Negative
# Precision: 0.548
# Match: 321 (9.0%)
# Gain = 0.044
# Examples ~ Class Negative:
# [MATCH]: Good:['SPACY:POS-ADJ'] afternoon:['SPACY:DEP-compound'] starshine ! How 's my boytoy ? Does he crave me yet ? Ache to fuck me ? * sips cappuccino * I miss you babe * teasing kiss *
# -------------------------
# [MATCH]: Wow so healthy . Old:['SPACY:POS-ADJ'] airport:['SPACY:DEP-compound'] rd lor . Ca nt thk of anything else . But i 'll b bathing my dog later .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Congrats ! Nokia 3650 video camera phone is your:['SPACY:POS-ADJ'] Call:['SPACY:DEP-compound'] 09066382422 Calls cost 150ppm Ave call 3mins vary from mobiles 16 + Close 300603 post BCM4284 Ldn WC1N3XX
# -------------------------
# [MATCH]: For your chance to WIN a FREE:['SPACY:POS-ADJ'] Bluetooth:['SPACY:DEP-compound'] Headset then simply reply back with " ADP "
# -------------------------
# ==================================================
# Rank 88
# Pattern: [['HYPERNYM:entity.n.01', 'SPACY:DEP-compound', 'SPACY:NER-ORG']]
# Window size: 1
# Class: Positive
# Precision: 0.699
# Match: 123 (3.4%)
# Gain = 0.043
# Examples ~ Class Positive:
# [MATCH]: HOT LIVE FANTASIES call now 08707509020 Just 20p per min NTT Ltd , PO:['SPACY:DEP-compound', 'HYPERNYM:entity.n.01', 'SPACY:NER-ORG'] Box 1327 Croydon CR9 5WB 0870 is a national rate call
# -------------------------
# [MATCH]: Not heard from U4 a while . Call 4 rude chat private line 01223585334 to cum . Wan 2C pics of me gettin shagged then text PIX to 8552 . 2End send STOP 8552 SAM:['SPACY:DEP-compound', 'HYPERNYM:entity.n.01', 'SPACY:NER-ORG'] xxx
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Honeybee Said : * I 'm d Sweetest in d World * God Laughed & amp ; Said : * Wait , U:['SPACY:DEP-compound', 'HYPERNYM:entity.n.01', 'SPACY:NER-ORG'] Havnt Met d Person Reading This Msg * MORAL : Even GOD Can Crack Jokes ! GM+GN+GE+GN : )
# -------------------------
# [MATCH]: Height of Confidence : All the Aeronautics:['SPACY:DEP-compound', 'HYPERNYM:entity.n.01', 'SPACY:NER-ORG'] professors wer calld & amp ; they wer askd 2 sit in an aeroplane . Aftr they sat they wer told dat the plane ws made by their students . Dey all hurried out of d plane .. Bt only 1 did nt move ... He said:"if it is made by my students , this wo nt even start ........ Datz confidence ..
# -------------------------
# ==================================================
# Rank 89
# Pattern: [['SPACY:DEP-appos']]
# Window size: 1
# Class: Negative
# Precision: 0.543
# Match: 311 (8.7%)
# Gain = 0.043
# Examples ~ Class Negative:
# [MATCH]: And you ! Will expect you whenever you text ! Hope all:['SPACY:DEP-appos'] goes well tomo
# -------------------------
# [MATCH]: Ee msg na poortiyagi odalebeku : Hanumanji 7 name 1-Hanuman 2-Bajarangabali 3-Maruti 4-Pavanaputra 5-Sankatmochan 6-Ramaduth 7-Mahaveer:['SPACY:DEP-appos'] ee 7 name   & lt;#&gt ;   janarige ivatte kalisidare next saturday olage ondu good news keluviri ... ! Maretare inde 1 dodda problum nalli siguviri idu matra   & lt;#&gt ; % true .. Do n't neglet .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: U've been selected to stay in 1 of 250 top British hotels - FOR NOTHING ! Holiday valued at Â£350 ! Dial 08712300220 to claim - National Rate Call . Bx526 , SW73SS:['SPACY:DEP-appos']
# -------------------------
# [MATCH]: Win the newest â€œHarry Potter and the Order of the Phoenix ( Book:['SPACY:DEP-appos'] 5 ) reply HARRY , answer 5 questions - chance to be the first among readers !
# -------------------------
# ==================================================
# Rank 90
# Pattern: [['SPACY:DEP-compound'], ['SPACY:DEP-dobj', 'SPACY:POS-PROPN']]
# Window size: 2
# Class: Positive
# Precision: 0.745
# Match: 106 (3.0%)
# Gain = 0.043
# Examples ~ Class Positive:
# [MATCH]: URGENT ! We are trying to contact you . Last weekends draw shows that you have won a Â£900 prize:['SPACY:DEP-compound'] GUARANTEED:['SPACY:POS-PROPN', 'SPACY:DEP-dobj'] . Call 09061701851 . Claim code K61 . Valid 12hours only
# -------------------------
# [MATCH]: U've been selected to stay in 1 of 250 top British hotels - FOR NOTHING ! Holiday valued at Â£350 ! Dial 08712300220 to claim - National Rate:['SPACY:DEP-compound'] Call:['SPACY:POS-PROPN', 'SPACY:DEP-dobj'] . Bx526 , SW73SS
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: THATÂ ’S ALRITE:['SPACY:DEP-compound'] GIRL:['SPACY:POS-PROPN', 'SPACY:DEP-dobj'] , U KNOW GAIL IS NEVA WRONG!!TAKE CARE SWEET AND DONÂ’T WORRY.C U L8TR HUN!LOVE Yaxxx
# -------------------------
# [MATCH]: IM FINE BABES AINT BEEN UP 2 MUCH THO ! SAW SCARY MOVIE YEST ITS QUITE FUNNY ! WANT 2MRW:['SPACY:DEP-compound'] AFTERNOON:['SPACY:POS-PROPN', 'SPACY:DEP-dobj'] ? AT TOWN OR MALL OR SUMTHIN?xx
# -------------------------
# ==================================================
# Rank 91
# Pattern: [['HYPERNYM:communication.n.02'], ['SPACY:POS-NUM']]
# Window size: 2
# Class: Positive
# Precision: 0.923
# Match: 65 (1.8%)
# Gain = 0.043
# Examples ~ Class Positive:
# [MATCH]: Congratulations ur awarded either Â£500 of CD gift vouchers & Free entry:['HYPERNYM:communication.n.02'] 2:['SPACY:POS-NUM'] our Â£100 weekly draw txt MUSIC to 87066 TnCs www . Ldew.com1win150ppmx3age16
# -------------------------
# [MATCH]: Congratulations ur awarded either Â£500 of CD gift vouchers & Free entry:['HYPERNYM:communication.n.02'] 2:['SPACY:POS-NUM'] our Â£100 weekly draw txt MUSIC to 87066 TnCs www . Ldew.com 1 win150ppmx3age16
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: " Getting tickets:['HYPERNYM:communication.n.02'] 4:['SPACY:POS-NUM'] walsall tue 6 th march . My mate is getting me them on sat . ill pay my treat . Want 2 go . Txt bak .Terry "
# -------------------------
# [MATCH]: Hi mate its RV did u hav a nice hol just a message:['HYPERNYM:communication.n.02'] 3:['SPACY:POS-NUM'] say hello coz havenÂ’t sent u 1 in ages started driving so stay off roads!RVx
# -------------------------
# ==================================================
# Rank 92
# Pattern: [['SPACY:DEP-compound'], ['HYPERNYM:relation.n.01']]
# Window size: 2
# Class: Positive
# Precision: 0.584
# Match: 178 (5.0%)
# Gain = 0.043
# Examples ~ Class Positive:
# [MATCH]: You have won a guaranteed Â£200:['SPACY:DEP-compound'] award:['HYPERNYM:relation.n.01'] or even Â£1000 cashto claim UR award call free on 08000407165 ( 18 + ) 2 stop getstop on 88222 PHP . RG21 4JX
# -------------------------
# [MATCH]: SMS SERVICES . for your inclusive text:['SPACY:DEP-compound'] credits:['HYPERNYM:relation.n.01'] , pls goto www.comuk.net login= 3qxj9 unsubscribe with STOP , no extra charge . help 08702840625.COMUK . 220-CM2 9AE
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: " CHEERS:['SPACY:DEP-compound'] U:['HYPERNYM:relation.n.01'] TEX MECAUSE U WEREBORED ! YEAH OKDEN HUNNY R UIN WK SAT?SOUNDÂ ’S LIKEYOUR HAVIN GR8FUN J ! KEEP UPDAT COUNTINLOTS OF LOVEME XXXXX . "
# -------------------------
# [MATCH]: Evry Emotion dsn't hav Words . Evry Wish dsn't hav Prayrs .. If u Smile , D World is wit u . Othrwise even d Drop of Tear dsn't lik 2 Stay wit:['SPACY:DEP-compound'] u:['HYPERNYM:relation.n.01'] . So b happy .. Good morning , keep smiling:- )
# -------------------------
# ==================================================
# Rank 93
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:DEP-compound'], ['HYPERNYM:abstraction.n.06']]
# Window size: 3
# Class: Positive
# Precision: 0.703
# Match: 118 (3.3%)
# Gain = 0.042
# Examples ~ Class Positive:
# [MATCH]: Ur:['SPACY:POS-PROPN'] HMV:['SPACY:DEP-compound'] Quiz:['HYPERNYM:abstraction.n.06'] cash - balance is currently Â£500 - to maximize ur cash - in now send HMV1 to 86688 only 150p / msg
# -------------------------
# [MATCH]: Do you want a new Video handset ? 750 any time any network mins ? UNLIMITED TEXT ? Camcorder ? Reply or Call now 08000930705 for del:['SPACY:POS-PROPN'] Sat:['SPACY:DEP-compound'] AM:['HYPERNYM:abstraction.n.06']
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: She is our sister .. She belongs 2 our family .. She is d hope of tomorrow .. Pray 4 her , who was fated 4 d Shoranur:['SPACY:POS-PROPN'] train:['SPACY:DEP-compound'] incident:['HYPERNYM:abstraction.n.06'] . Lets hold our hands together & amp ; fuelled by love & amp ; concern prior 2 her grief & amp ; pain . Pls join in dis chain & amp ; pass it . STOP VIOLENCE AGAINST WOMEN .
# -------------------------
# [MATCH]: HIYA COMIN 2 BRISTOL 1 ST WEEK IN APRIL . LES GOT OFF + RUDI ON NEW:['SPACY:POS-PROPN'] YRS:['SPACY:DEP-compound'] EVE:['HYPERNYM:abstraction.n.06'] BUT I WAS SNORING.THEY WERE DRUNK ! U BAK AT COLLEGE YET ? MY WORK SENDS INK 2 BATH .
# -------------------------
# ==================================================
# Rank 94
# Pattern: [['TEXT:call'], ['SPACY:DEP-dobj']]
# Window size: 2
# Class: Positive
# Precision: 0.614
# Match: 158 (4.4%)
# Gain = 0.042
# Examples ~ Class Positive:
# [MATCH]: Call:['TEXT:call'] Germany:['SPACY:DEP-dobj'] for only 1 pence per minute ! Call from a fixed line via access number 0844 861 85 85 . No prepayment . Direct access ! www.telediscount.co.uk
# -------------------------
# [MATCH]: Want a new Video Phone ? 750 anytime any network mins ? Half price line rental free text for 3 months ? Reply or call:['TEXT:call'] 08000930705:['SPACY:DEP-dobj'] for free delivery
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Hey now am free you can call:['TEXT:call'] me:['SPACY:DEP-dobj'] .
# -------------------------
# [MATCH]: My life Means a lot to me , Not because I love my life , But because I love the people in my life , The world calls them friends , I call:['TEXT:call'] them:['SPACY:DEP-dobj'] my World:- ) .. Ge:- ) ..
# -------------------------
# ==================================================
# Rank 95
# Pattern: [['SENTIMENT:pos']]
# Window size: 1
# Class: Negative
# Precision: 0.761
# Match: 1425 (39.9%)
# Gain = 0.042
# Examples ~ Class Negative:
# [MATCH]: One of the joys in lifeis waking up each daywith thoughts that somewhereSomeone cares enough:['SENTIMENT:pos'] tosend a warm morning greeting .. -
# -------------------------
# [MATCH]: That 's fine:['SENTIMENT:pos'] , I 'll bitch at you about it later then
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: UR awarded:['SENTIMENT:pos'] a City Break and could WIN a Â£200 Summer Shopping spree every WK . Txt STORE to 88039 . SkilGme . TsCs087147403231Winawk!Age16 Â£1.50perWKsub
# -------------------------
# [MATCH]: Santa calling ! Would your little ones like:['SENTIMENT:pos'] a call from Santa Xmas Eve ? Call 09077818151 to book you time . Calls1.50ppm last 3mins 30s T&C www.santacalling.com
# -------------------------
# ==================================================
# Rank 96
# Pattern: [['HYPERNYM:abstraction.n.06'], ['SPACY:NER-ORG', 'SPACY:POS-PROPN']]
# Window size: 2
# Class: Positive
# Precision: 0.805
# Match: 87 (2.4%)
# Gain = 0.042
# Examples ~ Class Positive:
# [MATCH]: okmail : Dear Dave this is your final notice to collect your 4 * Tenerife Holiday or # 5000 CASH award ! Call 09061743806 from landline . TCs:['HYPERNYM:abstraction.n.06'] SAE:['SPACY:POS-PROPN', 'SPACY:NER-ORG'] Box326 CW25WX 150ppm
# -------------------------
# [MATCH]: Your free ringtone is waiting to be collected . Simply text the password " MIX " to 85069 to verify . Get Usher and Britney . FML , PO:['HYPERNYM:abstraction.n.06'] Box:['SPACY:POS-PROPN', 'SPACY:NER-ORG'] 5249 , MK17 92H. 450Ppw 16
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Solve d Case : A Man Was Found Murdered On   & lt;DECIMAL&gt ; . & lt;#&gt ;   AfterNoon . 1,His wife called Police . 2,Police questioned everyone . 3,Wife : Sir , I was sleeping , when the murder took place . 4.Cook : I was cooking . 5.Gardener : I was picking vegetables . 6.House - Maid : I went 2 d post office . 7.Children : We went 2 play . 8.Neighbour : We went 2 a marriage . Police arrested d murderer Immediately . Who 's It ? Reply With Reason , If U r:['HYPERNYM:abstraction.n.06'] Brilliant:['SPACY:POS-PROPN', 'SPACY:NER-ORG'] .
# -------------------------
# [MATCH]: WHAT TIME U:['HYPERNYM:abstraction.n.06'] WRKIN:['SPACY:POS-PROPN', 'SPACY:NER-ORG'] ?
# -------------------------
# ==================================================
# Rank 97
# Pattern: [['HYPERNYM:act.n.02']]
# Window size: 1
# Class: Negative
# Precision: 0.686
# Match: 726 (20.4%)
# Gain = 0.041
# Examples ~ Class Negative:
# [MATCH]: I 've been searching for the right words to thank you for this breather . I promise i wo nt take your help for granted and will fulfil my promise:['HYPERNYM:act.n.02'] . You have been wonderful and a blessing at all times .
# -------------------------
# [MATCH]: Oh you got many responsibilities:['HYPERNYM:act.n.02'] .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Camera - You are awarded a SiPix Digital Camera ! call 09061221066 fromm landline . Delivery:['HYPERNYM:act.n.02'] within 28 days .
# -------------------------
# [MATCH]: Customer service announcement . We recently tried to make a delivery:['HYPERNYM:act.n.02'] to you but were unable to do so , please call 07099833605 to re - schedule . Ref:9280114
# -------------------------
# ==================================================
# Rank 98
# Pattern: [['HYPERNYM:communication.n.02', 'SPACY:DEP-compound']]
# Window size: 1
# Class: Positive
# Precision: 0.588
# Match: 170 (4.8%)
# Gain = 0.041
# Examples ~ Class Positive:
# [MATCH]: URGENT ! We are trying to contact U. Todays draw shows that you have won a Â£2000 prize:['HYPERNYM:communication.n.02', 'SPACY:DEP-compound'] GUARANTEED . Call 09066358361 from land line . Claim Y87 . Valid 12hrs only
# -------------------------
# [MATCH]: URGENT ! Your Mobile number has been awarded a < UKP>2000 prize:['HYPERNYM:communication.n.02', 'SPACY:DEP-compound'] GUARANTEED . Call 09061790125 from landline . Claim 3030 . Valid 12hrs only 150ppm
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: U R THE MOST BEAUTIFUL GIRL IVE EVER SEEN . U R MY BABY COME AND C:['HYPERNYM:communication.n.02', 'SPACY:DEP-compound'] ME IN THE COMMON ROOM
# -------------------------
# [MATCH]: Those cocksuckers . If it makes you feel better ipads are worthless garbage:['HYPERNYM:communication.n.02', 'SPACY:DEP-compound'] novelty items and you should feel bad for even wanting one
# -------------------------
# ==================================================
# Rank 99
# Pattern: [['SPACY:NER-ORG'], ['SPACY:POS-NUM']]
# Window size: 2
# Class: Positive
# Precision: 0.863
# Match: 73 (2.0%)
# Gain = 0.041
# Examples ~ Class Positive:
# [MATCH]: Please call our customer service representative on FREEPHONE:['SPACY:NER-ORG'] 0808:['SPACY:POS-NUM'] 145 4742 between 9am-11pm as you have WON a guaranteed Â£1000 cash or Â£5000 prize !
# -------------------------
# [MATCH]: Urgent ! call 09066350750 from your landline . Your complimentary 4 * Ibiza Holiday or 10,000 cash await collection SAE T&Cs PO BOX:['SPACY:NER-ORG'] 434:['SPACY:POS-NUM'] SK3 8WP 150 ppm 18 +
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: How have your little darlings been so far this week ? Need a coffee run tomo?Can't believe it 's that time of week already â€:['SPACY:NER-ORG'] ¦:['SPACY:POS-NUM']
# -------------------------
# [MATCH]: Boy ; I love u Grl : Hogolo Boy : gold chain kodstini Grl : Agalla Boy : necklace madstini Grl : agalla Boy : Hogli:['SPACY:NER-ORG'] 1:['SPACY:POS-NUM'] mutai eerulli kodthini ! Grl : I love U kano;- )
# -------------------------
# ==================================================

# %%
for idx, p in enumerate(the_patterns):
    print(f'{idx:>3} {p.support_class}   {round(p.coverage*100, 1):>4}   {p.precision:.3f}   {p.get_pattern_id()}')
# Out:
#   0 Negative   26.2   0.526   [['SPACY:POS-NUM']]
#   1 Positive    7.8   0.861   [['SPACY:NER-DATE', 'SPACY:POS-NUM']]
#   2 Positive   12.6   0.641   [['SPACY:DEP-compound'], ['SPACY:POS-PROPN']]
#   3 Positive   16.3   0.542   [['SPACY:DEP-compound', 'SPACY:POS-PROPN']]
#   4 Negative   38.7   0.680   [['SPACY:DEP-compound']]
#   5 Negative   21.8   0.559   [['SPACY:DEP-compound'], ['HYPERNYM:abstraction.n.06']]
#   6 Negative   19.0   0.527   [['SPACY:NER-ORG']]
#   7 Positive    8.6   0.708   [['HYPERNYM:abstraction.n.06'], ['SPACY:POS-PROPN']]
#   8 Positive    8.7   0.694   [['SPACY:DEP-compound', 'SPACY:POS-PROPN'], ['HYPERNYM:abstraction.n.06']]
#   9 Positive   15.6   0.508   [['HYPERNYM:abstraction.n.06', 'SPACY:POS-PROPN']]
#  10 Positive    3.8   1.000   [['TEXT:call'], ['SPACY:POS-NUM']]
#  11 Negative   37.8   0.690   [['SPACY:POS-PROPN']]
#  12 Positive    7.1   0.743   [['SPACY:DEP-pobj', 'SPACY:POS-NUM']]
#  13 Negative   18.3   0.548   [['SPACY:NER-DATE']]
#  14 Positive   11.8   0.562   [['SPACY:DEP-compound'], ['SPACY:DEP-compound']]
#  15 Positive    9.8   0.618   [['TEXT:call']]
#  16 Positive    4.0   0.931   [['TEXT:to'], ['SPACY:POS-NUM']]
#  17 Negative   18.7   0.563   [['HYPERNYM:abstraction.n.06', 'SPACY:DEP-compound']]
#  18 Positive    7.1   0.710   [['HYPERNYM:entity.n.01'], ['SPACY:POS-NUM']]
#  19 Positive    6.1   0.769   [['SPACY:DEP-compound'], ['SPACY:NER-ORG']]
#  20 Positive    7.1   0.698   [['HYPERNYM:abstraction.n.06', 'SPACY:DEP-compound', 'SPACY:POS-PROPN']]
#  21 Positive    3.4   0.975   [['SPACY:DEP-pobj', 'SPACY:NER-DATE', 'SPACY:POS-NUM']]
#  22 Positive    8.0   0.652   [['SPACY:POS-PROPN'], ['SPACY:DEP-compound']]
#  23 Positive    8.2   0.637   [['HYPERNYM:entity.n.01', 'SPACY:NER-ORG']]
#  24 Negative   18.9   0.591   [['HYPERNYM:entity.n.01'], ['HYPERNYM:abstraction.n.06']]
#  25 Positive    6.3   0.695   [['SPACY:NER-ORG'], ['HYPERNYM:entity.n.01']]
#  26 Positive    4.9   0.766   [['HYPERNYM:entity.n.01'], ['HYPERNYM:abstraction.n.06', 'SPACY:POS-PROPN']]
#  27 Negative   24.4   0.648   [['HYPERNYM:communication.n.02']]
#  28 Negative   17.9   0.593   [['HYPERNYM:abstraction.n.06'], ['HYPERNYM:entity.n.01']]
#  29 Positive    9.0   0.562   [['HYPERNYM:entity.n.01'], ['SPACY:DEP-compound']]
#  30 Positive    5.4   0.719   [['SPACY:DEP-compound', 'SPACY:NER-ORG', 'SPACY:POS-PROPN']]
#  31 Positive    5.7   0.696   [['SPACY:POS-PROPN'], ['SPACY:NER-ORG']]
#  32 Positive    4.6   0.773   [['SPACY:DEP-compound'], ['SPACY:POS-PROPN'], ['HYPERNYM:entity.n.01']]
#  33 Positive    7.1   0.618   [['SPACY:DEP-compound'], ['HYPERNYM:communication.n.02']]
#  34 Positive    5.0   0.726   [['SPACY:DEP-compound'], ['SPACY:DEP-compound'], ['SPACY:POS-PROPN']]
#  35 Positive    3.4   0.861   [['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
#  36 Positive    4.1   0.793   [['HYPERNYM:entity.n.01'], ['SPACY:DEP-compound', 'SPACY:POS-PROPN']]
#  37 Negative   40.4   0.735   [['SPACY:DEP-amod']]
#  38 Negative   37.2   0.983   [['TEXT:i']]
#  39 Positive    4.4   0.756   [['SPACY:POS-SYM']]
#  40 Positive    4.5   0.748   [['TEXT:free']]
#  41 Positive    5.4   0.686   [['HYPERNYM:entity.n.01'], ['SPACY:NER-ORG']]
#  42 Positive    2.7   0.938   [['TEXT:txt']]
#  43 Positive    5.8   0.655   [['SPACY:DEP-compound'], ['HYPERNYM:abstraction.n.06', 'SPACY:DEP-compound']]
#  44 Positive    9.8   0.507   [['HYPERNYM:abstraction.n.06', 'SPACY:DEP-compound'], ['HYPERNYM:abstraction.n.06']]
#  45 Positive    2.2   1.000   [['TEXT:claim']]
#  46 Negative   16.1   0.602   [['TEXT:!']]
#  47 Negative   13.5   0.568   [['SPACY:DEP-compound'], ['SPACY:DEP-dobj']]
#  48 Negative   13.4   0.572   [['HYPERNYM:message.n.02']]
#  49 Positive    2.4   0.942   [['TEXT:mobile']]
#  50 Positive    5.6   0.640   [['SPACY:DEP-compound'], ['SPACY:DEP-compound'], ['HYPERNYM:abstraction.n.06']]
#  51 Positive    4.6   0.701   [['SPACY:DEP-compound', 'SPACY:NER-PERSON']]
#  52 Positive    3.6   0.787   [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  53 Negative   55.0   0.780   [['SPACY:DEP-pobj']]
#  54 Positive    5.2   0.658   [['SPACY:POS-NUM'], ['SPACY:DEP-compound']]
#  55 Positive    4.3   0.714   [['SPACY:DEP-dobj', 'SPACY:POS-NUM']]
#  56 Positive    4.6   0.691   [['HYPERNYM:abstraction.n.06', 'SPACY:POS-PROPN'], ['HYPERNYM:abstraction.n.06']]
#  57 Positive    3.7   0.758   [['SPACY:POS-NUM'], ['TEXT:.']]
#  58 Positive    2.9   0.838   [['HYPERNYM:transferred_property.n.01']]
#  59 Positive    6.2   0.588   [['SPACY:DEP-dobj', 'SPACY:POS-PROPN']]
#  60 Positive    4.4   0.692   [['HYPERNYM:abstraction.n.06'], ['HYPERNYM:communication.n.02']]
#  61 Negative   10.5   0.539   [['SPACY:POS-NUM'], ['HYPERNYM:entity.n.01']]
#  62 Positive    3.2   0.791   [['SPACY:DEP-dobj', 'SPACY:NER-ORG']]
#  63 Positive    2.6   0.862   [['HYPERNYM:communication.n.02'], ['SPACY:POS-PROPN']]
#  64 Positive    3.2   0.789   [['SPACY:POS-PROPN'], ['HYPERNYM:communication.n.02']]
#  65 Positive    4.1   0.701   [['HYPERNYM:entity.n.01'], ['SPACY:DEP-compound'], ['HYPERNYM:abstraction.n.06']]
#  66 Positive    4.4   0.677   [['SPACY:POS-PROPN'], ['SPACY:DEP-dobj']]
#  67 Positive    5.3   0.622   [['SPACY:POS-PROPN'], ['HYPERNYM:object.n.01']]
#  68 Negative   72.7   0.816   [['HYPERNYM:abstraction.n.06']]
#  69 Positive    2.7   0.835   [['SPACY:POS-PROPN'], ['HYPERNYM:abstraction.n.06', 'SPACY:NER-ORG']]
#  70 Positive    2.2   0.922   [['HYPERNYM:win.v.01', 'SENTIMENT:pos']]
#  71 Positive    3.3   0.756   [['SPACY:POS-PROPN'], ['HYPERNYM:abstraction.n.06', 'SPACY:DEP-compound']]
#  72 Positive    2.9   0.798   [['SPACY:DEP-compound'], ['HYPERNYM:abstraction.n.06'], ['SPACY:POS-PROPN']]
#  73 Negative    9.4   0.539   [['SPACY:NER-ORG'], ['SPACY:NER-ORG']]
#  74 Positive    4.5   0.648   [['SPACY:DEP-compound'], ['HYPERNYM:abstraction.n.06'], ['HYPERNYM:entity.n.01']]
#  75 Positive    7.0   0.524   [['SPACY:DEP-amod'], ['SPACY:DEP-compound']]
#  76 Negative   30.8   0.725   [['TEXT:to']]
#  77 Positive    5.2   0.603   [['SPACY:DEP-compound'], ['HYPERNYM:act.n.02']]
#  78 Positive    3.2   0.746   [['SPACY:NER-ORG'], ['SPACY:DEP-compound']]
#  79 Positive    1.9   0.940   [['SPACY:NER-ORG'], ['TEXT:to']]
#  80 Positive    1.6   1.000   [['TEXT:prize']]
#  81 Negative    8.7   0.531   [['TEXT:to'], ['SPACY:DEP-pobj']]
#  82 Negative   21.7   0.686   [['HYPERNYM:relation.n.01']]
#  83 Positive    2.0   0.903   [['SPACY:POS-NUM'], ['SPACY:POS-SYM']]
#  84 Negative    8.7   0.535   [['HYPERNYM:entity.n.01'], ['TEXT:to']]
#  85 Positive    2.4   0.835   [['HYPERNYM:abstraction.n.06'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  86 Positive    1.8   0.938   [['TEXT:.'], ['TEXT:call']]
#  87 Negative    9.0   0.548   [['SPACY:POS-ADJ'], ['SPACY:DEP-compound']]
#  88 Positive    3.4   0.699   [['HYPERNYM:entity.n.01', 'SPACY:DEP-compound', 'SPACY:NER-ORG']]
#  89 Negative    8.7   0.543   [['SPACY:DEP-appos']]
#  90 Positive    3.0   0.745   [['SPACY:DEP-compound'], ['SPACY:DEP-dobj', 'SPACY:POS-PROPN']]
#  91 Positive    1.8   0.923   [['HYPERNYM:communication.n.02'], ['SPACY:POS-NUM']]
#  92 Positive    5.0   0.584   [['SPACY:DEP-compound'], ['HYPERNYM:relation.n.01']]
#  93 Positive    3.3   0.703   [['SPACY:POS-PROPN'], ['SPACY:DEP-compound'], ['HYPERNYM:abstraction.n.06']]
#  94 Positive    4.4   0.614   [['TEXT:call'], ['SPACY:DEP-dobj']]
#  95 Negative   39.9   0.761   [['SENTIMENT:pos']]
#  96 Positive    2.4   0.805   [['HYPERNYM:abstraction.n.06'], ['SPACY:NER-ORG', 'SPACY:POS-PROPN']]
#  97 Negative   20.4   0.686   [['HYPERNYM:act.n.02']]
#  98 Positive    4.8   0.588   [['HYPERNYM:communication.n.02', 'SPACY:DEP-compound']]
#  99 Positive    2.0   0.863   [['SPACY:NER-ORG'], ['SPACY:POS-NUM']]

# %% [markdown]
# ## Example 2

# %% [markdown]
# - Create a custom attribute - Hypernym3 (using only hypernyms which are at most three levels above the current synset)

# %%
HYPERNYM_DICT = dict()

def _get_anvr_pos(penn_tag: str): # Return Literal['a', 'n', 'v', 'r', None]
    if penn_tag.startswith('JJ'): # Adjective
        return 'a'
    elif penn_tag.startswith('NN'): # Noun
        return 'n'
    elif penn_tag.startswith('VB'): # Verb
        return 'v'
    elif penn_tag.startswith('RB'): # Adverb
        return 'r'
    else: # Invalid wordnet type
        return None 
    
def _get_all_hypernyms(synset: nltk.corpus.reader.wordnet.Synset, above: int) -> Set[nltk.corpus.reader.wordnet.Synset]:
    if above == 0:
        return set()
    
    if (str(synset), above) not in HYPERNYM_DICT:
        ans = set()
        direct_hypernyms = synset.hypernyms() # type: List[nltk.corpus.reader.wordnet.Synset]
        for ss in direct_hypernyms:
            ans.update(_get_all_hypernyms(ss, above-1))
            ans.update(set([ss]))
        HYPERNYM_DICT[(str(synset), above)] = ans
    return HYPERNYM_DICT[(str(synset), above)]
    
def _hypernym_extraction_3(text: str, tokens: List[str]) -> List[Set[str]]:
    ans = []
    for t in nlp(text):
        pos = _get_anvr_pos(t.tag_)
        if pos is not None:
            synset = lesk(tokens, t.text, pos)
            if synset is not None:
                all_hypernyms = set([synset]) # This version of hypernym extraction includes synset of the word itself
                all_hypernyms.update(_get_all_hypernyms(synset, 3))
                ans.append(set([str(ss)[8:-2] for ss in all_hypernyms]))
            else:
                ans.append(set([]))
        else:
            ans.append(set([]))
    return ans

Hypernym3Attribute = CustomAttribute(name = 'HYPERNYM3', extraction_function = _hypernym_extraction_3)

# %%
grasp_model_2 = GrASP(gaps_allowed = 2, num_patterns = 100, include_standard = ['TEXT', 'POS', 'SENTIMENT'],
                    include_custom = [Hypernym3Attribute],
                    correlation_threshold = 0.5, alphabet_size = 100)

# %%
the_patterns_2 = grasp_model_2.fit_transform(positive, negative)
# Out:
#   0%|          | 1/488 [00:00<01:12,  6.73it/s]
# Step 1: Create augmented texts
# 100%|██████████| 488/488 [00:27<00:00, 17.65it/s]
# 100%|██████████| 3079/3079 [02:28<00:00, 20.74it/s]
# Step 2: Find frequent attributes
#   0%|          | 5/1215 [00:00<00:26, 45.17it/s]
# Total number of candidate alphabet = 1215, such as ['SPACY:POS-VERB', 'SPACY:POS-NOUN', 'SPACY:POS-PUNCT', 'SPACY:POS-PRON', 'SPACY:POS-ADV']
# Step 3: Find alphabet set
# 100%|██████████| 1215/1215 [00:50<00:00, 24.17it/s]
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
# Finding top k: 100 / 100
#   0%|          | 0/100 [00:00<?, ?it/s]
# Total number of alphabet = 100
# ['SPACY:POS-NUM', 'SPACY:POS-PROPN', 'TEXT:call', 'TEXT:i', 'SPACY:POS-SYM', 'TEXT:free', 'TEXT:txt', 'TEXT:claim', 'TEXT:!', 'TEXT:mobile', 'HYPERNYM3:cost.n.01', 'SPACY:POS-ADP', 'HYPERNYM3:message.n.02', 'TEXT:to', 'TEXT:prize', 'HYPERNYM3:communication.n.02', 'HYPERNYM3:win.v.01', 'SENTIMENT:pos', 'HYPERNYM3:symbol.n.01', 'HYPERNYM3:statement.n.01', 'TEXT:your', 'SPACY:POS-ADJ', 'TEXT:or', 'TEXT:text', 'TEXT:stop', 'TEXT:-', 'TEXT:150p', 'TEXT:guaranteed', 'TEXT:urgent', 'HYPERNYM3:textbook.n.01', 'HYPERNYM3:act.n.02', 'TEXT:win', 'HYPERNYM3:contest.v.01', 'TEXT:+', 'HYPERNYM3:written_communication.n.01', 'SPACY:POS-PRON', 'TEXT:16', 'TEXT:cash', 'HYPERNYM3:abstraction.n.06', 'TEXT:from', 'HYPERNYM3:assertion.n.01', 'TEXT:reply', 'TEXT:now', 'TEXT:.', 'TEXT:tone', 'TEXT:18', 'HYPERNYM3:acquisition.n.02', 'SPACY:POS-DET', 'TEXT:nokia', 'TEXT:a', 'HYPERNYM3:user.n.01', 'TEXT:our', 'HYPERNYM3:mobile.n.02', 'HYPERNYM3:minute.n.01', 'HYPERNYM3:person.n.01', 'HYPERNYM3:claim.v.03', 'TEXT:service', 'TEXT:contact', 'HYPERNYM3:writing.n.02', 'TEXT:for', 'TEXT:...', 'HYPERNYM3:offer.n.02', 'TEXT:awarded', 'TEXT:â£1000', 'TEXT:150ppm', 'TEXT:4', 'HYPERNYM3:request.n.01', 'TEXT:per', 'HYPERNYM3:call.v.28', 'HYPERNYM3:convey.v.03', 'HYPERNYM3:television_camera.n.01', 'HYPERNYM3:land_line.n.01', 'TEXT:ur', 'HYPERNYM3:state.v.01', 'TEXT:camera', 'HYPERNYM3:phone.n.02', 'TEXT:rate', 'TEXT:my', 'HYPERNYM3:plastic_art.n.01', 'TEXT:latest', 'HYPERNYM3:text.n.04', 'HYPERNYM3:coding_system.n.01', 'TEXT:box', 'TEXT:draw', 'TEXT::', 'HYPERNYM3:event.n.01', 'TEXT:line', 'HYPERNYM3:free.a.01', 'TEXT:shows', 'HYPERNYM3:now.r.03', 'HYPERNYM3:declare.v.01', 'TEXT:10p', 'TEXT:collection', 'TEXT:2', 'SPACY:POS-NOUN', 'HYPERNYM3:memory_device.n.01', 'HYPERNYM3:document.n.01', 'HYPERNYM3:service.n.11', 'HYPERNYM3:equipment.n.01', 'HYPERNYM3:part.n.01']
# Example of patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Examples ~ Class Negative:
# [MATCH]: Sorry . You never hear unless you book it . One:['SPACY:POS-NUM'] was kinda a joke -- thet were really looking for skinny white girls . The other was one line -- you can only do so much on camera with that . Something like that they 're casting on the look .
# -------------------------
# [MATCH]: Am I the only one:['SPACY:POS-NUM'] who does n't stalk profiles ?
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Welcome to Select , an O2 service with added benefits . You can now call our specially trained advisors FREE from your mobile by dialling 402:['SPACY:POS-NUM'] .
# -------------------------
# [MATCH]: December only ! Had your mobile 11mths+:['SPACY:POS-NUM'] ? You are entitled to update to the latest colour camera mobile for Free ! Call The Mobile Update Co FREE on 08002986906
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN']]
# Window size: 3
# Class: Negative
# Precision: 0.690
# Match: 1347 (37.8%)
# Gain = 0.112
# Examples ~ Class Negative:
# [MATCH]: Macha do nt feel upset.i:['SPACY:POS-PROPN'] can assume your mindset.believe me one evening with me and i have some wonderful plans for both of us . LET LIFE BEGIN AGAIN.call me anytime
# -------------------------
# [MATCH]: HIYA:['SPACY:POS-PROPN'] COMIN 2 BRISTOL 1 ST WEEK IN APRIL . LES GOT OFF + RUDI ON NEW YRS EVE BUT I WAS SNORING.THEY WERE DRUNK ! U BAK AT COLLEGE YET ? MY WORK SENDS INK 2 BATH .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Congrats 2 mobile 3 G Videophones:['SPACY:POS-PROPN'] R yours . call 09063458130 now ! videochat wid ur mates , play java games , Dload polypH music , noline rentl . bx420 . ip4 . 5we . 150p
# -------------------------
# [MATCH]: Your free ringtone is waiting to be collected . Simply text the password " MIX:['SPACY:POS-PROPN'] " to 85069 to verify . Get Usher and Britney . FML , PO Box 5249 , MK17 92H. 450Ppw 16
# -------------------------
# ==================================================
# Pattern: [['TEXT:call']]
# Window size: 3
# Class: Positive
# Precision: 0.618
# Match: 348 (9.8%)
# Gain = 0.104
# Examples ~ Class Positive:
# [MATCH]: WIN URGENT ! Your mobile number has been awarded with a Â£2000 prize GUARANTEED call:['TEXT:call'] 09061790121 from land line . claim 3030 valid 12hrs only 150ppm
# -------------------------
# [MATCH]: INTERFLORA - Â“It 's not too late to order Interflora flowers for christmas call:['TEXT:call'] 0800 505060 to place your order before Midnight tomorrow .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Sorry , I 'll call:['TEXT:call'] later
# -------------------------
# [MATCH]: Sorry , I 'll call:['TEXT:call'] later in meeting
# -------------------------
# ==================================================
# Pattern: [['TEXT:i']]
# Window size: 3
# Class: Negative
# Precision: 0.983
# Match: 1327 (37.2%)
# Gain = 0.067
# Examples ~ Class Negative:
# [MATCH]: Thank You for calling . Forgot to say Happy Onam to you Sirji . I:['TEXT:i'] am fine here and remembered you when i met an insurance person . Meet You in Qatar Insha Allah . Rakhesh , ex Tata AIG who joined TISSCO , Tayseer .
# -------------------------
# [MATCH]: I:['TEXT:i'] have many dependents
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: I:['TEXT:i'] do n't know u and u do n't know me . Send CHAT to 86688 now and let 's find each other ! Only 150p / Msg rcvd . HG / Suite342/2Lands / Row / W1J6HL LDN . 18 years or over .
# -------------------------
# [MATCH]: I:['TEXT:i'] want some cock ! My hubby 's away , I need a real man 2 satisfy me . Txt WIFE to 89938 for no strings action . ( Txt STOP 2 end , txt rec Â£1.50ea . OTBox 731 LA1 7WS . )
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-SYM']]
# Window size: 3
# Class: Positive
# Precision: 0.756
# Match: 156 (4.4%)
# Gain = 0.067
# Examples ~ Class Positive:
# [MATCH]: Urgent ! call 09066612661 from landline . Your complementary 4 * Tenerife Holiday or Â£10,000 cash await collection SAE T&Cs PO Box 3 WA14 2PX 150ppm 18 +:['SPACY:POS-SYM'] Sender : Hol Offer
# -------------------------
# [MATCH]: Hi ya babe x:['SPACY:POS-SYM'] u 4goten bout me ? ' scammers getting smart .. Though this is a regular vodafone no , if you respond you get further prem rate msg / subscription . Other nos used also . Beware !
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Turns out my friends are staying for the whole show and wo n't be back til ~ & lt;#&gt ; , so feel free to go ahead and smoke that $:['SPACY:POS-SYM'] & lt;#&gt ;   worth
# -------------------------
# [MATCH]: I 'll text you when I drop x:['SPACY:POS-SYM'] off
# -------------------------
# ==================================================
# Step 4: Grow patterns
# 100%|██████████| 100/100 [01:39<00:00,  1.00it/s]
# Length 2 / 5; New candidates = 14950
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Examples ~ Class Negative:
# [MATCH]: U studying in sch or going home ? Anyway i 'll b going 2:['SPACY:POS-NUM'] sch later .
# -------------------------
# [MATCH]: Wat so late still early mah . Or we juz go 4:['SPACY:POS-NUM'] dinner lor . Aiya i dunno ...
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Latest Nokia Mobile or iPOD MP3 Player + Â£400 proze GUARANTEED ! Reply with : WIN to 83355:['SPACY:POS-NUM'] now ! Norcorp Ltd . Â£1,50/Mtmsgrcvd18 +
# -------------------------
# [MATCH]: Not heard from U4 a while . Call 4:['SPACY:POS-NUM'] rude chat private line 01223585334 to cum . Wan 2C pics of me gettin shagged then text PIX to 8552 . 2End send STOP 8552 SAM xxx
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.806
# Match: 319 (8.9%)
# Gain = 0.175
# Examples ~ Class Positive:
# [MATCH]: Please call our customer service representative on FREEPHONE:['SPACY:POS-PROPN'] 0808:['SPACY:POS-NUM'] 145 4742 between 9am-11pm as you have WON a guaranteed Â£1000 cash or Â£5000 prize !
# -------------------------
# [MATCH]: Great NEW Offer - DOUBLE Mins & DOUBLE Txt on best Orange tariffs AND get latest camera phones 4 FREE ! Call MobileUpd8:['SPACY:POS-PROPN'] free on 08000839402:['SPACY:POS-NUM'] NOW ! or 2stoptxt T&Cs
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I am going to film 2day da:['SPACY:POS-PROPN'] . At 6:['SPACY:POS-NUM'] pm . Sorry da .
# -------------------------
# [MATCH]: IM FINE BABES AINT:['SPACY:POS-PROPN'] BEEN UP 2:['SPACY:POS-NUM'] MUCH THO ! SAW SCARY MOVIE YEST ITS QUITE FUNNY ! WANT 2MRW AFTERNOON ? AT TOWN OR MALL OR SUMTHIN?xx
# -------------------------
# ==================================================
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.984
# Match: 183 (5.1%)
# Gain = 0.152
# Examples ~ Class Positive:
# [MATCH]: URGENT This is our 2nd attempt to contact U. Your Â£900 prize from YESTERDAY is still awaiting collection . To claim CALL:['TEXT:call'] NOW 09061702893:['SPACY:POS-NUM'] . ACL03530150PM
# -------------------------
# [MATCH]: Do nt forget you can place as many FREE Requests with 1stchoice.co.uk as you wish . For more Information call:['TEXT:call'] 08707808226:['SPACY:POS-NUM'] .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I 'm in a movie . Call:['TEXT:call'] me 4:['SPACY:POS-NUM'] wat ?
# -------------------------
# [MATCH]: Yun ah.the ubi one say if Ã¼ wan call:['TEXT:call'] by tomorrow.call 67441233:['SPACY:POS-NUM'] look for irene.ere only got bus8,22,65,61,66,382 . Ubi cres , ubi tech park.6ph for 1st 5wkg days . Ã¨n
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.579
# Match: 518 (14.5%)
# Gain = 0.148
# Examples ~ Class Positive:
# [MATCH]: XMAS:['SPACY:POS-PROPN'] Prize:['SPACY:POS-PROPN'] draws ! We are trying to contact U. Todays draw shows that you have won a Â£2000 prize GUARANTEED . Call 09058094565 from land line . Valid 12hrs only
# -------------------------
# [MATCH]: U have a secret admirer who is looking 2 make contact with U - find out who they R*reveal:['SPACY:POS-PROPN'] who thinks UR:['SPACY:POS-PROPN'] so special - call on 09058094599
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Your opinion about me ? 1 . Over 2 . Jada:['SPACY:POS-PROPN'] 3 . Kusruthi:['SPACY:POS-PROPN'] 4 . Lovable 5 . Silent 6 . Spl character 7 . Not matured 8 . Stylish 9 . Simple Pls reply ..
# -------------------------
# [MATCH]: " YEH:['SPACY:POS-PROPN'] I AM DEF:['SPACY:POS-PROPN'] UP4 SOMETHING SAT , JUST GOT PAYED2DAY & I HAVBEEN GIVEN AÂ£50 PAY RISE 4MY WORK & HAVEBEEN MADE PRESCHOOLCO - ORDINATOR 2I AM FEELINGOOD LUV "
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.613
# Match: 421 (11.8%)
# Gain = 0.129
# Examples ~ Class Positive:
# [MATCH]: < Forwarded from:['SPACY:POS-ADP'] 448712404000>Please:['SPACY:POS-NUM'] CALL 08712404000 immediately as there is an urgent message waiting for you .
# -------------------------
# [MATCH]: CDs 4u : Congratulations ur awarded Â£500 of CD gift vouchers or Â£125 gift guaranteed & Freeentry 2 Â£100 wkly draw xt:['SPACY:POS-ADP'] MUSIC to 87066:['SPACY:POS-NUM'] TnCs www.ldew.com1win150ppmx3age16
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: What is your record for:['SPACY:POS-ADP'] one:['SPACY:POS-NUM'] night ? :)
# -------------------------
# [MATCH]: Your opinion about:['SPACY:POS-ADP'] me ? 1:['SPACY:POS-NUM'] . Over 2 . Jada 3 . Kusruthi 4 . Lovable 5 . Silent 6 . Spl character 7 . Not matured 8 . Stylish 9 . Simple Pls reply ..
# -------------------------
# ==================================================
# 100%|██████████| 68/68 [02:08<00:00,  1.89s/it]
# Length 3 / 5; New candidates = 13344
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Examples ~ Class Negative:
# [MATCH]: Hi mate its RV did u hav a nice hol just a message 3:['SPACY:POS-NUM'] say hello coz havenÂ’t sent u 1 in ages started driving so stay off roads!RVx
# -------------------------
# [MATCH]: I will reach before ten:['SPACY:POS-NUM'] morning
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Babe : U want me do nt u:['SPACY:POS-NUM'] baby ! I m nasty and have a thing 4 filthyguys . Fancy a rude time with a sexy bitch . How about we go slo n hard ! Txt XXX SLO(4msgs )
# -------------------------
# [MATCH]: Ur cash - balance is currently 500:['SPACY:POS-NUM'] pounds - to maximize ur cash - in now send GO to 86688 only 150p / msg . CC : 08718720201 PO BOX 114/14 TCR / W1
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.806
# Match: 319 (8.9%)
# Gain = 0.175
# Examples ~ Class Positive:
# [MATCH]: PRIVATE ! Your 2003 Account Statement for < fone no > shows 800 un - redeemed S. I. M. points . Call 08715203656 Identifier:['SPACY:POS-PROPN'] Code : 42049:['SPACY:POS-NUM'] Expires 26/10/04
# -------------------------
# [MATCH]: Want a new Video:['SPACY:POS-PROPN'] Phone ? 750:['SPACY:POS-NUM'] anytime any network mins ? Half price line rental free text for 3 months ? Reply or call 08000930705 for free delivery
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Your opinion about me ? 1 . Over 2 . Jada:['SPACY:POS-PROPN'] 3:['SPACY:POS-NUM'] . Kusruthi 4 . Lovable 5 . Silent 6 . Spl character 7 . Not matured 8 . Stylish 9 . Simple Pls reply ..
# -------------------------
# [MATCH]: Ooh:['SPACY:POS-PROPN'] , 4got:['SPACY:POS-NUM'] , i 'm gon na start belly dancing in moseley weds 6.30 if u want 2 join me , they have a cafe too .
# -------------------------
# ==================================================
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.984
# Match: 183 (5.1%)
# Gain = 0.152
# Examples ~ Class Positive:
# [MATCH]: WINNER ! As a valued network customer you hvae been selected to receive a Â£900 reward ! To collect call:['TEXT:call'] 09061701444:['SPACY:POS-NUM'] . Valid 24 hours only . ACL03530150PM
# -------------------------
# [MATCH]: Do you want 750 anytime any network mins 150 text and a NEW VIDEO phone for only five pounds per week call:['TEXT:call'] 08002888812:['SPACY:POS-NUM'] or reply for delivery tomorrow
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Ummma.will call:['TEXT:call'] after check in.our:['SPACY:POS-NUM'] life will begin from qatar so pls pray very hard .
# -------------------------
# [MATCH]: Yun ah.the ubi one say if Ã¼ wan call:['TEXT:call'] by tomorrow.call 67441233:['SPACY:POS-NUM'] look for irene.ere only got bus8,22,65,61,66,382 . Ubi cres , ubi tech park.6ph for 1st 5wkg days . Ã¨n
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.579
# Match: 518 (14.5%)
# Gain = 0.148
# Examples ~ Class Positive:
# [MATCH]: Had your contract mobile 11 Mnths:['SPACY:POS-PROPN'] ? Latest Motorola:['SPACY:POS-PROPN'] , Nokia etc . all FREE ! Double Mins & Text on Orange tariffs . TEXT YES for callback , no to remove from records
# -------------------------
# [MATCH]: TheMob > Check out our newest selection of content , Games:['SPACY:POS-PROPN'] , Tones:['SPACY:POS-PROPN'] , Gossip , babes and sport , Keep your mobile fit and funky text WAP to 82468
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: " CHEERS FOR CALLIN:['SPACY:POS-PROPN'] BABE.SOZI CULDNT TALKBUT:['SPACY:POS-PROPN'] I WANNATELL U DETAILS LATER WENWECAN CHAT PROPERLY X "
# -------------------------
# [MATCH]: THANX4:['SPACY:POS-PROPN'] TODAY:['SPACY:POS-PROPN'] CER IT WAS NICE 2 CATCH UP BUT WE AVE 2 FIND MORE TIME MORE OFTEN OH WELL TAKE CARE C U SOON.C
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.613
# Match: 421 (11.8%)
# Gain = 0.129
# Examples ~ Class Positive:
# [MATCH]: PRIVATE ! Your 2003 Account Statement for:['SPACY:POS-ADP'] shows 800:['SPACY:POS-NUM'] un - redeemed S.I.M. points . Call 08718738001 Identifier Code : 49557 Expires 26/11/04
# -------------------------
# [MATCH]: You have won a Nokia 7250i . This is what you get when you win our FREE auction . To take part send Nokia to:['SPACY:POS-ADP'] 86021:['SPACY:POS-NUM'] now . HG / Suite342/2Lands Row / W1JHL 16 +
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I shall book chez jules for:['SPACY:POS-ADP'] half eight:['SPACY:POS-NUM'] , if that 's ok with you ?
# -------------------------
# [MATCH]: " NOT ENUFCREDEIT TOCALL.SHALL ILEAVE UNI AT:['SPACY:POS-ADP'] 6:['SPACY:POS-NUM'] + GET A BUS TO YOR HOUSE ? "
# -------------------------
# ==================================================
# 100%|██████████| 36/36 [01:22<00:00,  2.28s/it]
# Length 4 / 5; New candidates = 7137
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
#   0%|          | 0/5 [00:00<?, ?it/s]
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Examples ~ Class Negative:
# [MATCH]: Yeah so basically any time next week you can get away from your mom & amp ; get up before 3:['SPACY:POS-NUM']
# -------------------------
# [MATCH]: Solve d Case : A Man Was Found Murdered On   & lt;DECIMAL&gt ; . & lt;#&gt ;   AfterNoon . 1,His:['SPACY:POS-NUM'] wife called Police . 2,Police questioned everyone . 3,Wife : Sir , I was sleeping , when the murder took place . 4.Cook : I was cooking . 5.Gardener : I was picking vegetables . 6.House - Maid : I went 2 d post office . 7.Children : We went 2 play . 8.Neighbour : We went 2 a marriage . Police arrested d murderer Immediately . Who 's It ? Reply With Reason , If U r Brilliant .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: FreeMsg : Txt : CALL to No : 86888:['SPACY:POS-NUM'] & claim your reward of 3 hours talk time to use from your phone now ! Subscribe6GBP / mnth inc 3hrs 16 stop?txtStop
# -------------------------
# [MATCH]: Want 2:['SPACY:POS-NUM'] get laid tonight ? Want real Dogging locations sent direct 2 ur mob ? Join the UK 's largest Dogging Network bt Txting GRAVEL to 69888 ! Nt . ec2a . 31p.msg@150p
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.806
# Match: 319 (8.9%)
# Gain = 0.175
# Examples ~ Class Positive:
# [MATCH]: Adult:['SPACY:POS-PROPN'] 18:['SPACY:POS-NUM'] Content Your video will be with you shortly
# -------------------------
# [MATCH]: PRIVATE ! Your 2003 Account:['SPACY:POS-PROPN'] Statement for 07753741225:['SPACY:POS-NUM'] shows 800 un - redeemed S. I. M. points . Call 08715203677 Identifier Code : 42478 Expires 24/10/04
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: " BOO BABE ! U ENJOYIN YOURJOB ? U:['SPACY:POS-PROPN'] SEEMED 2:['SPACY:POS-NUM'] B GETTIN ON WELL HUNNY!HOPE URE OK?TAKE CARE & IÂ’LLSPEAK 2U SOONLOTS OF LOVEME XXXX . "
# -------------------------
# [MATCH]: Boy ; I love u Grl : Hogolo Boy : gold chain kodstini Grl : Agalla Boy : necklace madstini Grl : agalla Boy : Hogli:['SPACY:POS-PROPN'] 1:['SPACY:POS-NUM'] mutai eerulli kodthini ! Grl : I love U kano;- )
# -------------------------
# ==================================================
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.984
# Match: 183 (5.1%)
# Gain = 0.152
# Examples ~ Class Positive:
# [MATCH]: Todays Voda numbers ending 5226 are selected to receive a ? 350 award . If you hava a match please call:['TEXT:call'] 08712300220:['SPACY:POS-NUM'] quoting claim code 1131 standard rates app
# -------------------------
# [MATCH]: Do you want a new video handset ? 750 anytime any network mins ? Half Price Line Rental ? Camcorder ? Reply or call:['TEXT:call'] 08000930705:['SPACY:POS-NUM'] for delivery tomorrow
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I 'm in a movie . Call:['TEXT:call'] me 4:['SPACY:POS-NUM'] wat ?
# -------------------------
# [MATCH]: Ummma.will call:['TEXT:call'] after check in.our:['SPACY:POS-NUM'] life will begin from qatar so pls pray very hard .
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.579
# Match: 518 (14.5%)
# Gain = 0.148
# Examples ~ Class Positive:
# [MATCH]: The current leading bid is 151 . To pause this auction send OUT . Customer:['SPACY:POS-PROPN'] Care:['SPACY:POS-PROPN'] : 08718726270
# -------------------------
# [MATCH]: Dear Voucher:['SPACY:POS-PROPN'] Holder:['SPACY:POS-PROPN'] 2 claim your 1st class airport lounge passes when using Your holiday voucher call 08704439680 . When booking quote 1st class x 2
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: WOT:['SPACY:POS-PROPN'] U WANNA:['SPACY:POS-PROPN'] DO THEN MISSY ?
# -------------------------
# [MATCH]: Honeybee Said : * I 'm d Sweetest in d World * God:['SPACY:POS-PROPN'] Laughed:['SPACY:POS-PROPN'] & amp ; Said : * Wait , U Havnt Met d Person Reading This Msg * MORAL : Even GOD Can Crack Jokes ! GM+GN+GE+GN : )
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.613
# Match: 421 (11.8%)
# Gain = 0.129
# Examples ~ Class Positive:
# [MATCH]: 74355 XMAS iscoming & ur awarded either Â£500 CD gift vouchers & free entry 2 r Â£100 weekly draw txt MUSIC to:['SPACY:POS-ADP'] 87066:['SPACY:POS-NUM'] TnC
# -------------------------
# [MATCH]: Last Chance ! Claim ur Â£150 worth of discount vouchers today ! Text SHOP to:['SPACY:POS-ADP'] 85023:['SPACY:POS-NUM'] now ! SavaMob , offers mobile ! T Cs SavaMob POBOX84 , M263UZ . Â£3.00 Sub . 16
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Not planned yet : ) going to join company on:['SPACY:POS-ADP'] jan 5:['SPACY:POS-NUM'] only.don know what will happen after that .
# -------------------------
# [MATCH]: Purity of:['SPACY:POS-ADP'] friendship between two:['SPACY:POS-NUM'] is not about smiling after reading the forwarded message .. Its about smiling just by seeing the name . Gud evng musthu
# -------------------------
# ==================================================
# 100%|██████████| 5/5 [00:09<00:00,  1.83s/it]
# Length 5 / 5; New candidates = 994
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Examples ~ Class Negative:
# [MATCH]: â€ ¦ and donâ€˜t worry weâ€˜ll have finished by march â€ ¦:['SPACY:POS-NUM'] ish !
# -------------------------
# [MATCH]: OH YEAH , AND HAV A GREAT TIME IN NEWQUAY - SEND ME A POSTCARD ! 1:['SPACY:POS-NUM'] LOOK AFTER ALL THE GIRLS WHILE IM GONE(U KNOW THE 1IM TALKIN BOUT!)xx
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Will u meet ur dream partner soon ? Is ur career off 2:['SPACY:POS-NUM'] a flyng start ? 2 find out free , txt HORO followed by ur star sign , e. g. HORO ARIES
# -------------------------
# [MATCH]: Sunshine Hols . To claim ur med holiday send a stamped self address envelope to Drinks on Us UK , PO Box 113:['SPACY:POS-NUM'] , Bray , Wicklow , Eire . Quiz Starts Saturday ! Unsub Stop
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.806
# Match: 319 (8.9%)
# Gain = 0.175
# Examples ~ Class Positive:
# [MATCH]: U have a secret admirer . REVEAL who thinks U R So special . Call 09065174042 . To opt out Reply REVEAL:['SPACY:POS-PROPN'] STOP . 1.50:['SPACY:POS-NUM'] per msg recd . Cust care 07821230901
# -------------------------
# [MATCH]: FREE for 1st week ! No1:['SPACY:POS-PROPN'] Nokia tone 4:['SPACY:POS-NUM'] ur mobile every week just txt NOKIA to 8077 Get txting and tell ur mates . www.getzed.co.uk POBox 36504 W45WQ 16 + norm150p / tone
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Just got part Nottingham:['SPACY:POS-PROPN'] - 3:['SPACY:POS-NUM'] hrs 63miles . Good thing i love my man so much , but only doing 40 mph . Hey ho
# -------------------------
# [MATCH]: Solve d Case : A Man Was Found Murdered On   & lt;DECIMAL&gt ; . & lt;#&gt ;   AfterNoon:['SPACY:POS-PROPN'] . 1,His:['SPACY:POS-NUM'] wife called Police . 2,Police questioned everyone . 3,Wife : Sir , I was sleeping , when the murder took place . 4.Cook : I was cooking . 5.Gardener : I was picking vegetables . 6.House - Maid : I went 2 d post office . 7.Children : We went 2 play . 8.Neighbour : We went 2 a marriage . Police arrested d murderer Immediately . Who 's It ? Reply With Reason , If U r Brilliant .
# -------------------------
# ==================================================
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.984
# Match: 183 (5.1%)
# Gain = 0.152
# Examples ~ Class Positive:
# [MATCH]: Panasonic & BluetoothHdset FREE . Nokia FREE . Motorola FREE & DoubleMins & DoubleTxt on Orange contract . Call:['TEXT:call'] MobileUpd8 on 08000839402:['SPACY:POS-NUM'] or call 2optout
# -------------------------
# [MATCH]: Congratulations ur awarded either a yrs supply of CDs from Virgin Records or a Mystery Gift GUARANTEED Call:['TEXT:call'] 09061104283:['SPACY:POS-NUM'] Ts&Cs www.smsco.net Â£1.50pm approx 3mins
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Ummma.will call:['TEXT:call'] after check in.our:['SPACY:POS-NUM'] life will begin from qatar so pls pray very hard .
# -------------------------
# [MATCH]: Yun ah.the ubi one say if Ã¼ wan call:['TEXT:call'] by tomorrow.call 67441233:['SPACY:POS-NUM'] look for irene.ere only got bus8,22,65,61,66,382 . Ubi cres , ubi tech park.6ph for 1st 5wkg days . Ã¨n
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.579
# Match: 518 (14.5%)
# Gain = 0.148
# Examples ~ Class Positive:
# [MATCH]: 8007 25p 4 Alfie:['SPACY:POS-PROPN'] Moon:['SPACY:POS-PROPN'] 's Children in Need song on ur mob . Tell ur m8s . Txt TONE CHARITY to 8007 for nokias or POLY CHARITY for polys : zed 08701417012 profit 2 charity
# -------------------------
# [MATCH]: HMV:['SPACY:POS-PROPN'] BONUS:['SPACY:POS-PROPN'] SPECIAL 500 pounds of genuine HMV vouchers to be won . Just answer 4 easy questions . Play Now ! Send HMV to 86688 More info : www.100percent - real.com
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: House:['SPACY:POS-PROPN'] - Maid:['SPACY:POS-PROPN'] is the murderer , coz the man was murdered on   & lt;#&gt ; th January .. As public holiday all govt.instituitions are closed , including post office .. understand ?
# -------------------------
# [MATCH]: The word " Checkmate " in chess comes from the Persian phrase " Shah:['SPACY:POS-PROPN'] Maat:['SPACY:POS-PROPN'] " which means ; " the king is dead .. " Goodmorning .. Have a good day .. : )
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.613
# Match: 421 (11.8%)
# Gain = 0.129
# Examples ~ Class Positive:
# [MATCH]: Married local women looking for discreet action now ! 5 real matches instantly to your phone . Text MATCH to:['SPACY:POS-ADP'] 69969:['SPACY:POS-NUM'] Msg cost 150p 2 stop txt stop BCMSFWC1N3XX
# -------------------------
# [MATCH]: Ur cash - balance is currently 500 pounds - to maximize ur cash - in now send COLLECT to:['SPACY:POS-ADP'] 83600:['SPACY:POS-NUM'] only 150p / msg . CC : 08718720201 PO BOX 114/14 TCR / W1
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Yeah he got in at:['SPACY:POS-ADP'] 2:['SPACY:POS-NUM'] and was v apologetic . n had fallen out and she was actin like spoilt child and he got caught up in that . Till 2 ! But we wo n't go there ! Not doing too badly cheers . You ?
# -------------------------
# [MATCH]: The   & lt;#&gt ; g that i saw a few days ago , the guy wants sell wifi only for   & lt;#&gt ;   and with:['SPACY:POS-ADP'] 3:['SPACY:POS-NUM'] g for   & lt;#&gt ; . That 's why i blanked him .
# -------------------------
# ==================================================

# %%
for idx, p in enumerate(the_patterns_2):
    print(f'Rank {idx}')
    print(p)
# Out:
# Rank 0
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Examples ~ Class Negative:
# [MATCH]: HIYA STU WOT U UP 2.IM:['SPACY:POS-NUM'] IN SO MUCH TRUBLE AT HOME AT MOMENT EVONE HATES ME EVEN U ! WOT THE HELL AV I DONE NOW ? Y WONT U JUST TELL ME TEXT BCK PLEASE LUV DAN
# -------------------------
# [MATCH]: Dnt worry ... use ice pieces in a cloth pack.also take 2:['SPACY:POS-NUM'] tablets .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: from www . Applausestore.com MonthlySubscription@50p / msg max6/month T&CsC web age16:['SPACY:POS-NUM'] 2stop txt stop
# -------------------------
# [MATCH]: SMS AUCTION You have won a Nokia 7250i:['SPACY:POS-NUM'] . This is what you get when you win our FREE auction . To take part send Nokia to 86021 now . HG / Suite342/2Lands Row / W1JHL 16 +
# -------------------------
# ==================================================
# Rank 1
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.806
# Match: 319 (8.9%)
# Gain = 0.175
# Examples ~ Class Positive:
# [MATCH]: 22 days to kick off ! For Euro2004 U will be kept up to date with the latest news and results daily . To be removed send GET TXT:['SPACY:POS-PROPN'] STOP to 83222:['SPACY:POS-NUM']
# -------------------------
# [MATCH]: PRIVATE ! Your 2003 Account Statement:['SPACY:POS-PROPN'] for shows 800:['SPACY:POS-NUM'] un - redeemed S.I.M. points . Call 08718738001 Identifier Code : 49557 Expires 26/11/04
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I REALLY NEED 2 KISS U I MISS U MY BABY FROM UR:['SPACY:POS-PROPN'] BABY 4EVA:['SPACY:POS-NUM']
# -------------------------
# [MATCH]: HEY THERE BABE , HOW U DOIN ? WOT:['SPACY:POS-PROPN'] U UP 2:['SPACY:POS-NUM'] 2NITE LOVE ANNIE X.
# -------------------------
# ==================================================
# Rank 2
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.984
# Match: 183 (5.1%)
# Gain = 0.152
# Examples ~ Class Positive:
# [MATCH]: You are a winner you have been specially selected to receive Â£1000 cash or a Â£2000 award . Speak to a live operator to claim call:['TEXT:call'] 087123002209am-7pm:['SPACY:POS-NUM'] . Cost 10p
# -------------------------
# [MATCH]: A Â£400 XMAS REWARD IS WAITING FOR YOU ! Our computer has randomly picked you from our loyal mobile customers to receive a Â£400 reward . Just call:['TEXT:call'] 09066380611:['SPACY:POS-NUM']
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I 'm in a movie . Call:['TEXT:call'] me 4:['SPACY:POS-NUM'] wat ?
# -------------------------
# [MATCH]: Ummma.will call:['TEXT:call'] after check in.our:['SPACY:POS-NUM'] life will begin from qatar so pls pray very hard .
# -------------------------
# ==================================================
# Rank 3
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.579
# Match: 518 (14.5%)
# Gain = 0.148
# Examples ~ Class Positive:
# [MATCH]: Last Chance ! Claim ur Â£150 worth of discount vouchers today ! Text SHOP to 85023 now ! SavaMob , offers mobile ! T:['SPACY:POS-PROPN'] Cs:['SPACY:POS-PROPN'] SavaMob POBOX84 , M263UZ . Â£3.00 Sub . 16
# -------------------------
# [MATCH]: U have a secret admirer who is looking 2 make contact with U - find out who they R*reveal:['SPACY:POS-PROPN'] who thinks UR:['SPACY:POS-PROPN'] so special - call on 09058094599
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Well there 's not a lot of things happening in Lindsay:['SPACY:POS-PROPN'] on New:['SPACY:POS-PROPN'] years * sighs * Some bars in Ptbo and the blue heron has something going
# -------------------------
# [MATCH]: Heart is empty without love .. Mind is empty without wisdom .. Eyes r empty without dreams & amp ; Life is empty without frnds .. So Alwys:['SPACY:POS-PROPN'] Be In Touch:['SPACY:POS-PROPN'] . Good night & amp ; sweet dreams
# -------------------------
# ==================================================
# Rank 4
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.613
# Match: 421 (11.8%)
# Gain = 0.129
# Examples ~ Class Positive:
# [MATCH]: Welcome to UK - mobile - date this msg is FREE giving you free calling to:['SPACY:POS-ADP'] 08719839835:['SPACY:POS-NUM'] . Future mgs billed at 150p daily . To cancel send " go stop " to 89123
# -------------------------
# [MATCH]: Someone has contacted our dating service and entered your phone becausethey fancy you ! To find out who it is call from:['SPACY:POS-ADP'] a landline 09058098002:['SPACY:POS-NUM'] . PoBox1 , W14RG 150p
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Yup ... Ok i go home look at the timings then i msg Ã¼ again ... Xuhui going to learn on 2nd may too but her lesson is at:['SPACY:POS-ADP'] 8:['SPACY:POS-NUM'] am
# -------------------------
# [MATCH]: Not thought bout it ... || Drink in tap & spile at:['SPACY:POS-ADP'] seven:['SPACY:POS-NUM'] . || Is that pub on gas st off broad st by canal . || Ok ?
# -------------------------
# ==================================================
# Rank 5
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.811
# Match: 243 (6.8%)
# Gain = 0.129
# Examples ~ Class Positive:
# [MATCH]: * * FREE MESSAGE**Thanks for using the Auction Subscription Service . 18 . 150p:['SPACY:POS-NUM'] / MSGRCVD:['SPACY:POS-PROPN'] 2 Skip an Auction txt OUT . 2 Unsubscribe txt STOP CustomerCare 08718726270
# -------------------------
# [MATCH]: Hi 07734396839:['SPACY:POS-NUM'] IBH:['SPACY:POS-PROPN'] Customer Loyalty Offer : The NEW NOKIA6600 Mobile from ONLY Â£10 at TXTAUCTION!Txt word : START to No:81151 & get Yours Now!4 T &
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Solve d Case : A Man Was Found Murdered On   & lt;DECIMAL&gt ; . & lt;#&gt ;   AfterNoon . 1,His:['SPACY:POS-NUM'] wife called Police:['SPACY:POS-PROPN'] . 2,Police questioned everyone . 3,Wife : Sir , I was sleeping , when the murder took place . 4.Cook : I was cooking . 5.Gardener : I was picking vegetables . 6.House - Maid : I went 2 d post office . 7.Children : We went 2 play . 8.Neighbour : We went 2 a marriage . Police arrested d murderer Immediately . Who 's It ? Reply With Reason , If U r Brilliant .
# -------------------------
# [MATCH]: Solve d Case : A Man Was Found Murdered On   & lt;DECIMAL&gt ; . & lt;#&gt ;   AfterNoon . 1,His:['SPACY:POS-NUM'] wife called Police:['SPACY:POS-PROPN'] . 2,Police questioned everyone . 3,Wife : Sir , I was sleeping , when the murder took place . 4.Cook : I was cooking . 5.Gardener : I was picking vegetables . 6.House - Maid : I went 2 d post office . 7.Children : We went 2 play . 8.Neighbour : We went 2 a marriage . Police arrested d murderer Immediately . Who 's It ? Reply With Reason , If U r Brilliant .
# -------------------------
# ==================================================
# Rank 6
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Negative
# Precision: 0.526
# Match: 644 (18.1%)
# Gain = 0.119
# Examples ~ Class Negative:
# [MATCH]: My Parents:['SPACY:POS-NOUN'] , My Kidz:['SPACY:POS-PROPN'] , My Friends n My Colleagues . All screaming .. SURPRISE ! ! and I was waiting on the sofa .. ... ..... ' NAKED ... !
# -------------------------
# [MATCH]: Hi dis is yijue i would be happy to work wif Ã¼:['SPACY:POS-NOUN'] all for gek1510:['SPACY:POS-PROPN'] ...
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: URGENT ! Your Mobile number has been awarded a < UKP>2000 prize:['SPACY:POS-NOUN'] GUARANTEED:['SPACY:POS-PROPN'] . Call 09061790125 from landline . Claim 3030 . Valid 12hrs only 150ppm
# -------------------------
# [MATCH]: You have been selected to stay in 1 of 250 top British hotels - FOR NOTHING:['SPACY:POS-NOUN'] ! Holiday:['SPACY:POS-PROPN'] Worth Â£350 ! To Claim , Call London 02072069400 . Bx 526 , SW73SS
# -------------------------
# ==================================================
# Rank 7
# Pattern: [['TEXT:to'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.856
# Match: 194 (5.4%)
# Gain = 0.114
# Examples ~ Class Positive:
# [MATCH]: SMS AUCTION - A BRAND NEW Nokia 7250 is up 4 auction today ! Auction is FREE 2 join & take part ! Txt NOKIA to:['TEXT:to'] 86021:['SPACY:POS-NUM'] now !
# -------------------------
# [MATCH]: Our records indicate u maybe entitled to:['TEXT:to'] 5000:['SPACY:POS-NUM'] pounds in compensation for the Accident you had . To claim 4 free reply with CLAIM to this msg . 2 stop txt STOP
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Sorry about earlier . Putting out fires . Are you around to:['TEXT:to'] talk after 9:['SPACY:POS-NUM'] ? Or do you actually have a life , lol !
# -------------------------
# [MATCH]: I wanted to ask Ã¼ to:['TEXT:to'] wait 4:['SPACY:POS-NUM'] me to finish lect . Cos my lect finishes in an hour anyway .
# -------------------------
# ==================================================
# Rank 8
# Pattern: [['SPACY:POS-PROPN']]
# Window size: 3
# Class: Negative
# Precision: 0.690
# Match: 1347 (37.8%)
# Gain = 0.112
# Examples ~ Class Negative:
# [MATCH]: Nvm:['SPACY:POS-PROPN'] take ur time .
# -------------------------
# [MATCH]: " Petey boy whereare you me and all your friendsare in theKingshead:['SPACY:POS-PROPN'] come down if you canlove Nic "
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Free 1st week entry 2 TEXTPOD 4 a chance 2 win 40 GB:['SPACY:POS-PROPN'] iPod or Â£250 cash every wk . Txt POD to 84128 Ts&Cs www.textpod.net custcare 08712405020 .
# -------------------------
# [MATCH]: No 1 POLYPHONIC:['SPACY:POS-PROPN'] tone 4 ur mob every week ! Just txt PT2 to 87575 . 1st Tone FREE ! so get txtin now and tell ur friends . 150p / tone . 16 reply HL 4info
# -------------------------
# ==================================================
# Rank 9
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.702
# Match: 272 (7.6%)
# Gain = 0.105
# Examples ~ Class Positive:
# [MATCH]: SMS SERVICES . for your inclusive text credits , pls goto:['SPACY:POS-NOUN'] www.comuk.net:['SPACY:POS-NOUN'] login= 3qxj9:['SPACY:POS-NUM'] unsubscribe with STOP , no extra charge . help 08702840625.COMUK . 220-CM2 9AE
# -------------------------
# [MATCH]: Moby Pub Quiz . Win a Â£100 High Street prize if u know who the new Duchess of Cornwall will be ? Txt her first name to 82277.unsub STOP:['SPACY:POS-NOUN'] Â£1.50:['SPACY:POS-NOUN'] 008704050406:['SPACY:POS-NUM'] SP Arrow
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Not planned yet : ) going to join company:['SPACY:POS-NOUN'] on jan:['SPACY:POS-NOUN'] 5:['SPACY:POS-NUM'] only.don know what will happen after that .
# -------------------------
# [MATCH]: Rose for red , red for blood , blood for heart , heart for u. But u for me .... Send tis to all ur friends .. Including me .. If u like me .. If u get back , 1-u r poor in relation ! 2-u need some 1 to support 3-u r:['SPACY:POS-NOUN'] frnd:['SPACY:POS-NOUN'] 2:['SPACY:POS-NUM'] many 4-some1 luvs u 5 + - some1 is praying god to marry u.:- ) try it ....
# -------------------------
# ==================================================
# Rank 10
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 5
# Class: Positive
# Precision: 0.722
# Match: 255 (7.1%)
# Gain = 0.104
# Examples ~ Class Positive:
# [MATCH]: Hi 07734396839 IBH:['SPACY:POS-PROPN'] Customer:['SPACY:POS-PROPN'] Loyalty:['SPACY:POS-PROPN'] Offer : The NEW NOKIA6600 Mobile from ONLY Â£10 at TXTAUCTION!Txt word : START to No:81151 & get Yours Now!4 T &
# -------------------------
# [MATCH]: Knock:['SPACY:POS-PROPN'] Knock:['SPACY:POS-PROPN'] Txt:['SPACY:POS-PROPN'] whose there to 80082 to enter r weekly draw 4 a Â£250 gift voucher 4 a store of yr choice . T&Cs www.tkls.com age16 to stoptxtstopÂ£1.50/week
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: As per your request ' Melle:['SPACY:POS-PROPN'] Melle:['SPACY:POS-PROPN'] ( Oru:['SPACY:POS-PROPN'] Minnaminunginte Nurungu Vettam ) ' has been set as your callertune for all Callers . Press * 9 to copy your friends Callertune
# -------------------------
# [MATCH]: Madam , regret disturbance.might receive a reference check from DLF Premarica.kindly be informed . Rgds:['SPACY:POS-PROPN'] , Rakhesh:['SPACY:POS-PROPN'] , Kerala:['SPACY:POS-PROPN'] .
# -------------------------
# ==================================================
# Rank 11
# Pattern: [['TEXT:.'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.797
# Match: 202 (5.7%)
# Gain = 0.101
# Examples ~ Class Positive:
# [MATCH]: Congrats ! 1 year special cinema pass for 2 is yours .:['TEXT:.'] call 09061209465:['SPACY:POS-NUM'] now ! C Suprman V , Matrix3 , StarWars3 , etc all 4 FREE ! bx420-ip4 - 5we . 150pm . Do nt miss out !
# -------------------------
# [MATCH]: FREE entry into our Â£250 weekly competition just text the word WIN to 80086 NOW .:['TEXT:.'] 18:['SPACY:POS-NUM'] T&C www.txttowin.co.uk
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: , ,   and   picking them up from various points | going 2 yeovil | and they will do the motor project 4 3 hours | and then u take them home .:['TEXT:.'] ||:['SPACY:POS-NUM'] 12 2 5.30 max . || Very easy
# -------------------------
# [MATCH]: Its a valentine game . . . Send dis msg to all ur friends .:['TEXT:.'] .. If 5:['SPACY:POS-NUM'] answers r d same then someone really loves u. Ques- which colour suits me the best?rply me
# -------------------------
# ==================================================
# Rank 12
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.735
# Match: 238 (6.7%)
# Gain = 0.100
# Examples ~ Class Positive:
# [MATCH]: For ur chance to win a Â£250 cash every wk TXT : ACTION to 80608 . T's&C 's www.movietrivia.tv custcare 08712405022:['SPACY:POS-NUM'] , 1x150p:['SPACY:POS-NUM'] / wk
# -------------------------
# [MATCH]: Shop till u Drop , IS IT YOU , either 10:['SPACY:POS-NUM'] K , 5:['SPACY:POS-NUM'] K , Â£500 Cash or Â£100 Travel voucher , Call now , 09064011000 . NTT PO Box CR01327BT fixedline Cost 150ppm mobile vary
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: twenty:['SPACY:POS-NUM'] past five:['SPACY:POS-NUM'] he said will this train have been to durham already or not coz i am in a reserved seat
# -------------------------
# [MATCH]: Yup , no need . I 'll jus wait 4:['SPACY:POS-NUM'] e rain 2:['SPACY:POS-NUM'] stop .
# -------------------------
# ==================================================
# Rank 13
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
# Window size: 4
# Class: Negative
# Precision: 0.585
# Match: 714 (20.0%)
# Gain = 0.095
# Examples ~ Class Negative:
# [MATCH]: Wa , ur openin sentence very formal ... Anyway , i 'm fine too , juz tt i 'm eatin too much n puttin on weight ... Haha:['SPACY:POS-PROPN'] ... So anythin:['SPACY:POS-NOUN'] special happened ?
# -------------------------
# [MATCH]: K:)k:['SPACY:POS-PROPN'] .. its good:)when:['SPACY:POS-NOUN'] are you going ?
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Tone Club:['SPACY:POS-PROPN'] : Your subs:['SPACY:POS-NOUN'] has now expired 2 re - sub reply MONOC 4 monos or POLYC 4 polys 1 weekly @ 150p per week Txt STOP 2 stop This msg free Stream 0871212025016
# -------------------------
# [MATCH]: TheMob > Check out our newest selection of content , Games , Tones , Gossip:['SPACY:POS-PROPN'] , babes:['SPACY:POS-NOUN'] and sport , Keep your mobile fit and funky text WAP to 82468
# -------------------------
# ==================================================
# Rank 14
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
# Window size: 4
# Class: Positive
# Precision: 0.597
# Match: 313 (8.8%)
# Gain = 0.085
# Examples ~ Class Positive:
# [MATCH]: You are awarded a SiPix Digital Camera ! call 09061221061:['SPACY:POS-NUM'] from:['SPACY:POS-ADP'] landline . Delivery within 28days . T Cs Box177 . M221BP . 2yr warranty . 150ppm . 16 . p pÂ£3.99
# -------------------------
# [MATCH]: SMS . ac JSco : Energy is high , but u may not know where 2channel it . 2day:['SPACY:POS-NUM'] ur:['SPACY:POS-ADP'] leadership skills r strong . Psychic ? Reply ANS w / question . End ? Reply END JSCO
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: 7:['SPACY:POS-NUM'] wonders in:['SPACY:POS-ADP'] My WORLD 7th You 6th Ur style 5th Ur smile 4th Ur Personality 3rd Ur Nature 2nd Ur SMS and 1st " Ur Lovely Friendship " ... good morning dear
# -------------------------
# [MATCH]: Hurt me ... Tease me ... Make me cry ... But in the end of my life when i die plz keep one:['SPACY:POS-NUM'] rose on:['SPACY:POS-ADP'] my grave and say STUPID I MISS U .. HAVE A NICE DAY BSLVYL
# -------------------------
# ==================================================
# Rank 15
# Pattern: [['SPACY:POS-ADJ'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.655
# Match: 258 (7.2%)
# Gain = 0.084
# Examples ~ Class Positive:
# [MATCH]: sports fans - get the latest sports news str * 2 ur mobile:['SPACY:POS-ADJ'] 1:['SPACY:POS-NUM'] wk FREE PLUS a FREE TONE Txt SPORT ON to 8007 www.getzed.co.uk 0870141701216 + norm 4txt/120p
# -------------------------
# [MATCH]: 8007 FREE for 1st week ! No1 Nokia tone 4 ur mob every week just txt NOKIA to 8007 Get txting and tell ur mates www.getzed.co.uk POBox 36504 W4 5WQ norm:['SPACY:POS-ADJ'] 150p:['SPACY:POS-NUM'] / tone 16 +
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Is n't frnd a necesity in life ? imagine urself witout a frnd .. hw'd u feel at ur colleg ? wat'll u do wth ur cell ? wat abt functions ? thnk abt events espe'll cared , missed & amp ; irritated:['SPACY:POS-ADJ'] u ? 4wrd:['SPACY:POS-NUM'] it to all those dear - loving frnds wthout whom u ca nt live .. I jst did it .. Takecare .. : ) GOODMORNING
# -------------------------
# [MATCH]: twenty past:['SPACY:POS-ADJ'] five:['SPACY:POS-NUM'] he said will this train have been to durham already or not coz i am in a reserved seat
# -------------------------
# ==================================================
# Rank 16
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
# Window size: 5
# Class: Positive
# Precision: 0.649
# Match: 259 (7.3%)
# Gain = 0.083
# Examples ~ Class Positive:
# [MATCH]: FreeMsg : Feelin kinda lnly hope u like 2 keep me company ! Jst got a cam moby wanna c my pic?Txt or reply DATE to 82242 Msg150p:['SPACY:POS-PROPN'] 2rcv Hlp:['SPACY:POS-PROPN'] 08712317606 stop:['SPACY:POS-NOUN'] to 82242
# -------------------------
# [MATCH]: Text & meet someone sexy today . U can find a date or even flirt its up to U.:['SPACY:POS-PROPN'] Join:['SPACY:POS-PROPN'] 4 just 10p:['SPACY:POS-NOUN'] . REPLY with NAME & AGE eg Sam 25 . 18 -msg recd@thirtyeight pence
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Today is ACCEPT DAY .. U Accept me as ? Brother Sister Lover Dear1 Best1 Clos1 Lvblefrnd Jstfrnd Cutefrnd Lifpartnr Belovd:['SPACY:POS-PROPN'] Swtheart:['SPACY:POS-PROPN'] Bstfrnd No rply:['SPACY:POS-NOUN'] means enemy
# -------------------------
# [MATCH]: HOW ARE U ? I HAVE MISSED U ! I HAVENT BEEN UP 2 MUCH A BIT BORED WITH THE HOLIDAY WANT 2 GO:['SPACY:POS-PROPN'] BAK:['SPACY:POS-PROPN'] 2 COLLEGE:['SPACY:POS-NOUN'] ! SAD ISNT IT?xx
# -------------------------
# ==================================================
# Rank 17
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.926
# Match: 121 (3.4%)
# Gain = 0.082
# Examples ~ Class Positive:
# [MATCH]: PRIVATE ! Your 2003 Account:['SPACY:POS-PROPN'] Statement for:['SPACY:POS-ADP'] 07973788240:['SPACY:POS-NUM'] shows 800 un - redeemed S. I. M. points . Call 08715203649 Identifier Code : 40533 Expires 31/10/04
# -------------------------
# [MATCH]: I do n't know u and u do n't know me . Send CHAT:['SPACY:POS-PROPN'] to:['SPACY:POS-ADP'] 86688:['SPACY:POS-NUM'] now and let 's find each other ! Only 150p / Msg rcvd . HG / Suite342/2Lands / Row / W1J6HL LDN . 18 years or over .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: " I;m:['SPACY:POS-PROPN'] reaching in:['SPACY:POS-ADP'] another 2:['SPACY:POS-NUM'] stops . "
# -------------------------
# [MATCH]: I am going to film 2day da:['SPACY:POS-PROPN'] . At:['SPACY:POS-ADP'] 6:['SPACY:POS-NUM'] pm . Sorry da .
# -------------------------
# ==================================================
# Rank 18
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]
# Window size: 4
# Class: Positive
# Precision: 0.504
# Match: 421 (11.8%)
# Gain = 0.080
# Examples ~ Class Positive:
# [MATCH]: I want some cock ! My hubby 's away , I need a real man 2 satisfy me . Txt:['SPACY:POS-PROPN'] WIFE to:['SPACY:POS-ADP'] 89938 for no strings action . ( Txt STOP 2 end , txt rec Â£1.50ea . OTBox 731 LA1 7WS . )
# -------------------------
# [MATCH]: SMS SERVICES:['SPACY:POS-PROPN'] . for:['SPACY:POS-ADP'] your inclusive text credits , pls goto www.comuk.net login= 3qxj9 unsubscribe with STOP , no extra charge . help 08702840625.COMUK . 220-CM2 9AE
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Wen:['SPACY:POS-PROPN'] ur:['SPACY:POS-ADP'] lovable bcums angry wid u , dnt take it seriously .. Coz being angry is d most childish n true way of showing deep affection , care n luv ! .. kettoda manda ... Have nice day da .
# -------------------------
# [MATCH]: Japanese Proverb:['SPACY:POS-PROPN'] : If:['SPACY:POS-ADP'] one Can do it , U too Can do it , If none Can do it , U must do it Indian version : If one Can do it , LET HIM DO it .. If none Can do it , LEAVE it ! ! And finally Kerala version : If one can do it , Stop him doing it .. If none can do it , Make a strike against it ...
# -------------------------
# ==================================================
# Rank 19
# Pattern: [['SPACY:POS-NUM'], ['TEXT:.']]
# Window size: 4
# Class: Positive
# Precision: 0.591
# Match: 286 (8.0%)
# Gain = 0.074
# Examples ~ Class Positive:
# [MATCH]: Urgent ! Please call 09061743811:['SPACY:POS-NUM'] from landline .:['TEXT:.'] Your ABTA complimentary 4 * Tenerife Holiday or Â£5000 cash await collection SAE T&Cs Box 326 CW25WX 150ppm
# -------------------------
# [MATCH]: 1st wk FREE ! Gr8 tones str8 2 u each wk . Txt NOKIA ON to 8007 for Classic Nokia tones or HIT ON to 8007:['SPACY:POS-NUM'] for Polys .:['TEXT:.'] Nokia/150p Poly/200p 16 +
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Ok but tell me half an hr b4 u come i need 2:['SPACY:POS-NUM'] prepare .:['TEXT:.']
# -------------------------
# [MATCH]: Camera quite good , 10.1mega pixels , 3optical and 5digital:['SPACY:POS-NUM'] dooms .:['TEXT:.'] Have a lovely holiday , be safe and i hope you hav a good journey ! Happy new year to you both ! See you in a couple of weeks !
# -------------------------
# ==================================================
# Rank 20
# Pattern: [['SPACY:POS-NOUN'], ['TEXT:call']]
# Window size: 4
# Class: Positive
# Precision: 0.791
# Match: 153 (4.3%)
# Gain = 0.073
# Examples ~ Class Positive:
# [MATCH]: Congratulations U can claim 2 VIP row A Tickets 2 C Blu in concert in November or Blu gift:['SPACY:POS-NOUN'] guaranteed Call:['TEXT:call'] 09061104276 to claim TS&Cs www.smsco.net costÂ£3.75max
# -------------------------
# [MATCH]: URGENT ! Your Mobile number has been awarded with a Â£2000 prize:['SPACY:POS-NOUN'] GUARANTEED . Call:['TEXT:call'] 09061790121 from land line . Claim 3030 . Valid 12hrs only 150ppm
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Sorry ,   in meeting:['SPACY:POS-NOUN'] I 'll call:['TEXT:call'] you later
# -------------------------
# [MATCH]: Miss call:['SPACY:POS-NOUN'] miss call:['TEXT:call'] khelate kintu opponenter miss call dhorte lage . That s d rule . One with great phone receiving quality wins .
# -------------------------
# ==================================================
# Rank 21
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.843
# Match: 127 (3.6%)
# Gain = 0.069
# Examples ~ Class Positive:
# [MATCH]: sexy sexy cum and text me i m wet and warm and ready for some porn ! u up for some fun ? THIS MSG IS FREE RECD MSGS:['SPACY:POS-PROPN'] 150P INC VAT:['SPACY:POS-NOUN'] 2:['SPACY:POS-NUM'] CANCEL TEXT STOP
# -------------------------
# [MATCH]: PRIVATE ! Your 2003 Account Statement for 07808 XXXXXX shows 800 un - redeemed S. I. M.:['SPACY:POS-PROPN'] points:['SPACY:POS-NOUN'] . Call 08719899217:['SPACY:POS-NUM'] Identifier Code : 41685 Expires 07/11/04
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Once a fishrman woke early in d mrng . It was very dark . He waited a while & amp ; found a sack ful of stones . He strtd throwin thm in2 d sea 2 pass time . Atlast:['SPACY:POS-PROPN'] he had jus:['SPACY:POS-NOUN'] 1stone:['SPACY:POS-NUM'] , sun rose up & amp ; he found out tht those r nt stones , those were diamonds . Moral:"Dont wake up early in d mrng '' GOOD night
# -------------------------
# [MATCH]: OH YEAH , AND HAV A GREAT TIME IN NEWQUAY - SEND ME:['SPACY:POS-PROPN'] A POSTCARD:['SPACY:POS-NOUN'] ! 1:['SPACY:POS-NUM'] LOOK AFTER ALL THE GIRLS WHILE IM GONE(U KNOW THE 1IM TALKIN BOUT!)xx
# -------------------------
# ==================================================
# Rank 22
# Pattern: [['TEXT:i']]
# Window size: 3
# Class: Negative
# Precision: 0.983
# Match: 1327 (37.2%)
# Gain = 0.067
# Examples ~ Class Negative:
# [MATCH]: I:['TEXT:i'] 'm so in love with you . I 'm excited each day i spend with you . You make me so happy .
# -------------------------
# [MATCH]: I:['TEXT:i'] 'm always looking for an excuse to be in the city .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: I:['TEXT:i'] 'd like to tell you my deepest darkest fantasies . Call me 09094646631 just 60p / min . To stop texts call 08712460324 ( nat rate )
# -------------------------
# [MATCH]: sexy sexy cum and text me i:['TEXT:i'] m wet and warm and ready for some porn ! u up for some fun ? THIS MSG IS FREE RECD MSGS 150P INC VAT 2 CANCEL TEXT STOP
# -------------------------
# ==================================================
# Rank 23
# Pattern: [['SPACY:POS-SYM']]
# Window size: 3
# Class: Positive
# Precision: 0.756
# Match: 156 (4.4%)
# Gain = 0.067
# Examples ~ Class Positive:
# [MATCH]: I do n't know u and u do n't know me . Send CHAT to 86688 now and let 's find each other ! Only 150p /:['SPACY:POS-SYM'] Msg rcvd . HG / Suite342/2Lands / Row / W1J6HL LDN . 18 years or over .
# -------------------------
# [MATCH]: No . 1 Nokia Tone 4 ur mob every week ! Just txt NOK to 87021 . 1st Tone FREE ! so get txtin now and tell ur friends . 150p /:['SPACY:POS-SYM'] tone . 16 reply HL 4info
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: What i mean was i left too early to check , cos i 'm working a 9 -:['SPACY:POS-SYM'] 6 .
# -------------------------
# [MATCH]: Rose for red , red for blood , blood for heart , heart for u. But u for me .... Send tis to all ur friends .. Including me .. If u like me .. If u get back , 1-u r poor in relation ! 2-u need some 1 to support 3-u r frnd 2 many 4-some1 luvs u:['SPACY:POS-SYM'] 5 + - some1 is praying god to marry u.:- ) try it ....
# -------------------------
# ==================================================
# Rank 24
# Pattern: [['TEXT:free']]
# Window size: 3
# Class: Positive
# Precision: 0.748
# Match: 159 (4.5%)
# Gain = 0.067
# Examples ~ Class Positive:
# [MATCH]: Welcome to UK - mobile - date this msg is FREE:['TEXT:free'] giving you free calling to 08719839835 . Future mgs billed at 150p daily . To cancel send " go stop " to 89123
# -------------------------
# [MATCH]: You 'll not rcv any more msgs from the chat svc . For FREE:['TEXT:free'] Hardcore services text GO to : 69988 If u get nothing u must Age Verify with yr network & try again
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: It does nt make sense to take it there unless its free:['TEXT:free'] . If you need to know more , wikipedia.com
# -------------------------
# [MATCH]: I am waiting machan . Call me once you free:['TEXT:free'] .
# -------------------------
# ==================================================
# Rank 25
# Pattern: [['TEXT:txt']]
# Window size: 3
# Class: Positive
# Precision: 0.938
# Match: 96 (2.7%)
# Gain = 0.067
# Examples ~ Class Positive:
# [MATCH]: Knock Knock Txt:['TEXT:txt'] whose there to 80082 to enter r weekly draw 4 a Â£250 gift voucher 4 a store of yr choice . T&Cs www.tkls.com age16 to stoptxtstopÂ£1.50/week
# -------------------------
# [MATCH]: Sunshine Quiz Wkly Q ! Win a top Sony DVD player if u know which country the Algarve is in ? Txt:['TEXT:txt'] ansr to 82277 . Â£1.50 SP : Tyrone
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I love u 2 babe ! R u sure everything is alrite . Is he being an idiot ? Txt:['TEXT:txt'] bak girlie
# -------------------------
# [MATCH]: Sounds better than my evening i m just doing my costume . I m not sure what time i finish tomorrow but i will txt:['TEXT:txt'] you at the end .
# -------------------------
# ==================================================
# Rank 26
# Pattern: [['SPACY:POS-NOUN'], ['TEXT:to']]
# Window size: 4
# Class: Negative
# Precision: 0.591
# Match: 552 (15.5%)
# Gain = 0.065
# Examples ~ Class Negative:
# [MATCH]: I 'm always looking for an excuse:['SPACY:POS-NOUN'] to:['TEXT:to'] be in the city .
# -------------------------
# [MATCH]: Good sleep is about rhythm . The person:['SPACY:POS-NOUN'] has to:['TEXT:to'] establish a rhythm that the body will learn and use . If you want to know more :-)
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: wamma get laid?want real doggin locations:['SPACY:POS-NOUN'] sent direct to:['TEXT:to'] your mobile ? join the UKs largest dogging network . txt dogs to 69696 now!nyt . ec2a . 3lp Â£1.50/msg .
# -------------------------
# [MATCH]: This message:['SPACY:POS-NOUN'] is brought to:['TEXT:to'] you by GMW Ltd. and is not connected to the
# -------------------------
# ==================================================
# Rank 27
# Pattern: [['TEXT:claim']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 77 (2.2%)
# Gain = 0.064
# Examples ~ Class Positive:
# [MATCH]: Congratulations ! Thanks to a good friend U have WON the Â£2,000 Xmas prize . 2 claim:['TEXT:claim'] is easy , just call 08718726971 NOW ! Only 10p per minute . BT - national - rate .
# -------------------------
# [MATCH]: YOU ARE CHOSEN TO RECEIVE A Â£350 AWARD ! Pls call claim:['TEXT:claim'] number 09066364311 to collect your award which you are selected to receive as a valued mobile customer .
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Rank 28
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-ADP', 'TEXT:to']]
# Window size: 4
# Class: Positive
# Precision: 0.592
# Match: 250 (7.0%)
# Gain = 0.064
# Examples ~ Class Positive:
# [MATCH]: Great News ! Call FREEFONE 08006344447 to claim your guaranteed Â£1000 CASH or Â£2000 gift:['SPACY:POS-NOUN'] . Speak to:['TEXT:to', 'SPACY:POS-ADP'] a live operator NOW !
# -------------------------
# [MATCH]: For ur chance to win a Â£250 cash every wk TXT : ACTION:['SPACY:POS-NOUN'] to:['TEXT:to', 'SPACY:POS-ADP'] 80608 . T's&C 's www.movietrivia.tv custcare 08712405022 , 1x150p / wk .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Say this slowly . ? GOD , I LOVE YOU & amp ; I NEED YOU , CLEAN MY HEART WITH YOUR BLOOD.Send:['SPACY:POS-NOUN'] this to:['TEXT:to', 'SPACY:POS-ADP'] Ten special people & amp ; u c miracle tomorrow , do it , pls , pls do it ...
# -------------------------
# [MATCH]: Ha ha nan yalrigu heltini .. Iyo kothi chikku , u shared many things wit me .. so far i did n't told any body and even uttered a word abt u .. If ur trusting me so much how can i tell these to others .. Plz nxt time do nt use those words:['SPACY:POS-NOUN'] to:['TEXT:to', 'SPACY:POS-ADP'] me .. ok , chikku:-);-)B- )
# -------------------------
# ==================================================
# Rank 29
# Pattern: [['TEXT:!']]
# Window size: 3
# Class: Negative
# Precision: 0.602
# Match: 575 (16.1%)
# Gain = 0.063
# Examples ~ Class Negative:
# [MATCH]: Indeed and by the way it was either or - not both !:['TEXT:!']
# -------------------------
# [MATCH]: Kinda . First one gets in at twelve !:['TEXT:!'] Aah . Speak tomo
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: I do n't know u and u do n't know me . Send CHAT to 86688 now and let 's find each other !:['TEXT:!'] Only 150p / Msg rcvd . HG / Suite342/2Lands / Row / W1J6HL LDN . 18 years or over .
# -------------------------
# [MATCH]: I want some cock !:['TEXT:!'] My hubby 's away , I need a real man 2 satisfy me . Txt WIFE to 89938 for no strings action . ( Txt STOP 2 end , txt rec Â£1.50ea . OTBox 731 LA1 7WS . )
# -------------------------
# ==================================================
# Rank 30
# Pattern: [['TEXT:.'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.539
# Match: 297 (8.3%)
# Gain = 0.062
# Examples ~ Class Positive:
# [MATCH]: You are awarded a SiPix Digital Camera ! call 09061221061 from landline . Delivery within 28days .:['TEXT:.'] T:['SPACY:POS-PROPN'] Cs Box177 . M221BP . 2yr warranty . 150ppm . 16 . p pÂ£3.99
# -------------------------
# [MATCH]: U have a secret admirer .:['TEXT:.'] REVEAL:['SPACY:POS-PROPN'] who thinks U R So special . Call 09065174042 . To opt out Reply REVEAL STOP . 1.50 per msg recd . Cust care 07821230901
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: God 's love has no limit .:['TEXT:.'] God:['SPACY:POS-PROPN'] 's grace has no measure . God 's power has no boundaries . May u have God 's endless blessings always in ur life ... ! ! Gud ni8
# -------------------------
# [MATCH]: My trip was ok but quite tiring lor .:['TEXT:.'] Uni:['SPACY:POS-PROPN'] starts today but it 's ok 4 me cos i 'm not taking any modules but jus concentrating on my final yr project .
# -------------------------
# ==================================================
# Rank 31
# Pattern: [['SPACY:POS-PROPN'], ['TEXT:.']]
# Window size: 4
# Class: Positive
# Precision: 0.522
# Match: 312 (8.7%)
# Gain = 0.061
# Examples ~ Class Positive:
# [MATCH]: * * FREE MESSAGE**Thanks for using the Auction:['SPACY:POS-PROPN'] Subscription Service .:['TEXT:.'] 18 . 150p / MSGRCVD 2 Skip an Auction txt OUT . 2 Unsubscribe txt STOP CustomerCare 08718726270
# -------------------------
# [MATCH]: URGENT ! We are trying to contact U Todays draw shows that you have won a Â£800:['SPACY:POS-PROPN'] prize GUARANTEED .:['TEXT:.'] Call 09050000460 from land line . Claim J89 . po box245c2150pm
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Cuz:['SPACY:POS-PROPN'] ibored .:['TEXT:.'] And don wanna study
# -------------------------
# [MATCH]: 1Apple / Day = No Doctor:['SPACY:POS-PROPN'] .:['TEXT:.'] 1Tulsi Leaf / Day = No Cancer . 1Lemon / Day = No Fat . 1Cup Milk / day = No Bone Problms 3 Litres Watr / Day = No Diseases Snd ths 2 Whom U Care .. :- )
# -------------------------
# ==================================================
# Rank 32
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 5
# Class: Positive
# Precision: 0.624
# Match: 213 (6.0%)
# Gain = 0.061
# Examples ~ Class Positive:
# [MATCH]: URGENT ! We are trying to contact U. Todays draw shows that you have won a Â£2000 prize GUARANTEED . Call 09066358361 from land:['SPACY:POS-NOUN'] line . Claim:['SPACY:POS-PROPN'] Y87:['SPACY:POS-PROPN'] . Valid 12hrs only
# -------------------------
# [MATCH]: Last Chance ! Claim ur Â£150 worth of discount vouchers today ! Text SHOP to 85023 now ! SavaMob , offers mobile:['SPACY:POS-NOUN'] ! T:['SPACY:POS-PROPN'] Cs:['SPACY:POS-PROPN'] SavaMob POBOX84 , M263UZ . Â£3.00 Sub . 16
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: 7 wonders in My WORLD 7th You 6th Ur style 5th Ur smile:['SPACY:POS-NOUN'] 4th Ur:['SPACY:POS-PROPN'] Personality:['SPACY:POS-PROPN'] 3rd Ur Nature 2nd Ur SMS and 1st " Ur Lovely Friendship " ... good morning dear
# -------------------------
# [MATCH]: The battery is for mr adewale my uncle:['SPACY:POS-NOUN'] . Aka:['SPACY:POS-PROPN'] Egbon:['SPACY:POS-PROPN']
# -------------------------
# ==================================================
# Rank 33
# Pattern: [['TEXT:mobile']]
# Window size: 3
# Class: Positive
# Precision: 0.942
# Match: 86 (2.4%)
# Gain = 0.060
# Examples ~ Class Positive:
# [MATCH]: Thanks for the Vote . Now sing along with the stars with Karaoke on your mobile:['TEXT:mobile'] . For a FREE link just reply with SING now .
# -------------------------
# [MATCH]: URGENT ! Your Mobile:['TEXT:mobile'] No 07808726822 was awarded a Â£2,000 Bonus Caller Prize on 02/09/03 ! This is our 2nd attempt to contact YOU ! Call 0871 - 872 - 9758 BOX95QU
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Am only searching for good dual sim mobile:['TEXT:mobile'] pa .
# -------------------------
# [MATCH]: Plz note : if anyone calling from a mobile:['TEXT:mobile'] Co. & amp ; asks u to type # & lt;#&gt ;   or # & lt;#&gt ; . Do not do so . Disconnect the call , coz it iz an attempt of ' terrorist ' to make use of the sim card no . Itz confirmd by nokia n motorola n has been verified by CNN IBN .
# -------------------------
# ==================================================
# Rank 34
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
# Window size: 5
# Class: Positive
# Precision: 0.591
# Match: 235 (6.6%)
# Gain = 0.060
# Examples ~ Class Positive:
# [MATCH]: Had your mobile 11mths ? Update for FREE to Oranges latest colour camera mobiles & unlimited weekend:['SPACY:POS-NOUN'] calls:['SPACY:POS-NOUN'] . Call Mobile:['SPACY:POS-PROPN'] Upd8 on freefone 08000839402 or 2StopTx
# -------------------------
# [MATCH]: This message is free . Welcome to the new & improved Sex & Dogging club ! To unsubscribe from this service:['SPACY:POS-NOUN'] reply:['SPACY:POS-NOUN'] STOP:['SPACY:POS-PROPN'] . msgs@150p 18 only
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Goin to workout:['SPACY:POS-NOUN'] lor:['SPACY:POS-NOUN'] ... Muz:['SPACY:POS-PROPN'] lose e fats ...
# -------------------------
# [MATCH]: , ,   and   picking them up from various points | going 2 yeovil | and they will do the motor project:['SPACY:POS-NOUN'] 4 3 hours:['SPACY:POS-NOUN'] |:['SPACY:POS-PROPN'] and then u take them home . || 12 2 5.30 max . || Very easy
# -------------------------
# ==================================================
# Rank 35
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]
# Window size: 5
# Class: Positive
# Precision: 0.739
# Match: 142 (4.0%)
# Gain = 0.058
# Examples ~ Class Positive:
# [MATCH]: PRIVATE ! Your 2003 Account:['SPACY:POS-PROPN'] Statement:['SPACY:POS-PROPN'] for:['SPACY:POS-ADP'] 07815296484 shows 800 un - redeemed S.I.M. points . Call 08718738001 Identifier Code 41782 Expires 18/11/04
# -------------------------
# [MATCH]: U have a secret admirer . REVEAL who thinks U R So special . Call 09065174042 . To opt out Reply REVEAL:['SPACY:POS-PROPN'] STOP:['SPACY:POS-PROPN'] . 1.50 per:['SPACY:POS-ADP'] msg recd . Cust care 07821230901
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: & lt;#&gt ;   is fast approaching . So , Wish u a very Happy New Year Happy Sankranti Happy republic day Happy Valentines Day Happy Shivratri Happy Ugadi Happy Fools day Happy May Day Happy Independence Day , Happy Friendship , Mother , Father , Teachers , Childrens Day , & amp ; HAPPY BIRTHDAY 4 U. Happy Ganesh festival Happy Dasara Happy Diwali Happy Christmas   & lt;#&gt ;   Good Mornings Afternoons , Evenings Nights . RememberI:['SPACY:POS-PROPN'] AM:['SPACY:POS-PROPN'] the first to:['SPACY:POS-ADP'] WISHING U ALL THESE ... your 's Raj
# -------------------------
# [MATCH]: THING R GOOD THANX GOT:['SPACY:POS-PROPN'] EXAMS:['SPACY:POS-PROPN'] IN:['SPACY:POS-ADP'] MARCH IVE DONE NO REVISION ? IS FRAN STILL WITH BOYF ? IVE GOTTA INTERVIW 4 EXETER BIT WORRIED!x
# -------------------------
# ==================================================
# Rank 36
# Pattern: [['SPACY:POS-ADJ'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Negative
# Precision: 0.530
# Match: 368 (10.3%)
# Gain = 0.057
# Examples ~ Class Negative:
# [MATCH]: How 's my loverboy doing ? What does he do that keeps him from coming to his:['SPACY:POS-ADJ'] Queen:['SPACY:POS-PROPN'] , hmmm ? Does n't he ache to speak to me ? Miss me desparately ?
# -------------------------
# [MATCH]: Same:['SPACY:POS-ADJ'] . Wana:['SPACY:POS-PROPN'] plan a trip sometme then
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Dear Matthew please call 09063440451 from a landline , your:['SPACY:POS-ADJ'] complimentary 4*Lux Tenerife:['SPACY:POS-PROPN'] holiday or Â£1000 CASH await collection . ppm150 SAE T&Cs Box334 SK38XH .
# -------------------------
# [MATCH]: -PLS STOP bootydelious ( 32/F ) is inviting you to be her:['SPACY:POS-ADJ'] friend . Reply:['SPACY:POS-PROPN'] YES-434 or NO-434 See her : www . SMS.ac / u / bootydelious STOP ? Send STOP FRND to 62468
# -------------------------
# ==================================================
# Rank 37
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-ADJ']]
# Window size: 4
# Class: Positive
# Precision: 0.559
# Match: 245 (6.9%)
# Gain = 0.055
# Examples ~ Class Positive:
# [MATCH]: XCLUSIVE@CLUBSAISAI 2MOROW 28/5:['SPACY:POS-NUM'] SOIREE SPECIALE ZOUK:['SPACY:POS-ADJ'] WITH NICHOLS FROM PARIS.FREE ROSES 2 ALL LADIES ! ! ! info : 07946746291/07880867867
# -------------------------
# [MATCH]: complimentary 4 STAR Ibiza Holiday or Â£10,000:['SPACY:POS-NUM'] cash needs your:['SPACY:POS-ADJ'] URGENT collection . 09066364349 NOW from Landline not to lose out ! Box434SK38WP150PPM18 +
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Single line with a big meaning : : : : : " Miss anything 4:['SPACY:POS-NUM'] ur " Best:['SPACY:POS-ADJ'] Life " but , do n't miss ur best life for anything ... Gud nyt ...
# -------------------------
# [MATCH]: Sorry sent blank msg again . Yup but trying 2:['SPACY:POS-NUM'] do some serious:['SPACY:POS-ADJ'] studying now .
# -------------------------
# ==================================================
# Rank 38
# Pattern: [['SENTIMENT:pos'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.542
# Match: 260 (7.3%)
# Gain = 0.054
# Examples ~ Class Positive:
# [MATCH]: sexy sexy cum and text me i m wet and warm and ready for some porn ! u up for some fun:['SENTIMENT:pos'] ? THIS MSG:['SPACY:POS-PROPN'] IS FREE RECD MSGS 150P INC VAT 2 CANCEL TEXT STOP
# -------------------------
# [MATCH]: ( Bank of Granite issues Strong:['SENTIMENT:pos'] - Buy:['SPACY:POS-PROPN'] ) EXPLOSIVE PICK FOR OUR MEMBERS * * * * * UP OVER 300 % * * * * * * * * * * * Nasdaq Symbol CDGT That is a $ 5.00 per ..
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: " YEH I AM DEF UP4 SOMETHING SAT , JUST GOT PAYED2DAY & I HAVBEEN GIVEN AÂ£50 PAY RISE 4MY WORK:['SENTIMENT:pos'] & HAVEBEEN:['SPACY:POS-PROPN'] MADE PRESCHOOLCO - ORDINATOR 2I AM FEELINGOOD LUV "
# -------------------------
# [MATCH]: Tunde , how are you doing . This is just wishing you a great:['SENTIMENT:pos'] day . Abiola:['SPACY:POS-PROPN'] .
# -------------------------
# ==================================================
# Rank 39
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.802
# Match: 111 (3.1%)
# Gain = 0.053
# Examples ~ Class Positive:
# [MATCH]: SMS AUCTION You have won a Nokia 7250i . This is what you get when you win our FREE auction . To take part:['SPACY:POS-NOUN'] send Nokia:['SPACY:POS-PROPN'] to 86021:['SPACY:POS-NUM'] now . HG / Suite342/2Lands Row / W1JHL 16 +
# -------------------------
# [MATCH]: LORD OF THE RINGS : RETURN OF THE KING in store:['SPACY:POS-NOUN'] NOW!REPLY:['SPACY:POS-PROPN'] LOTR by 2:['SPACY:POS-NUM'] June 4 Chance 2 WIN LOTR soundtrack CDs StdTxtRate . Reply STOP to end txts
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Ee msg na poortiyagi:['SPACY:POS-NOUN'] odalebeku : Hanumanji:['SPACY:POS-PROPN'] 7:['SPACY:POS-NUM'] name 1-Hanuman 2-Bajarangabali 3-Maruti 4-Pavanaputra 5-Sankatmochan 6-Ramaduth 7-Mahaveer ee 7 name   & lt;#&gt ;   janarige ivatte kalisidare next saturday olage ondu good news keluviri ... ! Maretare inde 1 dodda problum nalli siguviri idu matra   & lt;#&gt ; % true .. Do n't neglet .
# -------------------------
# [MATCH]: Indians r poor but India is not a poor country . Says one of the swiss bank directors . He says that " & lt;#&gt ;   lac crore " of Indian money is deposited in swiss banks which can be used for ' taxless ' budget for   & lt;#&gt ;   yrs . Can give   & lt;#&gt ;   crore jobs to all Indians . From any village:['SPACY:POS-NOUN'] to Delhi:['SPACY:POS-PROPN'] 4:['SPACY:POS-NUM'] lane roads . Forever free power suply to more than   & lt;#&gt ;   social projects . Every citizen can get monthly   & lt;#&gt ; /- for   & lt;#&gt ;   yrs . No need of World Bank & amp ; IMF loan . Think how our money is blocked by rich politicians . We have full rights against corrupt politicians . Itna forward karo ki pura INDIA padhe.g.m . "
# -------------------------
# ==================================================
# Rank 40
# Pattern: [['TEXT:.'], ['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.985
# Match: 67 (1.9%)
# Gain = 0.053
# Examples ~ Class Positive:
# [MATCH]: Your 2004 account for 07XXXXXXXXX shows 786 unredeemed points .:['TEXT:.'] To claim call:['TEXT:call'] 08719181259:['SPACY:POS-NUM'] Identifier code : XXXXX Expires 26.03.05
# -------------------------
# [MATCH]: PRIVATE ! Your 2003 Account Statement for shows 800 un - redeemed S.I.M. points .:['TEXT:.'] Call:['TEXT:call'] 08718738001:['SPACY:POS-NUM'] Identifier Code : 49557 Expires 26/11/04
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I 'm in a movie .:['TEXT:.'] Call:['TEXT:call'] me 4:['SPACY:POS-NUM'] wat ?
# -------------------------
# ==================================================
# Rank 41
# Pattern: [['HYPERNYM3:communication.n.02'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.923
# Match: 78 (2.2%)
# Gain = 0.052
# Examples ~ Class Positive:
# [MATCH]: Thank you , winner notified by sms . Good Luck ! No future marketing reply:['HYPERNYM3:communication.n.02'] STOP to 84122:['SPACY:POS-NUM'] customer services 08450542832
# -------------------------
# [MATCH]: No 1 POLYPHONIC tone 4 ur mob every week ! Just txt PT2 to 87575 . 1st Tone FREE ! so get txtin now and tell ur friends . 150p / tone . 16 reply:['HYPERNYM3:communication.n.02'] HL 4info:['SPACY:POS-NUM']
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Huh but i got lesson:['HYPERNYM3:communication.n.02'] at 4:['SPACY:POS-NUM'] lei n i was thinkin of going to sch earlier n i tot of parkin at kent vale ...
# -------------------------
# [MATCH]: Yup ... Ok i go home look at the timings then i msg Ã¼ again ... Xuhui going to learn on 2nd may too but her lesson:['HYPERNYM3:communication.n.02'] is at 8:['SPACY:POS-NUM'] am
# -------------------------
# ==================================================
# Rank 42
# Pattern: [['HYPERNYM3:win.v.01', 'SENTIMENT:pos']]
# Window size: 3
# Class: Positive
# Precision: 0.922
# Match: 77 (2.2%)
# Gain = 0.051
# Examples ~ Class Positive:
# [MATCH]: + 123 Congratulations - in this week 's competition draw u have won:['HYPERNYM3:win.v.01', 'SENTIMENT:pos'] the Â£1450 prize to claim just call 09050002311 b4280703 . T&Cs / stop SMS 08718727868 . Over 18 only 150ppm
# -------------------------
# [MATCH]: URGENT ! We are trying to contact U. Todays draw shows that you have won:['HYPERNYM3:win.v.01', 'SENTIMENT:pos'] a Â£2000 prize GUARANTEED . Call 09066358361 from land line . Claim Y87 . Valid 12hrs only
# -------------------------
# Counterexamples ~ Not class Positive:
# ...
# -------------------------
# [MATCH]: This is the 2nd time we have tried to contact u. U have won the Â£400:['SPACY:POS-PROPN'] prize:['SPACY:POS-NOUN'] .:['TEXT:.'] 2 claim is easy , just call 087104711148 NOW ! Only 10p per minute . BT - national - rate
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: HI DARLIN IM MISSIN U HOPE YOU ARE HAVING A GOOD TIME . WHEN ARE U BACK AND WHAT TIME IF U CAN GIVE ME A CALL AT:['SPACY:POS-PROPN'] HOME:['SPACY:POS-NOUN'] .:['TEXT:.'] JESS XX
# -------------------------
# [MATCH]: Please protect yourself from e - threats . SIB never asks for sensitive information like Passwords , ATM / SMS:['SPACY:POS-PROPN'] PIN:['SPACY:POS-NOUN'] thru email .:['TEXT:.'] Never share your password with anybody .
# -------------------------
# ==================================================
# Rank 86
# Pattern: [['SENTIMENT:pos'], ['TEXT:call']]
# Window size: 4
# Class: Positive
# Precision: 0.838
# Match: 74 (2.1%)
# Gain = 0.039
# Examples ~ Class Positive:
# [MATCH]: YOU ARE CHOSEN TO RECEIVE A Â£350 AWARD:['SENTIMENT:pos'] ! Pls call:['TEXT:call'] claim number 09066364311 to collect your award which you are selected to receive as a valued mobile customer .
# -------------------------
# [MATCH]: URGENT ! We are trying to contact you . Last weekends draw shows that you have won a Â£900 prize:['SENTIMENT:pos'] GUARANTEED . Call:['TEXT:call'] 09061701851 . Claim code K61 . Valid 12hours only
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I 'm at work:['SENTIMENT:pos'] . Please call:['TEXT:call']
# -------------------------
# [MATCH]: Once free:['SENTIMENT:pos'] call:['TEXT:call'] me sir .
# -------------------------
# ==================================================
# Rank 87
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.868
# Match: 68 (1.9%)
# Gain = 0.038
# Examples ~ Class Positive:
# [MATCH]: YOUR CHANCE TO BE ON A REALITY FANTASY SHOW call now = 08707509020 Just 20p per min NTT Ltd , PO Box 1327:['SPACY:POS-NUM'] Croydon:['SPACY:POS-PROPN'] CR9 5WB:['SPACY:POS-NUM'] 0870 is a national = rate call
# -------------------------
# [MATCH]: PRIVATE ! Your 2003 Account Statement for shows 800 un - redeemed S. I. M. points . Call 08715203694:['SPACY:POS-NUM'] Identifier:['SPACY:POS-PROPN'] Code : 40533:['SPACY:POS-NUM'] Expires 31/10/04
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Hi here . have birth at on the   to   at 8:['SPACY:POS-NUM'] lb:['SPACY:POS-PROPN'] 7:['SPACY:POS-NUM'] oz . Mother and baby doing brilliantly .
# -------------------------
# [MATCH]: ZOE IT JUST HIT ME 2 IM FUCKING SHITIN MYSELF IL DEFO TRY MY HARDEST 2:['SPACY:POS-NUM'] CUM:['SPACY:POS-PROPN'] 2MOROW:['SPACY:POS-NUM'] LUV U MILLIONS LEKDOG
# -------------------------
# ==================================================
# Rank 88
# Pattern: [['HYPERNYM3:symbol.n.01']]
# Window size: 3
# Class: Positive
# Precision: 0.764
# Match: 89 (2.5%)
# Gain = 0.038
# Examples ~ Class Positive:
# [MATCH]: URGENT ! Your Mobile number has been awarded a < UKP>2000 prize:['HYPERNYM3:symbol.n.01'] GUARANTEED . Call 09061790125 from landline . Claim 3030 . Valid 12hrs only 150ppm
# -------------------------
# [MATCH]: WINNER ! ! As a valued network customer you have been selected to receivea Â£900 prize:['HYPERNYM3:symbol.n.01'] reward ! To claim call 09061701461 . Claim code KL341 . Valid 12 hours only .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Can you do a mag meeting this avo at some point:['HYPERNYM3:symbol.n.01'] ?
# -------------------------
# [MATCH]: Oh ho . Is this the first time u use these type:['HYPERNYM3:symbol.n.01'] of words
# -------------------------
# ==================================================
# Rank 89
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
# Window size: 5
# Class: Positive
# Precision: 0.543
# Match: 184 (5.2%)
# Gain = 0.037
# Examples ~ Class Positive:
# [MATCH]: Hi if:['SPACY:POS-ADP'] ur lookin 4:['SPACY:POS-NUM'] saucy:['SPACY:POS-NOUN'] daytime fun wiv busty married woman Am free all next week Chat now 2 sort time 09099726429 JANINExx CallsÂ£1/minMobsmoreLKPOBOX177HP51FL
# -------------------------
# [MATCH]: FREE RINGTONE text FIRST to:['SPACY:POS-ADP'] 87131:['SPACY:POS-NUM'] for a poly:['SPACY:POS-NOUN'] or text GET to 87131 for a true tone ! Help ? 0845 2814032 16 after 1st free , tones are 3xÂ£150pw to eÂ£nd txt stop
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: S:-)kallis wo nt play in:['SPACY:POS-ADP'] first two:['SPACY:POS-NUM'] odi:-:['SPACY:POS-NOUN'] )
# -------------------------
# [MATCH]: Hey there ! Glad u r better now . I hear u treated urself to a digi cam , is it good ? We r off at:['SPACY:POS-ADP'] 9:['SPACY:POS-NUM'] pm:['SPACY:POS-NOUN'] . Have a fab new year , c u in coupla wks !
# -------------------------
# ==================================================
# Rank 90
# Pattern: [['TEXT:!'], ['SPACY:POS-ADJ']]
# Window size: 4
# Class: Positive
# Precision: 0.648
# Match: 125 (3.5%)
# Gain = 0.037
# Examples ~ Class Positive:
# [MATCH]: Free - message : Jamster!Get the crazy frog sound now !:['TEXT:!'] For poly:['SPACY:POS-ADJ'] text MAD1 , for real text MAD2 to 88888 . 6 crazy sounds for just 3 GBP / week ! 16+only ! T&C 's apply
# -------------------------
# [MATCH]: Great NEW Offer - DOUBLE Mins & DOUBLE Txt on best Orange tariffs AND get latest camera phones 4 FREE !:['TEXT:!'] Call MobileUpd8 free:['SPACY:POS-ADJ'] on 08000839402 NOW ! or 2stoptxt T&Cs
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Wen ur lovable bcums angry wid u , dnt take it seriously .. Coz being angry is d most childish n true way of showing deep affection , care n luv !:['TEXT:!'] .. kettoda:['SPACY:POS-ADJ'] manda ... Have nice day da .
# -------------------------
# [MATCH]: HEY GIRL . HOW R U ? HOPE U R WELL ME AN DEL R BAK !:['TEXT:!'] AGAIN LONG:['SPACY:POS-ADJ'] TIME NO C ! GIVE ME A CALL SUM TIME FROM LUCYxx
# -------------------------
# ==================================================
# Rank 91
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
# Window size: 6
# Class: Positive
# Precision: 0.914
# Match: 58 (1.6%)
# Gain = 0.037
# Examples ~ Class Positive:
# [MATCH]: U have a Secret:['SPACY:POS-PROPN'] Admirer:['SPACY:POS-PROPN'] who:['SPACY:POS-NOUN'] is looking 2:['SPACY:POS-NUM'] make contact with U - find out who they R*reveal who thinks UR so special - call on 09065171142-stopsms-08
# -------------------------
# [MATCH]: sexy sexy cum and text me i m wet and warm and ready for some porn ! u up for some fun ? THIS MSG IS FREE RECD:['SPACY:POS-PROPN'] MSGS:['SPACY:POS-PROPN'] 150P INC VAT:['SPACY:POS-NOUN'] 2:['SPACY:POS-NUM'] CANCEL TEXT STOP
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: 1Apple / Day = No Doctor . 1Tulsi Leaf / Day = No Cancer . 1Lemon / Day = No Fat . 1Cup Milk / day = No Bone Problms 3 Litres Watr / Day = No Diseases:['SPACY:POS-PROPN'] Snd:['SPACY:POS-PROPN'] ths:['SPACY:POS-NOUN'] 2:['SPACY:POS-NUM'] Whom U Care .. :- )
# -------------------------
# [MATCH]: OH YEAH , AND HAV A GREAT TIME IN NEWQUAY - SEND:['SPACY:POS-PROPN'] ME:['SPACY:POS-PROPN'] A POSTCARD:['SPACY:POS-NOUN'] ! 1:['SPACY:POS-NUM'] LOOK AFTER ALL THE GIRLS WHILE IM GONE(U KNOW THE 1IM TALKIN BOUT!)xx
# -------------------------
# ==================================================
# Rank 92
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-DET']]
# Window size: 4
# Class: Positive
# Precision: 0.634
# Match: 131 (3.7%)
# Gain = 0.037
# Examples ~ Class Positive:
# [MATCH]: Marvel Mobile Play the official Ultimate Spider - man game ( Â£4.50 ) on ur mobile right now . Text SPIDER to 83338:['SPACY:POS-NUM'] for the:['SPACY:POS-DET'] game & we ll send u a FREE 8Ball wallpaper
# -------------------------
# [MATCH]: You have won a Nokia 7250i:['SPACY:POS-NUM'] . This:['SPACY:POS-DET'] is what you get when you win our FREE auction . To take part send Nokia to 86021 now . HG / Suite342/2Lands Row / W1JHL 16 +
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I wnt to buy a BMW car urgently .. its vry urgent.but:['SPACY:POS-NUM'] hv a:['SPACY:POS-DET'] shortage of   & lt;#&gt ; Lacs.there is no source to arng dis amt . & lt;#&gt ; lacs .. thats my prob
# -------------------------
# [MATCH]: Long after I quit . I get on only like 5:['SPACY:POS-NUM'] minutes a:['SPACY:POS-DET'] day as it is .
# -------------------------
# ==================================================
# Rank 93
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['TEXT:to']]
# Window size: 5
# Class: Positive
# Precision: 0.565
# Match: 168 (4.7%)
# Gain = 0.037
# Examples ~ Class Positive:
# [MATCH]: Had your mobile 10 mths:['SPACY:POS-NOUN'] ? Update:['SPACY:POS-NOUN'] to:['TEXT:to'] the latest Camera / Video phones for FREE . KEEP UR SAME NUMBER , Get extra free mins / texts . Text YES for a call
# -------------------------
# [MATCH]: Final Chance ! Claim ur Â£150 worth of discount vouchers today:['SPACY:POS-NOUN'] ! Text:['SPACY:POS-NOUN'] YES to:['TEXT:to'] 85023 now ! SavaMob , member offers mobile ! T Cs SavaMob POBOX84 , M263UZ . Â£3.00 Subs 16
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Smile in Pleasure Smile in Pain Smile when trouble pours like Rain Smile when sum1 Hurts U Smile becoz:['SPACY:POS-NOUN'] SOMEONE:['SPACY:POS-NOUN'] still Loves to:['TEXT:to'] see u Smiling ! !
# -------------------------
# [MATCH]: Good afternoon loverboy ! How goes you day ? Any luck come your way ? I think of you , sweetie and send my love:['SPACY:POS-NOUN'] across the sea:['SPACY:POS-NOUN'] to:['TEXT:to'] make you smile and happy
# -------------------------
# ==================================================
# Rank 94
# Pattern: [['SENTIMENT:pos'], ['SPACY:POS-DET'], ['SPACY:POS-PROPN']]
# Window size: 5
# Class: Positive
# Precision: 0.797
# Match: 79 (2.2%)
# Gain = 0.037
# Examples ~ Class Positive:
# [MATCH]: Moby Pub Quiz . Win:['SENTIMENT:pos'] a:['SPACY:POS-DET'] Â£100 High:['SPACY:POS-PROPN'] Street prize if u know who the new Duchess of Cornwall will be ? Txt her first name to 82277.unsub STOP Â£1.50 008704050406 SP Arrow
# -------------------------
# [MATCH]: URGENT ! We are trying to contact U. Todays draw shows that you have won:['SENTIMENT:pos'] a:['SPACY:POS-DET'] Â£800:['SPACY:POS-PROPN'] prize GUARANTEED . Call 09050003091 from land line . Claim C52 . Valid12hrs only
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Height of Confidence:['SENTIMENT:pos'] : All the:['SPACY:POS-DET'] Aeronautics:['SPACY:POS-PROPN'] professors wer calld & amp ; they wer askd 2 sit in an aeroplane . Aftr they sat they wer told dat the plane ws made by their students . Dey all hurried out of d plane .. Bt only 1 did nt move ... He said:"if it is made by my students , this wo nt even start ........ Datz confidence ..
# -------------------------
# [MATCH]: God picked up a flower and dippeditinaDEW , lovingly touched itwhichturnedinto u , and the he gifted:['SENTIMENT:pos'] tomeandsaid , THIS:['SPACY:POS-DET'] FRIEND:['SPACY:POS-PROPN'] IS 4U
# -------------------------
# ==================================================
# Rank 95
# Pattern: [['TEXT:.'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.875
# Match: 64 (1.8%)
# Gain = 0.037
# Examples ~ Class Positive:
# [MATCH]: Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005 .:['TEXT:.'] Text:['SPACY:POS-PROPN'] FA to 87121:['SPACY:POS-NUM'] to receive entry question(std txt rate)T&C 's apply 08452810075over18 's
# -------------------------
# [MATCH]: Urgent ! Please call 09061743811 from landline .:['TEXT:.'] Your ABTA:['SPACY:POS-PROPN'] complimentary 4:['SPACY:POS-NUM'] * Tenerife Holiday or Â£5000 cash await collection SAE T&Cs Box 326 CW25WX 150ppm
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: C movie is juz last minute decision mah .:['TEXT:.'] Juz:['SPACY:POS-PROPN'] watch 2:['SPACY:POS-NUM'] lar but i tot Ã¼ not interested .
# -------------------------
# [MATCH]: Your opinion about me ? 1 . Over 2 .:['TEXT:.'] Jada:['SPACY:POS-PROPN'] 3:['SPACY:POS-NUM'] . Kusruthi 4 . Lovable 5 . Silent 6 . Spl character 7 . Not matured 8 . Stylish 9 . Simple Pls reply ..
# -------------------------
# ==================================================
# Rank 96
# Pattern: [['HYPERNYM3:statement.n.01']]
# Window size: 3
# Class: Positive
# Precision: 0.692
# Match: 107 (3.0%)
# Gain = 0.037
# Examples ~ Class Positive:
# [MATCH]: URGENT ! Your Mobile number has been awarded a < UKP>2000 prize GUARANTEED . Call 09061790125 from landline . Claim:['HYPERNYM3:statement.n.01'] 3030 . Valid 12hrs only 150ppm
# -------------------------
# [MATCH]: Final Chance ! Claim:['HYPERNYM3:statement.n.01'] ur Â£150 worth of discount vouchers today ! Text YES to 85023 now ! SavaMob , member offers mobile ! T Cs SavaMob POBOX84 , M263UZ . Â£3.00 Subs 16
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: GOD ASKED , " What is forgiveness ? " A little child gave lovely reply:['HYPERNYM3:statement.n.01'] , " It is d wonderful fruit that a tree gives when it is being hurt by a stone .. Good night ......
# -------------------------
# [MATCH]: Glad to see your reply:['HYPERNYM3:statement.n.01'] .
# -------------------------
# ==================================================
# Rank 97
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
# Window size: 5
# Class: Positive
# Precision: 0.520
# Match: 198 (5.6%)
# Gain = 0.036
# Examples ~ Class Positive:
# [MATCH]: Todays Vodafone numbers ending with 4882 are selected to a receive:['SPACY:POS-NOUN'] a Â£350:['SPACY:POS-PROPN'] award:['SPACY:POS-NOUN'] . If your number matches call 09064019014 to receive your Â£350 award .
# -------------------------
# [MATCH]: You will be receiving this week:['SPACY:POS-NOUN'] 's Triple:['SPACY:POS-PROPN'] Echo ringtone:['SPACY:POS-NOUN'] shortly . Enjoy it !
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Becoz its   & lt;#&gt ;   jan:['SPACY:POS-NOUN'] whn al:['SPACY:POS-PROPN'] the post:['SPACY:POS-NOUN'] ofice is in holiday so she cn go fr the post ofice ... got it duffer
# -------------------------
# [MATCH]: Do you know what:['SPACY:POS-NOUN'] Mallika:['SPACY:POS-PROPN'] Sherawat did yesterday:['SPACY:POS-NOUN'] ? Find out now @   & lt;URL&gt ;
# -------------------------
# ==================================================
# Rank 98
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
# Window size: 5
# Class: Positive
# Precision: 1.000
# Match: 44 (1.2%)
# Gain = 0.036
# Examples ~ Class Positive:
# [MATCH]: URGENT ! Your Mobile number has been awarded with a Â£2000 prize GUARANTEED . Call:['TEXT:call'] 09058094455:['SPACY:POS-NUM'] from:['SPACY:POS-ADP'] land line . Claim 3030 . Valid 12hrs only
# -------------------------
# [MATCH]: Urgent ! Please call:['TEXT:call'] 09061743810:['SPACY:POS-NUM'] from:['SPACY:POS-ADP'] landline . Your ABTA complimentary 4 * Tenerife Holiday or # 5000 cash await collection SAE T&Cs Box 326 CW25WX 150 ppm
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Rank 99
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['TEXT:.'], ['SPACY:POS-NUM']]
# Window size: 6
# Class: Positive
# Precision: 1.000
# Match: 44 (1.2%)
# Gain = 0.036
# Examples ~ Class Positive:
# [MATCH]: Urgent ! Please call 09061213237 from a landline . Â£5000 cash or a 4 * holiday await collection . T & Cs SAE PO:['SPACY:POS-PROPN'] Box 177 M227XY:['SPACY:POS-NOUN'] .:['TEXT:.'] 16:['SPACY:POS-NUM'] +
# -------------------------
# [MATCH]: Not heard from U4:['SPACY:POS-PROPN'] a while:['SPACY:POS-NOUN'] .:['TEXT:.'] Call 4:['SPACY:POS-NUM'] rude chat private line 01223585334 to cum . Wan 2C pics of me gettin shagged then text PIX to 8552 . 2End send STOP 8552 SAM xxx
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================

# %% [markdown]
# - Sort the patterns by their information gain

# %%
for idx, p in enumerate(the_patterns_2):
    print(f'{idx:>3} {p.support_class}   {round(p.coverage*100, 1):>4}   {p.precision:.3f}   {p.get_pattern_id()}')
# Out:
#   0 Negative   26.2   0.526   [['SPACY:POS-NUM']]
#   1 Positive    8.9   0.806   [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#   2 Positive    5.1   0.984   [['TEXT:call'], ['SPACY:POS-NUM']]
#   3 Positive   14.5   0.579   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#   4 Positive   11.8   0.613   [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
#   5 Positive    6.8   0.811   [['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
#   6 Negative   18.1   0.526   [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
#   7 Positive    5.4   0.856   [['TEXT:to'], ['SPACY:POS-NUM']]
#   8 Negative   37.8   0.690   [['SPACY:POS-PROPN']]
#   9 Positive    7.6   0.702   [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  10 Positive    7.1   0.722   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  11 Positive    5.7   0.797   [['TEXT:.'], ['SPACY:POS-NUM']]
#  12 Positive    6.7   0.735   [['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
#  13 Negative   20.0   0.585   [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  14 Positive    8.8   0.597   [['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
#  15 Positive    7.2   0.655   [['SPACY:POS-ADJ'], ['SPACY:POS-NUM']]
#  16 Positive    7.3   0.649   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  17 Positive    3.4   0.926   [['SPACY:POS-PROPN'], ['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
#  18 Positive   11.8   0.504   [['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]
#  19 Positive    8.0   0.591   [['SPACY:POS-NUM'], ['TEXT:.']]
#  20 Positive    4.3   0.791   [['SPACY:POS-NOUN'], ['TEXT:call']]
#  21 Positive    3.6   0.843   [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  22 Negative   37.2   0.983   [['TEXT:i']]
#  23 Positive    4.4   0.756   [['SPACY:POS-SYM']]
#  24 Positive    4.5   0.748   [['TEXT:free']]
#  25 Positive    2.7   0.938   [['TEXT:txt']]
#  26 Negative   15.5   0.591   [['SPACY:POS-NOUN'], ['TEXT:to']]
#  27 Positive    2.2   1.000   [['TEXT:claim']]
#  28 Positive    7.0   0.592   [['SPACY:POS-NOUN'], ['SPACY:POS-ADP', 'TEXT:to']]
#  29 Negative   16.1   0.602   [['TEXT:!']]
#  30 Positive    8.3   0.539   [['TEXT:.'], ['SPACY:POS-PROPN']]
#  31 Positive    8.7   0.522   [['SPACY:POS-PROPN'], ['TEXT:.']]
#  32 Positive    6.0   0.624   [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  33 Positive    2.4   0.942   [['TEXT:mobile']]
#  34 Positive    6.6   0.591   [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
#  35 Positive    4.0   0.739   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]
#  36 Negative   10.3   0.530   [['SPACY:POS-ADJ'], ['SPACY:POS-PROPN']]
#  37 Positive    6.9   0.559   [['SPACY:POS-NUM'], ['SPACY:POS-ADJ']]
#  38 Positive    7.3   0.542   [['SENTIMENT:pos'], ['SPACY:POS-PROPN']]
#  39 Positive    3.1   0.802   [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  40 Positive    1.9   0.985   [['TEXT:.'], ['TEXT:call'], ['SPACY:POS-NUM']]
#  41 Positive    2.2   0.923   [['HYPERNYM3:communication.n.02'], ['SPACY:POS-NUM']]
#  42 Positive    2.2   0.922   [['HYPERNYM3:win.v.01', 'SENTIMENT:pos']]
#  43 Negative   13.6   0.601   [['SPACY:POS-ADP', 'TEXT:to']]
#  44 Positive    2.0   0.957   [['TEXT:call'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
#  45 Positive    3.1   0.784   [['TEXT:.'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  46 Positive    7.5   0.521   [['SPACY:POS-DET'], ['SPACY:POS-PROPN']]
#  47 Positive    3.8   0.716   [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
#  48 Negative   10.6   0.559   [['SPACY:POS-ADP'], ['SPACY:POS-PROPN']]
#  49 Positive    4.0   0.690   [['SPACY:POS-PROPN'], ['TEXT:to']]
#  50 Positive    2.2   0.909   [['HYPERNYM3:cost.n.01']]
#  51 Negative   65.0   0.804   [['SPACY:POS-ADP']]
#  52 Positive    2.2   0.899   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  53 Negative   54.1   0.785   [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN']]
#  54 Negative   12.1   0.586   [['HYPERNYM3:message.n.02']]
#  55 Positive    5.1   0.613   [['SPACY:POS-NOUN'], ['HYPERNYM3:message.n.02']]
#  56 Negative   30.8   0.725   [['TEXT:to']]
#  57 Positive    2.5   0.843   [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  58 Positive    2.4   0.851   [['TEXT:!'], ['SPACY:POS-NUM']]
#  59 Positive    1.6   1.000   [['TEXT:prize']]
#  60 Positive    2.2   0.873   [['HYPERNYM3:message.n.02'], ['SPACY:POS-NUM']]
#  61 Negative    8.6   0.533   [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NOUN']]
#  62 Negative   10.8   0.580   [['HYPERNYM3:communication.n.02']]
#  63 Positive    1.6   0.982   [['HYPERNYM3:call.v.28'], ['SPACY:POS-NUM']]
#  64 Positive    2.0   0.890   [['SPACY:POS-PROPN'], ['TEXT:call']]
#  65 Positive    2.9   0.765   [['TEXT:call'], ['SPACY:POS-ADP']]
#  66 Positive    2.4   0.816   [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
#  67 Negative   15.9   0.649   [['TEXT:.'], ['SPACY:POS-NOUN']]
#  68 Negative   39.6   0.759   [['SPACY:POS-NOUN'], ['SPACY:POS-ADP']]
#  69 Positive    1.5   0.982   [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['TEXT:to'], ['SPACY:POS-NUM']]
#  70 Positive    4.8   0.594   [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-ADP']]
#  71 Negative   39.9   0.761   [['SENTIMENT:pos']]
#  72 Positive    2.2   0.838   [['SPACY:POS-ADP'], ['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
#  73 Positive    1.9   0.909   [['TEXT:to'], ['SPACY:POS-NUM'], ['TEXT:.']]
#  74 Positive    4.0   0.639   [['SPACY:POS-ADJ'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  75 Positive    1.7   0.934   [['SPACY:POS-NUM'], ['TEXT:now']]
#  76 Positive    2.5   0.789   [['TEXT:.'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  77 Positive    3.5   0.675   [['SENTIMENT:pos'], ['SPACY:POS-NUM']]
#  78 Positive    3.6   0.667   [['TEXT:!'], ['SPACY:POS-PROPN']]
#  79 Positive    1.9   0.884   [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
#  80 Positive    2.2   0.833   [['SPACY:POS-PROPN'], ['TEXT:.'], ['SPACY:POS-NUM']]
#  81 Positive    5.1   0.563   [['TEXT:!'], ['SPACY:POS-NOUN']]
#  82 Positive    3.1   0.709   [['SPACY:POS-DET'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  83 Positive    3.4   0.678   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['TEXT:.']]
#  84 Positive    3.0   0.713   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  85 Positive    4.1   0.621   [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['TEXT:.']]
#  86 Positive    2.1   0.838   [['SENTIMENT:pos'], ['TEXT:call']]
#  87 Positive    1.9   0.868   [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  88 Positive    2.5   0.764   [['HYPERNYM3:symbol.n.01']]
#  89 Positive    5.2   0.543   [['SPACY:POS-ADP'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
#  90 Positive    3.5   0.648   [['TEXT:!'], ['SPACY:POS-ADJ']]
#  91 Positive    1.6   0.914   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  92 Positive    3.7   0.634   [['SPACY:POS-NUM'], ['SPACY:POS-DET']]
#  93 Positive    4.7   0.565   [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['TEXT:to']]
#  94 Positive    2.2   0.797   [['SENTIMENT:pos'], ['SPACY:POS-DET'], ['SPACY:POS-PROPN']]
#  95 Positive    1.8   0.875   [['TEXT:.'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  96 Positive    3.0   0.692   [['HYPERNYM3:statement.n.01']]
#  97 Positive    5.6   0.520   [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  98 Positive    1.2   1.000   [['TEXT:call'], ['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
#  99 Positive    1.2   1.000   [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['TEXT:.'], ['SPACY:POS-NUM']]

# %% [markdown]
# - Sort the patterns by their precision

# %%
for idx, p in enumerate(sorted(the_patterns_2, key = lambda x: -x.precision)):
    print(f'{idx:>3} {p.support_class}   {round(p.coverage*100, 1):>4}   {p.precision:.3f}   {p.get_pattern_id()}')
# Out:
#   0 Positive    2.2   1.000   [['TEXT:claim']]
#   1 Positive    1.6   1.000   [['TEXT:prize']]
#   2 Positive    1.2   1.000   [['TEXT:call'], ['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
#   3 Positive    1.2   1.000   [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['TEXT:.'], ['SPACY:POS-NUM']]
#   4 Positive    1.9   0.985   [['TEXT:.'], ['TEXT:call'], ['SPACY:POS-NUM']]
#   5 Positive    5.1   0.984   [['TEXT:call'], ['SPACY:POS-NUM']]
#   6 Negative   37.2   0.983   [['TEXT:i']]
#   7 Positive    1.6   0.982   [['HYPERNYM3:call.v.28'], ['SPACY:POS-NUM']]
#   8 Positive    1.5   0.982   [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['TEXT:to'], ['SPACY:POS-NUM']]
#   9 Positive    2.0   0.957   [['TEXT:call'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
#  10 Positive    2.4   0.942   [['TEXT:mobile']]
#  11 Positive    2.7   0.938   [['TEXT:txt']]
#  12 Positive    1.7   0.934   [['SPACY:POS-NUM'], ['TEXT:now']]
#  13 Positive    3.4   0.926   [['SPACY:POS-PROPN'], ['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
#  14 Positive    2.2   0.923   [['HYPERNYM3:communication.n.02'], ['SPACY:POS-NUM']]
#  15 Positive    2.2   0.922   [['HYPERNYM3:win.v.01', 'SENTIMENT:pos']]
#  16 Positive    1.6   0.914   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  17 Positive    2.2   0.909   [['HYPERNYM3:cost.n.01']]
#  18 Positive    1.9   0.909   [['TEXT:to'], ['SPACY:POS-NUM'], ['TEXT:.']]
#  19 Positive    2.2   0.899   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  20 Positive    2.0   0.890   [['SPACY:POS-PROPN'], ['TEXT:call']]
#  21 Positive    1.9   0.884   [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
#  22 Positive    1.8   0.875   [['TEXT:.'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  23 Positive    2.2   0.873   [['HYPERNYM3:message.n.02'], ['SPACY:POS-NUM']]
#  24 Positive    1.9   0.868   [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  25 Positive    5.4   0.856   [['TEXT:to'], ['SPACY:POS-NUM']]
#  26 Positive    2.4   0.851   [['TEXT:!'], ['SPACY:POS-NUM']]
#  27 Positive    2.5   0.843   [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  28 Positive    3.6   0.843   [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  29 Positive    2.1   0.838   [['SENTIMENT:pos'], ['TEXT:call']]
#  30 Positive    2.2   0.838   [['SPACY:POS-ADP'], ['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
#  31 Positive    2.2   0.833   [['SPACY:POS-PROPN'], ['TEXT:.'], ['SPACY:POS-NUM']]
#  32 Positive    2.4   0.816   [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
#  33 Positive    6.8   0.811   [['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
#  34 Positive    8.9   0.806   [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  35 Negative   65.0   0.804   [['SPACY:POS-ADP']]
#  36 Positive    3.1   0.802   [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  37 Positive    2.2   0.797   [['SENTIMENT:pos'], ['SPACY:POS-DET'], ['SPACY:POS-PROPN']]
#  38 Positive    5.7   0.797   [['TEXT:.'], ['SPACY:POS-NUM']]
#  39 Positive    4.3   0.791   [['SPACY:POS-NOUN'], ['TEXT:call']]
#  40 Positive    2.5   0.789   [['TEXT:.'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  41 Negative   54.1   0.785   [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN']]
#  42 Positive    3.1   0.784   [['TEXT:.'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  43 Positive    2.9   0.765   [['TEXT:call'], ['SPACY:POS-ADP']]
#  44 Positive    2.5   0.764   [['HYPERNYM3:symbol.n.01']]
#  45 Negative   39.9   0.761   [['SENTIMENT:pos']]
#  46 Negative   39.6   0.759   [['SPACY:POS-NOUN'], ['SPACY:POS-ADP']]
#  47 Positive    4.4   0.756   [['SPACY:POS-SYM']]
#  48 Positive    4.5   0.748   [['TEXT:free']]
#  49 Positive    4.0   0.739   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]
#  50 Positive    6.7   0.735   [['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
#  51 Negative   30.8   0.725   [['TEXT:to']]
#  52 Positive    7.1   0.722   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  53 Positive    3.8   0.716   [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
#  54 Positive    3.0   0.713   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  55 Positive    3.1   0.709   [['SPACY:POS-DET'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  56 Positive    7.6   0.702   [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  57 Positive    3.0   0.692   [['HYPERNYM3:statement.n.01']]
#  58 Negative   37.8   0.690   [['SPACY:POS-PROPN']]
#  59 Positive    4.0   0.690   [['SPACY:POS-PROPN'], ['TEXT:to']]
#  60 Positive    3.4   0.678   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['TEXT:.']]
#  61 Positive    3.5   0.675   [['SENTIMENT:pos'], ['SPACY:POS-NUM']]
#  62 Positive    3.6   0.667   [['TEXT:!'], ['SPACY:POS-PROPN']]
#  63 Positive    7.2   0.655   [['SPACY:POS-ADJ'], ['SPACY:POS-NUM']]
#  64 Negative   15.9   0.649   [['TEXT:.'], ['SPACY:POS-NOUN']]
#  65 Positive    7.3   0.649   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  66 Positive    3.5   0.648   [['TEXT:!'], ['SPACY:POS-ADJ']]
#  67 Positive    4.0   0.639   [['SPACY:POS-ADJ'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  68 Positive    3.7   0.634   [['SPACY:POS-NUM'], ['SPACY:POS-DET']]
#  69 Positive    6.0   0.624   [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  70 Positive    4.1   0.621   [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['TEXT:.']]
#  71 Positive    5.1   0.613   [['SPACY:POS-NOUN'], ['HYPERNYM3:message.n.02']]
#  72 Positive   11.8   0.613   [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
#  73 Negative   16.1   0.602   [['TEXT:!']]
#  74 Negative   13.6   0.601   [['SPACY:POS-ADP', 'TEXT:to']]
#  75 Positive    8.8   0.597   [['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
#  76 Positive    4.8   0.594   [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-ADP']]
#  77 Positive    7.0   0.592   [['SPACY:POS-NOUN'], ['SPACY:POS-ADP', 'TEXT:to']]
#  78 Positive    6.6   0.591   [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
#  79 Positive    8.0   0.591   [['SPACY:POS-NUM'], ['TEXT:.']]
#  80 Negative   15.5   0.591   [['SPACY:POS-NOUN'], ['TEXT:to']]
#  81 Negative   12.1   0.586   [['HYPERNYM3:message.n.02']]
#  82 Negative   20.0   0.585   [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  83 Negative   10.8   0.580   [['HYPERNYM3:communication.n.02']]
#  84 Positive   14.5   0.579   [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  85 Positive    4.7   0.565   [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['TEXT:to']]
#  86 Positive    5.1   0.563   [['TEXT:!'], ['SPACY:POS-NOUN']]
#  87 Negative   10.6   0.559   [['SPACY:POS-ADP'], ['SPACY:POS-PROPN']]
#  88 Positive    6.9   0.559   [['SPACY:POS-NUM'], ['SPACY:POS-ADJ']]
#  89 Positive    5.2   0.543   [['SPACY:POS-ADP'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
#  90 Positive    7.3   0.542   [['SENTIMENT:pos'], ['SPACY:POS-PROPN']]
#  91 Positive    8.3   0.539   [['TEXT:.'], ['SPACY:POS-PROPN']]
#  92 Negative    8.6   0.533   [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NOUN']]
#  93 Negative   10.3   0.530   [['SPACY:POS-ADJ'], ['SPACY:POS-PROPN']]
#  94 Negative   18.1   0.526   [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
#  95 Negative   26.2   0.526   [['SPACY:POS-NUM']]
#  96 Positive    8.7   0.522   [['SPACY:POS-PROPN'], ['TEXT:.']]
#  97 Positive    7.5   0.521   [['SPACY:POS-DET'], ['SPACY:POS-PROPN']]
#  98 Positive    5.6   0.520   [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  99 Positive   11.8   0.504   [['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]
