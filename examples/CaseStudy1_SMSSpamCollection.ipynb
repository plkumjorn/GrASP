# %%
# %load_ext autoreload
# %autoreload 2

# %%
import grasp
from grasp import GrASP
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Load the data
# - We use the SMS Spam Collection dataset from the following paper. Please download and unzip it by running the two cells below **only if you have not done this before**.
#
# ```
# Almeida, T. A., Hidalgo, J. M. G., & Yamakami, A. (2011, September). Contributions to the study of SMS spam filtering: new collection and results. In Proceedings of the 11th ACM symposium on Document engineering (pp. 259-262).
# ```

# %%
import urllib.request
url = 'http://www.dt.fee.unicamp.br/~tiago/smsspamcollection/smsspamcollection.zip'
filename = './data/smsspamcollection.zip'
urllib.request.urlretrieve(url, filename)

# %%
# !unzip ./data/smsspamcollection.zip -d ./data

# %% [markdown]
# - Load the data

# %%
def get_data():
    f = open('data/SMSSpamCollection.txt', 'r')
    texts, labels = [], []
    for line in f:
        line = line.strip()
        tab_idx = line.index('\t')
        label = line[:tab_idx]
        text = line[tab_idx+1:]
        if label == 'ham':
            label = 0
        elif label == 'spam':
            label = 1
        else:
            raise Exception(f"Invalid label - {label}")
        texts.append(text)
        labels.append(label)
    return texts, labels

# %%
texts, labels = get_data()
X_train, X_test, y_train, y_test = train_test_split(texts, labels, test_size=0.2, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1)
# len(texts), sum(labels), len(X_test), sum(y_test)

# %%
positive = [t for idx, t in enumerate(X_train) if y_train[idx]]
negative = [t for idx, t in enumerate(X_train) if not y_train[idx]]
print(f'Positive examples = {len(positive)}\nNegative examples = {len(negative)}')
# Out:
# Positive examples = 488
# Negative examples = 3079

# %% [markdown]
# ## Run GrASP

# %%
# Create the GrASP engine
grasp_model = GrASP(include_standard = ['TEXT', 'POS', 'HYPERNYM', 'SENTIMENT'],
                    num_patterns = 100, gaps_allowed = 2)

# %%
# Fit GrASP to the dataset
the_patterns = grasp_model.fit_transform(positive, negative)
# Out:
#   0%|          | 0/488 [00:00<?, ?it/s]
# Step 1: Create augmented texts
# 100%|██████████| 488/488 [00:20<00:00, 23.36it/s]
# 100%|██████████| 3079/3079 [01:26<00:00, 35.76it/s]
# Step 2: Find frequent attributes
#   1%|          | 7/1215 [00:00<00:18, 64.99it/s]
# Total number of candidate alphabet = 1215, such as ['SPACY:POS-VERB', 'SPACY:POS-NOUN', 'SPACY:POS-PUNCT', 'SPACY:POS-PRON', 'SPACY:POS-ADV']
# Step 3: Find alphabet set
# 100%|██████████| 1215/1215 [00:27<00:00, 44.34it/s]
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finding top k: 100 / 100
# Total number of alphabet = 100
# ['SPACY:POS-NUM', 'SPACY:POS-PROPN', 'TEXT:call', 'TEXT:i', 'SPACY:POS-SYM', 'TEXT:free', 'TEXT:txt', 'TEXT:claim', 'TEXT:!', 'TEXT:mobile', 'HYPERNYM:cost.n.01', 'SPACY:POS-ADP', 'HYPERNYM:message.n.02', 'TEXT:to', 'TEXT:prize', 'HYPERNYM:communication.n.02', 'HYPERNYM:win.v.01', 'SENTIMENT:pos', 'HYPERNYM:symbol.n.01', 'HYPERNYM:statement.n.01', 'TEXT:your', 'SPACY:POS-ADJ', 'TEXT:or', 'TEXT:text', 'TEXT:stop', 'TEXT:-', 'TEXT:150p', 'TEXT:guaranteed', 'TEXT:urgent', 'HYPERNYM:textbook.n.01', 'HYPERNYM:act.n.02', 'TEXT:win', 'HYPERNYM:contest.v.01', 'TEXT:+', 'HYPERNYM:written_communication.n.01', 'SPACY:POS-PRON', 'TEXT:16', 'TEXT:cash', 'HYPERNYM:abstraction.n.06', 'TEXT:from', 'HYPERNYM:assertion.n.01', 'TEXT:reply', 'TEXT:now', 'TEXT:.', 'TEXT:tone', 'TEXT:18', 'HYPERNYM:acquisition.n.02', 'SPACY:POS-DET', 'TEXT:nokia', 'TEXT:a', 'HYPERNYM:user.n.01', 'TEXT:our', 'HYPERNYM:mobile.n.02', 'HYPERNYM:minute.n.01', 'HYPERNYM:person.n.01', 'HYPERNYM:claim.v.03', 'TEXT:service', 'TEXT:contact', 'HYPERNYM:writing.n.02', 'TEXT:for', 'TEXT:...', 'HYPERNYM:offer.n.02', 'TEXT:awarded', 'TEXT:â£1000', 'TEXT:150ppm', 'TEXT:4', 'HYPERNYM:request.n.01', 'TEXT:per', 'HYPERNYM:call.v.28', 'HYPERNYM:convey.v.03', 'HYPERNYM:television_camera.n.01', 'HYPERNYM:land_line.n.01', 'TEXT:ur', 'HYPERNYM:state.v.01', 'TEXT:camera', 'HYPERNYM:phone.n.02', 'TEXT:rate', 'TEXT:my', 'HYPERNYM:solid_figure.n.01', 'TEXT:latest', 'HYPERNYM:text.n.04', 'HYPERNYM:coding_system.n.01', 'TEXT:box', 'TEXT:draw', 'TEXT::', 'HYPERNYM:event.n.01', 'TEXT:line', 'HYPERNYM:free.a.01', 'TEXT:shows', 'HYPERNYM:now.r.03', 'HYPERNYM:declare.v.01', 'TEXT:10p', 'TEXT:collection', 'TEXT:2', 'SPACY:POS-NOUN', 'HYPERNYM:memory_device.n.01', 'HYPERNYM:document.n.01', 'HYPERNYM:service.n.11', 'HYPERNYM:equipment.n.01', 'HYPERNYM:part.n.01']
# Example of patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Metric (global) = 0.223
# Examples ~ Class Negative:
# [MATCH]: Yar lor he wan 2:['SPACY:POS-NUM'] go c horse racing today mah , so eat earlier lor . I ate chicken rice . U ?
# -------------------------
# [MATCH]: HOW ARE U ? I HAVE MISSED U ! I HAVENT BEEN UP 2:['SPACY:POS-NUM'] MUCH A BIT BORED WITH THE HOLIDAY WANT 2 GO BAK 2 COLLEGE ! SAD ISNT IT?xx
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: You have WON a guaranteed Â£1000 cash or a Â£2000 prize . To claim yr prize call our customer service representative on 08714712379:['SPACY:POS-NUM'] between 10am-7pm Cost 10p
# -------------------------
# [MATCH]: You are a Â£1000 winner or Guaranteed Caller Prize , this is our Final attempt to contact you ! To Claim Call 09071517866:['SPACY:POS-NUM'] Now ! 150ppmPOBox10183BhamB64XE
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN']]
# Window size: 3
# Class: Negative
# Precision: 0.690
# Match: 1347 (37.8%)
# Gain = 0.112
# Metric (global) = 0.112
# Examples ~ Class Negative:
# [MATCH]: I am in escape theatre now . . Going to watch KAVALAN:['SPACY:POS-PROPN'] in a few minutes
# -------------------------
# [MATCH]: Gud:['SPACY:POS-PROPN'] mrng dear have a nice day
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: WIN:['SPACY:POS-PROPN'] : We have a winner ! Mr. T. Foley won an iPod ! More exciting prizes soon , so keep an eye on ur mobile or visit www.win-82050.co.uk
# -------------------------
# [MATCH]: Sppok up ur mob with a Halloween:['SPACY:POS-PROPN'] collection of nokia logo&pic message plus a FREE eerie tone , txt CARD SPOOK to 8007
# -------------------------
# ==================================================
# Pattern: [['TEXT:call']]
# Window size: 3
# Class: Positive
# Precision: 0.618
# Match: 348 (9.8%)
# Gain = 0.104
# Metric (global) = 0.104
# Examples ~ Class Positive:
# [MATCH]: Hack Chat . Get backdoor entry into 121 chat rooms at a fraction of the cost . Reply NEO69 or call:['TEXT:call'] 09050280520 , to subscribe 25p pm . DPS , Bcm box 8027 Ldn , wc1n3xx
# -------------------------
# [MATCH]: Free video camera phones with Half Price line rental for 12 mths and 500 cross ntwk mins 100 txts . Call:['TEXT:call'] MobileUpd8 08001950382 or Call2OptOut/674
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I am in tirupur .   call:['TEXT:call'] you da .
# -------------------------
# [MATCH]: Sorry , I 'll call:['TEXT:call'] later
# -------------------------
# ==================================================
# Pattern: [['TEXT:i']]
# Window size: 3
# Class: Negative
# Precision: 0.983
# Match: 1327 (37.2%)
# Gain = 0.067
# Metric (global) = 0.067
# Examples ~ Class Negative:
# [MATCH]: Thanks da thangam , i:['TEXT:i'] feel very very happy dear . I also miss you da .
# -------------------------
# [MATCH]: Yar i:['TEXT:i'] wanted 2 scold u yest but late already ... I where got zhong se qing you ? If u ask me b4 he ask me then i 'll go out w u all lor . N u still can act so real .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: cmon babe , make me horny , * turn * me on ! Txt me your fantasy now babe - ) I:['TEXT:i'] m hot , sticky and need you now . All replies cost Â£1.50 . 2 cancel send STOP
# -------------------------
# [MATCH]: I:['TEXT:i'] want some cock ! My hubby 's away , I need a real man 2 satisfy me . Txt WIFE to 89938 for no strings action . ( Txt STOP 2 end , txt rec Â£1.50ea . OTBox 731 LA1 7WS . )
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-SYM']]
# Window size: 3
# Class: Positive
# Precision: 0.756
# Match: 156 (4.4%)
# Gain = 0.067
# Metric (global) = 0.067
# Examples ~ Class Positive:
# [MATCH]: Bears Pic Nick , and Tom , Pete and ... Dick . In fact , all types try gay chat with photo upload call 08718730666 ( 10p /:['SPACY:POS-SYM'] min ) . 2 stop texts call 08712460324
# -------------------------
# [MATCH]: -PLS STOP bootydelious ( 32/F ) is inviting you to be her friend . Reply YES-434 or NO-434 See her : www . SMS.ac /:['SPACY:POS-SYM'] u / bootydelious STOP ? Send STOP FRND to 62468
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Wait that 's still not all that clear , were you not sure about me being sarcastic or that that 's why x:['SPACY:POS-SYM'] does n't want to live with us
# -------------------------
# [MATCH]: What i mean was i left too early to check , cos i 'm working a 9 -:['SPACY:POS-SYM'] 6 .
# -------------------------
# ==================================================
# Step 4: Grow patterns
# 100%|██████████| 100/100 [00:55<00:00,  1.80it/s]
# Length 2 / 5; New candidates = 14950
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Metric (global) = 0.223
# Examples ~ Class Negative:
# [MATCH]: I thk Ã¼ got ta go home by urself . Cos i 'll b going out shopping 4:['SPACY:POS-NUM'] my frens present .
# -------------------------
# [MATCH]: Ill be at yours in about 3:['SPACY:POS-NUM'] mins but look out for me
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: 88066:['SPACY:POS-NUM'] FROM 88066 LOST 3POUND HELP
# -------------------------
# [MATCH]: FREE MESSAGE Activate your 500:['SPACY:POS-NUM'] FREE Text Messages by replying to this message with the word FREE For terms & conditions , visit www.07781482378.com
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.806
# Match: 319 (8.9%)
# Gain = 0.175
# Metric (global) = 0.175
# Examples ~ Class Positive:
# [MATCH]: 5p 4 alfie Moon 's Children in need song on ur mob . Tell ur m8s . Txt Tone:['SPACY:POS-PROPN'] charity to 8007:['SPACY:POS-NUM'] for Nokias or Poly charity for polys : zed 08701417012 profit 2 charity .
# -------------------------
# [MATCH]: FREE entry into our Â£250 weekly competition just text the word WIN:['SPACY:POS-PROPN'] to 80086:['SPACY:POS-NUM'] NOW . 18 T&C www.txttowin.co.uk
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Yar:['SPACY:POS-PROPN'] i wanted 2:['SPACY:POS-NUM'] scold u yest but late already ... I where got zhong se qing you ? If u ask me b4 he ask me then i 'll go out w u all lor . N u still can act so real .
# -------------------------
# [MATCH]: THANX4 TODAY CER IT WAS NICE:['SPACY:POS-PROPN'] 2:['SPACY:POS-NUM'] CATCH UP BUT WE AVE 2 FIND MORE TIME MORE OFTEN OH WELL TAKE CARE C U SOON.C
# -------------------------
# ==================================================
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.984
# Match: 183 (5.1%)
# Gain = 0.152
# Metric (global) = 0.152
# Examples ~ Class Positive:
# [MATCH]: URGENT ! Your Mobile number has been awarded with a Â£2000 prize GUARANTEED . Call:['TEXT:call'] 09061790121:['SPACY:POS-NUM'] from land line . Claim 3030 . Valid 12hrs only 150ppm
# -------------------------
# [MATCH]: PRIVATE ! Your 2004 Account Statement for 07742676969 shows 786 unredeemed Bonus Points . To claim call:['TEXT:call'] 08719180248:['SPACY:POS-NUM'] Identifier Code : 45239 Expires
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Yun ah.the ubi one say if Ã¼ wan call:['TEXT:call'] by tomorrow.call 67441233:['SPACY:POS-NUM'] look for irene.ere only got bus8,22,65,61,66,382 . Ubi cres , ubi tech park.6ph for 1st 5wkg days . Ã¨n
# -------------------------
# [MATCH]: Ummma.will call:['TEXT:call'] after check in.our:['SPACY:POS-NUM'] life will begin from qatar so pls pray very hard .
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.579
# Match: 518 (14.5%)
# Gain = 0.148
# Metric (global) = 0.148
# Examples ~ Class Positive:
# [MATCH]: Congrats ! 1 year special cinema pass for 2 is yours . call 09061209465 now ! C Suprman V , Matrix3 , StarWars3 , etc all 4 FREE ! bx420-ip4:['SPACY:POS-PROPN'] - 5we:['SPACY:POS-PROPN'] . 150pm . Do nt miss out !
# -------------------------
# [MATCH]: INTERFLORA:['SPACY:POS-PROPN'] - Â“It:['SPACY:POS-PROPN'] 's not too late to order Interflora flowers for christmas call 0800 505060 to place your order before Midnight tomorrow .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: GOD:['SPACY:POS-PROPN'] ASKED:['SPACY:POS-PROPN'] , " What is forgiveness ? " A little child gave lovely reply , " It is d wonderful fruit that a tree gives when it is being hurt by a stone .. Good night ......
# -------------------------
# [MATCH]: Hello , my love ! How went your day ? Are you alright ? I think of you , my sweet and send a jolt to your heart to remind you ... I LOVE YOU ! Can you hear it ? I screamed it across the sea for all the world to hear . Ahmad:['SPACY:POS-PROPN'] al:['SPACY:POS-PROPN'] Hallaq is loved ! and owned ! * possessive passionate kiss *
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.613
# Match: 421 (11.8%)
# Gain = 0.129
# Metric (global) = 0.129
# Examples ~ Class Positive:
# [MATCH]: Wanna have a laugh ? Try CHIT - CHAT on your mobile now ! Logon by txting the word : CHAT and send it to:['SPACY:POS-ADP'] No : 8883:['SPACY:POS-NUM'] CM PO Box 4217 London W1A 6ZF 16 + 118p / msg rcvd
# -------------------------
# [MATCH]: Not heard from U4 a while . Call 4 rude chat private line 01223585334 to cum . Wan 2C pics of me gettin shagged then text PIX to:['SPACY:POS-ADP'] 8552:['SPACY:POS-NUM'] . 2End send STOP 8552 SAM xxx
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: We made it ! Eta at:['SPACY:POS-ADP'] taunton is 12:30:['SPACY:POS-NUM'] as planned , hope thatâ€˜s still okday ? ! Good to see you ! : -xx
# -------------------------
# [MATCH]: I might come to kerala for:['SPACY:POS-ADP'] 2:['SPACY:POS-NUM'] days.so you can be prepared to take a leave once i finalise .dont plan any travel during my visit.need to finish urgent works .
# -------------------------
# ==================================================
# 100%|██████████| 68/68 [00:59<00:00,  1.14it/s]
# Length 3 / 5; New candidates = 13344
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
#   0%|          | 0/36 [00:00<?, ?it/s]
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Metric (global) = 0.223
# Examples ~ Class Negative:
# [MATCH]: Thank You for calling . Forgot to say Happy Onam to you Sirji . I am fine here and remembered you when i met an insurance person . Meet You in Qatar Insha Allah . Rakhesh , ex:['SPACY:POS-NUM'] Tata AIG who joined TISSCO , Tayseer .
# -------------------------
# [MATCH]: Ever green quote ever told by Jerry in cartoon " A Person Who Irritates u Always Is the one:['SPACY:POS-NUM'] Who Loves u Vry Much But Fails to Express It ... ! .. ! ! :-) :-) gud nyt
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Guess what ! Somebody you know secretly fancies you ! Wanna find out who it is ? Give us a call on 09065394514:['SPACY:POS-NUM'] From Landline DATEBox1282EssexCM61XN 150p / min 18
# -------------------------
# [MATCH]: U were outbid by simonwatson5120 on the Shinco DVD Plyr . 2:['SPACY:POS-NUM'] bid again , visit sms . ac / smsrewards 2 end bid notifications , reply END OUT
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.806
# Match: 319 (8.9%)
# Gain = 0.175
# Metric (global) = 0.175
# Examples ~ Class Positive:
# [MATCH]: Last Chance ! Claim ur Â£150 worth of discount vouchers today ! Text:['SPACY:POS-PROPN'] SHOP to 85023:['SPACY:POS-NUM'] now ! SavaMob , offers mobile ! T Cs SavaMob POBOX84 , M263UZ . Â£3.00 Sub . 16
# -------------------------
# [MATCH]: URGENT ! We are trying to contact U. Todays draw shows that you have won a Â£800 prize GUARANTEED:['SPACY:POS-PROPN'] . Call 09050001808:['SPACY:POS-NUM'] from land line . Claim M95 . Valid12hrs only
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: " BOO BABE ! U ENJOYIN YOURJOB ? U:['SPACY:POS-PROPN'] SEEMED 2:['SPACY:POS-NUM'] B GETTIN ON WELL HUNNY!HOPE URE OK?TAKE CARE & IÂ’LLSPEAK 2U SOONLOTS OF LOVEME XXXX . "
# -------------------------
# [MATCH]: Quite late lar ... Ard:['SPACY:POS-PROPN'] 12:['SPACY:POS-NUM'] anyway i wun b drivin ...
# -------------------------
# ==================================================
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.984
# Match: 183 (5.1%)
# Gain = 0.152
# Metric (global) = 0.152
# Examples ~ Class Positive:
# [MATCH]: PRIVATE ! Your 2003 Account Statement for shows 800 un - redeemed S. I. M. points . Call:['TEXT:call'] 08719899230:['SPACY:POS-NUM'] Identifier Code : 41685 Expires 07/11/04
# -------------------------
# [MATCH]: Congrats ! 1 year special cinema pass for 2 is yours . call:['TEXT:call'] 09061209465:['SPACY:POS-NUM'] now ! C Suprman V , Matrix3 , StarWars3 , etc all 4 FREE ! bx420-ip4 - 5we . 150pm . Do nt miss out !
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I 'm in a movie . Call:['TEXT:call'] me 4:['SPACY:POS-NUM'] wat ?
# -------------------------
# [MATCH]: Yun ah.the ubi one say if Ã¼ wan call:['TEXT:call'] by tomorrow.call 67441233:['SPACY:POS-NUM'] look for irene.ere only got bus8,22,65,61,66,382 . Ubi cres , ubi tech park.6ph for 1st 5wkg days . Ã¨n
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.579
# Match: 518 (14.5%)
# Gain = 0.148
# Metric (global) = 0.148
# Examples ~ Class Positive:
# [MATCH]: Did you hear about the new " Divorce:['SPACY:POS-PROPN'] Barbie:['SPACY:POS-PROPN'] " ? It comes with all of Ken 's stuff !
# -------------------------
# [MATCH]: * FREE * POLYPHONIC RINGTONE Text SUPER to 87131 to get your FREE POLY TONE of the week now ! 16 SN:['SPACY:POS-PROPN'] PoBox202:['SPACY:POS-PROPN'] NR31 7ZS subscription 450pw
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: MOON has come to color your dreams , STARS to make them musical and my SMS to give you warm and Peaceful:['SPACY:POS-PROPN'] Sleep:['SPACY:POS-PROPN'] . Good Night
# -------------------------
# [MATCH]: Ãœ:['SPACY:POS-PROPN'] neva:['SPACY:POS-PROPN'] tell me how i noe ... I 'm not at home in da aft wat ...
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.613
# Match: 421 (11.8%)
# Gain = 0.129
# Metric (global) = 0.129
# Examples ~ Class Positive:
# [MATCH]: URGENT . Important information for:['SPACY:POS-ADP'] 02:['SPACY:POS-NUM'] user . Today is your lucky day ! 2 find out why , log onto http://www.urawinner.com there is a fantastic surprise awaiting you !
# -------------------------
# [MATCH]: Sunshine Quiz Wkly Q ! Win a top Sony DVD player if u know which country Liverpool played in mid week ? Txt ansr to:['SPACY:POS-ADP'] 82277:['SPACY:POS-NUM'] . Â£1.50 SP : Tyrone
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Pls ask macho how much is budget for:['SPACY:POS-ADP'] bb bold 2:['SPACY:POS-NUM'] is cos i saw a new one for   & lt;#&gt ;   dollars .
# -------------------------
# [MATCH]: Nope but i 'm going home now then go pump petrol lor ... Like:['SPACY:POS-ADP'] going 2:['SPACY:POS-NUM'] rain soon ...
# -------------------------
# ==================================================
# 100%|██████████| 36/36 [00:30<00:00,  1.18it/s]
# Length 4 / 5; New candidates = 7137
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
#   0%|          | 0/5 [00:00<?, ?it/s]
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Metric (global) = 0.223
# Examples ~ Class Negative:
# [MATCH]: I love u:['SPACY:POS-NUM'] 2 babe ! R u sure everything is alrite . Is he being an idiot ? Txt bak girlie
# -------------------------
# [MATCH]: No dice , art class 6:['SPACY:POS-NUM'] thru 9 :( thanks though . Any idea what time I should come tomorrow ?
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Can U get 2:['SPACY:POS-NUM'] phone NOW ? I wanna chat 2 set up meet Call me NOW on 09096102316 U can cum here 2moro Luv JANE xx CallsÂ£1/minmoremobsEMSPOBox45PO139WA
# -------------------------
# [MATCH]: SMSSERVICES . for yourinclusive text credits , pls goto www.comuk.net login= 3qxj9:['SPACY:POS-NUM'] unsubscribe with STOP , no extra charge . help 08702840625.COMUK . 220-CM2 9AE
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.806
# Match: 319 (8.9%)
# Gain = 0.175
# Metric (global) = 0.175
# Examples ~ Class Positive:
# [MATCH]: Dear U've been invited to XCHAT . This is our final attempt to contact u ! Txt:['SPACY:POS-PROPN'] CHAT to 86688:['SPACY:POS-NUM'] 150p / MsgrcvdHG / Suite342/2Lands / Row / W1J6HL LDN 18 yrs
# -------------------------
# [MATCH]: Your free ringtone is waiting to be collected . Simply text the password " MIX:['SPACY:POS-PROPN'] " to 85069:['SPACY:POS-NUM'] to verify . Get Usher and Britney . FML , PO Box 5249 , MK17 92H. 450Ppw 16
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Your opinion about me ? 1 . Over 2 . Jada:['SPACY:POS-PROPN'] 3:['SPACY:POS-NUM'] . Kusruthi 4 . Lovable 5 . Silent 6 . Spl character 7 . Not matured 8 . Stylish 9 . Simple Pls reply ..
# -------------------------
# [MATCH]: Wot:['SPACY:POS-PROPN'] u up 2:['SPACY:POS-NUM'] u weirdo ?
# -------------------------
# ==================================================
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.984
# Match: 183 (5.1%)
# Gain = 0.152
# Metric (global) = 0.152
# Examples ~ Class Positive:
# [MATCH]: Xmas Offer ! Latest Motorola , SonyEricsson & Nokia & FREE Bluetooth or DVD ! Double Mins & 1000 Txt on Orange . Call:['TEXT:call'] MobileUpd8 on 08000839402:['SPACY:POS-NUM'] or call2optout/4QF2
# -------------------------
# [MATCH]: YOUR CHANCE TO BE ON A REALITY FANTASY SHOW call:['TEXT:call'] now = 08707509020:['SPACY:POS-NUM'] Just 20p per min NTT Ltd , PO Box 1327 Croydon CR9 5WB 0870 is a national = rate call .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I 'm in a movie . Call:['TEXT:call'] me 4:['SPACY:POS-NUM'] wat ?
# -------------------------
# [MATCH]: Ummma.will call:['TEXT:call'] after check in.our:['SPACY:POS-NUM'] life will begin from qatar so pls pray very hard .
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.579
# Match: 518 (14.5%)
# Gain = 0.148
# Metric (global) = 0.148
# Examples ~ Class Positive:
# [MATCH]: URGENT This is our 2nd attempt to contact U. Your Â£900 prize from YESTERDAY is still awaiting collection . To claim CALL NOW:['SPACY:POS-PROPN'] 09061702893 . ACL03530150PM:['SPACY:POS-PROPN']
# -------------------------
# [MATCH]: You have been selected to stay in 1 of 250 top British hotels - FOR NOTHING ! Holiday:['SPACY:POS-PROPN'] Worth:['SPACY:POS-PROPN'] Â£350 ! To Claim , Call London 02072069400 . Bx 526 , SW73SS
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Joy 's father is John:['SPACY:POS-PROPN'] . Then John:['SPACY:POS-PROPN'] is the NAME of Joy 's father . Mandan
# -------------------------
# [MATCH]: Easy:['SPACY:POS-PROPN'] ah?sen:['SPACY:POS-PROPN'] got selected means its good ..
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.613
# Match: 421 (11.8%)
# Gain = 0.129
# Metric (global) = 0.129
# Examples ~ Class Positive:
# [MATCH]: URGENT ! Your Mobile No was awarded a Â£2,000 Bonus Caller Prize on:['SPACY:POS-ADP'] 1/08/03:['SPACY:POS-NUM'] ! This is our 2nd attempt to contact YOU ! Call 0871 - 4719 - 523 BOX95QU BT National Rate
# -------------------------
# [MATCH]: This is the 2nd attempt to contract U , you have won this weeks top prize of:['SPACY:POS-ADP'] either Â£1000:['SPACY:POS-NUM'] cash or Â£200 prize . Just call 09066361921
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Ãœ go home liao ? Ask dad to pick me up at:['SPACY:POS-ADP'] 6:['SPACY:POS-NUM'] ...
# -------------------------
# [MATCH]: Those cocksuckers . If it makes you feel better ipads are worthless garbage novelty items and you should feel bad for:['SPACY:POS-ADP'] even wanting one:['SPACY:POS-NUM']
# -------------------------
# ==================================================
# 100%|██████████| 5/5 [00:04<00:00,  1.20it/s]
# Length 5 / 5; New candidates = 994
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Metric (global) = 0.223
# Examples ~ Class Negative:
# [MATCH]: Your opinion about me ? 1:['SPACY:POS-NUM'] . Over 2 . Jada 3 . Kusruthi 4 . Lovable 5 . Silent 6 . Spl character 7 . Not matured 8 . Stylish 9 . Simple Pls reply ..
# -------------------------
# [MATCH]: Yup i thk cine is better cos no need 2:['SPACY:POS-NUM'] go down 2 plaza mah .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: 1st wk FREE ! Gr8 tones str8 2:['SPACY:POS-NUM'] u each wk . Txt NOKIA ON to 8007 for Classic Nokia tones or HIT ON to 8007 for Polys . Nokia/150p Poly/200p 16 +
# -------------------------
# [MATCH]: Guess who am I?This is the first time I created a web page WWW.ASJESUS.COM read all I wrote . I 'm waiting for your opinions . I want to be your friend 1/1:['SPACY:POS-NUM']
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.806
# Match: 319 (8.9%)
# Gain = 0.175
# Metric (global) = 0.175
# Examples ~ Class Positive:
# [MATCH]: WINNER ! ! As a valued network customer you have been selected to receivea Â£900 prize reward ! To claim call 09061701461 . Claim code KL341:['SPACY:POS-PROPN'] . Valid 12:['SPACY:POS-NUM'] hours only .
# -------------------------
# [MATCH]: Dear Dave this is your final notice to collect your 4 * Tenerife Holiday:['SPACY:POS-PROPN'] or # 5000:['SPACY:POS-NUM'] CASH award ! Call 09061743806 from landline . TCs SAE Box326 CW25WX 150ppm
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Eek that 's a lot of time especially since American Pie:['SPACY:POS-PROPN'] is like 8:['SPACY:POS-NUM'] minutes long . I ca n't stop singing it .
# -------------------------
# [MATCH]: 1Apple / Day = No Doctor:['SPACY:POS-PROPN'] . 1Tulsi:['SPACY:POS-NUM'] Leaf / Day = No Cancer . 1Lemon / Day = No Fat . 1Cup Milk / day = No Bone Problms 3 Litres Watr / Day = No Diseases Snd ths 2 Whom U Care .. :- )
# -------------------------
# ==================================================
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.984
# Match: 183 (5.1%)
# Gain = 0.152
# Metric (global) = 0.152
# Examples ~ Class Positive:
# [MATCH]: URGENT ! : Your Mobile No . was awarded a Â£2,000 Bonus Caller Prize on 02/09/03 ! This is our 2nd attempt to contact YOU ! Call:['TEXT:call'] 0871:['SPACY:POS-NUM'] - 872 - 9755 BOX95QU
# -------------------------
# [MATCH]: URGENT ! Your mobile No 077xxx WON a Â£2,000 Bonus Caller Prize on 02/06/03 ! This is the 2nd attempt to reach YOU ! Call:['TEXT:call'] 09066362206:['SPACY:POS-NUM'] ASAP ! BOX97N7QP , 150ppm
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I 'm in a movie . Call:['TEXT:call'] me 4:['SPACY:POS-NUM'] wat ?
# -------------------------
# [MATCH]: Yun ah.the ubi one say if Ã¼ wan call:['TEXT:call'] by tomorrow.call 67441233:['SPACY:POS-NUM'] look for irene.ere only got bus8,22,65,61,66,382 . Ubi cres , ubi tech park.6ph for 1st 5wkg days . Ã¨n
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.579
# Match: 518 (14.5%)
# Gain = 0.148
# Metric (global) = 0.148
# Examples ~ Class Positive:
# [MATCH]: URGENT , IMPORTANT INFORMATION FOR O2 USER . TODAY IS YOUR LUCKY DAY ! 2 FIND OUT WHY LOG:['SPACY:POS-PROPN'] ONTO:['SPACY:POS-PROPN'] HTTP://WWW.URAWINNER.COM THERE IS A FANTASTIC SURPRISE AWAITING FOR YOU
# -------------------------
# [MATCH]: Text & meet someone sexy today . U can find a date or even flirt its up to U.:['SPACY:POS-PROPN'] Join:['SPACY:POS-PROPN'] 4 just 10p . REPLY with NAME & AGE eg Sam 25 . 18 -msg recd@thirtyeight pence
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: HIYA:['SPACY:POS-PROPN'] COMIN:['SPACY:POS-PROPN'] 2 BRISTOL 1 ST WEEK IN APRIL . LES GOT OFF + RUDI ON NEW YRS EVE BUT I WAS SNORING.THEY WERE DRUNK ! U BAK AT COLLEGE YET ? MY WORK SENDS INK 2 BATH .
# -------------------------
# [MATCH]: My Parents , My Kidz:['SPACY:POS-PROPN'] , My Friends:['SPACY:POS-PROPN'] n My Colleagues . All screaming .. SURPRISE ! ! and I was waiting on the sofa .. ... ..... ' NAKED ... !
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.613
# Match: 421 (11.8%)
# Gain = 0.129
# Metric (global) = 0.129
# Examples ~ Class Positive:
# [MATCH]: U are subscribed to the best Mobile Content Service in the UK for:['SPACY:POS-ADP'] Â£3 per 10:['SPACY:POS-NUM'] days until you send STOP to 82324 . Helpline 08706091795
# -------------------------
# [MATCH]: Will u meet ur dream partner soon ? Is ur:['SPACY:POS-ADP'] career off 2:['SPACY:POS-NUM'] a flyng start ? 2 find out free , txt HORO followed by ur star sign , e. g. HORO ARIES
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: The battery is for:['SPACY:POS-ADP'] mr:['SPACY:POS-NUM'] adewale my uncle . Aka Egbon
# -------------------------
# [MATCH]: Hey . What happened ? U switch off ur:['SPACY:POS-ADP'] cell d:['SPACY:POS-NUM'] whole day . This is nt good . Now if u do care , give me a call tomorrow .
# -------------------------
# ==================================================

# %%
# Print the learned patterns
for idx, p in enumerate(the_patterns):
    print(f'Rank {idx+1}')
    print(p)
# Out:
# Rank 1
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Metric (global) = 0.223
# Examples ~ Class Negative:
# [MATCH]: Not planned yet : ) going to join company on jan 5:['SPACY:POS-NUM'] only.don know what will happen after that .
# -------------------------
# [MATCH]: Ard 6:['SPACY:POS-NUM'] like dat lor .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: sexy sexy cum and text me i m wet and warm and ready for some porn ! u up for some fun ? THIS MSG IS FREE RECD MSGS 150P INC VAT 2:['SPACY:POS-NUM'] CANCEL TEXT STOP
# -------------------------
# [MATCH]: Someone has contacted our dating service and entered your phone because they fancy you ! To find out who it is call from a landline 09111032124:['SPACY:POS-NUM'] . PoBox12n146tf150p
# -------------------------
# ==================================================
# Rank 2
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.806
# Match: 319 (8.9%)
# Gain = 0.175
# Metric (global) = 0.175
# Examples ~ Class Positive:
# [MATCH]: 1000 's flirting NOW ! Txt GIRL or BLOKE & ur NAME & AGE , eg GIRL:['SPACY:POS-PROPN'] ZOE 18:['SPACY:POS-NUM'] to 8007 to join and get chatting !
# -------------------------
# [MATCH]: You are a winner U have been specially selected 2 receive Â£1000 or a 4 * holiday ( flights inc ) speak to a live operator 2 claim 0871277810910p / min:['SPACY:POS-PROPN'] ( 18:['SPACY:POS-NUM'] + )
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Solve d Case : A Man Was Found Murdered On   & lt;DECIMAL&gt ; . & lt;#&gt ;   AfterNoon:['SPACY:POS-PROPN'] . 1,His:['SPACY:POS-NUM'] wife called Police . 2,Police questioned everyone . 3,Wife : Sir , I was sleeping , when the murder took place . 4.Cook : I was cooking . 5.Gardener : I was picking vegetables . 6.House - Maid : I went 2 d post office . 7.Children : We went 2 play . 8.Neighbour : We went 2 a marriage . Police arrested d murderer Immediately . Who 's It ? Reply With Reason , If U r Brilliant .
# -------------------------
# [MATCH]: I got ta collect da:['SPACY:POS-PROPN'] car at 6:['SPACY:POS-NUM'] lei .
# -------------------------
# ==================================================
# Rank 3
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.984
# Match: 183 (5.1%)
# Gain = 0.152
# Metric (global) = 0.152
# Examples ~ Class Positive:
# [MATCH]: we tried to contact you re your response to our offer of a new nokia fone and camcorder hit reply or call:['TEXT:call'] 08000930705:['SPACY:POS-NUM'] for delivery
# -------------------------
# [MATCH]: Congrats ! 2 mobile 3 G Videophones R yours . call:['TEXT:call'] 09061744553:['SPACY:POS-NUM'] now ! videochat wid ur mates , play java games , Dload polyH music , noline rentl . bx420 . ip4 . 5we . 150pm
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Yun ah.the ubi one say if Ã¼ wan call:['TEXT:call'] by tomorrow.call 67441233:['SPACY:POS-NUM'] look for irene.ere only got bus8,22,65,61,66,382 . Ubi cres , ubi tech park.6ph for 1st 5wkg days . Ã¨n
# -------------------------
# [MATCH]: Ummma.will call:['TEXT:call'] after check in.our:['SPACY:POS-NUM'] life will begin from qatar so pls pray very hard .
# -------------------------
# ==================================================
# Rank 4
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.579
# Match: 518 (14.5%)
# Gain = 0.148
# Metric (global) = 0.148
# Examples ~ Class Positive:
# [MATCH]: FreeMsg:['SPACY:POS-PROPN'] Hey:['SPACY:POS-PROPN'] U , i just got 1 of these video / pic fones , reply WILD to this txt & ill send U my pics , hurry up I m so bored at work xxx ( 18 150p / rcvd STOP2stop )
# -------------------------
# [MATCH]: Moby:['SPACY:POS-PROPN'] Pub:['SPACY:POS-PROPN'] Quiz . Win a Â£100 High Street prize if u know who the new Duchess of Cornwall will be ? Txt her first name to 82277.unsub STOP Â£1.50 008704050406 SP Arrow
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: YO:['SPACY:POS-PROPN'] YO:['SPACY:POS-PROPN'] YO BYATCH WHASSUP ?
# -------------------------
# [MATCH]: Nowadays people are notixiquating the laxinorficated opportunity for bambling of entropication .... Have you ever oblisingately opted ur books for the masteriastering amplikater of fidalfication ? It is very champlaxigating , i think it is atrocious .. Wotz:['SPACY:POS-PROPN'] Ur:['SPACY:POS-PROPN'] Opinion ? ? ? ? Junna
# -------------------------
# ==================================================
# Rank 5
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.613
# Match: 421 (11.8%)
# Gain = 0.129
# Metric (global) = 0.129
# Examples ~ Class Positive:
# [MATCH]: FREE for 1st week ! No1 Nokia tone 4 ur mobile every week just txt NOKIA to:['SPACY:POS-ADP'] 8077:['SPACY:POS-NUM'] Get txting and tell ur mates . www.getzed.co.uk POBox 36504 W45WQ 16 + norm150p / tone
# -------------------------
# [MATCH]: WIN a year supply of:['SPACY:POS-ADP'] CDs 4:['SPACY:POS-NUM'] a store of ur choice worth Â£500 & enter our Â£100 Weekly draw txt MUSIC to 87066 Ts&Cs www . Ldew.com.subs16 + 1win150ppmx3
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: We are pleased to inform that your application for Airtel Broadband is processed successfully . Your installation will happen within:['SPACY:POS-ADP'] 3:['SPACY:POS-NUM'] days .
# -------------------------
# [MATCH]: Pls ask macho how much is budget for:['SPACY:POS-ADP'] bb bold 2:['SPACY:POS-NUM'] is cos i saw a new one for   & lt;#&gt ;   dollars .
# -------------------------
# ==================================================
# Rank 6
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.811
# Match: 243 (6.8%)
# Gain = 0.129
# Metric (global) = 0.129
# Examples ~ Class Positive:
# [MATCH]: HOT LIVE FANTASIES call now 08707509020 Just 20p:['SPACY:POS-NUM'] per min NTT:['SPACY:POS-PROPN'] Ltd , PO Box 1327 Croydon CR9 5WB 0870 is a national rate call
# -------------------------
# [MATCH]: You 've won tkts to the EURO2004 CUP FINAL or Â£800 CASH , to collect CALL 09058099801:['SPACY:POS-NUM'] b4190604:['SPACY:POS-PROPN'] , POBOX 7876150ppm
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: FR'NDSHIP is like a needle of a clock . Though V r in d same clock , V r nt able 2 met . Evn if V meet , itz only 4few:['SPACY:POS-NUM'] seconds . Bt:['SPACY:POS-PROPN'] V alwys stay conected . Gud 9t;- )
# -------------------------
# [MATCH]: Hi Jon , Pete here , I ve bin 2:['SPACY:POS-NUM'] Spain:['SPACY:POS-PROPN'] recently & hav sum dinero left , Bill said u or ur Â‘rents mayb interested in it , I hav 12,000pes , so around Â£48 , tb , James .
# -------------------------
# ==================================================
# Rank 7
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Negative
# Precision: 0.526
# Match: 644 (18.1%)
# Gain = 0.119
# Metric (global) = 0.119
# Examples ~ Class Negative:
# [MATCH]: excellent . I spent   & lt;#&gt ;   years:['SPACY:POS-NOUN'] in the Air:['SPACY:POS-PROPN'] Force . Iraq and afghanistan . I am stable and honest . do you like traveling ?
# -------------------------
# [MATCH]: Wen ur lovable bcums:['SPACY:POS-NOUN'] angry wid u:['SPACY:POS-PROPN'] , dnt take it seriously .. Coz being angry is d most childish n true way of showing deep affection , care n luv ! .. kettoda manda ... Have nice day da .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Free msg : Single ? Find a partner in your area ! 1000s of real people are waiting to chat now!Send CHAT to 62220Cncl send:['SPACY:POS-NOUN'] STOPCS:['SPACY:POS-PROPN'] 08717890890Â£1.50 per msg
# -------------------------
# [MATCH]: Warner Village 83118 C Colin Farrell in SWAT this wkend:['SPACY:POS-NOUN'] @Warner:['SPACY:POS-PROPN'] Village & get 1 free med . Popcorn!Just show msg+ticket@kiosk . Valid 4 - 7/12 . C t&c @kiosk . Reply SONY 4 mre film offers
# -------------------------
# ==================================================
# Rank 8
# Pattern: [['TEXT:to'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.856
# Match: 194 (5.4%)
# Gain = 0.114
# Metric (global) = 0.114
# Examples ~ Class Positive:
# [MATCH]: Ur cash - balance is currently 500 pounds - to maximize ur cash - in now send COLLECT to:['TEXT:to'] 83600:['SPACY:POS-NUM'] only 150p / msg . CC : 08718720201 PO BOX 114/14 TCR / W1
# -------------------------
# [MATCH]: UR GOING 2 BAHAMAS ! CallFREEFONE 08081560665 and speak to a live operator to claim either Bahamas cruise ofÂ£2000 CASH 18+only . To opt out txt X to:['TEXT:to'] 07786200117:['SPACY:POS-NUM']
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Sorry about earlier . Putting out fires . Are you around to:['TEXT:to'] talk after 9:['SPACY:POS-NUM'] ? Or do you actually have a life , lol !
# -------------------------
# [MATCH]: Say this slowly . ? GOD , I LOVE YOU & amp ; I NEED YOU , CLEAN MY HEART WITH YOUR BLOOD.Send this to:['TEXT:to'] Ten:['SPACY:POS-NUM'] special people & amp ; u c miracle tomorrow , do it , pls , pls do it ...
# -------------------------
# ==================================================
# Rank 9
# Pattern: [['SPACY:POS-PROPN']]
# Window size: 3
# Class: Negative
# Precision: 0.690
# Match: 1347 (37.8%)
# Gain = 0.112
# Metric (global) = 0.112
# Examples ~ Class Negative:
# [MATCH]: Jus:['SPACY:POS-PROPN'] came back fr lunch wif my sis only . U leh ?
# -------------------------
# [MATCH]: 8 at the latest , g:['SPACY:POS-PROPN'] 's still there if you can scrounge up some ammo and want to give the new ak a try
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Do you want a new Video handset ? 750 any time any network mins ? UNLIMITED TEXT ? Camcorder:['SPACY:POS-PROPN'] ? Reply or Call now 08000930705 for del Sat AM
# -------------------------
# [MATCH]: WINNER:['SPACY:POS-PROPN'] ! As a valued network customer you hvae been selected to receive a Â£900 reward ! To collect call 09061701444 . Valid 24 hours only . ACL03530150PM
# -------------------------
# ==================================================
# Rank 10
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.702
# Match: 272 (7.6%)
# Gain = 0.105
# Metric (global) = 0.105
# Examples ~ Class Positive:
# [MATCH]: No 1 POLYPHONIC tone 4 ur mob every week ! Just txt PT2 to 87575 . 1st Tone FREE ! so get txtin now and tell ur friends . 150p / tone . 16 reply:['SPACY:POS-NOUN'] HL:['SPACY:POS-NOUN'] 4info:['SPACY:POS-NUM']
# -------------------------
# [MATCH]: Great NEW Offer - DOUBLE Mins & DOUBLE Txt on best Orange tariffs AND get latest camera:['SPACY:POS-NOUN'] phones:['SPACY:POS-NOUN'] 4:['SPACY:POS-NUM'] FREE ! Call MobileUpd8 free on 08000839402 NOW ! or 2stoptxt T&Cs
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Just gettin a bit arty with my collages at the mo:['SPACY:POS-NOUN'] , well tryin:['SPACY:POS-NOUN'] 2:['SPACY:POS-NUM'] ne way ! Got a roast in a min lovely i shall enjoy that !
# -------------------------
# [MATCH]: I m sorry bout last nite it wasnÂ’t ur fault it was me , spouse it was pmt or sumthin:['SPACY:POS-NOUN'] ! U:['SPACY:POS-NOUN'] 4give:['SPACY:POS-NUM'] me ? I think u shldxxxx
# -------------------------
# ==================================================
# Rank 11
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 5
# Class: Positive
# Precision: 0.722
# Match: 255 (7.1%)
# Gain = 0.104
# Metric (global) = 0.104
# Examples ~ Class Positive:
# [MATCH]: Do you want a New:['SPACY:POS-PROPN'] Nokia:['SPACY:POS-PROPN'] 3510i Colour:['SPACY:POS-PROPN'] Phone Delivered Tomorrow ? With 200 FREE minutes to any mobile + 100 FREE text + FREE camcorder Reply or Call 8000930705
# -------------------------
# [MATCH]: YOU ARE CHOSEN TO RECEIVE A:['SPACY:POS-PROPN'] Â£350:['SPACY:POS-PROPN'] AWARD:['SPACY:POS-PROPN'] ! Pls call claim number 09066364311 to collect your award which you are selected to receive as a valued mobile customer .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Hey ! I want you ! I crave you ! I miss you ! I need you ! I love you , Ahmad:['SPACY:POS-PROPN'] Saeed:['SPACY:POS-PROPN'] al:['SPACY:POS-PROPN'] Hallaq ...
# -------------------------
# [MATCH]: Nothing , smsing u n xy lor . Sorry lor da:['SPACY:POS-PROPN'] guys neva:['SPACY:POS-PROPN'] c:['SPACY:POS-PROPN'] u in person but they sort of know u lor . So u wan 2 meet them xy ask me 2 bring u along 4 our next meeting .
# -------------------------
# ==================================================
# Rank 12
# Pattern: [['TEXT:.'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.797
# Match: 202 (5.7%)
# Gain = 0.101
# Metric (global) = 0.101
# Examples ~ Class Positive:
# [MATCH]: Today 's Offer ! Claim ur Â£150 worth of discount vouchers ! Text YES to 85023 now ! SavaMob , member offers mobile ! T Cs 08717898035 . Â£3.00 Sub .:['TEXT:.'] 16:['SPACY:POS-NUM'] . Unsub reply X
# -------------------------
# [MATCH]: Please call Amanda with regard to renewing or upgrading your current T - Mobile handset free of charge . Offer ends today .:['TEXT:.'] Tel 0845:['SPACY:POS-NUM'] 021 3680 subject to T 's and C 's
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I 'm in a movie .:['TEXT:.'] Call me 4:['SPACY:POS-NUM'] wat ?
# -------------------------
# [MATCH]: Solve d Case : A Man Was Found Murdered On   & lt;DECIMAL&gt ; . & lt;#&gt ;   AfterNoon .:['TEXT:.'] 1,His:['SPACY:POS-NUM'] wife called Police . 2,Police questioned everyone . 3,Wife : Sir , I was sleeping , when the murder took place . 4.Cook : I was cooking . 5.Gardener : I was picking vegetables . 6.House - Maid : I went 2 d post office . 7.Children : We went 2 play . 8.Neighbour : We went 2 a marriage . Police arrested d murderer Immediately . Who 's It ? Reply With Reason , If U r Brilliant .
# -------------------------
# ==================================================
# Rank 13
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.735
# Match: 238 (6.7%)
# Gain = 0.100
# Metric (global) = 0.100
# Examples ~ Class Positive:
# [MATCH]: Download as many ringtones as u like no restrictions , 1000s:['SPACY:POS-NUM'] 2:['SPACY:POS-NUM'] choose . U can even send 2 yr buddys . Txt Sir to 80082 Â£3
# -------------------------
# [MATCH]: Ur cash - balance is currently 500 pounds - to maximize ur cash - in now send GO to 86688:['SPACY:POS-NUM'] only 150p:['SPACY:POS-NUM'] / meg . CC : 08718720201 HG / Suite342/2lands Row / W1j6HL
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Rose for red , red for blood , blood for heart , heart for u. But u for me .... Send tis to all ur friends .. Including me .. If u like me .. If u get back , 1-u r poor in relation ! 2-u:['SPACY:POS-NUM'] need some 1:['SPACY:POS-NUM'] to support 3-u r frnd 2 many 4-some1 luvs u 5 + - some1 is praying god to marry u.:- ) try it ....
# -------------------------
# [MATCH]: V nice ! Off 2:['SPACY:POS-NUM'] sheffield tom 2:['SPACY:POS-NUM'] air my opinions on categories 2 b used 2 measure ethnicity in next census . Busy transcribing . :-)
# -------------------------
# ==================================================
# Rank 14
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
# Window size: 4
# Class: Negative
# Precision: 0.585
# Match: 714 (20.0%)
# Gain = 0.095
# Metric (global) = 0.095
# Examples ~ Class Negative:
# [MATCH]: 1 ) Go to write msg 2 ) Put on Dictionary:['SPACY:POS-PROPN'] mode:['SPACY:POS-NOUN'] 3)Cover the screen with hand , 4)Press   & lt;#&gt ; . 5)Gently remove Ur hand .. Its interesting .. : )
# -------------------------
# [MATCH]: Wen:['SPACY:POS-PROPN'] ur lovable bcums:['SPACY:POS-NOUN'] angry wid u , dnt take it seriously .. Coz being angry is d most childish n true way of showing deep affection , care n luv ! .. kettoda manda ... Have nice day da .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: 5p 4 alfie Moon:['SPACY:POS-PROPN'] 's Children:['SPACY:POS-NOUN'] in need song on ur mob . Tell ur m8s . Txt Tone charity to 8007 for Nokias or Poly charity for polys : zed 08701417012 profit 2 charity .
# -------------------------
# [MATCH]: U were outbid by simonwatson5120 on the Shinco DVD Plyr:['SPACY:POS-PROPN'] . 2 bid:['SPACY:POS-NOUN'] again , visit sms . ac / smsrewards 2 end bid notifications , reply END OUT
# -------------------------
# ==================================================
# Rank 15
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
# Window size: 4
# Class: Positive
# Precision: 0.597
# Match: 313 (8.8%)
# Gain = 0.085
# Metric (global) = 0.085
# Examples ~ Class Positive:
# [MATCH]: URGENT ! Your Mobile number has been awarded with a Â£2000 prize GUARANTEED . Call 09061790121:['SPACY:POS-NUM'] from:['SPACY:POS-ADP'] land line . Claim 3030 . Valid 12hrs only 150ppm
# -------------------------
# [MATCH]: Urgent ! Please call 09061743810:['SPACY:POS-NUM'] from:['SPACY:POS-ADP'] landline . Your ABTA complimentary 4 * Tenerife Holiday or # 5000 cash await collection SAE T&Cs Box 326 CW25WX 150 ppm
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: No dice , art class 6:['SPACY:POS-NUM'] thru:['SPACY:POS-ADP'] 9 :( thanks though . Any idea what time I should come tomorrow ?
# -------------------------
# [MATCH]: Thanx a lot 4:['SPACY:POS-NUM'] ur:['SPACY:POS-ADP'] help !
# -------------------------
# ==================================================
# Rank 16
# Pattern: [['SPACY:POS-ADJ'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.655
# Match: 258 (7.2%)
# Gain = 0.084
# Metric (global) = 0.084
# Examples ~ Class Positive:
# [MATCH]: No . 1 Nokia Tone 4 ur mob every week ! Just txt:['SPACY:POS-ADJ'] NOK to 87021:['SPACY:POS-NUM'] . 1st Tone FREE ! so get txtin now and tell ur friends . 150p / tone . 16 reply HL 4info
# -------------------------
# [MATCH]: Can U get 2 phone NOW ? I wanna chat 2 set up meet Call me NOW on 09096102316 U can cum here 2moro Luv:['SPACY:POS-ADJ'] JANE xx:['SPACY:POS-NUM'] CallsÂ£1/minmoremobsEMSPOBox45PO139WA
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Some are lasting as much:['SPACY:POS-ADJ'] as 2:['SPACY:POS-NUM'] hours . You might get lucky .
# -------------------------
# [MATCH]: they released another Italian:['SPACY:POS-ADJ'] one:['SPACY:POS-NUM'] today and it has a cosign option
# -------------------------
# ==================================================
# Rank 17
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
# Window size: 5
# Class: Positive
# Precision: 0.649
# Match: 259 (7.3%)
# Gain = 0.083
# Metric (global) = 0.083
# Examples ~ Class Positive:
# [MATCH]: Not heard from U4 a while . Call 4 rude chat private line 01223585334 to cum . Wan 2C pics of me gettin shagged then text PIX to 8552 . 2End send STOP:['SPACY:POS-PROPN'] 8552 SAM:['SPACY:POS-PROPN'] xxx:['SPACY:POS-NOUN']
# -------------------------
# [MATCH]: Congratulations U can claim 2 VIP row A Tickets 2 C:['SPACY:POS-PROPN'] Blu:['SPACY:POS-PROPN'] in concert:['SPACY:POS-NOUN'] in November or Blu gift guaranteed Call 09061104276 to claim TS&Cs www.smsco.net costÂ£3.75max
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Goodnight:['SPACY:POS-PROPN'] da:['SPACY:POS-PROPN'] thangam:['SPACY:POS-NOUN'] I really miss u dear .
# -------------------------
# [MATCH]: Gud:['SPACY:POS-PROPN'] ni8:['SPACY:POS-PROPN'] dear:['SPACY:POS-NOUN'] .. slp well .. take care .. swt dreams .. Muah ..
# -------------------------
# ==================================================
# Rank 18
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.926
# Match: 121 (3.4%)
# Gain = 0.082
# Metric (global) = 0.082
# Examples ~ Class Positive:
# [MATCH]: UR awarded a City Break and could WIN a Â£200 Summer Shopping spree every WK . Txt:['SPACY:POS-PROPN'] STORE to:['SPACY:POS-ADP'] 88039.SkilGme:['SPACY:POS-NUM'] . TsCs087147403231Winawk!Age16+Â£1.50perWKsub
# -------------------------
# [MATCH]: I do n't know u and u do n't know me . Send CHAT:['SPACY:POS-PROPN'] to:['SPACY:POS-ADP'] 86688:['SPACY:POS-NUM'] now and let 's find each other ! Only 150p / Msg rcvd . HG / Suite342/2Lands / Row / W1J6HL LDN . 18 years or over .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I got ta collect da:['SPACY:POS-PROPN'] car at:['SPACY:POS-ADP'] 6:['SPACY:POS-NUM'] lei .
# -------------------------
# [MATCH]: Eek that 's a lot of time especially since American:['SPACY:POS-PROPN'] Pie is like:['SPACY:POS-ADP'] 8:['SPACY:POS-NUM'] minutes long . I ca n't stop singing it .
# -------------------------
# ==================================================
# Rank 19
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]
# Window size: 4
# Class: Positive
# Precision: 0.504
# Match: 421 (11.8%)
# Gain = 0.080
# Metric (global) = 0.080
# Examples ~ Class Positive:
# [MATCH]: Congratulations U can claim 2 VIP row A Tickets 2 C:['SPACY:POS-PROPN'] Blu in:['SPACY:POS-ADP'] concert in November or Blu gift guaranteed Call 09061104276 to claim TS&Cs www.smsco.net costÂ£3.75max
# -------------------------
# [MATCH]: Spook up your mob with a Halloween:['SPACY:POS-PROPN'] collection of:['SPACY:POS-ADP'] a logo & pic message plus a free eerie tone , txt CARD SPOOK to 8007 zed 08701417012150p per logo / pic
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Gal n boy walking in d park . gal - can i hold ur hand ? boy - y ? do u think i would run away ? gal - no , jst wana c how it feels walking in heaven:['SPACY:POS-PROPN'] with:['SPACY:POS-ADP'] an prince .. GN:- )
# -------------------------
# [MATCH]: " AH POOR BABY!HOPE URFEELING BETTERSN LUV ! PROBTHAT OVERDOSE:['SPACY:POS-PROPN'] OF:['SPACY:POS-ADP'] WORK HEY GO CAREFUL SPK 2 U SN LOTS OF LOVEJEN XXX . "
# -------------------------
# ==================================================
# Rank 20
# Pattern: [['SPACY:POS-NUM'], ['TEXT:.']]
# Window size: 4
# Class: Positive
# Precision: 0.591
# Match: 286 (8.0%)
# Gain = 0.074
# Metric (global) = 0.074
# Examples ~ Class Positive:
# [MATCH]: URGENT . Important information for 02:['SPACY:POS-NUM'] user .:['TEXT:.'] Today is your lucky day ! 2 find out why , log onto http://www.urawinner.com there is a fantastic surprise awaiting you !
# -------------------------
# [MATCH]: Todays Voda numbers ending 5226 are selected to receive a ? 350:['SPACY:POS-NUM'] award .:['TEXT:.'] If you hava a match please call 08712300220 quoting claim code 1131 standard rates app
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: X course it 2yrs:['SPACY:POS-NUM'] .:['TEXT:.'] Just so her messages on messenger lik you r sending me
# -------------------------
# [MATCH]: Miserable . They do n't tell u that the side effects of birth control are massive gut wrenching cramps for the first 2:['SPACY:POS-NUM'] months .:['TEXT:.'] I did n't sleep at all last night .
# -------------------------
# ==================================================
# Rank 21
# Pattern: [['SPACY:POS-NOUN'], ['TEXT:call']]
# Window size: 4
# Class: Positive
# Precision: 0.791
# Match: 153 (4.3%)
# Gain = 0.073
# Metric (global) = 0.073
# Examples ~ Class Positive:
# [MATCH]: GENT ! We are trying to contact you . Last weekends draw shows that you won a Â£1000 prize:['SPACY:POS-NOUN'] GUARANTEED . Call:['TEXT:call'] 09064012160 . Claim Code K52 . Valid 12hrs only . 150ppm
# -------------------------
# [MATCH]: Todays Voda numbers ending with 7634 are selected to receive a Â£350 reward . If you have a match:['SPACY:POS-NOUN'] please call:['TEXT:call'] 08712300220 quoting claim code 7684 standard rates apply .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I 'm in a meeting:['SPACY:POS-NOUN'] , call:['TEXT:call'] me later at
# -------------------------
# [MATCH]: hi baby i m sat on the bloody bus at the mo and i wo nt be home until about 7:30 wanna do somethin:['SPACY:POS-NOUN'] later ? call:['TEXT:call'] me later ortxt back jess xx
# -------------------------
# ==================================================
# Rank 22
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.843
# Match: 127 (3.6%)
# Gain = 0.069
# Metric (global) = 0.069
# Examples ~ Class Positive:
# [MATCH]: Urgent ! call 09066350750 from your landline . Your complimentary 4 * Ibiza Holiday or 10,000 cash await collection SAE T&Cs PO BOX 434 SK3:['SPACY:POS-PROPN'] 8WP 150 ppm:['SPACY:POS-NOUN'] 18:['SPACY:POS-NUM'] +
# -------------------------
# [MATCH]: Urgent Please call 09066612661 from landline . Â£5000 cash or a luxury 4 * Canary Islands Holiday await collection . T&Cs:['SPACY:POS-PROPN'] SAE award:['SPACY:POS-NOUN'] . 20M12AQ:['SPACY:POS-NUM'] . 150ppm . 16 + â€œ
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I got ta collect da:['SPACY:POS-PROPN'] car:['SPACY:POS-NOUN'] at 6:['SPACY:POS-NUM'] lei .
# -------------------------
# [MATCH]: THANX4 TODAY CER:['SPACY:POS-PROPN'] IT:['SPACY:POS-NOUN'] WAS NICE 2:['SPACY:POS-NUM'] CATCH UP BUT WE AVE 2 FIND MORE TIME MORE OFTEN OH WELL TAKE CARE C U SOON.C
# -------------------------
# ==================================================
# Rank 23
# Pattern: [['TEXT:i']]
# Window size: 3
# Class: Negative
# Precision: 0.983
# Match: 1327 (37.2%)
# Gain = 0.067
# Metric (global) = 0.067
# Examples ~ Class Negative:
# [MATCH]: Ok then i:['TEXT:i'] will come to ur home after half an hour
# -------------------------
# [MATCH]: Hi this is yijue , can i:['TEXT:i'] meet u at 11 tmr ?
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Hi its LUCY Hubby at meetins all day Fri & I:['TEXT:i'] will B alone at hotel U fancy cumin over ? Pls leave msg 2day 09099726395 Lucy x CallsÂ£1/minMobsmoreLKPOBOX177HP51FL
# -------------------------
# [MATCH]: accordingly . I:['TEXT:i'] repeat , just text the word ok on your mobile phone and send
# -------------------------
# ==================================================
# Rank 24
# Pattern: [['SPACY:POS-SYM']]
# Window size: 3
# Class: Positive
# Precision: 0.756
# Match: 156 (4.4%)
# Gain = 0.067
# Metric (global) = 0.067
# Examples ~ Class Positive:
# [MATCH]: Dear 0776xxxxxxx U've been invited to XCHAT . This is our final attempt to contact u ! Txt CHAT to 86688 150p /:['SPACY:POS-SYM'] MsgrcvdHG / Suite342/2Lands / Row / W1J6HL LDN 18yrs
# -------------------------
# [MATCH]: Latest Nokia Mobile or iPOD MP3 Player + Â£400 proze GUARANTEED ! Reply with : WIN to 83355 now ! Norcorp Ltd . Â£1,50/Mtmsgrcvd18 +:['SPACY:POS-SYM']
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Rose for red , red for blood , blood for heart , heart for u. But u for me .... Send tis to all ur friends .. Including me .. If u like me .. If u get back , 1-u r poor in relation ! 2-u need some 1 to support 3-u r frnd 2 many 4-some1 luvs u:['SPACY:POS-SYM'] 5 + - some1 is praying god to marry u.:- ) try it ....
# -------------------------
# [MATCH]: Forgot you were working today ! Wanna chat , but things are ok so drop me a text when you 're free /:['SPACY:POS-SYM'] bored etc and i 'll ring . Hope all is well , nose essay and all xx
# -------------------------
# ==================================================
# Rank 25
# Pattern: [['TEXT:free']]
# Window size: 3
# Class: Positive
# Precision: 0.748
# Match: 159 (4.5%)
# Gain = 0.067
# Metric (global) = 0.067
# Examples ~ Class Positive:
# [MATCH]: FREE:['TEXT:free'] entry into our Â£250 weekly comp just send the word ENTER to 84128 NOW . 18 T&C www.textcomp.com cust care 08712405020 .
# -------------------------
# [MATCH]: sports fans - get the latest sports news str * 2 ur mobile 1 wk FREE:['TEXT:free'] PLUS a FREE TONE Txt SPORT ON to 8007 www.getzed.co.uk 0870141701216 + norm 4txt/120p
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Hmmm .. Thk sure got time to hop ard ... Ya , can go 4 free:['TEXT:free'] abt ... Muz call u to discuss liao ...
# -------------------------
# [MATCH]: Sir , i am waiting for your call , once free:['TEXT:free'] please call me .
# -------------------------
# ==================================================
# Rank 26
# Pattern: [['TEXT:txt']]
# Window size: 3
# Class: Positive
# Precision: 0.938
# Match: 96 (2.7%)
# Gain = 0.067
# Metric (global) = 0.067
# Examples ~ Class Positive:
# [MATCH]: Married local women looking for discreet action now ! 5 real matches instantly to your phone . Text MATCH to 69969 Msg cost 150p 2 stop txt:['TEXT:txt'] stop BCMSFWC1N3XX
# -------------------------
# [MATCH]: XXXMobileMovieClub : To use your credit , click the WAP link in the next txt:['TEXT:txt'] message or click here > > http://wap . xxxmobilemovieclub.com?n=QJKGIGHJJGCBL
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: On the road so ca nt txt:['TEXT:txt']
# -------------------------
# [MATCH]: Oh yes I can speak txt:['TEXT:txt'] 2 u no ! Hmm . Did u get   email ?
# -------------------------
# ==================================================
# Rank 27
# Pattern: [['SPACY:POS-NOUN'], ['TEXT:to']]
# Window size: 4
# Class: Negative
# Precision: 0.591
# Match: 552 (15.5%)
# Gain = 0.065
# Metric (global) = 0.065
# Examples ~ Class Negative:
# [MATCH]: This weekend is fine ( an excuse:['SPACY:POS-NOUN'] not to:['TEXT:to'] do too much decorating )
# -------------------------
# [MATCH]: No problem:['SPACY:POS-NOUN'] . Talk to:['TEXT:to'] you later
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Had your mobile 11mths ? Update:['SPACY:POS-NOUN'] for FREE to:['TEXT:to'] Oranges latest colour camera mobiles & unlimited weekend calls . Call Mobile Upd8 on freefone 08000839402 or 2StopTx
# -------------------------
# [MATCH]: URGENT ! Your Mobile No 07808726822 was awarded a Â£2,000 Bonus Caller Prize on 02/09/03 ! This is our 2nd attempt:['SPACY:POS-NOUN'] to:['TEXT:to'] contact YOU ! Call 0871 - 872 - 9758 BOX95QU
# -------------------------
# ==================================================
# Rank 28
# Pattern: [['TEXT:claim']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 77 (2.2%)
# Gain = 0.064
# Metric (global) = 0.064
# Examples ~ Class Positive:
# [MATCH]: URGENT ! Your Mobile number has been awarded with a Â£2000 prize GUARANTEED . Call 09058094455 from land line . Claim:['TEXT:claim'] 3030 . Valid 12hrs only
# -------------------------
# [MATCH]: Great News ! Call FREEFONE 08006344447 to claim:['TEXT:claim'] your guaranteed Â£1000 CASH or Â£2000 gift . Speak to a live operator NOW !
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Rank 29
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-ADP', 'TEXT:to']]
# Window size: 4
# Class: Positive
# Precision: 0.592
# Match: 250 (7.0%)
# Gain = 0.064
# Metric (global) = 0.064
# Examples ~ Class Positive:
# [MATCH]: Do you want a New Nokia 3510i Colour Phone Delivered Tomorrow ? With 200 FREE minutes:['SPACY:POS-NOUN'] to:['SPACY:POS-ADP', 'TEXT:to'] any mobile + 100 FREE text + FREE camcorder Reply or Call 8000930705
# -------------------------
# [MATCH]: Ur balance is now Â£600 . Next question : Complete the landmark , Big , A. Bob , B. Barry or C. Ben ? . Text A , B:['SPACY:POS-NOUN'] or C to:['SPACY:POS-ADP', 'TEXT:to'] 83738 . Good luck !
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: In fact when do you leave ? I think addie:['SPACY:POS-NOUN'] goes back to:['SPACY:POS-ADP', 'TEXT:to'] school tues or we d
# -------------------------
# [MATCH]: Rose for red , red for blood , blood for heart , heart for u. But u for me .... Send tis:['SPACY:POS-NOUN'] to:['SPACY:POS-ADP', 'TEXT:to'] all ur friends .. Including me .. If u like me .. If u get back , 1-u r poor in relation ! 2-u need some 1 to support 3-u r frnd 2 many 4-some1 luvs u 5 + - some1 is praying god to marry u.:- ) try it ....
# -------------------------
# ==================================================
# Rank 30
# Pattern: [['TEXT:!']]
# Window size: 3
# Class: Negative
# Precision: 0.602
# Match: 575 (16.1%)
# Gain = 0.063
# Metric (global) = 0.063
# Examples ~ Class Negative:
# [MATCH]: Looks like you found something to do other than smoke , great job !:['TEXT:!']
# -------------------------
# [MATCH]: Thank u !:['TEXT:!']
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: PRIVATE !:['TEXT:!'] Your 2003 Account Statement for 078
# -------------------------
# [MATCH]: This is the 2nd time we have tried 2 contact u. U have won the 750 Pound prize . 2 claim is easy , call 08712101358 NOW !:['TEXT:!'] Only 10p per min . BT - national - rate
# -------------------------
# ==================================================
# Rank 31
# Pattern: [['TEXT:.'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.539
# Match: 297 (8.3%)
# Gain = 0.062
# Metric (global) = 0.062
# Examples ~ Class Positive:
# [MATCH]: < Forwarded from 88877>FREE entry into our Â£250 weekly comp just send the word ENTER to 88877 NOW .:['TEXT:.'] 18 T&C:['SPACY:POS-PROPN'] www.textcomp.com
# -------------------------
# [MATCH]: 0A$NETWORKS allow companies to bill for SMS , so they are responsible for their " suppliers " , just as a shop has to give a guarantee on what they sell .:['TEXT:.'] B.:['SPACY:POS-PROPN'] G.
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Lol ok ill try to send .:['TEXT:.'] Be warned Sprint:['SPACY:POS-PROPN'] is dead slow . You 'll prolly get it tomorrow
# -------------------------
# [MATCH]: Height of Confidence : All the Aeronautics professors wer calld & amp ; they wer askd 2 sit in an aeroplane .:['TEXT:.'] Aftr:['SPACY:POS-PROPN'] they sat they wer told dat the plane ws made by their students . Dey all hurried out of d plane .. Bt only 1 did nt move ... He said:"if it is made by my students , this wo nt even start ........ Datz confidence ..
# -------------------------
# ==================================================
# Rank 32
# Pattern: [['SPACY:POS-PROPN'], ['TEXT:.']]
# Window size: 4
# Class: Positive
# Precision: 0.522
# Match: 312 (8.7%)
# Gain = 0.061
# Metric (global) = 0.061
# Examples ~ Class Positive:
# [MATCH]: URGENT ! Your Mobile number has been awarded a < UKP>2000:['SPACY:POS-PROPN'] prize GUARANTEED .:['TEXT:.'] Call 09061790125 from landline . Claim 3030 . Valid 12hrs only 150ppm
# -------------------------
# [MATCH]: LORD OF THE RINGS : RETURN OF THE KING in store NOW!REPLY LOTR by 2 June 4 Chance 2 WIN LOTR soundtrack CDs StdTxtRate:['SPACY:POS-PROPN'] .:['TEXT:.'] Reply STOP to end txts
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Pls send me the correct name da:['SPACY:POS-PROPN'] .:['TEXT:.']
# -------------------------
# [MATCH]: She is our sister .. She belongs 2 our family .. She is d hope of tomorrow .. Pray 4 her , who was fated 4 d Shoranur:['SPACY:POS-PROPN'] train incident .:['TEXT:.'] Lets hold our hands together & amp ; fuelled by love & amp ; concern prior 2 her grief & amp ; pain . Pls join in dis chain & amp ; pass it . STOP VIOLENCE AGAINST WOMEN .
# -------------------------
# ==================================================
# Rank 33
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 5
# Class: Positive
# Precision: 0.624
# Match: 213 (6.0%)
# Gain = 0.061
# Metric (global) = 0.061
# Examples ~ Class Positive:
# [MATCH]: PRIVATE ! Your 2003 Account Statement for < fone no > shows 800 un - redeemed S. I. M. points . Call:['SPACY:POS-NOUN'] 08715203656 Identifier:['SPACY:POS-PROPN'] Code:['SPACY:POS-PROPN'] : 42049 Expires 26/10/04
# -------------------------
# [MATCH]: PRIVATE ! Your 2003 Account Statement for shows 800 un - redeemed S. I. M. points . Call:['SPACY:POS-NOUN'] 08718738002 Identifier:['SPACY:POS-PROPN'] Code:['SPACY:POS-PROPN'] : 48922 Expires 21/11/04
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: THATÂ:['SPACY:POS-NOUN'] ’S ALRITE:['SPACY:POS-PROPN'] GIRL:['SPACY:POS-PROPN'] , U KNOW GAIL IS NEVA WRONG!!TAKE CARE SWEET AND DONÂ’T WORRY.C U L8TR HUN!LOVE Yaxxx
# -------------------------
# [MATCH]: Alrite jod how s the revision:['SPACY:POS-NOUN'] goin ? Keris:['SPACY:POS-PROPN'] bin:['SPACY:POS-PROPN'] doin a smidgin . N e way u wanna cum over after college?xx
# -------------------------
# ==================================================
# Rank 34
# Pattern: [['TEXT:mobile']]
# Window size: 3
# Class: Positive
# Precision: 0.942
# Match: 86 (2.4%)
# Gain = 0.060
# Metric (global) = 0.060
# Examples ~ Class Positive:
# [MATCH]: URGENT ! : Your Mobile:['TEXT:mobile'] No . was awarded a Â£2,000 Bonus Caller Prize on 02/09/03 ! This is our 2nd attempt to contact YOU ! Call 0871 - 872 - 9755 BOX95QU
# -------------------------
# [MATCH]: T - Mobile:['TEXT:mobile'] customer you may now claim your FREE CAMERA PHONE upgrade & a pay & go sim card for your loyalty . Call on 0845 021 3680.Offer ends 28thFeb . T&C 's apply
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Hi , Mobile:['TEXT:mobile'] no .   & lt;#&gt ;   has added you in their contact list on www.fullonsms.com It s a great place to send free sms to people For more visit fullonsms.com
# -------------------------
# [MATCH]: Plz note : if anyone calling from a mobile:['TEXT:mobile'] Co. & amp ; asks u to type # & lt;#&gt ;   or # & lt;#&gt ; . Do not do so . Disconnect the call , coz it iz an attempt of ' terrorist ' to make use of the sim card no . Itz confirmd by nokia n motorola n has been verified by CNN IBN .
# -------------------------
# ==================================================
# Rank 35
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
# Window size: 5
# Class: Positive
# Precision: 0.591
# Match: 235 (6.6%)
# Gain = 0.060
# Metric (global) = 0.060
# Examples ~ Class Positive:
# [MATCH]: FREE > Ringtone:['SPACY:POS-NOUN'] ! Reply:['SPACY:POS-NOUN'] REAL:['SPACY:POS-PROPN'] or POLY eg REAL1 1 . PushButton 2 . DontCha 3 . BabyGoodbye 4 . GoldDigger 5 . WeBeBurnin 1st tone FREE and 6 more when u join for Â£3/wk
# -------------------------
# [MATCH]: Urgent ! Please call 09061213237 from a landline . Â£5000 cash or a 4 * holiday:['SPACY:POS-NOUN'] await:['SPACY:POS-NOUN'] collection . T:['SPACY:POS-PROPN'] & Cs SAE PO Box 177 M227XY . 16 +
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Yeah if we do have to get a random dude we need to change our info:['SPACY:POS-NOUN'] sheets:['SPACY:POS-NOUN'] to PARTY:['SPACY:POS-PROPN']   & lt;#&gt ; /7 NEVER STUDY just to be safe
# -------------------------
# [MATCH]: I love you . You set my soul on fire . It is not just a spark . But it is a flame . A big rawring:['SPACY:POS-NOUN'] flame:['SPACY:POS-NOUN'] . XoXo:['SPACY:POS-PROPN']
# -------------------------
# ==================================================
# Rank 36
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]
# Window size: 5
# Class: Positive
# Precision: 0.739
# Match: 142 (4.0%)
# Gain = 0.058
# Metric (global) = 0.058
# Examples ~ Class Positive:
# [MATCH]: URGENT ! We are trying to contact U.:['SPACY:POS-PROPN'] Todays:['SPACY:POS-PROPN'] draw shows that:['SPACY:POS-ADP'] you have won a Â£800 prize GUARANTEED . Call 09050001808 from land line . Claim M95 . Valid12hrs only
# -------------------------
# [MATCH]: Had your mobile 10 mths ? Update to the latest Camera:['SPACY:POS-PROPN'] / Video:['SPACY:POS-PROPN'] phones for:['SPACY:POS-ADP'] FREE . KEEP UR SAME NUMBER , Get extra free mins / texts . Text YES for a call
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: WE REGRET TO INFORM:['SPACY:POS-PROPN'] U:['SPACY:POS-PROPN'] THAT:['SPACY:POS-ADP'] THE NHS HAS MADE A MISTAKE.U WERE NEVER ACTUALLY BORN.PLEASE REPORT 2 YOR LOCAL HOSPITAL 2B TERMINATED.WE R SORRY 4 THE INCONVENIENCE
# -------------------------
# [MATCH]: Wishing you and your family Merry " X " mas and HAPPY:['SPACY:POS-PROPN'] NEW:['SPACY:POS-PROPN'] Year in:['SPACY:POS-ADP'] advance ..
# -------------------------
# ==================================================
# Rank 37
# Pattern: [['SPACY:POS-ADJ'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Negative
# Precision: 0.530
# Match: 368 (10.3%)
# Gain = 0.057
# Metric (global) = 0.057
# Examples ~ Class Negative:
# [MATCH]: â€:['SPACY:POS-ADJ'] ¦:['SPACY:POS-PROPN'] and donâ€˜t worry weâ€˜ll have finished by march â€ ¦ ish !
# -------------------------
# [MATCH]: 7 wonders in My WORLD 7th You 6th:['SPACY:POS-ADJ'] Ur:['SPACY:POS-PROPN'] style 5th Ur smile 4th Ur Personality 3rd Ur Nature 2nd Ur SMS and 1st " Ur Lovely Friendship " ... good morning dear
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: 8007 FREE for 1st:['SPACY:POS-ADJ'] week ! No1:['SPACY:POS-PROPN'] Nokia tone 4 ur mob every week just txt NOKIA to 8007 Get txting and tell ur mates www.getzed.co.uk POBox 36504 W4 5WQ norm 150p / tone 16 +
# -------------------------
# [MATCH]: Hi babe its:['SPACY:POS-ADJ'] Chloe:['SPACY:POS-PROPN'] , how r u ? I was smashed on saturday night , it was great ! How was your weekend ? U been missing me ? SP visionsms.com Text stop to stop 150p / text
# -------------------------
# ==================================================
# Rank 38
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-ADJ']]
# Window size: 4
# Class: Positive
# Precision: 0.559
# Match: 245 (6.9%)
# Gain = 0.055
# Metric (global) = 0.055
# Examples ~ Class Positive:
# [MATCH]: Todays Voda numbers ending with 7634 are selected to receive a Â£350 reward . If you have a match please call 08712300220 quoting claim code 7684:['SPACY:POS-NUM'] standard:['SPACY:POS-ADJ'] rates apply .
# -------------------------
# [MATCH]: Shop till u Drop , IS IT YOU , either 10 K , 5 K , Â£500 Cash or Â£100 Travel voucher , Call now , 09064011000 . NTT PO Box CR01327BT fixedline Cost 150ppm:['SPACY:POS-NUM'] mobile:['SPACY:POS-ADJ'] vary
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Huh but i ca nt go 2:['SPACY:POS-NUM'] ur house empty:['SPACY:POS-ADJ'] handed right ?
# -------------------------
# [MATCH]: Kate jackson rec center before 7ish:['SPACY:POS-NUM'] , right:['SPACY:POS-ADJ'] ?
# -------------------------
# ==================================================
# Rank 39
# Pattern: [['SENTIMENT:pos'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.542
# Match: 260 (7.3%)
# Gain = 0.054
# Metric (global) = 0.054
# Examples ~ Class Positive:
# [MATCH]: Congrats ! 1 year special cinema pass for 2 is yours . call 09061209465 now ! C Suprman V , Matrix3 , StarWars3 , etc all 4 FREE:['SENTIMENT:pos'] ! bx420-ip4:['SPACY:POS-PROPN'] - 5we . 150pm . Do nt miss out !
# -------------------------
# [MATCH]: We tried to call you re your reply to our sms for a video mobile 750 mins UNLIMITED TEXT free:['SENTIMENT:pos'] camcorder Reply:['SPACY:POS-PROPN'] or call now 08000930705 Del Thurs
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: That 's good . Lets thank:['SENTIMENT:pos'] God:['SPACY:POS-PROPN'] . Please complete the drug . Have lots of water . And have a beautiful day .
# -------------------------
# [MATCH]: Wa ... U so efficient:['SENTIMENT:pos'] ... Gee:['SPACY:POS-PROPN'] ... Thanx ...
# -------------------------
# ==================================================
# Rank 40
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.802
# Match: 111 (3.1%)
# Gain = 0.053
# Metric (global) = 0.053
# Examples ~ Class Positive:
# [MATCH]: Dear Dave this is your final notice to collect your 4 * Tenerife Holiday or # 5000 CASH award ! Call 09061743806 from landline . TCs:['SPACY:POS-NOUN'] SAE:['SPACY:POS-PROPN'] Box326 CW25WX 150ppm:['SPACY:POS-NUM']
# -------------------------
# [MATCH]: You have an important customer service announcement:['SPACY:POS-NOUN'] . Call FREEPHONE:['SPACY:POS-PROPN'] 0800:['SPACY:POS-NUM'] 542 0825 now !
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Height of Confidence : All the Aeronautics professors wer calld & amp ; they wer askd 2 sit in an aeroplane . Aftr they sat they wer told dat the plane ws made by their students . Dey all hurried out of d plane:['SPACY:POS-NOUN'] .. Bt:['SPACY:POS-PROPN'] only 1:['SPACY:POS-NUM'] did nt move ... He said:"if it is made by my students , this wo nt even start ........ Datz confidence ..
# -------------------------
# [MATCH]: Indians r poor but India is not a poor country . Says one of the swiss bank directors . He says that " & lt;#&gt ;   lac crore " of Indian money is deposited in swiss banks which can be used for ' taxless ' budget for   & lt;#&gt ;   yrs . Can give   & lt;#&gt ;   crore jobs to all Indians . From any village:['SPACY:POS-NOUN'] to Delhi:['SPACY:POS-PROPN'] 4:['SPACY:POS-NUM'] lane roads . Forever free power suply to more than   & lt;#&gt ;   social projects . Every citizen can get monthly   & lt;#&gt ; /- for   & lt;#&gt ;   yrs . No need of World Bank & amp ; IMF loan . Think how our money is blocked by rich politicians . We have full rights against corrupt politicians . Itna forward karo ki pura INDIA padhe.g.m . "
# -------------------------
# ==================================================
# Rank 41
# Pattern: [['TEXT:.'], ['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.985
# Match: 67 (1.9%)
# Gain = 0.053
# Metric (global) = 0.053
# Examples ~ Class Positive:
# [MATCH]: PRIVATE ! Your 2003 Account Statement for 07973788240 shows 800 un - redeemed S. I. M. points .:['TEXT:.'] Call:['TEXT:call'] 08715203649:['SPACY:POS-NUM'] Identifier Code : 40533 Expires 31/10/04
# -------------------------
# [MATCH]: This is the 2nd attempt to contract U , you have won this weeks top prize of either Â£1000 cash or Â£200 prize .:['TEXT:.'] Just call:['TEXT:call'] 09066361921:['SPACY:POS-NUM']
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I 'm in a movie .:['TEXT:.'] Call:['TEXT:call'] me 4:['SPACY:POS-NUM'] wat ?
# -------------------------
# ==================================================
# Rank 42
# Pattern: [['HYPERNYM:communication.n.02'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.923
# Match: 78 (2.2%)
# Gain = 0.052
# Metric (global) = 0.052
# Examples ~ Class Positive:
# [MATCH]: Congratulations ur awarded either Â£500 of CD gift vouchers & Free entry:['HYPERNYM:communication.n.02'] 2:['SPACY:POS-NUM'] our Â£100 weekly draw txt MUSIC to 87066 TnCs www . Ldew.com 1 win150ppmx3age16
# -------------------------
# [MATCH]: Todays Vodafone numbers:['HYPERNYM:communication.n.02'] ending with 4882:['SPACY:POS-NUM'] are selected to a receive a Â£350 award . If your number matches call 09064019014 to receive your Â£350 award .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Yup ... Ok i go home look at the timings then i msg Ã¼ again ... Xuhui going to learn on 2nd may too but her lesson:['HYPERNYM:communication.n.02'] is at 8:['SPACY:POS-NUM'] am
# -------------------------
# [MATCH]: Ask g or iouri , I 've told the story:['HYPERNYM:communication.n.02'] like ten:['SPACY:POS-NUM'] times already
# -------------------------
# ==================================================
# Rank 43
# Pattern: [['HYPERNYM:win.v.01', 'SENTIMENT:pos']]
# Window size: 3
# Class: Positive
# Precision: 0.922
# Match: 77 (2.2%)
# Gain = 0.051
# Metric (global) = 0.051
# Examples ~ Class Positive:
# [MATCH]: Buy Space Invaders 4 a chance 2 win:['SENTIMENT:pos', 'HYPERNYM:win.v.01'] orig Arcade Game console . Press 0 for Games Arcade ( std WAP charge ) See o2.co.uk/games 4 Terms + settings . No purchase
# -------------------------
# [MATCH]: You have WON:['SENTIMENT:pos', 'HYPERNYM:win.v.01'] a guaranteed Â£1000 cash or a Â£2000 prize . To claim yr prize call our customer service representative on 08714712412 between 10am-7pm Cost 10p
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: " Keep ur problems in ur heart , b'coz nobody will fight for u. Only u & amp ; u have to fight for ur self & amp ; win:['SENTIMENT:pos', 'HYPERNYM:win.v.01'] the battle . -VIVEKANAND- G 9 t .. SD ..
# -------------------------
# ...
# -------------------------
# [MATCH]: PRIVATE ! Your 2003 Account Statement for 07815296484 shows 800 un - redeemed S.I.M.:['SPACY:POS-PROPN'] points:['SPACY:POS-NOUN'] .:['TEXT:.'] Call 08718738001 Identifier Code 41782 Expires 18/11/04
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Tee:['SPACY:POS-PROPN'] hee:['SPACY:POS-NOUN'] .:['TEXT:.'] Off to lecture , cheery bye bye .
# -------------------------
# [MATCH]: Please da call me any mistake from my side sorry da . Pls da:['SPACY:POS-PROPN'] goto doctor:['SPACY:POS-NOUN'] .:['TEXT:.']
# -------------------------
# ==================================================
# Rank 87
# Pattern: [['SENTIMENT:pos'], ['TEXT:call']]
# Window size: 4
# Class: Positive
# Precision: 0.838
# Match: 74 (2.1%)
# Gain = 0.039
# Metric (global) = 0.039
# Examples ~ Class Positive:
# [MATCH]: Do you want a new Video phone ? 600 anytime any network mins 400 Inclusive Video calls AND downloads 5 per week Free:['SENTIMENT:pos'] delTOMORROW call:['TEXT:call'] 08002888812 or reply NOW
# -------------------------
# [MATCH]: Santa Calling ! Would your little ones like:['SENTIMENT:pos'] a call:['TEXT:call'] from Santa Xmas eve ? Call 09058094583 to book your time .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Good:['SENTIMENT:pos'] Morning plz call:['TEXT:call'] me sir
# -------------------------
# [MATCH]: I 'm at work:['SENTIMENT:pos'] . Please call:['TEXT:call']
# -------------------------
# ==================================================
# Rank 88
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.868
# Match: 68 (1.9%)
# Gain = 0.038
# Metric (global) = 0.038
# Examples ~ Class Positive:
# [MATCH]: YOUR CHANCE TO BE ON A REALITY FANTASY SHOW call now = 08707509020 Just 20p per min NTT Ltd , PO Box 1327:['SPACY:POS-NUM'] Croydon:['SPACY:POS-PROPN'] CR9 5WB:['SPACY:POS-NUM'] 0870 is a national = rate call .
# -------------------------
# [MATCH]: Your free ringtone is waiting to be collected . Simply text the password " MIX " to 85069 to verify . Get Usher and Britney . FML , PO Box 5249:['SPACY:POS-NUM'] , MK17:['SPACY:POS-PROPN'] 92H.:['SPACY:POS-NUM'] 450Ppw 16
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Your opinion about me ? 1 . Over 2:['SPACY:POS-NUM'] . Jada:['SPACY:POS-PROPN'] 3:['SPACY:POS-NUM'] . Kusruthi 4 . Lovable 5 . Silent 6 . Spl character 7 . Not matured 8 . Stylish 9 . Simple Pls reply ..
# -------------------------
# [MATCH]: HOW ARE U ? I HAVE MISSED U ! I HAVENT BEEN UP 2 MUCH A BIT BORED WITH THE HOLIDAY WANT 2:['SPACY:POS-NUM'] GO:['SPACY:POS-PROPN'] BAK 2:['SPACY:POS-NUM'] COLLEGE ! SAD ISNT IT?xx
# -------------------------
# ==================================================
# Rank 89
# Pattern: [['HYPERNYM:symbol.n.01']]
# Window size: 3
# Class: Positive
# Precision: 0.764
# Match: 89 (2.5%)
# Gain = 0.038
# Metric (global) = 0.038
# Examples ~ Class Positive:
# [MATCH]: PRIVATE ! Your 2003 Account Statement for 07815296484 shows 800 un - redeemed S.I.M. points . Call 08718738001 Identifier:['HYPERNYM:symbol.n.01'] Code 41782 Expires 18/11/04
# -------------------------
# [MATCH]: FREE MSG : We billed your mobile number:['HYPERNYM:symbol.n.01'] by mistake from shortcode 83332.Please call 08081263000 to have charges refunded . This call will be free from a BT landline
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Madam , regret disturbance.might receive a reference check:['HYPERNYM:symbol.n.01'] from DLF Premarica.kindly be informed . Rgds , Rakhesh , Kerala .
# -------------------------
# [MATCH]: ARR birthday today : ) i wish him to get more oscar:['HYPERNYM:symbol.n.01'] .
# -------------------------
# ==================================================
# Rank 90
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
# Window size: 5
# Class: Positive
# Precision: 0.543
# Match: 184 (5.2%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: Urgent Urgent ! We have 800 FREE flights to Europe to give away , call B4 10th Sept & take a friend 4 FREE . Call now to claim on:['SPACY:POS-ADP'] 09050000555:['SPACY:POS-NUM'] . BA128NNFWFLY150ppm:['SPACY:POS-NOUN']
# -------------------------
# [MATCH]: Call Germany for:['SPACY:POS-ADP'] only 1:['SPACY:POS-NUM'] pence:['SPACY:POS-NOUN'] per minute ! Call from a fixed line via access number 0844 861 85 85 . No prepayment . Direct access !
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Thk shld b can ... Ya , i wana go 4 lessons ... Haha , can go for:['SPACY:POS-ADP'] one:['SPACY:POS-NUM'] whole stretch:['SPACY:POS-NOUN'] ...
# -------------------------
# [MATCH]: Oic cos me n my sis got no lunch today my dad went out ... So dunno whether:['SPACY:POS-ADP'] 2:['SPACY:POS-NUM'] eat in sch:['SPACY:POS-NOUN'] or wat ...
# -------------------------
# ==================================================
# Rank 91
# Pattern: [['TEXT:!'], ['SPACY:POS-ADJ']]
# Window size: 4
# Class: Positive
# Precision: 0.648
# Match: 125 (3.5%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: Santa Calling !:['TEXT:!'] Would your:['SPACY:POS-ADJ'] little ones like a call from Santa Xmas eve ? Call 09058094583 to book your time .
# -------------------------
# [MATCH]: Sunshine Quiz Wkly Q !:['TEXT:!'] Win a top:['SPACY:POS-ADJ'] Sony DVD player if u know which country Liverpool played in mid week ? Txt ansr to 82277 . Â£1.50 SP : Tyrone
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: HEY GIRL . HOW R U ? HOPE U R WELL ME AN DEL R BAK !:['TEXT:!'] AGAIN LONG:['SPACY:POS-ADJ'] TIME NO C ! GIVE ME A CALL SUM TIME FROM LUCYxx
# -------------------------
# [MATCH]: Excellent !:['TEXT:!'] Are you ready:['SPACY:POS-ADJ'] to moan and scream in ecstasy ?
# -------------------------
# ==================================================
# Rank 92
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
# Window size: 6
# Class: Positive
# Precision: 0.914
# Match: 58 (1.6%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: PRIVATE ! Your 2003 Account Statement for < fone no > shows 800 un - redeemed S. I.:['SPACY:POS-PROPN'] M.:['SPACY:POS-PROPN'] points:['SPACY:POS-NOUN'] . Call 08715203656:['SPACY:POS-NUM'] Identifier Code : 42049 Expires 26/10/04
# -------------------------
# [MATCH]: URGENT ! Your mobile number * * * * * * * * * * * * * * * WON a Â£2000 Bonus:['SPACY:POS-PROPN'] Caller:['SPACY:POS-PROPN'] prize:['SPACY:POS-NOUN'] on 10/06/03:['SPACY:POS-NUM'] ! This is the 2nd attempt to reach you ! Call 09066368753 ASAP ! Box 97N7QP , 150ppm
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: HIYA:['SPACY:POS-PROPN'] STU:['SPACY:POS-PROPN'] WOT:['SPACY:POS-NOUN'] U UP 2.IM:['SPACY:POS-NUM'] IN SO MUCH TRUBLE AT HOME AT MOMENT EVONE HATES ME EVEN U ! WOT THE HELL AV I DONE NOW ? Y WONT U JUST TELL ME TEXT BCK PLEASE LUV DAN
# -------------------------
# [MATCH]: 1Apple / Day = No Doctor . 1Tulsi Leaf / Day = No Cancer . 1Lemon / Day = No Fat . 1Cup Milk / day = No Bone Problms 3 Litres Watr / Day = No Diseases:['SPACY:POS-PROPN'] Snd:['SPACY:POS-PROPN'] ths:['SPACY:POS-NOUN'] 2:['SPACY:POS-NUM'] Whom U Care .. :- )
# -------------------------
# ==================================================
# Rank 93
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-DET']]
# Window size: 4
# Class: Positive
# Precision: 0.634
# Match: 131 (3.7%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: Free 1st week entry 2:['SPACY:POS-NUM'] TEXTPOD 4 a:['SPACY:POS-DET'] chance 2 win 40 GB iPod or Â£250 cash every wk . Txt POD to 84128 Ts&Cs www.textpod.net custcare 08712405020 .
# -------------------------
# [MATCH]: FREE for 1st week ! No1 Nokia tone 4:['SPACY:POS-NUM'] ur mob every:['SPACY:POS-DET'] week just txt NOKIA to 8007 Get txting and tell ur mates www.getzed.co.uk POBox 36504 W45WQ norm150p / tone 16 +
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Just re read it and I have no shame but tell me how he takes it and if he runs I will blame u 4 ever ! ! Not really 4:['SPACY:POS-NUM'] ever just a:['SPACY:POS-DET'] long time
# -------------------------
# [MATCH]: HOW ARE U ? I HAVE MISSED U ! I HAVENT BEEN UP 2:['SPACY:POS-NUM'] MUCH A:['SPACY:POS-DET'] BIT BORED WITH THE HOLIDAY WANT 2 GO BAK 2 COLLEGE ! SAD ISNT IT?xx
# -------------------------
# ==================================================
# Rank 94
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['TEXT:to']]
# Window size: 5
# Class: Positive
# Precision: 0.565
# Match: 168 (4.7%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: This msg is for your mobile content order It has been resent as previous attempt failed due to network:['SPACY:POS-NOUN'] error:['SPACY:POS-NOUN'] Queries to:['TEXT:to'] customersqueries@netvision.uk.com
# -------------------------
# [MATCH]: Congratulations:['SPACY:POS-NOUN'] ! Thanks:['SPACY:POS-NOUN'] to:['TEXT:to'] a good friend U have WON the Â£2,000 Xmas prize . 2 claim is easy , just call 08718726971 NOW ! Only 10p per minute . BT - national - rate .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Then Ã¼:['SPACY:POS-NOUN'] ask dad:['SPACY:POS-NOUN'] to:['TEXT:to'] pick Ã¼ up lar ... Ãœ wan 2 stay until 6 meh ...
# -------------------------
# [MATCH]: Tell your friends:['SPACY:POS-NOUN'] what:['SPACY:POS-NOUN'] you plan to:['TEXT:to'] do on Valentines day @ & lt;URL&gt ;
# -------------------------
# ==================================================
# Rank 95
# Pattern: [['SENTIMENT:pos'], ['SPACY:POS-DET'], ['SPACY:POS-PROPN']]
# Window size: 5
# Class: Positive
# Precision: 0.797
# Match: 79 (2.2%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: Hi if ur lookin 4 saucy daytime fun wiv busty married woman Am free:['SENTIMENT:pos'] all:['SPACY:POS-DET'] next week Chat:['SPACY:POS-PROPN'] now 2 sort time 09099726429 JANINExx CallsÂ£1/minMobsmoreLKPOBOX177HP51FL
# -------------------------
# [MATCH]: URGENT ! We are trying to contact U Todays draw shows that you have won:['SENTIMENT:pos'] a:['SPACY:POS-DET'] Â£800:['SPACY:POS-PROPN'] prize GUARANTEED . Call 09050000460 from land line . Claim J89 . po box245c2150pm
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Smile in Pleasure Smile in Pain Smile when trouble pours like Rain Smile:['SENTIMENT:pos'] when sum1:['SPACY:POS-DET'] Hurts:['SPACY:POS-PROPN'] U Smile becoz SOMEONE still Loves to see u Smiling ! !
# -------------------------
# [MATCH]: Smile in Pleasure Smile in Pain Smile when trouble pours like Rain Smile:['SENTIMENT:pos'] when sum1:['SPACY:POS-DET'] Hurts:['SPACY:POS-PROPN'] U Smile becoz SOMEONE still Loves to see u Smiling ! !
# -------------------------
# ==================================================
# Rank 96
# Pattern: [['TEXT:.'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.875
# Match: 64 (1.8%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: I do n't know u and u do n't know me .:['TEXT:.'] Send CHAT:['SPACY:POS-PROPN'] to 86688:['SPACY:POS-NUM'] now and let 's find each other ! Only 150p / Msg rcvd . HG / Suite342/2Lands / Row / W1J6HL LDN . 18 years or over .
# -------------------------
# [MATCH]: Want to funk up ur fone with a weekly new tone reply TONES2U 2 this text . www.ringtones.co.uk , the original n best .:['TEXT:.'] Tones:['SPACY:POS-PROPN'] 3GBP:['SPACY:POS-NUM'] network operator rates apply
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: The length is e same but e top shorter n i got a fringe now . I thk i 'm not going liao . Too lazy .:['TEXT:.'] Dun:['SPACY:POS-PROPN'] wan 2:['SPACY:POS-NUM'] distract u also .
# -------------------------
# [MATCH]: Your opinion about me ? 1 . Over 2 .:['TEXT:.'] Jada:['SPACY:POS-PROPN'] 3:['SPACY:POS-NUM'] . Kusruthi 4 . Lovable 5 . Silent 6 . Spl character 7 . Not matured 8 . Stylish 9 . Simple Pls reply ..
# -------------------------
# ==================================================
# Rank 97
# Pattern: [['HYPERNYM:statement.n.01']]
# Window size: 3
# Class: Positive
# Precision: 0.692
# Match: 107 (3.0%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: URGENT ! Your Mobile number has been awarded with a Â£2000 prize GUARANTEED . Call 09058094455 from land line . Claim:['HYPERNYM:statement.n.01'] 3030 . Valid 12hrs only
# -------------------------
# [MATCH]: URGENT ! We are trying to contact you . Last weekends draw shows that you have won a Â£900 prize GUARANTEED . Call 09061701939 . Claim:['HYPERNYM:statement.n.01'] code S89 . Valid 12hrs only
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: You are not bothering me but you have to trust my answers:['HYPERNYM:statement.n.01'] . Pls .
# -------------------------
# [MATCH]: GOD ASKED , " What is forgiveness ? " A little child gave lovely reply:['HYPERNYM:statement.n.01'] , " It is d wonderful fruit that a tree gives when it is being hurt by a stone .. Good night ......
# -------------------------
# ==================================================
# Rank 98
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
# Window size: 5
# Class: Positive
# Precision: 0.520
# Match: 198 (5.6%)
# Gain = 0.036
# Metric (global) = 0.036
# Examples ~ Class Positive:
# [MATCH]: Congrats:['SPACY:POS-NOUN'] ! Nokia:['SPACY:POS-PROPN'] 3650 video:['SPACY:POS-NOUN'] camera phone is your Call 09066382422 Calls cost 150ppm Ave call 3mins vary from mobiles 16 + Close 300603 post BCM4284 Ldn WC1N3XX
# -------------------------
# [MATCH]: Dear Dave this is your final notice to collect your 4 * Tenerife Holiday or # 5000 CASH award ! Call 09061743806 from landline . TCs:['SPACY:POS-NOUN'] SAE:['SPACY:POS-PROPN'] Box326 CW25WX:['SPACY:POS-NOUN'] 150ppm
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: We can make a baby:['SPACY:POS-NOUN'] in yo:['SPACY:POS-PROPN'] tho:['SPACY:POS-NOUN']
# -------------------------
# [MATCH]: I REALLY NEED 2 KISS:['SPACY:POS-NOUN'] U I MISS:['SPACY:POS-PROPN'] U:['SPACY:POS-NOUN'] MY BABY FROM UR BABY 4EVA
# -------------------------
# ==================================================
# Rank 99
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
# Window size: 5
# Class: Positive
# Precision: 1.000
# Match: 44 (1.2%)
# Gain = 0.036
# Metric (global) = 0.036
# Examples ~ Class Positive:
# [MATCH]: Do you want 750 anytime any network mins 150 text and a NEW VIDEO phone for only five pounds per week call:['TEXT:call'] 08002888812:['SPACY:POS-NUM'] or reply for:['SPACY:POS-ADP'] delivery tomorrow
# -------------------------
# [MATCH]: Uâ€ ™ ve Bin Awarded Â£50 to Play 4 Instant Cash . Call:['TEXT:call'] 08715203028:['SPACY:POS-NUM'] To:['SPACY:POS-ADP'] Claim . EVERY 9th Player Wins Min Â£50-Â£500 . OptOut 08718727870
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Rank 100
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['TEXT:.'], ['SPACY:POS-NUM']]
# Window size: 6
# Class: Positive
# Precision: 1.000
# Match: 44 (1.2%)
# Gain = 0.036
# Metric (global) = 0.036
# Examples ~ Class Positive:
# [MATCH]: URGENT ! Your Mobile number has been awarded a < UKP>2000:['SPACY:POS-PROPN'] prize:['SPACY:POS-NOUN'] GUARANTEED .:['TEXT:.'] Call 09061790125:['SPACY:POS-NUM'] from landline . Claim 3030 . Valid 12hrs only 150ppm
# -------------------------
# [MATCH]: < Forwarded from 21870000>Hi - this is your Mailbox Messaging SMS:['SPACY:POS-PROPN'] alert:['SPACY:POS-NOUN'] .:['TEXT:.'] You have 40:['SPACY:POS-NUM'] matches . Please call back on 09056242159 to retrieve your messages and matches cc100p / min
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================

# %%
print(f'  #    class Cov(%)    Prec    Gain    Pattern')
for idx, p in enumerate(the_patterns):
    print(f'{idx+1:>3} {p.support_class}   {round(p.coverage*100, 1):>4}   {p.precision:.3f}   {p.metric:.3f}    {p.get_pattern_id()}')
# Out:
#   #    class Cov(%)    Prec    Gain    Pattern
#   1 Negative   26.2   0.526   0.223    [['SPACY:POS-NUM']]
#   2 Positive    8.9   0.806   0.175    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#   3 Positive    5.1   0.984   0.152    [['TEXT:call'], ['SPACY:POS-NUM']]
#   4 Positive   14.5   0.579   0.148    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#   5 Positive   11.8   0.613   0.129    [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
#   6 Positive    6.8   0.811   0.129    [['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
#   7 Negative   18.1   0.526   0.119    [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
#   8 Positive    5.4   0.856   0.114    [['TEXT:to'], ['SPACY:POS-NUM']]
#   9 Negative   37.8   0.690   0.112    [['SPACY:POS-PROPN']]
#  10 Positive    7.6   0.702   0.105    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  11 Positive    7.1   0.722   0.104    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  12 Positive    5.7   0.797   0.101    [['TEXT:.'], ['SPACY:POS-NUM']]
#  13 Positive    6.7   0.735   0.100    [['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
#  14 Negative   20.0   0.585   0.095    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  15 Positive    8.8   0.597   0.085    [['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
#  16 Positive    7.2   0.655   0.084    [['SPACY:POS-ADJ'], ['SPACY:POS-NUM']]
#  17 Positive    7.3   0.649   0.083    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  18 Positive    3.4   0.926   0.082    [['SPACY:POS-PROPN'], ['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
#  19 Positive   11.8   0.504   0.080    [['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]
#  20 Positive    8.0   0.591   0.074    [['SPACY:POS-NUM'], ['TEXT:.']]
#  21 Positive    4.3   0.791   0.073    [['SPACY:POS-NOUN'], ['TEXT:call']]
#  22 Positive    3.6   0.843   0.069    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  23 Negative   37.2   0.983   0.067    [['TEXT:i']]
#  24 Positive    4.4   0.756   0.067    [['SPACY:POS-SYM']]
#  25 Positive    4.5   0.748   0.067    [['TEXT:free']]
#  26 Positive    2.7   0.938   0.067    [['TEXT:txt']]
#  27 Negative   15.5   0.591   0.065    [['SPACY:POS-NOUN'], ['TEXT:to']]
#  28 Positive    2.2   1.000   0.064    [['TEXT:claim']]
#  29 Positive    7.0   0.592   0.064    [['SPACY:POS-NOUN'], ['SPACY:POS-ADP', 'TEXT:to']]
#  30 Negative   16.1   0.602   0.063    [['TEXT:!']]
#  31 Positive    8.3   0.539   0.062    [['TEXT:.'], ['SPACY:POS-PROPN']]
#  32 Positive    8.7   0.522   0.061    [['SPACY:POS-PROPN'], ['TEXT:.']]
#  33 Positive    6.0   0.624   0.061    [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  34 Positive    2.4   0.942   0.060    [['TEXT:mobile']]
#  35 Positive    6.6   0.591   0.060    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
#  36 Positive    4.0   0.739   0.058    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]
#  37 Negative   10.3   0.530   0.057    [['SPACY:POS-ADJ'], ['SPACY:POS-PROPN']]
#  38 Positive    6.9   0.559   0.055    [['SPACY:POS-NUM'], ['SPACY:POS-ADJ']]
#  39 Positive    7.3   0.542   0.054    [['SENTIMENT:pos'], ['SPACY:POS-PROPN']]
#  40 Positive    3.1   0.802   0.053    [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  41 Positive    1.9   0.985   0.053    [['TEXT:.'], ['TEXT:call'], ['SPACY:POS-NUM']]
#  42 Positive    2.2   0.923   0.052    [['HYPERNYM:communication.n.02'], ['SPACY:POS-NUM']]
#  43 Positive    2.2   0.922   0.051    [['HYPERNYM:win.v.01', 'SENTIMENT:pos']]
#  44 Negative   13.6   0.601   0.051    [['SPACY:POS-ADP', 'TEXT:to']]
#  45 Positive    2.0   0.957   0.051    [['TEXT:call'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
#  46 Positive    3.1   0.784   0.051    [['TEXT:.'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  47 Positive    7.5   0.521   0.051    [['SPACY:POS-DET'], ['SPACY:POS-PROPN']]
#  48 Positive    3.8   0.716   0.050    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
#  49 Negative   10.6   0.559   0.050    [['SPACY:POS-ADP'], ['SPACY:POS-PROPN']]
#  50 Positive    4.0   0.690   0.049    [['SPACY:POS-PROPN'], ['TEXT:to']]
#  51 Positive    2.2   0.909   0.049    [['HYPERNYM:cost.n.01']]
#  52 Negative   65.0   0.804   0.049    [['SPACY:POS-ADP']]
#  53 Positive    2.2   0.899   0.049    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  54 Negative   54.1   0.785   0.049    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN']]
#  55 Negative   12.1   0.586   0.049    [['HYPERNYM:message.n.02']]
#  56 Positive    5.1   0.613   0.049    [['SPACY:POS-NOUN'], ['HYPERNYM:message.n.02']]
#  57 Negative   30.8   0.725   0.048    [['TEXT:to']]
#  58 Positive    2.5   0.843   0.048    [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  59 Positive    2.4   0.851   0.047    [['TEXT:!'], ['SPACY:POS-NUM']]
#  60 Positive    1.6   1.000   0.046    [['TEXT:prize']]
#  61 Positive    2.2   0.873   0.046    [['HYPERNYM:message.n.02'], ['SPACY:POS-NUM']]
#  62 Negative    8.6   0.533   0.045    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NOUN']]
#  63 Negative   10.8   0.580   0.044    [['HYPERNYM:communication.n.02']]
#  64 Positive    1.6   0.982   0.044    [['HYPERNYM:call.v.28'], ['SPACY:POS-NUM']]
#  65 Positive    2.0   0.890   0.044    [['SPACY:POS-PROPN'], ['TEXT:call']]
#  66 Positive    2.9   0.765   0.044    [['TEXT:call'], ['SPACY:POS-ADP']]
#  67 Positive    2.4   0.816   0.043    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
#  68 Negative   15.9   0.649   0.043    [['TEXT:.'], ['SPACY:POS-NOUN']]
#  69 Negative   39.6   0.759   0.043    [['SPACY:POS-NOUN'], ['SPACY:POS-ADP']]
#  70 Positive    1.5   0.982   0.043    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['TEXT:to'], ['SPACY:POS-NUM']]
#  71 Positive    4.8   0.594   0.042    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-ADP']]
#  72 Negative   39.9   0.761   0.042    [['SENTIMENT:pos']]
#  73 Positive    2.2   0.838   0.042    [['SPACY:POS-ADP'], ['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
#  74 Positive    1.9   0.909   0.042    [['TEXT:to'], ['SPACY:POS-NUM'], ['TEXT:.']]
#  75 Positive    4.0   0.639   0.042    [['SPACY:POS-ADJ'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  76 Positive    1.7   0.934   0.041    [['SPACY:POS-NUM'], ['TEXT:now']]
#  77 Positive    2.5   0.789   0.041    [['TEXT:.'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  78 Positive    3.5   0.675   0.041    [['SENTIMENT:pos'], ['SPACY:POS-NUM']]
#  79 Positive    3.6   0.667   0.041    [['TEXT:!'], ['SPACY:POS-PROPN']]
#  80 Positive    1.9   0.884   0.041    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
#  81 Positive    2.2   0.833   0.040    [['SPACY:POS-PROPN'], ['TEXT:.'], ['SPACY:POS-NUM']]
#  82 Positive    5.1   0.563   0.040    [['TEXT:!'], ['SPACY:POS-NOUN']]
#  83 Positive    3.1   0.709   0.040    [['SPACY:POS-DET'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  84 Positive    3.4   0.678   0.040    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['TEXT:.']]
#  85 Positive    3.0   0.713   0.040    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  86 Positive    4.1   0.621   0.039    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['TEXT:.']]
#  87 Positive    2.1   0.838   0.039    [['SENTIMENT:pos'], ['TEXT:call']]
#  88 Positive    1.9   0.868   0.038    [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  89 Positive    2.5   0.764   0.038    [['HYPERNYM:symbol.n.01']]
#  90 Positive    5.2   0.543   0.037    [['SPACY:POS-ADP'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
#  91 Positive    3.5   0.648   0.037    [['TEXT:!'], ['SPACY:POS-ADJ']]
#  92 Positive    1.6   0.914   0.037    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  93 Positive    3.7   0.634   0.037    [['SPACY:POS-NUM'], ['SPACY:POS-DET']]
#  94 Positive    4.7   0.565   0.037    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['TEXT:to']]
#  95 Positive    2.2   0.797   0.037    [['SENTIMENT:pos'], ['SPACY:POS-DET'], ['SPACY:POS-PROPN']]
#  96 Positive    1.8   0.875   0.037    [['TEXT:.'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  97 Positive    3.0   0.692   0.037    [['HYPERNYM:statement.n.01']]
#  98 Positive    5.6   0.520   0.036    [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  99 Positive    1.2   1.000   0.036    [['TEXT:call'], ['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
# 100 Positive    1.2   1.000   0.036    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['TEXT:.'], ['SPACY:POS-NUM']]

# %% [markdown]
# ## Post-process the patterns

# %%
# Select only patterns of which precision is greater than 0.70
selected_patterns = [p for p in the_patterns if p.precision >= 0.70]
print(f'No. of remaining patterns = {len(selected_patterns)}')
# Out:
# No. of remaining patterns = 57

# %%
# For every pair of patterns (p1, p2), remove pattern p2 if there exists p1 in the patterns set such that p2 is a specialization of p1 and metric of p2 is lower than p1
selected_patterns = grasp.remove_specialized_patterns(selected_patterns, metric = lambda x: x.precision)
print(f'No. of remaining patterns = {len(selected_patterns)}')
# Out:
# No. of remaining patterns = 47

# %%
# Print the remaining patterns sorted by precision
selected_patterns = sorted(selected_patterns, key = lambda x: x.precision, reverse = True)
print(f'  #    class Cov(%)    Prec  Gain    Pattern')
for idx, p in enumerate(selected_patterns):
    print(f'{idx+1:>3} {p.support_class}   {round(p.coverage*100, 1):>4}   {p.precision:.3f}   {p.metric:.3f}    {p.get_pattern_id()}')
# Out:
#   #    class Cov(%)    Prec  Gain    Pattern
#   1 Positive    2.2   1.000   0.064    [['TEXT:claim']]
#   2 Positive    1.6   1.000   0.046    [['TEXT:prize']]
#   3 Positive    1.2   1.000   0.036    [['TEXT:call'], ['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
#   4 Positive    1.2   1.000   0.036    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['TEXT:.'], ['SPACY:POS-NUM']]
#   5 Positive    1.9   0.985   0.053    [['TEXT:.'], ['TEXT:call'], ['SPACY:POS-NUM']]
#   6 Positive    5.1   0.984   0.152    [['TEXT:call'], ['SPACY:POS-NUM']]
#   7 Negative   37.2   0.983   0.067    [['TEXT:i']]
#   8 Positive    1.5   0.982   0.043    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['TEXT:to'], ['SPACY:POS-NUM']]
#   9 Positive    2.4   0.942   0.060    [['TEXT:mobile']]
#  10 Positive    2.7   0.938   0.067    [['TEXT:txt']]
#  11 Positive    1.7   0.934   0.041    [['SPACY:POS-NUM'], ['TEXT:now']]
#  12 Positive    3.4   0.926   0.082    [['SPACY:POS-PROPN'], ['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
#  13 Positive    2.2   0.923   0.052    [['HYPERNYM:communication.n.02'], ['SPACY:POS-NUM']]
#  14 Positive    2.2   0.922   0.051    [['HYPERNYM:win.v.01', 'SENTIMENT:pos']]
#  15 Positive    1.6   0.914   0.037    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  16 Positive    2.2   0.909   0.049    [['HYPERNYM:cost.n.01']]
#  17 Positive    1.9   0.909   0.042    [['TEXT:to'], ['SPACY:POS-NUM'], ['TEXT:.']]
#  18 Positive    2.2   0.899   0.049    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  19 Positive    2.0   0.890   0.044    [['SPACY:POS-PROPN'], ['TEXT:call']]
#  20 Positive    1.9   0.884   0.041    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
#  21 Positive    1.8   0.875   0.037    [['TEXT:.'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  22 Positive    2.2   0.873   0.046    [['HYPERNYM:message.n.02'], ['SPACY:POS-NUM']]
#  23 Positive    1.9   0.868   0.038    [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  24 Positive    5.4   0.856   0.114    [['TEXT:to'], ['SPACY:POS-NUM']]
#  25 Positive    2.4   0.851   0.047    [['TEXT:!'], ['SPACY:POS-NUM']]
#  26 Positive    2.5   0.843   0.048    [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  27 Positive    3.6   0.843   0.069    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  28 Positive    2.1   0.838   0.039    [['SENTIMENT:pos'], ['TEXT:call']]
#  29 Positive    2.2   0.838   0.042    [['SPACY:POS-ADP'], ['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
#  30 Positive    2.2   0.833   0.040    [['SPACY:POS-PROPN'], ['TEXT:.'], ['SPACY:POS-NUM']]
#  31 Positive    2.4   0.816   0.043    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
#  32 Positive    6.8   0.811   0.129    [['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
#  33 Positive    8.9   0.806   0.175    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  34 Negative   65.0   0.804   0.049    [['SPACY:POS-ADP']]
#  35 Positive    2.2   0.797   0.037    [['SENTIMENT:pos'], ['SPACY:POS-DET'], ['SPACY:POS-PROPN']]
#  36 Positive    5.7   0.797   0.101    [['TEXT:.'], ['SPACY:POS-NUM']]
#  37 Positive    4.3   0.791   0.073    [['SPACY:POS-NOUN'], ['TEXT:call']]
#  38 Positive    2.5   0.789   0.041    [['TEXT:.'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  39 Negative   54.1   0.785   0.049    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN']]
#  40 Positive    3.1   0.784   0.051    [['TEXT:.'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  41 Positive    2.5   0.764   0.038    [['HYPERNYM:symbol.n.01']]
#  42 Negative   39.9   0.761   0.042    [['SENTIMENT:pos']]
#  43 Positive    4.4   0.756   0.067    [['SPACY:POS-SYM']]
#  44 Positive    6.7   0.735   0.100    [['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
#  45 Negative   30.8   0.725   0.048    [['TEXT:to']]
#  46 Positive    7.1   0.722   0.104    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  47 Positive    3.1   0.709   0.040    [['SPACY:POS-DET'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]

# %% [markdown]
# ## Save the patterns to a json file
# We can use this json file as an input of the web demo tool for exploring the learned patterns and the training data

# %%
grasp_model.to_json('results/case_study_1.json', patterns = selected_patterns, comment = 'Rank and group patterns based on precision. The minimum precision was set at 0.70')
# Out:
# 100%|██████████| 47/47 [00:00<00:00, 380.03it/s]
# 100%|██████████| 47/47 [00:00<00:00, 362.51it/s]
# Successfully dump the results to results/case_study_1.json
