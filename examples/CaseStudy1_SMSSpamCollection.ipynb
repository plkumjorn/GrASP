# %%
# %load_ext autoreload
# %autoreload 2

# %%
import grasptext
from grasptext import GrASP
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Load the data
# - We use the SMS Spam Collection dataset from the following paper. Please download and unzip it by running the two cells below **only if you have not done this before**.
#
# ```
# Almeida, T. A., Hidalgo, J. M. G., & Yamakami, A. (2011, September). Contributions to the study of SMS spam filtering: new collection and results. In Proceedings of the 11th ACM symposium on Document engineering (pp. 259-262).
# ```

# %%
import urllib.request
url = 'http://www.dt.fee.unicamp.br/~tiago/smsspamcollection/smsspamcollection.zip'
filename = './data/smsspamcollection.zip'
urllib.request.urlretrieve(url, filename)

# %%
# !unzip ./data/smsspamcollection.zip -d ./data

# %% [markdown]
# - Load the data

# %%
def get_data():
    f = open('./data/SMSSpamCollection.txt', 'r')
    texts, labels = [], []
    for line in f:
        line = line.strip()
        tab_idx = line.index('\t')
        label = line[:tab_idx]
        text = line[tab_idx+1:]
        if label == 'ham':
            label = 0
        elif label == 'spam':
            label = 1
        else:
            raise Exception(f"Invalid label - {label}")
        texts.append(text)
        labels.append(label)
    return texts, labels

# %%
texts, labels = get_data()
X_train, X_test, y_train, y_test = train_test_split(texts, labels, test_size=0.2, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1)
# len(texts), sum(labels), len(X_test), sum(y_test)

# %%
positive = [t for idx, t in enumerate(X_train) if y_train[idx]]
negative = [t for idx, t in enumerate(X_train) if not y_train[idx]]
print(f'Positive examples = {len(positive)}\nNegative examples = {len(negative)}')
# Out:
# Positive examples = 488
# Negative examples = 3079

# %% [markdown]
# ## Run GrASP

# %%
# Create the GrASP engine
grasp_model = GrASP(include_standard = ['TEXT', 'POS', 'HYPERNYM', 'SENTIMENT'],
                    num_patterns = 100, gaps_allowed = 2)

# %%
# Fit GrASP to the dataset
the_patterns = grasp_model.fit_transform(positive, negative)
# Out:
#   0%|          | 0/488 [00:00<?, ?it/s]
# Step 1: Create augmented texts
# 100%|██████████| 488/488 [00:22<00:00, 21.91it/s]
# 100%|██████████| 3079/3079 [01:42<00:00, 29.92it/s]
# Step 2: Find frequent attributes
#   1%|          | 7/1215 [00:00<00:20, 59.23it/s]
# Total number of candidate alphabet = 1215, such as ['SPACY:POS-VERB', 'SPACY:POS-NOUN', 'SPACY:POS-PUNCT', 'SPACY:POS-PRON', 'SPACY:POS-ADV']
# Step 3: Find alphabet set
# 100%|██████████| 1215/1215 [00:28<00:00, 42.92it/s]
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
#   0%|          | 0/100 [00:00<?, ?it/s]
# Finding top k: 100 / 100
# Total number of alphabet = 100
# ['SPACY:POS-NUM', 'SPACY:POS-PROPN', 'TEXT:call', 'TEXT:i', 'SPACY:POS-SYM', 'TEXT:free', 'TEXT:txt', 'TEXT:claim', 'TEXT:!', 'TEXT:mobile', 'HYPERNYM:cost.n.01', 'SPACY:POS-ADP', 'HYPERNYM:message.n.02', 'TEXT:to', 'TEXT:prize', 'HYPERNYM:communication.n.02', 'HYPERNYM:win.v.01', 'SENTIMENT:pos', 'HYPERNYM:symbol.n.01', 'HYPERNYM:statement.n.01', 'TEXT:your', 'SPACY:POS-ADJ', 'TEXT:or', 'TEXT:text', 'TEXT:stop', 'TEXT:-', 'TEXT:150p', 'TEXT:guaranteed', 'TEXT:urgent', 'HYPERNYM:textbook.n.01', 'HYPERNYM:act.n.02', 'TEXT:win', 'HYPERNYM:oppose.v.01', 'TEXT:+', 'HYPERNYM:written_communication.n.01', 'SPACY:POS-PRON', 'TEXT:16', 'TEXT:cash', 'HYPERNYM:abstraction.n.06', 'TEXT:from', 'HYPERNYM:assertion.n.01', 'TEXT:reply', 'TEXT:now', 'TEXT:.', 'TEXT:tone', 'TEXT:18', 'HYPERNYM:acquisition.n.02', 'SPACY:POS-DET', 'TEXT:nokia', 'TEXT:a', 'HYPERNYM:user.n.01', 'TEXT:our', 'HYPERNYM:mobile.n.02', 'HYPERNYM:minute.n.01', 'HYPERNYM:person.n.01', 'HYPERNYM:claim.v.03', 'TEXT:service', 'TEXT:contact', 'HYPERNYM:writing.n.02', 'TEXT:for', 'TEXT:...', 'HYPERNYM:offer.n.02', 'TEXT:awarded', 'TEXT:â£1000', 'TEXT:150ppm', 'TEXT:4', 'HYPERNYM:request.n.01', 'TEXT:per', 'HYPERNYM:call.v.28', 'HYPERNYM:convey.v.03', 'HYPERNYM:television_camera.n.01', 'HYPERNYM:land_line.n.01', 'TEXT:ur', 'HYPERNYM:state.v.01', 'TEXT:camera', 'HYPERNYM:phone.n.02', 'TEXT:rate', 'TEXT:my', 'HYPERNYM:sculpture.n.01', 'TEXT:latest', 'HYPERNYM:text.n.04', 'HYPERNYM:coding_system.n.01', 'TEXT:box', 'TEXT:draw', 'TEXT::', 'HYPERNYM:event.n.01', 'TEXT:line', 'HYPERNYM:free.a.01', 'TEXT:shows', 'HYPERNYM:now.r.03', 'HYPERNYM:declare.v.01', 'TEXT:10p', 'TEXT:collection', 'TEXT:2', 'SPACY:POS-NOUN', 'HYPERNYM:memory_device.n.01', 'HYPERNYM:document.n.01', 'HYPERNYM:service.n.11', 'HYPERNYM:equipment.n.01', 'HYPERNYM:part.n.01']
# Example of patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Metric (global) = 0.223
# Examples ~ Class Negative:
# [MATCH]: U coming 2:['SPACY:POS-NUM'] pick me ?
# -------------------------
# [MATCH]: From someone not to smoke when every time I 've smoked in the last two:['SPACY:POS-NUM'] weeks is because of you calling or texting me that you wanted to smoke
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Warner Village 83118:['SPACY:POS-NUM'] C Colin Farrell in SWAT this wkend @Warner Village & get 1 free med . Popcorn!Just show msg+ticket@kiosk . Valid 4 - 7/12 . C t&c @kiosk . Reply SONY 4 mre film offers
# -------------------------
# [MATCH]: Fantasy Football is back on your TV . Go to Sky Gamestar on Sky Active and play Â£250k Dream Team . Scoring starts on Saturday , so register now!SKY OPT OUT to 88088:['SPACY:POS-NUM']
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN']]
# Window size: 3
# Class: Negative
# Precision: 0.690
# Match: 1347 (37.8%)
# Gain = 0.112
# Metric (global) = 0.112
# Examples ~ Class Negative:
# [MATCH]: Cos darren say Ã¼ considering mah:['SPACY:POS-PROPN'] so i ask Ã¼ ...
# -------------------------
# [MATCH]: Shuhui:['SPACY:POS-PROPN'] has bought ron 's present it 's a swatch watch ...
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: YOU ARE CHOSEN TO RECEIVE A:['SPACY:POS-PROPN'] Â£350 AWARD ! Pls call claim number 09066364311 to collect your award which you are selected to receive as a valued mobile customer .
# -------------------------
# [MATCH]: Customer:['SPACY:POS-PROPN'] Loyalty Offer : The NEW Nokia6650 Mobile from ONLY Â£10 at TXTAUCTION ! Txt word : START to No : 81151 & get yours Now ! 4T&Ctxt TC 150p / MTmsg
# -------------------------
# ==================================================
# Pattern: [['TEXT:call']]
# Window size: 3
# Class: Positive
# Precision: 0.618
# Match: 348 (9.8%)
# Gain = 0.104
# Metric (global) = 0.104
# Examples ~ Class Positive:
# [MATCH]: FreeMsg : Txt : CALL:['TEXT:call'] to No : 86888 & claim your reward of 3 hours talk time to use from your phone now ! Subscribe6GBP / mnth inc 3hrs 16 stop?txtStop
# -------------------------
# [MATCH]: INTERFLORA - Â“It 's not too late to order Interflora flowers for christmas call:['TEXT:call'] 0800 505060 to place your order before Midnight tomorrow .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: He is there . You call:['TEXT:call'] and meet him
# -------------------------
# [MATCH]: Hi Dear Call:['TEXT:call'] me its urgnt . I do n't know what s your problem . You do n't want to work or if you have any other problem at least tell me . Wating for your reply .
# -------------------------
# ==================================================
# Pattern: [['TEXT:i']]
# Window size: 3
# Class: Negative
# Precision: 0.983
# Match: 1327 (37.2%)
# Gain = 0.067
# Metric (global) = 0.067
# Examples ~ Class Negative:
# [MATCH]: It will stop on itself . I:['TEXT:i'] however suggest she stays with someone that will be able to give ors for every stool .
# -------------------------
# [MATCH]: I:['TEXT:i'] do nt know ask to my brother . Nothing problem some thing that . Just i told .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: I:['TEXT:i'] do n't know u and u do n't know me . Send CHAT to 86688 now and let 's find each other ! Only 150p / Msg rcvd . HG / Suite342/2Lands / Row / W1J6HL LDN . 18 years or over .
# -------------------------
# [MATCH]: Babe : U want me do nt u baby ! I:['TEXT:i'] m nasty and have a thing 4 filthyguys . Fancy a rude time with a sexy bitch . How about we go slo n hard ! Txt XXX SLO(4msgs )
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-SYM']]
# Window size: 3
# Class: Positive
# Precision: 0.756
# Match: 156 (4.4%)
# Gain = 0.067
# Metric (global) = 0.067
# Examples ~ Class Positive:
# [MATCH]: FREE for 1st week ! No1 Nokia tone 4 ur mob every week just txt NOKIA to 8007 Get txting and tell ur mates www.getzed.co.uk POBox 36504 W45WQ norm150p /:['SPACY:POS-SYM'] tone 16 +
# -------------------------
# [MATCH]: Double Mins & Double Txt & 1/2 price Linerental on Latest Orange Bluetooth mobiles . Call MobileUpd8 for the very latest offers . 08000839402 or call2optout /:['SPACY:POS-SYM'] LF56
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Carlos is taking his sweet time as usual so let me know when you and patty are done /:['SPACY:POS-SYM'] want to smoke and I 'll tell him to haul ass
# -------------------------
# [MATCH]: Take care and sleep well.you need to learn to change in life.you only need to get CONVINCED on that.i will wait but no more conversations between us . GET CONVINCED by that time . Your family is over for you in many senses.respect them but not overemphasise.or:['SPACY:POS-SYM'] u have no role in my life .
# -------------------------
# ==================================================
# Step 4: Grow patterns
# 100%|██████████| 100/100 [00:55<00:00,  1.79it/s]
# Length 2 / 5; New candidates = 14950
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Metric (global) = 0.223
# Examples ~ Class Negative:
# [MATCH]: HIYA COMIN 2:['SPACY:POS-NUM'] BRISTOL 1 ST WEEK IN APRIL . LES GOT OFF + RUDI ON NEW YRS EVE BUT I WAS SNORING.THEY WERE DRUNK ! U BAK AT COLLEGE YET ? MY WORK SENDS INK 2 BATH .
# -------------------------
# [MATCH]: Ok . But i finish at 6:['SPACY:POS-NUM'] .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: -PLS STOP bootydelious ( 32/F:['SPACY:POS-NUM'] ) is inviting you to be her friend . Reply YES-434 or NO-434 See her : www . SMS.ac / u / bootydelious STOP ? Send STOP FRND to 62468
# -------------------------
# [MATCH]: FREE camera phones with linerental from 4.49/month:['SPACY:POS-NUM'] with 750 cross ntwk mins . 1/2 price txt bundle deals also avble . Call 08001950382 or call2optout / J MF
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.806
# Match: 319 (8.9%)
# Gain = 0.175
# Metric (global) = 0.175
# Examples ~ Class Positive:
# [MATCH]: HOT LIVE FANTASIES call now 08707509020 Just 20p per min NTT Ltd , PO:['SPACY:POS-PROPN'] Box 1327:['SPACY:POS-NUM'] Croydon CR9 5WB 0870 is a national rate call
# -------------------------
# [MATCH]: FREE GAME . Get Rayman:['SPACY:POS-PROPN'] Golf 4:['SPACY:POS-NUM'] FREE from the O2 Games Arcade . 1st get UR games settings . Reply POST , then save & activ8 . Press 0 key for Arcade . Termsapply
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Boy ; I love u Grl : Hogolo Boy : gold chain kodstini Grl : Agalla Boy : necklace madstini Grl : agalla Boy : Hogli:['SPACY:POS-PROPN'] 1:['SPACY:POS-NUM'] mutai eerulli kodthini ! Grl : I love U kano;- )
# -------------------------
# [MATCH]: C movie is juz last minute decision mah . Juz:['SPACY:POS-PROPN'] watch 2:['SPACY:POS-NUM'] lar but i tot Ã¼ not interested .
# -------------------------
# ==================================================
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.984
# Match: 183 (5.1%)
# Gain = 0.152
# Metric (global) = 0.152
# Examples ~ Class Positive:
# [MATCH]: YOUR CHANCE TO BE ON A REALITY FANTASY SHOW call:['TEXT:call'] now = 08707509020:['SPACY:POS-NUM'] Just 20p per min NTT Ltd , PO Box 1327 Croydon CR9 5WB 0870 is a national = rate call
# -------------------------
# [MATCH]: Xmas Offer ! Latest Motorola , SonyEricsson & Nokia & FREE Bluetooth or DVD ! Double Mins & 1000 Txt on Orange . Call:['TEXT:call'] MobileUpd8 on 08000839402:['SPACY:POS-NUM'] or call2optout/4QF2
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I 'm in a movie . Call:['TEXT:call'] me 4:['SPACY:POS-NUM'] wat ?
# -------------------------
# [MATCH]: Yun ah.the ubi one say if Ã¼ wan call:['TEXT:call'] by tomorrow.call 67441233:['SPACY:POS-NUM'] look for irene.ere only got bus8,22,65,61,66,382 . Ubi cres , ubi tech park.6ph for 1st 5wkg days . Ã¨n
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.579
# Match: 518 (14.5%)
# Gain = 0.148
# Metric (global) = 0.148
# Examples ~ Class Positive:
# [MATCH]: Latest Nokia:['SPACY:POS-PROPN'] Mobile:['SPACY:POS-PROPN'] or iPOD MP3 Player + Â£400 proze GUARANTEED ! Reply with : WIN to 83355 now ! Norcorp Ltd . Â£1,50/Mtmsgrcvd18 +
# -------------------------
# [MATCH]: Free:['SPACY:POS-PROPN'] Msg:['SPACY:POS-PROPN'] : Ringtone!From : http://tms . widelive.com/index . wml?id=1b6a5ecef91ff9 * 37819&first = true18:0430-JUL-05
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Yes . They replied my mail . I 'm going to the management office later . Plus will in to bank later also.or:['SPACY:POS-PROPN'] on wednesday:['SPACY:POS-PROPN'] .
# -------------------------
# [MATCH]: Sun:['SPACY:POS-PROPN'] ah ... Thk:['SPACY:POS-PROPN'] mayb can if dun have anythin on ... Thk have to book e lesson ... E pilates is at orchard mrt u noe hor ...
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.613
# Match: 421 (11.8%)
# Gain = 0.129
# Metric (global) = 0.129
# Examples ~ Class Positive:
# [MATCH]: URGENT ! Your mobile was awarded a Â£1,500 Bonus Caller Prize on:['SPACY:POS-ADP'] 27/6/03:['SPACY:POS-NUM'] . Our final attempt 2 contact U ! Call 08714714011
# -------------------------
# [MATCH]: Free video camera phones with Half Price line rental for:['SPACY:POS-ADP'] 12:['SPACY:POS-NUM'] mths and 500 cross ntwk mins 100 txts . Call MobileUpd8 08001950382 or Call2OptOut/674
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Or just do that:['SPACY:POS-ADP'] 6times:['SPACY:POS-NUM']
# -------------------------
# [MATCH]: I actually did for the first time in a while . I went to bed not too long after i spoke with you . Woke up at:['SPACY:POS-ADP'] 7:['SPACY:POS-NUM'] . How was your night ?
# -------------------------
# ==================================================
# 100%|██████████| 68/68 [01:18<00:00,  1.16s/it]
# Length 3 / 5; New candidates = 13344
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Metric (global) = 0.223
# Examples ~ Class Negative:
# [MATCH]: We made it ! Eta at taunton is 12:30:['SPACY:POS-NUM'] as planned , hope thatâ€˜s still okday ? ! Good to see you ! : -xx
# -------------------------
# [MATCH]: Me also da , i feel yesterday night   wait til 2day:['SPACY:POS-NUM'] night dear .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Urgent ! call 09061749602:['SPACY:POS-NUM'] from Landline . Your complimentary 4 * Tenerife Holiday or Â£10,000 cash await collection SAE T&Cs BOX 528 HP20 1YF 150ppm 18 +
# -------------------------
# [MATCH]: Urgent ! call 09066612661:['SPACY:POS-NUM'] from landline . Your complementary 4 * Tenerife Holiday or Â£10,000 cash await collection SAE T&Cs PO Box 3 WA14 2PX 150ppm 18 + Sender : Hol Offer
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.806
# Match: 319 (8.9%)
# Gain = 0.175
# Metric (global) = 0.175
# Examples ~ Class Positive:
# [MATCH]: U have a secret admirer . REVEAL who thinks U R So special . Call 09065174042 . To opt out Reply REVEAL:['SPACY:POS-PROPN'] STOP . 1.50:['SPACY:POS-NUM'] per msg recd . Cust care 07821230901
# -------------------------
# [MATCH]: Shop till u Drop , IS IT YOU , either 10 K , 5 K , Â£500 Cash or Â£100 Travel voucher , Call now , 09064011000 . NTT PO Box CR01327BT:['SPACY:POS-PROPN'] fixedline Cost 150ppm:['SPACY:POS-NUM'] mobile vary
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: God picked up a flower and dippeditinaDEW , lovingly touched itwhichturnedinto u , and the he gifted tomeandsaid , THIS FRIEND:['SPACY:POS-PROPN'] IS 4U:['SPACY:POS-NUM']
# -------------------------
# [MATCH]: Hi here . have birth at on the   to   at 8 lb:['SPACY:POS-PROPN'] 7:['SPACY:POS-NUM'] oz . Mother and baby doing brilliantly .
# -------------------------
# ==================================================
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.984
# Match: 183 (5.1%)
# Gain = 0.152
# Metric (global) = 0.152
# Examples ~ Class Positive:
# [MATCH]: YOUR CHANCE TO BE ON A REALITY FANTASY SHOW call:['TEXT:call'] now = 08707509020:['SPACY:POS-NUM'] Just 20p per min NTT Ltd , PO Box 1327 Croydon CR9 5WB 0870 is a national = rate call
# -------------------------
# [MATCH]: URGENT ! We are trying to contact U. Todays draw shows that you have won a Â£800 prize GUARANTEED . Call:['TEXT:call'] 09050003091:['SPACY:POS-NUM'] from land line . Claim C52 . Valid 12hrs only
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Ummma.will call:['TEXT:call'] after check in.our:['SPACY:POS-NUM'] life will begin from qatar so pls pray very hard .
# -------------------------
# [MATCH]: I 'm in a movie . Call:['TEXT:call'] me 4:['SPACY:POS-NUM'] wat ?
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.579
# Match: 518 (14.5%)
# Gain = 0.148
# Metric (global) = 0.148
# Examples ~ Class Positive:
# [MATCH]: Had your contract mobile 11 Mnths:['SPACY:POS-PROPN'] ? Latest Motorola:['SPACY:POS-PROPN'] , Nokia etc . all FREE ! Double Mins & Text on Orange tariffs . TEXT YES for callback , no to remove from records .
# -------------------------
# [MATCH]: okmail : Dear Dave this is your final notice to collect your 4 * Tenerife:['SPACY:POS-PROPN'] Holiday:['SPACY:POS-PROPN'] or # 5000 CASH award ! Call 09061743806 from landline . TCs SAE Box326 CW25WX 150ppm
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: U R THE MOST BEAUTIFUL GIRL:['SPACY:POS-PROPN'] IVE:['SPACY:POS-PROPN'] EVER SEEN . U R MY BABY COME AND C ME IN THE COMMON ROOM
# -------------------------
# [MATCH]: YO:['SPACY:POS-PROPN'] YO:['SPACY:POS-PROPN'] YO BYATCH WHASSUP ?
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.613
# Match: 421 (11.8%)
# Gain = 0.129
# Metric (global) = 0.129
# Examples ~ Class Positive:
# [MATCH]: U are subscribed to the best Mobile Content Service in the UK for:['SPACY:POS-ADP'] Â£3 per 10:['SPACY:POS-NUM'] days until you send STOP to 82324 . Helpline 08706091795
# -------------------------
# [MATCH]: SPJanuary Male Sale ! Hot Gay chat now cheaper , call 08709222922 . National rate from:['SPACY:POS-ADP'] 1.5p:['SPACY:POS-NUM'] / min cheap to 7.8p / min peak ! To stop texts call 08712460324 ( 10p / min )
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: What is your record for:['SPACY:POS-ADP'] one:['SPACY:POS-NUM'] night ? :)
# -------------------------
# [MATCH]: I REALLY NEED 2 KISS U I MISS U MY BABY FROM:['SPACY:POS-ADP'] UR BABY 4EVA:['SPACY:POS-NUM']
# -------------------------
# ==================================================
# 100%|██████████| 36/36 [00:37<00:00,  1.04s/it]
# Length 4 / 5; New candidates = 7137
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
#   0%|          | 0/5 [00:00<?, ?it/s]
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Metric (global) = 0.223
# Examples ~ Class Negative:
# [MATCH]: , ,   and   picking them up from various points | going 2:['SPACY:POS-NUM'] yeovil | and they will do the motor project 4 3 hours | and then u take them home . || 12 2 5.30 max . || Very easy
# -------------------------
# [MATCH]: Wot about on we d nite I am 3:['SPACY:POS-NUM'] then but only til 9 !
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: FREE MESSAGE Activate your 500:['SPACY:POS-NUM'] FREE Text Messages by replying to this message with the word FREE For terms & conditions , visit www.07781482378.com
# -------------------------
# [MATCH]: from www . Applausestore.com MonthlySubscription@50p / msg max6/month T&CsC web age16:['SPACY:POS-NUM'] 2stop txt stop
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.806
# Match: 319 (8.9%)
# Gain = 0.175
# Metric (global) = 0.175
# Examples ~ Class Positive:
# [MATCH]: Free - message : Jamster!Get the crazy frog sound now ! For poly text MAD1 , for real text MAD2:['SPACY:POS-PROPN'] to 88888:['SPACY:POS-NUM'] . 6 crazy sounds for just 3 GBP / week ! 16+only ! T&C 's apply
# -------------------------
# [MATCH]: Want 2 get laid tonight ? Want real Dogging locations sent direct 2 ur mob ? Join the UK 's largest Dogging Network bt Txting:['SPACY:POS-PROPN'] GRAVEL to 69888:['SPACY:POS-NUM'] ! Nt . ec2a . 31p.msg@150p
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: " BOO BABE ! U ENJOYIN YOURJOB ? U:['SPACY:POS-PROPN'] SEEMED 2:['SPACY:POS-NUM'] B GETTIN ON WELL HUNNY!HOPE URE OK?TAKE CARE & IÂ’LLSPEAK 2U SOONLOTS OF LOVEME XXXX . "
# -------------------------
# [MATCH]: U:['SPACY:POS-PROPN'] GOIN OUT 2NITE:['SPACY:POS-NUM'] ?
# -------------------------
# ==================================================
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.984
# Match: 183 (5.1%)
# Gain = 0.152
# Metric (global) = 0.152
# Examples ~ Class Positive:
# [MATCH]: Urgent ! call:['TEXT:call'] 09066350750:['SPACY:POS-NUM'] from your landline . Your complimentary 4 * Ibiza Holiday or 10,000 cash await collection SAE T&Cs PO BOX 434 SK3 8WP 150 ppm 18 +
# -------------------------
# [MATCH]: Shop till u Drop , IS IT YOU , either 10 K , 5 K , Â£500 Cash or Â£100 Travel voucher , Call:['TEXT:call'] now , 09064011000:['SPACY:POS-NUM'] . NTT PO Box CR01327BT fixedline Cost 150ppm mobile vary
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Yun ah.the ubi one say if Ã¼ wan call:['TEXT:call'] by tomorrow.call 67441233:['SPACY:POS-NUM'] look for irene.ere only got bus8,22,65,61,66,382 . Ubi cres , ubi tech park.6ph for 1st 5wkg days . Ã¨n
# -------------------------
# [MATCH]: I 'm in a movie . Call:['TEXT:call'] me 4:['SPACY:POS-NUM'] wat ?
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.579
# Match: 518 (14.5%)
# Gain = 0.148
# Metric (global) = 0.148
# Examples ~ Class Positive:
# [MATCH]: Your free ringtone is waiting to be collected . Simply text the password " MIX " to 85069 to verify . Get Usher:['SPACY:POS-PROPN'] and Britney:['SPACY:POS-PROPN'] . FML , PO Box 5249 , MK17 92H. 450Ppw 16
# -------------------------
# [MATCH]: You 've won tkts to the EURO2004:['SPACY:POS-PROPN'] CUP:['SPACY:POS-PROPN'] FINAL or Â£800 CASH , to collect CALL 09058099801 b4190604 , POBOX 7876150ppm
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Evry:['SPACY:POS-PROPN'] Emotion:['SPACY:POS-PROPN'] dsn't hav Words . Evry Wish dsn't hav Prayrs .. If u Smile , D World is wit u . Othrwise even d Drop of Tear dsn't lik 2 Stay wit u . So b happy .. Good morning , keep smiling:- )
# -------------------------
# [MATCH]: Gud:['SPACY:POS-PROPN'] ni8:['SPACY:POS-PROPN'] dear .. slp well .. take care .. swt dreams .. Muah ..
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.613
# Match: 421 (11.8%)
# Gain = 0.129
# Metric (global) = 0.129
# Examples ~ Class Positive:
# [MATCH]: No 1 POLYPHONIC tone 4 ur mob every week ! Just txt PT2 to:['SPACY:POS-ADP'] 87575:['SPACY:POS-NUM'] . 1st Tone FREE ! so get txtin now and tell ur friends . 150p / tone . 16 reply HL 4info
# -------------------------
# [MATCH]: Free 1st week entry 2 TEXTPOD 4 a chance 2 win 40 GB iPod or Â£250 cash every wk . Txt POD to:['SPACY:POS-ADP'] 84128:['SPACY:POS-NUM'] Ts&Cs www.textpod.net custcare 08712405020 .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Let me know how it changes in:['SPACY:POS-ADP'] the next 6hrs:['SPACY:POS-NUM'] . It can even be appendix but you are out of that age range . However its not impossible . So just chill and let me know in 6hrs
# -------------------------
# [MATCH]: Eat jap done oso aft ur lect wat ... Ãœ got lect at:['SPACY:POS-ADP'] 12:['SPACY:POS-NUM'] rite ...
# -------------------------
# ==================================================
# 100%|██████████| 5/5 [00:05<00:00,  1.03s/it]
# Length 5 / 5; New candidates = 994
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Metric (global) = 0.223
# Examples ~ Class Negative:
# [MATCH]: True . It is passable . And if you get a high score and apply for phd , you get 5years:['SPACY:POS-NUM'] of salary . So it makes life easier .
# -------------------------
# [MATCH]: Rose for red , red for blood , blood for heart , heart for u. But u for me .... Send tis to all ur friends .. Including me .. If u like me .. If u get back , 1-u:['SPACY:POS-NUM'] r poor in relation ! 2-u need some 1 to support 3-u r frnd 2 many 4-some1 luvs u 5 + - some1 is praying god to marry u.:- ) try it ....
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Text & meet someone sexy today . U can find a date or even flirt its up to U. Join 4:['SPACY:POS-NUM'] just 10p . REPLY with NAME & AGE eg Sam 25 . 18 -msg recd@thirtyeight pence
# -------------------------
# [MATCH]: Do you want a new Video phone ? 600:['SPACY:POS-NUM'] anytime any network mins 400 Inclusive Video calls AND downloads 5 per week Free delTOMORROW call 08002888812 or reply NOW
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.806
# Match: 319 (8.9%)
# Gain = 0.175
# Metric (global) = 0.175
# Examples ~ Class Positive:
# [MATCH]: This is the 2nd time we have tried to contact u. U have won the Â£400:['SPACY:POS-PROPN'] prize . 2:['SPACY:POS-NUM'] claim is easy , just call 087104711148 NOW ! Only 10p per minute . BT - national - rate
# -------------------------
# [MATCH]: 8007 25p 4 Alfie Moon 's Children in Need song on ur mob . Tell ur m8s . Txt TONE CHARITY:['SPACY:POS-PROPN'] to 8007:['SPACY:POS-NUM'] for nokias or POLY CHARITY for polys : zed 08701417012 profit 2 charity
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Your opinion about me ? 1 . Over 2 . Jada:['SPACY:POS-PROPN'] 3:['SPACY:POS-NUM'] . Kusruthi 4 . Lovable 5 . Silent 6 . Spl character 7 . Not matured 8 . Stylish 9 . Simple Pls reply ..
# -------------------------
# [MATCH]: Boy ; I love u Grl : Hogolo Boy : gold chain kodstini Grl : Agalla Boy : necklace madstini Grl : agalla Boy : Hogli:['SPACY:POS-PROPN'] 1:['SPACY:POS-NUM'] mutai eerulli kodthini ! Grl : I love U kano;- )
# -------------------------
# ==================================================
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.984
# Match: 183 (5.1%)
# Gain = 0.152
# Metric (global) = 0.152
# Examples ~ Class Positive:
# [MATCH]: You 've won tkts to the EURO2004 CUP FINAL or Â£800 CASH , to collect CALL:['TEXT:call'] 09058099801:['SPACY:POS-NUM'] b4190604 , POBOX 7876150ppm
# -------------------------
# [MATCH]: 88800 and 89034 are premium phone services call:['TEXT:call'] 08718711108:['SPACY:POS-NUM']
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Yun ah.the ubi one say if Ã¼ wan call:['TEXT:call'] by tomorrow.call 67441233:['SPACY:POS-NUM'] look for irene.ere only got bus8,22,65,61,66,382 . Ubi cres , ubi tech park.6ph for 1st 5wkg days . Ã¨n
# -------------------------
# [MATCH]: Ummma.will call:['TEXT:call'] after check in.our:['SPACY:POS-NUM'] life will begin from qatar so pls pray very hard .
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.579
# Match: 518 (14.5%)
# Gain = 0.148
# Metric (global) = 0.148
# Examples ~ Class Positive:
# [MATCH]: 8007 FREE for 1st week ! No1:['SPACY:POS-PROPN'] Nokia:['SPACY:POS-PROPN'] tone 4 ur mob every week just txt NOKIA to 8007 Get txting and tell ur mates www.getzed.co.uk POBox 36504 W4 5WQ norm 150p / tone 16 +
# -------------------------
# [MATCH]: Congrats ! 2 mobile 3 G Videophones R yours . call 09063458130 now ! videochat wid your mates , play java games , Dload:['SPACY:POS-PROPN'] polyPH:['SPACY:POS-PROPN'] music , noline rentl .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Boy ; I love u Grl : Hogolo:['SPACY:POS-PROPN'] Boy:['SPACY:POS-PROPN'] : gold chain kodstini Grl : Agalla Boy : necklace madstini Grl : agalla Boy : Hogli 1 mutai eerulli kodthini ! Grl : I love U kano;- )
# -------------------------
# [MATCH]: Gud:['SPACY:POS-PROPN'] ni8:['SPACY:POS-PROPN'] dear .. slp well .. take care .. swt dreams .. Muah ..
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.613
# Match: 421 (11.8%)
# Gain = 0.129
# Metric (global) = 0.129
# Examples ~ Class Positive:
# [MATCH]: Do you want a New Nokia 3510i Colour Phone Delivered Tomorrow ? With:['SPACY:POS-ADP'] 200:['SPACY:POS-NUM'] FREE minutes to any mobile + 100 FREE text + FREE camcorder Reply or Call 08000930705
# -------------------------
# [MATCH]: YES ! The only place in town to meet exciting adult singles is now in the UK . Txt CHAT to:['SPACY:POS-ADP'] 86688:['SPACY:POS-NUM'] now ! 150p / Msg .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Let me know how it changes in:['SPACY:POS-ADP'] the next 6hrs:['SPACY:POS-NUM'] . It can even be appendix but you are out of that age range . However its not impossible . So just chill and let me know in 6hrs
# -------------------------
# [MATCH]: Hi . || Do u want | to join me with sts later ? || Meeting them at:['SPACY:POS-ADP'] five:['SPACY:POS-NUM'] . || Call u after class .
# -------------------------
# ==================================================

# %%
# Print the learned patterns
for idx, p in enumerate(the_patterns):
    print(f'Rank {idx+1}')
    print(p)
# Out:
# Rank 1
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Metric (global) = 0.223
# Examples ~ Class Negative:
# [MATCH]: 8:['SPACY:POS-NUM'] at the latest , g 's still there if you can scrounge up some ammo and want to give the new ak a try
# -------------------------
# [MATCH]: Ok . Not much to do here though . H&M Friday , ca nt wait . Dunno wot the hell i m gon na do for another 3:['SPACY:POS-NUM'] weeks ! Become a slob- oh wait , already done that !
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Great News ! Call FREEFONE 08006344447:['SPACY:POS-NUM'] to claim your guaranteed Â£1000 CASH or Â£2000 gift . Speak to a live operator NOW !
# -------------------------
# [MATCH]: You have 1:['SPACY:POS-NUM'] new voicemail . Please call 08719181503
# -------------------------
# ==================================================
# Rank 2
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.806
# Match: 319 (8.9%)
# Gain = 0.175
# Metric (global) = 0.175
# Examples ~ Class Positive:
# [MATCH]: Your 2004 account for 07XXXXXXXXX shows 786 unredeemed points . To claim call 08719181259 Identifier code : XXXXX:['SPACY:POS-PROPN'] Expires 26.03.05:['SPACY:POS-NUM']
# -------------------------
# [MATCH]: To review and KEEP the fantastic Nokia N - Gage game deck with Club Nokia:['SPACY:POS-PROPN'] , go 2:['SPACY:POS-NUM'] www.cnupdates.com/newsletter . unsubscribe from alerts reply with the word OUT
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Boy ; I love u Grl : Hogolo Boy : gold chain kodstini Grl : Agalla Boy : necklace madstini Grl : agalla Boy : Hogli:['SPACY:POS-PROPN'] 1:['SPACY:POS-NUM'] mutai eerulli kodthini ! Grl : I love U kano;- )
# -------------------------
# [MATCH]: Yar:['SPACY:POS-PROPN'] i wanted 2:['SPACY:POS-NUM'] scold u yest but late already ... I where got zhong se qing you ? If u ask me b4 he ask me then i 'll go out w u all lor . N u still can act so real .
# -------------------------
# ==================================================
# Rank 3
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.984
# Match: 183 (5.1%)
# Gain = 0.152
# Metric (global) = 0.152
# Examples ~ Class Positive:
# [MATCH]: Do you want a new video handset ? 750 anytime any network mins ? Half Price Line Rental ? Camcorder ? Reply or call:['TEXT:call'] 08000930705:['SPACY:POS-NUM'] for delivery tomorrow
# -------------------------
# [MATCH]: URGENT ! Your mobile number * * * * * * * * * * * * * * * WON a Â£2000 Bonus Caller prize on 10/06/03 ! This is the 2nd attempt to reach you ! Call:['TEXT:call'] 09066368753:['SPACY:POS-NUM'] ASAP ! Box 97N7QP , 150ppm
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Ummma.will call:['TEXT:call'] after check in.our:['SPACY:POS-NUM'] life will begin from qatar so pls pray very hard .
# -------------------------
# [MATCH]: Yun ah.the ubi one say if Ã¼ wan call:['TEXT:call'] by tomorrow.call 67441233:['SPACY:POS-NUM'] look for irene.ere only got bus8,22,65,61,66,382 . Ubi cres , ubi tech park.6ph for 1st 5wkg days . Ã¨n
# -------------------------
# ==================================================
# Rank 4
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.579
# Match: 518 (14.5%)
# Gain = 0.148
# Metric (global) = 0.148
# Examples ~ Class Positive:
# [MATCH]: Had your mobile 11 months or more ? U R entitled to Update to the latest colour mobiles with camera for Free ! Call The Mobile:['SPACY:POS-PROPN'] Update:['SPACY:POS-PROPN'] Co FREE on 08002986030
# -------------------------
# [MATCH]: URGENT ! We are trying to contact U.:['SPACY:POS-PROPN'] Todays:['SPACY:POS-PROPN'] draw shows that you have won a Â£800 prize GUARANTEED . Call 09050001808 from land line . Claim M95 . Valid12hrs only
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: IM:['SPACY:POS-PROPN'] FINE:['SPACY:POS-PROPN'] BABES AINT BEEN UP 2 MUCH THO ! SAW SCARY MOVIE YEST ITS QUITE FUNNY ! WANT 2MRW AFTERNOON ? AT TOWN OR MALL OR SUMTHIN?xx
# -------------------------
# [MATCH]: HI:['SPACY:POS-PROPN'] ITS KATE:['SPACY:POS-PROPN'] CAN U GIVE ME A RING ASAP XXX
# -------------------------
# ==================================================
# Rank 5
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.613
# Match: 421 (11.8%)
# Gain = 0.129
# Metric (global) = 0.129
# Examples ~ Class Positive:
# [MATCH]: PRIVATE ! Your 2003 Account Statement for:['SPACY:POS-ADP'] 07973788240:['SPACY:POS-NUM'] shows 800 un - redeemed S. I. M. points . Call 08715203649 Identifier Code : 40533 Expires 31/10/04
# -------------------------
# [MATCH]: Want explicit SEX in:['SPACY:POS-ADP'] 30:['SPACY:POS-NUM'] secs ? Ring 02073162414 now ! Costs 20p / min
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Ugh . Got ta drive back to:['SPACY:POS-ADP'] sd:['SPACY:POS-NUM'] from la . My butt is sore .
# -------------------------
# [MATCH]: Yeah there 's barely enough room for:['SPACY:POS-ADP'] the two:['SPACY:POS-NUM'] of us , x has too many fucking shoes . Sorry man , see you later
# -------------------------
# ==================================================
# Rank 6
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.811
# Match: 243 (6.8%)
# Gain = 0.129
# Metric (global) = 0.129
# Examples ~ Class Positive:
# [MATCH]: Do you want a New Nokia 3510i:['SPACY:POS-NUM'] Colour:['SPACY:POS-PROPN'] Phone Delivered Tomorrow ? With 200 FREE minutes to any mobile + 100 FREE text + FREE camcorder Reply or Call 08000930705
# -------------------------
# [MATCH]: Hi if ur lookin 4 saucy daytime fun wiv busty married woman Am free all next week Chat now 2 sort time 09099726429:['SPACY:POS-NUM'] JANINExx:['SPACY:POS-PROPN'] CallsÂ£1/minMobsmoreLKPOBOX177HP51FL
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: , ,   and   picking them up from various points | going 2 yeovil | and they will do the motor project 4:['SPACY:POS-NUM'] 3 hours |:['SPACY:POS-PROPN'] and then u take them home . || 12 2 5.30 max . || Very easy
# -------------------------
# [MATCH]: I am going to film 2day:['SPACY:POS-NUM'] da:['SPACY:POS-PROPN'] . At 6 pm . Sorry da .
# -------------------------
# ==================================================
# Rank 7
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Negative
# Precision: 0.526
# Match: 644 (18.1%)
# Gain = 0.119
# Metric (global) = 0.119
# Examples ~ Class Negative:
# [MATCH]: Hey darlin .. i can pick u up at college if u tell me wen & where 2 mt:['SPACY:POS-NOUN'] .. love Pete:['SPACY:POS-PROPN'] xx
# -------------------------
# [MATCH]: Sounds like a plan:['SPACY:POS-NOUN'] ! Cardiff:['SPACY:POS-PROPN'] is still here and still cold ! I 'm sitting on the radiator !
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: URGENT ! Your Mobile number has been awarded with a Â£2000 prize:['SPACY:POS-NOUN'] GUARANTEED:['SPACY:POS-PROPN'] . Call 09061790121 from land line . Claim 3030 . Valid 12hrs only 150ppm
# -------------------------
# [MATCH]: Spook up your mob:['SPACY:POS-NOUN'] with a Halloween:['SPACY:POS-PROPN'] collection of a logo & pic message plus a free eerie tone , txt CARD SPOOK to 8007 zed 08701417012150p per logo / pic
# -------------------------
# ==================================================
# Rank 8
# Pattern: [['TEXT:to'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.856
# Match: 194 (5.4%)
# Gain = 0.114
# Metric (global) = 0.114
# Examples ~ Class Positive:
# [MATCH]: WINNER ! ! As a valued network customer you have been selected to receivea Â£900 prize reward ! To:['TEXT:to'] claim call 09061701461:['SPACY:POS-NUM'] . Claim code KL341 . Valid 12 hours only .
# -------------------------
# [MATCH]: Email AlertFrom : Jeri StewartSize : 2KBSubject : Low - cost prescripiton drvgsTo listen to:['TEXT:to'] email call 123:['SPACY:POS-NUM']
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Aight , I should be there by 8 at the latest , probably closer to:['TEXT:to'] 7:['SPACY:POS-NUM'] . Are jay and tyler down or should we just do two trips ?
# -------------------------
# [MATCH]: I 'm now but have to:['TEXT:to'] wait till 2:['SPACY:POS-NUM'] for the bus to pick me .
# -------------------------
# ==================================================
# Rank 9
# Pattern: [['SPACY:POS-PROPN']]
# Window size: 3
# Class: Negative
# Precision: 0.690
# Match: 1347 (37.8%)
# Gain = 0.112
# Metric (global) = 0.112
# Examples ~ Class Negative:
# [MATCH]: Oh ... Icic:['SPACY:POS-PROPN'] ... K lor , den meet other day ...
# -------------------------
# [MATCH]: How i noe ... Did Ã¼ specify da:['SPACY:POS-PROPN'] domain as nusstu ... Ãœ still in sch ...
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Hi its LUCY:['SPACY:POS-PROPN'] Hubby at meetins all day Fri & I will B alone at hotel U fancy cumin over ? Pls leave msg 2day 09099726395 Lucy x CallsÂ£1/minMobsmoreLKPOBOX177HP51FL
# -------------------------
# [MATCH]: Congrats ! 2 mobile 3 G Videophones:['SPACY:POS-PROPN'] R yours . call 09063458130 now ! videochat wid your mates , play java games , Dload polyPH music , noline rentl .
# -------------------------
# ==================================================
# Rank 10
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.702
# Match: 272 (7.6%)
# Gain = 0.105
# Metric (global) = 0.105
# Examples ~ Class Positive:
# [MATCH]: PRIVATE ! Your 2003 Account Statement for 07808 XXXXXX shows 800 un - redeemed S. I. M. points:['SPACY:POS-NOUN'] . Call:['SPACY:POS-NOUN'] 08719899217:['SPACY:POS-NUM'] Identifier Code : 41685 Expires 07/11/04
# -------------------------
# [MATCH]: U 447801259231 have a secret admirer:['SPACY:POS-NOUN'] who:['SPACY:POS-NOUN'] is looking 2:['SPACY:POS-NUM'] make contact with U - find out who they R*reveal who thinks UR so special - call on 09058094597
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I REALLY NEED 2 KISS U I MISS U MY BABY:['SPACY:POS-NOUN'] FROM UR BABY:['SPACY:POS-NOUN'] 4EVA:['SPACY:POS-NUM']
# -------------------------
# [MATCH]: Ok i found dis pierre:['SPACY:POS-NOUN'] cardin:['SPACY:POS-NOUN'] one:['SPACY:POS-NUM'] which looks normal costs 20 its on sale .
# -------------------------
# ==================================================
# Rank 11
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 5
# Class: Positive
# Precision: 0.722
# Match: 255 (7.1%)
# Gain = 0.104
# Metric (global) = 0.104
# Examples ~ Class Positive:
# [MATCH]: 5p 4 alfie Moon 's Children in need song on ur mob . Tell ur m8s:['SPACY:POS-PROPN'] . Txt:['SPACY:POS-PROPN'] Tone:['SPACY:POS-PROPN'] charity to 8007 for Nokias or Poly charity for polys : zed 08701417012 profit 2 charity .
# -------------------------
# [MATCH]: PRIVATE ! Your 2003 Account Statement for shows 800 un - redeemed S.:['SPACY:POS-PROPN'] I.:['SPACY:POS-PROPN'] M.:['SPACY:POS-PROPN'] points . Call 08715203694 Identifier Code : 40533 Expires 31/10/04
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Today is ACCEPT DAY .. U Accept me as ? Brother:['SPACY:POS-PROPN'] Sister:['SPACY:POS-PROPN'] Lover:['SPACY:POS-PROPN'] Dear1 Best1 Clos1 Lvblefrnd Jstfrnd Cutefrnd Lifpartnr Belovd Swtheart Bstfrnd No rply means enemy
# -------------------------
# [MATCH]: Brainless:['SPACY:POS-PROPN'] Baby:['SPACY:POS-PROPN'] Doll:['SPACY:POS-PROPN'] .. :-D;- ) , vehicle sariyag drive madoke barolla ..
# -------------------------
# ==================================================
# Rank 12
# Pattern: [['TEXT:.'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.797
# Match: 202 (5.7%)
# Gain = 0.101
# Metric (global) = 0.101
# Examples ~ Class Positive:
# [MATCH]: Want to funk up ur fone with a weekly new tone reply TONES2U 2 this text . www.ringtones.co.uk , the original n best .:['TEXT:.'] Tones 3GBP:['SPACY:POS-NUM'] network operator rates apply
# -------------------------
# [MATCH]: WELL DONE ! Your 4 * Costa Del Sol Holiday or Â£5000 await collection .:['TEXT:.'] Call 09050090044:['SPACY:POS-NUM'] Now toClaim . SAE , TCs , POBox334 , Stockport , SK38xh , CostÂ£1.50/pm , Max10mins
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Solve d Case : A Man Was Found Murdered On   & lt;DECIMAL&gt ; . & lt;#&gt ;   AfterNoon .:['TEXT:.'] 1,His:['SPACY:POS-NUM'] wife called Police . 2,Police questioned everyone . 3,Wife : Sir , I was sleeping , when the murder took place . 4.Cook : I was cooking . 5.Gardener : I was picking vegetables . 6.House - Maid : I went 2 d post office . 7.Children : We went 2 play . 8.Neighbour : We went 2 a marriage . Police arrested d murderer Immediately . Who 's It ? Reply With Reason , If U r Brilliant .
# -------------------------
# [MATCH]: Nope watching tv at home ... Not going out .:['TEXT:.'] V:['SPACY:POS-NUM'] bored ...
# -------------------------
# ==================================================
# Rank 13
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.735
# Match: 238 (6.7%)
# Gain = 0.100
# Metric (global) = 0.100
# Examples ~ Class Positive:
# [MATCH]: SMS . ac JSco : Energy is high , but u may not know where 2channel:['SPACY:POS-NUM'] it . 2day:['SPACY:POS-NUM'] ur leadership skills r strong . Psychic ? Reply ANS w / question . End ? Reply END JSCO
# -------------------------
# [MATCH]: Not heard from U4 a while . Call 4 rude chat private line 01223585334 to cum . Wan 2C pics of me gettin shagged then text PIX to 8552:['SPACY:POS-NUM'] . 2End:['SPACY:POS-NUM'] send STOP 8552 SAM xxx
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I want to tel u:['SPACY:POS-NUM'] one:['SPACY:POS-NUM'] thing u should not mistake me k THIS IS THE MESSAGE THAT YOU SENT : )
# -------------------------
# [MATCH]: Ee msg na poortiyagi odalebeku : Hanumanji 7:['SPACY:POS-NUM'] name 1-Hanuman:['SPACY:POS-NUM'] 2-Bajarangabali 3-Maruti 4-Pavanaputra 5-Sankatmochan 6-Ramaduth 7-Mahaveer ee 7 name   & lt;#&gt ;   janarige ivatte kalisidare next saturday olage ondu good news keluviri ... ! Maretare inde 1 dodda problum nalli siguviri idu matra   & lt;#&gt ; % true .. Do n't neglet .
# -------------------------
# ==================================================
# Rank 14
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
# Window size: 4
# Class: Negative
# Precision: 0.585
# Match: 714 (20.0%)
# Gain = 0.095
# Metric (global) = 0.095
# Examples ~ Class Negative:
# [MATCH]: Our Prashanthettan:['SPACY:POS-PROPN'] 's mother:['SPACY:POS-NOUN'] passed away last night . pray for her and family .
# -------------------------
# [MATCH]: Should i buy him a blackberry bold 2 or torch . Should i buy him new or used . Let me know . Plus are you saying i should buy the   & lt;#&gt ; g:['SPACY:POS-PROPN'] wifi:['SPACY:POS-NOUN'] ipad . And what are you saying about the about the   & lt;#&gt ; g ?
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Congrats ! 2 mobile 3 G Videophones:['SPACY:POS-PROPN'] R:['SPACY:POS-NOUN'] yours . call 09061744553 now ! videochat wid ur mates , play java games , Dload polyH music , noline rentl . bx420 . ip4 . 5we . 150pm
# -------------------------
# [MATCH]: + 123 Congratulations - in this week 's competition draw u have won the Â£1450 prize to claim just call 09050002311 b4280703 . T&Cs:['SPACY:POS-PROPN'] / stop SMS:['SPACY:POS-NOUN'] 08718727868 . Over 18 only 150ppm
# -------------------------
# ==================================================
# Rank 15
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
# Window size: 4
# Class: Positive
# Precision: 0.597
# Match: 313 (8.8%)
# Gain = 0.085
# Metric (global) = 0.085
# Examples ~ Class Positive:
# [MATCH]: sports fans - get the latest sports news str * 2:['SPACY:POS-NUM'] ur:['SPACY:POS-ADP'] mobile 1 wk FREE PLUS a FREE TONE Txt SPORT ON to 8007 www.getzed.co.uk 0870141701216 + norm 4txt/120p
# -------------------------
# [MATCH]: < Forwarded from 88877>FREE:['SPACY:POS-NUM'] entry into:['SPACY:POS-ADP'] our Â£250 weekly comp just send the word ENTER to 88877 NOW . 18 T&C www.textcomp.com
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Oic cos me n my sis got no lunch today my dad went out ... So dunno whether 2:['SPACY:POS-NUM'] eat in:['SPACY:POS-ADP'] sch or wat ...
# -------------------------
# [MATCH]: Indians r poor but India is not a poor country . Says one:['SPACY:POS-NUM'] of:['SPACY:POS-ADP'] the swiss bank directors . He says that " & lt;#&gt ;   lac crore " of Indian money is deposited in swiss banks which can be used for ' taxless ' budget for   & lt;#&gt ;   yrs . Can give   & lt;#&gt ;   crore jobs to all Indians . From any village to Delhi 4 lane roads . Forever free power suply to more than   & lt;#&gt ;   social projects . Every citizen can get monthly   & lt;#&gt ; /- for   & lt;#&gt ;   yrs . No need of World Bank & amp ; IMF loan . Think how our money is blocked by rich politicians . We have full rights against corrupt politicians . Itna forward karo ki pura INDIA padhe.g.m . "
# -------------------------
# ==================================================
# Rank 16
# Pattern: [['SPACY:POS-ADJ'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.655
# Match: 258 (7.2%)
# Gain = 0.084
# Metric (global) = 0.084
# Examples ~ Class Positive:
# [MATCH]: This is the 2nd time we have tried 2 contact u. U have won the 750 Pound prize . 2 claim is easy:['SPACY:POS-ADJ'] , call 08712101358:['SPACY:POS-NUM'] NOW ! Only 10p per min . BT - national - rate
# -------------------------
# [MATCH]: Free 1st:['SPACY:POS-ADJ'] week entry 2:['SPACY:POS-NUM'] TEXTPOD 4 a chance 2 win 40 GB iPod or Â£250 cash every wk . Txt POD to 84128 Ts&Cs www.textpod.net custcare 08712405020 .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Nice line said by a broken heart- Plz do n't cum 1 more times infront of me ... Other wise once again I ll trust U ... Good:['SPACY:POS-ADJ'] 9:['SPACY:POS-NUM'] t : )
# -------------------------
# [MATCH]: Okies ... I 'll go yan jiu too ... We can skip ard oso , go cine den go mrt:['SPACY:POS-ADJ'] one:['SPACY:POS-NUM'] , blah blah blah ...
# -------------------------
# ==================================================
# Rank 17
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
# Window size: 5
# Class: Positive
# Precision: 0.649
# Match: 259 (7.3%)
# Gain = 0.083
# Metric (global) = 0.083
# Examples ~ Class Positive:
# [MATCH]: U can WIN Â£100 of Music:['SPACY:POS-PROPN'] Gift:['SPACY:POS-PROPN'] Vouchers every week:['SPACY:POS-NOUN'] starting NOW Txt the word DRAW to 87066 TsCs www . Idew.com SkillGame , 1Winaweek , age16 . 150ppermessSubscription
# -------------------------
# [MATCH]: FREE2DAY sexy St:['SPACY:POS-PROPN'] George:['SPACY:POS-PROPN'] 's Day pic:['SPACY:POS-NOUN'] of Jordan!Txt PIC to 89080 do nt miss out , then every wk a saucy celeb!4 more pics c PocketBabe.co.uk 0870241182716 Â£3/wk
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Solve d Case : A Man Was Found Murdered On   & lt;DECIMAL&gt ; . & lt;#&gt ;   AfterNoon . 1,His wife called Police . 2,Police questioned everyone . 3,Wife : Sir , I was sleeping , when the murder took place . 4.Cook : I was cooking . 5.Gardener : I was picking vegetables . 6.House - Maid : I went 2 d post office . 7.Children : We went 2 play . 8.Neighbour : We went 2 a marriage . Police arrested d murderer Immediately . Who 's It ? Reply With Reason:['SPACY:POS-PROPN'] , If U:['SPACY:POS-PROPN'] r:['SPACY:POS-NOUN'] Brilliant .
# -------------------------
# [MATCH]: Today is ACCEPT DAY .. U Accept me as ? Brother Sister Lover Dear1 Best1 Clos1 Lvblefrnd Jstfrnd Cutefrnd Lifpartnr Belovd:['SPACY:POS-PROPN'] Swtheart:['SPACY:POS-PROPN'] Bstfrnd No rply:['SPACY:POS-NOUN'] means enemy
# -------------------------
# ==================================================
# Rank 18
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.926
# Match: 121 (3.4%)
# Gain = 0.082
# Metric (global) = 0.082
# Examples ~ Class Positive:
# [MATCH]: 4mths half price Orange line rental & latest camera phones 4 FREE . Had your phone 11mths ? Call MobilesDirect:['SPACY:POS-PROPN'] free on:['SPACY:POS-ADP'] 08000938767:['SPACY:POS-NUM'] to update now ! or2stoptxt
# -------------------------
# [MATCH]: Sunshine Quiz ! Win a super Sony DVD recorder if you canname the capital of Australia ? Text:['SPACY:POS-PROPN'] MQUIZ to:['SPACY:POS-ADP'] 82277:['SPACY:POS-NUM'] . B
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I got ta collect da:['SPACY:POS-PROPN'] car at:['SPACY:POS-ADP'] 6:['SPACY:POS-NUM'] lei .
# -------------------------
# [MATCH]: Aiya we discuss later lar ... Pick:['SPACY:POS-PROPN'] Ã¼ up at:['SPACY:POS-ADP'] 4:['SPACY:POS-NUM'] is it ?
# -------------------------
# ==================================================
# Rank 19
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]
# Window size: 4
# Class: Positive
# Precision: 0.504
# Match: 421 (11.8%)
# Gain = 0.080
# Metric (global) = 0.080
# Examples ~ Class Positive:
# [MATCH]: SMS AUCTION You have won a Nokia 7250i . This is what you get when you win our FREE auction . To take part send Nokia:['SPACY:POS-PROPN'] to:['SPACY:POS-ADP'] 86021 now . HG / Suite342/2Lands Row / W1JHL 16 +
# -------------------------
# [MATCH]: pdate_Now - Double mins and 1000 txts on Orange tariffs . Latest Motorola , SonyEricsson & Nokia & Bluetooth FREE ! Call MobileUpd8:['SPACY:POS-PROPN'] on:['SPACY:POS-ADP'] 08000839402 or call2optout/!YHL
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Yup . Thk:['SPACY:POS-PROPN'] of:['SPACY:POS-ADP'] u oso boring wat .
# -------------------------
# [MATCH]: Somewhr someone is surely made 4 u. And God has decided a perfect time to make u meet dat person . . . . till den , . . . . . Enjoy:['SPACY:POS-PROPN'] ur:['SPACY:POS-ADP'] crushes .. !!!;- )
# -------------------------
# ==================================================
# Rank 20
# Pattern: [['SPACY:POS-NUM'], ['TEXT:.']]
# Window size: 4
# Class: Positive
# Precision: 0.591
# Match: 286 (8.0%)
# Gain = 0.074
# Metric (global) = 0.074
# Examples ~ Class Positive:
# [MATCH]: Orange customer , you may now claim your FREE CAMERA PHONE upgrade for your loyalty . Call now on 0207:['SPACY:POS-NUM'] 153 9996 .:['TEXT:.'] Offer ends 14thMarch . T&C 's apply . Opt - out availa
# -------------------------
# [MATCH]: You have been specially selected to receive a " 3000 award ! Call 08712402050 BEFORE the lines close . Cost 10ppm . 16:['SPACY:POS-NUM'] + .:['TEXT:.'] T&Cs apply . AG Promo
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: True . It is passable . And if you get a high score and apply for phd , you get 5years:['SPACY:POS-NUM'] of salary .:['TEXT:.'] So it makes life easier .
# -------------------------
# [MATCH]: Yup i thk cine is better cos no need 2 go down 2:['SPACY:POS-NUM'] plaza mah .:['TEXT:.']
# -------------------------
# ==================================================
# Rank 21
# Pattern: [['SPACY:POS-NOUN'], ['TEXT:call']]
# Window size: 4
# Class: Positive
# Precision: 0.791
# Match: 153 (4.3%)
# Gain = 0.073
# Metric (global) = 0.073
# Examples ~ Class Positive:
# [MATCH]: Want a new Video Phone ? 750 anytime any network mins ? Half price line rental free text for 3 months ? Reply:['SPACY:POS-NOUN'] or call:['TEXT:call'] 08000930705 for free delivery
# -------------------------
# [MATCH]: Orange customer , you may now claim your FREE CAMERA PHONE upgrade for your loyalty:['SPACY:POS-NOUN'] . Call:['TEXT:call'] now on 0207 153 9996 . Offer ends 14thMarch . T&C 's apply . Opt - out availa
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I 'm at home:['SPACY:POS-NOUN'] . Please call:['TEXT:call']
# -------------------------
# [MATCH]: My friends:['SPACY:POS-NOUN'] use to call:['TEXT:call'] the same .
# -------------------------
# ==================================================
# Rank 22
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.843
# Match: 127 (3.6%)
# Gain = 0.069
# Metric (global) = 0.069
# Examples ~ Class Positive:
# [MATCH]: 8007 FREE for 1st week ! No1:['SPACY:POS-PROPN'] Nokia tone:['SPACY:POS-NOUN'] 4:['SPACY:POS-NUM'] ur mob every week just txt NOKIA to 8007 Get txting and tell ur mates www.getzed.co.uk POBox 36504 W4 5WQ norm 150p / tone 16 +
# -------------------------
# [MATCH]: okmail : Dear Dave this is your final notice to collect your 4 * Tenerife Holiday or # 5000 CASH award ! Call 09061743806 from landline . TCs SAE:['SPACY:POS-PROPN'] Box326 CW25WX:['SPACY:POS-NOUN'] 150ppm:['SPACY:POS-NUM']
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: 1Apple / Day = No Doctor . 1Tulsi Leaf / Day = No Cancer . 1Lemon / Day = No Fat . 1Cup Milk / day = No Bone Problms 3 Litres Watr / Day = No Diseases:['SPACY:POS-PROPN'] Snd ths:['SPACY:POS-NOUN'] 2:['SPACY:POS-NUM'] Whom U Care .. :- )
# -------------------------
# [MATCH]: I REALLY NEED 2 KISS U I MISS U MY BABY FROM UR:['SPACY:POS-PROPN'] BABY:['SPACY:POS-NOUN'] 4EVA:['SPACY:POS-NUM']
# -------------------------
# ==================================================
# Rank 23
# Pattern: [['TEXT:i']]
# Window size: 3
# Class: Negative
# Precision: 0.983
# Match: 1327 (37.2%)
# Gain = 0.067
# Metric (global) = 0.067
# Examples ~ Class Negative:
# [MATCH]: Hey sexy buns ! What of that day ? No word from you this morning on YM ... :-( ... I:['TEXT:i'] think of you
# -------------------------
# [MATCH]: I:['TEXT:i'] do nt want to hear philosophy . Just say what happen
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Hi its LUCY Hubby at meetins all day Fri & I:['TEXT:i'] will B alone at hotel U fancy cumin over ? Pls leave msg 2day 09099726395 Lucy x CallsÂ£1/minMobsmoreLKPOBOX177HP51FL
# -------------------------
# [MATCH]: Hi babe its Jordan , how r u ? I:['TEXT:i'] m home from abroad and lonely , text me back if u wanna chat xxSP visionsms.com Text stop to stopCost 150p 08712400603
# -------------------------
# ==================================================
# Rank 24
# Pattern: [['SPACY:POS-SYM']]
# Window size: 3
# Class: Positive
# Precision: 0.756
# Match: 156 (4.4%)
# Gain = 0.067
# Metric (global) = 0.067
# Examples ~ Class Positive:
# [MATCH]: 8007 FREE for 1st week ! No1 Nokia tone 4 ur mob every week just txt NOKIA to 8007 Get txting and tell ur mates www.getzed.co.uk POBox 36504 W4 5WQ norm 150p /:['SPACY:POS-SYM'] tone 16 +
# -------------------------
# [MATCH]: FreeMsg : Txt : CALL to No : 86888 & claim your reward of 3 hours talk time to use from your phone now ! Subscribe6GBP /:['SPACY:POS-SYM'] mnth inc 3hrs 16 stop?txtStop
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Turns out my friends are staying for the whole show and wo n't be back til ~ & lt;#&gt ; , so feel free to go ahead and smoke that $:['SPACY:POS-SYM'] & lt;#&gt ;   worth
# -------------------------
# [MATCH]: Dear friends , sorry for the late information . Today is the birthday of our loving Ar . Praveesh . for more details log on to face book and see . Its his number +:['SPACY:POS-SYM'] & lt;#&gt ; . Do nt miss a delicious treat .
# -------------------------
# ==================================================
# Rank 25
# Pattern: [['TEXT:free']]
# Window size: 3
# Class: Positive
# Precision: 0.748
# Match: 159 (4.5%)
# Gain = 0.067
# Metric (global) = 0.067
# Examples ~ Class Positive:
# [MATCH]: pdate_Now - Double mins and 1000 txts on Orange tariffs . Latest Motorola , SonyEricsson & Nokia & Bluetooth FREE:['TEXT:free'] ! Call MobileUpd8 on 08000839402 or call2optout/!YHL
# -------------------------
# [MATCH]: Free:['TEXT:free'] video camera phones with Half Price line rental for 12 mths and 500 cross ntwk mins 100 txts . Call MobileUpd8 08001950382 or Call2OptOut/674 &
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Sorry i 'm not free:['TEXT:free'] ...
# -------------------------
# [MATCH]: Aight I 've been set free:['TEXT:free'] , think you could text me blake 's address ? It occurs to me I 'm not quite as sure what I 'm doing as I thought I was
# -------------------------
# ==================================================
# Rank 26
# Pattern: [['TEXT:txt']]
# Window size: 3
# Class: Positive
# Precision: 0.938
# Match: 96 (2.7%)
# Gain = 0.067
# Metric (global) = 0.067
# Examples ~ Class Positive:
# [MATCH]: ou are guaranteed the latest Nokia Phone , a 40 GB iPod MP3 player or a Â£500 prize ! Txt:['TEXT:txt'] word : COLLECT to No : 83355 ! IBHltd LdnW15H 150p / Mtmsgrcvd18
# -------------------------
# [MATCH]: Sunshine Quiz Wkly Q ! Win a top Sony DVD player if u know which country Liverpool played in mid week ? Txt:['TEXT:txt'] ansr to 82277 . Â£1.50 SP : Tyrone
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: On the road so ca nt txt:['TEXT:txt']
# -------------------------
# [MATCH]: I love u 2 babe ! R u sure everything is alrite . Is he being an idiot ? Txt:['TEXT:txt'] bak girlie
# -------------------------
# ==================================================
# Rank 27
# Pattern: [['SPACY:POS-NOUN'], ['TEXT:to']]
# Window size: 4
# Class: Negative
# Precision: 0.591
# Match: 552 (15.5%)
# Gain = 0.065
# Metric (global) = 0.065
# Examples ~ Class Negative:
# [MATCH]: I do n't want you to leave . But i 'm barely doing what:['SPACY:POS-NOUN'] i can to:['TEXT:to'] stay sane . fighting with you constantly is n't helping .
# -------------------------
# [MATCH]: I sent my scores:['SPACY:POS-NOUN'] to:['TEXT:to'] sophas and i had to do secondary application for a few schools . I think if you are thinking of applying , do a research on cost also . Contact joke ogunrinde , her school is one me the less expensive ones
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Fantasy Football is back on your TV:['SPACY:POS-NOUN'] . Go to:['TEXT:to'] Sky Gamestar on Sky Active and play Â£250k Dream Team . Scoring starts on Saturday , so register now!SKY OPT OUT to 88088
# -------------------------
# [MATCH]: Get a FREE mobile video player FREE movie:['SPACY:POS-NOUN'] . To:['TEXT:to'] collect text GO to 89105 . Its free ! Extra films can be ordered t 's and c 's apply . 18 yrs only
# -------------------------
# ==================================================
# Rank 28
# Pattern: [['TEXT:claim']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 77 (2.2%)
# Gain = 0.064
# Metric (global) = 0.064
# Examples ~ Class Positive:
# [MATCH]: URGENT ! Your Mobile number has been awarded a < UKP>2000 prize GUARANTEED . Call 09061790125 from landline . Claim:['TEXT:claim'] 3030 . Valid 12hrs only 150ppm
# -------------------------
# [MATCH]: FreeMsg : Claim:['TEXT:claim'] ur 250 SMS messages - Text OK to 84025 now!Use web2mobile 2 ur mates etc . Join Txt250.com for 1.50p / wk . T&C BOX139 , LA32WU . 16 . Remove txtX or stop
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Rank 29
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-ADP', 'TEXT:to']]
# Window size: 4
# Class: Positive
# Precision: 0.592
# Match: 250 (7.0%)
# Gain = 0.064
# Metric (global) = 0.064
# Examples ~ Class Positive:
# [MATCH]: Great News ! Call FREEFONE 08006344447 to claim your guaranteed Â£1000 CASH or Â£2000 gift:['SPACY:POS-NOUN'] . Speak to:['SPACY:POS-ADP', 'TEXT:to'] a live operator NOW !
# -------------------------
# [MATCH]: Please call Amanda with regard:['SPACY:POS-NOUN'] to:['SPACY:POS-ADP', 'TEXT:to'] renewing or upgrading your current T - Mobile handset free of charge . Offer ends today . Tel 0845 021 3680 subject to T 's and C 's
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Indians r poor but India is not a poor country . Says one of the swiss bank directors . He says that " & lt;#&gt ;   lac crore " of Indian money is deposited in swiss banks which can be used for ' taxless ' budget for   & lt;#&gt ;   yrs . Can give   & lt;#&gt ;   crore:['SPACY:POS-NOUN'] jobs to:['SPACY:POS-ADP', 'TEXT:to'] all Indians . From any village to Delhi 4 lane roads . Forever free power suply to more than   & lt;#&gt ;   social projects . Every citizen can get monthly   & lt;#&gt ; /- for   & lt;#&gt ;   yrs . No need of World Bank & amp ; IMF loan . Think how our money is blocked by rich politicians . We have full rights against corrupt politicians . Itna forward karo ki pura INDIA padhe.g.m . "
# -------------------------
# [MATCH]: Got ur mail Dileep.thank you so muchand:['SPACY:POS-NOUN'] look forward to:['SPACY:POS-ADP', 'TEXT:to'] lots of support ... very less contacts here , remember one venugopal you mentioned.tomorrow if not late , i shall try to come up till there.goodnight dear .
# -------------------------
# ==================================================
# Rank 30
# Pattern: [['TEXT:!']]
# Window size: 3
# Class: Negative
# Precision: 0.602
# Match: 575 (16.1%)
# Gain = 0.063
# Metric (global) = 0.063
# Examples ~ Class Negative:
# [MATCH]: I know !:['TEXT:!'] Grumpy old people . My mom was like you better not be lying . Then again I am always the one to play jokes ...
# -------------------------
# [MATCH]: Ta - Daaaaa !:['TEXT:!'] I am home babe , are you still up ?
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: money !:['TEXT:!'] ! ! you r a lucky winner ! 2 claim your prize text money 2 88600 over Â£1million to give away ! ppt150x3+normal text rate box403 w1t1jy
# -------------------------
# [MATCH]: Last Chance !:['TEXT:!'] Claim ur Â£150 worth of discount vouchers today ! Text SHOP to 85023 now ! SavaMob , offers mobile ! T Cs SavaMob POBOX84 , M263UZ . Â£3.00 Sub . 16
# -------------------------
# ==================================================
# Rank 31
# Pattern: [['TEXT:.'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.539
# Match: 297 (8.3%)
# Gain = 0.062
# Metric (global) = 0.062
# Examples ~ Class Positive:
# [MATCH]: This is the 2nd time we have tried 2 contact u. U have won the 750 Pound prize . 2 claim is easy , call 08712101358 NOW ! Only 10p per min .:['TEXT:.'] BT:['SPACY:POS-PROPN'] - national - rate
# -------------------------
# [MATCH]: U have a secret admirer .:['TEXT:.'] REVEAL:['SPACY:POS-PROPN'] who thinks U R So special . Call 09065174042 . To opt out Reply REVEAL STOP . 1.50 per msg recd . Cust care 07821230901
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Nothin comes to my mind .:['TEXT:.'] Ãœ:['SPACY:POS-PROPN'] help me buy hanger lor . Ur laptop not heavy ?
# -------------------------
# [MATCH]: Your opinion about me ? 1 . Over 2 .:['TEXT:.'] Jada:['SPACY:POS-PROPN'] 3 . Kusruthi 4 . Lovable 5 . Silent 6 . Spl character 7 . Not matured 8 . Stylish 9 . Simple Pls reply ..
# -------------------------
# ==================================================
# Rank 32
# Pattern: [['SPACY:POS-PROPN'], ['TEXT:.']]
# Window size: 4
# Class: Positive
# Precision: 0.522
# Match: 312 (8.7%)
# Gain = 0.061
# Metric (global) = 0.061
# Examples ~ Class Positive:
# [MATCH]: PRIVATE ! Your 2003 Account Statement for < fone no > shows 800 un - redeemed S. I.:['SPACY:POS-PROPN'] M. points .:['TEXT:.'] Call 08715203656 Identifier Code : 42049 Expires 26/10/04
# -------------------------
# [MATCH]: Dear U've been invited to XCHAT:['SPACY:POS-PROPN'] .:['TEXT:.'] This is our final attempt to contact u ! Txt CHAT to 86688 150p / MsgrcvdHG / Suite342/2Lands / Row / W1J6HL LDN 18 yrs
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Please da call me any mistake from my side sorry da . Pls da:['SPACY:POS-PROPN'] goto doctor .:['TEXT:.']
# -------------------------
# [MATCH]: HI DARLIN IM MISSIN U HOPE YOU ARE HAVING A GOOD TIME . WHEN ARE U BACK AND WHAT TIME IF U CAN GIVE ME A CALL AT:['SPACY:POS-PROPN'] HOME .:['TEXT:.'] JESS XX
# -------------------------
# ==================================================
# Rank 33
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 5
# Class: Positive
# Precision: 0.624
# Match: 213 (6.0%)
# Gain = 0.061
# Metric (global) = 0.061
# Examples ~ Class Positive:
# [MATCH]: URGENT ! We are trying to contact U. Todays draw shows that you have won a Â£800 prize GUARANTEED . Call 09050003091 from land:['SPACY:POS-NOUN'] line . Claim:['SPACY:POS-PROPN'] C52:['SPACY:POS-PROPN'] . Valid12hrs only
# -------------------------
# [MATCH]: Sorry ! U can not unsubscribe yet . THE MOB offer package has a min term of 54 weeks > pls resubmit request after expiry:['SPACY:POS-NOUN'] . Reply:['SPACY:POS-PROPN'] THEMOB HELP:['SPACY:POS-PROPN'] 4 more info
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: As per your request:['SPACY:POS-NOUN'] ' Maangalyam:['SPACY:POS-PROPN'] ( Alaipayuthe:['SPACY:POS-PROPN'] ) ' has been set as your callertune for all Callers . Press * 9 to copy your friends Callertune
# -------------------------
# [MATCH]: HIYA COMIN 2 BRISTOL 1 ST WEEK:['SPACY:POS-NOUN'] IN APRIL:['SPACY:POS-PROPN'] . LES:['SPACY:POS-PROPN'] GOT OFF + RUDI ON NEW YRS EVE BUT I WAS SNORING.THEY WERE DRUNK ! U BAK AT COLLEGE YET ? MY WORK SENDS INK 2 BATH .
# -------------------------
# ==================================================
# Rank 34
# Pattern: [['TEXT:mobile']]
# Window size: 3
# Class: Positive
# Precision: 0.942
# Match: 86 (2.4%)
# Gain = 0.060
# Metric (global) = 0.060
# Examples ~ Class Positive:
# [MATCH]: Hi 07734396839 IBH Customer Loyalty Offer : The NEW NOKIA6600 Mobile:['TEXT:mobile'] from ONLY Â£10 at TXTAUCTION!Txt word : START to No:81151 & get Yours Now!4 T &
# -------------------------
# [MATCH]: Had your mobile:['TEXT:mobile'] 11mths ? Update for FREE to Oranges latest colour camera mobiles & unlimited weekend calls . Call Mobile Upd8 on freefone 08000839402 or 2StopTxt
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Hi , Mobile:['TEXT:mobile'] no .   & lt;#&gt ;   has added you in their contact list on www.fullonsms.com It s a great place to send free sms to people For more visit fullonsms.com
# -------------------------
# [MATCH]: Am only searching for good dual sim mobile:['TEXT:mobile'] pa .
# -------------------------
# ==================================================
# Rank 35
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
# Window size: 5
# Class: Positive
# Precision: 0.591
# Match: 235 (6.6%)
# Gain = 0.060
# Metric (global) = 0.060
# Examples ~ Class Positive:
# [MATCH]: EASTENDERS TV:['SPACY:POS-NOUN'] Quiz . What:['SPACY:POS-NOUN'] FLOWER:['SPACY:POS-PROPN'] does DOT compare herself to ? D= VIOLET E= TULIP F= LILY txt D E or F to 84025 NOW 4 chance 2 WIN Â£100 Cash WKENT/150P16 +
# -------------------------
# [MATCH]: December only ! Had your mobile 11mths+ ? You are entitled to update to the latest colour:['SPACY:POS-NOUN'] camera:['SPACY:POS-NOUN'] mobile for Free:['SPACY:POS-PROPN'] ! Call The Mobile Update Co FREE on 08002986906
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I love ya too but try and budget your money:['SPACY:POS-NOUN'] better babe:['SPACY:POS-NOUN'] . Gary:['SPACY:POS-PROPN'] would freak on me if he knew
# -------------------------
# [MATCH]: Do whatever you want . You know what the rules are . We had a talk earlier this week about what had to start happening , you showing responsibility . Yet , every week it 's can i bend the rule this way ? What about that way ? Do whatever . I 'm tired of having thia same argument with you every week . And a   & lt;#&gt:['SPACY:POS-NOUN'] ;   movie:['SPACY:POS-NOUN'] DOESNT:['SPACY:POS-PROPN'] inlude the previews . You 're still getting in after 1 .
# -------------------------
# ==================================================
# Rank 36
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]
# Window size: 5
# Class: Positive
# Precision: 0.739
# Match: 142 (4.0%)
# Gain = 0.058
# Metric (global) = 0.058
# Examples ~ Class Positive:
# [MATCH]: Congratulations U can claim 2 VIP row A Tickets:['SPACY:POS-PROPN'] 2 C:['SPACY:POS-PROPN'] Blu in:['SPACY:POS-ADP'] concert in November or Blu gift guaranteed Call 09061104276 to claim TS&Cs www.smsco.net costÂ£3.75max
# -------------------------
# [MATCH]: ( Bank of Granite issues Strong - Buy:['SPACY:POS-PROPN'] ) EXPLOSIVE:['SPACY:POS-PROPN'] PICK FOR:['SPACY:POS-ADP'] OUR MEMBERS * * * * * UP OVER 300 % * * * * * * * * * * * Nasdaq Symbol CDGT That is a $ 5.00 per ..
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: NEFT:['SPACY:POS-PROPN'] Transaction:['SPACY:POS-PROPN'] with:['SPACY:POS-ADP'] reference number   & lt;#&gt ;   for Rs . & lt;DECIMAL&gt ;   has been credited to the beneficiary account on   & lt;#&gt ;   at   & lt;TIME&gt ; : & lt;#&gt ;
# -------------------------
# [MATCH]: Please protect yourself from e - threats . SIB never asks for sensitive information like Passwords , ATM:['SPACY:POS-PROPN'] / SMS:['SPACY:POS-PROPN'] PIN thru:['SPACY:POS-ADP'] email . Never share your password with anybody .
# -------------------------
# ==================================================
# Rank 37
# Pattern: [['SPACY:POS-ADJ'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Negative
# Precision: 0.530
# Match: 368 (10.3%)
# Gain = 0.057
# Metric (global) = 0.057
# Examples ~ Class Negative:
# [MATCH]: I am getting threats from your:['SPACY:POS-ADJ'] sales executive Shifad:['SPACY:POS-PROPN'] as i raised complaint against him . Its an official message .
# -------------------------
# [MATCH]: This is hoping you enjoyed your game yesterday . Sorry i 've not been in touch but pls know that you are fondly bein thot off . Have a great:['SPACY:POS-ADJ'] week . Abiola:['SPACY:POS-PROPN']
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: URGENT ! Your:['SPACY:POS-ADJ'] mobile No 077xxx:['SPACY:POS-PROPN'] WON a Â£2,000 Bonus Caller Prize on 02/06/03 ! This is the 2nd attempt to reach YOU ! Call 09066362206 ASAP ! BOX97N7QP , 150ppm
# -------------------------
# [MATCH]: pdate_Now - Double mins and 1000 txts on Orange tariffs . Latest:['SPACY:POS-ADJ'] Motorola:['SPACY:POS-PROPN'] , SonyEricsson & Nokia & Bluetooth FREE ! Call MobileUpd8 on 08000839402 or call2optout/!YHL
# -------------------------
# ==================================================
# Rank 38
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-ADJ']]
# Window size: 4
# Class: Positive
# Precision: 0.559
# Match: 245 (6.9%)
# Gain = 0.055
# Metric (global) = 0.055
# Examples ~ Class Positive:
# [MATCH]: Sex up ur mobile with a FREE sexy pic of Jordan ! Just text BABE to 88600 . Then every wk get a sexy celeb ! PocketBabe.co.uk 4:['SPACY:POS-NUM'] more:['SPACY:POS-ADJ'] pics . 16 Â£3/wk 087016248
# -------------------------
# [MATCH]: Your 2004 account for 07XXXXXXXXX:['SPACY:POS-NUM'] shows 786 unredeemed:['SPACY:POS-ADJ'] points . To claim call 08719181259 Identifier code : XXXXX Expires 26.03.05
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Hurry home u:['SPACY:POS-NUM'] big:['SPACY:POS-ADJ'] butt . Hang up on your last caller if u have to . Food is done and I 'm starving . Do n't ask what I cooked .
# -------------------------
# [MATCH]: They did't play one:['SPACY:POS-NUM'] day last:['SPACY:POS-ADJ'] year know even though they have very good team .. Like india .
# -------------------------
# ==================================================
# Rank 39
# Pattern: [['SENTIMENT:pos'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.542
# Match: 260 (7.3%)
# Gain = 0.054
# Metric (global) = 0.054
# Examples ~ Class Positive:
# [MATCH]: You have won:['SENTIMENT:pos'] a Nokia:['SPACY:POS-PROPN'] 7250i . This is what you get when you win our FREE auction . To take part send Nokia to 86021 now . HG / Suite342/2Lands Row / W1JHL 16 +
# -------------------------
# [MATCH]: all the lastest from Stereophonics , Marley , Dizzee Racal , Libertines and The Strokes ! Win:['SENTIMENT:pos'] Nookii:['SPACY:POS-PROPN'] games with Flirt ! ! Click TheMob WAP Bookmark or text WAP to 82468
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Y?WHERE U AT DOGBREATH ? ITS JUST SOUNDING LIKE:['SENTIMENT:pos'] JAN:['SPACY:POS-PROPN'] C THATÂ ’S AL ! ! ! ! ! ! ! ! !
# -------------------------
# [MATCH]: This is wishing you a great:['SENTIMENT:pos'] day . Moji:['SPACY:POS-PROPN'] told me about your offer and as always i was speechless . You offer so easily to go to great lengths on my behalf and its stunning . My exam is next friday . After that i will keep in touch more . Sorry .
# -------------------------
# ==================================================
# Rank 40
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.802
# Match: 111 (3.1%)
# Gain = 0.053
# Metric (global) = 0.053
# Examples ~ Class Positive:
# [MATCH]: Hi if ur lookin 4 saucy daytime fun wiv busty married woman Am free all next week:['SPACY:POS-NOUN'] Chat:['SPACY:POS-PROPN'] now 2:['SPACY:POS-NUM'] sort time 09099726429 JANINExx CallsÂ£1/minMobsmoreLKPOBOX177HP51FL
# -------------------------
# [MATCH]: Here is your discount code RP176781 . To stop further messages reply stop . www.regalportfolio.co.uk:['SPACY:POS-NOUN'] . Customer Services:['SPACY:POS-PROPN'] 08717205546:['SPACY:POS-NUM']
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Kent vale lor:['SPACY:POS-NOUN'] ... Ãœ:['SPACY:POS-PROPN'] wait 4:['SPACY:POS-NUM'] me there ar ?
# -------------------------
# [MATCH]: IM REALY SOZ:['SPACY:POS-NOUN'] IMAT MY MUMS:['SPACY:POS-PROPN'] 2NITE:['SPACY:POS-NUM'] WHAT ABOUT 2MORO
# -------------------------
# ==================================================
# Rank 41
# Pattern: [['TEXT:.'], ['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.985
# Match: 67 (1.9%)
# Gain = 0.053
# Metric (global) = 0.053
# Examples ~ Class Positive:
# [MATCH]: PRIVATE ! Your 2003 Account Statement for shows 800 un - redeemed S. I. M. points .:['TEXT:.'] Call:['TEXT:call'] 08718738002:['SPACY:POS-NUM'] Identifier Code : 48922 Expires 21/11/04
# -------------------------
# [MATCH]: Not heard from U4 a while .:['TEXT:.'] Call:['TEXT:call'] 4:['SPACY:POS-NUM'] rude chat private line 01223585334 to cum . Wan 2C pics of me gettin shagged then text PIX to 8552 . 2End send STOP 8552 SAM xxx
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I 'm in a movie .:['TEXT:.'] Call:['TEXT:call'] me 4:['SPACY:POS-NUM'] wat ?
# -------------------------
# ==================================================
# Rank 42
# Pattern: [['HYPERNYM:communication.n.02'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.923
# Match: 78 (2.2%)
# Gain = 0.052
# Metric (global) = 0.052
# Examples ~ Class Positive:
# [MATCH]: Do you want a new Video phone ? 600 anytime any network mins 400 Inclusive Video calls:['HYPERNYM:communication.n.02'] AND downloads 5:['SPACY:POS-NUM'] per week Free delTOMORROW call 08002888812 or reply NOW
# -------------------------
# [MATCH]: 83039 62735=Â£450 UK Break AccommodationVouchers terms & conditions apply . 2 claim you mustprovide your claim number:['HYPERNYM:communication.n.02'] which is 15541:['SPACY:POS-NUM']
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Ask g or iouri , I 've told the story:['HYPERNYM:communication.n.02'] like ten:['SPACY:POS-NUM'] times already
# -------------------------
# [MATCH]: Oh god i am happy to see your message:['HYPERNYM:communication.n.02'] after 3:['SPACY:POS-NUM'] days
# -------------------------
# ==================================================
# Rank 43
# Pattern: [['HYPERNYM:win.v.01', 'SENTIMENT:pos']]
# Window size: 3
# Class: Positive
# Precision: 0.922
# Match: 77 (2.2%)
# Gain = 0.051
# Metric (global) = 0.051
# Examples ~ Class Positive:
# [MATCH]: This is the 2nd time we have tried 2 contact u. U have won:['HYPERNYM:win.v.01', 'SENTIMENT:pos'] the 750 Pound prize . 2 claim is easy , call 08718726970 NOW ! Only 10p per min . BT - national - rate
# -------------------------
# [MATCH]: Sunshine Quiz Wkly Q ! Win:['HYPERNYM:win.v.01', 'SENTIMENT:pos'] a top Sony DVD player if u know which country the Algarve is in ? Txt ansr to 82277 . Â£1.50 SP : Tyrone
# ...
# Window size: 4
# Class: Positive
# Precision: 0.838
# Match: 74 (2.1%)
# Gain = 0.039
# Metric (global) = 0.039
# Examples ~ Class Positive:
# [MATCH]: A Â£400 XMAS REWARD IS WAITING FOR YOU ! Our computer has randomly picked you from our loyal mobile customers to receive a Â£400 reward:['SENTIMENT:pos'] . Just call:['TEXT:call'] 09066380611
# -------------------------
# [MATCH]: You have WON a guaranteed Â£1000 cash or a Â£2000 prize . To claim yr prize:['SENTIMENT:pos'] call:['TEXT:call'] our customer service representative on 08714712412 between 10am-7pm Cost 10p
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Once free:['SENTIMENT:pos'] call:['TEXT:call'] me sir .
# -------------------------
# [MATCH]: U calling me right:['SENTIMENT:pos'] ? Call:['TEXT:call'] my hand phone ...
# -------------------------
# ==================================================
# Rank 88
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.868
# Match: 68 (1.9%)
# Gain = 0.038
# Metric (global) = 0.038
# Examples ~ Class Positive:
# [MATCH]: HOT LIVE FANTASIES call now 08707509020 Just 20p per min NTT Ltd , PO Box 1327:['SPACY:POS-NUM'] Croydon:['SPACY:POS-PROPN'] CR9 5WB:['SPACY:POS-NUM'] 0870 is a national rate call
# -------------------------
# [MATCH]: Urgent ! call 09066612661 from landline . Your complementary 4 * Tenerife Holiday or Â£10,000 cash await collection SAE T&Cs PO Box 3:['SPACY:POS-NUM'] WA14:['SPACY:POS-PROPN'] 2PX 150ppm:['SPACY:POS-NUM'] 18 + Sender : Hol Offer
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I am going to film 2day:['SPACY:POS-NUM'] da:['SPACY:POS-PROPN'] . At 6:['SPACY:POS-NUM'] pm . Sorry da .
# -------------------------
# [MATCH]: Your opinion about me ? 1 . Over 2:['SPACY:POS-NUM'] . Jada:['SPACY:POS-PROPN'] 3:['SPACY:POS-NUM'] . Kusruthi 4 . Lovable 5 . Silent 6 . Spl character 7 . Not matured 8 . Stylish 9 . Simple Pls reply ..
# -------------------------
# ==================================================
# Rank 89
# Pattern: [['HYPERNYM:symbol.n.01']]
# Window size: 3
# Class: Positive
# Precision: 0.764
# Match: 89 (2.5%)
# Gain = 0.038
# Metric (global) = 0.038
# Examples ~ Class Positive:
# [MATCH]: This is the 2nd time we have tried 2 contact u. U have won the 750 Pound prize:['HYPERNYM:symbol.n.01'] . 2 claim is easy , call 08712101358 NOW ! Only 10p per min . BT - national - rate
# -------------------------
# [MATCH]: This is the 2nd time we have tried to contact u. U have won the Â£1450 prize:['HYPERNYM:symbol.n.01'] to claim just call 09053750005 b4 310303 . T&Cs / stop SMS 08718725756 . 140ppm
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Height of " Oh shit .... ! ! " situation : A guy throws a luv letter:['HYPERNYM:symbol.n.01'] on a gal but falls on her brothers head who s a gay,.;-):-D
# -------------------------
# [MATCH]: Lol yep did that yesterday . Already got my fireplace . Now its just another icon:['HYPERNYM:symbol.n.01'] sitting there for me .
# -------------------------
# ==================================================
# Rank 90
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
# Window size: 5
# Class: Positive
# Precision: 0.543
# Match: 184 (5.2%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: < Forwarded from:['SPACY:POS-ADP'] 448712404000>Please:['SPACY:POS-NUM'] CALL:['SPACY:POS-NOUN'] 08712404000 immediately as there is an urgent message waiting for you .
# -------------------------
# [MATCH]: Free video camera phones with Half Price line rental for:['SPACY:POS-ADP'] 12:['SPACY:POS-NUM'] mths:['SPACY:POS-NOUN'] and 500 cross ntwk mins 100 txts . Call MobileUpd8 08001950382 or Call2OptOut/674 &
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: You know my old Dom I told you about yesterday ? His name is Roger ? He got in touch with me last night and wants me to meet him today at:['SPACY:POS-ADP'] 2:['SPACY:POS-NUM'] pm:['SPACY:POS-NOUN']
# -------------------------
# [MATCH]: Nothing , smsing u n xy lor . Sorry lor da guys neva c u in person but they sort of know u lor . So u wan 2 meet them xy ask me 2 bring u along:['SPACY:POS-ADP'] 4:['SPACY:POS-NUM'] our next meeting:['SPACY:POS-NOUN'] .
# -------------------------
# ==================================================
# Rank 91
# Pattern: [['TEXT:!'], ['SPACY:POS-ADJ']]
# Window size: 4
# Class: Positive
# Precision: 0.648
# Match: 125 (3.5%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: WIN URGENT !:['TEXT:!'] Your:['SPACY:POS-ADJ'] mobile number has been awarded with a Â£2000 prize GUARANTEED call 09061790121 from land line . claim 3030 valid 12hrs only 150ppm
# -------------------------
# [MATCH]: Congrats !:['TEXT:!'] 1 year special:['SPACY:POS-ADJ'] cinema pass for 2 is yours . call 09061209465 now ! C Suprman V , Matrix3 , StarWars3 , etc all 4 FREE ! bx420-ip4 - 5we . 150pm . Do nt miss out !
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Good morning princess !:['TEXT:!'] Have a great:['SPACY:POS-ADJ'] day !
# -------------------------
# [MATCH]: Ca nt believe i said so many things to you this morning when all i really wanted to say was good morning , i love you !:['TEXT:!'] Have a beautiful:['SPACY:POS-ADJ'] morning . See you in the library later .
# -------------------------
# ==================================================
# Rank 92
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
# Window size: 6
# Class: Positive
# Precision: 0.914
# Match: 58 (1.6%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: Great:['SPACY:POS-PROPN'] News:['SPACY:POS-PROPN'] ! Call:['SPACY:POS-NOUN'] FREEFONE 08006344447:['SPACY:POS-NUM'] to claim your guaranteed Â£1000 CASH or Â£2000 gift . Speak to a live operator NOW !
# -------------------------
# [MATCH]: URGENT ! We are trying to contact you . Last weekends draw shows that you have won a Â£900:['SPACY:POS-PROPN'] prize GUARANTEED:['SPACY:POS-PROPN'] . Call:['SPACY:POS-NOUN'] 09061701939:['SPACY:POS-NUM'] . Claim code S89 . Valid 12hrs only
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: HIYA:['SPACY:POS-PROPN'] STU:['SPACY:POS-PROPN'] WOT:['SPACY:POS-NOUN'] U UP 2.IM:['SPACY:POS-NUM'] IN SO MUCH TRUBLE AT HOME AT MOMENT EVONE HATES ME EVEN U ! WOT THE HELL AV I DONE NOW ? Y WONT U JUST TELL ME TEXT BCK PLEASE LUV DAN
# -------------------------
# [MATCH]: THANX4 TODAY:['SPACY:POS-PROPN'] CER:['SPACY:POS-PROPN'] IT:['SPACY:POS-NOUN'] WAS NICE 2:['SPACY:POS-NUM'] CATCH UP BUT WE AVE 2 FIND MORE TIME MORE OFTEN OH WELL TAKE CARE C U SOON.C
# -------------------------
# ==================================================
# Rank 93
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-DET']]
# Window size: 4
# Class: Positive
# Precision: 0.634
# Match: 131 (3.7%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: No 1 POLYPHONIC tone 4:['SPACY:POS-NUM'] ur mob every:['SPACY:POS-DET'] week ! Just txt PT2 to 87575 . 1st Tone FREE ! so get txtin now and tell ur friends . 150p / tone . 16 reply HL 4info
# -------------------------
# [MATCH]: You have won ? 1,000:['SPACY:POS-NUM'] cash or a:['SPACY:POS-DET'] ? 2,000 prize ! To claim , call09050000327 . T&C : RSTM , SW7 3SS . 150ppm
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: You are always putting your business out there . You put pictures of your ass on facebook . You are one:['SPACY:POS-NUM'] of the:['SPACY:POS-DET'] most open people i 've ever met . Why would i think a picture of your room would hurt you , make you feel violated .
# -------------------------
# [MATCH]: Hello hun how ru ? Its here by the way . I m good . Been on 2:['SPACY:POS-NUM'] dates with that:['SPACY:POS-DET'] guy i met in walkabout so far . We have to meet up soon . How s everyone else ?
# -------------------------
# ==================================================
# Rank 94
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['TEXT:to']]
# Window size: 5
# Class: Positive
# Precision: 0.565
# Match: 168 (4.7%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: Congratulations:['SPACY:POS-NOUN'] ! Thanks:['SPACY:POS-NOUN'] to:['TEXT:to'] a good friend U have WON the Â£2,000 Xmas prize . 2 claim is easy , just call 08718726971 NOW ! Only 10p per minute . BT - national - rate .
# -------------------------
# [MATCH]: Talk sexy ! ! Make new friends or fall in love in the worlds most discreet text dating service . Just text:['SPACY:POS-NOUN'] VIP:['SPACY:POS-NOUN'] to:['TEXT:to'] 83110 and see who you could meet .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: i see . When we finish we have loads:['SPACY:POS-NOUN'] of loans:['SPACY:POS-NOUN'] to:['TEXT:to'] pay
# -------------------------
# [MATCH]: Lol ! Nah was n't too bad thanks:['SPACY:POS-NOUN'] . Its good:['SPACY:POS-NOUN'] to:['TEXT:to'] b home but its been quite a reality check . How s ur day been ? Did u do anything with website ?
# -------------------------
# ==================================================
# Rank 95
# Pattern: [['SENTIMENT:pos'], ['SPACY:POS-DET'], ['SPACY:POS-PROPN']]
# Window size: 5
# Class: Positive
# Precision: 0.797
# Match: 79 (2.2%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: For your chance to WIN:['SENTIMENT:pos'] a:['SPACY:POS-DET'] FREE Bluetooth:['SPACY:POS-PROPN'] Headset then simply reply back with " ADP "
# -------------------------
# [MATCH]: URGENT ! We are trying to contact you . Last weekends draw shows that you have won:['SENTIMENT:pos'] a:['SPACY:POS-DET'] Â£900:['SPACY:POS-PROPN'] prize GUARANTEED . Call 09061701939 . Claim code S89 . Valid 12hrs only
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Height of Confidence:['SENTIMENT:pos'] : All the:['SPACY:POS-DET'] Aeronautics:['SPACY:POS-PROPN'] professors wer calld & amp ; they wer askd 2 sit in an aeroplane . Aftr they sat they wer told dat the plane ws made by their students . Dey all hurried out of d plane .. Bt only 1 did nt move ... He said:"if it is made by my students , this wo nt even start ........ Datz confidence ..
# -------------------------
# [MATCH]: Talk With Yourself Atleast Once In A Day ... ! ! ! Otherwise You Will Miss Your Best:['SENTIMENT:pos'] FRIEND In This:['SPACY:POS-DET'] WORLD:['SPACY:POS-PROPN'] ... ! ! ! -Shakespeare- SHESIL   & lt;#&gt ;
# -------------------------
# ==================================================
# Rank 96
# Pattern: [['TEXT:.'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.875
# Match: 64 (1.8%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: U have won a nokia 6230 plus a free digital camera . This is what u get when u win our FREE auction . To take part send NOKIA to 83383 now .:['TEXT:.'] POBOX114/14TCR:['SPACY:POS-PROPN'] / W1 16:['SPACY:POS-NUM']
# -------------------------
# [MATCH]: FREE > Ringtone ! Reply REAL or POLY eg REAL1 1 .:['TEXT:.'] PushButton:['SPACY:POS-PROPN'] 2:['SPACY:POS-NUM'] . DontCha 3 . BabyGoodbye 4 . GoldDigger 5 . WeBeBurnin 1st tone FREE and 6 more when u join for Â£3/wk
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: MY NO .:['TEXT:.'] IN LUTON:['SPACY:POS-PROPN'] 0125698789:['SPACY:POS-NUM'] RING ME IF UR AROUND ! H *
# -------------------------
# [MATCH]: Thank You for calling . Forgot to say Happy Onam to you Sirji . I am fine here and remembered you when i met an insurance person . Meet You in Qatar Insha Allah .:['TEXT:.'] Rakhesh:['SPACY:POS-PROPN'] , ex:['SPACY:POS-NUM'] Tata AIG who joined TISSCO , Tayseer .
# -------------------------
# ==================================================
# Rank 97
# Pattern: [['HYPERNYM:statement.n.01']]
# Window size: 3
# Class: Positive
# Precision: 0.692
# Match: 107 (3.0%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: Win the newest â€œHarry Potter and the Order of the Phoenix ( Book 5 ) reply HARRY , answer:['HYPERNYM:statement.n.01'] 5 questions - chance to be the first among readers !
# -------------------------
# [MATCH]: You have an important customer service announcement:['HYPERNYM:statement.n.01'] from PREMIER .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Do whatever you want . You know what the rules are . We had a talk earlier this week about what had to start happening , you showing responsibility . Yet , every week it 's can i bend the rule this way ? What about that way ? Do whatever . I 'm tired of having thia same argument:['HYPERNYM:statement.n.01'] with you every week . And a   & lt;#&gt ;   movie DOESNT inlude the previews . You 're still getting in after 1 .
# -------------------------
# [MATCH]: How long before you get reply:['HYPERNYM:statement.n.01'] , just defer admission til next semester
# -------------------------
# ==================================================
# Rank 98
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
# Window size: 5
# Class: Positive
# Precision: 0.520
# Match: 198 (5.6%)
# Gain = 0.036
# Metric (global) = 0.036
# Examples ~ Class Positive:
# [MATCH]: Want to funk up ur fone with a weekly new tone reply:['SPACY:POS-NOUN'] TONES2U:['SPACY:POS-PROPN'] 2 this text:['SPACY:POS-NOUN'] . www.ringtones.co.uk , the original n best . Tones 3GBP network operator rates apply
# -------------------------
# [MATCH]: WIN a year supply of CDs 4 a store of ur choice worth Â£500 & enter our Â£100 Weekly draw txt MUSIC:['SPACY:POS-NOUN'] to 87066 Ts&Cs:['SPACY:POS-PROPN'] www:['SPACY:POS-NOUN'] . Ldew.com.subs16 + 1win150ppmx3
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Storming msg:['SPACY:POS-NOUN'] : Wen:['SPACY:POS-PROPN'] u lift:['SPACY:POS-NOUN'] d phne , u say " HELLO " Do u knw wt is d real meaning of HELLO ? ? . . . It 's d name of a girl .. ! . . . Yes .. And u knw who is dat girl ? ? " Margaret Hello " She is d girlfrnd f Grahmbell who invnted telphone ... . . . . Moral : One can 4get d name of a person , bt not his girlfrnd ... G o o d n i g h t . . .@
# -------------------------
# [MATCH]: HIYA STU WOT U UP 2.IM IN SO MUCH TRUBLE AT HOME AT MOMENT EVONE HATES ME EVEN U ! WOT THE HELL AV I DONE NOW ? Y WONT U JUST TELL ME TEXT:['SPACY:POS-NOUN'] BCK:['SPACY:POS-PROPN'] PLEASE LUV DAN:['SPACY:POS-NOUN']
# -------------------------
# ==================================================
# Rank 99
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
# Window size: 5
# Class: Positive
# Precision: 1.000
# Match: 44 (1.2%)
# Gain = 0.036
# Metric (global) = 0.036
# Examples ~ Class Positive:
# [MATCH]: Urgent ! call:['TEXT:call'] 09061749602:['SPACY:POS-NUM'] from:['SPACY:POS-ADP'] Landline . Your complimentary 4 * Tenerife Holiday or Â£10,000 cash await collection SAE T&Cs BOX 528 HP20 1YF 150ppm 18 +
# -------------------------
# [MATCH]: Guess what ! Somebody you know secretly fancies you ! Wanna find out who it is ? Give us a call:['TEXT:call'] on 09065394514:['SPACY:POS-NUM'] From:['SPACY:POS-ADP'] Landline DATEBox1282EssexCM61XN 150p / min 18
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Rank 100
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['TEXT:.'], ['SPACY:POS-NUM']]
# Window size: 6
# Class: Positive
# Precision: 1.000
# Match: 44 (1.2%)
# Gain = 0.036
# Metric (global) = 0.036
# Examples ~ Class Positive:
# [MATCH]: URGENT ! We are trying to contact you . Last weekends draw shows that you have won a Â£900:['SPACY:POS-PROPN'] prize:['SPACY:POS-NOUN'] GUARANTEED .:['TEXT:.'] Call 09061701851:['SPACY:POS-NUM'] . Claim code K61 . Valid 12hours only
# -------------------------
# [MATCH]: WIN a year supply of CDs 4 a store of ur choice worth Â£500 & enter our Â£100 Weekly draw txt MUSIC to 87066 Ts&Cs:['SPACY:POS-PROPN'] www:['SPACY:POS-NOUN'] .:['TEXT:.'] Ldew.com.subs16 + 1win150ppmx3:['SPACY:POS-NUM']
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================

# %%
print(f'  #    class Cov(%)    Prec    Gain    Pattern')
for idx, p in enumerate(the_patterns):
    print(f'{idx+1:>3} {p.support_class}   {round(p.coverage*100, 1):>4}   {p.precision:.3f}   {p.metric:.3f}    {p.get_pattern_id()}')
# Out:
#   #    class Cov(%)    Prec    Gain    Pattern
#   1 Negative   26.2   0.526   0.223    [['SPACY:POS-NUM']]
#   2 Positive    8.9   0.806   0.175    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#   3 Positive    5.1   0.984   0.152    [['TEXT:call'], ['SPACY:POS-NUM']]
#   4 Positive   14.5   0.579   0.148    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#   5 Positive   11.8   0.613   0.129    [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
#   6 Positive    6.8   0.811   0.129    [['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
#   7 Negative   18.1   0.526   0.119    [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
#   8 Positive    5.4   0.856   0.114    [['TEXT:to'], ['SPACY:POS-NUM']]
#   9 Negative   37.8   0.690   0.112    [['SPACY:POS-PROPN']]
#  10 Positive    7.6   0.702   0.105    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  11 Positive    7.1   0.722   0.104    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  12 Positive    5.7   0.797   0.101    [['TEXT:.'], ['SPACY:POS-NUM']]
#  13 Positive    6.7   0.735   0.100    [['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
#  14 Negative   20.0   0.585   0.095    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  15 Positive    8.8   0.597   0.085    [['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
#  16 Positive    7.2   0.655   0.084    [['SPACY:POS-ADJ'], ['SPACY:POS-NUM']]
#  17 Positive    7.3   0.649   0.083    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  18 Positive    3.4   0.926   0.082    [['SPACY:POS-PROPN'], ['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
#  19 Positive   11.8   0.504   0.080    [['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]
#  20 Positive    8.0   0.591   0.074    [['SPACY:POS-NUM'], ['TEXT:.']]
#  21 Positive    4.3   0.791   0.073    [['SPACY:POS-NOUN'], ['TEXT:call']]
#  22 Positive    3.6   0.843   0.069    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  23 Negative   37.2   0.983   0.067    [['TEXT:i']]
#  24 Positive    4.4   0.756   0.067    [['SPACY:POS-SYM']]
#  25 Positive    4.5   0.748   0.067    [['TEXT:free']]
#  26 Positive    2.7   0.938   0.067    [['TEXT:txt']]
#  27 Negative   15.5   0.591   0.065    [['SPACY:POS-NOUN'], ['TEXT:to']]
#  28 Positive    2.2   1.000   0.064    [['TEXT:claim']]
#  29 Positive    7.0   0.592   0.064    [['SPACY:POS-NOUN'], ['SPACY:POS-ADP', 'TEXT:to']]
#  30 Negative   16.1   0.602   0.063    [['TEXT:!']]
#  31 Positive    8.3   0.539   0.062    [['TEXT:.'], ['SPACY:POS-PROPN']]
#  32 Positive    8.7   0.522   0.061    [['SPACY:POS-PROPN'], ['TEXT:.']]
#  33 Positive    6.0   0.624   0.061    [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  34 Positive    2.4   0.942   0.060    [['TEXT:mobile']]
#  35 Positive    6.6   0.591   0.060    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
#  36 Positive    4.0   0.739   0.058    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]
#  37 Negative   10.3   0.530   0.057    [['SPACY:POS-ADJ'], ['SPACY:POS-PROPN']]
#  38 Positive    6.9   0.559   0.055    [['SPACY:POS-NUM'], ['SPACY:POS-ADJ']]
#  39 Positive    7.3   0.542   0.054    [['SENTIMENT:pos'], ['SPACY:POS-PROPN']]
#  40 Positive    3.1   0.802   0.053    [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  41 Positive    1.9   0.985   0.053    [['TEXT:.'], ['TEXT:call'], ['SPACY:POS-NUM']]
#  42 Positive    2.2   0.923   0.052    [['HYPERNYM:communication.n.02'], ['SPACY:POS-NUM']]
#  43 Positive    2.2   0.922   0.051    [['HYPERNYM:win.v.01', 'SENTIMENT:pos']]
#  44 Negative   13.6   0.601   0.051    [['SPACY:POS-ADP', 'TEXT:to']]
#  45 Positive    2.0   0.957   0.051    [['TEXT:call'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
#  46 Positive    3.1   0.784   0.051    [['TEXT:.'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  47 Positive    7.5   0.521   0.051    [['SPACY:POS-DET'], ['SPACY:POS-PROPN']]
#  48 Positive    3.8   0.716   0.050    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
#  49 Negative   10.6   0.559   0.050    [['SPACY:POS-ADP'], ['SPACY:POS-PROPN']]
#  50 Positive    4.0   0.690   0.049    [['SPACY:POS-PROPN'], ['TEXT:to']]
#  51 Positive    2.2   0.909   0.049    [['HYPERNYM:cost.n.01']]
#  52 Negative   65.0   0.804   0.049    [['SPACY:POS-ADP']]
#  53 Positive    2.2   0.899   0.049    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  54 Negative   54.1   0.785   0.049    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN']]
#  55 Negative   12.1   0.586   0.049    [['HYPERNYM:message.n.02']]
#  56 Positive    5.1   0.613   0.049    [['SPACY:POS-NOUN'], ['HYPERNYM:message.n.02']]
#  57 Negative   30.8   0.725   0.048    [['TEXT:to']]
#  58 Positive    2.5   0.843   0.048    [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  59 Positive    2.4   0.851   0.047    [['TEXT:!'], ['SPACY:POS-NUM']]
#  60 Positive    1.6   1.000   0.046    [['TEXT:prize']]
#  61 Positive    2.2   0.873   0.046    [['HYPERNYM:message.n.02'], ['SPACY:POS-NUM']]
#  62 Negative    8.6   0.533   0.045    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NOUN']]
#  63 Negative   10.8   0.580   0.044    [['HYPERNYM:communication.n.02']]
#  64 Positive    1.6   0.982   0.044    [['HYPERNYM:call.v.28'], ['SPACY:POS-NUM']]
#  65 Positive    2.0   0.890   0.044    [['SPACY:POS-PROPN'], ['TEXT:call']]
#  66 Positive    2.9   0.765   0.044    [['TEXT:call'], ['SPACY:POS-ADP']]
#  67 Positive    2.4   0.816   0.043    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
#  68 Negative   15.9   0.649   0.043    [['TEXT:.'], ['SPACY:POS-NOUN']]
#  69 Negative   39.6   0.759   0.043    [['SPACY:POS-NOUN'], ['SPACY:POS-ADP']]
#  70 Positive    1.5   0.982   0.043    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['TEXT:to'], ['SPACY:POS-NUM']]
#  71 Positive    4.8   0.594   0.042    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-ADP']]
#  72 Negative   39.9   0.761   0.042    [['SENTIMENT:pos']]
#  73 Positive    2.2   0.838   0.042    [['SPACY:POS-ADP'], ['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
#  74 Positive    1.9   0.909   0.042    [['TEXT:to'], ['SPACY:POS-NUM'], ['TEXT:.']]
#  75 Positive    4.0   0.639   0.042    [['SPACY:POS-ADJ'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  76 Positive    1.7   0.934   0.041    [['SPACY:POS-NUM'], ['TEXT:now']]
#  77 Positive    2.5   0.789   0.041    [['TEXT:.'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  78 Positive    3.5   0.675   0.041    [['SENTIMENT:pos'], ['SPACY:POS-NUM']]
#  79 Positive    3.6   0.667   0.041    [['TEXT:!'], ['SPACY:POS-PROPN']]
#  80 Positive    1.9   0.884   0.041    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
#  81 Positive    2.2   0.833   0.040    [['SPACY:POS-PROPN'], ['TEXT:.'], ['SPACY:POS-NUM']]
#  82 Positive    5.1   0.563   0.040    [['TEXT:!'], ['SPACY:POS-NOUN']]
#  83 Positive    3.1   0.709   0.040    [['SPACY:POS-DET'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  84 Positive    3.4   0.678   0.040    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['TEXT:.']]
#  85 Positive    3.0   0.713   0.040    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  86 Positive    4.1   0.621   0.039    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['TEXT:.']]
#  87 Positive    2.1   0.838   0.039    [['SENTIMENT:pos'], ['TEXT:call']]
#  88 Positive    1.9   0.868   0.038    [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  89 Positive    2.5   0.764   0.038    [['HYPERNYM:symbol.n.01']]
#  90 Positive    5.2   0.543   0.037    [['SPACY:POS-ADP'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
#  91 Positive    3.5   0.648   0.037    [['TEXT:!'], ['SPACY:POS-ADJ']]
#  92 Positive    1.6   0.914   0.037    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  93 Positive    3.7   0.634   0.037    [['SPACY:POS-NUM'], ['SPACY:POS-DET']]
#  94 Positive    4.7   0.565   0.037    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['TEXT:to']]
#  95 Positive    2.2   0.797   0.037    [['SENTIMENT:pos'], ['SPACY:POS-DET'], ['SPACY:POS-PROPN']]
#  96 Positive    1.8   0.875   0.037    [['TEXT:.'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  97 Positive    3.0   0.692   0.037    [['HYPERNYM:statement.n.01']]
#  98 Positive    5.6   0.520   0.036    [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  99 Positive    1.2   1.000   0.036    [['TEXT:call'], ['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
# 100 Positive    1.2   1.000   0.036    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['TEXT:.'], ['SPACY:POS-NUM']]

# %% [markdown]
# ## Post-process the patterns

# %%
# Select only patterns of which precision is greater than 0.70
selected_patterns = [p for p in the_patterns if p.precision >= 0.70]
print(f'No. of remaining patterns = {len(selected_patterns)}')
# Out:
# No. of remaining patterns = 57

# %%
# For every pair of patterns (p1, p2), remove pattern p2 if there exists p1 in the patterns set such that p2 is a specialization of p1 and metric of p2 is lower than p1
selected_patterns = grasptext.remove_specialized_patterns(selected_patterns, metric = lambda x: x.precision)
print(f'No. of remaining patterns = {len(selected_patterns)}')
# Out:
# No. of remaining patterns = 47

# %%
# Print the remaining patterns sorted by precision
selected_patterns = sorted(selected_patterns, key = lambda x: x.precision, reverse = True)
print(f'  #    class Cov(%)    Prec  Gain    Pattern')
for idx, p in enumerate(selected_patterns):
    print(f'{idx+1:>3} {p.support_class}   {round(p.coverage*100, 1):>4}   {p.precision:.3f}   {p.metric:.3f}    {p.get_pattern_id()}')
# Out:
#   #    class Cov(%)    Prec  Gain    Pattern
#   1 Positive    2.2   1.000   0.064    [['TEXT:claim']]
#   2 Positive    1.6   1.000   0.046    [['TEXT:prize']]
#   3 Positive    1.2   1.000   0.036    [['TEXT:call'], ['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
#   4 Positive    1.2   1.000   0.036    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['TEXT:.'], ['SPACY:POS-NUM']]
#   5 Positive    1.9   0.985   0.053    [['TEXT:.'], ['TEXT:call'], ['SPACY:POS-NUM']]
#   6 Positive    5.1   0.984   0.152    [['TEXT:call'], ['SPACY:POS-NUM']]
#   7 Negative   37.2   0.983   0.067    [['TEXT:i']]
#   8 Positive    1.5   0.982   0.043    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['TEXT:to'], ['SPACY:POS-NUM']]
#   9 Positive    2.4   0.942   0.060    [['TEXT:mobile']]
#  10 Positive    2.7   0.938   0.067    [['TEXT:txt']]
#  11 Positive    1.7   0.934   0.041    [['SPACY:POS-NUM'], ['TEXT:now']]
#  12 Positive    3.4   0.926   0.082    [['SPACY:POS-PROPN'], ['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
#  13 Positive    2.2   0.923   0.052    [['HYPERNYM:communication.n.02'], ['SPACY:POS-NUM']]
#  14 Positive    2.2   0.922   0.051    [['HYPERNYM:win.v.01', 'SENTIMENT:pos']]
#  15 Positive    1.6   0.914   0.037    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  16 Positive    2.2   0.909   0.049    [['HYPERNYM:cost.n.01']]
#  17 Positive    1.9   0.909   0.042    [['TEXT:to'], ['SPACY:POS-NUM'], ['TEXT:.']]
#  18 Positive    2.2   0.899   0.049    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  19 Positive    2.0   0.890   0.044    [['SPACY:POS-PROPN'], ['TEXT:call']]
#  20 Positive    1.9   0.884   0.041    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
#  21 Positive    1.8   0.875   0.037    [['TEXT:.'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  22 Positive    2.2   0.873   0.046    [['HYPERNYM:message.n.02'], ['SPACY:POS-NUM']]
#  23 Positive    1.9   0.868   0.038    [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  24 Positive    5.4   0.856   0.114    [['TEXT:to'], ['SPACY:POS-NUM']]
#  25 Positive    2.4   0.851   0.047    [['TEXT:!'], ['SPACY:POS-NUM']]
#  26 Positive    2.5   0.843   0.048    [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  27 Positive    3.6   0.843   0.069    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  28 Positive    2.1   0.838   0.039    [['SENTIMENT:pos'], ['TEXT:call']]
#  29 Positive    2.2   0.838   0.042    [['SPACY:POS-ADP'], ['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
#  30 Positive    2.2   0.833   0.040    [['SPACY:POS-PROPN'], ['TEXT:.'], ['SPACY:POS-NUM']]
#  31 Positive    2.4   0.816   0.043    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
#  32 Positive    6.8   0.811   0.129    [['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
#  33 Positive    8.9   0.806   0.175    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  34 Negative   65.0   0.804   0.049    [['SPACY:POS-ADP']]
#  35 Positive    2.2   0.797   0.037    [['SENTIMENT:pos'], ['SPACY:POS-DET'], ['SPACY:POS-PROPN']]
#  36 Positive    5.7   0.797   0.101    [['TEXT:.'], ['SPACY:POS-NUM']]
#  37 Positive    4.3   0.791   0.073    [['SPACY:POS-NOUN'], ['TEXT:call']]
#  38 Positive    2.5   0.789   0.041    [['TEXT:.'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  39 Negative   54.1   0.785   0.049    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN']]
#  40 Positive    3.1   0.784   0.051    [['TEXT:.'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  41 Positive    2.5   0.764   0.038    [['HYPERNYM:symbol.n.01']]
#  42 Negative   39.9   0.761   0.042    [['SENTIMENT:pos']]
#  43 Positive    4.4   0.756   0.067    [['SPACY:POS-SYM']]
#  44 Positive    6.7   0.735   0.100    [['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
#  45 Negative   30.8   0.725   0.048    [['TEXT:to']]
#  46 Positive    7.1   0.722   0.104    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  47 Positive    3.1   0.709   0.040    [['SPACY:POS-DET'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]

# %% [markdown]
# ## Save the patterns to a json file
# We can use this json file as an input of the web demo tool for exploring the learned patterns and the training data

# %%
grasp_model.to_json('results/case_study_1.json', patterns = selected_patterns, comment = 'Rank and group patterns based on precision. The minimum precision was set at 0.70')
# Out:
# 100%|██████████| 47/47 [00:00<00:00, 372.92it/s]
# 100%|██████████| 47/47 [00:00<00:00, 333.53it/s]
# Successfully dump the results to results/case_study_1.json
