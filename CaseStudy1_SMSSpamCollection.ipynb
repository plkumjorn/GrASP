# %%
# %load_ext autoreload
# %autoreload 2

# %%
import grasp
from grasp import GrASP, CustomAttribute, remove_specialized_patterns
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Load the data
# - Download and unzip the spam dataset **if you have not done this before**

# %%
import urllib.request
url = 'http://www.dt.fee.unicamp.br/~tiago/smsspamcollection/smsspamcollection.zip'
filename = './data/smsspamcollection.zip'
urllib.request.urlretrieve(url, filename)

# %%
# !unzip ./data/smsspamcollection.zip -d ./data

# %% [markdown]
# - Load the data

# %%
def get_data():
    f = open('data/SMSSpamCollection.txt', 'r')
    texts, labels = [], []
    for line in f:
        line = line.strip()
        tab_idx = line.index('\t')
        label = line[:tab_idx]
        text = line[tab_idx+1:]
        if label == 'ham':
            label = 0
        elif label == 'spam':
            label = 1
        else:
            raise Exception(f"Invalid label - {label}")
        texts.append(text)
        labels.append(label)
    return texts, labels

# %%
texts, labels = get_data()
X_train, X_test, y_train, y_test = train_test_split(texts, labels, test_size=0.2, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1)
len(texts), sum(labels), len(X_test), sum(y_test)
# Out:
# (5574, 747, 1115, 138)

# %%
positive = [t for idx, t in enumerate(X_train) if y_train[idx]]
negative = [t for idx, t in enumerate(X_train) if not y_train[idx]]

# %% [markdown]
# ## Run GrASP

# %%
# Create the GrASP engine
grasp_model = GrASP(gaps_allowed = 2, num_patterns = 100, include_standard = ['TEXT', 'POS', 'SENTIMENT'],
                    include_custom = [CustomAttribute(name = 'HYPERNYM3', extraction_function = grasp.get_custom_hypernym_extraction_function(above = 3), translation_function = grasp._hypernym_translation)],
                    correlation_threshold = 0.5, alphabet_size = 200)

# %%
# Fit GrASP to the dataset
the_patterns = grasp_model.fit_transform(positive, negative)
# Out:
#   0%|          | 0/488 [00:00<?, ?it/s]
# Step 1: Create augmented texts
# 100%|██████████| 488/488 [00:17<00:00, 27.72it/s]
# 100%|██████████| 3079/3079 [01:21<00:00, 37.93it/s]
# Step 2: Find frequent attributes
#   0%|          | 5/1215 [00:00<00:26, 45.58it/s]
# Total number of candidate alphabet = 1215, such as ['SPACY:POS-VERB', 'SPACY:POS-NOUN', 'SPACY:POS-PUNCT', 'SPACY:POS-PRON', 'SPACY:POS-ADV']
# Step 3: Find alphabet set
# 100%|██████████| 1215/1215 [00:27<00:00, 43.56it/s]
# Finding top k: 20 / 200
# Finding top k: 40 / 200
# Finding top k: 60 / 200
# Finding top k: 80 / 200
# Finding top k: 100 / 200
# Finding top k: 120 / 200
# Finding top k: 140 / 200
# Finding top k: 160 / 200
# Finding top k: 180 / 200
# Finding top k: 200 / 200
#   0%|          | 0/200 [00:00<?, ?it/s]
# Total number of alphabet = 200
# ['SPACY:POS-NUM', 'SPACY:POS-PROPN', 'TEXT:call', 'TEXT:i', 'SPACY:POS-SYM', 'TEXT:free', 'TEXT:txt', 'TEXT:claim', 'TEXT:!', 'TEXT:mobile', 'HYPERNYM3:cost.n.01', 'SPACY:POS-ADP', 'HYPERNYM3:message.n.02', 'TEXT:to', 'TEXT:prize', 'HYPERNYM3:communication.n.02', 'HYPERNYM3:win.v.01', 'SENTIMENT:pos', 'HYPERNYM3:symbol.n.01', 'HYPERNYM3:statement.n.01', 'TEXT:your', 'SPACY:POS-ADJ', 'TEXT:or', 'TEXT:text', 'TEXT:stop', 'TEXT:-', 'TEXT:150p', 'TEXT:guaranteed', 'TEXT:urgent', 'HYPERNYM3:textbook.n.01', 'HYPERNYM3:act.n.02', 'TEXT:win', 'HYPERNYM3:oppose.v.01', 'TEXT:+', 'HYPERNYM3:written_communication.n.01', 'SPACY:POS-PRON', 'TEXT:16', 'TEXT:cash', 'HYPERNYM3:abstraction.n.06', 'TEXT:from', 'HYPERNYM3:assertion.n.01', 'TEXT:reply', 'TEXT:now', 'TEXT:.', 'TEXT:tone', 'TEXT:18', 'HYPERNYM3:acquisition.n.02', 'SPACY:POS-DET', 'TEXT:nokia', 'TEXT:a', 'HYPERNYM3:user.n.01', 'TEXT:our', 'HYPERNYM3:mobile.n.02', 'HYPERNYM3:minute.n.01', 'HYPERNYM3:person.n.01', 'HYPERNYM3:claim.v.03', 'TEXT:service', 'TEXT:contact', 'HYPERNYM3:writing.n.02', 'TEXT:for', 'TEXT:...', 'HYPERNYM3:offer.n.02', 'TEXT:awarded', 'TEXT:â£1000', 'TEXT:150ppm', 'TEXT:4', 'HYPERNYM3:request.n.01', 'TEXT:per', 'HYPERNYM3:call.v.28', 'HYPERNYM3:convey.v.03', 'HYPERNYM3:television_equipment.n.01', 'HYPERNYM3:land_line.n.01', 'TEXT:ur', 'HYPERNYM3:state.v.01', 'TEXT:camera', 'HYPERNYM3:phone.n.02', 'TEXT:rate', 'TEXT:my', 'HYPERNYM3:plastic_art.n.01', 'TEXT:latest', 'HYPERNYM3:text.n.04', 'HYPERNYM3:coding_system.n.01', 'TEXT:box', 'TEXT:draw', 'TEXT::', 'HYPERNYM3:event.n.01', 'TEXT:line', 'HYPERNYM3:free.a.01', 'TEXT:shows', 'HYPERNYM3:now.r.03', 'HYPERNYM3:declare.v.01', 'TEXT:10p', 'TEXT:collection', 'TEXT:2', 'SPACY:POS-NOUN', 'HYPERNYM3:memory_device.n.01', 'HYPERNYM3:document.n.01', 'HYPERNYM3:service.n.11', 'HYPERNYM3:equipment.n.01', 'HYPERNYM3:part.n.01', 'HYPERNYM3:instrumentality.n.03', 'SPACY:POS-PART', 'TEXT:chat', 'HYPERNYM3:communicator.n.01', 'TEXT:mins', 'HYPERNYM3:activity.n.01', 'HYPERNYM3:vacation.n.01', 'TEXT:offer', 'TEXT:video', 'HYPERNYM3:workweek.n.01', 'TEXT:;', 'TEXT:..', 'TEXT:1st', 'HYPERNYM3:touch.v.05', 'HYPERNYM3:samarium.n.01', 'HYPERNYM3:unit.n.03', 'HYPERNYM3:request.v.01', 'TEXT:but', 'TEXT:network', 'TEXT:apply', 'TEXT:only', 'TEXT:collect', 'TEXT:new', 'TEXT:(', 'HYPERNYM3:time_period.n.01', 'HYPERNYM3:probability.n.01', 'TEXT:receive', 'HYPERNYM3:have.v.07', 'TEXT: ', 'TEXT:selected', 'HYPERNYM3:speech_act.n.01', 'TEXT:msg', 'TEXT:me', "TEXT:'m", 'HYPERNYM3:communication.n.01', 'HYPERNYM3:commercial_document.n.01', 'TEXT:it', 'HYPERNYM3:answer.v.01', 'TEXT:every', 'HYPERNYM3:information.n.01', 'TEXT:wk', 'HYPERNYM3:sound_property.n.01', 'HYPERNYM3:condition.n.01', 'HYPERNYM3:call.n.04', 'TEXT:word', 'TEXT:on', 'SPACY:POS-CCONJ', 'TEXT:cost', 'HYPERNYM3:match.v.01', 'HYPERNYM3:now.r.06', 'HYPERNYM3:promise.v.01', 'HYPERNYM3:derivative_instrument.n.01', 'HYPERNYM3:game.n.01', 'TEXT:send', 'TEXT:that', 'HYPERNYM3:substance.n.01', 'TEXT:please', 'TEXT:phone', 'HYPERNYM3:time_unit.n.01', 'TEXT:gift', 'TEXT:top', 'TEXT:with', 'HYPERNYM3:electronic_equipment.n.01', 'TEXT:this', 'TEXT:ok', 'TEXT:come', 'HYPERNYM3:ur.n.01', 'HYPERNYM3:rate.n.01', 'TEXT:texts', 'HYPERNYM3:quality.n.01', 'HYPERNYM3:stop.v.05', 'TEXT:he', 'HYPERNYM3:secret.n.02', 'SPACY:POS-INTJ', 'HYPERNYM3:entity.n.01', 'TEXT:find', 'HYPERNYM3:relation.n.01', 'HYPERNYM3:people.n.01', 'HYPERNYM3:syndicate.n.01', 'HYPERNYM3:group.n.01', 'SPACY:POS-VERB', 'TEXT:2nd', 'HYPERNYM3:supporter.n.01', 'TEXT:t', 'HYPERNYM3:definite_quantity.n.01', 'HYPERNYM3:call.v.07', 'HYPERNYM3:worth.n.02', 'TEXT:how', 'TEXT:have', 'TEXT:account', "TEXT:'ll", 'HYPERNYM3:choose.v.01', 'HYPERNYM3:late.a.05', 'TEXT:price', 'HYPERNYM3:margin_call.n.01', 'TEXT:been', 'HYPERNYM3:change.v.01', 'HYPERNYM3:difficulty.n.03', 'TEXT:later', 'TEXT:did']
# Example of patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Metric (global) = 0.223
# Examples ~ Class Negative:
# [MATCH]: A Boy loved a gal . He propsd bt she did nt mind . He gv lv lttrs , Bt her frnds threw thm . Again d boy decided 2:['SPACY:POS-NUM'] aproach d gal , dt time a truck was speeding towards d gal . Wn it was about 2 hit d girl , d boy ran like hell n saved her . She asked ' hw cn u run so fast ? ' D boy replied " Boost is d secret of my energy " n instantly d girl shouted " our energy " n Thy lived happily 2gthr drinking boost evrydy Moral of d story:- I hv free msgs : D ; ) : gud ni8
# -------------------------
# [MATCH]: Haha yeah , 2:['SPACY:POS-NUM'] oz is kind of a shitload
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: We tried to call you re your reply to our sms for a video mobile 750:['SPACY:POS-NUM'] mins UNLIMITED TEXT free camcorder Reply or call now 08000930705 Del Thurs
# -------------------------
# [MATCH]: Loan for any purpose Â£500 - Â£75,000 . Homeowners + Tenants welcome . Have you been previously refused ? We can still help . Call Free 0800:['SPACY:POS-NUM'] 1956669 or text back ' help '
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN']]
# Window size: 3
# Class: Negative
# Precision: 0.690
# Match: 1347 (37.8%)
# Gain = 0.112
# Metric (global) = 0.112
# Examples ~ Class Negative:
# [MATCH]: Hmmm.still:['SPACY:POS-PROPN'] we do nt have opener ?
# -------------------------
# [MATCH]: Haha:['SPACY:POS-PROPN'] ... do nt be angry with yourself ... Take it as a practice for the real thing . =)
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Got what it takes 2 take part in the WRC:['SPACY:POS-PROPN'] Rally in Oz ? U can with Lucozade Energy ! Text RALLY LE to 61200 ( 25p ) , see packs or lucozade.co.uk/wrc & itcould be u !
# -------------------------
# [MATCH]: 500 New:['SPACY:POS-PROPN'] Mobiles from 2004 , MUST GO ! Txt : NOKIA to No : 89545 & collect yours today!From ONLY Â£1 www.4-tc.biz 2optout 087187262701.50gbp / mtmsg18
# -------------------------
# ==================================================
# Pattern: [['TEXT:call']]
# Window size: 3
# Class: Positive
# Precision: 0.618
# Match: 348 (9.8%)
# Gain = 0.104
# Metric (global) = 0.104
# Examples ~ Class Positive:
# [MATCH]: You have 1 new message . Please call:['TEXT:call'] 08712400200 .
# -------------------------
# [MATCH]: Free video camera phones with Half Price line rental for 12 mths and 500 cross ntwk mins 100 txts . Call:['TEXT:call'] MobileUpd8 08001950382 or Call2OptOut/674 &
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Tomorrow i am not going to theatre . . . So i can come wherever u call:['TEXT:call'] me . . . Tell me where and when to come tomorrow
# -------------------------
# [MATCH]: My life Means a lot to me , Not because I love my life , But because I love the people in my life , The world calls them friends , I call:['TEXT:call'] them my World:- ) .. Ge:- ) ..
# -------------------------
# ==================================================
# Pattern: [['TEXT:i']]
# Window size: 3
# Class: Negative
# Precision: 0.983
# Match: 1327 (37.2%)
# Gain = 0.067
# Metric (global) = 0.067
# Examples ~ Class Negative:
# [MATCH]: Hurry home u big butt . Hang up on your last caller if u have to . Food is done and I:['TEXT:i'] 'm starving . Do n't ask what I cooked .
# -------------------------
# [MATCH]: Well I:['TEXT:i'] might not come then ...
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: sexy sexy cum and text me i:['TEXT:i'] m wet and warm and ready for some porn ! u up for some fun ? THIS MSG IS FREE RECD MSGS 150P INC VAT 2 CANCEL TEXT STOP
# -------------------------
# [MATCH]: I:['TEXT:i'] do n't know u and u do n't know me . Send CHAT to 86688 now and let 's find each other ! Only 150p / Msg rcvd . HG / Suite342/2Lands / Row / W1J6HL LDN . 18 years or over .
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-SYM']]
# Window size: 3
# Class: Positive
# Precision: 0.756
# Match: 156 (4.4%)
# Gain = 0.067
# Metric (global) = 0.067
# Examples ~ Class Positive:
# [MATCH]: YOU 07801543489 are guaranteed the latests Nokia Phone , a 40 GB iPod MP3 player or a Â£500 prize ! Txt word : COLLECT to No:83355 ! TC - LLC NY - USA 150p /:['SPACY:POS-SYM'] Mt msgrcvd18 +
# -------------------------
# [MATCH]: For ur chance to win a Â£250 cash every wk TXT : ACTION to 80608 . T's&C 's www.movietrivia.tv custcare 08712405022 , 1x150p /:['SPACY:POS-SYM'] wk
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Hey ... Great deal ... Farm tour 9 am to 5 pm $:['SPACY:POS-SYM'] 95/pax , $ 50 deposit by 16 May
# -------------------------
# [MATCH]: HIYA COMIN 2 BRISTOL 1 ST WEEK IN APRIL . LES GOT OFF +:['SPACY:POS-SYM'] RUDI ON NEW YRS EVE BUT I WAS SNORING.THEY WERE DRUNK ! U BAK AT COLLEGE YET ? MY WORK SENDS INK 2 BATH .
# -------------------------
# ==================================================
# Step 4: Grow patterns
# 100%|██████████| 200/200 [03:04<00:00,  1.08it/s]
# Length 2 / 5; New candidates = 59900
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Metric (global) = 0.223
# Examples ~ Class Negative:
# [MATCH]: Yar i wanted 2:['SPACY:POS-NUM'] scold u yest but late already ... I where got zhong se qing you ? If u ask me b4 he ask me then i 'll go out w u all lor . N u still can act so real .
# -------------------------
# [MATCH]: So u gon na get deus ex:['SPACY:POS-NUM'] ?
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Ur cash - balance is currently 500:['SPACY:POS-NUM'] pounds - to maximize ur cash - in now send GO to 86688 only 150p / meg . CC : 08718720201 HG / Suite342/2lands Row / W1j6HL
# -------------------------
# [MATCH]: BIG BROTHER ALERT ! The computer has selected u for 10k:['SPACY:POS-NUM'] cash or # 150 voucher . Call 09064018838 . NTT PO Box CRO1327 18 + BT Landline Cost 150ppm mobiles vary
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.806
# Match: 319 (8.9%)
# Gain = 0.175
# Metric (global) = 0.175
# Examples ~ Class Positive:
# [MATCH]: YES ! The only place in town to meet exciting adult singles is now in the UK . Txt:['SPACY:POS-PROPN'] CHAT to 86688:['SPACY:POS-NUM'] now ! 150p / Msg .
# -------------------------
# [MATCH]: PRIVATE ! Your 2003 Account:['SPACY:POS-PROPN'] Statement for 078:['SPACY:POS-NUM']
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: HIYA:['SPACY:POS-PROPN'] COMIN 2:['SPACY:POS-NUM'] BRISTOL 1 ST WEEK IN APRIL . LES GOT OFF + RUDI ON NEW YRS EVE BUT I WAS SNORING.THEY WERE DRUNK ! U BAK AT COLLEGE YET ? MY WORK SENDS INK 2 BATH .
# -------------------------
# [MATCH]: " AH POOR BABY!HOPE URFEELING BETTERSN LUV ! PROBTHAT OVERDOSE OF WORK HEY GO CAREFUL:['SPACY:POS-PROPN'] SPK 2:['SPACY:POS-NUM'] U SN LOTS OF LOVEJEN XXX . "
# -------------------------
# ==================================================
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.984
# Match: 183 (5.1%)
# Gain = 0.152
# Metric (global) = 0.152
# Examples ~ Class Positive:
# [MATCH]: You have an important customer service announcement from PREMIER . Call:['TEXT:call'] FREEPHONE 0800:['SPACY:POS-NUM'] 542 0578 now !
# -------------------------
# [MATCH]: Urgent ! Please call:['TEXT:call'] 09061743811:['SPACY:POS-NUM'] from landline . Your ABTA complimentary 4 * Tenerife Holiday or Â£5000 cash await collection SAE T&Cs Box 326 CW25WX 150ppm
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Ummma.will call:['TEXT:call'] after check in.our:['SPACY:POS-NUM'] life will begin from qatar so pls pray very hard .
# -------------------------
# [MATCH]: Yun ah.the ubi one say if Ã¼ wan call:['TEXT:call'] by tomorrow.call 67441233:['SPACY:POS-NUM'] look for irene.ere only got bus8,22,65,61,66,382 . Ubi cres , ubi tech park.6ph for 1st 5wkg days . Ã¨n
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.579
# Match: 518 (14.5%)
# Gain = 0.148
# Metric (global) = 0.148
# Examples ~ Class Positive:
# [MATCH]: To review and KEEP the fantastic Nokia:['SPACY:POS-PROPN'] N:['SPACY:POS-PROPN'] - Gage game deck with Club Nokia , go 2 www.cnupdates.com/newsletter . unsubscribe from alerts reply with the word OUT
# -------------------------
# [MATCH]: YOU 07801543489 are guaranteed the latests Nokia:['SPACY:POS-PROPN'] Phone:['SPACY:POS-PROPN'] , a 40 GB iPod MP3 player or a Â£500 prize ! Txt word : COLLECT to No:83355 ! TC - LLC NY - USA 150p / Mt msgrcvd18 +
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Oh ... Haha:['SPACY:POS-PROPN'] ... Den:['SPACY:POS-PROPN'] we shld had went today too ... Gee , nvm la ... Kaiez , i dun mind goin jazz oso ... Scared hiphop open ca nt catch up ...
# -------------------------
# [MATCH]: Smile in Pleasure:['SPACY:POS-PROPN'] Smile in Pain:['SPACY:POS-PROPN'] Smile when trouble pours like Rain Smile when sum1 Hurts U Smile becoz SOMEONE still Loves to see u Smiling ! !
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.613
# Match: 421 (11.8%)
# Gain = 0.129
# Metric (global) = 0.129
# Examples ~ Class Positive:
# [MATCH]: URGENT ! Your mobile number * * * * * * * * * * * * * * * WON a Â£2000 Bonus Caller prize on:['SPACY:POS-ADP'] 10/06/03:['SPACY:POS-NUM'] ! This is the 2nd attempt to reach you ! Call 09066368753 ASAP ! Box 97N7QP , 150ppm
# -------------------------
# [MATCH]: URGENT ! Your Mobile No was awarded a Â£2,000 Bonus Caller Prize on:['SPACY:POS-ADP'] 1/08/03:['SPACY:POS-NUM'] ! This is our 2nd attempt to contact YOU ! Call 0871 - 4719 - 523 BOX95QU BT National Rate
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: S:-)kallis wo nt play in:['SPACY:POS-ADP'] first two:['SPACY:POS-NUM'] odi:- )
# -------------------------
# [MATCH]: What time . Iâ€˜m out until:['SPACY:POS-ADP'] prob 3:['SPACY:POS-NUM'] or so
# -------------------------
# ==================================================
# 100%|██████████| 70/70 [02:12<00:00,  1.89s/it]
# Length 3 / 5; New candidates = 27723
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Metric (global) = 0.223
# Examples ~ Class Negative:
# [MATCH]: Will be office around 4:['SPACY:POS-NUM'] pm . Now i am going hospital .
# -------------------------
# [MATCH]: My trip was ok but quite tiring lor . Uni starts today but it 's ok 4:['SPACY:POS-NUM'] me cos i 'm not taking any modules but jus concentrating on my final yr project .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Call Germany for only 1:['SPACY:POS-NUM'] pence per minute ! Call from a fixed line via access number 0844 861 85 85 . No prepayment . Direct access ! www.telediscount.co.uk
# -------------------------
# [MATCH]: FREE for 1st week ! No1 Nokia tone 4:['SPACY:POS-NUM'] ur mob every week just txt NOKIA to 8007 Get txting and tell ur mates www.getzed.co.uk POBox 36504 W45WQ norm150p / tone 16 +
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.806
# Match: 319 (8.9%)
# Gain = 0.175
# Metric (global) = 0.175
# Examples ~ Class Positive:
# [MATCH]: FREE entry into our Â£250 weekly competition just text the word WIN:['SPACY:POS-PROPN'] to 80086:['SPACY:POS-NUM'] NOW . 18 T&C www.txttowin.co.uk
# -------------------------
# [MATCH]: You are awarded a SiPix Digital Camera:['SPACY:POS-PROPN'] ! call 09061221061:['SPACY:POS-NUM'] from landline . Delivery within 28days . T Cs Box177 . M221BP . 2yr warranty . 150ppm . 16 . p pÂ£3.99
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Height of Confidence : All the Aeronautics professors wer calld & amp ; they wer askd 2 sit in an aeroplane . Aftr they sat they wer told dat the plane ws made by their students . Dey all hurried out of d plane .. Bt:['SPACY:POS-PROPN'] only 1:['SPACY:POS-NUM'] did nt move ... He said:"if it is made by my students , this wo nt even start ........ Datz confidence ..
# -------------------------
# [MATCH]: IM REALY SOZ IMAT MY MUMS:['SPACY:POS-PROPN'] 2NITE:['SPACY:POS-NUM'] WHAT ABOUT 2MORO
# -------------------------
# ==================================================
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.984
# Match: 183 (5.1%)
# Gain = 0.152
# Metric (global) = 0.152
# Examples ~ Class Positive:
# [MATCH]: Urgent Please call:['TEXT:call'] 09066612661:['SPACY:POS-NUM'] from landline . Â£5000 cash or a luxury 4 * Canary Islands Holiday await collection . T&Cs SAE award . 20M12AQ . 150ppm . 16 + â€œ
# -------------------------
# [MATCH]: YOU ARE CHOSEN TO RECEIVE A Â£350 AWARD ! Pls call:['TEXT:call'] claim number 09066364311:['SPACY:POS-NUM'] to collect your award which you are selected to receive as a valued mobile customer .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Yun ah.the ubi one say if Ã¼ wan call:['TEXT:call'] by tomorrow.call 67441233:['SPACY:POS-NUM'] look for irene.ere only got bus8,22,65,61,66,382 . Ubi cres , ubi tech park.6ph for 1st 5wkg days . Ã¨n
# -------------------------
# [MATCH]: I 'm in a movie . Call:['TEXT:call'] me 4:['SPACY:POS-NUM'] wat ?
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.579
# Match: 518 (14.5%)
# Gain = 0.148
# Metric (global) = 0.148
# Examples ~ Class Positive:
# [MATCH]: Knock:['SPACY:POS-PROPN'] Knock:['SPACY:POS-PROPN'] Txt whose there to 80082 to enter r weekly draw 4 a Â£250 gift voucher 4 a store of yr choice . T&Cs www.tkls.com age16 to stoptxtstopÂ£1.50/week
# -------------------------
# [MATCH]: RCT ' THNQ Adrian:['SPACY:POS-PROPN'] for U:['SPACY:POS-PROPN'] text . Rgds Vatian
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: As I entered my cabin my PA said , '' Happy B'day:['SPACY:POS-PROPN'] Boss:['SPACY:POS-PROPN'] ! ! '' . I felt special . She askd me 4 lunch . After lunch she invited me to her apartment . We went there .
# -------------------------
# [MATCH]: Gud:['SPACY:POS-PROPN'] ni8:['SPACY:POS-PROPN'] dear .. slp well .. take care .. swt dreams .. Muah ..
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.613
# Match: 421 (11.8%)
# Gain = 0.129
# Metric (global) = 0.129
# Examples ~ Class Positive:
# [MATCH]: Do you realize that in:['SPACY:POS-ADP'] about 40:['SPACY:POS-NUM'] years , we 'll have thousands of old ladies running around with tattoos ?
# -------------------------
# [MATCH]: U have won a nokia 6230 plus a free digital camera . This is what u get when u win our FREE auction . To take part send NOKIA to:['SPACY:POS-ADP'] 83383:['SPACY:POS-NUM'] now . POBOX114/14TCR / W1 16
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I 'll be in:['SPACY:POS-ADP'] sch fr 4:['SPACY:POS-NUM'] - 6 ... I dun haf da book in sch ... It 's at home ...
# -------------------------
# [MATCH]: â€ ¦ and donâ€˜t worry weâ€˜ll have finished by:['SPACY:POS-ADP'] march â€ ¦:['SPACY:POS-NUM'] ish !
# -------------------------
# ==================================================
# 100%|██████████| 36/36 [00:59<00:00,  1.66s/it]
# Length 4 / 5; New candidates = 14334
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
#   0%|          | 0/4 [00:00<?, ?it/s]
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Metric (global) = 0.223
# Examples ~ Class Negative:
# [MATCH]: Alex knows a guy who sells mids but he 's down in south tampa and I do n't think I could set it up before like 8:['SPACY:POS-NUM']
# -------------------------
# [MATCH]: 8:['SPACY:POS-NUM'] at the latest , g 's still there if you can scrounge up some ammo and want to give the new ak a try
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: SMS AUCTION You have won a Nokia 7250i:['SPACY:POS-NUM'] . This is what you get when you win our FREE auction . To take part send Nokia to 86021 now . HG / Suite342/2Lands Row / W1JHL 16 +
# -------------------------
# [MATCH]: Gr8 Poly tones 4:['SPACY:POS-NUM'] ALL mobs direct 2u rply with POLY TITLE to 8007 eg POLY BREATHE1 Titles : CRAZYIN , SLEEPINGWITH , FINEST , YMCA : getzed.co.uk POBox365O4W45WQ 300p
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.806
# Match: 319 (8.9%)
# Gain = 0.175
# Metric (global) = 0.175
# Examples ~ Class Positive:
# [MATCH]: Panasonic & BluetoothHdset FREE . Nokia FREE . Motorola FREE & DoubleMins & DoubleTxt on Orange contract . Call MobileUpd8:['SPACY:POS-PROPN'] on 08000839402:['SPACY:POS-NUM'] or call 2optout
# -------------------------
# [MATCH]: Please call our customer service representative on FREEPHONE:['SPACY:POS-PROPN'] 0808:['SPACY:POS-NUM'] 145 4742 between 9am-11pm as you have WON a guaranteed Â£1000 cash or Â£5000 prize !
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Gd:['SPACY:POS-PROPN'] luck 4:['SPACY:POS-NUM'] ur exams :-)
# -------------------------
# [MATCH]: Yun:['SPACY:POS-PROPN'] ah.the ubi one:['SPACY:POS-NUM'] say if Ã¼ wan call by tomorrow.call 67441233 look for irene.ere only got bus8,22,65,61,66,382 . Ubi cres , ubi tech park.6ph for 1st 5wkg days . Ã¨n
# -------------------------
# ==================================================
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.984
# Match: 183 (5.1%)
# Gain = 0.152
# Metric (global) = 0.152
# Examples ~ Class Positive:
# [MATCH]: Urgent ! Please call:['TEXT:call'] 09061743810:['SPACY:POS-NUM'] from landline . Your ABTA complimentary 4 * Tenerife Holiday or # 5000 cash await collection SAE T&Cs Box 326 CW25WX 150 ppm
# -------------------------
# [MATCH]: URGENT This is our 2nd attempt to contact U. Your Â£900 prize from YESTERDAY is still awaiting collection . To claim CALL:['TEXT:call'] NOW 09061702893:['SPACY:POS-NUM'] . ACL03530150PM
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Ummma.will call:['TEXT:call'] after check in.our:['SPACY:POS-NUM'] life will begin from qatar so pls pray very hard .
# -------------------------
# [MATCH]: I 'm in a movie . Call:['TEXT:call'] me 4:['SPACY:POS-NUM'] wat ?
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.579
# Match: 518 (14.5%)
# Gain = 0.148
# Metric (global) = 0.148
# Examples ~ Class Positive:
# [MATCH]: FREE for 1st week ! No1:['SPACY:POS-PROPN'] Nokia:['SPACY:POS-PROPN'] tone 4 ur mob every week just txt NOKIA to 8007 Get txting and tell ur mates www.getzed.co.uk POBox 36504 W45WQ norm150p / tone 16 +
# -------------------------
# [MATCH]: XMAS:['SPACY:POS-PROPN'] Prize:['SPACY:POS-PROPN'] draws ! We are trying to contact U. Todays draw shows that you have won a Â£2000 prize GUARANTEED . Call 09058094565 from land line . Valid 12hrs only
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: How 's it feel ? Mr. Your not my real Valentine:['SPACY:POS-PROPN'] just my yo:['SPACY:POS-PROPN'] Valentine even tho u hardly play ! !
# -------------------------
# [MATCH]: U meet other fren dun wan meet me ah ... Muz:['SPACY:POS-PROPN'] b:['SPACY:POS-PROPN'] a guy rite ...
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.613
# Match: 421 (11.8%)
# Gain = 0.129
# Metric (global) = 0.129
# Examples ~ Class Positive:
# [MATCH]: 4mths half price Orange line rental & latest camera phones 4 FREE . Had your phone 11mths ? Call MobilesDirect free on:['SPACY:POS-ADP'] 08000938767:['SPACY:POS-NUM'] to update now ! or2stoptxt
# -------------------------
# [MATCH]: FREE entry into our Â£250 weekly comp just send the word ENTER to:['SPACY:POS-ADP'] 84128:['SPACY:POS-NUM'] NOW . 18 T&C www.textcomp.com cust care 08712405020 .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Rose for red , red for blood , blood for heart , heart for u. But u for me .... Send tis to all ur friends .. Including me .. If u like me .. If u get back , 1-u r poor in:['SPACY:POS-ADP'] relation ! 2-u:['SPACY:POS-NUM'] need some 1 to support 3-u r frnd 2 many 4-some1 luvs u 5 + - some1 is praying god to marry u.:- ) try it ....
# -------------------------
# [MATCH]: Hey ... Great deal ... Farm tour 9 am to:['SPACY:POS-ADP'] 5:['SPACY:POS-NUM'] pm $ 95/pax , $ 50 deposit by 16 May
# -------------------------
# ==================================================
# 100%|██████████| 4/4 [00:06<00:00,  1.70s/it]
# Length 5 / 5; New candidates = 1595
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Metric (global) = 0.223
# Examples ~ Class Negative:
# [MATCH]: After my work ah ... Den 6:['SPACY:POS-NUM'] plus lor ... U workin oso rite ... Den go orchard lor , no other place to go liao ...
# -------------------------
# [MATCH]: Hi Jon , Pete here , I ve bin 2:['SPACY:POS-NUM'] Spain recently & hav sum dinero left , Bill said u or ur Â‘rents mayb interested in it , I hav 12,000pes , so around Â£48 , tb , James .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: You are awarded a SiPix Digital Camera ! call 09061221061:['SPACY:POS-NUM'] from landline . Delivery within 28days . T Cs Box177 . M221BP . 2yr warranty . 150ppm . 16 . p pÂ£3.99
# -------------------------
# [MATCH]: Your free ringtone is waiting to be collected . Simply text the password " MIX " to 85069:['SPACY:POS-NUM'] to verify . Get Usher and Britney . FML , PO Box 5249 , MK17 92H. 450Ppw 16
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.806
# Match: 319 (8.9%)
# Gain = 0.175
# Metric (global) = 0.175
# Examples ~ Class Positive:
# [MATCH]: You are a Â£1000 winner or Guaranteed Caller Prize , this is our Final attempt to contact you ! To Claim:['SPACY:POS-PROPN'] Call 09071517866:['SPACY:POS-NUM'] Now ! 150ppmPOBox10183BhamB64XE
# -------------------------
# [MATCH]: SMS AUCTION You have won a Nokia:['SPACY:POS-PROPN'] 7250i:['SPACY:POS-NUM'] . This is what you get when you win our FREE auction . To take part send Nokia to 86021 now . HG / Suite342/2Lands Row / W1JHL 16 +
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: WHEN THE FIRST STRIKE IS A RED:['SPACY:POS-PROPN'] ONE:['SPACY:POS-NUM'] . THE BIRD + ANTELOPE BEGIN TOPLAY IN THE FIELDOF SELFINDEPENDENCE BELIEVE THIS + THE FLOWER OF CONTENTION WILL GROW.RANDOM !
# -------------------------
# [MATCH]: 1Apple / Day = No Doctor:['SPACY:POS-PROPN'] . 1Tulsi:['SPACY:POS-NUM'] Leaf / Day = No Cancer . 1Lemon / Day = No Fat . 1Cup Milk / day = No Bone Problms 3 Litres Watr / Day = No Diseases Snd ths 2 Whom U Care .. :- )
# -------------------------
# ==================================================
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.984
# Match: 183 (5.1%)
# Gain = 0.152
# Metric (global) = 0.152
# Examples ~ Class Positive:
# [MATCH]: We tried to contact you re your reply to our offer of 750 mins 150 textand a new video phone call:['TEXT:call'] 08002988890:['SPACY:POS-NUM'] now or reply for free delivery tomorrow
# -------------------------
# [MATCH]: Do you want a new video handset ? 750 anytime any network mins ? Half Price Line Rental ? Camcorder ? Reply or call:['TEXT:call'] 08000930705:['SPACY:POS-NUM'] for delivery tomorrow
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Ummma.will call:['TEXT:call'] after check in.our:['SPACY:POS-NUM'] life will begin from qatar so pls pray very hard .
# -------------------------
# [MATCH]: I 'm in a movie . Call:['TEXT:call'] me 4:['SPACY:POS-NUM'] wat ?
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.579
# Match: 518 (14.5%)
# Gain = 0.148
# Metric (global) = 0.148
# Examples ~ Class Positive:
# [MATCH]: Free entry in 2 a wkly comp to win FA:['SPACY:POS-PROPN'] Cup:['SPACY:POS-PROPN'] final tkts 21st May 2005 . Text FA to 87121 to receive entry question(std txt rate)T&C 's apply 08452810075over18 's
# -------------------------
# [MATCH]: You have an important customer service announcement from PREMIER:['SPACY:POS-PROPN'] . Call FREEPHONE:['SPACY:POS-PROPN'] 0800 542 0578 now !
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Nothing , smsing u n xy lor . Sorry lor da:['SPACY:POS-PROPN'] guys neva:['SPACY:POS-PROPN'] c u in person but they sort of know u lor . So u wan 2 meet them xy ask me 2 bring u along 4 our next meeting .
# -------------------------
# [MATCH]: U havenÂ’t lost me ill always b here 4u.i didnÂ’t intend 2 hurt u but I never knew how u felt about me when Iwas+marine&thatÂ:['SPACY:POS-PROPN'] ’s:['SPACY:POS-PROPN'] what itried2tell urmom.i careabout u
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.613
# Match: 421 (11.8%)
# Gain = 0.129
# Metric (global) = 0.129
# Examples ~ Class Positive:
# [MATCH]: Someone has contacted our dating service and entered your phone becausethey fancy you ! To find out who it is call from:['SPACY:POS-ADP'] a landline 09058098002:['SPACY:POS-NUM'] . PoBox1 , W14RG 150p
# -------------------------
# [MATCH]: No 1 POLYPHONIC tone 4 ur mob every week ! Just txt PT2 to:['SPACY:POS-ADP'] 87575:['SPACY:POS-NUM'] . 1st Tone FREE ! so get txtin now and tell ur friends . 150p / tone . 16 reply HL 4info
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I actually did for the first time in a while . I went to bed not too long after i spoke with you . Woke up at:['SPACY:POS-ADP'] 7:['SPACY:POS-NUM'] . How was your night ?
# -------------------------
# [MATCH]: Ok i found dis:['SPACY:POS-ADP'] pierre cardin one:['SPACY:POS-NUM'] which looks normal costs 20 its on sale .
# -------------------------
# ==================================================

# %%
# Print the learned patterns
for idx, p in enumerate(the_patterns):
    print(f'Rank {idx+1}')
    print(p)
# Out:
# Rank 1
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Metric (global) = 0.223
# Examples ~ Class Negative:
# [MATCH]: One:['SPACY:POS-NUM'] of the joys in lifeis waking up each daywith thoughts that somewhereSomeone cares enough tosend a warm morning greeting .. -
# -------------------------
# [MATCH]: I will reach before ten:['SPACY:POS-NUM'] morning
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Your free ringtone is waiting to be collected . Simply text the password " MIX " to 85069:['SPACY:POS-NUM'] to verify . Get Usher and Britney . FML , PO Box 5249 , MK17 92H. 450Ppw 16
# -------------------------
# [MATCH]: 449050000301:['SPACY:POS-NUM'] You have won a Â£2,000 price ! To claim , call 09050000301 .
# -------------------------
# ==================================================
# Rank 2
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.806
# Match: 319 (8.9%)
# Gain = 0.175
# Metric (global) = 0.175
# Examples ~ Class Positive:
# [MATCH]: URGENT ! We are trying to contact U. Todays draw shows that you have won a Â£800 prize GUARANTEED:['SPACY:POS-PROPN'] . Call 09050003091:['SPACY:POS-NUM'] from land line . Claim C52 . Valid 12hrs only
# -------------------------
# [MATCH]: No . 1 Nokia:['SPACY:POS-PROPN'] Tone 4:['SPACY:POS-NUM'] ur mob every week ! Just txt NOK to 87021 . 1st Tone FREE ! so get txtin now and tell ur friends . 150p / tone . 16 reply HL 4info
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Yun:['SPACY:POS-PROPN'] ah.the ubi one:['SPACY:POS-NUM'] say if Ã¼ wan call by tomorrow.call 67441233 look for irene.ere only got bus8,22,65,61,66,382 . Ubi cres , ubi tech park.6ph for 1st 5wkg days . Ã¨n
# -------------------------
# [MATCH]: Solve d Case : A Man Was Found Murdered On   & lt;DECIMAL&gt ; . & lt;#&gt ;   AfterNoon:['SPACY:POS-PROPN'] . 1,His:['SPACY:POS-NUM'] wife called Police . 2,Police questioned everyone . 3,Wife : Sir , I was sleeping , when the murder took place . 4.Cook : I was cooking . 5.Gardener : I was picking vegetables . 6.House - Maid : I went 2 d post office . 7.Children : We went 2 play . 8.Neighbour : We went 2 a marriage . Police arrested d murderer Immediately . Who 's It ? Reply With Reason , If U r Brilliant .
# -------------------------
# ==================================================
# Rank 3
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.984
# Match: 183 (5.1%)
# Gain = 0.152
# Metric (global) = 0.152
# Examples ~ Class Positive:
# [MATCH]: Thanks for your ringtone order , reference number X29 . Your mobile will be charged 4.50 . Should your tone not arrive please call:['TEXT:call'] customer services 09065989180:['SPACY:POS-NUM']
# -------------------------
# [MATCH]: You have an important customer service announcement . Call:['TEXT:call'] FREEPHONE 0800:['SPACY:POS-NUM'] 542 0825 now !
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Yun ah.the ubi one say if Ã¼ wan call:['TEXT:call'] by tomorrow.call 67441233:['SPACY:POS-NUM'] look for irene.ere only got bus8,22,65,61,66,382 . Ubi cres , ubi tech park.6ph for 1st 5wkg days . Ã¨n
# -------------------------
# [MATCH]: Ummma.will call:['TEXT:call'] after check in.our:['SPACY:POS-NUM'] life will begin from qatar so pls pray very hard .
# -------------------------
# ==================================================
# Rank 4
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.579
# Match: 518 (14.5%)
# Gain = 0.148
# Metric (global) = 0.148
# Examples ~ Class Positive:
# [MATCH]: FreeMsg:['SPACY:POS-PROPN'] > FAV:['SPACY:POS-PROPN'] XMAS TONES!Reply REAL
# -------------------------
# [MATCH]: U have a secret admirer . REVEAL:['SPACY:POS-PROPN'] who thinks U:['SPACY:POS-PROPN'] R So special . Call 09065174042 . To opt out Reply REVEAL STOP . 1.50 per msg recd . Cust care 07821230901
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Sad story of a Man - Last week was my b'day . My Wife did'nt wish me . My Parents forgot n so did my Kids . I went to work . Even my Colleagues did not wish . As I entered my cabin my PA said , '' Happy B'day:['SPACY:POS-PROPN'] Boss:['SPACY:POS-PROPN'] ! ! '' . I felt special . She askd me 4 lunch . After lunch she invited me to her apartment . We went there . She said , '' do u mind if I go into the bedroom for a minute ? '' ' ' OK '' , I sed in a sexy mood . She came out 5 minuts latr wid a cake ... n My Wife , My Parents , My Kidz , My Friends n My Colleagues . All screaming .. SURPRISE ! ! and I was waiting on the sofa .. ... ..... ' NAKED ... !
# -------------------------
# [MATCH]: TODAY is Sorry day . ! If ever i was angry with you , if ever i misbehaved or hurt you ? plz plz JUST SLAP URSELF:['SPACY:POS-PROPN'] Bcoz:['SPACY:POS-PROPN'] , Its ur fault , I 'm basically GOOD
# -------------------------
# ==================================================
# Rank 5
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.613
# Match: 421 (11.8%)
# Gain = 0.129
# Metric (global) = 0.129
# Examples ~ Class Positive:
# [MATCH]: Hey I am really horny want to chat or see me naked text hot to:['SPACY:POS-ADP'] 69698:['SPACY:POS-NUM'] text charged at 150pm to unsubscribe text stop 69698
# -------------------------
# [MATCH]: Sorry I missed your call let 's talk when you have the time . I 'm on:['SPACY:POS-ADP'] 07090201529:['SPACY:POS-NUM']
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: You know my old Dom I told you about yesterday ? His name is Roger ? He got in touch with me last night and wants me to meet him today at:['SPACY:POS-ADP'] 2:['SPACY:POS-NUM'] pm
# -------------------------
# [MATCH]: Do u ever get a song stuck in your head for no reason and it wo n't go away til u listen to:['SPACY:POS-ADP'] it like 5:['SPACY:POS-NUM'] times ?
# -------------------------
# ==================================================
# Rank 6
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.811
# Match: 243 (6.8%)
# Gain = 0.129
# Metric (global) = 0.129
# Examples ~ Class Positive:
# [MATCH]: YOU VE WON ! Your 4:['SPACY:POS-NUM'] * Costa:['SPACY:POS-PROPN'] Del Sol Holiday or Â£5000 await collection . Call 09050090044 Now toClaim . SAE , TC s , POBox334 , Stockport , SK38xh , CostÂ£1.50/pm , Max10mins
# -------------------------
# [MATCH]: YOU 07801543489 are guaranteed the latests Nokia Phone , a 40:['SPACY:POS-NUM'] GB:['SPACY:POS-PROPN'] iPod MP3 player or a Â£500 prize ! Txt word : COLLECT to No:83355 ! TC - LLC NY - USA 150p / Mt msgrcvd18 +
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Solve d Case : A Man Was Found Murdered On   & lt;DECIMAL&gt ; . & lt;#&gt ;   AfterNoon . 1,His:['SPACY:POS-NUM'] wife called Police:['SPACY:POS-PROPN'] . 2,Police questioned everyone . 3,Wife : Sir , I was sleeping , when the murder took place . 4.Cook : I was cooking . 5.Gardener : I was picking vegetables . 6.House - Maid : I went 2 d post office . 7.Children : We went 2 play . 8.Neighbour : We went 2 a marriage . Police arrested d murderer Immediately . Who 's It ? Reply With Reason , If U r Brilliant .
# -------------------------
# [MATCH]: Thank You for calling . Forgot to say Happy Onam to you Sirji . I am fine here and remembered you when i met an insurance person . Meet You in Qatar Insha Allah . Rakhesh , ex:['SPACY:POS-NUM'] Tata:['SPACY:POS-PROPN'] AIG who joined TISSCO , Tayseer .
# -------------------------
# ==================================================
# Rank 7
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Negative
# Precision: 0.526
# Match: 644 (18.1%)
# Gain = 0.119
# Metric (global) = 0.119
# Examples ~ Class Negative:
# [MATCH]: Eat jap done oso aft ur lect wat:['SPACY:POS-NOUN'] ... Ãœ:['SPACY:POS-PROPN'] got lect at 12 rite ...
# -------------------------
# [MATCH]: Hi Jon , Pete here , I ve bin 2 Spain recently & hav sum dinero:['SPACY:POS-NOUN'] left , Bill:['SPACY:POS-PROPN'] said u or ur Â‘rents mayb interested in it , I hav 12,000pes , so around Â£48 , tb , James .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: I want some cock ! My hubby 's away , I need a real man 2 satisfy me . Txt WIFE to 89938 for no strings action:['SPACY:POS-NOUN'] . ( Txt:['SPACY:POS-PROPN'] STOP 2 end , txt rec Â£1.50ea . OTBox 731 LA1 7WS . )
# -------------------------
# [MATCH]: Sunshine Hols . To claim ur med holiday send a stamped self address:['SPACY:POS-NOUN'] envelope to Drinks:['SPACY:POS-PROPN'] on Us UK , PO Box 113 , Bray , Wicklow , Eire . Quiz Starts Saturday ! Unsub Stop
# -------------------------
# ==================================================
# Rank 8
# Pattern: [['TEXT:to'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.856
# Match: 194 (5.4%)
# Gain = 0.114
# Metric (global) = 0.114
# Examples ~ Class Positive:
# [MATCH]: Dear U've been invited to XCHAT . This is our final attempt to contact u ! Txt CHAT to:['TEXT:to'] 86688:['SPACY:POS-NUM'] 150p / MsgrcvdHG / Suite342/2Lands / Row / W1J6HL LDN 18 yrs
# -------------------------
# [MATCH]: 500 New Mobiles from 2004 , MUST GO ! Txt : NOKIA to:['TEXT:to'] No : 89545:['SPACY:POS-NUM'] & collect yours today!From ONLY Â£1 www.4-tc.biz 2optout 087187262701.50gbp / mtmsg18
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: 1 ) Go to:['TEXT:to'] write msg 2:['SPACY:POS-NUM'] ) Put on Dictionary mode 3)Cover the screen with hand , 4)Press   & lt;#&gt ; . 5)Gently remove Ur hand .. Its interesting .. : )
# -------------------------
# [MATCH]: I might come to:['TEXT:to'] kerala for 2:['SPACY:POS-NUM'] days.so you can be prepared to take a leave once i finalise .dont plan any travel during my visit.need to finish urgent works .
# -------------------------
# ==================================================
# Rank 9
# Pattern: [['SPACY:POS-PROPN']]
# Window size: 3
# Class: Negative
# Precision: 0.690
# Match: 1347 (37.8%)
# Gain = 0.112
# Metric (global) = 0.112
# Examples ~ Class Negative:
# [MATCH]: They can try ! They can get lost , in fact . Tee:['SPACY:POS-PROPN'] hee
# -------------------------
# [MATCH]: Babe:['SPACY:POS-PROPN'] ! How goes that day ? What are you up to ? I miss you already , my Love ... * loving kiss * ... I hope everything goes well .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: U have a secret admirer who is looking 2 make contact with U - find out who they R*reveal:['SPACY:POS-PROPN'] who thinks UR so special - call on 09058094594
# -------------------------
# [MATCH]: Urgent ! Please call 09061213237 from landline . Â£5000 cash or a luxury 4 * Canary:['SPACY:POS-PROPN'] Islands Holiday await collection . T&Cs SAE PO Box 177 . M227XY . 150ppm . 16 +
# -------------------------
# ==================================================
# Rank 10
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.702
# Match: 272 (7.6%)
# Gain = 0.105
# Metric (global) = 0.105
# Examples ~ Class Positive:
# [MATCH]: FREE for 1st week ! No1 Nokia tone 4 ur mobile every week just txt NOKIA to 8077 Get txting and tell ur mates:['SPACY:POS-NOUN'] . www.getzed.co.uk POBox:['SPACY:POS-NOUN'] 36504:['SPACY:POS-NUM'] W45WQ 16 + norm150p / tone
# -------------------------
# [MATCH]: 74355 XMAS iscoming & ur awarded either Â£500 CD gift vouchers:['SPACY:POS-NOUN'] & free entry:['SPACY:POS-NOUN'] 2:['SPACY:POS-NUM'] r Â£100 weekly draw txt MUSIC to 87066 TnC
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: & lt;#&gt ;   is fast approaching . So , Wish u a very Happy New Year Happy Sankranti Happy republic day Happy Valentines Day Happy Shivratri Happy Ugadi Happy Fools day Happy May Day Happy Independence Day , Happy Friendship , Mother , Father , Teachers , Childrens Day , & amp:['SPACY:POS-NOUN'] ; HAPPY BIRTHDAY:['SPACY:POS-NOUN'] 4:['SPACY:POS-NUM'] U. Happy Ganesh festival Happy Dasara Happy Diwali Happy Christmas   & lt;#&gt ;   Good Mornings Afternoons , Evenings Nights . RememberI AM the first to WISHING U ALL THESE ... your 's Raj
# -------------------------
# [MATCH]: Sorry i now then c ur msg ... Yar lor so poor thing ... But only 4 one night ... Tmr u'll have a brand:['SPACY:POS-NOUN'] new room:['SPACY:POS-NOUN'] 2:['SPACY:POS-NUM'] sleep in ...
# -------------------------
# ==================================================
# Rank 11
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 5
# Class: Positive
# Precision: 0.722
# Match: 255 (7.1%)
# Gain = 0.104
# Metric (global) = 0.104
# Examples ~ Class Positive:
# [MATCH]: Hi 07734396839 IBH:['SPACY:POS-PROPN'] Customer:['SPACY:POS-PROPN'] Loyalty:['SPACY:POS-PROPN'] Offer : The NEW NOKIA6600 Mobile from ONLY Â£10 at TXTAUCTION!Txt word : START to No:81151 & get Yours Now!4 T &
# -------------------------
# [MATCH]: You are being ripped off ! Get your mobile content from www.clubmoby.com call 08717509990 poly / true / Pix:['SPACY:POS-PROPN'] / Ringtones:['SPACY:POS-PROPN'] / Games:['SPACY:POS-PROPN'] six downloads for only 3
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Nothing , smsing u n xy lor . Sorry lor da:['SPACY:POS-PROPN'] guys neva:['SPACY:POS-PROPN'] c:['SPACY:POS-PROPN'] u in person but they sort of know u lor . So u wan 2 meet them xy ask me 2 bring u along 4 our next meeting .
# -------------------------
# [MATCH]: WHEN THE FIRST STRIKE IS A RED ONE . THE BIRD:['SPACY:POS-PROPN'] + ANTELOPE:['SPACY:POS-PROPN'] BEGIN TOPLAY:['SPACY:POS-PROPN'] IN THE FIELDOF SELFINDEPENDENCE BELIEVE THIS + THE FLOWER OF CONTENTION WILL GROW.RANDOM !
# -------------------------
# ==================================================
# Rank 12
# Pattern: [['TEXT:.'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.797
# Match: 202 (5.7%)
# Gain = 0.101
# Metric (global) = 0.101
# Examples ~ Class Positive:
# [MATCH]: FREE for 1st week ! No1 Nokia tone 4 ur mobile every week just txt NOKIA to 8077 Get txting and tell ur mates .:['TEXT:.'] www.getzed.co.uk POBox 36504:['SPACY:POS-NUM'] W45WQ 16 + norm150p / tone
# -------------------------
# [MATCH]: Want to funk up ur fone with a weekly new tone reply TONES2U 2 this text . www.ringtones.co.uk , the original n best .:['TEXT:.'] Tones 3GBP:['SPACY:POS-NUM'] network operator rates apply
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: As per your request ' Melle Melle ( Oru Minnaminunginte Nurungu Vettam ) ' has been set as your callertune for all Callers .:['TEXT:.'] Press * 9:['SPACY:POS-NUM'] to copy your friends Callertune
# -------------------------
# [MATCH]: Solve d Case : A Man Was Found Murdered On   & lt;DECIMAL&gt ; . & lt;#&gt ;   AfterNoon .:['TEXT:.'] 1,His:['SPACY:POS-NUM'] wife called Police . 2,Police questioned everyone . 3,Wife : Sir , I was sleeping , when the murder took place . 4.Cook : I was cooking . 5.Gardener : I was picking vegetables . 6.House - Maid : I went 2 d post office . 7.Children : We went 2 play . 8.Neighbour : We went 2 a marriage . Police arrested d murderer Immediately . Who 's It ? Reply With Reason , If U r Brilliant .
# -------------------------
# ==================================================
# Rank 13
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.735
# Match: 238 (6.7%)
# Gain = 0.100
# Metric (global) = 0.100
# Examples ~ Class Positive:
# [MATCH]: LORD OF THE RINGS : RETURN OF THE KING in store NOW!REPLY LOTR by 2:['SPACY:POS-NUM'] June 4:['SPACY:POS-NUM'] Chance 2 WIN LOTR soundtrack CDs StdTxtRate . Reply STOP to end txts
# -------------------------
# [MATCH]: * * FREE MESSAGE**Thanks for using the Auction Subscription Service . 18:['SPACY:POS-NUM'] . 150p:['SPACY:POS-NUM'] / MSGRCVD 2 Skip an Auction txt OUT . 2 Unsubscribe txt STOP CustomerCare 08718726270
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Ok i also wan 2:['SPACY:POS-NUM'] watch e 9:['SPACY:POS-NUM'] pm show ...
# -------------------------
# [MATCH]: Camera quite good , 10.1mega:['SPACY:POS-NUM'] pixels , 3optical:['SPACY:POS-NUM'] and 5digital dooms . Have a lovely holiday , be safe and i hope you hav a good journey ! Happy new year to you both ! See you in a couple of weeks !
# -------------------------
# ==================================================
# Rank 14
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
# Window size: 4
# Class: Negative
# Precision: 0.585
# Match: 714 (20.0%)
# Gain = 0.095
# Metric (global) = 0.095
# Examples ~ Class Negative:
# [MATCH]: Mmmmmm ... I love you , so much , Ahmad ... I ca n't wait for this year to begin as every second takes me closer to being at your side . Happy New Year:['SPACY:POS-PROPN'] , my love:['SPACY:POS-NOUN'] ! !
# -------------------------
# [MATCH]: Got ur mail Dileep.thank:['SPACY:POS-PROPN'] you so muchand:['SPACY:POS-NOUN'] look forward to lots of support ... very less contacts here , remember one venugopal you mentioned.tomorrow if not late , i shall try to come up till there.goodnight dear .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: 1st wk FREE ! Gr8 tones str8 2 u each wk . Txt NOKIA ON to 8007 for Classic:['SPACY:POS-PROPN'] Nokia tones:['SPACY:POS-NOUN'] or HIT ON to 8007 for Polys . Nokia/150p Poly/200p 16 +
# -------------------------
# [MATCH]: ou are guaranteed the latest Nokia Phone , a 40 GB:['SPACY:POS-PROPN'] iPod MP3:['SPACY:POS-NOUN'] player or a Â£500 prize ! Txt word : COLLECT to No : 83355 ! IBHltd LdnW15H 150p / Mtmsgrcvd18
# -------------------------
# ==================================================
# Rank 15
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
# Window size: 4
# Class: Positive
# Precision: 0.597
# Match: 313 (8.8%)
# Gain = 0.085
# Metric (global) = 0.085
# Examples ~ Class Positive:
# [MATCH]: Do you want 750 anytime any network mins 150 text and a NEW VIDEO phone for only five:['SPACY:POS-NUM'] pounds per:['SPACY:POS-ADP'] week call 08002888812 or reply for delivery tomorrow
# -------------------------
# [MATCH]: PRIVATE ! Your 2003:['SPACY:POS-NUM'] Account Statement for:['SPACY:POS-ADP'] shows 800 un - redeemed S. I. M. points . Call 08719899230 Identifier Code : 41685 Expires 07/11/04
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Sweetheart , hope you are not having that kind of day ! Have one:['SPACY:POS-NUM'] with:['SPACY:POS-ADP'] loads of reasons to smile . Biola
# -------------------------
# [MATCH]: Did he say how fantastic I am by any chance , or anything need a bigger life lift as losing the will 2 live , do you think I would be the first person 2:['SPACY:POS-NUM'] die from:['SPACY:POS-ADP'] N V Q ?
# -------------------------
# ==================================================
# Rank 16
# Pattern: [['SPACY:POS-ADJ'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.655
# Match: 258 (7.2%)
# Gain = 0.084
# Metric (global) = 0.084
# Examples ~ Class Positive:
# [MATCH]: Dear:['SPACY:POS-ADJ'] 0776xxxxxxx:['SPACY:POS-NUM'] U've been invited to XCHAT . This is our final attempt to contact u ! Txt CHAT to 86688 150p / MsgrcvdHG / Suite342/2Lands / Row / W1J6HL LDN 18yrs
# -------------------------
# [MATCH]: Not heard from U4 a while . Call 4 rude chat private:['SPACY:POS-ADJ'] line 01223585334:['SPACY:POS-NUM'] to cum . Wan 2C pics of me gettin shagged then text PIX to 8552 . 2End send STOP 8552 SAM xxx
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Anything is valuable:['SPACY:POS-ADJ'] in only 2:['SPACY:POS-NUM'] situations : First- Before getting it ... Second- After loosing it ...
# -------------------------
# [MATCH]: The 2 oz guy is being kinda flaky:['SPACY:POS-ADJ'] but one:['SPACY:POS-NUM'] friend is interested in picking up $ & lt;#&gt ;   worth tonight if possible
# -------------------------
# ==================================================
# Rank 17
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
# Window size: 5
# Class: Positive
# Precision: 0.649
# Match: 259 (7.3%)
# Gain = 0.083
# Metric (global) = 0.083
# Examples ~ Class Positive:
# [MATCH]: XCLUSIVE@CLUBSAISAI 2MOROW 28/5 SOIREE SPECIALE ZOUK WITH NICHOLS FROM PARIS.FREE:['SPACY:POS-PROPN'] ROSES:['SPACY:POS-PROPN'] 2 ALL LADIES:['SPACY:POS-NOUN'] ! ! ! info : 07946746291/07880867867
# -------------------------
# [MATCH]: Phony:['SPACY:POS-PROPN'] Â£350:['SPACY:POS-PROPN'] award:['SPACY:POS-NOUN'] - Todays Voda numbers ending XXXX are selected to receive a Â£350 award . If you have a match please call 08712300220 quoting claim code 3100 standard rates app
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: NEFT:['SPACY:POS-PROPN'] Transaction:['SPACY:POS-PROPN'] with reference:['SPACY:POS-NOUN'] number   & lt;#&gt ;   for Rs . & lt;DECIMAL&gt ;   has been credited to the beneficiary account on   & lt;#&gt ;   at   & lt;TIME&gt ; : & lt;#&gt ;
# -------------------------
# [MATCH]: Alrite jod how s the revision goin ? Keris:['SPACY:POS-PROPN'] bin:['SPACY:POS-PROPN'] doin a smidgin:['SPACY:POS-NOUN'] . N e way u wanna cum over after college?xx
# -------------------------
# ==================================================
# Rank 18
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.926
# Match: 121 (3.4%)
# Gain = 0.082
# Metric (global) = 0.082
# Examples ~ Class Positive:
# [MATCH]: 500 New:['SPACY:POS-PROPN'] Mobiles from:['SPACY:POS-ADP'] 2004:['SPACY:POS-NUM'] , MUST GO ! Txt : NOKIA to No : 89545 & collect yours today!From ONLY Â£1 www.4-tc.biz 2optout 087187262701.50gbp / mtmsg18
# -------------------------
# [MATCH]: PRIVATE ! Your 2003 Account:['SPACY:POS-PROPN'] Statement for:['SPACY:POS-ADP'] 07808247860:['SPACY:POS-NUM'] shows 800 un - redeemed S. I. M. points . Call 08719899229 Identifier Code : 40411 Expires 06/11/04
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: We made it ! Eta:['SPACY:POS-PROPN'] at:['SPACY:POS-ADP'] taunton is 12:30:['SPACY:POS-NUM'] as planned , hope thatâ€˜s still okday ? ! Good to see you ! : -xx
# -------------------------
# [MATCH]: Aiya we discuss later lar ... Pick:['SPACY:POS-PROPN'] Ã¼ up at:['SPACY:POS-ADP'] 4:['SPACY:POS-NUM'] is it ?
# -------------------------
# ==================================================
# Rank 19
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]
# Window size: 4
# Class: Positive
# Precision: 0.504
# Match: 421 (11.8%)
# Gain = 0.080
# Metric (global) = 0.080
# Examples ~ Class Positive:
# [MATCH]: U have a secret admirer . REVEAL who thinks U R So special . Call 09065174042 . To opt out Reply REVEAL STOP:['SPACY:POS-PROPN'] . 1.50 per:['SPACY:POS-ADP'] msg recd . Cust care 07821230901
# -------------------------
# [MATCH]: HMV BONUS SPECIAL:['SPACY:POS-PROPN'] 500 pounds of:['SPACY:POS-ADP'] genuine HMV vouchers to be won . Just answer 4 easy questions . Play Now ! Send HMV to 86688 More info : www.100percent - real.com
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: When people see my msgs , They think Iam:['SPACY:POS-PROPN'] addicted to:['SPACY:POS-ADP'] msging ... They are wrong , Bcoz They don\'t know that Iam addicted to my sweet Friends .. ! ! BSLVYL
# -------------------------
# [MATCH]: Y:['SPACY:POS-PROPN'] de:['SPACY:POS-ADP'] asking like this .
# -------------------------
# ==================================================
# Rank 20
# Pattern: [['SPACY:POS-NUM'], ['TEXT:.']]
# Window size: 4
# Class: Positive
# Precision: 0.591
# Match: 286 (8.0%)
# Gain = 0.074
# Metric (global) = 0.074
# Examples ~ Class Positive:
# [MATCH]: No . 1 Nokia Tone 4 ur mob every week ! Just txt NOK to 87021:['SPACY:POS-NUM'] .:['TEXT:.'] 1st Tone FREE ! so get txtin now and tell ur friends . 150p / tone . 16 reply HL 4info
# -------------------------
# [MATCH]: Camera - You are awarded a SiPix Digital Camera ! call 09061221066:['SPACY:POS-NUM'] fromm landline .:['TEXT:.'] Delivery within 28 days .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Darren was saying dat if u meeting da ge den we dun meet 4:['SPACY:POS-NUM'] dinner .:['TEXT:.'] Cos later u leave xy will feel awkward . Den u meet him 4 lunch lor .
# -------------------------
# [MATCH]: Once a fishrman woke early in d mrng . It was very dark . He waited a while & amp ; found a sack ful of stones . He strtd throwin thm in2 d sea 2:['SPACY:POS-NUM'] pass time .:['TEXT:.'] Atlast he had jus 1stone , sun rose up & amp ; he found out tht those r nt stones , those were diamonds . Moral:"Dont wake up early in d mrng '' GOOD night
# -------------------------
# ==================================================
# Rank 21
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-VERB']]
# Window size: 4
# Class: Positive
# Precision: 0.525
# Match: 360 (10.1%)
# Gain = 0.073
# Metric (global) = 0.073
# Examples ~ Class Positive:
# [MATCH]: U have a Secret Admirer who is looking 2:['SPACY:POS-NUM'] make:['SPACY:POS-VERB'] contact with U - find out who they R*reveal who thinks UR so special - call on 09065171142-stopsms-08718727870150ppm
# -------------------------
# [MATCH]: Congratulations U can claim 2 VIP row A Tickets 2 C Blu in concert in November or Blu gift guaranteed Call 09061104276:['SPACY:POS-NUM'] to claim:['SPACY:POS-VERB'] TS&Cs www.smsco.net costÂ£3.75max
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: As per your request ' Melle Melle ( Oru Minnaminunginte Nurungu Vettam ) ' has been set as your callertune for all Callers . Press * 9:['SPACY:POS-NUM'] to copy:['SPACY:POS-VERB'] your friends Callertune
# -------------------------
# [MATCH]: From someone not to smoke when every time I 've smoked in the last two:['SPACY:POS-NUM'] weeks is:['SPACY:POS-VERB'] because of you calling or texting me that you wanted to smoke
# -------------------------
# ==================================================
# Rank 22
# Pattern: [['SPACY:POS-NOUN'], ['TEXT:call']]
# Window size: 4
# Class: Positive
# Precision: 0.791
# Match: 153 (4.3%)
# Gain = 0.073
# Metric (global) = 0.073
# Examples ~ Class Positive:
# [MATCH]: YOUR CHANCE TO BE ON A REALITY:['SPACY:POS-NOUN'] FANTASY SHOW call:['TEXT:call'] now = 08707509020 Just 20p per min NTT Ltd , PO Box 1327 Croydon CR9 5WB 0870 is a national = rate call .
# -------------------------
# [MATCH]: PRIVATE ! Your 2003 Account Statement for shows 800 un - redeemed S. I. M. points:['SPACY:POS-NOUN'] . Call:['TEXT:call'] 08718738002 Identifier Code : 48922 Expires 21/11/04
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I 'm in a meeting:['SPACY:POS-NOUN'] , call:['TEXT:call'] me later at
# -------------------------
# [MATCH]: Hi.:)technical support.providing assistance to us customer:['SPACY:POS-NOUN'] through call:['TEXT:call'] and email : )
# -------------------------
# ==================================================
# Rank 23
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.843
# Match: 127 (3.6%)
# Gain = 0.069
# Metric (global) = 0.069
# Examples ~ Class Positive:
# [MATCH]: This is the 2nd time we have tried to contact u. U have won the Â£1450 prize to claim just call 09053750005 b4 310303 . T&Cs:['SPACY:POS-PROPN'] / stop SMS:['SPACY:POS-NOUN'] 08718725756:['SPACY:POS-NUM'] . 140ppm
# -------------------------
# [MATCH]: Dear Dave this is your final notice to collect your 4 * Tenerife Holiday or # 5000 CASH award ! Call 09061743806 from landline . TCs SAE:['SPACY:POS-PROPN'] Box326 CW25WX:['SPACY:POS-NOUN'] 150ppm:['SPACY:POS-NUM']
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: OH YEAH , AND HAV A GREAT TIME IN NEWQUAY - SEND ME:['SPACY:POS-PROPN'] A POSTCARD:['SPACY:POS-NOUN'] ! 1:['SPACY:POS-NUM'] LOOK AFTER ALL THE GIRLS WHILE IM GONE(U KNOW THE 1IM TALKIN BOUT!)xx
# -------------------------
# [MATCH]: HEY THERE BABE , HOW U DOIN ? WOT:['SPACY:POS-PROPN'] U:['SPACY:POS-NOUN'] UP 2:['SPACY:POS-NUM'] 2NITE LOVE ANNIE X.
# -------------------------
# ==================================================
# Rank 24
# Pattern: [['SPACY:POS-VERB'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Negative
# Precision: 0.585
# Match: 556 (15.6%)
# Gain = 0.068
# Metric (global) = 0.068
# Examples ~ Class Negative:
# [MATCH]: HCL chennai requires FRESHERS for voice process . Excellent english needed:['SPACY:POS-VERB'] . Salary:['SPACY:POS-PROPN'] upto   & lt;#&gt ; .Call Ms . Suman   & lt;#&gt ;   for Telephonic interview -via Indyarocks.com
# -------------------------
# [MATCH]: Hi mate:['SPACY:POS-VERB'] its RV:['SPACY:POS-PROPN'] did u hav a nice hol just a message 3 say hello coz havenÂ’t sent u 1 in ages started driving so stay off roads!RVx
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Not heard:['SPACY:POS-VERB'] from U4:['SPACY:POS-PROPN'] a while . Call 4 rude chat private line 01223585334 to cum . Wan 2C pics of me gettin shagged then text PIX to 8552 . 2End send STOP 8552 SAM xxx
# -------------------------
# [MATCH]: You have:['SPACY:POS-VERB'] won a Nokia:['SPACY:POS-PROPN'] 7250i . This is what you get when you win our FREE auction . To take part send Nokia to 86021 now . HG / Suite342/2Lands Row / W1JHL 16 +
# -------------------------
# ==================================================
# Rank 25
# Pattern: [['TEXT:i']]
# Window size: 3
# Class: Negative
# Precision: 0.983
# Match: 1327 (37.2%)
# Gain = 0.067
# Metric (global) = 0.067
# Examples ~ Class Negative:
# [MATCH]: Going thru a very different feeling.wavering decisions and coping up with the same is the same individual.time will heal everything i:['TEXT:i'] believe .
# -------------------------
# [MATCH]: Oops I:['TEXT:i'] did have it ,   & lt;#&gt ; ?
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: FreeMsg Today 's the day if you are ready ! I:['TEXT:i'] 'm horny & live in your town . I love sex fun & games ! Netcollex Ltd 08700621170150p per msg reply Stop to end
# -------------------------
# [MATCH]: Hi its LUCY Hubby at meetins all day Fri & I:['TEXT:i'] will B alone at hotel U fancy cumin over ? Pls leave msg 2day 09099726395 Lucy x CallsÂ£1/minMobsmoreLKPOBOX177HP51FL
# -------------------------
# ==================================================
# Rank 26
# Pattern: [['SPACY:POS-SYM']]
# Window size: 3
# Class: Positive
# Precision: 0.756
# Match: 156 (4.4%)
# Gain = 0.067
# Metric (global) = 0.067
# Examples ~ Class Positive:
# [MATCH]: Text BANNEDUK to 89555 to see ! cost 150p textoperator g696ga 18 +:['SPACY:POS-SYM'] XXX
# -------------------------
# [MATCH]: Mila , age23 , blonde , new in UK . I look sex with UK guys . if u like fun with me . Text MTALK to 69866.18 . 30pp /:['SPACY:POS-SYM'] txt 1st 5free . Â£1.50 increments . Help08718728876
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: The 2 oz guy is being kinda flaky but one friend is interested in picking up $:['SPACY:POS-SYM'] & lt;#&gt ;   worth tonight if possible
# -------------------------
# [MATCH]: Turns out my friends are staying for the whole show and wo n't be back til ~ & lt;#&gt ; , so feel free to go ahead and smoke that $:['SPACY:POS-SYM'] & lt;#&gt ;   worth
# -------------------------
# ==================================================
# Rank 27
# Pattern: [['TEXT:free']]
# Window size: 3
# Class: Positive
# Precision: 0.748
# Match: 159 (4.5%)
# Gain = 0.067
# Metric (global) = 0.067
# Examples ~ Class Positive:
# [MATCH]: FREE:['TEXT:free'] for 1st week ! No1 Nokia tone 4 ur mob every week just txt NOKIA to 8007 Get txting and tell ur mates www.getzed.co.uk POBox 36504 W45WQ norm150p / tone 16 +
# -------------------------
# [MATCH]: Do you want a new Video phone ? 600 anytime any network mins 400 Inclusive Video calls AND downloads 5 per week Free:['TEXT:free'] delTOMORROW call 08002888812 or reply NOW
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Hi ! You just spoke to MANEESHA V. We 'd like to know if you were satisfied with the experience . Reply Toll Free:['TEXT:free'] with Yes or No .
# -------------------------
# [MATCH]: That sucks . I 'll go over so u can do my hair . You 'll do it free:['TEXT:free'] right ?
# -------------------------
# ==================================================
# Rank 28
# Pattern: [['TEXT:txt']]
# Window size: 3
# Class: Positive
# Precision: 0.938
# Match: 96 (2.7%)
# Gain = 0.067
# Metric (global) = 0.067
# Examples ~ Class Positive:
# [MATCH]: Sunshine Quiz Wkly Q ! Win a top Sony DVD player if u know which country Liverpool played in mid week ? Txt:['TEXT:txt'] ansr to 82277 . Â£1.50 SP : Tyrone
# -------------------------
# [MATCH]: WIN a year supply of CDs 4 a store of ur choice worth Â£500 & enter our Â£100 Weekly draw txt:['TEXT:txt'] MUSIC to 87066 Ts&Cs www . Ldew.com.subs16 + 1win150ppmx3
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Oh yes I can speak txt:['TEXT:txt'] 2 u no ! Hmm . Did u get   email ?
# -------------------------
# [MATCH]: " Getting tickets 4 walsall tue 6 th march . My mate is getting me them on sat . ill pay my treat . Want 2 go . Txt:['TEXT:txt'] bak .Terry "
# -------------------------
# ==================================================
# Rank 29
# Pattern: [['SPACY:POS-VERB', 'TEXT:call']]
# Window size: 3
# Class: Positive
# Precision: 0.591
# Match: 257 (7.2%)
# Gain = 0.066
# Metric (global) = 0.066
# Examples ~ Class Positive:
# [MATCH]: Urgent ! call:['TEXT:call', 'SPACY:POS-VERB'] 09066612661 from landline . Your complementary 4 * Tenerife Holiday or Â£10,000 cash await collection SAE T&Cs PO Box 3 WA14 2PX 150ppm 18 + Sender : Hol Offer
# -------------------------
# [MATCH]: Hack Chat . Get backdoor entry into 121 chat rooms at a fraction of the cost . Reply NEO69 or call:['TEXT:call', 'SPACY:POS-VERB'] 09050280520 , to subscribe 25p pm . DPS , Bcm box 8027 Ldn , wc1n3xx
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Sir , i am waiting for your call , once free please call:['TEXT:call', 'SPACY:POS-VERB'] me .
# -------------------------
# [MATCH]: Pls call:['TEXT:call', 'SPACY:POS-VERB'] me da . What happen .
# -------------------------
# ==================================================
# Rank 30
# Pattern: [['SPACY:POS-NOUN'], ['TEXT:to']]
# Window size: 4
# Class: Negative
# Precision: 0.591
# Match: 552 (15.5%)
# Gain = 0.065
# Metric (global) = 0.065
# Examples ~ Class Negative:
# [MATCH]: Can you call me plz . Your number shows out of coveragd area . I have urgnt call in vasai & amp:['SPACY:POS-NOUN'] ; have to:['TEXT:to'] reach before 4'o clock so call me plz
# -------------------------
# [MATCH]: Can you tell Shola to please go to college of medicine and visit the academic department , tell the academic secretary what the current situation is and ask if she can transfer there . She should ask someone:['SPACY:POS-NOUN'] to:['TEXT:to'] check Sagamu for the same thing and lautech . Its vital she completes her medical education in Nigeria . Its less expensive much less expensive . Unless she will be getting citizen rates in new zealand .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Goal ! Arsenal 4 ( Henry , 7 v Liverpool 2 Henry scores with a simple shot from 6 yards from a pass:['SPACY:POS-NOUN'] by Bergkamp to:['TEXT:to'] give Arsenal a 2 goal margin after 78 mins .
# -------------------------
# [MATCH]: FreeMsg Today 's the day if you are ready ! I 'm horny & live in your town . I love sex fun & games ! Netcollex Ltd 08700621170150p per msg:['SPACY:POS-NOUN'] reply Stop to:['TEXT:to'] end
# -------------------------
# ==================================================
# Rank 31
# Pattern: [['TEXT:claim']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 77 (2.2%)
# Gain = 0.064
# Metric (global) = 0.064
# Examples ~ Class Positive:
# [MATCH]: Last Chance ! Claim:['TEXT:claim'] ur Â£150 worth of discount vouchers today ! Text SHOP to 85023 now ! SavaMob , offers mobile ! T Cs SavaMob POBOX84 , M263UZ . Â£3.00 Sub . 16
# -------------------------
# [MATCH]: WIN URGENT ! Your mobile number has been awarded with a Â£2000 prize GUARANTEED call 09061790121 from land line . claim:['TEXT:claim'] 3030 valid 12hrs only 150ppm
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Rank 32
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-ADP', 'TEXT:to']]
# Window size: 4
# Class: Positive
# Precision: 0.592
# Match: 250 (7.0%)
# Gain = 0.064
# Metric (global) = 0.064
# Examples ~ Class Positive:
# [MATCH]: FREEMSG : Our records indicate you may be entitled to 3750 pounds for the Accident you had . To claim for free reply:['SPACY:POS-NOUN'] with YES to:['TEXT:to', 'SPACY:POS-ADP'] this msg . To opt out text STOP
# -------------------------
# [MATCH]: Your unique user ID is 1172 . For removal:['SPACY:POS-NOUN'] send STOP to:['TEXT:to', 'SPACY:POS-ADP'] 87239 customer services 08708034412
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Rose for red , red for blood , blood for heart , heart for u. But u for me .... Send tis:['SPACY:POS-NOUN'] to:['TEXT:to', 'SPACY:POS-ADP'] all ur friends .. Including me .. If u like me .. If u get back , 1-u r poor in relation ! 2-u need some 1 to support 3-u r frnd 2 many 4-some1 luvs u 5 + - some1 is praying god to marry u.:- ) try it ....
# -------------------------
# [MATCH]: Its a valentine game . . . Send dis:['SPACY:POS-NOUN'] msg to:['TEXT:to', 'SPACY:POS-ADP'] all ur friends . .. If 5 answers r d same then someone really loves u. Ques- which colour suits me the best?rply me
# -------------------------
# ==================================================
# Rank 33
# Pattern: [['TEXT:!']]
# Window size: 3
# Class: Negative
# Precision: 0.602
# Match: 575 (16.1%)
# Gain = 0.063
# Metric (global) = 0.063
# Examples ~ Class Negative:
# [MATCH]: Awesome question with a cute answer : Someone asked a boy " how is ur life ? " . . He smiled & amp ; answered : . . " She is fine !:['TEXT:!'] " Gudnite
# -------------------------
# [MATCH]: I thought i 'd get him a watch , just cos that s the kind of thing u get4an18th . And he loves so much !:['TEXT:!']
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: important information 4 orange user 0789xxxxxxx . today is your lucky day!2find out why log onto http://www.urawinner.com THERE 'S A FANTASTIC SURPRISE AWAITING YOU !:['TEXT:!']
# -------------------------
# [MATCH]: Congrats !:['TEXT:!'] 1 year special cinema pass for 2 is yours . call 09061209465 now ! C Suprman V , Matrix3 , StarWars3 , etc all 4 FREE ! bx420-ip4 - 5we . 150pm . Do nt miss out !
# -------------------------
# ==================================================
# Rank 34
# Pattern: [['TEXT:.'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.539
# Match: 297 (8.3%)
# Gain = 0.062
# Metric (global) = 0.062
# Examples ~ Class Positive:
# [MATCH]: Dear Subscriber ur draw 4 Â£100 gift voucher will b entered on receipt of a correct ans .:['TEXT:.'] When was Elvis:['SPACY:POS-PROPN'] Presleys Birthday ? TXT answer to 80062
# -------------------------
# [MATCH]: Get the official ENGLAND poly ringtone or colour flag on yer mobile for tonights game ! Text TONE or FLAG to 84199 .:['TEXT:.'] Optout:['SPACY:POS-PROPN'] txt ENG STOP Box39822 W111WX Â£1.50
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Not a lot has happened here . Feels very quiet .:['TEXT:.'] Beth:['SPACY:POS-PROPN'] is at her aunts and charlie is working lots . Just me and helen in at the mo . How have you been ?
# -------------------------
# [MATCH]: Good evening Sir , Al Salam Wahleykkum.sharing a happy news . By the grace of God , i got an offer from Tayseer , TISSCO and i joined . Hope you are fine .:['TEXT:.'] Inshah:['SPACY:POS-PROPN'] Allah , meet you sometime . Rakhesh , visitor from India .
# -------------------------
# ==================================================
# Rank 35
# Pattern: [['SPACY:POS-PROPN'], ['TEXT:.']]
# Window size: 4
# Class: Positive
# Precision: 0.522
# Match: 312 (8.7%)
# Gain = 0.061
# Metric (global) = 0.061
# Examples ~ Class Positive:
# [MATCH]: UpgrdCentre Orange customer , you may now claim your FREE CAMERA PHONE upgrade for your loyalty . Call now on 0207 153 9153 . Offer ends 26th July:['SPACY:POS-PROPN'] .:['TEXT:.'] T&C 's apply . Opt - out available
# -------------------------
# [MATCH]: Sunshine:['SPACY:POS-PROPN'] Hols .:['TEXT:.'] To claim ur med holiday send a stamped self address envelope to Drinks on Us UK , PO Box 113 , Bray , Wicklow , Eire . Quiz Starts Saturday ! Unsub Stop
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: You could have seen me .. i did't recognise you Face:['SPACY:POS-PROPN'] .:['TEXT:.'] : )
# -------------------------
# [MATCH]: No da if you run that it activate the full version da:['SPACY:POS-PROPN'] .:['TEXT:.']
# -------------------------
# ==================================================
# Rank 36
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 5
# Class: Positive
# Precision: 0.624
# Match: 213 (6.0%)
# Gain = 0.061
# Metric (global) = 0.061
# Examples ~ Class Positive:
# [MATCH]: We tried to contact you re your reply to our offer:['SPACY:POS-NOUN'] of a Video:['SPACY:POS-PROPN'] Phone:['SPACY:POS-PROPN'] 750 anytime any network mins Half Price Line Rental Camcorder Reply or call 08000930705
# -------------------------
# [MATCH]: You can donate Â£2.50:['SPACY:POS-NOUN'] to UNICEF:['SPACY:POS-PROPN'] 's Asian:['SPACY:POS-PROPN'] Tsunami disaster support fund by texting DONATE to 864233 . Â£2.50 will be added to your next bill
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: " YEH I AM DEF UP4 SOMETHING:['SPACY:POS-NOUN'] SAT:['SPACY:POS-PROPN'] , JUST GOT:['SPACY:POS-PROPN'] PAYED2DAY & I HAVBEEN GIVEN AÂ£50 PAY RISE 4MY WORK & HAVEBEEN MADE PRESCHOOLCO - ORDINATOR 2I AM FEELINGOOD LUV "
# -------------------------
# [MATCH]: Good FRIENDS CaRE for each Other .. CLoSE Friends UNDERSTaND each Other ... and TRUE Friends STaY forever beyond words , beyond time:['SPACY:POS-NOUN'] . Gud:['SPACY:POS-PROPN'] ni8:['SPACY:POS-PROPN']
# -------------------------
# ==================================================
# Rank 37
# Pattern: [['TEXT:mobile']]
# Window size: 3
# Class: Positive
# Precision: 0.942
# Match: 86 (2.4%)
# Gain = 0.060
# Metric (global) = 0.060
# Examples ~ Class Positive:
# [MATCH]: Had your mobile:['TEXT:mobile'] 11 months or more ? U R entitled to Update to the latest colour mobiles with camera for Free ! Call The Mobile Update Co FREE on 08002986030
# -------------------------
# [MATCH]: Had your mobile:['TEXT:mobile'] 10 mths ? Update to the latest Camera / Video phones for FREE . KEEP UR SAME NUMBER , Get extra free mins / texts . Text YES for a call
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Plz note : if anyone calling from a mobile:['TEXT:mobile'] Co. & amp ; asks u to type # & lt;#&gt ;   or # & lt;#&gt ; . Do not do so . Disconnect the call , coz it iz an attempt of ' terrorist ' to make use of the sim card no . Itz confirmd by nokia n motorola n has been verified by CNN IBN .
# -------------------------
# [MATCH]: Plz note : if anyone calling from a mobile:['TEXT:mobile'] Co. & amp ; asks u to type # & lt;#&gt ;   or # & lt;#&gt ; . Do not do so . Disconnect the call , coz it iz an attempt of ' terrorist ' to make use of the sim card no . Itz confirmd by nokia n motorola n has been verified by CNN IBN .
# -------------------------
# ==================================================
# Rank 38
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
# Window size: 5
# Class: Positive
# Precision: 0.591
# Match: 235 (6.6%)
# Gain = 0.060
# Metric (global) = 0.060
# Examples ~ Class Positive:
# [MATCH]: URGENT ! We are trying to contact U. Todays draw shows that you have won a Â£800 prize GUARANTEED . Call 09050003091 from land:['SPACY:POS-NOUN'] line:['SPACY:POS-NOUN'] . Claim:['SPACY:POS-PROPN'] C52 . Valid12hrs only
# -------------------------
# [MATCH]: Today 's Offer ! Claim ur Â£150 worth of discount vouchers ! Text YES to 85023 now ! SavaMob , member:['SPACY:POS-NOUN'] offers mobile:['SPACY:POS-NOUN'] ! T:['SPACY:POS-PROPN'] Cs 08717898035 . Â£3.00 Sub . 16 . Unsub reply X
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Tmr then Ã¼ brin lar ... Aiya later i come n c:['SPACY:POS-NOUN'] lar:['SPACY:POS-NOUN'] ... Mayb:['SPACY:POS-PROPN'] Ã¼ neva set properly Ã¼ got da help sheet wif Ã¼ ...
# -------------------------
# [MATCH]: " Si.como no?!listened2the plaid album - quite gd&the new air1 which is hilarious - also boughtÂ”braindanceÂ”a:['SPACY:POS-NOUN'] comp.ofstuff:['SPACY:POS-NOUN'] on aphexÂ:['SPACY:POS-PROPN'] ’s ; abel , u hav2hear it!c u sn xxxx "
# -------------------------
# ==================================================
# Rank 39
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]
# Window size: 5
# Class: Positive
# Precision: 0.739
# Match: 142 (4.0%)
# Gain = 0.058
# Metric (global) = 0.058
# Examples ~ Class Positive:
# [MATCH]: URGENT ! We are trying to contact U.:['SPACY:POS-PROPN'] Todays:['SPACY:POS-PROPN'] draw shows that:['SPACY:POS-ADP'] you have won a Â£800 prize GUARANTEED . Call 09050003091 from land line . Claim C52 . Valid12hrs only
# -------------------------
# [MATCH]: URGENT ! Your Mobile No . was awarded Â£2000 Bonus:['SPACY:POS-PROPN'] Caller:['SPACY:POS-PROPN'] Prize on:['SPACY:POS-ADP'] 5/9/03 This is our final try to contact U ! Call from Landline 09064019788 BOX42WR29C , 150PPM
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Eek that 's a lot of time especially since American:['SPACY:POS-PROPN'] Pie:['SPACY:POS-PROPN'] is like:['SPACY:POS-ADP'] 8 minutes long . I ca n't stop singing it .
# -------------------------
# [MATCH]: ALRITE SAM ITS NIC:['SPACY:POS-PROPN'] JUST CHECKIN:['SPACY:POS-PROPN'] THAT:['SPACY:POS-ADP'] THIS IS UR NUMBER - SO IS IT?T.B *
# -------------------------
# ==================================================
# Rank 40
# Pattern: [['SPACY:POS-ADJ'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Negative
# Precision: 0.530
# Match: 368 (10.3%)
# Gain = 0.057
# Metric (global) = 0.057
# Examples ~ Class Negative:
# [MATCH]: Its normally hot:['SPACY:POS-ADJ'] mail . Com:['SPACY:POS-PROPN'] you see !
# -------------------------
# [MATCH]: U need my presnts always bcz U ca nt mis love . " jeevithathile irulinae neekunna prakasamanu sneham " prakasam ennal prabha ' That mns prabha:['SPACY:POS-ADJ'] is'LOVE:['SPACY:POS-PROPN'] ' Got it . Do nt mis me ....
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: URGENT ! Your Mobile No . was awarded Â£2000:['SPACY:POS-ADJ'] Bonus:['SPACY:POS-PROPN'] Caller Prize on 5/9/03 This is our final try to contact U ! Call from Landline 09064019788 BOX42WR29C , 150PPM
# -------------------------
# [MATCH]: 87077 : Kick off a new season with 2wks FREE goals & news to ur mobile:['SPACY:POS-ADJ'] ! Txt:['SPACY:POS-PROPN'] ur club name to 87077 eg VILLA to 87077
# -------------------------
# ==================================================
# Rank 41
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-ADJ']]
# Window size: 4
# Class: Positive
# Precision: 0.559
# Match: 245 (6.9%)
# Gain = 0.055
# Metric (global) = 0.055
# Examples ~ Class Positive:
# [MATCH]: Your 2004 account for 07XXXXXXXXX:['SPACY:POS-NUM'] shows 786 unredeemed:['SPACY:POS-ADJ'] points . To claim call 08719181259 Identifier code : XXXXX Expires 26.03.05
# -------------------------
# [MATCH]: Hey Boys . Want hot XXX pics sent direct 2 ur phone ? Txt PORN to 69855:['SPACY:POS-NUM'] , 24Hrs free:['SPACY:POS-ADJ'] and then just 50p per day . To stop text STOPBCM SF WC1N3XX
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: My sister cleared two:['SPACY:POS-NUM'] round in birla:['SPACY:POS-ADJ'] soft yesterday .
# -------------------------
# [MATCH]: Sure thing big man . i have hockey elections at 6 , shouldnâ€˜t:['SPACY:POS-NUM'] go on longer:['SPACY:POS-ADJ'] than an hour though
# -------------------------
# ==================================================
# Rank 42
# Pattern: [['SENTIMENT:pos'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.542
# Match: 260 (7.3%)
# Gain = 0.054
# Metric (global) = 0.054
# Examples ~ Class Positive:
# ...
# -------------------------
# ==================================================
# Rank 87
# Pattern: [['TEXT:!'], ['SPACY:POS-NOUN']]
# Window size: 4
# Class: Positive
# Precision: 0.563
# Match: 183 (5.1%)
# Gain = 0.040
# Metric (global) = 0.040
# Examples ~ Class Positive:
# [MATCH]: Free msg : Single ? Find a partner in your area !:['TEXT:!'] 1000s:['SPACY:POS-NOUN'] of real people are waiting to chat now!Send CHAT to 62220Cncl send STOPCS 08717890890Â£1.50 per msg
# -------------------------
# [MATCH]: URGENT ! Your mobile No 077xxx WON a Â£2,000 Bonus Caller Prize on 02/06/03 ! This is the 2nd attempt to reach YOU ! Call 09066362206 ASAP !:['TEXT:!'] BOX97N7QP:['SPACY:POS-NOUN'] , 150ppm
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Hello !:['TEXT:!'] Good week:['SPACY:POS-NOUN'] ? Fancy a drink or something later ?
# -------------------------
# [MATCH]: I like cheap !:['TEXT:!'] But iâ€˜m:['SPACY:POS-NOUN'] happy to splash out on the wine if it makes you feel better ..
# -------------------------
# ==================================================
# Rank 88
# Pattern: [['SPACY:POS-DET'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 5
# Class: Positive
# Precision: 0.709
# Match: 110 (3.1%)
# Gain = 0.040
# Metric (global) = 0.040
# Examples ~ Class Positive:
# [MATCH]: * * FREE MESSAGE**Thanks for using the:['SPACY:POS-DET'] Auction:['SPACY:POS-PROPN'] Subscription:['SPACY:POS-PROPN'] Service . 18 . 150p / MSGRCVD 2 Skip an Auction txt OUT . 2 Unsubscribe txt STOP CustomerCare 08718726270
# -------------------------
# [MATCH]: Win the newest â€œHarry Potter and the Order of the:['SPACY:POS-DET'] Phoenix:['SPACY:POS-PROPN'] ( Book:['SPACY:POS-PROPN'] 5 ) reply HARRY , answer 5 questions - chance to be the first among readers !
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Hello beautiful r u ok ? I 've kinda ad a row wiv and he walked out the pub ? ? I wanted a:['SPACY:POS-DET'] night wiv u:['SPACY:POS-PROPN'] Miss:['SPACY:POS-PROPN'] u
# -------------------------
# [MATCH]: " NOT ENUFCREDEIT TOCALL.SHALL ILEAVE UNI AT 6 + GET A:['SPACY:POS-DET'] BUS TO YOR:['SPACY:POS-PROPN'] HOUSE:['SPACY:POS-PROPN'] ? "
# -------------------------
# ==================================================
# Rank 89
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['TEXT:.']]
# Window size: 5
# Class: Positive
# Precision: 0.678
# Match: 121 (3.4%)
# Gain = 0.040
# Metric (global) = 0.040
# Examples ~ Class Positive:
# [MATCH]: PRIVATE ! Your 2003 Account Statement for shows 800 un - redeemed S.:['SPACY:POS-PROPN'] I.:['SPACY:POS-PROPN'] M. points .:['TEXT:.'] Call 08719899230 Identifier Code : 41685 Expires 07/11/04
# -------------------------
# [MATCH]: Uâ€ ™ ve Bin Awarded Â£50 to Play 4 Instant:['SPACY:POS-PROPN'] Cash:['SPACY:POS-PROPN'] .:['TEXT:.'] Call 08715203028 To Claim . EVERY 9th Player Wins Min Â£50-Â£500 . OptOut 08718727870
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: excellent . I spent   & lt;#&gt ;   years in the Air:['SPACY:POS-PROPN'] Force:['SPACY:POS-PROPN'] .:['TEXT:.'] Iraq and afghanistan . I am stable and honest . do you like traveling ?
# -------------------------
# [MATCH]: " BOO BABE ! U ENJOYIN YOURJOB ? U SEEMED 2 B GETTIN ON WELL HUNNY!HOPE URE OK?TAKE CARE & IÂ’LLSPEAK 2U SOONLOTS OF LOVEME:['SPACY:POS-PROPN'] XXXX:['SPACY:POS-PROPN'] .:['TEXT:.'] "
# -------------------------
# ==================================================
# Rank 90
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
# Window size: 6
# Class: Positive
# Precision: 0.713
# Match: 108 (3.0%)
# Gain = 0.040
# Metric (global) = 0.040
# Examples ~ Class Positive:
# [MATCH]: UR awarded a City Break and could WIN a Â£200:['SPACY:POS-PROPN'] Summer:['SPACY:POS-PROPN'] Shopping:['SPACY:POS-PROPN'] spree:['SPACY:POS-NOUN'] every WK . Txt STORE to 88039.SkilGme . TsCs087147403231Winawk!Age16+Â£1.50perWKsub
# -------------------------
# [MATCH]: Get the official ENGLAND poly ringtone or colour flag on yer mobile for tonights game ! Text TONE or FLAG to 84199 . Optout:['SPACY:POS-PROPN'] txt ENG:['SPACY:POS-PROPN'] STOP:['SPACY:POS-PROPN'] Box39822 W111WX:['SPACY:POS-NOUN'] Â£1.50
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Today is ACCEPT DAY .. U Accept me as ? Brother Sister Lover Dear1 Best1 Clos1 Lvblefrnd Jstfrnd Cutefrnd Lifpartnr:['SPACY:POS-PROPN'] Belovd:['SPACY:POS-PROPN'] Swtheart:['SPACY:POS-PROPN'] Bstfrnd No rply:['SPACY:POS-NOUN'] means enemy
# -------------------------
# [MATCH]: " CHEERS FOR CALLIN BABE.SOZI CULDNT TALKBUT I WANNATELL U DETAILS LATER WENWECAN:['SPACY:POS-PROPN'] CHAT:['SPACY:POS-PROPN'] PROPERLY:['SPACY:POS-PROPN'] X:['SPACY:POS-NOUN'] "
# -------------------------
# ==================================================
# Rank 91
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['TEXT:.']]
# Window size: 5
# Class: Positive
# Precision: 0.621
# Match: 145 (4.1%)
# Gain = 0.039
# Metric (global) = 0.039
# Examples ~ Class Positive:
# [MATCH]: Congrats ! 2 mobile 3 G Videophones:['SPACY:POS-PROPN'] R:['SPACY:POS-NOUN'] yours .:['TEXT:.'] call 09063458130 now ! videochat wid your mates , play java games , Dload polyPH music , noline rentl .
# -------------------------
# [MATCH]: URGENT ! Your Mobile number has been awarded a < UKP>2000:['SPACY:POS-PROPN'] prize:['SPACY:POS-NOUN'] GUARANTEED .:['TEXT:.'] Call 09061790125 from landline . Claim 3030 . Valid 12hrs only 150ppm
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Please protect yourself from e - threats . SIB never asks for sensitive information like Passwords , ATM / SMS:['SPACY:POS-PROPN'] PIN:['SPACY:POS-NOUN'] thru email .:['TEXT:.'] Never share your password with anybody .
# -------------------------
# [MATCH]: Host - based IDPS:['SPACY:POS-PROPN'] for linux:['SPACY:POS-NOUN'] systems .:['TEXT:.']
# -------------------------
# ==================================================
# Rank 92
# Pattern: [['SENTIMENT:pos'], ['TEXT:call']]
# Window size: 4
# Class: Positive
# Precision: 0.838
# Match: 74 (2.1%)
# Gain = 0.039
# Metric (global) = 0.039
# Examples ~ Class Positive:
# [MATCH]: YOU ARE CHOSEN TO RECEIVE A Â£350 AWARD:['SENTIMENT:pos'] ! Pls call:['TEXT:call'] claim number 09066364311 to collect your award which you are selected to receive as a valued mobile customer .
# -------------------------
# [MATCH]: 5 Free Top:['SENTIMENT:pos'] Polyphonic Tones call:['TEXT:call'] 087018728737 , National Rate . Get a toppoly tune sent every week , just text SUBPOLY to 81618 , Â£3 per pole . UnSub 08718727870 .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Once free:['SENTIMENT:pos'] call:['TEXT:call'] me sir . I am waiting for you .
# -------------------------
# [MATCH]: Sir , i am waiting for your call , once free:['SENTIMENT:pos'] please call:['TEXT:call'] me .
# -------------------------
# ==================================================
# Rank 93
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.868
# Match: 68 (1.9%)
# Gain = 0.038
# Metric (global) = 0.038
# Examples ~ Class Positive:
# [MATCH]: This is the 2nd time we have tried 2 contact u. U have won the 750:['SPACY:POS-NUM'] Pound:['SPACY:POS-PROPN'] prize . 2:['SPACY:POS-NUM'] claim is easy , call 08712101358 NOW ! Only 10p per min . BT - national - rate
# -------------------------
# [MATCH]: FREE > Ringtone ! Reply REAL or POLY eg REAL1 1:['SPACY:POS-NUM'] . PushButton:['SPACY:POS-PROPN'] 2:['SPACY:POS-NUM'] . DontCha 3 . BabyGoodbye 4 . GoldDigger 5 . WeBeBurnin 1st tone FREE and 6 more when u join for Â£3/wk
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Your opinion about me ? 1 . Over 2:['SPACY:POS-NUM'] . Jada:['SPACY:POS-PROPN'] 3:['SPACY:POS-NUM'] . Kusruthi 4 . Lovable 5 . Silent 6 . Spl character 7 . Not matured 8 . Stylish 9 . Simple Pls reply ..
# -------------------------
# [MATCH]: Your opinion about me ? 1 . Over 2:['SPACY:POS-NUM'] . Jada:['SPACY:POS-PROPN'] 3:['SPACY:POS-NUM'] . Kusruthi 4 . Lovable 5 . Silent 6 . Spl character 7 . Not matured 8 . Stylish 9 . Simple Pls reply ..
# -------------------------
# ==================================================
# Rank 94
# Pattern: [['HYPERNYM3:symbol.n.01']]
# Window size: 3
# Class: Positive
# Precision: 0.764
# Match: 89 (2.5%)
# Gain = 0.038
# Metric (global) = 0.038
# Examples ~ Class Positive:
# [MATCH]: URGENT ! Your mobile number * * * * * * * * * * * * * * * WON a Â£2000 Bonus Caller prize:['HYPERNYM3:symbol.n.01'] on 10/06/03 ! This is the 2nd attempt to reach you ! Call 09066368753 ASAP ! Box 97N7QP , 150ppm
# -------------------------
# [MATCH]: Please call our customer service representative on FREEPHONE 0808 145 4742 between 9am-11pm as you have WON a guaranteed Â£1000 cash or Â£5000 prize:['HYPERNYM3:symbol.n.01'] !
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Lol or I could just starve and lose a pound:['HYPERNYM3:symbol.n.01'] by the end of the day .
# -------------------------
# [MATCH]: ARR birthday today : ) i wish him to get more oscar:['HYPERNYM3:symbol.n.01'] .
# -------------------------
# ==================================================
# Rank 95
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
# Window size: 5
# Class: Positive
# Precision: 0.543
# Match: 184 (5.2%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: Marvel Mobile Play the official Ultimate Spider - man game ( Â£4.50 ) on ur mobile right now . Text SPIDER to:['SPACY:POS-ADP'] 83338:['SPACY:POS-NUM'] for the game:['SPACY:POS-NOUN'] & we ll send u a FREE 8Ball wallpaper
# -------------------------
# [MATCH]: UR awarded a City Break and could WIN a Â£200 Summer Shopping spree every WK . Txt STORE to:['SPACY:POS-ADP'] 88039.SkilGme:['SPACY:POS-NUM'] . TsCs087147403231Winawk!Age16+Â£1.50perWKsub:['SPACY:POS-NOUN']
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I 'm now but have to wait till:['SPACY:POS-ADP'] 2:['SPACY:POS-NUM'] for the bus:['SPACY:POS-NOUN'] to pick me .
# -------------------------
# [MATCH]: " I;m reaching in:['SPACY:POS-ADP'] another 2:['SPACY:POS-NUM'] stops:['SPACY:POS-NOUN'] . "
# -------------------------
# ==================================================
# Rank 96
# Pattern: [['TEXT:!'], ['SPACY:POS-ADJ']]
# Window size: 4
# Class: Positive
# Precision: 0.648
# Match: 125 (3.5%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: WIN : We have a winner ! Mr. T. Foley won an iPod !:['TEXT:!'] More exciting:['SPACY:POS-ADJ'] prizes soon , so keep an eye on ur mobile or visit www.win-82050.co.uk
# -------------------------
# [MATCH]: URGENT !:['TEXT:!'] : Your:['SPACY:POS-ADJ'] Mobile No . was awarded a Â£2,000 Bonus Caller Prize on 02/09/03 ! This is our 2nd attempt to contact YOU ! Call 0871 - 872 - 9755 BOX95QU
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: That s cool !:['TEXT:!'] Sometimes slow:['SPACY:POS-ADJ'] and gentle . Sonetimes rough and hard :)
# -------------------------
# [MATCH]: Good morning princess !:['TEXT:!'] Have a great:['SPACY:POS-ADJ'] day !
# -------------------------
# ==================================================
# Rank 97
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
# Window size: 6
# Class: Positive
# Precision: 0.914
# Match: 58 (1.6%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: FREE for 1st week ! No1:['SPACY:POS-PROPN'] Nokia:['SPACY:POS-PROPN'] tone:['SPACY:POS-NOUN'] 4:['SPACY:POS-NUM'] ur mob every week just txt NOKIA to 8007 Get txting and tell ur mates www.getzed.co.uk POBox 36504 W45WQ norm150p / tone 16 +
# -------------------------
# [MATCH]: PRIVATE ! Your 2003 Account Statement for < fone no > shows 800 un - redeemed S. I.:['SPACY:POS-PROPN'] M.:['SPACY:POS-PROPN'] points:['SPACY:POS-NOUN'] . Call 08715203656:['SPACY:POS-NUM'] Identifier Code : 42049 Expires 26/10/04
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Juz:['SPACY:POS-PROPN'] go google:['SPACY:POS-PROPN'] n search:['SPACY:POS-NOUN'] 4:['SPACY:POS-NUM'] qet ...
# -------------------------
# [MATCH]: HIYA:['SPACY:POS-PROPN'] STU:['SPACY:POS-PROPN'] WOT:['SPACY:POS-NOUN'] U UP 2.IM:['SPACY:POS-NUM'] IN SO MUCH TRUBLE AT HOME AT MOMENT EVONE HATES ME EVEN U ! WOT THE HELL AV I DONE NOW ? Y WONT U JUST TELL ME TEXT BCK PLEASE LUV DAN
# -------------------------
# ==================================================
# Rank 98
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-DET']]
# Window size: 4
# Class: Positive
# Precision: 0.634
# Match: 131 (3.7%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: HOT LIVE FANTASIES call now 08707509020 Just 20p per min NTT Ltd , PO Box 1327 Croydon CR9 5WB:['SPACY:POS-NUM'] 0870 is a:['SPACY:POS-DET'] national rate call
# -------------------------
# [MATCH]: FREE RING TONE just text " POLYS " to 87131:['SPACY:POS-NUM'] . Then every:['SPACY:POS-DET'] week get a new tone . 0870737910216yrs only Â£1.50/wk .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Oh , i will get paid . The most outstanding one:['SPACY:POS-NUM'] is for a:['SPACY:POS-DET'] commercial i did for Hasbro ... in AUGUST ! They made us jump through so many hoops to get paid . Still not .
# -------------------------
# [MATCH]: Hey next sun 1030:['SPACY:POS-NUM'] there 's a:['SPACY:POS-DET'] basic yoga course ... at bugis ... We can go for that ... Pilates intro next sat .... Tell me what time you r free
# -------------------------
# ==================================================
# Rank 99
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['TEXT:to']]
# Window size: 5
# Class: Positive
# Precision: 0.565
# Match: 168 (4.7%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: U can WIN Â£100 of Music Gift Vouchers every week starting NOW Txt the word:['SPACY:POS-NOUN'] DRAW:['SPACY:POS-NOUN'] to:['TEXT:to'] 87066 TsCs www.ldew.com SkillGame,1Winaweek , age16.150ppermessSubscription
# -------------------------
# [MATCH]: Sunshine Hols . To claim ur med holiday send a stamped self:['SPACY:POS-NOUN'] address:['SPACY:POS-NOUN'] envelope to:['TEXT:to'] Drinks on Us UK , PO Box 113 , Bray , Wicklow , Eire . Quiz Starts Saturday ! Unsub Stop
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Sorry da . I gone mad so many pending works:['SPACY:POS-NOUN'] what:['SPACY:POS-NOUN'] to:['TEXT:to'] do .
# -------------------------
# [MATCH]: How many times i told in the stage:['SPACY:POS-NOUN'] all use:['SPACY:POS-NOUN'] to:['TEXT:to'] laugh . You not listen aha .
# -------------------------
# ==================================================
# Rank 100
# Pattern: [['SENTIMENT:pos'], ['SPACY:POS-DET'], ['SPACY:POS-PROPN']]
# Window size: 5
# Class: Positive
# Precision: 0.797
# Match: 79 (2.2%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: Sunshine Quiz Wkly Q ! Win:['SENTIMENT:pos'] a:['SPACY:POS-DET'] top Sony:['SPACY:POS-PROPN'] DVD player if u know which country Liverpool played in mid week ? Txt ansr to 82277 . Â£1.50 SP : Tyrone
# -------------------------
# [MATCH]: You 've won:['SENTIMENT:pos'] tkts to the:['SPACY:POS-DET'] EURO2004:['SPACY:POS-PROPN'] CUP FINAL or Â£800 CASH , to collect CALL 09058099801 b4190604 , POBOX 7876150ppm
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I taught that Ranjith sir called me . So only i sms like:['SENTIMENT:pos'] that:['SPACY:POS-DET'] . Becaus:['SPACY:POS-PROPN'] he s verifying about project . Prabu told today so only pa do nt mistake me ..
# -------------------------
# [MATCH]: Smile in Pleasure Smile in Pain Smile when trouble pours like Rain Smile:['SENTIMENT:pos'] when sum1:['SPACY:POS-DET'] Hurts:['SPACY:POS-PROPN'] U Smile becoz SOMEONE still Loves to see u Smiling ! !
# -------------------------
# ==================================================

# %%
print(f'  #    class Cov(%)    Prec  Gain    Pattern')
for idx, p in enumerate(the_patterns):
    print(f'{idx+1:>3} {p.support_class}   {round(p.coverage*100, 1):>4}   {p.precision:.3f}   {p.metric:.3f}    {p.get_pattern_id()}')
# Out:
#   #    class Cov(%)    Prec  Gain    Pattern
#   1 Negative   26.2   0.526   0.223    [['SPACY:POS-NUM']]
#   2 Positive    8.9   0.806   0.175    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#   3 Positive    5.1   0.984   0.152    [['TEXT:call'], ['SPACY:POS-NUM']]
#   4 Positive   14.5   0.579   0.148    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#   5 Positive   11.8   0.613   0.129    [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
#   6 Positive    6.8   0.811   0.129    [['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
#   7 Negative   18.1   0.526   0.119    [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
#   8 Positive    5.4   0.856   0.114    [['TEXT:to'], ['SPACY:POS-NUM']]
#   9 Negative   37.8   0.690   0.112    [['SPACY:POS-PROPN']]
#  10 Positive    7.6   0.702   0.105    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  11 Positive    7.1   0.722   0.104    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  12 Positive    5.7   0.797   0.101    [['TEXT:.'], ['SPACY:POS-NUM']]
#  13 Positive    6.7   0.735   0.100    [['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
#  14 Negative   20.0   0.585   0.095    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  15 Positive    8.8   0.597   0.085    [['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
#  16 Positive    7.2   0.655   0.084    [['SPACY:POS-ADJ'], ['SPACY:POS-NUM']]
#  17 Positive    7.3   0.649   0.083    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  18 Positive    3.4   0.926   0.082    [['SPACY:POS-PROPN'], ['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
#  19 Positive   11.8   0.504   0.080    [['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]
#  20 Positive    8.0   0.591   0.074    [['SPACY:POS-NUM'], ['TEXT:.']]
#  21 Positive   10.1   0.525   0.073    [['SPACY:POS-NUM'], ['SPACY:POS-VERB']]
#  22 Positive    4.3   0.791   0.073    [['SPACY:POS-NOUN'], ['TEXT:call']]
#  23 Positive    3.6   0.843   0.069    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  24 Negative   15.6   0.585   0.068    [['SPACY:POS-VERB'], ['SPACY:POS-PROPN']]
#  25 Negative   37.2   0.983   0.067    [['TEXT:i']]
#  26 Positive    4.4   0.756   0.067    [['SPACY:POS-SYM']]
#  27 Positive    4.5   0.748   0.067    [['TEXT:free']]
#  28 Positive    2.7   0.938   0.067    [['TEXT:txt']]
#  29 Positive    7.2   0.591   0.066    [['SPACY:POS-VERB', 'TEXT:call']]
#  30 Negative   15.5   0.591   0.065    [['SPACY:POS-NOUN'], ['TEXT:to']]
#  31 Positive    2.2   1.000   0.064    [['TEXT:claim']]
#  32 Positive    7.0   0.592   0.064    [['SPACY:POS-NOUN'], ['SPACY:POS-ADP', 'TEXT:to']]
#  33 Negative   16.1   0.602   0.063    [['TEXT:!']]
#  34 Positive    8.3   0.539   0.062    [['TEXT:.'], ['SPACY:POS-PROPN']]
#  35 Positive    8.7   0.522   0.061    [['SPACY:POS-PROPN'], ['TEXT:.']]
#  36 Positive    6.0   0.624   0.061    [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  37 Positive    2.4   0.942   0.060    [['TEXT:mobile']]
#  38 Positive    6.6   0.591   0.060    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
#  39 Positive    4.0   0.739   0.058    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]
#  40 Negative   10.3   0.530   0.057    [['SPACY:POS-ADJ'], ['SPACY:POS-PROPN']]
#  41 Positive    6.9   0.559   0.055    [['SPACY:POS-NUM'], ['SPACY:POS-ADJ']]
#  42 Positive    7.3   0.542   0.054    [['SENTIMENT:pos'], ['SPACY:POS-PROPN']]
#  43 Positive    3.1   0.802   0.053    [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  44 Positive    5.3   0.621   0.053    [['SPACY:POS-VERB'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  45 Positive    1.9   0.985   0.053    [['TEXT:.'], ['TEXT:call'], ['SPACY:POS-NUM']]
#  46 Positive    2.2   0.923   0.052    [['HYPERNYM3:communication.n.02'], ['SPACY:POS-NUM']]
#  47 Positive    2.2   0.922   0.051    [['HYPERNYM3:win.v.01', 'SENTIMENT:pos']]
#  48 Negative   13.6   0.601   0.051    [['SPACY:POS-ADP', 'TEXT:to']]
#  49 Positive    2.0   0.957   0.051    [['TEXT:call'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
#  50 Positive    3.1   0.784   0.051    [['TEXT:.'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  51 Positive    7.5   0.521   0.051    [['SPACY:POS-DET'], ['SPACY:POS-PROPN']]
#  52 Positive    3.8   0.716   0.050    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
#  53 Positive    6.0   0.575   0.050    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-VERB']]
#  54 Negative   10.6   0.559   0.050    [['SPACY:POS-ADP'], ['SPACY:POS-PROPN']]
#  55 Positive    4.0   0.690   0.049    [['SPACY:POS-PROPN'], ['TEXT:to']]
#  56 Positive    2.2   0.909   0.049    [['HYPERNYM3:cost.n.01']]
#  57 Negative   65.0   0.804   0.049    [['SPACY:POS-ADP']]
#  58 Positive    2.2   0.899   0.049    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  59 Negative   54.1   0.785   0.049    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN']]
#  60 Negative   12.1   0.586   0.049    [['HYPERNYM3:message.n.02']]
#  61 Positive    5.1   0.613   0.049    [['SPACY:POS-NOUN'], ['HYPERNYM3:message.n.02']]
#  62 Negative   30.8   0.725   0.048    [['TEXT:to']]
#  63 Positive    2.5   0.843   0.048    [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  64 Positive    2.4   0.851   0.047    [['TEXT:!'], ['SPACY:POS-NUM']]
#  65 Positive    1.6   1.000   0.046    [['TEXT:prize']]
#  66 Positive    2.2   0.873   0.046    [['HYPERNYM3:message.n.02'], ['SPACY:POS-NUM']]
#  67 Negative    8.6   0.533   0.045    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NOUN']]
#  68 Negative   10.8   0.580   0.044    [['HYPERNYM3:communication.n.02']]
#  69 Positive    1.6   0.982   0.044    [['HYPERNYM3:call.v.28'], ['SPACY:POS-NUM']]
#  70 Positive    2.0   0.890   0.044    [['SPACY:POS-PROPN'], ['TEXT:call']]
#  71 Positive    2.9   0.765   0.044    [['TEXT:call'], ['SPACY:POS-ADP']]
#  72 Positive    2.4   0.816   0.043    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
#  73 Negative   15.9   0.649   0.043    [['TEXT:.'], ['SPACY:POS-NOUN']]
#  74 Negative   39.6   0.759   0.043    [['SPACY:POS-NOUN'], ['SPACY:POS-ADP']]
#  75 Positive    1.5   0.982   0.043    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['TEXT:to'], ['SPACY:POS-NUM']]
#  76 Positive    4.8   0.594   0.042    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-ADP']]
#  77 Negative   39.9   0.761   0.042    [['SENTIMENT:pos']]
#  78 Positive    2.2   0.838   0.042    [['SPACY:POS-ADP'], ['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
#  79 Positive    1.9   0.909   0.042    [['TEXT:to'], ['SPACY:POS-NUM'], ['TEXT:.']]
#  80 Positive    4.0   0.639   0.042    [['SPACY:POS-ADJ'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  81 Positive    1.7   0.934   0.041    [['SPACY:POS-NUM'], ['TEXT:now']]
#  82 Positive    2.5   0.789   0.041    [['TEXT:.'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  83 Positive    3.5   0.675   0.041    [['SENTIMENT:pos'], ['SPACY:POS-NUM']]
#  84 Positive    3.6   0.667   0.041    [['TEXT:!'], ['SPACY:POS-PROPN']]
#  85 Positive    1.9   0.884   0.041    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
#  86 Positive    2.2   0.833   0.040    [['SPACY:POS-PROPN'], ['TEXT:.'], ['SPACY:POS-NUM']]
#  87 Positive    5.1   0.563   0.040    [['TEXT:!'], ['SPACY:POS-NOUN']]
#  88 Positive    3.1   0.709   0.040    [['SPACY:POS-DET'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  89 Positive    3.4   0.678   0.040    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['TEXT:.']]
#  90 Positive    3.0   0.713   0.040    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  91 Positive    4.1   0.621   0.039    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['TEXT:.']]
#  92 Positive    2.1   0.838   0.039    [['SENTIMENT:pos'], ['TEXT:call']]
#  93 Positive    1.9   0.868   0.038    [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  94 Positive    2.5   0.764   0.038    [['HYPERNYM3:symbol.n.01']]
#  95 Positive    5.2   0.543   0.037    [['SPACY:POS-ADP'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
#  96 Positive    3.5   0.648   0.037    [['TEXT:!'], ['SPACY:POS-ADJ']]
#  97 Positive    1.6   0.914   0.037    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  98 Positive    3.7   0.634   0.037    [['SPACY:POS-NUM'], ['SPACY:POS-DET']]
#  99 Positive    4.7   0.565   0.037    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['TEXT:to']]
# 100 Positive    2.2   0.797   0.037    [['SENTIMENT:pos'], ['SPACY:POS-DET'], ['SPACY:POS-PROPN']]

# %% [markdown]
# ## Post-process the patterns

# %%
# Select only patterns of which precision is greater than 0.70
selected_patterns = [p for p in the_patterns if p.precision >= 0.70]
print(f'No. of remaining patterns = {len(selected_patterns)}')
# Out:
# No. of remaining patterns = 54

# %%
# For every pair of patterns (p1, p2), remove pattern p2 if there exists p1 in the patterns set such that p2 is a specialization of p1 and metric of p2 is lower than p1
selected_patterns = remove_specialized_patterns(selected_patterns, metric = lambda x: x.precision)
print(f'No. of remaining patterns = {len(selected_patterns)}')
# Out:
# No. of remaining patterns = 44

# %%
# Print the remaining patterns sorted by precision
selected_patterns = sorted(selected_patterns, key = lambda x: x.precision, reverse = True)
print(f'  #    class Cov(%)    Prec  Gain    Pattern')
for idx, p in enumerate(selected_patterns):
    print(f'{idx+1:>3} {p.support_class}   {round(p.coverage*100, 1):>4}   {p.precision:.3f}   {p.metric:.3f}    {p.get_pattern_id()}')
# Out:
#   #    class Cov(%)    Prec  Gain    Pattern
#   1 Positive    2.2   1.000   0.064    [['TEXT:claim']]
#   2 Positive    1.6   1.000   0.046    [['TEXT:prize']]
#   3 Positive    1.9   0.985   0.053    [['TEXT:.'], ['TEXT:call'], ['SPACY:POS-NUM']]
#   4 Positive    5.1   0.984   0.152    [['TEXT:call'], ['SPACY:POS-NUM']]
#   5 Negative   37.2   0.983   0.067    [['TEXT:i']]
#   6 Positive    1.5   0.982   0.043    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['TEXT:to'], ['SPACY:POS-NUM']]
#   7 Positive    2.4   0.942   0.060    [['TEXT:mobile']]
#   8 Positive    2.7   0.938   0.067    [['TEXT:txt']]
#   9 Positive    1.7   0.934   0.041    [['SPACY:POS-NUM'], ['TEXT:now']]
#  10 Positive    3.4   0.926   0.082    [['SPACY:POS-PROPN'], ['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
#  11 Positive    2.2   0.923   0.052    [['HYPERNYM3:communication.n.02'], ['SPACY:POS-NUM']]
#  12 Positive    2.2   0.922   0.051    [['HYPERNYM3:win.v.01', 'SENTIMENT:pos']]
#  13 Positive    1.6   0.914   0.037    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  14 Positive    2.2   0.909   0.049    [['HYPERNYM3:cost.n.01']]
#  15 Positive    1.9   0.909   0.042    [['TEXT:to'], ['SPACY:POS-NUM'], ['TEXT:.']]
#  16 Positive    2.2   0.899   0.049    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  17 Positive    2.0   0.890   0.044    [['SPACY:POS-PROPN'], ['TEXT:call']]
#  18 Positive    1.9   0.884   0.041    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
#  19 Positive    2.2   0.873   0.046    [['HYPERNYM3:message.n.02'], ['SPACY:POS-NUM']]
#  20 Positive    1.9   0.868   0.038    [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  21 Positive    5.4   0.856   0.114    [['TEXT:to'], ['SPACY:POS-NUM']]
#  22 Positive    2.4   0.851   0.047    [['TEXT:!'], ['SPACY:POS-NUM']]
#  23 Positive    2.5   0.843   0.048    [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  24 Positive    3.6   0.843   0.069    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  25 Positive    2.1   0.838   0.039    [['SENTIMENT:pos'], ['TEXT:call']]
#  26 Positive    2.2   0.838   0.042    [['SPACY:POS-ADP'], ['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
#  27 Positive    2.2   0.833   0.040    [['SPACY:POS-PROPN'], ['TEXT:.'], ['SPACY:POS-NUM']]
#  28 Positive    2.4   0.816   0.043    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
#  29 Positive    6.8   0.811   0.129    [['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
#  30 Positive    8.9   0.806   0.175    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  31 Negative   65.0   0.804   0.049    [['SPACY:POS-ADP']]
#  32 Positive    2.2   0.797   0.037    [['SENTIMENT:pos'], ['SPACY:POS-DET'], ['SPACY:POS-PROPN']]
#  33 Positive    5.7   0.797   0.101    [['TEXT:.'], ['SPACY:POS-NUM']]
#  34 Positive    4.3   0.791   0.073    [['SPACY:POS-NOUN'], ['TEXT:call']]
#  35 Positive    2.5   0.789   0.041    [['TEXT:.'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  36 Negative   54.1   0.785   0.049    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN']]
#  37 Positive    3.1   0.784   0.051    [['TEXT:.'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  38 Positive    2.5   0.764   0.038    [['HYPERNYM3:symbol.n.01']]
#  39 Negative   39.9   0.761   0.042    [['SENTIMENT:pos']]
#  40 Positive    4.4   0.756   0.067    [['SPACY:POS-SYM']]
#  41 Positive    6.7   0.735   0.100    [['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
#  42 Negative   30.8   0.725   0.048    [['TEXT:to']]
#  43 Positive    7.1   0.722   0.104    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  44 Positive    3.1   0.709   0.040    [['SPACY:POS-DET'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]

# %% [markdown]
# ## Save the patterns to a json file
# We can use this json file as an input of the web demo tool for exploring the learned patterns and the training data

# %%
grasp_model.to_json('case_study_1.json', patterns = selected_patterns, comment = 'Rank and group patterns based on precision. The minimum precision was set at 0.70')
# Out:
# 100%|██████████| 44/44 [00:00<00:00, 298.09it/s]
# 100%|██████████| 44/44 [00:00<00:00, 261.05it/s]
# Successfully dump the results to case_study_1.json
