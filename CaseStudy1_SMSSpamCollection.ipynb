# %%
# %load_ext autoreload
# %autoreload 2

# %%
import grasp
from grasp import GrASP, CustomAttribute, remove_specialized_patterns
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Load the data
# - Download and unzip the spam dataset **if you have not done this before**

# %%
import urllib.request
url = 'http://www.dt.fee.unicamp.br/~tiago/smsspamcollection/smsspamcollection.zip'
filename = './data/smsspamcollection.zip'
urllib.request.urlretrieve(url, filename)

# %%
# !unzip ./data/smsspamcollection.zip -d ./data

# %% [markdown]
# - Load the data

# %%
def get_data():
    f = open('data/SMSSpamCollection.txt', 'r')
    texts, labels = [], []
    for line in f:
        line = line.strip()
        tab_idx = line.index('\t')
        label = line[:tab_idx]
        text = line[tab_idx+1:]
        if label == 'ham':
            label = 0
        elif label == 'spam':
            label = 1
        else:
            raise Exception(f"Invalid label - {label}")
        texts.append(text)
        labels.append(label)
    return texts, labels

# %%
texts, labels = get_data()
X_train, X_test, y_train, y_test = train_test_split(texts, labels, test_size=0.2, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1)
# len(texts), sum(labels), len(X_test), sum(y_test)

# %%
positive = [t for idx, t in enumerate(X_train) if y_train[idx]]
negative = [t for idx, t in enumerate(X_train) if not y_train[idx]]
print(f'Positive examples = {len(positive)}\nNegative examples = {len(negative)}')
# Out:
# Positive examples = 488
# Negative examples = 3079

# %% [markdown]
# ## Run GrASP

# %%
# Create the GrASP engine
grasp_model = GrASP(gaps_allowed = 2, num_patterns = 100, include_standard = ['TEXT', 'POS', 'HYPERNYM', 'SENTIMENT'],
                    correlation_threshold = 0.5, alphabet_size = 200)

# %%
# Fit GrASP to the dataset
the_patterns = grasp_model.fit_transform(positive, negative)
# Out:
#   0%|          | 0/488 [00:00<?, ?it/s]
# Step 1: Create augmented texts
# 100%|██████████| 488/488 [00:20<00:00, 24.28it/s]
# 100%|██████████| 3079/3079 [01:22<00:00, 37.18it/s]
# Step 2: Find frequent attributes
#   1%|          | 8/1215 [00:00<00:16, 73.56it/s]
# Total number of candidate alphabet = 1215, such as ['SPACY:POS-VERB', 'SPACY:POS-NOUN', 'SPACY:POS-PUNCT', 'SPACY:POS-PRON', 'SPACY:POS-ADV']
# Step 3: Find alphabet set
# 100%|██████████| 1215/1215 [00:26<00:00, 45.70it/s]
# Finding top k: 20 / 200
# Finding top k: 40 / 200
# Finding top k: 60 / 200
# Finding top k: 80 / 200
# Finding top k: 100 / 200
# Finding top k: 120 / 200
# Finding top k: 140 / 200
# Finding top k: 160 / 200
# Finding top k: 180 / 200
# Finding top k: 200 / 200
#   0%|          | 0/200 [00:00<?, ?it/s]
# Total number of alphabet = 200
# ['SPACY:POS-NUM', 'SPACY:POS-PROPN', 'TEXT:call', 'TEXT:i', 'SPACY:POS-SYM', 'TEXT:free', 'TEXT:txt', 'TEXT:claim', 'TEXT:!', 'TEXT:mobile', 'HYPERNYM3:cost.n.01', 'SPACY:POS-ADP', 'HYPERNYM3:message.n.02', 'TEXT:to', 'TEXT:prize', 'HYPERNYM3:communication.n.02', 'HYPERNYM3:win.v.01', 'SENTIMENT:pos', 'HYPERNYM3:symbol.n.01', 'HYPERNYM3:statement.n.01', 'TEXT:your', 'SPACY:POS-ADJ', 'TEXT:or', 'TEXT:text', 'TEXT:stop', 'TEXT:-', 'TEXT:150p', 'TEXT:guaranteed', 'TEXT:urgent', 'HYPERNYM3:textbook.n.01', 'HYPERNYM3:act.n.02', 'TEXT:win', 'HYPERNYM3:challenge.v.01', 'TEXT:+', 'HYPERNYM3:written_communication.n.01', 'SPACY:POS-PRON', 'TEXT:16', 'TEXT:cash', 'HYPERNYM3:abstraction.n.06', 'TEXT:from', 'HYPERNYM3:assertion.n.01', 'TEXT:reply', 'TEXT:now', 'TEXT:.', 'TEXT:tone', 'TEXT:18', 'HYPERNYM3:acquisition.n.02', 'SPACY:POS-DET', 'TEXT:nokia', 'TEXT:a', 'HYPERNYM3:user.n.01', 'TEXT:our', 'HYPERNYM3:mobile.n.02', 'HYPERNYM3:minute.n.01', 'HYPERNYM3:person.n.01', 'HYPERNYM3:claim.v.03', 'TEXT:service', 'TEXT:contact', 'HYPERNYM3:writing.n.02', 'TEXT:for', 'TEXT:...', 'HYPERNYM3:offer.n.02', 'TEXT:awarded', 'TEXT:â£1000', 'TEXT:150ppm', 'TEXT:4', 'HYPERNYM3:request.n.01', 'TEXT:per', 'HYPERNYM3:call.v.28', 'HYPERNYM3:convey.v.03', 'HYPERNYM3:television_camera.n.01', 'HYPERNYM3:land_line.n.01', 'TEXT:ur', 'HYPERNYM3:state.v.01', 'TEXT:camera', 'HYPERNYM3:phone.n.02', 'TEXT:rate', 'TEXT:my', 'HYPERNYM3:solid_figure.n.01', 'TEXT:latest', 'HYPERNYM3:text.n.04', 'HYPERNYM3:coding_system.n.01', 'TEXT:box', 'TEXT:draw', 'TEXT::', 'HYPERNYM3:event.n.01', 'TEXT:line', 'HYPERNYM3:free.a.01', 'TEXT:shows', 'HYPERNYM3:now.r.03', 'HYPERNYM3:declare.v.01', 'TEXT:10p', 'TEXT:collection', 'TEXT:2', 'SPACY:POS-NOUN', 'HYPERNYM3:memory_device.n.01', 'HYPERNYM3:document.n.01', 'HYPERNYM3:service.n.11', 'HYPERNYM3:equipment.n.01', 'HYPERNYM3:part.n.01', 'HYPERNYM3:instrumentality.n.03', 'SPACY:POS-PART', 'TEXT:chat', 'HYPERNYM3:communicator.n.01', 'TEXT:mins', 'HYPERNYM3:activity.n.01', 'HYPERNYM3:leisure.n.01', 'TEXT:offer', 'TEXT:video', 'HYPERNYM3:workweek.n.01', 'TEXT:;', 'TEXT:..', 'TEXT:1st', 'HYPERNYM3:touch.v.05', 'HYPERNYM3:samarium.n.01', 'HYPERNYM3:unit.n.03', 'HYPERNYM3:request.v.01', 'TEXT:but', 'TEXT:network', 'TEXT:apply', 'TEXT:only', 'TEXT:collect', 'TEXT:new', 'TEXT:(', 'HYPERNYM3:time_period.n.01', 'HYPERNYM3:probability.n.01', 'TEXT:receive', 'HYPERNYM3:have.v.07', 'SPACY:POS-SPACE', 'TEXT:selected', 'HYPERNYM3:speech_act.n.01', 'TEXT:msg', 'TEXT:me', "TEXT:'m", 'HYPERNYM3:communication.n.01', 'HYPERNYM3:commercial_document.n.01', 'TEXT:it', 'HYPERNYM3:answer.v.01', 'TEXT:every', 'HYPERNYM3:information.n.01', 'TEXT:wk', 'HYPERNYM3:sound_property.n.01', 'HYPERNYM3:condition.n.01', 'HYPERNYM3:call.n.04', 'TEXT:word', 'TEXT:on', 'SPACY:POS-CCONJ', 'TEXT:cost', 'HYPERNYM3:match.v.01', 'HYPERNYM3:now.r.06', 'HYPERNYM3:promise.v.01', 'HYPERNYM3:option.n.01', 'HYPERNYM3:game.n.01', 'TEXT:send', 'TEXT:that', 'HYPERNYM3:substance.n.01', 'TEXT:please', 'TEXT:phone', 'HYPERNYM3:time_unit.n.01', 'TEXT:gift', 'TEXT:top', 'TEXT:with', 'HYPERNYM3:electronic_equipment.n.01', 'TEXT:this', 'TEXT:ok', 'TEXT:come', 'HYPERNYM3:ur.n.01', 'HYPERNYM3:rate.n.01', 'TEXT:texts', 'HYPERNYM3:quality.n.01', 'HYPERNYM3:stop.v.05', 'TEXT:he', 'HYPERNYM3:secret.n.02', 'SPACY:POS-INTJ', 'HYPERNYM3:entity.n.01', 'TEXT:find', 'HYPERNYM3:relation.n.01', 'HYPERNYM3:people.n.01', 'HYPERNYM3:syndicate.n.01', 'HYPERNYM3:group.n.01', 'SPACY:POS-VERB', 'TEXT:2nd', 'HYPERNYM3:supporter.n.01', 'TEXT:t', 'HYPERNYM3:definite_quantity.n.01', 'HYPERNYM3:call.v.07', 'HYPERNYM3:worth.n.02', 'TEXT:how', 'TEXT:have', 'TEXT:account', "TEXT:'ll", 'HYPERNYM3:choose.v.01', 'TEXT:price', 'HYPERNYM3:late.a.05', 'HYPERNYM3:margin_call.n.01', 'TEXT:been', 'HYPERNYM3:change.v.01', 'HYPERNYM3:difficulty.n.03', 'TEXT:later', 'TEXT:did']
# Example of patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Metric (global) = 0.223
# Examples ~ Class Negative:
# [MATCH]: Your board is working fine . The issue of overheating is also reslove . But still software inst is pending . I will come around 8'o:['SPACY:POS-NUM'] clock .
# -------------------------
# [MATCH]: No it will reach by 9:['SPACY:POS-NUM'] only . She telling she will be there . I do nt know
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: URGENT ! Your Mobile number has been awarded with a Â£2000 prize GUARANTEED . Call 09061790121:['SPACY:POS-NUM'] from land line . Claim 3030 . Valid 12hrs only 150ppm
# -------------------------
# [MATCH]: Urgent ! Please call 09061213237:['SPACY:POS-NUM'] from a landline . Â£5000 cash or a 4 * holiday await collection . T & Cs SAE PO Box 177 M227XY . 16 +
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN']]
# Window size: 3
# Class: Negative
# Precision: 0.690
# Match: 1347 (37.8%)
# Gain = 0.112
# Metric (global) = 0.112
# Examples ~ Class Negative:
# [MATCH]: You will go to walmart:['SPACY:POS-PROPN'] . I.ll stay .
# -------------------------
# [MATCH]: I 'll be in sch fr 4 - 6 ... I dun haf da:['SPACY:POS-PROPN'] book in sch ... It 's at home ...
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: 08714712388 between 10am-7pm:['SPACY:POS-PROPN'] Cost 10p
# -------------------------
# [MATCH]: FREE > Ringtone ! Reply REAL:['SPACY:POS-PROPN'] or POLY eg REAL1 1 . PushButton 2 . DontCha 3 . BabyGoodbye 4 . GoldDigger 5 . WeBeBurnin 1st tone FREE and 6 more when u join for Â£3/wk
# -------------------------
# ==================================================
# Pattern: [['TEXT:call']]
# Window size: 3
# Class: Positive
# Precision: 0.618
# Match: 348 (9.8%)
# Gain = 0.104
# Metric (global) = 0.104
# Examples ~ Class Positive:
# [MATCH]: We currently have a message awaiting your collection . To collect your message just call:['TEXT:call'] 08718723815 .
# -------------------------
# [MATCH]: Someone has contacted our dating service and entered your phone becausethey fancy you ! To find out who it is call:['TEXT:call'] from a landline 09058098002 . PoBox1 , W14RG 150p
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Sorry , I 'll call:['TEXT:call'] later
# -------------------------
# [MATCH]: Sorry , I 'll call:['TEXT:call'] later
# -------------------------
# ==================================================
# Pattern: [['TEXT:i']]
# Window size: 3
# Class: Negative
# Precision: 0.983
# Match: 1327 (37.2%)
# Gain = 0.067
# Metric (global) = 0.067
# Examples ~ Class Negative:
# [MATCH]: I:['TEXT:i'] just got home babe , are you still awake ?
# -------------------------
# [MATCH]: Sounds great ! I:['TEXT:i'] m going to sleep now . Have a good night !
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: accordingly . I:['TEXT:i'] repeat , just text the word ok on your mobile phone and send
# -------------------------
# [MATCH]: cmon babe , make me horny , * turn * me on ! Txt me your fantasy now babe - ) I:['TEXT:i'] m hot , sticky and need you now . All replies cost Â£1.50 . 2 cancel send STOP
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-SYM']]
# Window size: 3
# Class: Positive
# Precision: 0.756
# Match: 156 (4.4%)
# Gain = 0.067
# Metric (global) = 0.067
# Examples ~ Class Positive:
# [MATCH]: I 'd like to tell you my deepest darkest fantasies . Call me 09094646631 just 60p /:['SPACY:POS-SYM'] min . To stop texts call 08712460324 ( nat rate )
# -------------------------
# [MATCH]: YOU 07801543489 are guaranteed the latests Nokia Phone , a 40 GB iPod MP3 player or a Â£500 prize ! Txt word : COLLECT to No:83355 ! TC - LLC NY - USA 150p /:['SPACY:POS-SYM'] Mt msgrcvd18 +
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: HIYA COMIN 2 BRISTOL 1 ST WEEK IN APRIL . LES GOT OFF +:['SPACY:POS-SYM'] RUDI ON NEW YRS EVE BUT I WAS SNORING.THEY WERE DRUNK ! U BAK AT COLLEGE YET ? MY WORK SENDS INK 2 BATH .
# -------------------------
# [MATCH]: Rose for red , red for blood , blood for heart , heart for u. But u for me .... Send tis to all ur friends .. Including me .. If u like me .. If u get back , 1-u r poor in relation ! 2-u need some 1 to support 3-u r frnd 2 many 4-some1 luvs u:['SPACY:POS-SYM'] 5 + - some1 is praying god to marry u.:- ) try it ....
# -------------------------
# ==================================================
# Step 4: Grow patterns
# 100%|██████████| 200/200 [02:48<00:00,  1.18it/s]
# Length 2 / 5; New candidates = 59900
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Metric (global) = 0.223
# Examples ~ Class Negative:
# [MATCH]: Not planned yet : ) going to join company on jan 5:['SPACY:POS-NUM'] only.don know what will happen after that .
# -------------------------
# [MATCH]: I have 2:['SPACY:POS-NUM'] docs appointments next week.:/ I 'm tired of them shoving stuff up me . Ugh why could n't I have had a normal body ?
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: FreeMsg : Claim ur 250:['SPACY:POS-NUM'] SMS messages - Text OK to 84025 now!Use web2mobile 2 ur mates etc . Join Txt250.com for 1.50p / wk . T&C BOX139 , LA32WU . 16 . Remove txtX or stop
# -------------------------
# [MATCH]: URGENT , IMPORTANT INFORMATION FOR O2 USER . TODAY IS YOUR LUCKY DAY ! 2:['SPACY:POS-NUM'] FIND OUT WHY LOG ONTO HTTP://WWW.URAWINNER.COM THERE IS A FANTASTIC SURPRISE AWAITING FOR YOU
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.806
# Match: 319 (8.9%)
# Gain = 0.175
# Metric (global) = 0.175
# Examples ~ Class Positive:
# [MATCH]: Had your mobile 11 months or more ? U R entitled to Update to the latest colour mobiles with camera for Free ! Call The Mobile Update Co:['SPACY:POS-PROPN'] FREE on 08002986030:['SPACY:POS-NUM']
# -------------------------
# [MATCH]: Sunshine Hols . To claim ur med holiday send a stamped self address envelope to Drinks on Us UK , PO:['SPACY:POS-PROPN'] Box 113:['SPACY:POS-NUM'] , Bray , Wicklow , Eire . Quiz Starts Saturday ! Unsub Stop
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: U:['SPACY:POS-PROPN'] GOIN OUT 2NITE:['SPACY:POS-NUM'] ?
# -------------------------
# [MATCH]: Then Ã¼ ask dad to pick Ã¼ up lar ... Ãœ:['SPACY:POS-PROPN'] wan 2:['SPACY:POS-NUM'] stay until 6 meh ...
# -------------------------
# ==================================================
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.984
# Match: 183 (5.1%)
# Gain = 0.152
# Metric (global) = 0.152
# Examples ~ Class Positive:
# [MATCH]: YOU ARE CHOSEN TO RECEIVE A Â£350 AWARD ! Pls call:['TEXT:call'] claim number 09066364311:['SPACY:POS-NUM'] to collect your award which you are selected to receive as a valued mobile customer .
# -------------------------
# [MATCH]: Call:['TEXT:call'] 09095350301:['SPACY:POS-NUM'] and send our girls into erotic ecstacy . Just 60p / min . To stop texts call 08712460324 ( nat rate )
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Ummma.will call:['TEXT:call'] after check in.our:['SPACY:POS-NUM'] life will begin from qatar so pls pray very hard .
# -------------------------
# [MATCH]: I 'm in a movie . Call:['TEXT:call'] me 4:['SPACY:POS-NUM'] wat ?
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.579
# Match: 518 (14.5%)
# Gain = 0.148
# Metric (global) = 0.148
# Examples ~ Class Positive:
# [MATCH]: You have won a Nokia 7250i . This is what you get when you win our FREE auction . To take part send Nokia to 86021 now . HG:['SPACY:POS-PROPN'] / Suite342/2Lands:['SPACY:POS-PROPN'] Row / W1JHL 16 +
# -------------------------
# [MATCH]: This message is brought to you by GMW:['SPACY:POS-PROPN'] Ltd.:['SPACY:POS-PROPN'] and is not connected to the
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: That 's the trouble with classes that go well - you 're due a dodgey one â€ ¦:['SPACY:POS-PROPN'] Expecting:['SPACY:POS-PROPN'] mine tomo ! See you for recovery , same time , same place
# -------------------------
# [MATCH]: Dear friends , sorry for the late information . Today is the birthday of our loving Ar:['SPACY:POS-PROPN'] . Praveesh:['SPACY:POS-PROPN'] . for more details log on to face book and see . Its his number + & lt;#&gt ; . Do nt miss a delicious treat .
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.613
# Match: 421 (11.8%)
# Gain = 0.129
# Metric (global) = 0.129
# Examples ~ Class Positive:
# [MATCH]: PRIVATE ! Your 2003 Account Statement for:['SPACY:POS-ADP'] shows 800:['SPACY:POS-NUM'] un - redeemed S. I. M. points . Call 08718738002 Identifier Code : 48922 Expires 21/11/04
# -------------------------
# [MATCH]: In The Simpsons Movie released in:['SPACY:POS-ADP'] July 2007:['SPACY:POS-NUM'] name the band that died at the start of the film ? A - Green Day , B - Blue Day , C - Red Day . ( Send A , B or C )
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Oh god i am happy to see your message after:['SPACY:POS-ADP'] 3:['SPACY:POS-NUM'] days
# -------------------------
# [MATCH]: What do u reckon as:['SPACY:POS-ADP'] need 2:['SPACY:POS-NUM'] arrange transport if u ca n't do it , thanks
# -------------------------
# ==================================================
# 100%|██████████| 70/70 [02:10<00:00,  1.86s/it]
# Length 3 / 5; New candidates = 27723
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Metric (global) = 0.223
# Examples ~ Class Negative:
# [MATCH]: 1Apple:['SPACY:POS-NUM'] / Day = No Doctor . 1Tulsi Leaf / Day = No Cancer . 1Lemon / Day = No Fat . 1Cup Milk / day = No Bone Problms 3 Litres Watr / Day = No Diseases Snd ths 2 Whom U Care .. :- )
# -------------------------
# [MATCH]: HEY THERE BABE , HOW U DOIN ? WOT U UP 2:['SPACY:POS-NUM'] 2NITE LOVE ANNIE X.
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Hello from Orange . For 1:['SPACY:POS-NUM'] month 's free access to games , news and sport , plus 10 free texts and 20 photo messages , reply YES . Terms apply : www.orange.co.uk/ow
# -------------------------
# [MATCH]: Great News ! Call FREEFONE 08006344447:['SPACY:POS-NUM'] to claim your guaranteed Â£1000 CASH or Â£2000 gift . Speak to a live operator NOW !
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.806
# Match: 319 (8.9%)
# Gain = 0.175
# Metric (global) = 0.175
# Examples ~ Class Positive:
# [MATCH]: FREE GAME . Get Rayman:['SPACY:POS-PROPN'] Golf 4:['SPACY:POS-NUM'] FREE from the O2 Games Arcade . 1st get UR games settings . Reply POST , then save & activ8 . Press 0 key for Arcade . Termsapply
# -------------------------
# [MATCH]: Bored of speed dating ? Try SPEEDCHAT , txt SPEEDCHAT:['SPACY:POS-PROPN'] to 80155:['SPACY:POS-NUM'] , if you do n't like em txt SWAP and get a new chatter ! Chat80155 POBox36504W45WQ 150p / msg rcd 16
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: God picked up a flower and dippeditinaDEW , lovingly touched itwhichturnedinto u , and the he gifted tomeandsaid , THIS FRIEND:['SPACY:POS-PROPN'] IS 4U:['SPACY:POS-NUM']
# -------------------------
# [MATCH]: Your opinion about me ? 1 . Over 2 . Jada:['SPACY:POS-PROPN'] 3:['SPACY:POS-NUM'] . Kusruthi 4 . Lovable 5 . Silent 6 . Spl character 7 . Not matured 8 . Stylish 9 . Simple Pls reply ..
# -------------------------
# ==================================================
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.984
# Match: 183 (5.1%)
# Gain = 0.152
# Metric (global) = 0.152
# Examples ~ Class Positive:
# [MATCH]: You are a winner you have been specially selected to receive Â£1000 cash or a Â£2000 award . Speak to a live operator to claim call:['TEXT:call'] 087123002209am-7pm:['SPACY:POS-NUM'] . Cost 10p
# -------------------------
# [MATCH]: Someone U know has asked our dating service 2 contact you ! Ca nt Guess who ? CALL:['TEXT:call'] 09058091854:['SPACY:POS-NUM'] NOW all will be revealed . PO BOX385 M6 6WU
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Yun ah.the ubi one say if Ã¼ wan call:['TEXT:call'] by tomorrow.call 67441233:['SPACY:POS-NUM'] look for irene.ere only got bus8,22,65,61,66,382 . Ubi cres , ubi tech park.6ph for 1st 5wkg days . Ã¨n
# -------------------------
# [MATCH]: I 'm in a movie . Call:['TEXT:call'] me 4:['SPACY:POS-NUM'] wat ?
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.579
# Match: 518 (14.5%)
# Gain = 0.148
# Metric (global) = 0.148
# Examples ~ Class Positive:
# [MATCH]: Congratulations U can claim 2 VIP row A Tickets:['SPACY:POS-PROPN'] 2 C:['SPACY:POS-PROPN'] Blu in concert in November or Blu gift guaranteed Call 09061104276 to claim TS&Cs www.smsco.net costÂ£3.75max
# -------------------------
# [MATCH]: You have won ? 1,000 cash or a ? 2,000 prize ! To claim , call09050000327 . T&C:['SPACY:POS-PROPN'] : RSTM:['SPACY:POS-PROPN'] , SW7 3SS . 150ppm
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Christmas is An occasion that is Celebrated as a Reflection:['SPACY:POS-PROPN'] of UR:['SPACY:POS-PROPN'] ... Values ... , Desires ... , Affections ... &amp ; Traditions .... Have an ideal Christmas ...
# -------------------------
# [MATCH]: Oh ! A half hour is much longer in Syria:['SPACY:POS-PROPN'] than Canada:['SPACY:POS-PROPN'] , eh ? Wow you must get SO much more work done in a day than us with all that extra time ! * grins *
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.613
# Match: 421 (11.8%)
# Gain = 0.129
# Metric (global) = 0.129
# Examples ~ Class Positive:
# [MATCH]: Email AlertFrom : Jeri StewartSize : 2KBSubject : Low - cost prescripiton drvgsTo listen to:['SPACY:POS-ADP'] email call 123:['SPACY:POS-NUM']
# -------------------------
# [MATCH]: For ur chance to win a Â£250 wkly shopping spree TXT : SHOP to:['SPACY:POS-ADP'] 80878:['SPACY:POS-NUM'] . T's&C 's www.txt-2-shop.com custcare 08715705022 , 1x150p / wk
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: V nice ! Off 2 sheffield tom 2 air my opinions on:['SPACY:POS-ADP'] categories 2:['SPACY:POS-NUM'] b used 2 measure ethnicity in next census . Busy transcribing . :-)
# -------------------------
# [MATCH]: Kinda . First one gets in at:['SPACY:POS-ADP'] twelve:['SPACY:POS-NUM'] ! Aah . Speak tomo
# -------------------------
# ==================================================
# 100%|██████████| 36/36 [01:03<00:00,  1.76s/it]
# Length 4 / 5; New candidates = 14334
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Metric (global) = 0.223
# Examples ~ Class Negative:
# [MATCH]: Can help u:['SPACY:POS-NUM'] swoop by picking u up from wherever ur other birds r meeting if u want .
# -------------------------
# [MATCH]: This is one:['SPACY:POS-NUM'] of the days you have a billion classes , right ?
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: SMS SERVICES . for your inclusive text credits , pls goto www.comuk.net login= 3qxj9:['SPACY:POS-NUM'] unsubscribe with STOP , no extra charge . help 08702840625.COMUK . 220-CM2 9AE
# -------------------------
# [MATCH]: PRIVATE ! Your 2003:['SPACY:POS-NUM'] Account Statement for 07815296484 shows 800 un - redeemed S.I.M. points . Call 08718738001 Identifier Code 41782 Expires 18/11/04
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.806
# Match: 319 (8.9%)
# Gain = 0.175
# Metric (global) = 0.175
# Examples ~ Class Positive:
# [MATCH]: okmail : Dear Dave this is your final notice to collect your 4 * Tenerife Holiday:['SPACY:POS-PROPN'] or # 5000:['SPACY:POS-NUM'] CASH award ! Call 09061743806 from landline . TCs SAE Box326 CW25WX 150ppm
# -------------------------
# [MATCH]: URGENT ! We are trying to contact U. Todays draw shows that you have won a Â£800 prize GUARANTEED:['SPACY:POS-PROPN'] . Call 09050001808:['SPACY:POS-NUM'] from land line . Claim M95 . Valid12hrs only
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Height of Confidence : All the Aeronautics professors wer calld & amp ; they wer askd 2 sit in an aeroplane . Aftr they sat they wer told dat the plane ws made by their students . Dey all hurried out of d plane .. Bt:['SPACY:POS-PROPN'] only 1:['SPACY:POS-NUM'] did nt move ... He said:"if it is made by my students , this wo nt even start ........ Datz confidence ..
# -------------------------
# [MATCH]: Boy ; I love u Grl : Hogolo Boy : gold chain kodstini Grl : Agalla Boy : necklace madstini Grl : agalla Boy : Hogli:['SPACY:POS-PROPN'] 1:['SPACY:POS-NUM'] mutai eerulli kodthini ! Grl : I love U kano;- )
# -------------------------
# ==================================================
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.984
# Match: 183 (5.1%)
# Gain = 0.152
# Metric (global) = 0.152
# Examples ~ Class Positive:
# [MATCH]: < Forwarded from 21870000>Hi - this is your Mailbox Messaging SMS alert . You have 4 messages . You have 21 matches . Please call:['TEXT:call'] back on 09056242159:['SPACY:POS-NUM'] to retrieve your messages and matches
# -------------------------
# [MATCH]: HOT LIVE FANTASIES call:['TEXT:call'] now 08707500020:['SPACY:POS-NUM'] Just 20p per min NTT Ltd , PO Box 1327 Croydon CR9 5WB 0870 is a national rate call
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I 'm in a movie . Call:['TEXT:call'] me 4:['SPACY:POS-NUM'] wat ?
# -------------------------
# [MATCH]: Ummma.will call:['TEXT:call'] after check in.our:['SPACY:POS-NUM'] life will begin from qatar so pls pray very hard .
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.579
# Match: 518 (14.5%)
# Gain = 0.148
# Metric (global) = 0.148
# Examples ~ Class Positive:
# [MATCH]: Santa:['SPACY:POS-PROPN'] Calling:['SPACY:POS-PROPN'] ! Would your little ones like a call from Santa Xmas eve ? Call 09058094583 to book your time .
# -------------------------
# [MATCH]: FREE MESSAGE Activate your 500 FREE Text:['SPACY:POS-PROPN'] Messages:['SPACY:POS-PROPN'] by replying to this message with the word FREE For terms & conditions , visit www.07781482378.com
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: " BOO:['SPACY:POS-PROPN'] BABE:['SPACY:POS-PROPN'] ! U ENJOYIN YOURJOB ? U SEEMED 2 B GETTIN ON WELL HUNNY!HOPE URE OK?TAKE CARE & IÂ’LLSPEAK 2U SOONLOTS OF LOVEME XXXX . "
# -------------------------
# [MATCH]: COME BACK TO TAMPA:['SPACY:POS-PROPN'] FFFFUUUUUUU:['SPACY:POS-PROPN']
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.613
# Match: 421 (11.8%)
# Gain = 0.129
# Metric (global) = 0.129
# Examples ~ Class Positive:
# [MATCH]: Guess what ! Somebody you know secretly fancies you ! Wanna find out who it is ? Give us a call on:['SPACY:POS-ADP'] 09065394514:['SPACY:POS-NUM'] From Landline DATEBox1282EssexCM61XN 150p / min 18
# -------------------------
# [MATCH]: 88066 FROM:['SPACY:POS-ADP'] 88066:['SPACY:POS-NUM'] LOST 3POUND HELP
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: " NOT ENUFCREDEIT TOCALL.SHALL ILEAVE UNI AT:['SPACY:POS-ADP'] 6:['SPACY:POS-NUM'] + GET A BUS TO YOR HOUSE ? "
# -------------------------
# [MATCH]: is your hamster dead ? Hey so tmr i meet you at:['SPACY:POS-ADP'] 1:['SPACY:POS-NUM'] pm orchard mrt ?
# -------------------------
# ==================================================
# 100%|██████████| 4/4 [00:07<00:00,  1.90s/it]
# Length 5 / 5; New candidates = 1595
# Finding top k: 10 / 100
# Finding top k: 20 / 100
# Finding top k: 30 / 100
# Finding top k: 40 / 100
# Finding top k: 50 / 100
# Finding top k: 60 / 100
# Finding top k: 70 / 100
# Finding top k: 80 / 100
# Finding top k: 90 / 100
# Finding top k: 100 / 100
# Example of current patterns
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Metric (global) = 0.223
# Examples ~ Class Negative:
# [MATCH]: Ok no problem ... Yup i 'm going to sch at 4:['SPACY:POS-NUM'] if i rem correctly ...
# -------------------------
# [MATCH]: Single line with a big meaning : : : : : " Miss anything 4:['SPACY:POS-NUM'] ur " Best Life " but , do n't miss ur best life for anything ... Gud nyt ...
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: GENT ! We are trying to contact you . Last weekends draw shows that you won a Â£1000 prize GUARANTEED . Call 09064012160:['SPACY:POS-NUM'] . Claim Code K52 . Valid 12hrs only . 150ppm
# -------------------------
# [MATCH]: I do n't know u and u do n't know me . Send CHAT to 86688:['SPACY:POS-NUM'] now and let 's find each other ! Only 150p / Msg rcvd . HG / Suite342/2Lands / Row / W1J6HL LDN . 18 years or over .
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.806
# Match: 319 (8.9%)
# Gain = 0.175
# Metric (global) = 0.175
# Examples ~ Class Positive:
# [MATCH]: Santa calling ! Would your little ones like a call from Santa Xmas Eve:['SPACY:POS-PROPN'] ? Call 09077818151:['SPACY:POS-NUM'] to book you time . Calls1.50ppm last 3mins 30s T&C www.santacalling.com
# -------------------------
# [MATCH]: Please call our customer service representative on FREEPHONE:['SPACY:POS-PROPN'] 0808:['SPACY:POS-NUM'] 145 4742 between 9am-11pm as you have WON a guaranteed Â£1000 cash or Â£5000 prize !
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: HIYA:['SPACY:POS-PROPN'] COMIN 2:['SPACY:POS-NUM'] BRISTOL 1 ST WEEK IN APRIL . LES GOT OFF + RUDI ON NEW YRS EVE BUT I WAS SNORING.THEY WERE DRUNK ! U BAK AT COLLEGE YET ? MY WORK SENDS INK 2 BATH .
# -------------------------
# [MATCH]: K:['SPACY:POS-PROPN'] then 2marrow:['SPACY:POS-NUM'] are you coming to class .
# -------------------------
# ==================================================
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.984
# Match: 183 (5.1%)
# Gain = 0.152
# Metric (global) = 0.152
# Examples ~ Class Positive:
# [MATCH]: Xmas Offer ! Latest Motorola , SonyEricsson & Nokia & FREE Bluetooth or DVD ! Double Mins & 1000 Txt on Orange . Call:['TEXT:call'] MobileUpd8 on 08000839402:['SPACY:POS-NUM'] or call2optout/4QF2
# -------------------------
# [MATCH]: YOU ARE CHOSEN TO RECEIVE A Â£350 AWARD ! Pls call:['TEXT:call'] claim number 09066364311:['SPACY:POS-NUM'] to collect your award which you are selected to receive as a valued mobile customer .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Yun ah.the ubi one say if Ã¼ wan call:['TEXT:call'] by tomorrow.call 67441233:['SPACY:POS-NUM'] look for irene.ere only got bus8,22,65,61,66,382 . Ubi cres , ubi tech park.6ph for 1st 5wkg days . Ã¨n
# -------------------------
# [MATCH]: I 'm in a movie . Call:['TEXT:call'] me 4:['SPACY:POS-NUM'] wat ?
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.579
# Match: 518 (14.5%)
# Gain = 0.148
# Metric (global) = 0.148
# Examples ~ Class Positive:
# [MATCH]: 8007 25p 4 Alfie:['SPACY:POS-PROPN'] Moon:['SPACY:POS-PROPN'] 's Children in Need song on ur mob . Tell ur m8s . Txt TONE CHARITY to 8007 for nokias or POLY CHARITY for polys : zed 08701417012 profit 2 charity
# -------------------------
# [MATCH]: Bears:['SPACY:POS-PROPN'] Pic:['SPACY:POS-PROPN'] Nick , and Tom , Pete and ... Dick . In fact , all types try gay chat with photo upload call 08718730666 ( 10p / min ) . 2 stop texts call 08712460324
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: As per your request ' Melle:['SPACY:POS-PROPN'] Melle:['SPACY:POS-PROPN'] ( Oru Minnaminunginte Nurungu Vettam ) ' has been set as your callertune for all Callers . Press * 9 to copy your friends Callertune
# -------------------------
# [MATCH]: Hi ! You just spoke to MANEESHA:['SPACY:POS-PROPN'] V.:['SPACY:POS-PROPN'] We 'd like to know if you were satisfied with the experience . Reply Toll Free with Yes or No .
# -------------------------
# ==================================================
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.613
# Match: 421 (11.8%)
# Gain = 0.129
# Metric (global) = 0.129
# Examples ~ Class Positive:
# [MATCH]: CLAIRE here am havin borin time & am now alone U wanna cum over:['SPACY:POS-ADP'] 2nite:['SPACY:POS-NUM'] ? Chat now 09099725823 hope 2 C U Luv CLAIRE xx CallsÂ£1/minmoremobsEMSPOBox45PO139WA
# -------------------------
# [MATCH]: Get a FREE mobile video player FREE movie . To collect text GO to:['SPACY:POS-ADP'] 89105:['SPACY:POS-NUM'] . Its free ! Extra films can be ordered t 's and c 's apply . 18 yrs only
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: No . Its not specialisation . Can work but its slave labor . Will look for it this month sha cos:['SPACY:POS-ADP'] no shakara 4:['SPACY:POS-NUM'] beggar .
# -------------------------
# [MATCH]: What are you doing in langport ? Sorry , but I 'll probably be in:['SPACY:POS-ADP'] bed by 9:['SPACY:POS-NUM'] pm . It sucks being ill at xmas ! When do you and go2sri lanka ?
# -------------------------
# ==================================================

# %%
# Print the learned patterns
for idx, p in enumerate(the_patterns):
    print(f'Rank {idx+1}')
    print(p)
# Out:
# Rank 1
# Pattern: [['SPACY:POS-NUM']]
# Window size: 3
# Class: Negative
# Precision: 0.526
# Match: 936 (26.2%)
# Gain = 0.223
# Metric (global) = 0.223
# Examples ~ Class Negative:
# [MATCH]: Ugh . Got ta drive back to sd:['SPACY:POS-NUM'] from la . My butt is sore .
# -------------------------
# [MATCH]: Haha ... Where got so fast lose weight , thk muz go 4:['SPACY:POS-NUM'] a month den got effect ... Gee , later we go aust put bk e weight .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Last Chance ! Claim ur Â£150 worth of discount vouchers today ! Text SHOP to 85023:['SPACY:POS-NUM'] now ! SavaMob , offers mobile ! T Cs SavaMob POBOX84 , M263UZ . Â£3.00 Sub . 16
# -------------------------
# [MATCH]: For ur chance to win a Â£250 wkly shopping spree TXT : SHOP to 80878:['SPACY:POS-NUM'] . T's&C 's www.txt-2-shop.com custcare 08715705022 , 1x150p / wk
# -------------------------
# ==================================================
# Rank 2
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.806
# Match: 319 (8.9%)
# Gain = 0.175
# Metric (global) = 0.175
# Examples ~ Class Positive:
# [MATCH]: URGENT ! Your Mobile number has been awarded a < UKP>2000 prize GUARANTEED:['SPACY:POS-PROPN'] . Call 09061790125:['SPACY:POS-NUM'] from landline . Claim 3030 . Valid 12hrs only 150ppm
# -------------------------
# [MATCH]: Want to funk up ur fone with a weekly new tone reply TONES2U:['SPACY:POS-PROPN'] 2:['SPACY:POS-NUM'] this text . www.ringtones.co.uk , the original n best . Tones 3GBP network operator rates apply
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: " BOO BABE ! U ENJOYIN YOURJOB ? U:['SPACY:POS-PROPN'] SEEMED 2:['SPACY:POS-NUM'] B GETTIN ON WELL HUNNY!HOPE URE OK?TAKE CARE & IÂ’LLSPEAK 2U SOONLOTS OF LOVEME XXXX . "
# -------------------------
# [MATCH]: Hi Jon , Pete here , I ve bin:['SPACY:POS-PROPN'] 2:['SPACY:POS-NUM'] Spain recently & hav sum dinero left , Bill said u or ur Â‘rents mayb interested in it , I hav 12,000pes , so around Â£48 , tb , James .
# -------------------------
# ==================================================
# Rank 3
# Pattern: [['TEXT:call'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.984
# Match: 183 (5.1%)
# Gain = 0.152
# Metric (global) = 0.152
# Examples ~ Class Positive:
# [MATCH]: INTERFLORA - Â“It 's not too late to order Interflora flowers for christmas call:['TEXT:call'] 0800:['SPACY:POS-NUM'] 505060 to place your order before Midnight tomorrow .
# -------------------------
# [MATCH]: Loan for any purpose Â£500 - Â£75,000 . Homeowners + Tenants welcome . Have you been previously refused ? We can still help . Call:['TEXT:call'] Free 0800:['SPACY:POS-NUM'] 1956669 or text back ' help '
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I 'm in a movie . Call:['TEXT:call'] me 4:['SPACY:POS-NUM'] wat ?
# -------------------------
# [MATCH]: Yun ah.the ubi one say if Ã¼ wan call:['TEXT:call'] by tomorrow.call 67441233:['SPACY:POS-NUM'] look for irene.ere only got bus8,22,65,61,66,382 . Ubi cres , ubi tech park.6ph for 1st 5wkg days . Ã¨n
# -------------------------
# ==================================================
# Rank 4
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.579
# Match: 518 (14.5%)
# Gain = 0.148
# Metric (global) = 0.148
# Examples ~ Class Positive:
# [MATCH]: Show ur colours ! Euro 2004 2 - 4 - 1 Offer ! Get an England:['SPACY:POS-PROPN'] Flag:['SPACY:POS-PROPN'] & 3Lions tone on ur phone ! Click on the following service message for info !
# -------------------------
# [MATCH]: You have an important customer service announcement from PREMIER:['SPACY:POS-PROPN'] . Call FREEPHONE:['SPACY:POS-PROPN'] 0800 542 0578 now !
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Oh , i will get paid . The most outstanding one is for a commercial i did for Hasbro:['SPACY:POS-PROPN'] ... in AUGUST:['SPACY:POS-PROPN'] ! They made us jump through so many hoops to get paid . Still not .
# -------------------------
# [MATCH]: Hello beautiful r u ok ? I 've kinda ad a row wiv and he walked out the pub ? ? I wanted a night wiv u:['SPACY:POS-PROPN'] Miss:['SPACY:POS-PROPN'] u
# -------------------------
# ==================================================
# Rank 5
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.613
# Match: 421 (11.8%)
# Gain = 0.129
# Metric (global) = 0.129
# Examples ~ Class Positive:
# [MATCH]: URGENT . Important information for:['SPACY:POS-ADP'] 02:['SPACY:POS-NUM'] user . Today is your lucky day ! 2 find out why , log onto http://www.urawinner.com there is a fantastic surprise awaiting you !
# -------------------------
# [MATCH]: Free entry in:['SPACY:POS-ADP'] 2:['SPACY:POS-NUM'] a weekly comp for a chance to win an ipod . Txt POD to 80182 to get entry ( std txt rate ) T&C 's apply 08452810073 for details 18 +
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I 'll pick you up at:['SPACY:POS-ADP'] about 5.15pm:['SPACY:POS-NUM'] to go to taunton if you still want to come .
# -------------------------
# [MATCH]: S:-)kallis wo nt play in:['SPACY:POS-ADP'] first two:['SPACY:POS-NUM'] odi:- )
# -------------------------
# ==================================================
# Rank 6
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.811
# Match: 243 (6.8%)
# Gain = 0.129
# Metric (global) = 0.129
# Examples ~ Class Positive:
# [MATCH]: You have WON a guaranteed Â£1000 cash or a Â£2000 prize . To claim yr prize call our customer service representative on 08714712379:['SPACY:POS-NUM'] between 10am-7pm:['SPACY:POS-PROPN'] Cost 10p
# -------------------------
# [MATCH]: ou are guaranteed the latest Nokia Phone , a 40:['SPACY:POS-NUM'] GB:['SPACY:POS-PROPN'] iPod MP3 player or a Â£500 prize ! Txt word : COLLECT to No : 83355 ! IBHltd LdnW15H 150p / Mtmsgrcvd18
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Solve d Case : A Man Was Found Murdered On   & lt;DECIMAL&gt ; . & lt;#&gt ;   AfterNoon . 1,His:['SPACY:POS-NUM'] wife called Police:['SPACY:POS-PROPN'] . 2,Police questioned everyone . 3,Wife : Sir , I was sleeping , when the murder took place . 4.Cook : I was cooking . 5.Gardener : I was picking vegetables . 6.House - Maid : I went 2 d post office . 7.Children : We went 2 play . 8.Neighbour : We went 2 a marriage . Police arrested d murderer Immediately . Who 's It ? Reply With Reason , If U r Brilliant .
# -------------------------
# [MATCH]: " AH POOR BABY!HOPE URFEELING BETTERSN LUV ! PROBTHAT OVERDOSE OF WORK HEY GO CAREFUL SPK 2:['SPACY:POS-NUM'] U SN:['SPACY:POS-PROPN'] LOTS OF LOVEJEN XXX . "
# -------------------------
# ==================================================
# Rank 7
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Negative
# Precision: 0.526
# Match: 644 (18.1%)
# Gain = 0.119
# Metric (global) = 0.119
# Examples ~ Class Negative:
# [MATCH]: " CHEERS:['SPACY:POS-NOUN'] U:['SPACY:POS-PROPN'] TEX MECAUSE U WEREBORED ! YEAH OKDEN HUNNY R UIN WK SAT?SOUNDÂ ’S LIKEYOUR HAVIN GR8FUN J ! KEEP UPDAT COUNTINLOTS OF LOVEME XXXXX . "
# -------------------------
# [MATCH]: Still at west coast:['SPACY:POS-NOUN'] ... Haiz:['SPACY:POS-PROPN'] ... Ãœ'll take forever to come back ...
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Fantasy Football is back on your TV . Go to Sky Gamestar on Sky Active and play Â£250k Dream Team . Scoring:['SPACY:POS-NOUN'] starts on Saturday:['SPACY:POS-PROPN'] , so register now!SKY OPT OUT to 88088
# -------------------------
# [MATCH]: < Forwarded from 88877>FREE entry:['SPACY:POS-NOUN'] into our Â£250:['SPACY:POS-PROPN'] weekly comp just send the word ENTER to 88877 NOW . 18 T&C www.textcomp.com
# -------------------------
# ==================================================
# Rank 8
# Pattern: [['TEXT:to'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.856
# Match: 194 (5.4%)
# Gain = 0.114
# Metric (global) = 0.114
# Examples ~ Class Positive:
# [MATCH]: 22 days to kick off ! For Euro2004 U will be kept up to date with the latest news and results daily . To be removed send GET TXT STOP to:['TEXT:to'] 83222:['SPACY:POS-NUM']
# -------------------------
# [MATCH]: Valentines Day Special ! Win over Â£1000 in our quiz and take your partner on the trip of a lifetime ! Send GO to:['TEXT:to'] 83600:['SPACY:POS-NUM'] now . 150p / msg rcvd . CustCare:08718720201 .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: 1 ) Go to:['TEXT:to'] write msg 2:['SPACY:POS-NUM'] ) Put on Dictionary mode 3)Cover the screen with hand , 4)Press   & lt;#&gt ; . 5)Gently remove Ur hand .. Its interesting .. : )
# -------------------------
# [MATCH]: Desires- u going to:['TEXT:to'] doctor 4:['SPACY:POS-NUM'] liver . And get a bit stylish . Get ur hair managed . That s it .
# -------------------------
# ==================================================
# Rank 9
# Pattern: [['SPACY:POS-PROPN']]
# Window size: 3
# Class: Negative
# Precision: 0.690
# Match: 1347 (37.8%)
# Gain = 0.112
# Metric (global) = 0.112
# Examples ~ Class Negative:
# [MATCH]: Edison has rightly said , " A fool can ask more questions than a wise man can answer " Now you know why all of us are speechless during ViVa:['SPACY:POS-PROPN'] .. GM , GN , GE , GNT:- )
# -------------------------
# [MATCH]: Can you plz tell me the ans . BSLVYL:['SPACY:POS-PROPN'] sent via fullonsms.com
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Win a Â£1000:['SPACY:POS-PROPN'] cash prize or a prize worth Â£5000
# -------------------------
# [MATCH]: 08714712388 between 10am-7pm:['SPACY:POS-PROPN'] Cost 10p
# -------------------------
# ==================================================
# Rank 10
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.702
# Match: 272 (7.6%)
# Gain = 0.105
# Metric (global) = 0.105
# Examples ~ Class Positive:
# [MATCH]: Goal ! Arsenal 4 ( Henry , 7 v Liverpool 2 Henry scores with a simple shot from 6 yards from a pass by Bergkamp to give Arsenal a 2 goal:['SPACY:POS-NOUN'] margin:['SPACY:POS-NOUN'] after 78:['SPACY:POS-NUM'] mins .
# -------------------------
# [MATCH]: FREE RINGTONE:['SPACY:POS-NOUN'] text:['SPACY:POS-NOUN'] FIRST to 87131:['SPACY:POS-NUM'] for a poly or text GET to 87131 for a true tone ! Help ? 0845 2814032 16 after 1st free , tones are 3xÂ£150pw to eÂ£nd txt stop
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: V nice ! Off 2 sheffield tom 2 air my opinions:['SPACY:POS-NOUN'] on categories:['SPACY:POS-NOUN'] 2:['SPACY:POS-NUM'] b used 2 measure ethnicity in next census . Busy transcribing . :-)
# -------------------------
# [MATCH]: " Hey sorry I didntgive ya a a bellearlier hunny , just been in bedbut:['SPACY:POS-NOUN'] mite:['SPACY:POS-NOUN'] go 2:['SPACY:POS-NUM'] thepub l8tr if uwana mt up?loads a luv Jenxxx . "
# -------------------------
# ==================================================
# Rank 11
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 5
# Class: Positive
# Precision: 0.722
# Match: 255 (7.1%)
# Gain = 0.104
# Metric (global) = 0.104
# Examples ~ Class Positive:
# [MATCH]: PRIVATE ! Your 2003 Account:['SPACY:POS-PROPN'] Statement:['SPACY:POS-PROPN'] for 07808 XXXXXX:['SPACY:POS-PROPN'] shows 800 un - redeemed S. I. M. points . Call 08719899217 Identifier Code : 41685 Expires 07/11/04
# -------------------------
# [MATCH]: December only ! Had your mobile 11mths+ ? You are entitled to update to the latest colour camera mobile for Free ! Call The Mobile:['SPACY:POS-PROPN'] Update:['SPACY:POS-PROPN'] Co:['SPACY:POS-PROPN'] FREE on 08002986906
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: " CHEERS FOR CALLIN BABE.SOZI CULDNT TALKBUT I WANNATELL U DETAILS LATER WENWECAN:['SPACY:POS-PROPN'] CHAT:['SPACY:POS-PROPN'] PROPERLY:['SPACY:POS-PROPN'] X "
# -------------------------
# [MATCH]: MY NEW:['SPACY:POS-PROPN'] YEARS:['SPACY:POS-PROPN'] EVE:['SPACY:POS-PROPN'] WAS OK . I WENT TO A PARTY WITH MY BOYFRIEND . WHO IS THIS SI THEN HEY
# -------------------------
# ==================================================
# Rank 12
# Pattern: [['TEXT:.'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.797
# Match: 202 (5.7%)
# Gain = 0.101
# Metric (global) = 0.101
# Examples ~ Class Positive:
# [MATCH]: BIG BROTHER ALERT ! The computer has selected u for 10k cash or # 150 voucher .:['TEXT:.'] Call 09064018838:['SPACY:POS-NUM'] . NTT PO Box CRO1327 18 + BT Landline Cost 150ppm mobiles vary
# -------------------------
# [MATCH]: This is the 2nd time we have tried 2 contact u. U have won the 750 Pound prize .:['TEXT:.'] 2:['SPACY:POS-NUM'] claim is easy , call 08712101358 NOW ! Only 10p per min . BT - national - rate
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: MY NO .:['TEXT:.'] IN LUTON 0125698789:['SPACY:POS-NUM'] RING ME IF UR AROUND ! H *
# -------------------------
# [MATCH]: Sorry . You never hear unless you book it .:['TEXT:.'] One:['SPACY:POS-NUM'] was kinda a joke -- thet were really looking for skinny white girls . The other was one line -- you can only do so much on camera with that . Something like that they 're casting on the look .
# -------------------------
# ==================================================
# Rank 13
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.735
# Match: 238 (6.7%)
# Gain = 0.100
# Metric (global) = 0.100
# Examples ~ Class Positive:
# [MATCH]: HOT LIVE FANTASIES call now 08707509020:['SPACY:POS-NUM'] Just 20p:['SPACY:POS-NUM'] per min NTT Ltd , PO Box 1327 Croydon CR9 5WB 0870 .. k
# -------------------------
# [MATCH]: WINNER ! As a valued network customer you hvae been selected to receive a Â£900 reward ! To collect call 09061701444:['SPACY:POS-NUM'] . Valid 24:['SPACY:POS-NUM'] hours only . ACL03530150PM
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Your opinion about me ? 1:['SPACY:POS-NUM'] . Over 2:['SPACY:POS-NUM'] . Jada 3 . Kusruthi 4 . Lovable 5 . Silent 6 . Spl character 7 . Not matured 8 . Stylish 9 . Simple Pls reply ..
# -------------------------
# [MATCH]: 4:['SPACY:POS-NUM'] tacos + 1:['SPACY:POS-NUM'] rajas burrito , right ?
# -------------------------
# ==================================================
# Rank 14
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
# Window size: 4
# Class: Negative
# Precision: 0.585
# Match: 714 (20.0%)
# Gain = 0.095
# Metric (global) = 0.095
# Examples ~ Class Negative:
# [MATCH]: I 'm home . Ard:['SPACY:POS-PROPN'] wat time:['SPACY:POS-NOUN'] will u reach ?
# -------------------------
# [MATCH]: Desires-:['SPACY:POS-PROPN'] u:['SPACY:POS-NOUN'] going to doctor 4 liver . And get a bit stylish . Get ur hair managed . That s it .
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Free 1st week entry 2 TEXTPOD 4 a chance 2 win 40 GB iPod:['SPACY:POS-PROPN'] or Â£250 cash:['SPACY:POS-NOUN'] every wk . Txt POD to 84128 Ts&Cs www.textpod.net custcare 08712405020 .
# -------------------------
# [MATCH]: As one of our registered subscribers u can enter the draw 4 a 100 G.B.:['SPACY:POS-PROPN'] gift:['SPACY:POS-NOUN'] voucher by replying with ENTER . To unsubscribe text STOP
# -------------------------
# ==================================================
# Rank 15
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
# Window size: 4
# Class: Positive
# Precision: 0.597
# Match: 313 (8.8%)
# Gain = 0.085
# Metric (global) = 0.085
# Examples ~ Class Positive:
# [MATCH]: XMAS Prize draws ! We are trying to contact U. Todays draw shows that you have won a Â£2000 prize GUARANTEED . Call 09058094565:['SPACY:POS-NUM'] from:['SPACY:POS-ADP'] land line . Valid 12hrs only
# -------------------------
# [MATCH]: Spook up your mob with a Halloween collection of a logo & pic message plus a free eerie tone , txt CARD SPOOK to 8007:['SPACY:POS-NUM'] zed 08701417012150p per:['SPACY:POS-ADP'] logo / pic
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I 'll pick you up at about 5.15pm:['SPACY:POS-NUM'] to go to:['SPACY:POS-ADP'] taunton if you still want to come .
# -------------------------
# [MATCH]: I wait 4:['SPACY:POS-NUM'] Ã¼ inside:['SPACY:POS-ADP'] da car park ...
# -------------------------
# ==================================================
# Rank 16
# Pattern: [['SPACY:POS-ADJ'], ['SPACY:POS-NUM']]
# Window size: 4
# Class: Positive
# Precision: 0.655
# Match: 258 (7.2%)
# Gain = 0.084
# Metric (global) = 0.084
# Examples ~ Class Positive:
# [MATCH]: I do n't know u and u do n't know me . Send CHAT to 86688 now and let 's find each other:['SPACY:POS-ADJ'] ! Only 150p:['SPACY:POS-NUM'] / Msg rcvd . HG / Suite342/2Lands / Row / W1J6HL LDN . 18 years or over .
# -------------------------
# [MATCH]: Do n't b floppy ... b snappy & happy ! Only gay chat service with photo upload call 08718730666 ( 10p / min ) . 2 stop our:['SPACY:POS-ADJ'] texts call 08712460324:['SPACY:POS-NUM']
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Sorry . You never hear unless you book it . One was kinda a joke -- thet were really looking for skinny white girls . The other:['SPACY:POS-ADJ'] was one:['SPACY:POS-NUM'] line -- you can only do so much on camera with that . Something like that they 're casting on the look .
# -------------------------
# [MATCH]: For real when u getting on yo ? I only need 2 more:['SPACY:POS-ADJ'] tickets and one:['SPACY:POS-NUM'] more jacket and I 'm done . I already used all my multis .
# -------------------------
# ==================================================
# Rank 17
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
# Window size: 5
# Class: Positive
# Precision: 0.649
# Match: 259 (7.3%)
# Gain = 0.083
# Metric (global) = 0.083
# Examples ~ Class Positive:
# [MATCH]: Todays:['SPACY:POS-PROPN'] Voda:['SPACY:POS-PROPN'] numbers:['SPACY:POS-NOUN'] ending with 7634 are selected to receive a Â£350 reward . If you have a match please call 08712300220 quoting claim code 7684 standard rates apply .
# -------------------------
# [MATCH]: 5p 4 alfie Moon 's Children in need song on ur mob . Tell ur m8s:['SPACY:POS-PROPN'] . Txt:['SPACY:POS-PROPN'] Tone charity:['SPACY:POS-NOUN'] to 8007 for Nokias or Poly charity for polys : zed 08701417012 profit 2 charity .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Sun ca nt come to earth but send luv as rays . cloud ca nt come to river but send luv as rain . I ca nt come to meet U , but can send my care as msg to U.:['SPACY:POS-PROPN'] Gud:['SPACY:POS-PROPN'] evng:['SPACY:POS-NOUN']
# -------------------------
# [MATCH]: Kaiez:['SPACY:POS-PROPN'] ... Enjoy:['SPACY:POS-PROPN'] ur tuition:['SPACY:POS-NOUN'] ... Gee ... Thk e second option sounds beta ... I 'll go yan jiu den msg u ...
# -------------------------
# ==================================================
# Rank 18
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.926
# Match: 121 (3.4%)
# Gain = 0.082
# Metric (global) = 0.082
# Examples ~ Class Positive:
# [MATCH]: Your free ringtone is waiting to be collected . Simply text the password " MIX:['SPACY:POS-PROPN'] " to:['SPACY:POS-ADP'] 85069:['SPACY:POS-NUM'] to verify . Get Usher and Britney . FML , PO Box 5249 , MK17 92H. 450Ppw 16
# -------------------------
# [MATCH]: No . 1 Nokia Tone 4 ur mob every week ! Just txt NOK:['SPACY:POS-PROPN'] to:['SPACY:POS-ADP'] 87021:['SPACY:POS-NUM'] . 1st Tone FREE ! so get txtin now and tell ur friends . 150p / tone . 16 reply HL 4info
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Omg:['SPACY:POS-PROPN'] if:['SPACY:POS-ADP'] its not one:['SPACY:POS-NUM'] thing its another . My cat has worms :/ when does this bad day end ?
# -------------------------
# [MATCH]: I got ta collect da:['SPACY:POS-PROPN'] car at:['SPACY:POS-ADP'] 6:['SPACY:POS-NUM'] lei .
# -------------------------
# ==================================================
# Rank 19
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]
# Window size: 4
# Class: Positive
# Precision: 0.504
# Match: 421 (11.8%)
# Gain = 0.080
# Metric (global) = 0.080
# Examples ~ Class Positive:
# [MATCH]: Will u meet ur dream partner soon ? Is ur career off 2 a flyng start ? 2 find out free , txt HORO:['SPACY:POS-PROPN'] followed by:['SPACY:POS-ADP'] ur star sign , e. g. HORO ARIES
# -------------------------
# [MATCH]: Join the UK 's horniest Dogging service and u can have sex 2nite!. Just sign up and follow the instructions . Txt:['SPACY:POS-PROPN'] ENTRY to:['SPACY:POS-ADP'] 69888 now ! Nyt . EC2A.3LP.msg@150p
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I am in escape theatre now . . Going to watch KAVALAN:['SPACY:POS-PROPN'] in:['SPACY:POS-ADP'] a few minutes
# -------------------------
# [MATCH]: TODAY is Sorry day . ! If ever i was angry with you , if ever i misbehaved or hurt you ? plz plz JUST SLAP URSELF Bcoz:['SPACY:POS-PROPN'] , Its ur:['SPACY:POS-ADP'] fault , I 'm basically GOOD
# -------------------------
# ==================================================
# Rank 20
# Pattern: [['SPACY:POS-NUM'], ['TEXT:.']]
# Window size: 4
# Class: Positive
# Precision: 0.591
# Match: 286 (8.0%)
# Gain = 0.074
# Metric (global) = 0.074
# Examples ~ Class Positive:
# [MATCH]: Sex up ur mobile with a FREE sexy pic of Jordan ! Just text BABE to 88600:['SPACY:POS-NUM'] .:['TEXT:.'] Then every wk get a sexy celeb ! PocketBabe.co.uk 4 more pics . 16 Â£3/wk 087016248
# -------------------------
# [MATCH]: For ur chance to win Â£250 cash every wk TXT : PLAY to 83370:['SPACY:POS-NUM'] .:['TEXT:.'] T's&C 's www.music-trivia.net custcare 08715705022 , 1x150p / wk .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Hi i wo n't b ard 4:['SPACY:POS-NUM'] christmas .:['TEXT:.'] But do enjoy n merry x'mas .
# -------------------------
# [MATCH]: Okay ... I booked all already ... Including the one:['SPACY:POS-NUM'] at bugis .:['TEXT:.']
# -------------------------
# ==================================================
# Rank 21
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-VERB']]
# Window size: 4
# Class: Positive
# Precision: 0.525
# Match: 360 (10.1%)
# Gain = 0.073
# Metric (global) = 0.073
# Examples ~ Class Positive:
# [MATCH]: You have won a guaranteed Â£200 award or even Â£1000 cashto claim UR award call free on 08000407165 ( 18 + ) 2:['SPACY:POS-NUM'] stop:['SPACY:POS-VERB'] getstop on 88222 PHP
# -------------------------
# [MATCH]: I do n't know u and u do n't know me . Send CHAT to 86688:['SPACY:POS-NUM'] now and let:['SPACY:POS-VERB'] 's find each other ! Only 150p / Msg rcvd . HG / Suite342/2Lands / Row / W1J6HL LDN . 18 years or over .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: hi baby i m sat on the bloody bus at the mo and i wo nt be home until about 7:30:['SPACY:POS-NUM'] wanna do:['SPACY:POS-VERB'] somethin later ? call me later ortxt back jess xx
# -------------------------
# [MATCH]: Sorry about earlier . Putting out fires . Are you around to talk after 9:['SPACY:POS-NUM'] ? Or do:['SPACY:POS-VERB'] you actually have a life , lol !
# -------------------------
# ==================================================
# Rank 22
# Pattern: [['SPACY:POS-NOUN'], ['TEXT:call']]
# Window size: 4
# Class: Positive
# Precision: 0.791
# Match: 153 (4.3%)
# Gain = 0.073
# Metric (global) = 0.073
# Examples ~ Class Positive:
# [MATCH]: PRIVATE ! Your 2003 Account Statement for shows 800 un - redeemed S. I. M. points:['SPACY:POS-NOUN'] . Call:['TEXT:call'] 08715203694 Identifier Code : 40533 Expires 31/10/04
# -------------------------
# [MATCH]: 88800 and 89034 are premium phone:['SPACY:POS-NOUN'] services call:['TEXT:call'] 08718711108
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I don wake since . I checked that stuff and saw that its true no available spaces:['SPACY:POS-NOUN'] . Pls call:['TEXT:call'] the embassy or send a mail to them .
# -------------------------
# [MATCH]: Yun ah.the ubi one say if Ã¼:['SPACY:POS-NOUN'] wan call:['TEXT:call'] by tomorrow.call 67441233 look for irene.ere only got bus8,22,65,61,66,382 . Ubi cres , ubi tech park.6ph for 1st 5wkg days . Ã¨n
# -------------------------
# ==================================================
# Rank 23
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.843
# Match: 127 (3.6%)
# Gain = 0.069
# Metric (global) = 0.069
# Examples ~ Class Positive:
# [MATCH]: PRIVATE ! Your 2003 Account Statement for 07815296484 shows 800 un - redeemed S.I.M.:['SPACY:POS-PROPN'] points:['SPACY:POS-NOUN'] . Call 08718738001:['SPACY:POS-NUM'] Identifier Code 41782 Expires 18/11/04
# -------------------------
# [MATCH]: You have an important customer service announcement from PREMIER:['SPACY:POS-PROPN'] . Call:['SPACY:POS-NOUN'] FREEPHONE 0800:['SPACY:POS-NUM'] 542 0578 now !
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: As per your request ' Melle Melle ( Oru Minnaminunginte Nurungu Vettam ) ' has been set as your callertune for all Callers:['SPACY:POS-PROPN'] . Press:['SPACY:POS-NOUN'] * 9:['SPACY:POS-NUM'] to copy your friends Callertune
# -------------------------
# [MATCH]: HEY THERE BABE , HOW U DOIN ? WOT:['SPACY:POS-PROPN'] U:['SPACY:POS-NOUN'] UP 2:['SPACY:POS-NUM'] 2NITE LOVE ANNIE X.
# -------------------------
# ==================================================
# Rank 24
# Pattern: [['SPACY:POS-VERB'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Negative
# Precision: 0.585
# Match: 556 (15.6%)
# Gain = 0.068
# Metric (global) = 0.068
# Examples ~ Class Negative:
# [MATCH]: Life is more strict than teacher ... Bcoz Teacher teaches lesson & amp ; then conducts exam , But Life first conducts:['SPACY:POS-VERB'] Exam:['SPACY:POS-PROPN'] & amp ; then teaches Lessons . Happy morning . . .
# -------------------------
# [MATCH]: The Xmas story is peace .. The Xmas msg is love .. The Xmas miracle is:['SPACY:POS-VERB'] jesus:['SPACY:POS-PROPN'] .. Hav a blessed month ahead & amp ; wish U Merry Xmas ...
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Last Chance ! Claim ur Â£150 worth of discount vouchers today ! Text SHOP to 85023 now ! SavaMob , offers:['SPACY:POS-VERB'] mobile ! T:['SPACY:POS-PROPN'] Cs SavaMob POBOX84 , M263UZ . Â£3.00 Sub . 16
# -------------------------
# [MATCH]: Hi babe:['SPACY:POS-VERB'] its Chloe:['SPACY:POS-PROPN'] , how r u ? I was smashed on saturday night , it was great ! How was your weekend ? U been missing me ? SP visionsms.com Text stop to stop 150p / text
# -------------------------
# ==================================================
# Rank 25
# Pattern: [['TEXT:i']]
# Window size: 3
# Class: Negative
# Precision: 0.983
# Match: 1327 (37.2%)
# Gain = 0.067
# Metric (global) = 0.067
# Examples ~ Class Negative:
# [MATCH]: I:['TEXT:i'] place all ur points on e cultures module already .
# -------------------------
# [MATCH]: If I:['TEXT:i'] get there before you after your ten billion calls and texts so help me god
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: accordingly . I:['TEXT:i'] repeat , just text the word ok on your mobile phone and send
# -------------------------
# [MATCH]: I:['TEXT:i'] do n't know u and u do n't know me . Send CHAT to 86688 now and let 's find each other ! Only 150p / Msg rcvd . HG / Suite342/2Lands / Row / W1J6HL LDN . 18 years or over .
# -------------------------
# ==================================================
# Rank 26
# Pattern: [['SPACY:POS-SYM']]
# Window size: 3
# Class: Positive
# Precision: 0.756
# Match: 156 (4.4%)
# Gain = 0.067
# Metric (global) = 0.067
# Examples ~ Class Positive:
# [MATCH]: YOU 07801543489 are guaranteed the latests Nokia Phone , a 40 GB iPod MP3 player or a Â£500 prize ! Txt word : COLLECT to No:83355 ! TC - LLC NY - USA 150p /:['SPACY:POS-SYM'] Mt msgrcvd18 +
# -------------------------
# [MATCH]: Ur ringtone service has changed ! 25 Free credits ! Go to club4mobiles.com to choose content now ! Stop ? txt CLUB STOP to 87070 . 150p /:['SPACY:POS-SYM'] wk Club4 PO Box1146 MK45 2WT
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Well at this right I 'm gon na have to get up and check today 's steam sales /:['SPACY:POS-SYM'] pee so text me when you want me to come get you
# -------------------------
# [MATCH]: Er yeah , i will b there at 15:26 , sorry ! Just tell me which pub /:['SPACY:POS-SYM'] cafe to sit in and come wen u can
# -------------------------
# ==================================================
# Rank 27
# Pattern: [['TEXT:free']]
# Window size: 3
# Class: Positive
# Precision: 0.748
# Match: 159 (4.5%)
# Gain = 0.067
# Metric (global) = 0.067
# Examples ~ Class Positive:
# [MATCH]: Welcome to UK - mobile - date this msg is FREE:['TEXT:free'] giving you free calling to 08719839835 . Future mgs billed at 150p daily . To cancel send " go stop " to 89123
# -------------------------
# [MATCH]: Do you want a New Nokia 3510i colour phone DeliveredTomorrow ? With 300 free:['TEXT:free'] minutes to any mobile + 100 free texts + Free Camcorder reply or call 08000930705
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Sir , i am waiting for your call , once free:['TEXT:free'] please call me .
# -------------------------
# [MATCH]: Indians r poor but India is not a poor country . Says one of the swiss bank directors . He says that " & lt;#&gt ;   lac crore " of Indian money is deposited in swiss banks which can be used for ' taxless ' budget for   & lt;#&gt ;   yrs . Can give   & lt;#&gt ;   crore jobs to all Indians . From any village to Delhi 4 lane roads . Forever free:['TEXT:free'] power suply to more than   & lt;#&gt ;   social projects . Every citizen can get monthly   & lt;#&gt ; /- for   & lt;#&gt ;   yrs . No need of World Bank & amp ; IMF loan . Think how our money is blocked by rich politicians . We have full rights against corrupt politicians . Itna forward karo ki pura INDIA padhe.g.m . "
# -------------------------
# ==================================================
# Rank 28
# Pattern: [['TEXT:txt']]
# Window size: 3
# Class: Positive
# Precision: 0.938
# Match: 96 (2.7%)
# Gain = 0.067
# Metric (global) = 0.067
# Examples ~ Class Positive:
# [MATCH]: Get the official ENGLAND poly ringtone or colour flag on yer mobile for tonights game ! Text TONE or FLAG to 84199 . Optout txt:['TEXT:txt'] ENG STOP Box39822 W111WX Â£1.50
# -------------------------
# [MATCH]: FREE for 1st week ! No1 Nokia tone 4 ur mobile every week just txt:['TEXT:txt'] NOKIA to 8077 Get txting and tell ur mates . www.getzed.co.uk POBox 36504 W45WQ 16 + norm150p / tone
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Hello darlin i ve finished college now so txt:['TEXT:txt'] me when u finish if u can love Kate xxx
# -------------------------
# [MATCH]: On the road so ca nt txt:['TEXT:txt']
# -------------------------
# ==================================================
# Rank 29
# Pattern: [['SPACY:POS-VERB', 'TEXT:call']]
# Window size: 3
# Class: Positive
# Precision: 0.591
# Match: 257 (7.2%)
# Gain = 0.066
# Metric (global) = 0.066
# Examples ~ Class Positive:
# [MATCH]: URGENT ! Your Mobile number has been awarded with a Â£2000 prize GUARANTEED . Call:['SPACY:POS-VERB', 'TEXT:call'] 09061790121 from land line . Claim 3030 . Valid 12hrs only 150ppm
# -------------------------
# [MATCH]: A Â£400 XMAS REWARD IS WAITING FOR YOU ! Our computer has randomly picked you from our loyal mobile customers to receive a Â£400 reward . Just call:['SPACY:POS-VERB', 'TEXT:call'] 09066380611
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Nothing but we jus tot u would ask cos u ba gua ... But we went mt faber yest ... Yest jus went out already mah so today not going out ... Jus call:['SPACY:POS-VERB', 'TEXT:call'] lor ...
# -------------------------
# [MATCH]: Ãœ ready then call:['SPACY:POS-VERB', 'TEXT:call'] me ...
# -------------------------
# ==================================================
# Rank 30
# Pattern: [['SPACY:POS-NOUN'], ['TEXT:to']]
# Window size: 4
# Class: Negative
# Precision: 0.591
# Match: 552 (15.5%)
# Gain = 0.065
# Metric (global) = 0.065
# Examples ~ Class Negative:
# [MATCH]: Plz note : if anyone calling from a mobile Co. & amp ; asks u:['SPACY:POS-NOUN'] to:['TEXT:to'] type # & lt;#&gt ;   or # & lt;#&gt ; . Do not do so . Disconnect the call , coz it iz an attempt of ' terrorist ' to make use of the sim card no . Itz confirmd by nokia n motorola n has been verified by CNN IBN .
# -------------------------
# [MATCH]: As per your request ' Maangalyam ( Alaipayuthe ) ' has been set as your callertune for all Callers . Press:['SPACY:POS-NOUN'] * 9 to:['TEXT:to'] copy your friends Callertune
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Congratulations ur awarded either Â£500 of CD gift vouchers & Free entry 2 our Â£100 weekly draw txt MUSIC:['SPACY:POS-NOUN'] to:['TEXT:to'] 87066 TnCs www . Ldew.com 1 win150ppmx3age16
# -------------------------
# [MATCH]: Free entry in 2 a weekly comp for a chance:['SPACY:POS-NOUN'] to:['TEXT:to'] win an ipod . Txt POD to 80182 to get entry ( std txt rate ) T&C 's apply 08452810073 for details 18 +
# -------------------------
# ==================================================
# Rank 31
# Pattern: [['TEXT:claim']]
# Window size: 3
# Class: Positive
# Precision: 1.000
# Match: 77 (2.2%)
# Gain = 0.064
# Metric (global) = 0.064
# Examples ~ Class Positive:
# [MATCH]: + 123 Congratulations - in this week 's competition draw u have won the Â£1450 prize to claim:['TEXT:claim'] just call 09050002311 b4280703 . T&Cs / stop SMS 08718727868 . Over 18 only 150ppm
# -------------------------
# [MATCH]: Last Chance ! Claim:['TEXT:claim'] ur Â£150 worth of discount vouchers today ! Text SHOP to 85023 now ! SavaMob , offers mobile ! T Cs SavaMob POBOX84 , M263UZ . Â£3.00 Sub . 16
# -------------------------
# Counterexamples ~ Not class Positive:
#
# ==================================================
# Rank 32
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-ADP', 'TEXT:to']]
# Window size: 4
# Class: Positive
# Precision: 0.592
# Match: 250 (7.0%)
# Gain = 0.064
# Metric (global) = 0.064
# Examples ~ Class Positive:
# [MATCH]: Email AlertFrom : Jeri StewartSize : 2KBSubject : Low - cost prescripiton:['SPACY:POS-NOUN'] drvgsTo listen to:['TEXT:to', 'SPACY:POS-ADP'] email call 123
# -------------------------
# [MATCH]: SMS . ac sun0819 posts HELLO:"You seem cool , wanted to say hi . HI ! ! ! " Stop ? Send STOP:['SPACY:POS-NOUN'] to:['TEXT:to', 'SPACY:POS-ADP'] 62468
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I 'm taking derek & amp ; taylor:['SPACY:POS-NOUN'] to:['TEXT:to', 'SPACY:POS-ADP'] walmart , if I 'm not back by the time you 're done just leave the mouse on my desk and I 'll text you when priscilla 's ready
# -------------------------
# [MATCH]: I am on the way:['SPACY:POS-NOUN'] to:['TEXT:to', 'SPACY:POS-ADP'] tirupur .
# -------------------------
# ==================================================
# Rank 33
# Pattern: [['TEXT:!']]
# Window size: 3
# Class: Negative
# Precision: 0.602
# Match: 575 (16.1%)
# Gain = 0.063
# Metric (global) = 0.063
# Examples ~ Class Negative:
# [MATCH]: I m sorry bout last nite it wasnÂ’t ur fault it was me , spouse it was pmt or sumthin !:['TEXT:!'] U 4give me ? I think u shldxxxx
# -------------------------
# [MATCH]: Good afternoon sunshine !:['TEXT:!'] How dawns that day ? Are we refreshed and happy to be alive ? Do we breathe in the air and smile ? I think of you , my love ... As always
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Urgent !:['TEXT:!'] Please call 09061213237 from a landline . Â£5000 cash or a 4 * holiday await collection . T & Cs SAE PO Box 177 M227XY . 16 +
# -------------------------
# [MATCH]: Congrats !:['TEXT:!'] 1 year special cinema pass for 2 is yours . call 09061209465 now ! C Suprman V , Matrix3 , StarWars3 , etc all 4 FREE ! bx420-ip4 - 5we . 150pm . Do nt miss out !
# -------------------------
# ==================================================
# Rank 34
# Pattern: [['TEXT:.'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.539
# Match: 297 (8.3%)
# Gain = 0.062
# Metric (global) = 0.062
# Examples ~ Class Positive:
# [MATCH]: Urgent UR awarded a complimentary trip to EuroDisinc Trav , Aco&Entry41 Or Â£1000 . To claim txt DIS to 87121 18 + 6*Â£1.50(moreFrmMob .:['TEXT:.'] ShrAcomOrSglSuplt)10:['SPACY:POS-PROPN'] , LS1 3AJ
# -------------------------
# [MATCH]: Had your contract mobile 11 Mnths ? Latest Motorola , Nokia etc . all FREE ! Double Mins & Text on Orange tariffs .:['TEXT:.'] TEXT:['SPACY:POS-PROPN'] YES for callback , no to remove from records .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Missed your call cause I was yelling at scrappy .:['TEXT:.'] Miss:['SPACY:POS-PROPN'] u. Ca n't wait for u to come home . I 'm so lonely today .
# -------------------------
# [MATCH]: She is our sister .. She belongs 2 our family .. She is d hope of tomorrow .. Pray 4 her , who was fated 4 d Shoranur train incident . Lets hold our hands together & amp ; fuelled by love & amp ; concern prior 2 her grief & amp ; pain . Pls join in dis chain & amp ; pass it .:['TEXT:.'] STOP VIOLENCE AGAINST:['SPACY:POS-PROPN'] WOMEN .
# -------------------------
# ==================================================
# Rank 35
# Pattern: [['SPACY:POS-PROPN'], ['TEXT:.']]
# Window size: 4
# Class: Positive
# Precision: 0.522
# Match: 312 (8.7%)
# Gain = 0.061
# Metric (global) = 0.061
# Examples ~ Class Positive:
# [MATCH]: You have won a Nokia:['SPACY:POS-PROPN'] 7250i .:['TEXT:.'] This is what you get when you win our FREE auction . To take part send Nokia to 86021 now . HG / Suite342/2Lands Row / W1JHL 16 +
# -------------------------
# [MATCH]: Sunshine Quiz ! Win a super Sony DVD recorder if you canname the capital of Australia ? Text MQUIZ:['SPACY:POS-PROPN'] to 82277 .:['TEXT:.'] B
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Congratulations ore mo owo re wa:['SPACY:POS-PROPN'] .:['TEXT:.'] Enjoy it and i wish you many happy moments to and fro wherever you go
# -------------------------
# [MATCH]: Mark:['SPACY:POS-PROPN'] works tomorrow .:['TEXT:.'] He gets out at 5 . His work is by your house so he can meet u afterwards .
# -------------------------
# ==================================================
# Rank 36
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 5
# Class: Positive
# Precision: 0.624
# Match: 213 (6.0%)
# Gain = 0.061
# Metric (global) = 0.061
# Examples ~ Class Positive:
# [MATCH]: Congratulations U can claim 2 VIP row:['SPACY:POS-NOUN'] A Tickets:['SPACY:POS-PROPN'] 2 C:['SPACY:POS-PROPN'] Blu in concert in November or Blu gift guaranteed Call 09061104276 to claim TS&Cs www.smsco.net costÂ£3.75max
# -------------------------
# [MATCH]: ( Bank of Granite issues:['SPACY:POS-NOUN'] Strong:['SPACY:POS-PROPN'] - Buy:['SPACY:POS-PROPN'] ) EXPLOSIVE PICK FOR OUR MEMBERS * * * * * UP OVER 300 % * * * * * * * * * * * Nasdaq Symbol CDGT That is a $ 5.00 per ..
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: She is our sister .. She belongs 2 our family .. She is d hope of tomorrow .. Pray 4 her , who was fated 4 d Shoranur train incident . Lets hold our hands together & amp ; fuelled by love & amp ; concern prior 2 her grief & amp ; pain . Pls join in dis chain & amp ; pass it . STOP:['SPACY:POS-NOUN'] VIOLENCE AGAINST:['SPACY:POS-PROPN'] WOMEN:['SPACY:POS-PROPN'] .
# -------------------------
# [MATCH]: " BOO BABE ! U ENJOYIN YOURJOB ? U SEEMED 2 B:['SPACY:POS-NOUN'] GETTIN:['SPACY:POS-PROPN'] ON WELL HUNNY!HOPE:['SPACY:POS-PROPN'] URE OK?TAKE CARE & IÂ’LLSPEAK 2U SOONLOTS OF LOVEME XXXX . "
# -------------------------
# ==================================================
# Rank 37
# Pattern: [['TEXT:mobile']]
# Window size: 3
# Class: Positive
# Precision: 0.942
# Match: 86 (2.4%)
# Gain = 0.060
# Metric (global) = 0.060
# Examples ~ Class Positive:
# [MATCH]: Today 's Offer ! Claim ur Â£150 worth of discount vouchers ! Text YES to 85023 now ! SavaMob , member offers mobile:['TEXT:mobile'] ! T Cs 08717898035 . Â£3.00 Sub . 16 . Unsub reply X
# -------------------------
# [MATCH]: FREE MSG : We billed your mobile:['TEXT:mobile'] number by mistake from shortcode 83332.Please call 08081263000 to have charges refunded . This call will be free from a BT landline
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Actually , my mobile:['TEXT:mobile'] is full of msg . And i m doing a work online , where i need to send them   & lt;#&gt ;   sent msg i wil explain u later .
# -------------------------
# [MATCH]: Plz note : if anyone calling from a mobile:['TEXT:mobile'] Co. & amp ; asks u to type # & lt;#&gt ;   or # & lt;#&gt ; . Do not do so . Disconnect the call , coz it iz an attempt of ' terrorist ' to make use of the sim card no . Itz confirmd by nokia n motorola n has been verified by CNN IBN .
# -------------------------
# ==================================================
# Rank 38
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
# Window size: 5
# Class: Positive
# Precision: 0.591
# Match: 235 (6.6%)
# Gain = 0.060
# Metric (global) = 0.060
# Examples ~ Class Positive:
# [MATCH]: U can WIN Â£100 of Music Gift Vouchers every week starting NOW Txt the word:['SPACY:POS-NOUN'] DRAW:['SPACY:POS-NOUN'] to 87066 TsCs:['SPACY:POS-PROPN'] www.ldew.com SkillGame,1Winaweek , age16.150ppermessSubscription
# -------------------------
# [MATCH]: I want some cock ! My hubby 's away , I need a real man 2 satisfy me . Txt WIFE to 89938 for no strings:['SPACY:POS-NOUN'] action:['SPACY:POS-NOUN'] . ( Txt:['SPACY:POS-PROPN'] STOP 2 end , txt rec Â£1.50ea . OTBox 731 LA1 7WS . )
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Total video converter free download:['SPACY:POS-NOUN'] type:['SPACY:POS-NOUN'] this in google:['SPACY:POS-PROPN'] search : )
# -------------------------
# [MATCH]: Smile in Pleasure Smile in Pain Smile when trouble pours like Rain:['SPACY:POS-NOUN'] Smile:['SPACY:POS-NOUN'] when sum1 Hurts:['SPACY:POS-PROPN'] U Smile becoz SOMEONE still Loves to see u Smiling ! !
# -------------------------
# ==================================================
# Rank 39
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]
# Window size: 5
# Class: Positive
# Precision: 0.739
# Match: 142 (4.0%)
# Gain = 0.058
# Metric (global) = 0.058
# Examples ~ Class Positive:
# [MATCH]: URGENT ! We are trying to contact U.:['SPACY:POS-PROPN'] Todays:['SPACY:POS-PROPN'] draw shows that:['SPACY:POS-ADP'] you have won a Â£2000 prize GUARANTEED . Call 09066358361 from land line . Claim Y87 . Valid 12hrs only
# -------------------------
# [MATCH]: URGENT ! Your mobile was awarded a Â£1,500:['SPACY:POS-PROPN'] Bonus:['SPACY:POS-PROPN'] Caller Prize on:['SPACY:POS-ADP'] 27/6/03 . Our final attempt 2 contact U ! Call 08714714011
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Dear friends , sorry for the late information . Today is the birthday of our loving Ar:['SPACY:POS-PROPN'] . Praveesh:['SPACY:POS-PROPN'] . for:['SPACY:POS-ADP'] more details log on to face book and see . Its his number + & lt;#&gt ; . Do nt miss a delicious treat .
# -------------------------
# [MATCH]: Thank You for calling . Forgot to say Happy:['SPACY:POS-PROPN'] Onam:['SPACY:POS-PROPN'] to:['SPACY:POS-ADP'] you Sirji . I am fine here and remembered you when i met an insurance person . Meet You in Qatar Insha Allah . Rakhesh , ex Tata AIG who joined TISSCO , Tayseer .
# -------------------------
# ==================================================
# Rank 40
# Pattern: [['SPACY:POS-ADJ'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Negative
# Precision: 0.530
# Match: 368 (10.3%)
# Gain = 0.057
# Metric (global) = 0.057
# Examples ~ Class Negative:
# [MATCH]: Edison has rightly said , " A fool can ask more questions than a wise man can answer " Now you know why all of us are speechless:['SPACY:POS-ADJ'] during ViVa:['SPACY:POS-PROPN'] .. GM , GN , GE , GNT:- )
# -------------------------
# [MATCH]: â€:['SPACY:POS-ADJ'] ¦:['SPACY:POS-PROPN'] and donâ€˜t worry weâ€˜ll have finished by march â€ ¦ ish !
# -------------------------
# Counterexamples ~ Not class Negative:
# [MATCH]: Hi if ur lookin 4 saucy daytime fun wiv busty married woman Am free all next:['SPACY:POS-ADJ'] week Chat:['SPACY:POS-PROPN'] now 2 sort time 09099726429 JANINExx CallsÂ£1/minMobsmoreLKPOBOX177HP51FL
# -------------------------
# [MATCH]: Congrats ! 1 year special cinema pass for 2 is yours . call 09061209465 now ! C Suprman V , Matrix3 , StarWars3 , etc all 4 FREE:['SPACY:POS-ADJ'] ! bx420-ip4:['SPACY:POS-PROPN'] - 5we . 150pm . Do nt miss out !
# -------------------------
# ==================================================
# Rank 41
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-ADJ']]
# Window size: 4
# Class: Positive
# Precision: 0.559
# Match: 245 (6.9%)
# Gain = 0.055
# Metric (global) = 0.055
# Examples ~ Class Positive:
# [MATCH]: URGENT ! Your Mobile number has been awarded with a Â£2000 prize GUARANTEED . Call 09061790121 from land line . Claim 3030:['SPACY:POS-NUM'] . Valid:['SPACY:POS-ADJ'] 12hrs only 150ppm
# -------------------------
# [MATCH]: BIG BROTHER ALERT ! The computer has selected u for 10k cash or # 150:['SPACY:POS-NUM'] voucher:['SPACY:POS-ADJ'] . Call 09064018838 . NTT PO Box CRO1327 18 + BT Landline Cost 150ppm mobiles vary
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: * Will have two:['SPACY:POS-NUM'] more:['SPACY:POS-ADJ'] cartons off u and is very pleased with shelves
# -------------------------
# [MATCH]: As per your request ' Maangalyam ( Alaipayuthe ) ' has been set as your callertune for all Callers . Press * 9:['SPACY:POS-NUM'] to copy your:['SPACY:POS-ADJ'] friends Callertune
# -------------------------
# ==================================================
# Rank 42
# Pattern: [['SENTIMENT:pos'], ['SPACY:POS-PROPN']]
# Window size: 4
# Class: Positive
# Precision: 0.542
# Match: 260 (7.3%)
# Gain = 0.054
# Metric (global) = 0.054
# Examples ~ Class Positive:
# [MATCH]: Urgent ! Please call 09061743811 from landline . Your ABTA complimentary:['SENTIMENT:pos'] 4 * Tenerife:['SPACY:POS-PROPN'] Holiday or Â£5000 cash await collection SAE T&Cs Box 326 CW25WX 150ppm
# -------------------------
# [MATCH]: FREE:['SENTIMENT:pos'] GAME:['SPACY:POS-PROPN'] . Get Rayman Golf 4 FREE from the O2 Games Arcade . 1st get UR games settings . Reply POST , then save & activ8 . Press 0 key for Arcade . Termsapply
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Uncle Abbey ! Happy:['SENTIMENT:pos'] New:['SPACY:POS-PROPN'] Year . Abiola
# -------------------------
# [MATCH]: " YEH I AM DEF UP4 SOMETHING SAT , JUST GOT PAYED2DAY & I HAVBEEN GIVEN AÂ£50 PAY RISE 4MY WORK:['SENTIMENT:pos'] & HAVEBEEN:['SPACY:POS-PROPN'] MADE PRESCHOOLCO - ORDINATOR 2I AM FEELINGOOD LUV "
# -------------------------
# ==================================================
# Rank 43
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.802
# Match: 111 (3.1%)
# Gain = 0.053
# Metric (global) = 0.053
# Examples ~ Class Positive:
# [MATCH]: FREE for 1st week ! No1 Nokia tone 4 ur mobile every week just txt NOKIA to 8077 Get txting and tell ur mates . www.getzed.co.uk POBox:['SPACY:POS-NOUN'] 36504 W45WQ:['SPACY:POS-PROPN'] 16:['SPACY:POS-NUM'] + norm150p / tone
# -------------------------
# [MATCH]: from www . Applausestore.com MonthlySubscription@50p / msg max6/month:['SPACY:POS-NOUN'] T&CsC:['SPACY:POS-PROPN'] web age16:['SPACY:POS-NUM'] 2stop txt stop
# -------------------------
# Counterexamples ~ Not class Positive:
# ...
# -------------------------
# ==================================================
# Rank 88
# Pattern: [['SPACY:POS-DET'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
# Window size: 5
# Class: Positive
# Precision: 0.709
# Match: 110 (3.1%)
# Gain = 0.040
# Metric (global) = 0.040
# Examples ~ Class Positive:
# [MATCH]: YOU 07801543489 are guaranteed the:['SPACY:POS-DET'] latests Nokia:['SPACY:POS-PROPN'] Phone:['SPACY:POS-PROPN'] , a 40 GB iPod MP3 player or a Â£500 prize ! Txt word : COLLECT to No:83355 ! TC - LLC NY - USA 150p / Mt msgrcvd18 +
# -------------------------
# [MATCH]: < Forwarded from 21870000>Hi - this:['SPACY:POS-DET'] is your Mailbox:['SPACY:POS-PROPN'] Messaging:['SPACY:POS-PROPN'] SMS alert . You have 40 matches . Please call back on 09056242159 to retrieve your messages and matches cc100p / min
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Hi ! You just spoke to MANEESHA V. We 'd like to know if you were satisfied with the:['SPACY:POS-DET'] experience . Reply:['SPACY:POS-PROPN'] Toll:['SPACY:POS-PROPN'] Free with Yes or No .
# -------------------------
# [MATCH]: Christmas is An occasion that is Celebrated as a:['SPACY:POS-DET'] Reflection:['SPACY:POS-PROPN'] of UR:['SPACY:POS-PROPN'] ... Values ... , Desires ... , Affections ... &amp ; Traditions .... Have an ideal Christmas ...
# -------------------------
# ==================================================
# Rank 89
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['TEXT:.']]
# Window size: 5
# Class: Positive
# Precision: 0.678
# Match: 121 (3.4%)
# Gain = 0.040
# Metric (global) = 0.040
# Examples ~ Class Positive:
# [MATCH]: Your free ringtone is waiting to be collected . Simply text the password " MIX " to 85069 to verify . Get Usher:['SPACY:POS-PROPN'] and Britney:['SPACY:POS-PROPN'] .:['TEXT:.'] FML , PO Box 5249 , MK17 92H. 450Ppw 16
# -------------------------
# [MATCH]: Buy Space Invaders 4 a chance 2 win orig Arcade:['SPACY:POS-PROPN'] Game:['SPACY:POS-PROPN'] console .:['TEXT:.'] Press 0 for Games Arcade ( std WAP charge ) See o2.co.uk/games 4 Terms + settings . No purchase
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: R U & SAM:['SPACY:POS-PROPN'] P:['SPACY:POS-PROPN'] IN EACHOTHER .:['TEXT:.'] IF WE MEET WE CAN GO 2 MY HOUSE
# -------------------------
# [MATCH]: " CHEERS U TEX MECAUSE U WEREBORED ! YEAH OKDEN HUNNY R UIN WK SAT?SOUNDÂ ’S LIKEYOUR HAVIN GR8FUN J ! KEEP UPDAT COUNTINLOTS:['SPACY:POS-PROPN'] OF LOVEME:['SPACY:POS-PROPN'] XXXXX .:['TEXT:.'] "
# -------------------------
# ==================================================
# Rank 90
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
# Window size: 6
# Class: Positive
# Precision: 0.713
# Match: 108 (3.0%)
# Gain = 0.040
# Metric (global) = 0.040
# Examples ~ Class Positive:
# [MATCH]: * FREE * POLYPHONIC RINGTONE Text SUPER to 87131 to get your FREE POLY TONE of the week now ! 16 SN:['SPACY:POS-PROPN'] PoBox202:['SPACY:POS-PROPN'] NR31:['SPACY:POS-PROPN'] 7ZS:['SPACY:POS-NOUN'] subscription 450pw
# -------------------------
# [MATCH]: Phony Â£350:['SPACY:POS-PROPN'] award - Todays:['SPACY:POS-PROPN'] Voda:['SPACY:POS-PROPN'] numbers:['SPACY:POS-NOUN'] ending XXXX are selected to receive a Â£350 award . If you have a match please call 08712300220 quoting claim code 3100 standard rates app
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: CHEERS LOU ! YEAH WAS A GOODNITE SHAME U NEVA:['SPACY:POS-PROPN'] CAME ! C:['SPACY:POS-PROPN'] YA:['SPACY:POS-PROPN'] GAILxx:['SPACY:POS-NOUN']
# -------------------------
# [MATCH]: Thanx 4 2day ! U r a goodmate I THINK UR:['SPACY:POS-PROPN'] RITE:['SPACY:POS-PROPN'] SARY:['SPACY:POS-PROPN'] ! ASUSUAL!1 U:['SPACY:POS-NOUN'] CHEERED ME UP ! LOVE U FRANYxxxxx
# -------------------------
# ==================================================
# Rank 91
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['TEXT:.']]
# Window size: 5
# Class: Positive
# Precision: 0.621
# Match: 145 (4.1%)
# Gain = 0.039
# Metric (global) = 0.039
# Examples ~ Class Positive:
# [MATCH]: PRIVATE ! Your 2003 Account Statement for 07808 XXXXXX shows 800 un - redeemed S.:['SPACY:POS-PROPN'] I. M. points:['SPACY:POS-NOUN'] .:['TEXT:.'] Call 08719899217 Identifier Code : 41685 Expires 07/11/04
# -------------------------
# [MATCH]: PRIVATE ! Your 2003 Account Statement for 07753741225 shows 800 un - redeemed S.:['SPACY:POS-PROPN'] I. M. points:['SPACY:POS-NOUN'] .:['TEXT:.'] Call 08715203677 Identifier Code : 42478 Expires 24/10/04
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Yup:['SPACY:POS-PROPN'] next stop:['SPACY:POS-NOUN'] .:['TEXT:.']
# -------------------------
# [MATCH]: She is our sister .. She belongs 2 our family .. She is d hope of tomorrow .. Pray 4 her , who was fated 4 d Shoranur:['SPACY:POS-PROPN'] train incident:['SPACY:POS-NOUN'] .:['TEXT:.'] Lets hold our hands together & amp ; fuelled by love & amp ; concern prior 2 her grief & amp ; pain . Pls join in dis chain & amp ; pass it . STOP VIOLENCE AGAINST WOMEN .
# -------------------------
# ==================================================
# Rank 92
# Pattern: [['SENTIMENT:pos'], ['TEXT:call']]
# Window size: 4
# Class: Positive
# Precision: 0.838
# Match: 74 (2.1%)
# Gain = 0.039
# Metric (global) = 0.039
# Examples ~ Class Positive:
# [MATCH]: Santa calling ! Would your little ones like:['SENTIMENT:pos'] a call:['TEXT:call'] from Santa Xmas Eve ? Call 09077818151 to book you time . Calls1.50ppm last 3mins 30s T&C www.santacalling.com
# -------------------------
# [MATCH]: You have won a guaranteed 32000 award or maybe even Â£1000 cash to claim ur award:['SENTIMENT:pos'] call:['TEXT:call'] free on 0800 ..... ( 18 + ) . Its a legitimat efreefone number wat do u think ? ? ?
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: When you get free:['SENTIMENT:pos'] , call:['TEXT:call'] me
# -------------------------
# [MATCH]: I 'm at work:['SENTIMENT:pos'] . Please call:['TEXT:call']
# -------------------------
# ==================================================
# Rank 93
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
# Window size: 5
# Class: Positive
# Precision: 0.868
# Match: 68 (1.9%)
# Gain = 0.038
# Metric (global) = 0.038
# Examples ~ Class Positive:
# [MATCH]: No . 1:['SPACY:POS-NUM'] Nokia:['SPACY:POS-PROPN'] Tone 4:['SPACY:POS-NUM'] ur mob every week ! Just txt NOK to 87021 . 1st Tone FREE ! so get txtin now and tell ur friends . 150p / tone . 16 reply HL 4info
# -------------------------
# [MATCH]: You have won a guaranteed Â£200 award or even Â£1000 cashto claim UR award call free on 08000407165 ( 18 + ) 2 stop getstop on 88222:['SPACY:POS-NUM'] PHP:['SPACY:POS-PROPN'] . RG21 4JX:['SPACY:POS-NUM']
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: ZOE IT JUST HIT ME 2 IM FUCKING SHITIN MYSELF IL DEFO TRY MY HARDEST 2:['SPACY:POS-NUM'] CUM:['SPACY:POS-PROPN'] 2MOROW:['SPACY:POS-NUM'] LUV U MILLIONS LEKDOG
# -------------------------
# [MATCH]: Your opinion about me ? 1 . Over 2:['SPACY:POS-NUM'] . Jada:['SPACY:POS-PROPN'] 3:['SPACY:POS-NUM'] . Kusruthi 4 . Lovable 5 . Silent 6 . Spl character 7 . Not matured 8 . Stylish 9 . Simple Pls reply ..
# -------------------------
# ==================================================
# Rank 94
# Pattern: [['HYPERNYM3:symbol.n.01']]
# Window size: 3
# Class: Positive
# Precision: 0.764
# Match: 89 (2.5%)
# Gain = 0.038
# Metric (global) = 0.038
# Examples ~ Class Positive:
# [MATCH]: Please call our customer service representative on FREEPHONE 0808 145 4742 between 9am-11pm as you have WON a guaranteed Â£1000 cash or Â£5000 prize:['HYPERNYM3:symbol.n.01'] !
# -------------------------
# [MATCH]: PRIVATE ! Your 2003 Account Statement for < fone no > shows 800 un - redeemed S. I. M. points . Call 08715203656 Identifier:['HYPERNYM3:symbol.n.01'] Code : 42049 Expires 26/10/04
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: The LAY MAN ! Just to let you know you are missed and thought off . Do have a great day . And if you can send me bimbo and ugo 's numbers:['HYPERNYM3:symbol.n.01'] , ill appreciate . Safe
# -------------------------
# [MATCH]: I do n't have anybody 's number:['HYPERNYM3:symbol.n.01'] , I still have n't thought up a tactful way to ask alex
# -------------------------
# ==================================================
# Rank 95
# Pattern: [['SPACY:POS-ADP'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
# Window size: 5
# Class: Positive
# Precision: 0.543
# Match: 184 (5.2%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: sports fans - get the latest sports news str * 2 ur mobile 1 wk FREE PLUS a FREE TONE Txt SPORT ON:['SPACY:POS-ADP'] to 8007:['SPACY:POS-NUM'] www.getzed.co.uk:['SPACY:POS-NOUN'] 0870141701216 + norm 4txt/120p
# -------------------------
# [MATCH]: Talk sexy ! ! Make new friends or fall in love in the worlds most discreet text dating service . Just text VIP to:['SPACY:POS-ADP'] 83110:['SPACY:POS-NUM'] and see who:['SPACY:POS-NOUN'] you could meet .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Anything is valuable in:['SPACY:POS-ADP'] only 2:['SPACY:POS-NUM'] situations:['SPACY:POS-NOUN'] : First- Before getting it ... Second- After loosing it ...
# -------------------------
# [MATCH]: I am going to film 2day da . At:['SPACY:POS-ADP'] 6:['SPACY:POS-NUM'] pm:['SPACY:POS-NOUN'] . Sorry da .
# -------------------------
# ==================================================
# Rank 96
# Pattern: [['TEXT:!'], ['SPACY:POS-ADJ']]
# Window size: 4
# Class: Positive
# Precision: 0.648
# Match: 125 (3.5%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: Want 2 get laid tonight ? Want real Dogging locations sent direct 2 ur mob ? Join the UK 's largest Dogging Network bt Txting GRAVEL to 69888 !:['TEXT:!'] Nt . ec2a:['SPACY:POS-ADJ'] . 31p.msg@150p
# -------------------------
# [MATCH]: YES !:['TEXT:!'] The only:['SPACY:POS-ADJ'] place in town to meet exciting adult singles is now in the UK . Txt CHAT to 86688 now ! 150p / Msg .
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: I love u 2 babe !:['TEXT:!'] R u sure:['SPACY:POS-ADJ'] everything is alrite . Is he being an idiot ? Txt bak girlie
# -------------------------
# [MATCH]: Hiya . How was last night ? I 've been naughty and bought myself clothes and very little ... Ready for more shopping tho !:['TEXT:!'] What:['SPACY:POS-ADJ'] kind of time do you wanna meet ?
# -------------------------
# ==================================================
# Rank 97
# Pattern: [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
# Window size: 6
# Class: Positive
# Precision: 0.914
# Match: 58 (1.6%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: URGENT ! We are trying to contact U. Todays draw shows that you have won a Â£800:['SPACY:POS-PROPN'] prize GUARANTEED:['SPACY:POS-PROPN'] . Call:['SPACY:POS-NOUN'] 09050003091:['SPACY:POS-NUM'] from land line . Claim C52 . Valid 12hrs only
# -------------------------
# [MATCH]: PRIVATE ! Your 2003 Account Statement for shows 800 un - redeemed S. I.:['SPACY:POS-PROPN'] M.:['SPACY:POS-PROPN'] points:['SPACY:POS-NOUN'] . Call 08718738002:['SPACY:POS-NUM'] Identifier Code : 48922 Expires 21/11/04
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: 1Apple / Day = No Doctor . 1Tulsi Leaf / Day = No Cancer . 1Lemon / Day = No Fat . 1Cup Milk / day = No Bone Problms 3 Litres Watr / Day = No Diseases:['SPACY:POS-PROPN'] Snd:['SPACY:POS-PROPN'] ths:['SPACY:POS-NOUN'] 2:['SPACY:POS-NUM'] Whom U Care .. :- )
# -------------------------
# [MATCH]: HIYA:['SPACY:POS-PROPN'] STU:['SPACY:POS-PROPN'] WOT:['SPACY:POS-NOUN'] U UP 2.IM:['SPACY:POS-NUM'] IN SO MUCH TRUBLE AT HOME AT MOMENT EVONE HATES ME EVEN U ! WOT THE HELL AV I DONE NOW ? Y WONT U JUST TELL ME TEXT BCK PLEASE LUV DAN
# -------------------------
# ==================================================
# Rank 98
# Pattern: [['SPACY:POS-NUM'], ['SPACY:POS-DET']]
# Window size: 4
# Class: Positive
# Precision: 0.634
# Match: 131 (3.7%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: Free entry in 2:['SPACY:POS-NUM'] a:['SPACY:POS-DET'] weekly comp for a chance to win an ipod . Txt POD to 80182 to get entry ( std txt rate ) T&C 's apply 08452810073 for details 18 +
# -------------------------
# [MATCH]: Want a new Video Phone ? 750:['SPACY:POS-NUM'] anytime any:['SPACY:POS-DET'] network mins ? Half price line rental free text for 3 months ? Reply or call 08000930705 for free delivery
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: One:['SPACY:POS-NUM'] of the:['SPACY:POS-DET'] joys in lifeis waking up each daywith thoughts that somewhereSomeone cares enough tosend a warm morning greeting .. -
# -------------------------
# [MATCH]: Solve d Case : A Man Was Found Murdered On   & lt;DECIMAL&gt ; . & lt;#&gt ;   AfterNoon . 1,His wife called Police . 2,Police questioned everyone . 3,Wife : Sir , I was sleeping , when the murder took place . 4.Cook : I was cooking . 5.Gardener : I was picking vegetables . 6.House - Maid : I went 2 d post office . 7.Children : We went 2 play . 8.Neighbour : We went 2:['SPACY:POS-NUM'] a:['SPACY:POS-DET'] marriage . Police arrested d murderer Immediately . Who 's It ? Reply With Reason , If U r Brilliant .
# -------------------------
# ==================================================
# Rank 99
# Pattern: [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['TEXT:to']]
# Window size: 5
# Class: Positive
# Precision: 0.565
# Match: 168 (4.7%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: Hey Boys . Want hot XXX pics sent direct 2 ur phone:['SPACY:POS-NOUN'] ? Txt PORN:['SPACY:POS-NOUN'] to:['TEXT:to'] 69855 , 24Hrs free and then just 50p per day . To stop text STOPBCM SF WC1N3XX
# -------------------------
# [MATCH]: Final Chance ! Claim ur Â£150 worth of discount vouchers today:['SPACY:POS-NOUN'] ! Text:['SPACY:POS-NOUN'] YES to:['TEXT:to'] 85023 now ! SavaMob , member offers mobile ! T Cs SavaMob POBOX84 , M263UZ . Â£3.00 Subs 16
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: Plz note : if anyone calling from a mobile Co. & amp:['SPACY:POS-NOUN'] ; asks u:['SPACY:POS-NOUN'] to:['TEXT:to'] type # & lt;#&gt ;   or # & lt;#&gt ; . Do not do so . Disconnect the call , coz it iz an attempt of ' terrorist ' to make use of the sim card no . Itz confirmd by nokia n motorola n has been verified by CNN IBN .
# -------------------------
# [MATCH]: Hey loverboy ! I love you ! ! I had to tell ... I look at your picture:['SPACY:POS-NOUN'] and ache:['SPACY:POS-NOUN'] to:['TEXT:to'] feel you between my legs ... Fuck I want you ... I need you ... I crave you .
# -------------------------
# ==================================================
# Rank 100
# Pattern: [['SENTIMENT:pos'], ['SPACY:POS-DET'], ['SPACY:POS-PROPN']]
# Window size: 5
# Class: Positive
# Precision: 0.797
# Match: 79 (2.2%)
# Gain = 0.037
# Metric (global) = 0.037
# Examples ~ Class Positive:
# [MATCH]: Santa calling ! Would your little ones like:['SENTIMENT:pos'] a:['SPACY:POS-DET'] call from Santa:['SPACY:POS-PROPN'] Xmas Eve ? Call 09077818151 to book you time . Calls1.50ppm last 3mins 30s T&C www.santacalling.com
# -------------------------
# [MATCH]: You have won:['SENTIMENT:pos'] a:['SPACY:POS-DET'] Nokia:['SPACY:POS-PROPN'] 7250i . This is what you get when you win our FREE auction . To take part send Nokia to 86021 now . HG / Suite342/2Lands Row / W1JHL 16 +
# -------------------------
# Counterexamples ~ Not class Positive:
# [MATCH]: To the wonderful Okors , have a great month . We cherish you guys and wish you well:['SENTIMENT:pos'] each:['SPACY:POS-DET'] day . MojiBiola:['SPACY:POS-PROPN']
# -------------------------
# [MATCH]: Love:['SENTIMENT:pos'] that:['SPACY:POS-DET'] holiday Monday:['SPACY:POS-PROPN'] feeling even if I have to go to the dentists in an hour
# -------------------------
# ==================================================

# %%
print(f'  #    class Cov(%)    Prec    Gain    Pattern')
for idx, p in enumerate(the_patterns):
    print(f'{idx+1:>3} {p.support_class}   {round(p.coverage*100, 1):>4}   {p.precision:.3f}   {p.metric:.3f}    {p.get_pattern_id()}')
# Out:
#   #    class Cov(%)    Prec    Gain    Pattern
#   1 Negative   26.2   0.526   0.223    [['SPACY:POS-NUM']]
#   2 Positive    8.9   0.806   0.175    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#   3 Positive    5.1   0.984   0.152    [['TEXT:call'], ['SPACY:POS-NUM']]
#   4 Positive   14.5   0.579   0.148    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#   5 Positive   11.8   0.613   0.129    [['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
#   6 Positive    6.8   0.811   0.129    [['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
#   7 Negative   18.1   0.526   0.119    [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
#   8 Positive    5.4   0.856   0.114    [['TEXT:to'], ['SPACY:POS-NUM']]
#   9 Negative   37.8   0.690   0.112    [['SPACY:POS-PROPN']]
#  10 Positive    7.6   0.702   0.105    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  11 Positive    7.1   0.722   0.104    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  12 Positive    5.7   0.797   0.101    [['TEXT:.'], ['SPACY:POS-NUM']]
#  13 Positive    6.7   0.735   0.100    [['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
#  14 Negative   20.0   0.585   0.095    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  15 Positive    8.8   0.597   0.085    [['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
#  16 Positive    7.2   0.655   0.084    [['SPACY:POS-ADJ'], ['SPACY:POS-NUM']]
#  17 Positive    7.3   0.649   0.083    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  18 Positive    3.4   0.926   0.082    [['SPACY:POS-PROPN'], ['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
#  19 Positive   11.8   0.504   0.080    [['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]
#  20 Positive    8.0   0.591   0.074    [['SPACY:POS-NUM'], ['TEXT:.']]
#  21 Positive   10.1   0.525   0.073    [['SPACY:POS-NUM'], ['SPACY:POS-VERB']]
#  22 Positive    4.3   0.791   0.073    [['SPACY:POS-NOUN'], ['TEXT:call']]
#  23 Positive    3.6   0.843   0.069    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  24 Negative   15.6   0.585   0.068    [['SPACY:POS-VERB'], ['SPACY:POS-PROPN']]
#  25 Negative   37.2   0.983   0.067    [['TEXT:i']]
#  26 Positive    4.4   0.756   0.067    [['SPACY:POS-SYM']]
#  27 Positive    4.5   0.748   0.067    [['TEXT:free']]
#  28 Positive    2.7   0.938   0.067    [['TEXT:txt']]
#  29 Positive    7.2   0.591   0.066    [['SPACY:POS-VERB', 'TEXT:call']]
#  30 Negative   15.5   0.591   0.065    [['SPACY:POS-NOUN'], ['TEXT:to']]
#  31 Positive    2.2   1.000   0.064    [['TEXT:claim']]
#  32 Positive    7.0   0.592   0.064    [['SPACY:POS-NOUN'], ['SPACY:POS-ADP', 'TEXT:to']]
#  33 Negative   16.1   0.602   0.063    [['TEXT:!']]
#  34 Positive    8.3   0.539   0.062    [['TEXT:.'], ['SPACY:POS-PROPN']]
#  35 Positive    8.7   0.522   0.061    [['SPACY:POS-PROPN'], ['TEXT:.']]
#  36 Positive    6.0   0.624   0.061    [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  37 Positive    2.4   0.942   0.060    [['TEXT:mobile']]
#  38 Positive    6.6   0.591   0.060    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['SPACY:POS-PROPN']]
#  39 Positive    4.0   0.739   0.058    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-ADP']]
#  40 Negative   10.3   0.530   0.057    [['SPACY:POS-ADJ'], ['SPACY:POS-PROPN']]
#  41 Positive    6.9   0.559   0.055    [['SPACY:POS-NUM'], ['SPACY:POS-ADJ']]
#  42 Positive    7.3   0.542   0.054    [['SENTIMENT:pos'], ['SPACY:POS-PROPN']]
#  43 Positive    3.1   0.802   0.053    [['SPACY:POS-NOUN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  44 Positive    5.3   0.621   0.053    [['SPACY:POS-VERB'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  45 Positive    1.9   0.985   0.053    [['TEXT:.'], ['TEXT:call'], ['SPACY:POS-NUM']]
#  46 Positive    2.2   0.923   0.052    [['HYPERNYM3:communication.n.02'], ['SPACY:POS-NUM']]
#  47 Positive    2.2   0.922   0.051    [['HYPERNYM3:win.v.01', 'SENTIMENT:pos']]
#  48 Negative   13.6   0.601   0.051    [['SPACY:POS-ADP', 'TEXT:to']]
#  49 Positive    2.0   0.957   0.051    [['TEXT:call'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
#  50 Positive    3.1   0.784   0.051    [['TEXT:.'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  51 Positive    7.5   0.521   0.051    [['SPACY:POS-DET'], ['SPACY:POS-PROPN']]
#  52 Positive    3.8   0.716   0.050    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
#  53 Positive    6.0   0.575   0.050    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-VERB']]
#  54 Negative   10.6   0.559   0.050    [['SPACY:POS-ADP'], ['SPACY:POS-PROPN']]
#  55 Positive    4.0   0.690   0.049    [['SPACY:POS-PROPN'], ['TEXT:to']]
#  56 Positive    2.2   0.909   0.049    [['HYPERNYM3:cost.n.01']]
#  57 Negative   65.0   0.804   0.049    [['SPACY:POS-ADP']]
#  58 Positive    2.2   0.899   0.049    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  59 Negative   54.1   0.785   0.049    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN']]
#  60 Negative   12.1   0.586   0.049    [['HYPERNYM3:message.n.02']]
#  61 Positive    5.1   0.613   0.049    [['SPACY:POS-NOUN'], ['HYPERNYM3:message.n.02']]
#  62 Negative   30.8   0.725   0.048    [['TEXT:to']]
#  63 Positive    2.5   0.843   0.048    [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  64 Positive    2.4   0.851   0.047    [['TEXT:!'], ['SPACY:POS-NUM']]
#  65 Positive    1.6   1.000   0.046    [['TEXT:prize']]
#  66 Positive    2.2   0.873   0.046    [['HYPERNYM3:message.n.02'], ['SPACY:POS-NUM']]
#  67 Negative    8.6   0.533   0.045    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NOUN']]
#  68 Negative   10.8   0.580   0.044    [['HYPERNYM3:communication.n.02']]
#  69 Positive    1.6   0.982   0.044    [['HYPERNYM3:call.v.28'], ['SPACY:POS-NUM']]
#  70 Positive    2.0   0.890   0.044    [['SPACY:POS-PROPN'], ['TEXT:call']]
#  71 Positive    2.9   0.765   0.044    [['TEXT:call'], ['SPACY:POS-ADP']]
#  72 Positive    2.4   0.816   0.043    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
#  73 Negative   15.9   0.649   0.043    [['TEXT:.'], ['SPACY:POS-NOUN']]
#  74 Negative   39.6   0.759   0.043    [['SPACY:POS-NOUN'], ['SPACY:POS-ADP']]
#  75 Positive    1.5   0.982   0.043    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['TEXT:to'], ['SPACY:POS-NUM']]
#  76 Positive    4.8   0.594   0.042    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-ADP']]
#  77 Negative   39.9   0.761   0.042    [['SENTIMENT:pos']]
#  78 Positive    2.2   0.838   0.042    [['SPACY:POS-ADP'], ['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
#  79 Positive    1.9   0.909   0.042    [['TEXT:to'], ['SPACY:POS-NUM'], ['TEXT:.']]
#  80 Positive    4.0   0.639   0.042    [['SPACY:POS-ADJ'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  81 Positive    1.7   0.934   0.041    [['SPACY:POS-NUM'], ['TEXT:now']]
#  82 Positive    2.5   0.789   0.041    [['TEXT:.'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  83 Positive    3.5   0.675   0.041    [['SENTIMENT:pos'], ['SPACY:POS-NUM']]
#  84 Positive    3.6   0.667   0.041    [['TEXT:!'], ['SPACY:POS-PROPN']]
#  85 Positive    1.9   0.884   0.041    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
#  86 Positive    2.2   0.833   0.040    [['SPACY:POS-PROPN'], ['TEXT:.'], ['SPACY:POS-NUM']]
#  87 Positive    5.1   0.563   0.040    [['TEXT:!'], ['SPACY:POS-NOUN']]
#  88 Positive    3.1   0.709   0.040    [['SPACY:POS-DET'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  89 Positive    3.4   0.678   0.040    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['TEXT:.']]
#  90 Positive    3.0   0.713   0.040    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  91 Positive    4.1   0.621   0.039    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['TEXT:.']]
#  92 Positive    2.1   0.838   0.039    [['SENTIMENT:pos'], ['TEXT:call']]
#  93 Positive    1.9   0.868   0.038    [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  94 Positive    2.5   0.764   0.038    [['HYPERNYM3:symbol.n.01']]
#  95 Positive    5.2   0.543   0.037    [['SPACY:POS-ADP'], ['SPACY:POS-NUM'], ['SPACY:POS-NOUN']]
#  96 Positive    3.5   0.648   0.037    [['TEXT:!'], ['SPACY:POS-ADJ']]
#  97 Positive    1.6   0.914   0.037    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  98 Positive    3.7   0.634   0.037    [['SPACY:POS-NUM'], ['SPACY:POS-DET']]
#  99 Positive    4.7   0.565   0.037    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['TEXT:to']]
# 100 Positive    2.2   0.797   0.037    [['SENTIMENT:pos'], ['SPACY:POS-DET'], ['SPACY:POS-PROPN']]

# %% [markdown]
# ## Post-process the patterns

# %%
# Select only patterns of which precision is greater than 0.70
selected_patterns = [p for p in the_patterns if p.precision >= 0.70]
print(f'No. of remaining patterns = {len(selected_patterns)}')
# Out:
# No. of remaining patterns = 54

# %%
# For every pair of patterns (p1, p2), remove pattern p2 if there exists p1 in the patterns set such that p2 is a specialization of p1 and metric of p2 is lower than p1
selected_patterns = remove_specialized_patterns(selected_patterns, metric = lambda x: x.precision)
print(f'No. of remaining patterns = {len(selected_patterns)}')
# Out:
# No. of remaining patterns = 44

# %%
# Print the remaining patterns sorted by precision
selected_patterns = sorted(selected_patterns, key = lambda x: x.precision, reverse = True)
print(f'  #    class Cov(%)    Prec  Gain    Pattern')
for idx, p in enumerate(selected_patterns):
    print(f'{idx+1:>3} {p.support_class}   {round(p.coverage*100, 1):>4}   {p.precision:.3f}   {p.metric:.3f}    {p.get_pattern_id()}')
# Out:
#   #    class Cov(%)    Prec  Gain    Pattern
#   1 Positive    2.2   1.000   0.064    [['TEXT:claim']]
#   2 Positive    1.6   1.000   0.046    [['TEXT:prize']]
#   3 Positive    1.9   0.985   0.053    [['TEXT:.'], ['TEXT:call'], ['SPACY:POS-NUM']]
#   4 Positive    5.1   0.984   0.152    [['TEXT:call'], ['SPACY:POS-NUM']]
#   5 Negative   37.2   0.983   0.067    [['TEXT:i']]
#   6 Positive    1.5   0.982   0.043    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN'], ['TEXT:to'], ['SPACY:POS-NUM']]
#   7 Positive    2.4   0.942   0.060    [['TEXT:mobile']]
#   8 Positive    2.7   0.938   0.067    [['TEXT:txt']]
#   9 Positive    1.7   0.934   0.041    [['SPACY:POS-NUM'], ['TEXT:now']]
#  10 Positive    3.4   0.926   0.082    [['SPACY:POS-PROPN'], ['SPACY:POS-ADP'], ['SPACY:POS-NUM']]
#  11 Positive    2.2   0.923   0.052    [['HYPERNYM3:communication.n.02'], ['SPACY:POS-NUM']]
#  12 Positive    2.2   0.922   0.051    [['HYPERNYM3:win.v.01', 'SENTIMENT:pos']]
#  13 Positive    1.6   0.914   0.037    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  14 Positive    2.2   0.909   0.049    [['HYPERNYM3:cost.n.01']]
#  15 Positive    1.9   0.909   0.042    [['TEXT:to'], ['SPACY:POS-NUM'], ['TEXT:.']]
#  16 Positive    2.2   0.899   0.049    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  17 Positive    2.0   0.890   0.044    [['SPACY:POS-PROPN'], ['TEXT:call']]
#  18 Positive    1.9   0.884   0.041    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-ADP']]
#  19 Positive    2.2   0.873   0.046    [['HYPERNYM3:message.n.02'], ['SPACY:POS-NUM']]
#  20 Positive    1.9   0.868   0.038    [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  21 Positive    5.4   0.856   0.114    [['TEXT:to'], ['SPACY:POS-NUM']]
#  22 Positive    2.4   0.851   0.047    [['TEXT:!'], ['SPACY:POS-NUM']]
#  23 Positive    2.5   0.843   0.048    [['SPACY:POS-NUM'], ['SPACY:POS-PROPN'], ['SPACY:POS-NOUN']]
#  24 Positive    3.6   0.843   0.069    [['SPACY:POS-PROPN'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  25 Positive    2.1   0.838   0.039    [['SENTIMENT:pos'], ['TEXT:call']]
#  26 Positive    2.2   0.838   0.042    [['SPACY:POS-ADP'], ['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
#  27 Positive    2.2   0.833   0.040    [['SPACY:POS-PROPN'], ['TEXT:.'], ['SPACY:POS-NUM']]
#  28 Positive    2.4   0.816   0.043    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
#  29 Positive    6.8   0.811   0.129    [['SPACY:POS-NUM'], ['SPACY:POS-PROPN']]
#  30 Positive    8.9   0.806   0.175    [['SPACY:POS-PROPN'], ['SPACY:POS-NUM']]
#  31 Negative   65.0   0.804   0.049    [['SPACY:POS-ADP']]
#  32 Positive    2.2   0.797   0.037    [['SENTIMENT:pos'], ['SPACY:POS-DET'], ['SPACY:POS-PROPN']]
#  33 Positive    5.7   0.797   0.101    [['TEXT:.'], ['SPACY:POS-NUM']]
#  34 Positive    4.3   0.791   0.073    [['SPACY:POS-NOUN'], ['TEXT:call']]
#  35 Positive    2.5   0.789   0.041    [['TEXT:.'], ['SPACY:POS-NOUN'], ['SPACY:POS-NUM']]
#  36 Negative   54.1   0.785   0.049    [['SPACY:POS-NOUN'], ['SPACY:POS-NOUN']]
#  37 Positive    3.1   0.784   0.051    [['TEXT:.'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  38 Positive    2.5   0.764   0.038    [['HYPERNYM3:symbol.n.01']]
#  39 Negative   39.9   0.761   0.042    [['SENTIMENT:pos']]
#  40 Positive    4.4   0.756   0.067    [['SPACY:POS-SYM']]
#  41 Positive    6.7   0.735   0.100    [['SPACY:POS-NUM'], ['SPACY:POS-NUM']]
#  42 Negative   30.8   0.725   0.048    [['TEXT:to']]
#  43 Positive    7.1   0.722   0.104    [['SPACY:POS-PROPN'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]
#  44 Positive    3.1   0.709   0.040    [['SPACY:POS-DET'], ['SPACY:POS-PROPN'], ['SPACY:POS-PROPN']]

# %% [markdown]
# ## Save the patterns to a json file
# We can use this json file as an input of the web demo tool for exploring the learned patterns and the training data

# %%
grasp_model.to_json('results/case_study_1.json', patterns = selected_patterns, comment = 'Rank and group patterns based on precision. The minimum precision was set at 0.70')
# Out:
# 100%|██████████| 44/44 [00:00<00:00, 358.56it/s]
# 100%|██████████| 44/44 [00:00<00:00, 310.68it/s]
# Successfully dump the results to results/case_study_1.json
